# %%
import tensorflow as tf
import tensorflow_datasets as tfds

# %%
def articles():
    with open('page_revisions_text', 'rb') as text_file:
        pending_article_data = b''
        while True:
            data = text_file.read(1024 * 1024)
            if len(data) == 0:
                break

            articles = data.split(b'\0')
            articles[0] = pending_article_data + articles[0]
            for index, article in enumerate(articles):
                if index + 1 == len(articles):
                    pending_article_data = article
                else:
                    yield article

        print(pending_article_data)
        if len(pending_article_data) != 0:
            yield pending_article_data

# %%
subword_text_encoder = tfds.features.text.SubwordTextEncoder.load_from_file('vocab_4096')

# %% [markdown]
# Да видим как би изглеждало обучение с кодираните статии...

# %%
import os

import numpy as np
import itertools

# %%
BATCH_SIZE = 128
BATCHED_ITEM_LENGTH = 256
BUFFER_SIZE = 256
TYPE=np.uint16

def articles_generator():
    for index, article in enumerate(itertools.islice(articles(), 0, 2000)):
        yield np.array(subword_text_encoder.encode(article + b'\0')[::-1], dtype=TYPE)

    # Pad the article count to the batch size
    # We do this to ensure that no data is dropped
    index += 1
    while index % BATCH_SIZE != 0:
        yield np.array([0], dtype=TYPE)
        index += 1

def subbatches():
    dataset = tf.data.Dataset.from_generator(articles_generator, output_types=TYPE)
    dataset = dataset.shuffle(BUFFER_SIZE)
    dataset = dataset.padded_batch(BATCH_SIZE, padded_shapes=([None]), drop_remainder=True)

    for batch in dataset.as_numpy_iterator():
        remaining = batch[::-1]
        while remaining.shape[1] > 1:
            yield remaining[:, :BATCHED_ITEM_LENGTH + 1]
            remaining = remaining[:, BATCHED_ITEM_LENGTH:]

dataset = tf.data.Dataset.from_generator(subbatches, output_types=TYPE, output_shapes=(BATCH_SIZE, None))
dataset = dataset.map(lambda batch: (batch[:, :-1], batch[:, 1:]))

dataset
# Out:
# <MapDataset shapes: ((128, None), (128, None)), types: (tf.uint16, tf.uint16)>

# %%
def build_model(vocab_size, embedding_dim, rnn_units, batch_size):
    return tf.keras.Sequential([
        tf.keras.layers.Embedding(vocab_size, embedding_dim, batch_input_shape=[batch_size, None]),
        tf.keras.layers.LSTM(rnn_units, return_sequences=True, stateful=True, recurrent_initializer='glorot_uniform'),
        tf.keras.layers.LSTM(rnn_units, return_sequences=True, stateful=True, recurrent_initializer='glorot_uniform'),
        tf.keras.layers.Dense(vocab_size),
    ])

# %%
def loss(labels, logits):
    return tf.keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)

def average_batch_length(true_labels, predictions):
    return tf.shape(true_labels)[1]

model = build_model(vocab_size = subword_text_encoder.vocab_size, embedding_dim=512, rnn_units=1024, batch_size=BATCH_SIZE)
model.compile(optimizer='adam', loss=loss, metrics=[average_batch_length])

# %%
checkpoint_dir = './training_checkpoints' # Directory where the checkpoints will be saved
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt_{epoch}") # Name of the checkpoint files

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_prefix, save_weights_only=True)

# %%
class ModelStateResetter(tf.keras.callbacks.Callback):
    def __init__(self):
        self.last_total_length = 0

    def on_batch_end(self, batch, logs={}):
        average_batch_length = logs.get('average_batch_length', 0)
        total_length = int(round(average_batch_length * (batch + 1)))
        current_batch_length = total_length - self.last_total_length
        self.last_total_length = total_length
        
        if current_batch_length < BATCHED_ITEM_LENGTH:
            self.model.reset_states()
        
model_state_resetter_callback = ModelStateResetter()

# %%
total_epochs = 35

for epoch in range(total_epochs):
    print('Epoch %d/%d' % (epoch + 1, total_epochs))
    model.fit(dataset, callbacks=[checkpoint_callback, model_state_resetter_callback])
# Out:
# Epoch 1/35
# 1307/1307 [==============================] - 900s 688ms/step - loss: 0.7954 - average_batch_length: 254.3145
# Epoch 2/35
# 1354/1354 [==============================] - 924s 682ms/step - loss: 0.5930 - average_batch_length: 254.4993
# Epoch 3/35
# 1307/1307 [==============================] - 897s 686ms/step - loss: 0.5487 - average_batch_length: 254.4858
# Epoch 4/35
# 1381/1381 [==============================] - 945s 684ms/step - loss: 0.4761 - average_batch_length: 254.4866
# Epoch 5/35
# 1327/1327 [==============================] - 907s 684ms/step - loss: 0.4623 - average_batch_length: 254.6526
# Epoch 6/35
# 1317/1317 [==============================] - 890s 676ms/step - loss: 0.4414 - average_batch_length: 254.6826
# Epoch 7/35
# 1395/1395 [==============================] - 920s 659ms/step - loss: 0.3994 - average_batch_length: 254.5756
# Epoch 8/35
# 1335/1335 [==============================] - 892s 668ms/step - loss: 0.4023 - average_batch_length: 254.6749
# Epoch 9/35
# 1276/1276 [==============================] - 866s 679ms/step - loss: 0.4082 - average_batch_length: 254.7680
# Epoch 10/35
# 1297/1297 [==============================] - 854s 658ms/step - loss: 0.3898 - average_batch_length: 254.5297
# Epoch 11/35
# 1335/1335 [==============================] - 878s 658ms/step - loss: 0.3694 - average_batch_length: 254.3700
# Epoch 12/35
# 1354/1354 [==============================] - 891s 658ms/step - loss: 0.3558 - average_batch_length: 254.5480
# Epoch 13/35
# 1264/1264 [==============================] - 831s 658ms/step - loss: 0.3725 - average_batch_length: 254.1962
# Epoch 14/35
# 1335/1335 [==============================] - 878s 658ms/step - loss: 0.3452 - average_batch_length: 254.4704
# Epoch 15/35
# 1286/1286 [==============================] - 847s 658ms/step - loss: 0.3507 - average_batch_length: 254.5233
# Epoch 16/35
# 1331/1331 [==============================] - 876s 658ms/step - loss: 0.3323 - average_batch_length: 254.6056
# Epoch 17/35
# 1314/1314 [==============================] - 865s 658ms/step - loss: 0.3303 - average_batch_length: 254.4871
# Epoch 18/35
# 1352/1352 [==============================] - 891s 659ms/step - loss: 0.3149 - average_batch_length: 254.8217
# Epoch 19/35
# 1356/1356 [==============================] - 894s 659ms/step - loss: 0.3080 - average_batch_length: 254.6040
# Epoch 20/35
# 1362/1362 [==============================] - 897s 659ms/step - loss: 0.3013 - average_batch_length: 254.6711
# Epoch 21/35
# 1365/1365 [==============================] - 899s 658ms/step - loss: 0.2951 - average_batch_length: 254.6711
# Epoch 22/35
# 1354/1354 [==============================] - 892s 659ms/step - loss: 0.2921 - average_batch_length: 254.6928
# Epoch 23/35
# 1331/1331 [==============================] - 876s 658ms/step - loss: 0.2920 - average_batch_length: 254.5139
# Epoch 24/35
# 1353/1353 [==============================] - 892s 659ms/step - loss: 0.2823 - average_batch_length: 254.7709
# Epoch 25/35
# 1355/1355 [==============================] - 892s 658ms/step - loss: 0.2767 - average_batch_length: 254.5026
# Epoch 26/35
# 1368/1368 [==============================] - 900s 658ms/step - loss: 0.2691 - average_batch_length: 254.3823
# Epoch 27/35
# 1351/1351 [==============================] - 890s 659ms/step - loss: 0.2682 - average_batch_length: 254.7639
# Epoch 28/35
# 1298/1298 [==============================] - 855s 659ms/step - loss: 0.2740 - average_batch_length: 254.4931
# Epoch 29/35
# 1307/1307 [==============================] - 860s 658ms/step - loss: 0.2675 - average_batch_length: 254.4889
# Epoch 30/35
# 1337/1337 [==============================] - 880s 659ms/step - loss: 0.2570 - average_batch_length: 254.4503
# Epoch 31/35
# 1331/1331 [==============================] - 877s 659ms/step - loss: 0.2542 - average_batch_length: 254.7220
# Epoch 32/35
# 1314/1314 [==============================] - 864s 657ms/step - loss: 0.2527 - average_batch_length: 254.1651
# Epoch 33/35
# 1327/1327 [==============================] - 873s 658ms/step - loss: 0.2461 - average_batch_length: 254.6745
# Epoch 34/35
# 1274/1274 [==============================] - 839s 659ms/step - loss: 0.2521 - average_batch_length: 254.6593
# Epoch 35/35
# 1349/1349 [==============================] - 888s 658ms/step - loss: 0.2343 - average_batch_length: 254.4900

# %% [markdown]
# За сега не се вижда въществена разлика когато подравняваме текстовете в batch-а в дясно и в ляво.

# %%
with open('page_revisions_text', 'rb') as text_file:
    data = text_file.read()

article = data.split(b'\0')[120]
del data

encoded_article = np.array(subword_text_encoder.encode(article + b'\0'), dtype=TYPE)

print('Raw:', len(article))
print('Encoded:', len(encoded_article))
# Out:
# Raw: 25541
# Encoded: 8222

# %%
import ctypes

class Huffman:
    huffman = ctypes.CDLL('x64/Release/huffman')
    
    huffman.create_tree.restype = ctypes.c_void_p
    huffman.destroy_tree.restype = None
    huffman.load_weights.restype = None
    huffman.create_code_string.restype = ctypes.c_char_p
    
    def __init__(self, category_count):
        self.tree = ctypes.c_void_p(self.huffman.create_tree(category_count))

    def __del__(self):
        self.huffman.destroy_tree(self.tree)
        
    def load_weights(self, weights):
        self.huffman.load_weights(self.tree, weights.ctypes.data_as(ctypes.POINTER(ctypes.c_float)))
    
    def get_code_length(self, category):
        return self.huffman.get_code_length(self.tree, category)

    def get_code_zero_count(self, category):
        return self.huffman.get_code_zero_count(self.tree, category)

# %%
def huffman_archive_size(model, text):
    archived_size = 0
    zeros = 0
    input_eval = np.array([[0]], dtype=TYPE)
    huffman_tree = Huffman(subword_text_encoder.vocab_size)

    text_generated = []

    model.reset_states()

    for index, byte in enumerate(text):
        predictions = model(input_eval)
        predictions = tf.squeeze(predictions, 0) # remove the batch dimension

        weights = tf.nn.softmax(predictions[0]).numpy()
        huffman_tree.load_weights(weights)
        zeros += huffman_tree.get_code_zero_count(byte.item())
        archived_size += huffman_tree.get_code_length(byte.item())

        input_eval = tf.expand_dims([byte], 0)
  
    return archived_size, zeros

# %%
tf.train.latest_checkpoint(checkpoint_dir)
model = build_model(vocab_size = subword_text_encoder.vocab_size, embedding_dim=512, rnn_units=1024, batch_size=1)
model.load_weights(tf.train.latest_checkpoint(checkpoint_dir))
model.build(tf.TensorShape([1, None]))

# %%
archived_size, zeros = huffman_archive_size(model, encoded_article)
print('Compressed length:', archived_size)

compression_ratio = archived_size / (len(encoded_article) * 8)
print('Compression ratio for encoded:', compression_ratio)

compression_ratio = archived_size / (len(article) * 8)
print('Compression ratio for raw:', compression_ratio)

k = (zeros / archived_size)
compression_ratio = compression_ratio * (-k * np.log2(k) - (1-k) * np.log2(1-k))
print('Potential compression ratio with arithmetic coding:', compression_ratio)
# Out:
# Compressed length: 170843
# Compression ratio for encoded: 2.5973455363658475
# Compression ratio for raw: 0.8361213343252026
# Potential compression ratio with arithmetic coding: 0.836075518621219

# %% [markdown]
# Доста любопитно. Нека видим какъв е резултатът за първите 2000 статии.

# %%
total_raw = 0
total_compressed = 0

for index, article in enumerate(itertools.islice(articles(), 0, 2000)):
    raw = (len(article) + 1) * 8
    encoded_article = np.array(subword_text_encoder.encode(article + b'\0'), dtype=TYPE)
    compressed, _ = huffman_archive_size(model, encoded_article)
    total_raw += raw
    total_compressed += compressed
    print('Article %d:\tCompression: %f\tAvg Compression: %f' % (index, compressed/raw, total_compressed/total_raw))
# Out:
# Article 0:	Compression: 1.013889	Avg Compression: 1.013889
# Article 1:	Compression: 1.130952	Avg Compression: 1.095833
# Article 2:	Compression: 1.130102	Avg Compression: 1.111239
# Article 3:	Compression: 1.050000	Avg Compression: 1.098022
# Article 4:	Compression: 1.014286	Avg Compression: 1.081178
# Article 5:	Compression: 0.660256	Avg Compression: 1.004108
# Article 6:	Compression: 0.879414	Avg Compression: 0.879866
# Article 7:	Compression: 0.837838	Avg Compression: 0.879839
# Article 8:	Compression: 0.940625	Avg Compression: 0.879881
# Article 9:	Compression: 0.833333	Avg Compression: 0.879847
# Article 10:	Compression: 1.085526	Avg Compression: 0.879980
# Article 11:	Compression: 0.872159	Avg Compression: 0.879974
# Article 12:	Compression: 0.897727	Avg Compression: 0.879987
# Article 13:	Compression: 1.036184	Avg Compression: 0.880088
# Article 14:	Compression: 0.968085	Avg Compression: 0.880158
# Article 15:	Compression: 1.145833	Avg Compression: 0.880266
# Article 16:	Compression: 0.932143	Avg Compression: 0.880296
# Article 17:	Compression: 1.156250	Avg Compression: 0.880408
# Article 18:	Compression: 0.832932	Avg Compression: 0.858850
# Article 19:	Compression: 0.814394	Avg Compression: 0.858836
# Article 20:	Compression: 0.878571	Avg Compression: 0.858843
# Article 21:	Compression: 0.805921	Avg Compression: 0.858824
# Article 22:	Compression: 1.083333	Avg Compression: 0.858886
# Article 23:	Compression: 1.048077	Avg Compression: 0.858932
# Article 24:	Compression: 0.985294	Avg Compression: 0.858971
# Article 25:	Compression: 1.094697	Avg Compression: 0.859043
# Article 26:	Compression: 1.032609	Avg Compression: 0.859079
# Article 27:	Compression: 0.899890	Avg Compression: 0.862160
# Article 28:	Compression: 0.949324	Avg Compression: 0.862188
# Article 29:	Compression: 0.909483	Avg Compression: 0.862211
# Article 30:	Compression: 0.933422	Avg Compression: 0.868053
# Article 31:	Compression: 1.182292	Avg Compression: 0.868112
# Article 32:	Compression: 1.164773	Avg Compression: 0.868163
# Article 33:	Compression: 1.010870	Avg Compression: 0.868188
# Article 34:	Compression: 1.028409	Avg Compression: 0.868216
# Article 35:	Compression: 1.181818	Avg Compression: 0.868269
# Article 36:	Compression: 1.026042	Avg Compression: 0.868299
# Article 37:	Compression: 1.101190	Avg Compression: 0.868337
# Article 38:	Compression: 1.107143	Avg Compression: 0.868376
# Article 39:	Compression: 1.084821	Avg Compression: 0.868423
# Article 40:	Compression: 1.100000	Avg Compression: 0.868477
# Article 41:	Compression: 1.072917	Avg Compression: 0.868516
# Article 42:	Compression: 0.970588	Avg Compression: 0.868556
# Article 43:	Compression: 1.034884	Avg Compression: 0.868612
# Article 44:	Compression: 1.020833	Avg Compression: 0.868662
# Article 45:	Compression: 1.020833	Avg Compression: 0.868711
# Article 46:	Compression: 1.057692	Avg Compression: 0.868769
# Article 47:	Compression: 1.118590	Avg Compression: 0.868844
# Article 48:	Compression: 0.721774	Avg Compression: 0.868809
# Article 49:	Compression: 1.151786	Avg Compression: 0.868870
# Article 50:	Compression: 1.081522	Avg Compression: 0.868908
# Article 51:	Compression: 1.053030	Avg Compression: 0.868956
# Article 52:	Compression: 1.087963	Avg Compression: 0.869001
# Article 53:	Compression: 0.991071	Avg Compression: 0.869028
# Article 54:	Compression: 1.045000	Avg Compression: 0.869062
# Article 55:	Compression: 1.016892	Avg Compression: 0.869105
# Article 56:	Compression: 1.156250	Avg Compression: 0.869158
# Article 57:	Compression: 0.976190	Avg Compression: 0.869175
# Article 58:	Compression: 1.145161	Avg Compression: 0.869242
# Article 59:	Compression: 1.098958	Avg Compression: 0.869284
# Article 60:	Compression: 0.960714	Avg Compression: 0.869309
# Article 61:	Compression: 1.022727	Avg Compression: 0.869348
# Article 62:	Compression: 1.066964	Avg Compression: 0.869391
# Article 63:	Compression: 0.899194	Avg Compression: 0.869398
# Article 64:	Compression: 0.895833	Avg Compression: 0.869403
# Article 65:	Compression: 0.931818	Avg Compression: 0.869414
# Article 66:	Compression: 0.942708	Avg Compression: 0.869428
# Article 67:	Compression: 0.982143	Avg Compression: 0.869452
# Article 68:	Compression: 1.077586	Avg Compression: 0.869499
# Article 69:	Compression: 0.941667	Avg Compression: 0.869524
# Article 70:	Compression: 0.883333	Avg Compression: 0.869527
# Article 71:	Compression: 1.117188	Avg Compression: 0.869588
# Article 72:	Compression: 1.052419	Avg Compression: 0.869632
# Article 73:	Compression: 0.712121	Avg Compression: 0.869592
# Article 74:	Compression: 0.979651	Avg Compression: 0.869629
# Article 75:	Compression: 1.120968	Avg Compression: 0.869689
# Article 76:	Compression: 1.032609	Avg Compression: 0.869718
# Article 77:	Compression: 0.910714	Avg Compression: 0.869729
# Article 78:	Compression: 0.792763	Avg Compression: 0.869706
# Article 79:	Compression: 1.051471	Avg Compression: 0.869754
# Article 80:	Compression: 1.075758	Avg Compression: 0.869806
# Article 81:	Compression: 0.955128	Avg Compression: 0.869832
# Article 82:	Compression: 0.956250	Avg Compression: 0.869845
# Article 83:	Compression: 0.806548	Avg Compression: 0.869825
# Article 84:	Compression: 0.915742	Avg Compression: 0.873410
# Article 85:	Compression: 0.915441	Avg Compression: 0.873420
# Article 86:	Compression: 0.848485	Avg Compression: 0.873414
# Article 87:	Compression: 0.806548	Avg Compression: 0.873394
# Article 88:	Compression: 0.995690	Avg Compression: 0.873419
# Article 89:	Compression: 0.767361	Avg Compression: 0.873392
# Article 90:	Compression: 1.146552	Avg Compression: 0.873448
# Article 91:	Compression: 0.935185	Avg Compression: 0.873460
# Article 92:	Compression: 0.930841	Avg Compression: 0.880787
# Article 93:	Compression: 0.869318	Avg Compression: 0.880785
# Article 94:	Compression: 0.960653	Avg Compression: 0.889728
# Article 95:	Compression: 0.974265	Avg Compression: 0.889744
# Article 96:	Compression: 0.889692	Avg Compression: 0.889728
# Article 97:	Compression: 0.892630	Avg Compression: 0.890148
# Article 98:	Compression: 0.857751	Avg Compression: 0.890030
# Article 99:	Compression: 0.956250	Avg Compression: 0.890035
# Article 100:	Compression: 0.941667	Avg Compression: 0.890042
# Article 101:	Compression: 1.019886	Avg Compression: 0.890061
# Article 102:	Compression: 0.947222	Avg Compression: 0.890069
# Article 103:	Compression: 0.928241	Avg Compression: 0.890076
# Article 104:	Compression: 0.930804	Avg Compression: 0.890083
# Article 105:	Compression: 0.921569	Avg Compression: 0.890089
# Article 106:	Compression: 1.000000	Avg Compression: 0.890104
# Article 107:	Compression: 1.164583	Avg Compression: 0.890157
# Article 108:	Compression: 1.004808	Avg Compression: 0.890176
# Article 109:	Compression: 1.060096	Avg Compression: 0.890205
# Article 110:	Compression: 1.133721	Avg Compression: 0.890239
# Article 111:	Compression: 1.175000	Avg Compression: 0.890290
# Article 112:	Compression: 0.994639	Avg Compression: 0.893604
# Article 113:	Compression: 0.935185	Avg Compression: 0.893607
# Article 114:	Compression: 0.956250	Avg Compression: 0.893611
# Article 115:	Compression: 0.940217	Avg Compression: 0.893618
# Article 116:	Compression: 0.831250	Avg Compression: 0.893614
# Article 117:	Compression: 0.939340	Avg Compression: 0.893774
# Article 118:	Compression: 1.003289	Avg Compression: 0.893787
# Article 119:	Compression: 0.861215	Avg Compression: 0.893425
# Article 120:	Compression: 0.836089	Avg Compression: 0.889229
# Article 121:	Compression: 0.970757	Avg Compression: 0.890366
# Article 122:	Compression: 0.921296	Avg Compression: 0.890368
# Article 123:	Compression: 0.895601	Avg Compression: 0.890914
# Article 124:	Compression: 0.942027	Avg Compression: 0.891144
# Article 125:	Compression: 0.974265	Avg Compression: 0.891151
# Article 126:	Compression: 1.133065	Avg Compression: 0.891170
# Article 127:	Compression: 0.945519	Avg Compression: 0.891754
# Article 128:	Compression: 0.844697	Avg Compression: 0.891750
# Article 129:	Compression: 0.800000	Avg Compression: 0.891742
# Article 130:	Compression: 0.756579	Avg Compression: 0.891730
# Article 131:	Compression: 0.985294	Avg Compression: 0.891737
# Article 132:	Compression: 0.871675	Avg Compression: 0.891286
# Article 133:	Compression: 0.825000	Avg Compression: 0.891279
# Article 134:	Compression: 0.932143	Avg Compression: 0.891283
# Article 135:	Compression: 1.033088	Avg Compression: 0.891295
# Article 136:	Compression: 0.777174	Avg Compression: 0.891282
# Article 137:	Compression: 0.972222	Avg Compression: 0.891289
# Article 138:	Compression: 0.941532	Avg Compression: 0.891297
# Article 139:	Compression: 0.927141	Avg Compression: 0.893333
# Article 140:	Compression: 0.907405	Avg Compression: 0.894262
# Article 141:	Compression: 0.887981	Avg Compression: 0.894214
# Article 142:	Compression: 0.987535	Avg Compression: 0.895795
# Article 143:	Compression: 0.879258	Avg Compression: 0.895640
# Article 144:	Compression: 1.057692	Avg Compression: 0.895653
# Article 145:	Compression: 0.950409	Avg Compression: 0.897606
# Article 146:	Compression: 0.883257	Avg Compression: 0.897370
# Article 147:	Compression: 0.903036	Avg Compression: 0.897522
# Article 148:	Compression: 0.832202	Avg Compression: 0.893723
# Article 149:	Compression: 0.824668	Avg Compression: 0.889366
# Article 150:	Compression: 0.996429	Avg Compression: 0.889372
# Article 151:	Compression: 0.819949	Avg Compression: 0.888557
# Article 152:	Compression: 0.869929	Avg Compression: 0.886852
# Article 153:	Compression: 0.823015	Avg Compression: 0.885389
# Article 154:	Compression: 1.038043	Avg Compression: 0.885394
# Article 155:	Compression: 0.923655	Avg Compression: 0.887064
# Article 156:	Compression: 0.854769	Avg Compression: 0.884987
# Article 157:	Compression: 1.000483	Avg Compression: 0.887085
# Article 158:	Compression: 1.049854	Avg Compression: 0.887303
# Article 159:	Compression: 0.934329	Avg Compression: 0.887619
# Article 160:	Compression: 1.156250	Avg Compression: 0.887628
# Article 161:	Compression: 0.821394	Avg Compression: 0.887272
# Article 162:	Compression: 0.925325	Avg Compression: 0.888601
# Article 163:	Compression: 0.900730	Avg Compression: 0.888646
# Article 164:	Compression: 0.863870	Avg Compression: 0.887170
# Article 165:	Compression: 1.087209	Avg Compression: 0.887180
# Article 166:	Compression: 0.999137	Avg Compression: 0.887518
# Article 167:	Compression: 1.065000	Avg Compression: 0.887523
# Article 168:	Compression: 1.000000	Avg Compression: 0.887526
# Article 169:	Compression: 0.905706	Avg Compression: 0.887754
# Article 170:	Compression: 0.949324	Avg Compression: 0.889715
# Article 171:	Compression: 0.886660	Avg Compression: 0.889562
# Article 172:	Compression: 0.860714	Avg Compression: 0.889561
# Article 173:	Compression: 0.895249	Avg Compression: 0.889587
# Article 174:	Compression: 0.990385	Avg Compression: 0.889591
# Article 175:	Compression: 0.950357	Avg Compression: 0.890307
# Article 176:	Compression: 0.942693	Avg Compression: 0.891078
# Article 177:	Compression: 0.814394	Avg Compression: 0.891075
# Article 178:	Compression: 0.864286	Avg Compression: 0.891074
# Article 179:	Compression: 0.792763	Avg Compression: 0.891070
# Article 180:	Compression: 1.051471	Avg Compression: 0.891076
# Article 181:	Compression: 1.075758	Avg Compression: 0.891082
# Article 182:	Compression: 0.994318	Avg Compression: 0.891085
# Article 183:	Compression: 0.884375	Avg Compression: 0.891084
# Article 184:	Compression: 0.893750	Avg Compression: 0.891084
# Article 185:	Compression: 1.002907	Avg Compression: 0.891089
# Article 186:	Compression: 1.002907	Avg Compression: 0.891094
# Article 187:	Compression: 1.002907	Avg Compression: 0.891099
# Article 188:	Compression: 0.899372	Avg Compression: 0.891132
# Article 189:	Compression: 0.841873	Avg Compression: 0.891006
# Article 190:	Compression: 0.878472	Avg Compression: 0.891005
# Article 191:	Compression: 0.962193	Avg Compression: 0.891032
# Article 192:	Compression: 1.069196	Avg Compression: 0.891042
# Article 193:	Compression: 0.850074	Avg Compression: 0.888844
# Article 194:	Compression: 0.879064	Avg Compression: 0.888606
# Article 195:	Compression: 0.963546	Avg Compression: 0.889213
# Article 196:	Compression: 0.977273	Avg Compression: 0.889215
# Article 197:	Compression: 0.940789	Avg Compression: 0.889216
# Article 198:	Compression: 0.901052	Avg Compression: 0.889593
# Article 199:	Compression: 0.838910	Avg Compression: 0.889417
# Article 200:	Compression: 0.969828	Avg Compression: 0.889419
# Article 201:	Compression: 0.909090	Avg Compression: 0.889863
# Article 202:	Compression: 0.908733	Avg Compression: 0.890162
# Article 203:	Compression: 1.023438	Avg Compression: 0.890166
# Article 204:	Compression: 1.047095	Avg Compression: 0.890453
# Article 205:	Compression: 1.057150	Avg Compression: 0.890741
# Article 206:	Compression: 0.857232	Avg Compression: 0.890314
# Article 207:	Compression: 0.896171	Avg Compression: 0.890329
# Article 208:	Compression: 1.013889	Avg Compression: 0.890333
# Article 209:	Compression: 0.950000	Avg Compression: 0.890335
# Article 210:	Compression: 0.950000	Avg Compression: 0.890337
# Article 211:	Compression: 0.950000	Avg Compression: 0.890338
# Article 212:	Compression: 0.880525	Avg Compression: 0.890028
# Article 213:	Compression: 0.818170	Avg Compression: 0.889381
# Article 214:	Compression: 0.840763	Avg Compression: 0.889293
# Article 215:	Compression: 1.482143	Avg Compression: 0.889303
# Article 216:	Compression: 0.840278	Avg Compression: 0.889302
# Article 217:	Compression: 0.840278	Avg Compression: 0.889300
# Article 218:	Compression: 0.960938	Avg Compression: 0.889302
# Article 219:	Compression: 0.956250	Avg Compression: 0.889303
# Article 220:	Compression: 0.872434	Avg Compression: 0.889275
# Article 221:	Compression: 1.026042	Avg Compression: 0.889278
# Article 222:	Compression: 0.882590	Avg Compression: 0.889229
# Article 223:	Compression: 0.860714	Avg Compression: 0.889228
# Article 224:	Compression: 0.869424	Avg Compression: 0.889059
# Article 225:	Compression: 0.994033	Avg Compression: 0.889092
# Article 226:	Compression: 0.868093	Avg Compression: 0.888900
# Article 227:	Compression: 0.978265	Avg Compression: 0.889876
# Article 228:	Compression: 0.884541	Avg Compression: 0.889863
# Article 229:	Compression: 1.013514	Avg Compression: 0.889867
# Article 230:	Compression: 0.860005	Avg Compression: 0.889779
# Article 231:	Compression: 0.880953	Avg Compression: 0.889487
# Article 232:	Compression: 0.866876	Avg Compression: 0.889436
# Article 233:	Compression: 0.903372	Avg Compression: 0.889723
# Article 234:	Compression: 0.875042	Avg Compression: 0.889228
# Article 235:	Compression: 0.881513	Avg Compression: 0.889172
# Article 236:	Compression: 0.857114	Avg Compression: 0.889088
# Article 237:	Compression: 0.978906	Avg Compression: 0.889352
# Article 238:	Compression: 0.799698	Avg Compression: 0.889249
# Article 239:	Compression: 1.010000	Avg Compression: 0.889251
# Article 240:	Compression: 0.860884	Avg Compression: 0.888882
# Article 241:	Compression: 0.971391	Avg Compression: 0.889049
# Article 242:	Compression: 1.029129	Avg Compression: 0.889828
# Article 243:	Compression: 0.886874	Avg Compression: 0.889824
# Article 244:	Compression: 0.970333	Avg Compression: 0.890209
# Article 245:	Compression: 0.823149	Avg Compression: 0.890010
# Article 246:	Compression: 0.991071	Avg Compression: 0.890012
# Article 247:	Compression: 0.946962	Avg Compression: 0.890048
# Article 248:	Compression: 0.911700	Avg Compression: 0.890147
# Article 249:	Compression: 0.966913	Avg Compression: 0.890256
# Article 250:	Compression: 0.868379	Avg Compression: 0.890183
# Article 251:	Compression: 0.864352	Avg Compression: 0.890155
# Article 252:	Compression: 1.092593	Avg Compression: 0.890158
# Article 253:	Compression: 1.035430	Avg Compression: 0.892262
# Article 254:	Compression: 0.914286	Avg Compression: 0.892262
# Article 255:	Compression: 1.013889	Avg Compression: 0.892265
# Article 256:	Compression: 0.880536	Avg Compression: 0.892076
# Article 257:	Compression: 0.936681	Avg Compression: 0.892458
# Article 258:	Compression: 0.847015	Avg Compression: 0.891974
# Article 259:	Compression: 1.025000	Avg Compression: 0.891976
# Article 260:	Compression: 1.069149	Avg Compression: 0.891981
# Article 261:	Compression: 0.834057	Avg Compression: 0.891581
# Article 262:	Compression: 1.007738	Avg Compression: 0.891696
# Article 263:	Compression: 0.934294	Avg Compression: 0.892242
# Article 264:	Compression: 0.925753	Avg Compression: 0.892743
# Article 265:	Compression: 1.031250	Avg Compression: 0.892745
# Article 266:	Compression: 0.874713	Avg Compression: 0.892452
# Article 267:	Compression: 0.915810	Avg Compression: 0.892752
# Article 268:	Compression: 0.917969	Avg Compression: 0.892753
# Article 269:	Compression: 0.884046	Avg Compression: 0.892667
# Article 270:	Compression: 0.894381	Avg Compression: 0.892673
# Article 271:	Compression: 0.844983	Avg Compression: 0.892549
# Article 272:	Compression: 0.838472	Avg Compression: 0.892387
# Article 273:	Compression: 0.839692	Avg Compression: 0.892350
# Article 274:	Compression: 0.975315	Avg Compression: 0.892458
# Article 275:	Compression: 0.893634	Avg Compression: 0.892459
# Article 276:	Compression: 0.781870	Avg Compression: 0.892329
# Article 277:	Compression: 0.893887	Avg Compression: 0.892338
# Article 278:	Compression: 0.966756	Avg Compression: 0.892767
# Article 279:	Compression: 0.896379	Avg Compression: 0.892790
# Article 280:	Compression: 0.895833	Avg Compression: 0.892790
# Article 281:	Compression: 0.898364	Avg Compression: 0.892906
# Article 282:	Compression: 0.944926	Avg Compression: 0.893021
# Article 283:	Compression: 0.853467	Avg Compression: 0.892653
# Article 284:	Compression: 0.986020	Avg Compression: 0.893866
# Article 285:	Compression: 0.766304	Avg Compression: 0.893863
# Article 286:	Compression: 0.800000	Avg Compression: 0.893861
# Article 287:	Compression: 1.251083	Avg Compression: 0.894400
# Article 288:	Compression: 0.889046	Avg Compression: 0.894395
# Article 289:	Compression: 0.800000	Avg Compression: 0.894393
# Article 290:	Compression: 1.094697	Avg Compression: 0.894895
# Article 291:	Compression: 0.977273	Avg Compression: 0.894896
# Article 292:	Compression: 0.924862	Avg Compression: 0.895939
# Article 293:	Compression: 0.884970	Avg Compression: 0.895611
# Article 294:	Compression: 0.948802	Avg Compression: 0.896218
# Article 295:	Compression: 0.905095	Avg Compression: 0.896289
# Article 296:	Compression: 0.926101	Avg Compression: 0.896767
# Article 297:	Compression: 1.185000	Avg Compression: 0.896770
# Article 298:	Compression: 1.107143	Avg Compression: 0.896774
# Article 299:	Compression: 0.924421	Avg Compression: 0.897252
# Article 300:	Compression: 0.894606	Avg Compression: 0.897217
# Article 301:	Compression: 0.915317	Avg Compression: 0.897388
# Article 302:	Compression: 0.838752	Avg Compression: 0.896966
# Article 303:	Compression: 0.903846	Avg Compression: 0.896966
# Article 304:	Compression: 0.833926	Avg Compression: 0.896093
# Article 305:	Compression: 0.827280	Avg Compression: 0.895322
# Article 306:	Compression: 0.867059	Avg Compression: 0.895198
# Article 307:	Compression: 0.985294	Avg Compression: 0.895200
# Article 308:	Compression: 0.929435	Avg Compression: 0.895201
# Article 309:	Compression: 0.859375	Avg Compression: 0.895200
# Article 310:	Compression: 1.099265	Avg Compression: 0.895203
# Article 311:	Compression: 0.973837	Avg Compression: 0.895205
# Article 312:	Compression: 0.805921	Avg Compression: 0.895203
# Article 313:	Compression: 0.945312	Avg Compression: 0.895205
# Article 314:	Compression: 1.094697	Avg Compression: 0.895208
# Article 315:	Compression: 0.871875	Avg Compression: 0.895207
# Article 316:	Compression: 0.973837	Avg Compression: 0.895209
# Article 317:	Compression: 0.934643	Avg Compression: 0.895260
# Article 318:	Compression: 0.907446	Avg Compression: 0.895577
# Article 319:	Compression: 0.836701	Avg Compression: 0.895520
# Article 320:	Compression: 1.070833	Avg Compression: 0.895523
# Article 321:	Compression: 0.803058	Avg Compression: 0.895494
# Article 322:	Compression: 0.897200	Avg Compression: 0.895501
# Article 323:	Compression: 0.812866	Avg Compression: 0.894057
# Article 324:	Compression: 0.863801	Avg Compression: 0.893447
# Article 325:	Compression: 0.991216	Avg Compression: 0.893580
# Article 326:	Compression: 0.771051	Avg Compression: 0.891380
# Article 327:	Compression: 0.823433	Avg Compression: 0.890738
# Article 328:	Compression: 1.003289	Avg Compression: 0.890740
# Article 329:	Compression: 0.906008	Avg Compression: 0.890747
# Article 330:	Compression: 0.897525	Avg Compression: 0.890749
# Article 331:	Compression: 0.995629	Avg Compression: 0.890879
# Article 332:	Compression: 0.905160	Avg Compression: 0.890887
# Article 333:	Compression: 0.869932	Avg Compression: 0.890386
# Article 334:	Compression: 0.883804	Avg Compression: 0.890367
# Article 335:	Compression: 0.861553	Avg Compression: 0.890226
# Article 336:	Compression: 1.054274	Avg Compression: 0.890547
# Article 337:	Compression: 1.007340	Avg Compression: 0.890677
# Article 338:	Compression: 1.012927	Avg Compression: 0.890733
# Article 339:	Compression: 0.950892	Avg Compression: 0.890836
# Article 340:	Compression: 0.887937	Avg Compression: 0.890801
# Article 341:	Compression: 0.793174	Avg Compression: 0.890748
# Article 342:	Compression: 0.846356	Avg Compression: 0.890704
# Article 343:	Compression: 1.170139	Avg Compression: 0.890708
# Article 344:	Compression: 0.976151	Avg Compression: 0.891062
# Article 345:	Compression: 0.980333	Avg Compression: 0.891557
# Article 346:	Compression: 0.859099	Avg Compression: 0.891225
# Article 347:	Compression: 1.196541	Avg Compression: 0.891243
# Article 348:	Compression: 0.933988	Avg Compression: 0.891569
# Article 349:	Compression: 0.932189	Avg Compression: 0.891989
# Article 350:	Compression: 1.087500	Avg Compression: 0.891991
# Article 351:	Compression: 1.118421	Avg Compression: 0.891992
# Article 352:	Compression: 0.910500	Avg Compression: 0.892223
# Article 353:	Compression: 0.871875	Avg Compression: 0.892222
# Article 354:	Compression: 0.909590	Avg Compression: 0.892483
# Article 355:	Compression: 0.927782	Avg Compression: 0.892559
# Article 356:	Compression: 0.906957	Avg Compression: 0.892580
# Article 357:	Compression: 0.893868	Avg Compression: 0.892580
# Article 358:	Compression: 0.932143	Avg Compression: 0.892581
# Article 359:	Compression: 0.972222	Avg Compression: 0.892583
# Article 360:	Compression: 0.980263	Avg Compression: 0.892585
# Article 361:	Compression: 0.833333	Avg Compression: 0.892584
# Article 362:	Compression: 1.041071	Avg Compression: 0.892588
# Article 363:	Compression: 0.872159	Avg Compression: 0.892587
# Article 364:	Compression: 0.956169	Avg Compression: 0.892589
# Article 365:	Compression: 1.036972	Avg Compression: 0.892593
# Article 366:	Compression: 1.006250	Avg Compression: 0.892596
# Article 367:	Compression: 1.125000	Avg Compression: 0.892598
# Article 368:	Compression: 0.923907	Avg Compression: 0.892649
# Article 369:	Compression: 0.815445	Avg Compression: 0.892469
# Article 370:	Compression: 0.817857	Avg Compression: 0.892468
# Article 371:	Compression: 0.746711	Avg Compression: 0.892466
# Article 372:	Compression: 0.944853	Avg Compression: 0.892466
# Article 373:	Compression: 1.000000	Avg Compression: 0.892468
# Article 374:	Compression: 0.818750	Avg Compression: 0.892466
# Article 375:	Compression: 0.825000	Avg Compression: 0.892465
# Article 376:	Compression: 0.924419	Avg Compression: 0.892466
# Article 377:	Compression: 0.996324	Avg Compression: 0.892467
# Article 378:	Compression: 0.924419	Avg Compression: 0.892468
# Article 379:	Compression: 0.803030	Avg Compression: 0.892467
# Article 380:	Compression: 0.994681	Avg Compression: 0.892468
# Article 381:	Compression: 0.934659	Avg Compression: 0.892469
# Article 382:	Compression: 1.053030	Avg Compression: 0.892471
# Article 383:	Compression: 0.850191	Avg Compression: 0.892185
# Article 384:	Compression: 0.898843	Avg Compression: 0.892255
# Article 385:	Compression: 1.004286	Avg Compression: 0.892443
# Article 386:	Compression: 0.880030	Avg Compression: 0.892394
# Article 387:	Compression: 0.907910	Avg Compression: 0.892485
# Article 388:	Compression: 0.979381	Avg Compression: 0.892503
# Article 389:	Compression: 0.881712	Avg Compression: 0.892409
# Article 390:	Compression: 0.866712	Avg Compression: 0.892180
# Article 391:	Compression: 0.878818	Avg Compression: 0.892101
# Article 392:	Compression: 0.908117	Avg Compression: 0.892182
# Article 393:	Compression: 0.944563	Avg Compression: 0.892376
# Article 394:	Compression: 0.872126	Avg Compression: 0.892237
# Article 395:	Compression: 0.927814	Avg Compression: 0.892351
# Article 396:	Compression: 0.990065	Avg Compression: 0.892697
# Article 397:	Compression: 0.806818	Avg Compression: 0.892696
# Article 398:	Compression: 0.856531	Avg Compression: 0.892195
# Article 399:	Compression: 0.906150	Avg Compression: 0.892227
# Article 400:	Compression: 0.882353	Avg Compression: 0.892227
# Article 401:	Compression: 0.870990	Avg Compression: 0.892214
# Article 402:	Compression: 1.136905	Avg Compression: 0.892215
# Article 403:	Compression: 0.885844	Avg Compression: 0.892114
# Article 404:	Compression: 0.879573	Avg Compression: 0.891860
# Article 405:	Compression: 0.874748	Avg Compression: 0.891678
# Article 406:	Compression: 0.971462	Avg Compression: 0.891916
# Article 407:	Compression: 0.914774	Avg Compression: 0.891965
# Article 408:	Compression: 0.880957	Avg Compression: 0.891940
# Article 409:	Compression: 0.899925	Avg Compression: 0.891945
# Article 410:	Compression: 0.849856	Avg Compression: 0.891851
# Article 411:	Compression: 0.935185	Avg Compression: 0.891851
# Article 412:	Compression: 0.923562	Avg Compression: 0.891998
# Article 413:	Compression: 1.054167	Avg Compression: 0.891999
# Article 414:	Compression: 0.953726	Avg Compression: 0.892672
# Article 415:	Compression: 1.012255	Avg Compression: 0.892702
# Article 416:	Compression: 0.870019	Avg Compression: 0.892569
# Article 417:	Compression: 0.906196	Avg Compression: 0.892588
# Article 418:	Compression: 0.914407	Avg Compression: 0.892647
# Article 419:	Compression: 0.905414	Avg Compression: 0.892943
# Article 420:	Compression: 0.864673	Avg Compression: 0.892684
# Article 421:	Compression: 0.845446	Avg Compression: 0.892516
# Article 422:	Compression: 0.818790	Avg Compression: 0.892475
# Article 423:	Compression: 0.932190	Avg Compression: 0.892484
# Article 424:	Compression: 0.856160	Avg Compression: 0.892447
# Article 425:	Compression: 0.966667	Avg Compression: 0.892455
# Article 426:	Compression: 0.921696	Avg Compression: 0.892664
# Article 427:	Compression: 0.833146	Avg Compression: 0.892244
# Article 428:	Compression: 0.919978	Avg Compression: 0.892349
# Article 429:	Compression: 1.010854	Avg Compression: 0.892538
# Article 430:	Compression: 0.893509	Avg Compression: 0.892540
# Article 431:	Compression: 1.024038	Avg Compression: 0.892541
# Article 432:	Compression: 1.019385	Avg Compression: 0.892561
# Article 433:	Compression: 0.858901	Avg Compression: 0.891814
# Article 434:	Compression: 0.856405	Avg Compression: 0.891659
# Article 435:	Compression: 1.005208	Avg Compression: 0.891660
# Article 436:	Compression: 0.966898	Avg Compression: 0.891834
# Article 437:	Compression: 0.937295	Avg Compression: 0.892018
# Article 438:	Compression: 0.961871	Avg Compression: 0.892227
# Article 439:	Compression: 0.998989	Avg Compression: 0.892401
# Article 440:	Compression: 0.999490	Avg Compression: 0.892625
# Article 441:	Compression: 0.999446	Avg Compression: 0.892757
# Article 442:	Compression: 0.855753	Avg Compression: 0.892456
# Article 443:	Compression: 0.840454	Avg Compression: 0.892389
# Article 444:	Compression: 0.866003	Avg Compression: 0.892108
# Article 445:	Compression: 0.978964	Avg Compression: 0.892122
# Article 446:	Compression: 0.863463	Avg Compression: 0.892034
# Article 447:	Compression: 0.692308	Avg Compression: 0.892031
# Article 448:	Compression: 0.962500	Avg Compression: 0.892032
# Article 449:	Compression: 0.852207	Avg Compression: 0.891884
# Article 450:	Compression: 0.949396	Avg Compression: 0.891908
# Article 451:	Compression: 1.099068	Avg Compression: 0.892262
# Article 452:	Compression: 0.923611	Avg Compression: 0.892262
# Article 453:	Compression: 0.963383	Avg Compression: 0.892513
# Article 454:	Compression: 0.890032	Avg Compression: 0.892512
# Article 455:	Compression: 1.100352	Avg Compression: 0.892641
# Article 456:	Compression: 1.190789	Avg Compression: 0.892644
# Article 457:	Compression: 0.901786	Avg Compression: 0.892644
# Article 458:	Compression: 0.901786	Avg Compression: 0.892644
# Article 459:	Compression: 0.829453	Avg Compression: 0.892599
# Article 460:	Compression: 0.850435	Avg Compression: 0.892565
# Article 461:	Compression: 0.843929	Avg Compression: 0.892340
# Article 462:	Compression: 1.013889	Avg Compression: 0.892340
# Article 463:	Compression: 0.941971	Avg Compression: 0.892491
# Article 464:	Compression: 1.119792	Avg Compression: 0.892492
# Article 465:	Compression: 0.953125	Avg Compression: 0.892493
# Article 466:	Compression: 0.839073	Avg Compression: 0.892140
# Article 467:	Compression: 0.870039	Avg Compression: 0.892052
# Article 468:	Compression: 0.958781	Avg Compression: 0.892098
# Article 469:	Compression: 0.875919	Avg Compression: 0.892076
# Article 470:	Compression: 0.912614	Avg Compression: 0.892103
# Article 471:	Compression: 0.987360	Avg Compression: 0.892125
# Article 472:	Compression: 0.968476	Avg Compression: 0.892161
# Article 473:	Compression: 1.213542	Avg Compression: 0.892163
# Article 474:	Compression: 1.213542	Avg Compression: 0.892165
# Article 475:	Compression: 1.213542	Avg Compression: 0.892167
# Article 476:	Compression: 1.213542	Avg Compression: 0.892169
# Article 477:	Compression: 1.213542	Avg Compression: 0.892171
# Article 478:	Compression: 1.213542	Avg Compression: 0.892173
# Article 479:	Compression: 1.213542	Avg Compression: 0.892175
# Article 480:	Compression: 1.213542	Avg Compression: 0.892177
# Article 481:	Compression: 1.213542	Avg Compression: 0.892179
# Article 482:	Compression: 1.213542	Avg Compression: 0.892181
# Article 483:	Compression: 1.213542	Avg Compression: 0.892183
# Article 484:	Compression: 1.213542	Avg Compression: 0.892185
# Article 485:	Compression: 0.929819	Avg Compression: 0.892189
# Article 486:	Compression: 0.993364	Avg Compression: 0.892421
# Article 487:	Compression: 0.906965	Avg Compression: 0.892443
# Article 488:	Compression: 0.971058	Avg Compression: 0.892462
# Article 489:	Compression: 0.859459	Avg Compression: 0.892261
# Article 490:	Compression: 1.044101	Avg Compression: 0.892347
# Article 491:	Compression: 0.966322	Avg Compression: 0.892474
# Article 492:	Compression: 1.165450	Avg Compression: 0.892836
# Article 493:	Compression: 0.874525	Avg Compression: 0.892819
# Article 494:	Compression: 0.980769	Avg Compression: 0.892820
# Article 495:	Compression: 1.057298	Avg Compression: 0.893016
# Article 496:	Compression: 0.899194	Avg Compression: 0.893016
# Article 497:	Compression: 1.003989	Avg Compression: 0.893024
# Article 498:	Compression: 0.907114	Avg Compression: 0.893031
# Article 499:	Compression: 0.838182	Avg Compression: 0.893016
# Article 500:	Compression: 0.885056	Avg Compression: 0.893013
# Article 501:	Compression: 0.956081	Avg Compression: 0.893013
# Article 502:	Compression: 0.871691	Avg Compression: 0.892998
# Article 503:	Compression: 0.975806	Avg Compression: 0.892999
# Article 504:	Compression: 0.908686	Avg Compression: 0.893021
# Article 505:	Compression: 0.973958	Avg Compression: 0.893021
# Article 506:	Compression: 0.920382	Avg Compression: 0.893080
# Article 507:	Compression: 1.007812	Avg Compression: 0.893081
# Article 508:	Compression: 0.863996	Avg Compression: 0.893046
# Article 509:	Compression: 0.902141	Avg Compression: 0.893057
# Article 510:	Compression: 0.915002	Avg Compression: 0.893124
# Article 511:	Compression: 0.973958	Avg Compression: 0.893124
# Article 512:	Compression: 0.917558	Avg Compression: 0.893237
# Article 513:	Compression: 1.025621	Avg Compression: 0.893860
# Article 514:	Compression: 1.128571	Avg Compression: 0.893862
# Article 515:	Compression: 0.978720	Avg Compression: 0.893909
# Article 516:	Compression: 0.916205	Avg Compression: 0.893932
# Article 517:	Compression: 0.892501	Avg Compression: 0.893925
# Article 518:	Compression: 0.957469	Avg Compression: 0.894174
# Article 519:	Compression: 0.862093	Avg Compression: 0.894097
# Article 520:	Compression: 0.859003	Avg Compression: 0.894065
# Article 521:	Compression: 0.947917	Avg Compression: 0.894065
# Article 522:	Compression: 0.870573	Avg Compression: 0.893999
# Article 523:	Compression: 0.947535	Avg Compression: 0.894096
# Article 524:	Compression: 0.905858	Avg Compression: 0.894124
# Article 525:	Compression: 1.050000	Avg Compression: 0.894125
# Article 526:	Compression: 1.067079	Avg Compression: 0.894517
# Article 527:	Compression: 1.063300	Avg Compression: 0.894725
# Article 528:	Compression: 0.914573	Avg Compression: 0.894825
# Article 529:	Compression: 0.965869	Avg Compression: 0.895081
# Article 530:	Compression: 0.967527	Avg Compression: 0.895329
# Article 531:	Compression: 0.978535	Avg Compression: 0.895587
# Article 532:	Compression: 0.973516	Avg Compression: 0.895899
# Article 533:	Compression: 0.976709	Avg Compression: 0.896211
# Article 534:	Compression: 0.974492	Avg Compression: 0.896465
# Article 535:	Compression: 0.971015	Avg Compression: 0.896701
# Article 536:	Compression: 0.915528	Avg Compression: 0.896801
# Article 537:	Compression: 0.874677	Avg Compression: 0.896759
# Article 538:	Compression: 0.951332	Avg Compression: 0.896923
# Article 539:	Compression: 0.892645	Avg Compression: 0.896920
# Article 540:	Compression: 0.968812	Avg Compression: 0.897158
# Article 541:	Compression: 0.919515	Avg Compression: 0.897261
# Article 542:	Compression: 1.018878	Avg Compression: 0.897274
# Article 543:	Compression: 0.881839	Avg Compression: 0.897206
# Article 544:	Compression: 0.858171	Avg Compression: 0.896503
# Article 545:	Compression: 0.900735	Avg Compression: 0.896503
# Article 546:	Compression: 0.970158	Avg Compression: 0.896718
# Article 547:	Compression: 1.033227	Avg Compression: 0.896870
# Article 548:	Compression: 0.891841	Avg Compression: 0.896854
# Article 549:	Compression: 0.901462	Avg Compression: 0.896872
# Article 550:	Compression: 0.873153	Avg Compression: 0.896852
# Article 551:	Compression: 0.884939	Avg Compression: 0.896822
# Article 552:	Compression: 0.846248	Avg Compression: 0.896711
# Article 553:	Compression: 1.062500	Avg Compression: 0.896712
# Article 554:	Compression: 0.917445	Avg Compression: 0.896752
# Article 555:	Compression: 0.956493	Avg Compression: 0.896855
# Article 556:	Compression: 1.015625	Avg Compression: 0.896856
# Article 557:	Compression: 0.936401	Avg Compression: 0.896865
# Article 558:	Compression: 0.822531	Avg Compression: 0.896751
# Article 559:	Compression: 0.853823	Avg Compression: 0.896716
# Article 560:	Compression: 0.874875	Avg Compression: 0.896682
# Article 561:	Compression: 0.866011	Avg Compression: 0.896665
# Article 562:	Compression: 0.920311	Avg Compression: 0.896737
# Article 563:	Compression: 0.895261	Avg Compression: 0.896732
# Article 564:	Compression: 0.896730	Avg Compression: 0.896732
# Article 565:	Compression: 1.133929	Avg Compression: 0.896733
# Article 566:	Compression: 0.877511	Avg Compression: 0.896713
# Article 567:	Compression: 0.902174	Avg Compression: 0.896713
# Article 568:	Compression: 1.006657	Avg Compression: 0.896809
# Article 569:	Compression: 0.957371	Avg Compression: 0.896936
# Article 570:	Compression: 0.867143	Avg Compression: 0.896930
# Article 571:	Compression: 0.950000	Avg Compression: 0.896930
# Article 572:	Compression: 0.950000	Avg Compression: 0.896931
# Article 573:	Compression: 0.950000	Avg Compression: 0.896931
# Article 574:	Compression: 0.931071	Avg Compression: 0.896960
# Article 575:	Compression: 0.889104	Avg Compression: 0.896943
# Article 576:	Compression: 0.933511	Avg Compression: 0.896944
# Article 577:	Compression: 0.892500	Avg Compression: 0.896944
# Article 578:	Compression: 1.021739	Avg Compression: 0.896945
# Article 579:	Compression: 0.938034	Avg Compression: 0.896990
# Article 580:	Compression: 0.966346	Avg Compression: 0.896991
# Article 581:	Compression: 0.966346	Avg Compression: 0.896991
# Article 582:	Compression: 0.921296	Avg Compression: 0.896992
# Article 583:	Compression: 1.011364	Avg Compression: 0.896993
# Article 584:	Compression: 0.925000	Avg Compression: 0.896993
# Article 585:	Compression: 0.818423	Avg Compression: 0.896966
# Article 586:	Compression: 0.852382	Avg Compression: 0.896117
# Article 587:	Compression: 0.752119	Avg Compression: 0.896116
# Article 588:	Compression: 0.836806	Avg Compression: 0.896115
# Article 589:	Compression: 1.065972	Avg Compression: 0.896116
# Article 590:	Compression: 0.871711	Avg Compression: 0.896116
# Article 591:	Compression: 0.829268	Avg Compression: 0.896116
# Article 592:	Compression: 0.979730	Avg Compression: 0.896116
# Article 593:	Compression: 0.872093	Avg Compression: 0.896116
# Article 594:	Compression: 0.889535	Avg Compression: 0.896116
# Article 595:	Compression: 0.970109	Avg Compression: 0.896117
# Article 596:	Compression: 1.040541	Avg Compression: 0.896118
# Article 597:	Compression: 0.970109	Avg Compression: 0.896119
# Article 598:	Compression: 0.828571	Avg Compression: 0.896118
# Article 599:	Compression: 0.782895	Avg Compression: 0.896117
# Article 600:	Compression: 0.937500	Avg Compression: 0.896117
# Article 601:	Compression: 1.015152	Avg Compression: 0.896118
# Article 602:	Compression: 0.843750	Avg Compression: 0.896118
# Article 603:	Compression: 0.840625	Avg Compression: 0.896117
# Article 604:	Compression: 1.062500	Avg Compression: 0.896119
# Article 605:	Compression: 0.938953	Avg Compression: 0.896119
# Article 606:	Compression: 0.810811	Avg Compression: 0.896118
# Article 607:	Compression: 0.771875	Avg Compression: 0.896117
# Article 608:	Compression: 0.916667	Avg Compression: 0.896117
# Article 609:	Compression: 0.960714	Avg Compression: 0.896118
# Article 610:	Compression: 0.812500	Avg Compression: 0.896117
# Article 611:	Compression: 0.812500	Avg Compression: 0.896116
# Article 612:	Compression: 0.947222	Avg Compression: 0.896117
# Article 613:	Compression: 1.003472	Avg Compression: 0.896118
# Article 614:	Compression: 0.843750	Avg Compression: 0.896117
# Article 615:	Compression: 0.947222	Avg Compression: 0.896118
# Article 616:	Compression: 0.939154	Avg Compression: 0.896142
# Article 617:	Compression: 0.952678	Avg Compression: 0.896168
# Article 618:	Compression: 0.835683	Avg Compression: 0.896134
# Article 619:	Compression: 0.933466	Avg Compression: 0.896162
# Article 620:	Compression: 0.960979	Avg Compression: 0.896175
# Article 621:	Compression: 1.008007	Avg Compression: 0.896195
# Article 622:	Compression: 0.991379	Avg Compression: 0.896195
# Article 623:	Compression: 0.665541	Avg Compression: 0.896193
# Article 624:	Compression: 0.612500	Avg Compression: 0.896191
# Article 625:	Compression: 0.781454	Avg Compression: 0.896001
# Article 626:	Compression: 0.885714	Avg Compression: 0.896001
# Article 627:	Compression: 0.729167	Avg Compression: 0.895999
# Article 628:	Compression: 0.790541	Avg Compression: 0.895999
# Article 629:	Compression: 0.805556	Avg Compression: 0.895998
# Article 630:	Compression: 0.785256	Avg Compression: 0.895997
# Article 631:	Compression: 0.628571	Avg Compression: 0.895995
# Article 632:	Compression: 0.805556	Avg Compression: 0.895994
# Article 633:	Compression: 0.768939	Avg Compression: 0.895993
# Article 634:	Compression: 0.990446	Avg Compression: 0.896242
# Article 635:	Compression: 0.885531	Avg Compression: 0.896196
# Article 636:	Compression: 0.872861	Avg Compression: 0.896038
# Article 637:	Compression: 0.883789	Avg Compression: 0.896008
# Article 638:	Compression: 0.895210	Avg Compression: 0.896008
# Article 639:	Compression: 0.896831	Avg Compression: 0.896009
# Article 640:	Compression: 0.819865	Avg Compression: 0.895999
# Article 641:	Compression: 0.625000	Avg Compression: 0.895997
# Article 642:	Compression: 0.854116	Avg Compression: 0.895865
# Article 643:	Compression: 0.926852	Avg Compression: 0.895895
# Article 644:	Compression: 0.877509	Avg Compression: 0.895873
# Article 645:	Compression: 0.843757	Avg Compression: 0.895621
# Article 646:	Compression: 0.911453	Avg Compression: 0.895630
# Article 647:	Compression: 0.829825	Avg Compression: 0.895601
# Article 648:	Compression: 0.954154	Avg Compression: 0.895622
# Article 649:	Compression: 0.861607	Avg Compression: 0.895333
# Article 650:	Compression: 0.773810	Avg Compression: 0.895332
# Article 651:	Compression: 0.966045	Avg Compression: 0.895738
# Article 652:	Compression: 1.035714	Avg Compression: 0.895739
# Article 653:	Compression: 0.885794	Avg Compression: 0.895733
# Article 654:	Compression: 1.094697	Avg Compression: 0.895735
# Article 655:	Compression: 0.973560	Avg Compression: 0.895931
# Article 656:	Compression: 0.952883	Avg Compression: 0.895944
# Article 657:	Compression: 1.113095	Avg Compression: 0.895945
# Article 658:	Compression: 0.878871	Avg Compression: 0.895926
# Article 659:	Compression: 0.921294	Avg Compression: 0.896002
# Article 660:	Compression: 0.834286	Avg Compression: 0.895911
# Article 661:	Compression: 0.874452	Avg Compression: 0.895850
# Article 662:	Compression: 0.931762	Avg Compression: 0.895943
# Article 663:	Compression: 0.911238	Avg Compression: 0.895951
# Article 664:	Compression: 1.019255	Avg Compression: 0.896076
# Article 665:	Compression: 0.926781	Avg Compression: 0.896120
# Article 666:	Compression: 0.958778	Avg Compression: 0.896136
# Article 667:	Compression: 0.844005	Avg Compression: 0.895982
# Article 668:	Compression: 0.851571	Avg Compression: 0.895863
# Article 669:	Compression: 0.896484	Avg Compression: 0.895863
# Article 670:	Compression: 0.909547	Avg Compression: 0.895917
# Article 671:	Compression: 0.956398	Avg Compression: 0.896120
# Article 672:	Compression: 0.899702	Avg Compression: 0.896121
# Article 673:	Compression: 0.902756	Avg Compression: 0.896156
# Article 674:	Compression: 0.818996	Avg Compression: 0.895834
# Article 675:	Compression: 1.129630	Avg Compression: 0.895835
# Article 676:	Compression: 0.891639	Avg Compression: 0.895831
# Article 677:	Compression: 0.932130	Avg Compression: 0.895930
# Article 678:	Compression: 0.839592	Avg Compression: 0.895792
# Article 679:	Compression: 1.062500	Avg Compression: 0.895793
# Article 680:	Compression: 1.152778	Avg Compression: 0.895794
# Article 681:	Compression: 0.941942	Avg Compression: 0.895816
# Article 682:	Compression: 0.919362	Avg Compression: 0.895826
# Article 683:	Compression: 0.785856	Avg Compression: 0.895781
# Article 684:	Compression: 0.942708	Avg Compression: 0.895781
# Article 685:	Compression: 0.817868	Avg Compression: 0.895743
# Article 686:	Compression: 0.842328	Avg Compression: 0.895708
# Article 687:	Compression: 0.934211	Avg Compression: 0.895708
# Article 688:	Compression: 1.010000	Avg Compression: 0.895708
# Article 689:	Compression: 0.909614	Avg Compression: 0.895740
# Article 690:	Compression: 1.037291	Avg Compression: 0.895758
# Article 691:	Compression: 0.895652	Avg Compression: 0.895758
# Article 692:	Compression: 1.035714	Avg Compression: 0.895759
# Article 693:	Compression: 0.894894	Avg Compression: 0.895758
# Article 694:	Compression: 0.813747	Avg Compression: 0.895438
# Article 695:	Compression: 0.826435	Avg Compression: 0.895399
# Article 696:	Compression: 0.830009	Avg Compression: 0.894699
# Article 697:	Compression: 0.871118	Avg Compression: 0.894679
# Article 698:	Compression: 1.056034	Avg Compression: 0.894680
# Article 699:	Compression: 0.840914	Avg Compression: 0.894524
# Article 700:	Compression: 0.896401	Avg Compression: 0.894533
# Article 701:	Compression: 0.888917	Avg Compression: 0.894505
# Article 702:	Compression: 0.992129	Avg Compression: 0.894583
# Article 703:	Compression: 0.942606	Avg Compression: 0.894658
# Article 704:	Compression: 0.961815	Avg Compression: 0.894717
# Article 705:	Compression: 0.988928	Avg Compression: 0.894770
# Article 706:	Compression: 0.842265	Avg Compression: 0.894472
# Article 707:	Compression: 0.967254	Avg Compression: 0.894477
# Article 708:	Compression: 0.887989	Avg Compression: 0.894438
# Article 709:	Compression: 1.022927	Avg Compression: 0.894592
# Article 710:	Compression: 0.900735	Avg Compression: 0.894592
# Article 711:	Compression: 0.878472	Avg Compression: 0.894592
# Article 712:	Compression: 0.967391	Avg Compression: 0.894592
# Article 713:	Compression: 0.967391	Avg Compression: 0.894592
# Article 714:	Compression: 0.989583	Avg Compression: 0.894593
# Article 715:	Compression: 0.884146	Avg Compression: 0.894593
# Article 716:	Compression: 1.095588	Avg Compression: 0.894594
# Article 717:	Compression: 1.025000	Avg Compression: 0.894595
# Article 718:	Compression: 0.817308	Avg Compression: 0.894594
# Article 719:	Compression: 0.914452	Avg Compression: 0.894612
# Article 720:	Compression: 0.946429	Avg Compression: 0.894612
# Article 721:	Compression: 0.946429	Avg Compression: 0.894613
# Article 722:	Compression: 0.946429	Avg Compression: 0.894613
# Article 723:	Compression: 0.946429	Avg Compression: 0.894613
# Article 724:	Compression: 0.946429	Avg Compression: 0.894614
# Article 725:	Compression: 0.946429	Avg Compression: 0.894614
# Article 726:	Compression: 0.972912	Avg Compression: 0.894634
# Article 727:	Compression: 0.900225	Avg Compression: 0.894641
# Article 728:	Compression: 0.839254	Avg Compression: 0.894482
# Article 729:	Compression: 1.012931	Avg Compression: 0.894483
# Article 730:	Compression: 0.876861	Avg Compression: 0.894418
# Article 731:	Compression: 0.894182	Avg Compression: 0.894417
# Article 732:	Compression: 0.800541	Avg Compression: 0.894148
# Article 733:	Compression: 0.934034	Avg Compression: 0.894285
# Article 734:	Compression: 1.060345	Avg Compression: 0.894286
# Article 735:	Compression: 0.917125	Avg Compression: 0.894296
# Article 736:	Compression: 0.889835	Avg Compression: 0.894292
# Article 737:	Compression: 0.879960	Avg Compression: 0.894261
# Article 738:	Compression: 0.849340	Avg Compression: 0.894074
# Article 739:	Compression: 0.971028	Avg Compression: 0.894285
# Article 740:	Compression: 0.941406	Avg Compression: 0.894285
# Article 741:	Compression: 0.918650	Avg Compression: 0.894323
# Article 742:	Compression: 0.932605	Avg Compression: 0.894346
# Article 743:	Compression: 0.983817	Avg Compression: 0.894539
# Article 744:	Compression: 0.917639	Avg Compression: 0.894604
# Article 745:	Compression: 0.982566	Avg Compression: 0.894814
# Article 746:	Compression: 1.132991	Avg Compression: 0.894851
# Article 747:	Compression: 0.846127	Avg Compression: 0.894823
# Article 748:	Compression: 1.060345	Avg Compression: 0.894824
# Article 749:	Compression: 1.087500	Avg Compression: 0.894825
# Article 750:	Compression: 0.937346	Avg Compression: 0.894843
# Article 751:	Compression: 1.026210	Avg Compression: 0.894845
# Article 752:	Compression: 0.924213	Avg Compression: 0.894852
# Article 753:	Compression: 0.841287	Avg Compression: 0.894794
# Article 754:	Compression: 0.897565	Avg Compression: 0.894809
# Article 755:	Compression: 0.932441	Avg Compression: 0.894848
# Article 756:	Compression: 0.860970	Avg Compression: 0.894830
# Article 757:	Compression: 0.859041	Avg Compression: 0.894822
# Article 758:	Compression: 1.003289	Avg Compression: 0.894823
# Article 759:	Compression: 0.968466	Avg Compression: 0.894840
# Article 760:	Compression: 0.871368	Avg Compression: 0.894830
# Article 761:	Compression: 1.041667	Avg Compression: 0.894830
# Article 762:	Compression: 1.059028	Avg Compression: 0.894831
# Article 763:	Compression: 0.891350	Avg Compression: 0.894825
# Article 764:	Compression: 1.071544	Avg Compression: 0.895064
# Article 765:	Compression: 0.814394	Avg Compression: 0.895064
# Article 766:	Compression: 0.891019	Avg Compression: 0.895003
# Article 767:	Compression: 0.862052	Avg Compression: 0.894955
# Article 768:	Compression: 1.187500	Avg Compression: 0.894957
# Article 769:	Compression: 0.919319	Avg Compression: 0.895011
# Article 770:	Compression: 0.856661	Avg Compression: 0.894974
# Article 771:	Compression: 0.836514	Avg Compression: 0.894943
# Article 772:	Compression: 0.867604	Avg Compression: 0.894942
# Article 773:	Compression: 1.089286	Avg Compression: 0.894943
# Article 774:	Compression: 0.841956	Avg Compression: 0.894884
# Article 775:	Compression: 1.103261	Avg Compression: 0.894885
# Article 776:	Compression: 0.944773	Avg Compression: 0.894990
# Article 777:	Compression: 0.909459	Avg Compression: 0.894996
# Article 778:	Compression: 0.859466	Avg Compression: 0.894937
# Article 779:	Compression: 0.861326	Avg Compression: 0.894923
# Article 780:	Compression: 0.967457	Avg Compression: 0.894935
# Article 781:	Compression: 0.926168	Avg Compression: 0.894941
# Article 782:	Compression: 0.907926	Avg Compression: 0.895034
# Article 783:	Compression: 0.892071	Avg Compression: 0.895030
# Article 784:	Compression: 0.914622	Avg Compression: 0.895042
# Article 785:	Compression: 0.849877	Avg Compression: 0.895033
# Article 786:	Compression: 0.904908	Avg Compression: 0.895039
# Article 787:	Compression: 1.025675	Avg Compression: 0.895054
# ...
# Article 1742:	Compression: 1.142575	Avg Compression: 0.895875
# Article 1743:	Compression: 0.933222	Avg Compression: 0.895883
# Article 1744:	Compression: 0.822944	Avg Compression: 0.895832
# Article 1745:	Compression: 0.973936	Avg Compression: 0.895847
# Article 1746:	Compression: 1.101303	Avg Compression: 0.895864
# Article 1747:	Compression: 1.004316	Avg Compression: 0.895871
# Article 1748:	Compression: 0.933608	Avg Compression: 0.895876
# Article 1749:	Compression: 1.073916	Avg Compression: 0.895900
# Article 1750:	Compression: 0.917836	Avg Compression: 0.895902
# Article 1751:	Compression: 0.976190	Avg Compression: 0.895902
# Article 1752:	Compression: 0.935276	Avg Compression: 0.895927
# Article 1753:	Compression: 0.980957	Avg Compression: 0.896013
# Article 1754:	Compression: 0.903597	Avg Compression: 0.896014
# Article 1755:	Compression: 1.096154	Avg Compression: 0.896014
# Article 1756:	Compression: 0.902362	Avg Compression: 0.896015
# Article 1757:	Compression: 0.975962	Avg Compression: 0.896015
# Article 1758:	Compression: 1.030828	Avg Compression: 0.896024
# Article 1759:	Compression: 0.913043	Avg Compression: 0.896024
# Article 1760:	Compression: 0.800653	Avg Compression: 0.895794
# Article 1761:	Compression: 0.898338	Avg Compression: 0.895795
# Article 1762:	Compression: 0.961957	Avg Compression: 0.895795
# Article 1763:	Compression: 1.109375	Avg Compression: 0.895796
# Article 1764:	Compression: 0.814188	Avg Compression: 0.895647
# Article 1765:	Compression: 0.899117	Avg Compression: 0.895648
# Article 1766:	Compression: 1.049235	Avg Compression: 0.895654
# Article 1767:	Compression: 0.851837	Avg Compression: 0.895648
# Article 1768:	Compression: 0.865209	Avg Compression: 0.895618
# Article 1769:	Compression: 0.905341	Avg Compression: 0.895632
# Article 1770:	Compression: 0.800187	Avg Compression: 0.895627
# Article 1771:	Compression: 1.028846	Avg Compression: 0.895627
# Article 1772:	Compression: 0.861161	Avg Compression: 0.895572
# Article 1773:	Compression: 1.547414	Avg Compression: 0.895574
# Article 1774:	Compression: 0.946921	Avg Compression: 0.895589
# Article 1775:	Compression: 0.855439	Avg Compression: 0.895580
# Article 1776:	Compression: 0.985461	Avg Compression: 0.895615
# Article 1777:	Compression: 0.996898	Avg Compression: 0.895630
# Article 1778:	Compression: 0.883869	Avg Compression: 0.895627
# Article 1779:	Compression: 0.836058	Avg Compression: 0.895617
# Article 1780:	Compression: 1.031250	Avg Compression: 0.895617
# Article 1781:	Compression: 0.899261	Avg Compression: 0.895621
# Article 1782:	Compression: 1.145000	Avg Compression: 0.895622
# Article 1783:	Compression: 1.025373	Avg Compression: 0.895648
# Article 1784:	Compression: 1.083333	Avg Compression: 0.895649
# Article 1785:	Compression: 0.912063	Avg Compression: 0.895651
# Article 1786:	Compression: 0.974235	Avg Compression: 0.895655
# Article 1787:	Compression: 0.869698	Avg Compression: 0.895653
# Article 1788:	Compression: 1.342391	Avg Compression: 0.895654
# Article 1789:	Compression: 0.914327	Avg Compression: 0.895678
# Article 1790:	Compression: 1.080882	Avg Compression: 0.895678
# Article 1791:	Compression: 0.886136	Avg Compression: 0.895677
# Article 1792:	Compression: 0.868056	Avg Compression: 0.895677
# Article 1793:	Compression: 0.879230	Avg Compression: 0.895665
# Article 1794:	Compression: 0.885000	Avg Compression: 0.895665
# Article 1795:	Compression: 0.902126	Avg Compression: 0.895669
# Article 1796:	Compression: 0.978461	Avg Compression: 0.895682
# Article 1797:	Compression: 0.906499	Avg Compression: 0.895692
# Article 1798:	Compression: 0.882852	Avg Compression: 0.895675
# Article 1799:	Compression: 0.868056	Avg Compression: 0.895675
# Article 1800:	Compression: 0.827743	Avg Compression: 0.895664
# Article 1801:	Compression: 0.857027	Avg Compression: 0.895650
# Article 1802:	Compression: 0.910064	Avg Compression: 0.895657
# Article 1803:	Compression: 0.844907	Avg Compression: 0.895657
# Article 1804:	Compression: 1.002616	Avg Compression: 0.895660
# Article 1805:	Compression: 0.900396	Avg Compression: 0.895661
# Article 1806:	Compression: 0.812990	Avg Compression: 0.895622
# Article 1807:	Compression: 0.844907	Avg Compression: 0.895621
# Article 1808:	Compression: 0.905029	Avg Compression: 0.895632
# Article 1809:	Compression: 0.871390	Avg Compression: 0.895611
# Article 1810:	Compression: 0.969633	Avg Compression: 0.895691
# Article 1811:	Compression: 1.128906	Avg Compression: 0.895692
# Article 1812:	Compression: 1.077586	Avg Compression: 0.895692
# Article 1813:	Compression: 0.962500	Avg Compression: 0.895692
# Article 1814:	Compression: 0.962500	Avg Compression: 0.895692
# Article 1815:	Compression: 1.019231	Avg Compression: 0.895692
# Article 1816:	Compression: 1.005208	Avg Compression: 0.895693
# Article 1817:	Compression: 1.046324	Avg Compression: 0.895738
# Article 1818:	Compression: 0.990551	Avg Compression: 0.895754
# Article 1819:	Compression: 0.917958	Avg Compression: 0.895788
# Article 1820:	Compression: 1.029573	Avg Compression: 0.895834
# Article 1821:	Compression: 1.137378	Avg Compression: 0.895846
# Article 1822:	Compression: 1.146088	Avg Compression: 0.895853
# Article 1823:	Compression: 0.890686	Avg Compression: 0.895849
# Article 1824:	Compression: 0.925059	Avg Compression: 0.895850
# Article 1825:	Compression: 0.859556	Avg Compression: 0.895835
# Article 1826:	Compression: 0.882812	Avg Compression: 0.895835
# Article 1827:	Compression: 1.022321	Avg Compression: 0.895835
# Article 1828:	Compression: 0.906250	Avg Compression: 0.895835
# Article 1829:	Compression: 0.975000	Avg Compression: 0.895835
# Article 1830:	Compression: 1.066667	Avg Compression: 0.895836
# Article 1831:	Compression: 1.116667	Avg Compression: 0.895836
# Article 1832:	Compression: 0.965278	Avg Compression: 0.895836
# Article 1833:	Compression: 0.933594	Avg Compression: 0.895836
# Article 1834:	Compression: 0.827243	Avg Compression: 0.895812
# Article 1835:	Compression: 0.857068	Avg Compression: 0.895755
# Article 1836:	Compression: 0.872898	Avg Compression: 0.895715
# Article 1837:	Compression: 1.050595	Avg Compression: 0.895716
# Article 1838:	Compression: 0.795840	Avg Compression: 0.895591
# Article 1839:	Compression: 0.778226	Avg Compression: 0.895471
# Article 1840:	Compression: 0.959184	Avg Compression: 0.895472
# Article 1841:	Compression: 1.096154	Avg Compression: 0.895472
# Article 1842:	Compression: 0.975962	Avg Compression: 0.895472
# Article 1843:	Compression: 0.955800	Avg Compression: 0.895480
# Article 1844:	Compression: 0.888514	Avg Compression: 0.895480
# Article 1845:	Compression: 0.978026	Avg Compression: 0.895482
# Article 1846:	Compression: 1.138245	Avg Compression: 0.895485
# Article 1847:	Compression: 0.891560	Avg Compression: 0.895484
# Article 1848:	Compression: 0.905491	Avg Compression: 0.895487
# Article 1849:	Compression: 0.890531	Avg Compression: 0.895483
# Article 1850:	Compression: 0.918969	Avg Compression: 0.895489
# Article 1851:	Compression: 0.879438	Avg Compression: 0.895486
# Article 1852:	Compression: 1.267241	Avg Compression: 0.895486
# Article 1853:	Compression: 0.885798	Avg Compression: 0.895483
# Article 1854:	Compression: 1.067568	Avg Compression: 0.895483
# Article 1855:	Compression: 0.868609	Avg Compression: 0.895474
# Article 1856:	Compression: 1.451087	Avg Compression: 0.895475
# Article 1857:	Compression: 1.004007	Avg Compression: 0.895495
# Article 1858:	Compression: 0.912549	Avg Compression: 0.895497
# Article 1859:	Compression: 0.985154	Avg Compression: 0.895503
# Article 1860:	Compression: 0.961207	Avg Compression: 0.895511
# Article 1861:	Compression: 0.943686	Avg Compression: 0.895522
# Article 1862:	Compression: 0.959842	Avg Compression: 0.895529
# Article 1863:	Compression: 0.851980	Avg Compression: 0.895395
# Article 1864:	Compression: 0.916857	Avg Compression: 0.895401
# Article 1865:	Compression: 0.887358	Avg Compression: 0.895387
# Article 1866:	Compression: 0.915986	Avg Compression: 0.895391
# Article 1867:	Compression: 0.972493	Avg Compression: 0.895406
# Article 1868:	Compression: 0.880390	Avg Compression: 0.895405
# Article 1869:	Compression: 1.238636	Avg Compression: 0.895406
# Article 1870:	Compression: 0.968750	Avg Compression: 0.895419
# Article 1871:	Compression: 0.939286	Avg Compression: 0.895420
# Article 1872:	Compression: 0.853061	Avg Compression: 0.895413
# Article 1873:	Compression: 0.913409	Avg Compression: 0.895414
# Article 1874:	Compression: 1.087963	Avg Compression: 0.895414
# Article 1875:	Compression: 0.872507	Avg Compression: 0.895406
# Article 1876:	Compression: 0.960526	Avg Compression: 0.895406
# Article 1877:	Compression: 0.856951	Avg Compression: 0.895384
# Article 1878:	Compression: 0.995967	Avg Compression: 0.895414
# Article 1879:	Compression: 0.625438	Avg Compression: 0.895265
# Article 1880:	Compression: 0.910205	Avg Compression: 0.895287
# Article 1881:	Compression: 1.100000	Avg Compression: 0.895287
# Article 1882:	Compression: 1.099138	Avg Compression: 0.895288
# Article 1883:	Compression: 0.875141	Avg Compression: 0.895280
# Article 1884:	Compression: 0.878882	Avg Compression: 0.895275
# Article 1885:	Compression: 0.711538	Avg Compression: 0.895275
# Article 1886:	Compression: 1.055556	Avg Compression: 0.895275
# Article 1887:	Compression: 1.055556	Avg Compression: 0.895275
# Article 1888:	Compression: 1.055556	Avg Compression: 0.895276
# Article 1889:	Compression: 1.055556	Avg Compression: 0.895276
# Article 1890:	Compression: 1.025000	Avg Compression: 0.895276
# Article 1891:	Compression: 1.025000	Avg Compression: 0.895277
# Article 1892:	Compression: 0.869953	Avg Compression: 0.895275
# Article 1893:	Compression: 1.025000	Avg Compression: 0.895275
# Article 1894:	Compression: 1.025000	Avg Compression: 0.895275
# Article 1895:	Compression: 1.025000	Avg Compression: 0.895275
# Article 1896:	Compression: 1.028571	Avg Compression: 0.895276
# Article 1897:	Compression: 0.788690	Avg Compression: 0.895275
# Article 1898:	Compression: 0.818091	Avg Compression: 0.895246
# Article 1899:	Compression: 0.817389	Avg Compression: 0.895219
# Article 1900:	Compression: 0.977830	Avg Compression: 0.895223
# Article 1901:	Compression: 0.878740	Avg Compression: 0.895219
# Article 1902:	Compression: 0.848395	Avg Compression: 0.895213
# Article 1903:	Compression: 0.776937	Avg Compression: 0.894839
# Article 1904:	Compression: 0.905878	Avg Compression: 0.894841
# Article 1905:	Compression: 0.922387	Avg Compression: 0.894846
# Article 1906:	Compression: 0.870065	Avg Compression: 0.894835
# Article 1907:	Compression: 0.865556	Avg Compression: 0.894813
# Article 1908:	Compression: 0.876951	Avg Compression: 0.894798
# Article 1909:	Compression: 1.119318	Avg Compression: 0.894798
# Article 1910:	Compression: 0.893085	Avg Compression: 0.894798
# Article 1911:	Compression: 0.918350	Avg Compression: 0.894802
# Article 1912:	Compression: 1.070364	Avg Compression: 0.894806
# Article 1913:	Compression: 0.900465	Avg Compression: 0.894808
# Article 1914:	Compression: 0.970733	Avg Compression: 0.894817
# Article 1915:	Compression: 0.915777	Avg Compression: 0.894822
# Article 1916:	Compression: 0.971445	Avg Compression: 0.894828
# Article 1917:	Compression: 0.955475	Avg Compression: 0.894834
# Article 1918:	Compression: 0.957202	Avg Compression: 0.894850
# Article 1919:	Compression: 1.069444	Avg Compression: 0.894851
# Article 1920:	Compression: 1.444853	Avg Compression: 0.894852
# Article 1921:	Compression: 0.926616	Avg Compression: 0.894854
# Article 1922:	Compression: 0.985528	Avg Compression: 0.894866
# Article 1923:	Compression: 0.882632	Avg Compression: 0.894863
# Article 1924:	Compression: 0.981590	Avg Compression: 0.894922
# Article 1925:	Compression: 0.824295	Avg Compression: 0.894903
# Article 1926:	Compression: 1.083612	Avg Compression: 0.894921
# Article 1927:	Compression: 0.971879	Avg Compression: 0.894926
# Article 1928:	Compression: 0.963240	Avg Compression: 0.894934
# Article 1929:	Compression: 0.951831	Avg Compression: 0.894950
# Article 1930:	Compression: 0.889407	Avg Compression: 0.894946
# Article 1931:	Compression: 0.933141	Avg Compression: 0.894960
# Article 1932:	Compression: 0.874011	Avg Compression: 0.894942
# Article 1933:	Compression: 0.849534	Avg Compression: 0.894937
# Article 1934:	Compression: 0.941667	Avg Compression: 0.894937
# Article 1935:	Compression: 0.832963	Avg Compression: 0.894916
# Article 1936:	Compression: 0.944127	Avg Compression: 0.894944
# Article 1937:	Compression: 0.981979	Avg Compression: 0.894951
# Article 1938:	Compression: 0.920843	Avg Compression: 0.894960
# Article 1939:	Compression: 0.983709	Avg Compression: 0.894965
# Article 1940:	Compression: 0.837166	Avg Compression: 0.894894
# Article 1941:	Compression: 0.836094	Avg Compression: 0.894697
# Article 1942:	Compression: 0.831222	Avg Compression: 0.894646
# Article 1943:	Compression: 1.004785	Avg Compression: 0.894651
# Article 1944:	Compression: 0.851403	Avg Compression: 0.894623
# Article 1945:	Compression: 1.030044	Avg Compression: 0.894643
# Article 1946:	Compression: 0.926282	Avg Compression: 0.894643
# Article 1947:	Compression: 0.888185	Avg Compression: 0.894642
# Article 1948:	Compression: 1.233696	Avg Compression: 0.894642
# Article 1949:	Compression: 0.871758	Avg Compression: 0.894633
# Article 1950:	Compression: 0.898092	Avg Compression: 0.894634
# Article 1951:	Compression: 0.898669	Avg Compression: 0.894635
# Article 1952:	Compression: 0.895696	Avg Compression: 0.894635
# Article 1953:	Compression: 0.919241	Avg Compression: 0.894649
# Article 1954:	Compression: 0.833654	Avg Compression: 0.894644
# Article 1955:	Compression: 0.834132	Avg Compression: 0.894629
# Article 1956:	Compression: 0.866355	Avg Compression: 0.894606
# Article 1957:	Compression: 1.058155	Avg Compression: 0.894637
# Article 1958:	Compression: 0.873825	Avg Compression: 0.894626
# Article 1959:	Compression: 0.896462	Avg Compression: 0.894627
# Article 1960:	Compression: 0.965000	Avg Compression: 0.894627
# Article 1961:	Compression: 0.832661	Avg Compression: 0.894610
# Article 1962:	Compression: 1.056250	Avg Compression: 0.894611
# Article 1963:	Compression: 1.278409	Avg Compression: 0.894611
# Article 1964:	Compression: 0.930368	Avg Compression: 0.894614
# Article 1965:	Compression: 0.921271	Avg Compression: 0.894618
# Article 1966:	Compression: 0.962812	Avg Compression: 0.894693
# Article 1967:	Compression: 0.984892	Avg Compression: 0.894774
# Article 1968:	Compression: 0.964921	Avg Compression: 0.894860
# Article 1969:	Compression: 0.988741	Avg Compression: 0.894906
# Article 1970:	Compression: 0.934951	Avg Compression: 0.894929
# Article 1971:	Compression: 0.836793	Avg Compression: 0.894923
# Article 1972:	Compression: 0.868570	Avg Compression: 0.894919
# Article 1973:	Compression: 1.001093	Avg Compression: 0.894929
# Article 1974:	Compression: 1.018939	Avg Compression: 0.894929
# Article 1975:	Compression: 0.920000	Avg Compression: 0.894929
# Article 1976:	Compression: 0.939136	Avg Compression: 0.894947
# Article 1977:	Compression: 1.388393	Avg Compression: 0.894948
# Article 1978:	Compression: 0.959940	Avg Compression: 0.894966
# Article 1979:	Compression: 0.948171	Avg Compression: 0.894966
# Article 1980:	Compression: 0.913300	Avg Compression: 0.894972
# Article 1981:	Compression: 1.162879	Avg Compression: 0.894973
# Article 1982:	Compression: 0.923795	Avg Compression: 0.895041
# Article 1983:	Compression: 0.899478	Avg Compression: 0.895043
# Article 1984:	Compression: 0.852873	Avg Compression: 0.895033
# Article 1985:	Compression: 0.852865	Avg Compression: 0.895024
# Article 1986:	Compression: 0.904174	Avg Compression: 0.895026
# Article 1987:	Compression: 1.165441	Avg Compression: 0.895026
# Article 1988:	Compression: 0.866667	Avg Compression: 0.895026
# Article 1989:	Compression: 0.932900	Avg Compression: 0.895057
# Article 1990:	Compression: 0.885427	Avg Compression: 0.895057
# Article 1991:	Compression: 0.899378	Avg Compression: 0.895058
# Article 1992:	Compression: 0.914693	Avg Compression: 0.895064
# Article 1993:	Compression: 1.090580	Avg Compression: 0.895065
# Article 1994:	Compression: 0.843366	Avg Compression: 0.895057
# Article 1995:	Compression: 0.904212	Avg Compression: 0.895065
# Article 1996:	Compression: 0.939286	Avg Compression: 0.895065
# Article 1997:	Compression: 0.868143	Avg Compression: 0.895060
# Article 1998:	Compression: 0.954006	Avg Compression: 0.895076
# Article 1999:	Compression: 0.892458	Avg Compression: 0.895072

# %% [markdown]
# Драстична разлика спряко предишната терадка. Единствената разлика е подравняването. Изглежда наистина е проблем за обучението. Keras има механизъм за справяне с това - маскиращ слой. Ще го опитаме в следващата терадка...
