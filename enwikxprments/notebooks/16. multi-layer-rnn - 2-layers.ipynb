# %%
import tensorflow as tf
import tensorflow_datasets as tfds

# %%
def articles():
    with open('page_revisions_text', 'rb') as text_file:
        pending_article_data = b''
        while True:
            data = text_file.read(1024 * 1024)
            if len(data) == 0:
                break

            articles = data.split(b'\0')
            articles[0] = pending_article_data + articles[0]
            for index, article in enumerate(articles):
                if index + 1 == len(articles):
                    pending_article_data = article
                else:
                    yield article

        print(pending_article_data)
        if len(pending_article_data) != 0:
            yield pending_article_data

# %%
subword_text_encoder = tfds.features.text.SubwordTextEncoder.load_from_file('vocab_4096')

# %% [markdown]
# Да видим как би изглеждало обучение с кодираните статии...

# %%
import os

import numpy as np
import itertools

# %%
BATCH_SIZE = 128
BATCHED_ITEM_LENGTH = 256
BUFFER_SIZE = 256
TYPE=np.uint16

def articles_generator():
    for index, article in enumerate(itertools.islice(articles(), 0, 2000)):
        yield np.array(subword_text_encoder.encode(article + b'\0'), dtype=TYPE)

    # Pad the article count to the batch size
    # We do this to ensure that no data is dropped
    index += 1
    while index % BATCH_SIZE != 0:
        yield np.array([0], dtype=TYPE)
        index += 1

def subbatches():
    dataset = tf.data.Dataset.from_generator(articles_generator, output_types=TYPE)
    dataset = dataset.shuffle(BUFFER_SIZE)
    dataset = dataset.padded_batch(BATCH_SIZE, padded_shapes=([None]), drop_remainder=True)

    for batch in dataset.as_numpy_iterator():
        remaining = batch
        while remaining.shape[1] > 1:
            yield remaining[:, :BATCHED_ITEM_LENGTH + 1]
            remaining = remaining[:, BATCHED_ITEM_LENGTH:]

dataset = tf.data.Dataset.from_generator(subbatches, output_types=TYPE, output_shapes=(BATCH_SIZE, None))
dataset = dataset.map(lambda batch: (batch[:, :-1], batch[:, 1:]))

dataset
# Out:
# <MapDataset shapes: ((128, None), (128, None)), types: (tf.uint16, tf.uint16)>

# %%
def build_model(vocab_size, embedding_dim, rnn_units, batch_size):
    return tf.keras.Sequential([
        tf.keras.layers.Embedding(vocab_size, embedding_dim, batch_input_shape=[batch_size, None]),
        tf.keras.layers.LSTM(rnn_units, return_sequences=True, stateful=True, recurrent_initializer='glorot_uniform'),
        tf.keras.layers.LSTM(rnn_units, return_sequences=True, stateful=True, recurrent_initializer='glorot_uniform'),
        tf.keras.layers.Dense(vocab_size),
    ])

# %%
def loss(labels, logits):
    return tf.keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)

def average_batch_length(true_labels, predictions):
    return tf.shape(true_labels)[1]

model = build_model(vocab_size = subword_text_encoder.vocab_size, embedding_dim=512, rnn_units=1024, batch_size=BATCH_SIZE)
model.compile(optimizer='adam', loss=loss, metrics=[average_batch_length])

# %%
checkpoint_dir = './training_checkpoints' # Directory where the checkpoints will be saved
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt_{epoch}") # Name of the checkpoint files

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_prefix, save_weights_only=True)

# %%
class ModelStateResetter(tf.keras.callbacks.Callback):
    def __init__(self):
        self.last_total_length = 0

    def on_batch_end(self, batch, logs={}):
        average_batch_length = logs.get('average_batch_length', 0)
        total_length = int(round(average_batch_length * (batch + 1)))
        current_batch_length = total_length - self.last_total_length
        self.last_total_length = total_length
        
        if current_batch_length < BATCHED_ITEM_LENGTH:
            self.model.reset_states()
        
model_state_resetter_callback = ModelStateResetter()

# %%
total_epochs = 17

for epoch in range(total_epochs):
    print('Epoch %d/%d' % (epoch + 1, total_epochs))
    model.fit(dataset, callbacks=[checkpoint_callback, model_state_resetter_callback])
# Out:
# Epoch 1/17
# 1343/1343 [==============================] - 886s 660ms/step - loss: 0.7827 - average_batch_length: 254.4289
# Epoch 2/17
# 1311/1311 [==============================] - 867s 661ms/step - loss: 0.6102 - average_batch_length: 254.3875
# Epoch 3/17
# 1384/1384 [==============================] - 915s 661ms/step - loss: 0.5174 - average_batch_length: 254.6358
# Epoch 4/17
# 1357/1357 [==============================] - 893s 658ms/step - loss: 0.4838 - average_batch_length: 254.2616
# Epoch 5/17
# 1307/1307 [==============================] - 882s 675ms/step - loss: 0.4690 - average_batch_length: 254.2043
# Epoch 6/17
# 1373/1373 [==============================] - 925s 673ms/step - loss: 0.4237 - average_batch_length: 254.3139
# Epoch 7/17
# 1367/1367 [==============================] - 901s 659ms/step - loss: 0.4074 - average_batch_length: 254.6818
# Epoch 8/17
# 1234/1234 [==============================] - 811s 658ms/step - loss: 0.4349 - average_batch_length: 254.3509
# Epoch 9/17
# 1321/1321 [==============================] - 869s 658ms/step - loss: 0.3934 - average_batch_length: 254.4777
# Epoch 10/17
# 1337/1337 [==============================] - 880s 658ms/step - loss: 0.3779 - average_batch_length: 254.7307
# Epoch 11/17
# 1357/1357 [==============================] - 893s 658ms/step - loss: 0.3626 - average_batch_length: 254.8364
# Epoch 12/17
# 1343/1343 [==============================] - 884s 658ms/step - loss: 0.3578 - average_batch_length: 254.7215
# Epoch 13/17
# 1330/1330 [==============================] - 876s 659ms/step - loss: 0.3530 - average_batch_length: 254.6391
# Epoch 14/17
# 1421/1421 [==============================] - 934s 657ms/step - loss: 0.3235 - average_batch_length: 254.5771
# Epoch 15/17
# 1317/1317 [==============================] - 866s 658ms/step - loss: 0.3415 - average_batch_length: 254.6659
# Epoch 16/17
# 1325/1325 [==============================] - 872s 658ms/step - loss: 0.3326 - average_batch_length: 254.6634
# Epoch 17/17
# 1353/1353 [==============================] - 890s 658ms/step - loss: 0.3193 - average_batch_length: 254.4472

# %%
total_epochs = 8

for epoch in range(total_epochs):
    print('Epoch %d/%d' % (epoch + 1, total_epochs))
    model.fit(dataset, callbacks=[checkpoint_callback, model_state_resetter_callback])
# Out:
# Epoch 1/8
# 1347/1347 [==============================] - 891s 662ms/step - loss: 0.3146 - average_batch_length: 254.4388
# Epoch 2/8
# 1261/1261 [==============================] - 843s 669ms/step - loss: 0.3299 - average_batch_length: 254.6201
# Epoch 3/8
# 1292/1292 [==============================] - 874s 677ms/step - loss: 0.3156 - average_batch_length: 254.3839
# Epoch 4/8
# 1292/1292 [==============================] - 880s 681ms/step - loss: 0.3097 - average_batch_length: 254.7454
# Epoch 5/8
# 1346/1346 [==============================] - 911s 677ms/step - loss: 0.2920 - average_batch_length: 254.6701
# Epoch 6/8
# 1308/1308 [==============================] - 880s 673ms/step - loss: 0.2952 - average_batch_length: 254.4541
# Epoch 7/8
# 1288/1288 [==============================] - 857s 665ms/step - loss: 0.2940 - average_batch_length: 254.4907
# Epoch 8/8
# 1322/1322 [==============================] - 873s 660ms/step - loss: 0.2814 - average_batch_length: 254.6558

# %%
total_epochs = 5

for epoch in range(total_epochs):
    print('Epoch %d/%d' % (epoch + 1, total_epochs))
    model.fit(dataset, callbacks=[checkpoint_callback, model_state_resetter_callback])
# Out:
# Epoch 1/5
# 1385/1385 [==============================] - 917s 662ms/step - loss: 0.2641 - average_batch_length: 254.5098
# Epoch 2/5
# 1363/1363 [==============================] - 901s 661ms/step - loss: 0.2641 - average_batch_length: 254.6383
# Epoch 3/5
# 1308/1308 [==============================] - 865s 662ms/step - loss: 0.2698 - average_batch_length: 254.5092
# Epoch 4/5
# 1378/1378 [==============================] - 908s 659ms/step - loss: 0.2515 - average_batch_length: 254.6045
# Epoch 5/5
# 1289/1289 [==============================] - 855s 663ms/step - loss: 0.2643 - average_batch_length: 254.4639

# %%
total_epochs = 5

for epoch in range(total_epochs):
    print('Epoch %d/%d' % (epoch + 1, total_epochs))
    model.fit(dataset, callbacks=[checkpoint_callback, model_state_resetter_callback])
# Out:
# Epoch 1/5
# 1355/1355 [==============================] - 894s 660ms/step - loss: 0.2466 - average_batch_length: 254.4339
# Epoch 2/5
# 1312/1312 [==============================] - 864s 658ms/step - loss: 0.2504 - average_batch_length: 254.4588
# Epoch 3/5
# 1326/1326 [==============================] - 873s 658ms/step - loss: 0.2437 - average_batch_length: 254.3363
# Epoch 4/5
# 1373/1373 [==============================] - 907s 660ms/step - loss: 0.2309 - average_batch_length: 254.7567
# Epoch 5/5
# 1366/1366 [==============================] - 905s 663ms/step - loss: 0.2287 - average_batch_length: 254.5827

# %%
total_epochs = 3

for epoch in range(total_epochs):
    print('Epoch %d/%d' % (epoch + 1, total_epochs))
    model.fit(dataset, callbacks=[checkpoint_callback, model_state_resetter_callback])
# Out:
# Epoch 1/3
# 1339/1339 [==============================] - 886s 662ms/step - loss: 0.2291 - average_batch_length: 254.6311
# Epoch 2/3
# 1332/1332 [==============================] - 896s 673ms/step - loss: 0.2262 - average_batch_length: 254.2770
# Epoch 3/3
# 1289/1289 [==============================] - 871s 675ms/step - loss: 0.2297 - average_batch_length: 254.4360

# %%
with open('page_revisions_text', 'rb') as text_file:
    data = text_file.read()

article = data.split(b'\0')[120]
del data

encoded_article = np.array(subword_text_encoder.encode(article + b'\0'), dtype=TYPE)

print('Raw:', len(article))
print('Encoded:', len(encoded_article))
# Out:
# Raw: 25541
# Encoded: 8222

# %%
import ctypes

class Huffman:
    huffman = ctypes.CDLL('x64/Release/huffman')
    
    huffman.create_tree.restype = ctypes.c_void_p
    huffman.destroy_tree.restype = None
    huffman.load_weights.restype = None
    huffman.create_code_string.restype = ctypes.c_char_p
    
    def __init__(self, category_count):
        self.tree = ctypes.c_void_p(self.huffman.create_tree(category_count))

    def __del__(self):
        self.huffman.destroy_tree(self.tree)
        
    def load_weights(self, weights):
        self.huffman.load_weights(self.tree, weights.ctypes.data_as(ctypes.POINTER(ctypes.c_float)))
    
    def get_code_length(self, category):
        return self.huffman.get_code_length(self.tree, category)

    def get_code_zero_count(self, category):
        return self.huffman.get_code_zero_count(self.tree, category)

# %%
def huffman_archive_size(model, text):
    archived_size = 0
    zeros = 0
    input_eval = np.array([[0]], dtype=TYPE)
    huffman_tree = Huffman(subword_text_encoder.vocab_size)

    text_generated = []

    model.reset_states()

    for index, byte in enumerate(text):
        predictions = model(input_eval)
        predictions = tf.squeeze(predictions, 0) # remove the batch dimension

        weights = tf.nn.softmax(predictions[0]).numpy()
        huffman_tree.load_weights(weights)
        zeros += huffman_tree.get_code_zero_count(byte.item())
        archived_size += huffman_tree.get_code_length(byte.item())

        input_eval = tf.expand_dims([byte], 0)
  
    return archived_size, zeros

# %%
tf.train.latest_checkpoint(checkpoint_dir)
model = build_model(vocab_size = subword_text_encoder.vocab_size, embedding_dim=512, rnn_units=1024, batch_size=1)
model.load_weights(tf.train.latest_checkpoint(checkpoint_dir))
model.build(tf.TensorShape([1, None]))

# %%
archived_size, zeros = huffman_archive_size(model, encoded_article)
print('Compressed length:', archived_size)

compression_ratio = archived_size / (len(encoded_article) * 8)
print('Compression ratio for encoded:', compression_ratio)

compression_ratio = archived_size / (len(article) * 8)
print('Compression ratio for raw:', compression_ratio)

k = (zeros / archived_size)
compression_ratio = compression_ratio * (-k * np.log2(k) - (1-k) * np.log2(1-k))
print('Potential compression ratio with arithmetic coding:', compression_ratio)
# Out:
# Compressed length: 34985
# Compression ratio for encoded: 0.5318809292143031
# Compression ratio for raw: 0.1712198034532712
# Potential compression ratio with arithmetic coding: 0.171157297572381

# %% [markdown]
# Вече имаме сравнително бърза имплементация на Хъфман код. Можем да си позволим да видим как изглеждат резултатите за повече от една статия.

# %%
total_raw = 0
total_compressed = 0

for index, article in enumerate(itertools.islice(articles(), 0, 2000)):
    raw = (len(article) + 1) * 8
    encoded_article = np.array(subword_text_encoder.encode(article + b'\0'), dtype=TYPE)
    compressed, _ = huffman_archive_size(model, encoded_article)
    total_raw += raw
    total_compressed += compressed
    print('Article %d:\tCompression: %f\tAvg Compression: %f' % (index, compressed/raw, total_compressed/total_raw))
# Out:
# Article 0:	Compression: 23.722222	Avg Compression: 23.722222
# Article 1:	Compression: 10.196429	Avg Compression: 14.254167
# Article 2:	Compression: 8.719388	Avg Compression: 11.766055
# Article 3:	Compression: 14.320833	Avg Compression: 12.317446
# Article 4:	Compression: 12.214286	Avg Compression: 12.296695
# Article 5:	Compression: 10.948718	Avg Compression: 12.049883
# Article 6:	Compression: 0.158998	Avg Compression: 0.202087
# Article 7:	Compression: 11.543919	Avg Compression: 0.209222
# Article 8:	Compression: 10.728125	Avg Compression: 0.216371
# Article 9:	Compression: 10.181548	Avg Compression: 0.223477
# Article 10:	Compression: 11.286184	Avg Compression: 0.230610
# Article 11:	Compression: 9.710227	Avg Compression: 0.237682
# Article 12:	Compression: 9.727273	Avg Compression: 0.244756
# Article 13:	Compression: 11.223684	Avg Compression: 0.251820
# Article 14:	Compression: 9.095745	Avg Compression: 0.258852
# Article 15:	Compression: 17.781250	Avg Compression: 0.265964
# Article 16:	Compression: 12.235714	Avg Compression: 0.273045
# Article 17:	Compression: 17.848958	Avg Compression: 0.280171
# Article 18:	Compression: 0.149664	Avg Compression: 0.220909
# Article 19:	Compression: 12.928030	Avg Compression: 0.224775
# Article 20:	Compression: 12.185714	Avg Compression: 0.228634
# Article 21:	Compression: 11.223684	Avg Compression: 0.232484
# Article 22:	Compression: 14.416667	Avg Compression: 0.236403
# Article 23:	Compression: 16.418269	Avg Compression: 0.240278
# Article 24:	Compression: 12.544118	Avg Compression: 0.244129
# Article 25:	Compression: 12.905303	Avg Compression: 0.247974
# Article 26:	Compression: 18.548913	Avg Compression: 0.251847
# Article 27:	Compression: 0.205122	Avg Compression: 0.248320
# Article 28:	Compression: 11.510135	Avg Compression: 0.251863
# Article 29:	Compression: 7.431034	Avg Compression: 0.255403
# Article 30:	Compression: 0.189818	Avg Compression: 0.250022
# Article 31:	Compression: 17.796875	Avg Compression: 0.253308
# Article 32:	Compression: 19.369318	Avg Compression: 0.256588
# Article 33:	Compression: 18.603261	Avg Compression: 0.259879
# Article 34:	Compression: 19.346591	Avg Compression: 0.263153
# Article 35:	Compression: 19.346591	Avg Compression: 0.266426
# Article 36:	Compression: 17.755208	Avg Compression: 0.269697
# Article 37:	Compression: 20.380952	Avg Compression: 0.272988
# Article 38:	Compression: 20.309524	Avg Compression: 0.276267
# Article 39:	Compression: 15.290179	Avg Compression: 0.279542
# Article 40:	Compression: 14.241667	Avg Compression: 0.282804
# Article 41:	Compression: 17.864583	Avg Compression: 0.286089
# Article 42:	Compression: 8.421569	Avg Compression: 0.289319
# Article 43:	Compression: 9.938953	Avg Compression: 0.292548
# Article 44:	Compression: 10.169643	Avg Compression: 0.295774
# Article 45:	Compression: 10.169643	Avg Compression: 0.298999
# Article 46:	Compression: 10.942308	Avg Compression: 0.302226
# Article 47:	Compression: 10.935897	Avg Compression: 0.305449
# Article 48:	Compression: 13.762097	Avg Compression: 0.308690
# Article 49:	Compression: 15.276786	Avg Compression: 0.311945
# Article 50:	Compression: 18.510870	Avg Compression: 0.315196
# Article 51:	Compression: 12.958333	Avg Compression: 0.318435
# Article 52:	Compression: 15.865741	Avg Compression: 0.321694
# Article 53:	Compression: 15.232143	Avg Compression: 0.324934
# Article 54:	Compression: 17.055000	Avg Compression: 0.328179
# Article 55:	Compression: 11.503378	Avg Compression: 0.331387
# Article 56:	Compression: 17.770833	Avg Compression: 0.334633
# Article 57:	Compression: 20.267857	Avg Compression: 0.337879
# Article 58:	Compression: 13.786290	Avg Compression: 0.341111
# Article 59:	Compression: 17.796875	Avg Compression: 0.344358
# Article 60:	Compression: 12.246429	Avg Compression: 0.347587
# Article 61:	Compression: 12.931818	Avg Compression: 0.350804
# Article 62:	Compression: 15.406250	Avg Compression: 0.354069
# Article 63:	Compression: 13.745968	Avg Compression: 0.357284
# Article 64:	Compression: 17.843750	Avg Compression: 0.360533
# Article 65:	Compression: 19.335227	Avg Compression: 0.363764
# Article 66:	Compression: 17.796875	Avg Compression: 0.367002
# Article 67:	Compression: 15.254464	Avg Compression: 0.370228
# Article 68:	Compression: 14.715517	Avg Compression: 0.373446
# Article 69:	Compression: 9.494444	Avg Compression: 0.376620
# Article 70:	Compression: 14.212500	Avg Compression: 0.379829
# Article 71:	Compression: 13.398438	Avg Compression: 0.383049
# Article 72:	Compression: 13.883065	Avg Compression: 0.386283
# Article 73:	Compression: 12.928030	Avg Compression: 0.389481
# Article 74:	Compression: 9.988372	Avg Compression: 0.392669
# Article 75:	Compression: 13.826613	Avg Compression: 0.395884
# Article 76:	Compression: 18.548913	Avg Compression: 0.399108
# Article 77:	Compression: 12.260714	Avg Compression: 0.402312
# Article 78:	Compression: 11.233553	Avg Compression: 0.405487
# Article 79:	Compression: 12.577206	Avg Compression: 0.408680
# Article 80:	Compression: 12.943182	Avg Compression: 0.411869
# Article 81:	Compression: 10.961538	Avg Compression: 0.415041
# Article 82:	Compression: 21.300000	Avg Compression: 0.418261
# Article 83:	Compression: 10.163690	Avg Compression: 0.421415
# Article 84:	Compression: 0.189547	Avg Compression: 0.403312
# Article 85:	Compression: 12.577206	Avg Compression: 0.406252
# Article 86:	Compression: 12.973485	Avg Compression: 0.409197
# Article 87:	Compression: 10.163690	Avg Compression: 0.412105
# Article 88:	Compression: 14.754310	Avg Compression: 0.415057
# Article 89:	Compression: 11.895833	Avg Compression: 0.417989
# Article 90:	Compression: 14.780172	Avg Compression: 0.420944
# Article 91:	Compression: 15.828704	Avg Compression: 0.423894
# Article 92:	Compression: 0.135672	Avg Compression: 0.387091
# Article 93:	Compression: 19.392045	Avg Compression: 0.389678
# Article 94:	Compression: 0.186914	Avg Compression: 0.366974
# Article 95:	Compression: 12.595588	Avg Compression: 0.369258
# Article 96:	Compression: 0.148698	Avg Compression: 0.301741
# Article 97:	Compression: 0.153133	Avg Compression: 0.280243
# Article 98:	Compression: 0.243616	Avg Compression: 0.280110
# Article 99:	Compression: 21.300000	Avg Compression: 0.281476
# Article 100:	Compression: 9.494444	Avg Compression: 0.282822
# Article 101:	Compression: 9.744318	Avg Compression: 0.284174
# Article 102:	Compression: 9.513889	Avg Compression: 0.285522
# Article 103:	Compression: 7.921296	Avg Compression: 0.286860
# Article 104:	Compression: 7.660714	Avg Compression: 0.288200
# Article 105:	Compression: 8.394608	Avg Compression: 0.289542
# Article 106:	Compression: 10.178571	Avg Compression: 0.290889
# Article 107:	Compression: 7.256250	Avg Compression: 0.292245
# Article 108:	Compression: 8.225962	Avg Compression: 0.293583
# Article 109:	Compression: 8.233173	Avg Compression: 0.294921
# Article 110:	Compression: 10.127907	Avg Compression: 0.296292
# Article 111:	Compression: 7.925000	Avg Compression: 0.297652
# Article 112:	Compression: 0.142183	Avg Compression: 0.292715
# Article 113:	Compression: 15.828704	Avg Compression: 0.294031
# Article 114:	Compression: 21.300000	Avg Compression: 0.295349
# Article 115:	Compression: 9.347826	Avg Compression: 0.296656
# Article 116:	Compression: 21.331250	Avg Compression: 0.297976
# Article 117:	Compression: 0.489853	Avg Compression: 0.298648
# Article 118:	Compression: 11.273026	Avg Compression: 0.299952
# Article 119:	Compression: 0.271007	Avg Compression: 0.299630
# Article 120:	Compression: 0.171213	Avg Compression: 0.290233
# Article 121:	Compression: 0.206983	Avg Compression: 0.289071
# Article 122:	Compression: 15.875000	Avg Compression: 0.290260
# Article 123:	Compression: 0.150415	Avg Compression: 0.275670
# Article 124:	Compression: 0.375912	Avg Compression: 0.276120
# Article 125:	Compression: 12.595588	Avg Compression: 0.277175
# Article 126:	Compression: 13.826613	Avg Compression: 0.278233
# Article 127:	Compression: 0.226928	Avg Compression: 0.277681
# Article 128:	Compression: 12.935606	Avg Compression: 0.278721
# Article 129:	Compression: 12.189286	Avg Compression: 0.279760
# Article 130:	Compression: 11.230263	Avg Compression: 0.280796
# Article 131:	Compression: 12.573529	Avg Compression: 0.281837
# Article 132:	Compression: 0.193346	Avg Compression: 0.279845
# Article 133:	Compression: 10.675000	Avg Compression: 0.280857
# Article 134:	Compression: 12.210714	Avg Compression: 0.281873
# Article 135:	Compression: 12.544118	Avg Compression: 0.282888
# Article 136:	Compression: 9.304348	Avg Compression: 0.283898
# Article 137:	Compression: 11.920139	Avg Compression: 0.284917
# Article 138:	Compression: 6.925403	Avg Compression: 0.285919
# Article 139:	Compression: 0.163121	Avg Compression: 0.278942
# Article 140:	Compression: 0.160984	Avg Compression: 0.271156
# Article 141:	Compression: 0.282908	Avg Compression: 0.271245
# Article 142:	Compression: 0.176447	Avg Compression: 0.269639
# Article 143:	Compression: 0.188564	Avg Compression: 0.268880
# Article 144:	Compression: 10.942308	Avg Compression: 0.269742
# Article 145:	Compression: 0.150426	Avg Compression: 0.265487
# Article 146:	Compression: 0.181304	Avg Compression: 0.264103
# Article 147:	Compression: 0.183549	Avg Compression: 0.261942
# Article 148:	Compression: 0.155690	Avg Compression: 0.255762
# Article 149:	Compression: 0.153408	Avg Compression: 0.249304
# Article 150:	Compression: 12.217857	Avg Compression: 0.250011
# Article 151:	Compression: 0.191597	Avg Compression: 0.249324
# Article 152:	Compression: 0.155104	Avg Compression: 0.240703
# Article 153:	Compression: 0.179711	Avg Compression: 0.239304
# Article 154:	Compression: 18.505435	Avg Compression: 0.239926
# Article 155:	Compression: 0.149228	Avg Compression: 0.235967
# Article 156:	Compression: 0.137151	Avg Compression: 0.229611
# Article 157:	Compression: 0.149979	Avg Compression: 0.228164
# Article 158:	Compression: 0.497690	Avg Compression: 0.228524
# Article 159:	Compression: 0.192370	Avg Compression: 0.228280
# Article 160:	Compression: 17.848958	Avg Compression: 0.228826
# Article 161:	Compression: 0.243613	Avg Compression: 0.228905
# Article 162:	Compression: 0.166498	Avg Compression: 0.226725
# Article 163:	Compression: 0.276612	Avg Compression: 0.226908
# Article 164:	Compression: 0.137315	Avg Compression: 0.221572
# Article 165:	Compression: 10.049419	Avg Compression: 0.222062
# Article 166:	Compression: 0.285769	Avg Compression: 0.222254
# Article 167:	Compression: 17.080000	Avg Compression: 0.222741
# Article 168:	Compression: 17.130000	Avg Compression: 0.223230
# Article 169:	Compression: 0.182859	Avg Compression: 0.222724
# Article 170:	Compression: 0.185937	Avg Compression: 0.221552
# Article 171:	Compression: 0.149921	Avg Compression: 0.217958
# Article 172:	Compression: 12.189286	Avg Compression: 0.218398
# Article 173:	Compression: 0.208456	Avg Compression: 0.218352
# Article 174:	Compression: 10.961538	Avg Compression: 0.218790
# Article 175:	Compression: 0.194482	Avg Compression: 0.218503
# Article 176:	Compression: 0.155563	Avg Compression: 0.217577
# Article 177:	Compression: 12.973485	Avg Compression: 0.218005
# Article 178:	Compression: 12.200000	Avg Compression: 0.218432
# Article 179:	Compression: 11.233553	Avg Compression: 0.218858
# Article 180:	Compression: 12.577206	Avg Compression: 0.219285
# Article 181:	Compression: 12.943182	Avg Compression: 0.219712
# Article 182:	Compression: 19.363636	Avg Compression: 0.220141
# Article 183:	Compression: 10.678125	Avg Compression: 0.220566
# Article 184:	Compression: 10.700000	Avg Compression: 0.220993
# Article 185:	Compression: 9.944767	Avg Compression: 0.221418
# Article 186:	Compression: 9.944767	Avg Compression: 0.221843
# Article 187:	Compression: 9.944767	Avg Compression: 0.222268
# Article 188:	Compression: 0.174089	Avg Compression: 0.222074
# Article 189:	Compression: 0.257509	Avg Compression: 0.222165
# Article 190:	Compression: 11.958333	Avg Compression: 0.222592
# Article 191:	Compression: 0.395436	Avg Compression: 0.222656
# Article 192:	Compression: 7.625000	Avg Compression: 0.223075
# Article 193:	Compression: 0.158042	Avg Compression: 0.219587
# Article 194:	Compression: 0.178272	Avg Compression: 0.218581
# Article 195:	Compression: 0.197923	Avg Compression: 0.218413
# Article 196:	Compression: 19.426136	Avg Compression: 0.218804
# Article 197:	Compression: 22.460526	Avg Compression: 0.219195
# Article 198:	Compression: 0.144357	Avg Compression: 0.216810
# Article 199:	Compression: 0.152678	Avg Compression: 0.216587
# Article 200:	Compression: 14.762931	Avg Compression: 0.216964
# Article 201:	Compression: 0.167989	Avg Compression: 0.215859
# Article 202:	Compression: 0.166545	Avg Compression: 0.215077
# Article 203:	Compression: 13.382812	Avg Compression: 0.215439
# Article 204:	Compression: 0.309923	Avg Compression: 0.215612
# Article 205:	Compression: 0.319025	Avg Compression: 0.215790
# Article 206:	Compression: 0.185856	Avg Compression: 0.215409
# Article 207:	Compression: 0.169877	Avg Compression: 0.215286
# Article 208:	Compression: 11.881944	Avg Compression: 0.215640
# Article 209:	Compression: 12.175000	Avg Compression: 0.215992
# Article 210:	Compression: 12.175000	Avg Compression: 0.216344
# Article 211:	Compression: 12.175000	Avg Compression: 0.216697
# Article 212:	Compression: 0.155921	Avg Compression: 0.214772
# Article 213:	Compression: 0.180966	Avg Compression: 0.214468
# Article 214:	Compression: 0.231603	Avg Compression: 0.214499
# Article 215:	Compression: 20.470238	Avg Compression: 0.214842
# Article 216:	Compression: 11.878472	Avg Compression: 0.215181
# Article 217:	Compression: 11.878472	Avg Compression: 0.215519
# Article 218:	Compression: 13.414062	Avg Compression: 0.215860
# Article 219:	Compression: 21.300000	Avg Compression: 0.216200
# Article 220:	Compression: 0.326307	Avg Compression: 0.216381
# Article 221:	Compression: 17.755208	Avg Compression: 0.216720
# Article 222:	Compression: 0.220318	Avg Compression: 0.216747
# Article 223:	Compression: 12.189286	Avg Compression: 0.217081
# Article 224:	Compression: 0.198323	Avg Compression: 0.216921
# Article 225:	Compression: 1.163631	Avg Compression: 0.217219
# Article 226:	Compression: 0.196381	Avg Compression: 0.217029
# Article 227:	Compression: 0.170451	Avg Compression: 0.216520
# Article 228:	Compression: 0.212031	Avg Compression: 0.216509
# Article 229:	Compression: 11.550676	Avg Compression: 0.216834
# Article 230:	Compression: 0.174306	Avg Compression: 0.216709
# Article 231:	Compression: 0.157498	Avg Compression: 0.214753
# Article 232:	Compression: 0.254207	Avg Compression: 0.214842
# Article 233:	Compression: 0.159888	Avg Compression: 0.213712
# Article 234:	Compression: 0.153179	Avg Compression: 0.211672
# Article 235:	Compression: 0.188966	Avg Compression: 0.211507
# Article 236:	Compression: 0.277243	Avg Compression: 0.211680
# Article 237:	Compression: 0.184826	Avg Compression: 0.211601
# Article 238:	Compression: 0.203701	Avg Compression: 0.211591
# Article 239:	Compression: 17.100000	Avg Compression: 0.211885
# Article 240:	Compression: 0.164029	Avg Compression: 0.211263
# Article 241:	Compression: 0.172245	Avg Compression: 0.211184
# Article 242:	Compression: 0.193687	Avg Compression: 0.211087
# Article 243:	Compression: 0.372225	Avg Compression: 0.211299
# Article 244:	Compression: 0.202466	Avg Compression: 0.211257
# Article 245:	Compression: 0.251224	Avg Compression: 0.211375
# Article 246:	Compression: 15.232143	Avg Compression: 0.211659
# Article 247:	Compression: 0.259328	Avg Compression: 0.211689
# Article 248:	Compression: 0.209805	Avg Compression: 0.211680
# Article 249:	Compression: 0.315233	Avg Compression: 0.211828
# Article 250:	Compression: 0.241172	Avg Compression: 0.211927
# Article 251:	Compression: 0.386265	Avg Compression: 0.212115
# Article 252:	Compression: 15.856481	Avg Compression: 0.212397
# Article 253:	Compression: 0.166986	Avg Compression: 0.211740
# Article 254:	Compression: 12.221429	Avg Compression: 0.212016
# Article 255:	Compression: 11.881944	Avg Compression: 0.212292
# Article 256:	Compression: 0.155334	Avg Compression: 0.211375
# Article 257:	Compression: 0.147058	Avg Compression: 0.210824
# Article 258:	Compression: 0.153469	Avg Compression: 0.210213
# Article 259:	Compression: 21.312500	Avg Compression: 0.210481
# Article 260:	Compression: 9.127660	Avg Compression: 0.210747
# Article 261:	Compression: 0.187654	Avg Compression: 0.210587
# Article 262:	Compression: 0.414167	Avg Compression: 0.210788
# Article 263:	Compression: 0.163627	Avg Compression: 0.210183
# Article 264:	Compression: 0.154511	Avg Compression: 0.209351
# Article 265:	Compression: 17.776042	Avg Compression: 0.209609
# Article 266:	Compression: 0.163348	Avg Compression: 0.208857
# Article 267:	Compression: 0.145738	Avg Compression: 0.208047
# Article 268:	Compression: 13.339844	Avg Compression: 0.208297
# Article 269:	Compression: 0.176052	Avg Compression: 0.207980
# Article 270:	Compression: 0.196649	Avg Compression: 0.207944
# Article 271:	Compression: 0.224436	Avg Compression: 0.207987
# Article 272:	Compression: 0.224284	Avg Compression: 0.208036
# Article 273:	Compression: 0.438238	Avg Compression: 0.208195
# Article 274:	Compression: 0.346210	Avg Compression: 0.208373
# Article 275:	Compression: 0.452256	Avg Compression: 0.208549
# Article 276:	Compression: 0.306796	Avg Compression: 0.208665
# Article 277:	Compression: 0.166321	Avg Compression: 0.208420
# Article 278:	Compression: 0.190454	Avg Compression: 0.208316
# Article 279:	Compression: 0.197697	Avg Compression: 0.208249
# Article 280:	Compression: 17.739583	Avg Compression: 0.208490
# Article 281:	Compression: 0.154257	Avg Compression: 0.207360
# Article 282:	Compression: 0.247833	Avg Compression: 0.207450
# Article 283:	Compression: 0.181123	Avg Compression: 0.207205
# Article 284:	Compression: 0.182806	Avg Compression: 0.206889
# Article 285:	Compression: 9.323370	Avg Compression: 0.207117
# Article 286:	Compression: 12.239286	Avg Compression: 0.207347
# Article 287:	Compression: 0.237008	Avg Compression: 0.207392
# Article 288:	Compression: 0.394584	Avg Compression: 0.207580
# Article 289:	Compression: 12.239286	Avg Compression: 0.207809
# Article 290:	Compression: 0.222835	Avg Compression: 0.207847
# Article 291:	Compression: 19.426136	Avg Compression: 0.208076
# Article 292:	Compression: 0.154994	Avg Compression: 0.206229
# Article 293:	Compression: 0.154677	Avg Compression: 0.204689
# Article 294:	Compression: 0.154447	Avg Compression: 0.204116
# Article 295:	Compression: 0.182182	Avg Compression: 0.203940
# Article 296:	Compression: 0.152066	Avg Compression: 0.203108
# Article 297:	Compression: 17.080000	Avg Compression: 0.203315
# Article 298:	Compression: 12.192857	Avg Compression: 0.203521
# Article 299:	Compression: 0.148937	Avg Compression: 0.202577
# Article 300:	Compression: 0.152742	Avg Compression: 0.201931
# Article 301:	Compression: 0.158796	Avg Compression: 0.201524
# Article 302:	Compression: 0.181272	Avg Compression: 0.201378
# Article 303:	Compression: 16.447115	Avg Compression: 0.201575
# Article 304:	Compression: 0.184643	Avg Compression: 0.201341
# Article 305:	Compression: 0.168792	Avg Compression: 0.200976
# Article 306:	Compression: 0.209996	Avg Compression: 0.201016
# Article 307:	Compression: 12.544118	Avg Compression: 0.201206
# Article 308:	Compression: 6.913306	Avg Compression: 0.201395
# Article 309:	Compression: 10.678125	Avg Compression: 0.201586
# Article 310:	Compression: 12.518382	Avg Compression: 0.201776
# Article 311:	Compression: 9.924419	Avg Compression: 0.201965
# Article 312:	Compression: 11.223684	Avg Compression: 0.202156
# Article 313:	Compression: 6.699219	Avg Compression: 0.202344
# Article 314:	Compression: 12.905303	Avg Compression: 0.202535
# Article 315:	Compression: 10.662500	Avg Compression: 0.202725
# Article 316:	Compression: 9.924419	Avg Compression: 0.202914
# Article 317:	Compression: 0.275537	Avg Compression: 0.203009
# Article 318:	Compression: 0.159552	Avg Compression: 0.201879
# Article 319:	Compression: 0.197032	Avg Compression: 0.201875
# Article 320:	Compression: 14.312500	Avg Compression: 0.202061
# Article 321:	Compression: 0.691727	Avg Compression: 0.202211
# Article 322:	Compression: 0.180247	Avg Compression: 0.202121
# Article 323:	Compression: 0.146207	Avg Compression: 0.201144
# Article 324:	Compression: 0.147252	Avg Compression: 0.200057
# Article 325:	Compression: 0.274215	Avg Compression: 0.200158
# Article 326:	Compression: 0.141978	Avg Compression: 0.199113
# Article 327:	Compression: 0.155583	Avg Compression: 0.198702
# Article 328:	Compression: 11.273026	Avg Compression: 0.198875
# Article 329:	Compression: 0.400624	Avg Compression: 0.198971
# Article 330:	Compression: 1.043069	Avg Compression: 0.199146
# Article 331:	Compression: 0.158694	Avg Compression: 0.199096
# Article 332:	Compression: 0.427961	Avg Compression: 0.199225
# Article 333:	Compression: 0.157826	Avg Compression: 0.198236
# Article 334:	Compression: 0.201870	Avg Compression: 0.198247
# Article 335:	Compression: 0.186460	Avg Compression: 0.198189
# Article 336:	Compression: 0.210454	Avg Compression: 0.198213
# Article 337:	Compression: 0.283007	Avg Compression: 0.198307
# Article 338:	Compression: 0.431517	Avg Compression: 0.198415
# Article 339:	Compression: 0.234567	Avg Compression: 0.198477
# Article 340:	Compression: 0.173261	Avg Compression: 0.198178
# Article 341:	Compression: 0.168617	Avg Compression: 0.198162
# Article 342:	Compression: 0.278495	Avg Compression: 0.198241
# Article 343:	Compression: 11.878472	Avg Compression: 0.198404
# Article 344:	Compression: 0.157416	Avg Compression: 0.198235
# Article 345:	Compression: 0.149988	Avg Compression: 0.197967
# Article 346:	Compression: 0.175181	Avg Compression: 0.197734
# Article 347:	Compression: 2.728774	Avg Compression: 0.197888
# Article 348:	Compression: 0.183011	Avg Compression: 0.197775
# Article 349:	Compression: 0.153162	Avg Compression: 0.197313
# Article 350:	Compression: 21.375000	Avg Compression: 0.197472
# Article 351:	Compression: 22.414474	Avg Compression: 0.197630
# Article 352:	Compression: 0.182475	Avg Compression: 0.197441
# Article 353:	Compression: 10.662500	Avg Compression: 0.197596
# Article 354:	Compression: 0.160490	Avg Compression: 0.197040
# Article 355:	Compression: 0.217647	Avg Compression: 0.197084
# Article 356:	Compression: 0.235375	Avg Compression: 0.197141
# Article 357:	Compression: 8.176887	Avg Compression: 0.197295
# Article 358:	Compression: 6.132143	Avg Compression: 0.197446
# Article 359:	Compression: 5.961806	Avg Compression: 0.197597
# Article 360:	Compression: 11.259868	Avg Compression: 0.197750
# Article 361:	Compression: 10.181548	Avg Compression: 0.197902
# Article 362:	Compression: 6.132143	Avg Compression: 0.198053
# Article 363:	Compression: 9.710227	Avg Compression: 0.198205
# Article 364:	Compression: 5.586039	Avg Compression: 0.198356
# Article 365:	Compression: 6.038732	Avg Compression: 0.198506
# Article 366:	Compression: 5.373437	Avg Compression: 0.198657
# Article 367:	Compression: 16.538462	Avg Compression: 0.198811
# Article 368:	Compression: 0.245589	Avg Compression: 0.198887
# Article 369:	Compression: 0.199714	Avg Compression: 0.198889
# Article 370:	Compression: 12.182143	Avg Compression: 0.199041
# Article 371:	Compression: 11.233553	Avg Compression: 0.199193
# Article 372:	Compression: 12.569853	Avg Compression: 0.199345
# Article 373:	Compression: 12.920455	Avg Compression: 0.199497
# Article 374:	Compression: 10.675000	Avg Compression: 0.199648
# Article 375:	Compression: 10.690625	Avg Compression: 0.199800
# Article 376:	Compression: 9.938953	Avg Compression: 0.199952
# Article 377:	Compression: 12.536765	Avg Compression: 0.200103
# Article 378:	Compression: 9.938953	Avg Compression: 0.200255
# Article 379:	Compression: 12.935606	Avg Compression: 0.200407
# Article 380:	Compression: 9.087766	Avg Compression: 0.200558
# Article 381:	Compression: 9.769886	Avg Compression: 0.200710
# Article 382:	Compression: 13.075758	Avg Compression: 0.200864
# Article 383:	Compression: 0.148939	Avg Compression: 0.200513
# Article 384:	Compression: 0.176250	Avg Compression: 0.200257
# Article 385:	Compression: 0.222804	Avg Compression: 0.200294
# Article 386:	Compression: 0.196719	Avg Compression: 0.200280
# Article 387:	Compression: 0.176365	Avg Compression: 0.200140
# Article 388:	Compression: 0.734536	Avg Compression: 0.200249
# Article 389:	Compression: 0.181988	Avg Compression: 0.200091
# Article 390:	Compression: 0.186938	Avg Compression: 0.199974
# Article 391:	Compression: 0.177597	Avg Compression: 0.199841
# Article 392:	Compression: 0.190559	Avg Compression: 0.199794
# Article 393:	Compression: 0.185359	Avg Compression: 0.199740
# Article 394:	Compression: 0.162771	Avg Compression: 0.199486
# Article 395:	Compression: 0.234899	Avg Compression: 0.199599
# Article 396:	Compression: 0.181817	Avg Compression: 0.199536
# Article 397:	Compression: 19.414773	Avg Compression: 0.199678
# Article 398:	Compression: 0.150121	Avg Compression: 0.198991
# Article 399:	Compression: 0.200946	Avg Compression: 0.198996
# Article 400:	Compression: 25.125000	Avg Compression: 0.199135
# Article 401:	Compression: 0.407966	Avg Compression: 0.199262
# Article 402:	Compression: 20.339286	Avg Compression: 0.199402
# Article 403:	Compression: 0.159902	Avg Compression: 0.198774
# Article 404:	Compression: 0.145860	Avg Compression: 0.197700
# Article 405:	Compression: 0.176913	Avg Compression: 0.197479
# Article 406:	Compression: 0.208535	Avg Compression: 0.197512
# Article 407:	Compression: 0.205052	Avg Compression: 0.197529
# Article 408:	Compression: 0.183880	Avg Compression: 0.197497
# Article 409:	Compression: 0.213114	Avg Compression: 0.197507
# Article 410:	Compression: 0.191618	Avg Compression: 0.197494
# Article 411:	Compression: 15.828704	Avg Compression: 0.197625
# Article 412:	Compression: 0.177438	Avg Compression: 0.197532
# Article 413:	Compression: 14.245833	Avg Compression: 0.197663
# Article 414:	Compression: 0.150652	Avg Compression: 0.197150
# Article 415:	Compression: 0.729013	Avg Compression: 0.197283
# Article 416:	Compression: 0.183345	Avg Compression: 0.197202
# Article 417:	Compression: 0.233138	Avg Compression: 0.197252
# Article 418:	Compression: 0.204460	Avg Compression: 0.197271
# Article 419:	Compression: 0.144336	Avg Compression: 0.196046
# Article 420:	Compression: 0.173454	Avg Compression: 0.195839
# Article 421:	Compression: 0.201721	Avg Compression: 0.195860
# Article 422:	Compression: 0.372021	Avg Compression: 0.195958
# Article 423:	Compression: 0.720098	Avg Compression: 0.196075
# Article 424:	Compression: 0.282421	Avg Compression: 0.196162
# Article 425:	Compression: 1.326389	Avg Compression: 0.196281
# Article 426:	Compression: 0.161695	Avg Compression: 0.196034
# Article 427:	Compression: 0.183189	Avg Compression: 0.195943
# Article 428:	Compression: 0.184058	Avg Compression: 0.195898
# Article 429:	Compression: 0.198298	Avg Compression: 0.195902
# Article 430:	Compression: 0.204561	Avg Compression: 0.195923
# Article 431:	Compression: 16.394231	Avg Compression: 0.196044
# Article 432:	Compression: 0.875223	Avg Compression: 0.196152
# Article 433:	Compression: 0.151624	Avg Compression: 0.195165
# Article 434:	Compression: 0.172862	Avg Compression: 0.195067
# Article 435:	Compression: 17.734375	Avg Compression: 0.195184
# Article 436:	Compression: 0.181237	Avg Compression: 0.195151
# Article 437:	Compression: 0.168122	Avg Compression: 0.195042
# Article 438:	Compression: 0.171008	Avg Compression: 0.194970
# Article 439:	Compression: 0.189470	Avg Compression: 0.194961
# Article 440:	Compression: 0.185848	Avg Compression: 0.194942
# Article 441:	Compression: 0.207558	Avg Compression: 0.194958
# Article 442:	Compression: 0.151404	Avg Compression: 0.194603
# Article 443:	Compression: 0.238713	Avg Compression: 0.194660
# Article 444:	Compression: 0.162035	Avg Compression: 0.194312
# Article 445:	Compression: 0.876214	Avg Compression: 0.194426
# Article 446:	Compression: 0.140328	Avg Compression: 0.194258
# Article 447:	Compression: 10.964744	Avg Compression: 0.194371
# Article 448:	Compression: 21.375000	Avg Compression: 0.194484
# Article 449:	Compression: 0.156378	Avg Compression: 0.194343
# Article 450:	Compression: 0.446141	Avg Compression: 0.194451
# Article 451:	Compression: 0.180315	Avg Compression: 0.194427
# Article 452:	Compression: 11.895833	Avg Compression: 0.194539
# Article 453:	Compression: 0.181592	Avg Compression: 0.194493
# Article 454:	Compression: 0.376849	Avg Compression: 0.194569
# Article 455:	Compression: 0.326985	Avg Compression: 0.194651
# Article 456:	Compression: 11.437500	Avg Compression: 0.194764
# Article 457:	Compression: 15.236607	Avg Compression: 0.194876
# Article 458:	Compression: 15.236607	Avg Compression: 0.194987
# Article 459:	Compression: 0.209462	Avg Compression: 0.194998
# Article 460:	Compression: 0.278256	Avg Compression: 0.195065
# Article 461:	Compression: 0.182083	Avg Compression: 0.195005
# Article 462:	Compression: 15.879630	Avg Compression: 0.195116
# Article 463:	Compression: 0.178943	Avg Compression: 0.195067
# Article 464:	Compression: 17.828125	Avg Compression: 0.195178
# Article 465:	Compression: 17.838542	Avg Compression: 0.195290
# Article 466:	Compression: 0.163938	Avg Compression: 0.195082
# Article 467:	Compression: 0.162824	Avg Compression: 0.194955
# Article 468:	Compression: 0.294718	Avg Compression: 0.195023
# Article 469:	Compression: 0.215616	Avg Compression: 0.195050
# Article 470:	Compression: 0.179541	Avg Compression: 0.195030
# Article 471:	Compression: 0.612360	Avg Compression: 0.195126
# Article 472:	Compression: 0.365016	Avg Compression: 0.195206
# Article 473:	Compression: 17.744792	Avg Compression: 0.195315
# Article 474:	Compression: 17.744792	Avg Compression: 0.195424
# Article 475:	Compression: 17.744792	Avg Compression: 0.195533
# Article 476:	Compression: 17.744792	Avg Compression: 0.195642
# Article 477:	Compression: 17.744792	Avg Compression: 0.195752
# Article 478:	Compression: 17.744792	Avg Compression: 0.195861
# Article 479:	Compression: 17.744792	Avg Compression: 0.195970
# Article 480:	Compression: 17.744792	Avg Compression: 0.196079
# Article 481:	Compression: 17.744792	Avg Compression: 0.196188
# Article 482:	Compression: 17.744792	Avg Compression: 0.196297
# Article 483:	Compression: 17.744792	Avg Compression: 0.196406
# Article 484:	Compression: 17.744792	Avg Compression: 0.196515
# Article 485:	Compression: 0.992771	Avg Compression: 0.196600
# Article 486:	Compression: 0.163492	Avg Compression: 0.196524
# Article 487:	Compression: 0.204768	Avg Compression: 0.196537
# Article 488:	Compression: 0.574697	Avg Compression: 0.196626
# Article 489:	Compression: 0.168651	Avg Compression: 0.196456
# Article 490:	Compression: 0.300611	Avg Compression: 0.196515
# Article 491:	Compression: 0.222048	Avg Compression: 0.196558
# Article 492:	Compression: 0.247214	Avg Compression: 0.196625
# Article 493:	Compression: 0.250068	Avg Compression: 0.196676
# Article 494:	Compression: 16.466346	Avg Compression: 0.196784
# Article 495:	Compression: 0.204625	Avg Compression: 0.196793
# Article 496:	Compression: 13.745968	Avg Compression: 0.196900
# Article 497:	Compression: 1.604167	Avg Compression: 0.197001
# Article 498:	Compression: 0.346341	Avg Compression: 0.197075
# Article 499:	Compression: 0.602841	Avg Compression: 0.197189
# Article 500:	Compression: 0.407707	Avg Compression: 0.197260
# Article 501:	Compression: 11.797297	Avg Compression: 0.197369
# Article 502:	Compression: 0.288148	Avg Compression: 0.197434
# Article 503:	Compression: 13.758065	Avg Compression: 0.197541
# Article 504:	Compression: 0.249337	Avg Compression: 0.197613
# Article 505:	Compression: 17.744792	Avg Compression: 0.197720
# Article 506:	Compression: 0.189673	Avg Compression: 0.197702
# Article 507:	Compression: 13.355469	Avg Compression: 0.197809
# Article 508:	Compression: 0.166239	Avg Compression: 0.197772
# Article 509:	Compression: 0.230698	Avg Compression: 0.197809
# Article 510:	Compression: 0.186704	Avg Compression: 0.197775
# Article 511:	Compression: 17.744792	Avg Compression: 0.197881
# Article 512:	Compression: 0.168671	Avg Compression: 0.197746
# Article 513:	Compression: 0.145392	Avg Compression: 0.197500
# Article 514:	Compression: 12.228571	Avg Compression: 0.197605
# Article 515:	Compression: 0.339310	Avg Compression: 0.197684
# Article 516:	Compression: 0.234981	Avg Compression: 0.197722
# Article 517:	Compression: 0.170593	Avg Compression: 0.197581
# Article 518:	Compression: 0.145209	Avg Compression: 0.197375
# Article 519:	Compression: 0.190225	Avg Compression: 0.197358
# Article 520:	Compression: 0.219677	Avg Compression: 0.197379
# Article 521:	Compression: 17.781250	Avg Compression: 0.197482
# Article 522:	Compression: 0.191439	Avg Compression: 0.197465
# Article 523:	Compression: 0.189571	Avg Compression: 0.197451
# Article 524:	Compression: 0.192061	Avg Compression: 0.197438
# Article 525:	Compression: 21.306250	Avg Compression: 0.197541
# Article 526:	Compression: 0.194500	Avg Compression: 0.197535
# Article 527:	Compression: 0.229064	Avg Compression: 0.197574
# Article 528:	Compression: 0.193366	Avg Compression: 0.197552
# Article 529:	Compression: 0.125117	Avg Compression: 0.197291
# Article 530:	Compression: 0.142442	Avg Compression: 0.197104
# Article 531:	Compression: 0.137328	Avg Compression: 0.196918
# Article 532:	Compression: 0.131563	Avg Compression: 0.196657
# Article 533:	Compression: 0.133254	Avg Compression: 0.196412
# Article 534:	Compression: 0.142136	Avg Compression: 0.196236
# Article 535:	Compression: 0.138499	Avg Compression: 0.196053
# Article 536:	Compression: 0.166266	Avg Compression: 0.195895
# Article 537:	Compression: 0.197703	Avg Compression: 0.195898
# Article 538:	Compression: 0.176134	Avg Compression: 0.195839
# Article 539:	Compression: 0.146086	Avg Compression: 0.195796
# Article 540:	Compression: 0.139604	Avg Compression: 0.195610
# Article 541:	Compression: 0.185198	Avg Compression: 0.195562
# Article 542:	Compression: 0.489031	Avg Compression: 0.195595
# Article 543:	Compression: 0.190241	Avg Compression: 0.195571
# Article 544:	Compression: 0.146032	Avg Compression: 0.194679
# Article 545:	Compression: 12.621324	Avg Compression: 0.194775
# Article 546:	Compression: 0.138179	Avg Compression: 0.194609
# Article 547:	Compression: 0.216015	Avg Compression: 0.194633
# Article 548:	Compression: 0.157731	Avg Compression: 0.194510
# Article 549:	Compression: 0.166232	Avg Compression: 0.194395
# Article 550:	Compression: 0.247064	Avg Compression: 0.194439
# Article 551:	Compression: 0.176787	Avg Compression: 0.194395
# Article 552:	Compression: 0.186696	Avg Compression: 0.194378
# Article 553:	Compression: 23.722222	Avg Compression: 0.194472
# Article 554:	Compression: 0.206452	Avg Compression: 0.194496
# Article 555:	Compression: 0.209825	Avg Compression: 0.194522
# Article 556:	Compression: 13.312500	Avg Compression: 0.194616
# Article 557:	Compression: 0.492115	Avg Compression: 0.194679
# Article 558:	Compression: 0.204363	Avg Compression: 0.194694
# Article 559:	Compression: 0.266028	Avg Compression: 0.194752
# Article 560:	Compression: 0.229333	Avg Compression: 0.194806
# Article 561:	Compression: 0.303190	Avg Compression: 0.194866
# Article 562:	Compression: 0.183771	Avg Compression: 0.194832
# Article 563:	Compression: 0.184745	Avg Compression: 0.194797
# Article 564:	Compression: 0.149430	Avg Compression: 0.194630
# Article 565:	Compression: 15.392857	Avg Compression: 0.194723
# Article 566:	Compression: 0.234935	Avg Compression: 0.194766
# Article 567:	Compression: 18.646739	Avg Compression: 0.194858
# Article 568:	Compression: 0.237409	Avg Compression: 0.194895
# Article 569:	Compression: 0.190965	Avg Compression: 0.194887
# Article 570:	Compression: 0.620429	Avg Compression: 0.194968
# Article 571:	Compression: 12.175000	Avg Compression: 0.195060
# Article 572:	Compression: 12.175000	Avg Compression: 0.195151
# Article 573:	Compression: 12.175000	Avg Compression: 0.195242
# Article 574:	Compression: 0.287423	Avg Compression: 0.195321
# Article 575:	Compression: 0.204439	Avg Compression: 0.195340
# Article 576:	Compression: 9.087766	Avg Compression: 0.195431
# Article 577:	Compression: 8.547500	Avg Compression: 0.195522
# Article 578:	Compression: 9.309783	Avg Compression: 0.195613
# Article 579:	Compression: 0.206604	Avg Compression: 0.195625
# Article 580:	Compression: 8.228365	Avg Compression: 0.195716
# Article 581:	Compression: 8.242788	Avg Compression: 0.195806
# Article 582:	Compression: 7.916667	Avg Compression: 0.195897
# Article 583:	Compression: 7.788636	Avg Compression: 0.195987
# Article 584:	Compression: 9.519444	Avg Compression: 0.196079
# Article 585:	Compression: 0.341100	Avg Compression: 0.196129
# Article 586:	Compression: 0.152890	Avg Compression: 0.195306
# Article 587:	Compression: 7.262712	Avg Compression: 0.195395
# Article 588:	Compression: 11.888889	Avg Compression: 0.195484
# Article 589:	Compression: 11.868056	Avg Compression: 0.195574
# Article 590:	Compression: 11.269737	Avg Compression: 0.195663
# Article 591:	Compression: 10.448171	Avg Compression: 0.195753
# Article 592:	Compression: 11.597973	Avg Compression: 0.195842
# Article 593:	Compression: 9.965116	Avg Compression: 0.195932
# Article 594:	Compression: 9.976744	Avg Compression: 0.196021
# Article 595:	Compression: 9.317935	Avg Compression: 0.196111
# Article 596:	Compression: 11.554054	Avg Compression: 0.196200
# Article 597:	Compression: 9.317935	Avg Compression: 0.196289
# Article 598:	Compression: 12.182143	Avg Compression: 0.196379
# Article 599:	Compression: 11.223684	Avg Compression: 0.196468
# Article 600:	Compression: 12.566176	Avg Compression: 0.196557
# Article 601:	Compression: 12.909091	Avg Compression: 0.196646
# Article 602:	Compression: 10.668750	Avg Compression: 0.196736
# Article 603:	Compression: 10.684375	Avg Compression: 0.196825
# Article 604:	Compression: 12.547794	Avg Compression: 0.196914
# Article 605:	Compression: 9.927326	Avg Compression: 0.197003
# Article 606:	Compression: 11.527027	Avg Compression: 0.197092
# Article 607:	Compression: 10.665625	Avg Compression: 0.197182
# Article 608:	Compression: 11.878472	Avg Compression: 0.197271
# Article 609:	Compression: 12.178571	Avg Compression: 0.197360
# Article 610:	Compression: 10.157738	Avg Compression: 0.197449
# Article 611:	Compression: 10.172619	Avg Compression: 0.197538
# Article 612:	Compression: 9.494444	Avg Compression: 0.197627
# Article 613:	Compression: 11.833333	Avg Compression: 0.197717
# Article 614:	Compression: 11.871528	Avg Compression: 0.197806
# Article 615:	Compression: 9.494444	Avg Compression: 0.197895
# Article 616:	Compression: 0.245589	Avg Compression: 0.197921
# Article 617:	Compression: 0.263908	Avg Compression: 0.197952
# Article 618:	Compression: 0.249856	Avg Compression: 0.197981
# Article 619:	Compression: 0.243524	Avg Compression: 0.198014
# Article 620:	Compression: 0.494841	Avg Compression: 0.198073
# Article 621:	Compression: 0.548784	Avg Compression: 0.198136
# Article 622:	Compression: 14.663793	Avg Compression: 0.198225
# Article 623:	Compression: 11.506757	Avg Compression: 0.198314
# Article 624:	Compression: 10.668750	Avg Compression: 0.198403
# Article 625:	Compression: 0.156198	Avg Compression: 0.198333
# Article 626:	Compression: 12.171429	Avg Compression: 0.198422
# Article 627:	Compression: 10.160714	Avg Compression: 0.198510
# Article 628:	Compression: 11.530405	Avg Compression: 0.198599
# Article 629:	Compression: 9.477778	Avg Compression: 0.198688
# Article 630:	Compression: 10.932692	Avg Compression: 0.198776
# Article 631:	Compression: 12.196429	Avg Compression: 0.198865
# Article 632:	Compression: 9.477778	Avg Compression: 0.198954
# Article 633:	Compression: 12.935606	Avg Compression: 0.199043
# Article 634:	Compression: 0.140490	Avg Compression: 0.198889
# Article 635:	Compression: 0.179127	Avg Compression: 0.198805
# Article 636:	Compression: 0.162770	Avg Compression: 0.198560
# Article 637:	Compression: 0.185801	Avg Compression: 0.198529
# Article 638:	Compression: 0.198332	Avg Compression: 0.198529
# Article 639:	Compression: 0.187107	Avg Compression: 0.198514
# Article 640:	Compression: 0.881734	Avg Compression: 0.198599
# Article 641:	Compression: 10.643750	Avg Compression: 0.198686
# Article 642:	Compression: 0.185985	Avg Compression: 0.198645
# Article 643:	Compression: 0.222593	Avg Compression: 0.198668
# Article 644:	Compression: 0.217644	Avg Compression: 0.198691
# Article 645:	Compression: 0.182871	Avg Compression: 0.198614
# Article 646:	Compression: 0.262328	Avg Compression: 0.198651
# Article 647:	Compression: 0.273179	Avg Compression: 0.198684
# Article 648:	Compression: 0.368917	Avg Compression: 0.198743
# Article 649:	Compression: 0.150204	Avg Compression: 0.198330
# Article 650:	Compression: 10.169643	Avg Compression: 0.198415
# Article 651:	Compression: 0.136515	Avg Compression: 0.198059
# Article 652:	Compression: 20.357143	Avg Compression: 0.198145
# Article 653:	Compression: 0.290532	Avg Compression: 0.198197
# Article 654:	Compression: 13.064394	Avg Compression: 0.198283
# Article 655:	Compression: 0.132699	Avg Compression: 0.198118
# Article 656:	Compression: 0.483434	Avg Compression: 0.198185
# Article 657:	Compression: 20.363095	Avg Compression: 0.198270
# Article 658:	Compression: 0.143423	Avg Compression: 0.198208
# Article 659:	Compression: 0.187078	Avg Compression: 0.198175
# Article 660:	Compression: 0.147110	Avg Compression: 0.198099
# Article 661:	Compression: 0.189180	Avg Compression: 0.198074
# Article 662:	Compression: 0.178761	Avg Compression: 0.198024
# Article 663:	Compression: 0.218826	Avg Compression: 0.198036
# Article 664:	Compression: 0.237648	Avg Compression: 0.198076
# Article 665:	Compression: 0.203230	Avg Compression: 0.198084
# Article 666:	Compression: 0.476825	Avg Compression: 0.198151
# Article 667:	Compression: 0.160337	Avg Compression: 0.198040
# Article 668:	Compression: 0.187014	Avg Compression: 0.198010
# Article 669:	Compression: 0.213861	Avg Compression: 0.198026
# Article 670:	Compression: 0.173599	Avg Compression: 0.197931
# Article 671:	Compression: 0.129602	Avg Compression: 0.197701
# Article 672:	Compression: 0.188512	Avg Compression: 0.197697
# Article 673:	Compression: 0.178632	Avg Compression: 0.197598
# Article 674:	Compression: 0.169492	Avg Compression: 0.197480
# Article 675:	Compression: 15.819444	Avg Compression: 0.197562
# Article 676:	Compression: 0.224370	Avg Compression: 0.197588
# Article 677:	Compression: 0.197115	Avg Compression: 0.197586
# Article 678:	Compression: 0.198671	Avg Compression: 0.197589
# Article 679:	Compression: 19.426136	Avg Compression: 0.197671
# Article 680:	Compression: 15.833333	Avg Compression: 0.197752
# Article 681:	Compression: 0.326557	Avg Compression: 0.197812
# Article 682:	Compression: 0.328859	Avg Compression: 0.197870
# Article 683:	Compression: 0.315473	Avg Compression: 0.197919
# Article 684:	Compression: 8.966146	Avg Compression: 0.198000
# Article 685:	Compression: 0.238229	Avg Compression: 0.198020
# Article 686:	Compression: 0.269618	Avg Compression: 0.198067
# Article 687:	Compression: 22.453947	Avg Compression: 0.198149
# Article 688:	Compression: 17.100000	Avg Compression: 0.198230
# Article 689:	Compression: 0.168432	Avg Compression: 0.198161
# Article 690:	Compression: 0.780632	Avg Compression: 0.198235
# Article 691:	Compression: 0.193680	Avg Compression: 0.198225
# Article 692:	Compression: 20.297619	Avg Compression: 0.198306
# Article 693:	Compression: 0.328787	Avg Compression: 0.198362
# Article 694:	Compression: 0.176458	Avg Compression: 0.198276
# Article 695:	Compression: 0.231767	Avg Compression: 0.198295
# Article 696:	Compression: 0.161812	Avg Compression: 0.197905
# Article 697:	Compression: 0.253174	Avg Compression: 0.197951
# Article 698:	Compression: 14.724138	Avg Compression: 0.198031
# Article 699:	Compression: 0.157699	Avg Compression: 0.197914
# Article 700:	Compression: 0.151149	Avg Compression: 0.197706
# Article 701:	Compression: 0.161112	Avg Compression: 0.197527
# Article 702:	Compression: 0.236248	Avg Compression: 0.197558
# Article 703:	Compression: 0.175072	Avg Compression: 0.197523
# Article 704:	Compression: 0.239343	Avg Compression: 0.197560
# Article 705:	Compression: 0.303342	Avg Compression: 0.197620
# Article 706:	Compression: 0.145674	Avg Compression: 0.197325
# Article 707:	Compression: 0.418310	Avg Compression: 0.197340
# Article 708:	Compression: 0.159223	Avg Compression: 0.197109
# Article 709:	Compression: 0.176199	Avg Compression: 0.197084
# Article 710:	Compression: 12.569853	Avg Compression: 0.197161
# Article 711:	Compression: 11.847222	Avg Compression: 0.197237
# Article 712:	Compression: 18.489130	Avg Compression: 0.197315
# Article 713:	Compression: 18.489130	Avg Compression: 0.197392
# Article 714:	Compression: 11.885417	Avg Compression: 0.197469
# Article 715:	Compression: 10.420732	Avg Compression: 0.197546
# Article 716:	Compression: 12.544118	Avg Compression: 0.197623
# Article 717:	Compression: 12.210714	Avg Compression: 0.197700
# Article 718:	Compression: 10.945513	Avg Compression: 0.197777
# Article 719:	Compression: 0.219695	Avg Compression: 0.197796
# Article 720:	Compression: 10.172619	Avg Compression: 0.197872
# Article 721:	Compression: 10.172619	Avg Compression: 0.197949
# Article 722:	Compression: 10.172619	Avg Compression: 0.198026
# Article 723:	Compression: 10.172619	Avg Compression: 0.198103
# Article 724:	Compression: 10.172619	Avg Compression: 0.198179
# Article 725:	Compression: 10.172619	Avg Compression: 0.198256
# Article 726:	Compression: 0.372930	Avg Compression: 0.198300
# Article 727:	Compression: 0.160236	Avg Compression: 0.198254
# Article 728:	Compression: 0.175056	Avg Compression: 0.198187
# Article 729:	Compression: 14.724138	Avg Compression: 0.198264
# Article 730:	Compression: 0.175568	Avg Compression: 0.198181
# Article 731:	Compression: 0.182690	Avg Compression: 0.198152
# Article 732:	Compression: 0.158759	Avg Compression: 0.198038
# Article 733:	Compression: 0.167842	Avg Compression: 0.197935
# Article 734:	Compression: 14.719828	Avg Compression: 0.198010
# Article 735:	Compression: 0.350275	Avg Compression: 0.198078
# Article 736:	Compression: 0.225913	Avg Compression: 0.198098
# Article 737:	Compression: 0.156672	Avg Compression: 0.198007
# Article 738:	Compression: 0.163033	Avg Compression: 0.197862
# Article 739:	Compression: 0.134945	Avg Compression: 0.197690
# Article 740:	Compression: 13.496094	Avg Compression: 0.197766
# Article 741:	Compression: 0.184349	Avg Compression: 0.197744
# Article 742:	Compression: 0.246319	Avg Compression: 0.197774
# Article 743:	Compression: 0.132343	Avg Compression: 0.197633
# Article 744:	Compression: 0.177119	Avg Compression: 0.197575
# Article 745:	Compression: 0.127980	Avg Compression: 0.197409
# Article 746:	Compression: 0.660103	Avg Compression: 0.197480
# Article 747:	Compression: 0.268213	Avg Compression: 0.197521
# Article 748:	Compression: 14.719828	Avg Compression: 0.197595
# Article 749:	Compression: 14.250000	Avg Compression: 0.197670
# Article 750:	Compression: 0.310495	Avg Compression: 0.197718
# Article 751:	Compression: 6.937500	Avg Compression: 0.197792
# Article 752:	Compression: 0.456514	Avg Compression: 0.197856
# Article 753:	Compression: 0.173931	Avg Compression: 0.197830
# Article 754:	Compression: 0.164963	Avg Compression: 0.197651
# Article 755:	Compression: 0.210148	Avg Compression: 0.197664
# Article 756:	Compression: 0.297686	Avg Compression: 0.197715
# Article 757:	Compression: 0.235240	Avg Compression: 0.197724
# Article 758:	Compression: 11.250000	Avg Compression: 0.197798
# Article 759:	Compression: 0.454167	Avg Compression: 0.197857
# Article 760:	Compression: 0.324357	Avg Compression: 0.197910
# Article 761:	Compression: 17.760417	Avg Compression: 0.197984
# Article 762:	Compression: 12.003472	Avg Compression: 0.198058
# Article 763:	Compression: 0.178966	Avg Compression: 0.198025
# Article 764:	Compression: 0.127466	Avg Compression: 0.197930
# Article 765:	Compression: 12.943182	Avg Compression: 0.198003
# Article 766:	Compression: 0.160032	Avg Compression: 0.197433
# Article 767:	Compression: 0.196904	Avg Compression: 0.197433
# Article 768:	Compression: 11.266447	Avg Compression: 0.197505
# Article 769:	Compression: 0.146508	Avg Compression: 0.197392
# Article 770:	Compression: 0.214491	Avg Compression: 0.197408
# Article 771:	Compression: 0.294155	Avg Compression: 0.197460
# Article 772:	Compression: 0.661243	Avg Compression: 0.197473
# Article 773:	Compression: 20.315476	Avg Compression: 0.197545
# Article 774:	Compression: 0.181801	Avg Compression: 0.197528
# Article 775:	Compression: 18.559783	Avg Compression: 0.197600
# Article 776:	Compression: 0.194652	Avg Compression: 0.197594
# Article 777:	Compression: 0.268295	Avg Compression: 0.197622
# Article 778:	Compression: 0.173074	Avg Compression: 0.197582
# Article 779:	Compression: 0.202834	Avg Compression: 0.197584
# Article 780:	Compression: 0.504541	Avg Compression: 0.197636
# Article 781:	Compression: 0.550935	Avg Compression: 0.197700
# Article 782:	Compression: 0.152711	Avg Compression: 0.197376
# ...
# Article 1744:	Compression: 0.171646	Avg Compression: 0.192389
# Article 1745:	Compression: 0.288086	Avg Compression: 0.192408
# Article 1746:	Compression: 0.473104	Avg Compression: 0.192431
# Article 1747:	Compression: 0.673593	Avg Compression: 0.192460
# Article 1748:	Compression: 0.416317	Avg Compression: 0.192489
# Article 1749:	Compression: 0.222399	Avg Compression: 0.192493
# Article 1750:	Compression: 0.476643	Avg Compression: 0.192523
# Article 1751:	Compression: 20.363095	Avg Compression: 0.192555
# Article 1752:	Compression: 0.195876	Avg Compression: 0.192557
# Article 1753:	Compression: 0.120760	Avg Compression: 0.192485
# Article 1754:	Compression: 0.408944	Avg Compression: 0.192511
# Article 1755:	Compression: 16.524038	Avg Compression: 0.192543
# Article 1756:	Compression: 0.342576	Avg Compression: 0.192563
# Article 1757:	Compression: 16.350962	Avg Compression: 0.192596
# Article 1758:	Compression: 0.534509	Avg Compression: 0.192617
# Article 1759:	Compression: 18.527174	Avg Compression: 0.192650
# Article 1760:	Compression: 0.141108	Avg Compression: 0.192525
# Article 1761:	Compression: 0.184096	Avg Compression: 0.192520
# Article 1762:	Compression: 18.581522	Avg Compression: 0.192553
# Article 1763:	Compression: 17.822917	Avg Compression: 0.192586
# Article 1764:	Compression: 0.151006	Avg Compression: 0.192510
# Article 1765:	Compression: 0.198351	Avg Compression: 0.192512
# Article 1766:	Compression: 0.968112	Avg Compression: 0.192542
# Article 1767:	Compression: 0.333799	Avg Compression: 0.192562
# Article 1768:	Compression: 0.155147	Avg Compression: 0.192526
# Article 1769:	Compression: 0.140530	Avg Compression: 0.192454
# Article 1770:	Compression: 0.747948	Avg Compression: 0.192483
# Article 1771:	Compression: 16.437500	Avg Compression: 0.192515
# Article 1772:	Compression: 0.166451	Avg Compression: 0.192474
# Article 1773:	Compression: 14.866379	Avg Compression: 0.192507
# Article 1774:	Compression: 0.238445	Avg Compression: 0.192520
# Article 1775:	Compression: 0.256743	Avg Compression: 0.192534
# Article 1776:	Compression: 0.148298	Avg Compression: 0.192517
# Article 1777:	Compression: 0.248548	Avg Compression: 0.192525
# Article 1778:	Compression: 0.262061	Avg Compression: 0.192541
# Article 1779:	Compression: 0.311202	Avg Compression: 0.192561
# Article 1780:	Compression: 21.306250	Avg Compression: 0.192594
# Article 1781:	Compression: 0.169851	Avg Compression: 0.192569
# Article 1782:	Compression: 17.060000	Avg Compression: 0.192601
# Article 1783:	Compression: 0.260541	Avg Compression: 0.192615
# Article 1784:	Compression: 13.060606	Avg Compression: 0.192647
# Article 1785:	Compression: 0.393884	Avg Compression: 0.192675
# Article 1786:	Compression: 0.773953	Avg Compression: 0.192702
# Article 1787:	Compression: 0.679949	Avg Compression: 0.192731
# Article 1788:	Compression: 18.728261	Avg Compression: 0.192764
# Article 1789:	Compression: 0.164008	Avg Compression: 0.192727
# Article 1790:	Compression: 25.117647	Avg Compression: 0.192759
# Article 1791:	Compression: 0.416170	Avg Compression: 0.192787
# Article 1792:	Compression: 11.895833	Avg Compression: 0.192819
# Article 1793:	Compression: 0.180741	Avg Compression: 0.192810
# Article 1794:	Compression: 17.195000	Avg Compression: 0.192842
# Article 1795:	Compression: 0.160054	Avg Compression: 0.192823
# Article 1796:	Compression: 0.302088	Avg Compression: 0.192841
# Article 1797:	Compression: 0.175286	Avg Compression: 0.192825
# Article 1798:	Compression: 0.164024	Avg Compression: 0.192789
# Article 1799:	Compression: 11.895833	Avg Compression: 0.192821
# Article 1800:	Compression: 0.342417	Avg Compression: 0.192844
# Article 1801:	Compression: 0.215752	Avg Compression: 0.192853
# Article 1802:	Compression: 0.202667	Avg Compression: 0.192858
# Article 1803:	Compression: 7.907407	Avg Compression: 0.192889
# Article 1804:	Compression: 0.575291	Avg Compression: 0.192902
# Article 1805:	Compression: 0.346123	Avg Compression: 0.192920
# Article 1806:	Compression: 0.181653	Avg Compression: 0.192915
# Article 1807:	Compression: 7.907407	Avg Compression: 0.192947
# Article 1808:	Compression: 0.103856	Avg Compression: 0.192843
# Article 1809:	Compression: 0.163027	Avg Compression: 0.192817
# Article 1810:	Compression: 0.118537	Avg Compression: 0.192737
# Article 1811:	Compression: 13.308594	Avg Compression: 0.192769
# Article 1812:	Compression: 14.715517	Avg Compression: 0.192801
# Article 1813:	Compression: 21.318750	Avg Compression: 0.192833
# Article 1814:	Compression: 21.318750	Avg Compression: 0.192865
# Article 1815:	Compression: 16.427885	Avg Compression: 0.192897
# Article 1816:	Compression: 17.817708	Avg Compression: 0.192929
# Article 1817:	Compression: 0.201144	Avg Compression: 0.192931
# Article 1818:	Compression: 0.313417	Avg Compression: 0.192952
# Article 1819:	Compression: 0.164011	Avg Compression: 0.192907
# Article 1820:	Compression: 0.177908	Avg Compression: 0.192902
# Article 1821:	Compression: 0.822849	Avg Compression: 0.192931
# Article 1822:	Compression: 1.127445	Avg Compression: 0.192960
# Article 1823:	Compression: 0.139857	Avg Compression: 0.192919
# Article 1824:	Compression: 0.550059	Avg Compression: 0.192931
# Article 1825:	Compression: 0.203229	Avg Compression: 0.192935
# Article 1826:	Compression: 13.312500	Avg Compression: 0.192967
# Article 1827:	Compression: 15.254464	Avg Compression: 0.192999
# Article 1828:	Compression: 21.300000	Avg Compression: 0.193030
# Article 1829:	Compression: 14.191667	Avg Compression: 0.193062
# Article 1830:	Compression: 14.191667	Avg Compression: 0.193094
# Article 1831:	Compression: 14.241667	Avg Compression: 0.193126
# Article 1832:	Compression: 11.864583	Avg Compression: 0.193157
# Article 1833:	Compression: 13.335938	Avg Compression: 0.193189
# Article 1834:	Compression: 0.176575	Avg Compression: 0.193183
# Article 1835:	Compression: 0.152715	Avg Compression: 0.193123
# Article 1836:	Compression: 0.162819	Avg Compression: 0.193071
# Article 1837:	Compression: 10.172619	Avg Compression: 0.193102
# Article 1838:	Compression: 0.150883	Avg Compression: 0.193049
# Article 1839:	Compression: 0.163205	Avg Compression: 0.193019
# Article 1840:	Compression: 8.821429	Avg Compression: 0.193051
# Article 1841:	Compression: 16.456731	Avg Compression: 0.193082
# Article 1842:	Compression: 16.350962	Avg Compression: 0.193114
# Article 1843:	Compression: 0.400900	Avg Compression: 0.193140
# Article 1844:	Compression: 11.604730	Avg Compression: 0.193172
# Article 1845:	Compression: 1.321686	Avg Compression: 0.193201
# Article 1846:	Compression: 2.907285	Avg Compression: 0.193232
# Article 1847:	Compression: 0.352869	Avg Compression: 0.193252
# Article 1848:	Compression: 0.231346	Avg Compression: 0.193263
# Article 1849:	Compression: 0.187909	Avg Compression: 0.193258
# Article 1850:	Compression: 0.220495	Avg Compression: 0.193265
# Article 1851:	Compression: 0.259389	Avg Compression: 0.193279
# Article 1852:	Compression: 14.715517	Avg Compression: 0.193310
# Article 1853:	Compression: 0.188049	Avg Compression: 0.193308
# Article 1854:	Compression: 11.601351	Avg Compression: 0.193340
# Article 1855:	Compression: 0.241783	Avg Compression: 0.193355
# Article 1856:	Compression: 18.836957	Avg Compression: 0.193387
# Article 1857:	Compression: 0.180693	Avg Compression: 0.193385
# Article 1858:	Compression: 0.406826	Avg Compression: 0.193413
# Article 1859:	Compression: 0.621289	Avg Compression: 0.193440
# Article 1860:	Compression: 0.205801	Avg Compression: 0.193442
# Article 1861:	Compression: 0.264991	Avg Compression: 0.193457
# Article 1862:	Compression: 0.366784	Avg Compression: 0.193477
# Article 1863:	Compression: 0.160779	Avg Compression: 0.193376
# Article 1864:	Compression: 0.167930	Avg Compression: 0.193369
# Article 1865:	Compression: 0.161859	Avg Compression: 0.193313
# Article 1866:	Compression: 0.279013	Avg Compression: 0.193332
# Article 1867:	Compression: 0.170712	Avg Compression: 0.193328
# Article 1868:	Compression: 0.984600	Avg Compression: 0.193357
# Article 1869:	Compression: 19.477273	Avg Compression: 0.193388
# Article 1870:	Compression: 0.263189	Avg Compression: 0.193401
# Article 1871:	Compression: 0.544388	Avg Compression: 0.193408
# Article 1872:	Compression: 0.309439	Avg Compression: 0.193429
# Article 1873:	Compression: 0.469479	Avg Compression: 0.193444
# Article 1874:	Compression: 15.819444	Avg Compression: 0.193475
# Article 1875:	Compression: 0.207149	Avg Compression: 0.193480
# Article 1876:	Compression: 22.453947	Avg Compression: 0.193511
# Article 1877:	Compression: 0.171238	Avg Compression: 0.193499
# Article 1878:	Compression: 0.236545	Avg Compression: 0.193511
# Article 1879:	Compression: 0.165124	Avg Compression: 0.193496
# Article 1880:	Compression: 0.171967	Avg Compression: 0.193464
# Article 1881:	Compression: 14.200000	Avg Compression: 0.193495
# Article 1882:	Compression: 14.685345	Avg Compression: 0.193526
# Article 1883:	Compression: 0.232997	Avg Compression: 0.193542
# Article 1884:	Compression: 0.261152	Avg Compression: 0.193560
# Article 1885:	Compression: 8.213942	Avg Compression: 0.193590
# Article 1886:	Compression: 15.777778	Avg Compression: 0.193621
# Article 1887:	Compression: 15.777778	Avg Compression: 0.193653
# Article 1888:	Compression: 15.777778	Avg Compression: 0.193684
# Article 1889:	Compression: 15.777778	Avg Compression: 0.193715
# Article 1890:	Compression: 17.070000	Avg Compression: 0.193746
# Article 1891:	Compression: 17.070000	Avg Compression: 0.193777
# Article 1892:	Compression: 0.482981	Avg Compression: 0.193800
# Article 1893:	Compression: 17.070000	Avg Compression: 0.193831
# Article 1894:	Compression: 17.070000	Avg Compression: 0.193862
# Article 1895:	Compression: 17.070000	Avg Compression: 0.193894
# Article 1896:	Compression: 12.203571	Avg Compression: 0.193925
# Article 1897:	Compression: 10.154762	Avg Compression: 0.193956
# Article 1898:	Compression: 0.220053	Avg Compression: 0.193966
# Article 1899:	Compression: 0.153711	Avg Compression: 0.193952
# Article 1900:	Compression: 0.775943	Avg Compression: 0.193975
# Article 1901:	Compression: 0.268875	Avg Compression: 0.193990
# Article 1902:	Compression: 0.202512	Avg Compression: 0.193991
# Article 1903:	Compression: 0.127048	Avg Compression: 0.193779
# Article 1904:	Compression: 0.273626	Avg Compression: 0.193798
# Article 1905:	Compression: 0.316845	Avg Compression: 0.193819
# Article 1906:	Compression: 0.216531	Avg Compression: 0.193829
# Article 1907:	Compression: 0.179019	Avg Compression: 0.193819
# Article 1908:	Compression: 0.187741	Avg Compression: 0.193813
# Article 1909:	Compression: 19.568182	Avg Compression: 0.193845
# Article 1910:	Compression: 0.429845	Avg Compression: 0.193870
# Article 1911:	Compression: 0.313647	Avg Compression: 0.193892
# Article 1912:	Compression: 1.533526	Avg Compression: 0.193922
# Article 1913:	Compression: 0.226440	Avg Compression: 0.193932
# Article 1914:	Compression: 0.342884	Avg Compression: 0.193950
# Article 1915:	Compression: 0.226720	Avg Compression: 0.193958
# Article 1916:	Compression: 0.449645	Avg Compression: 0.193978
# Article 1917:	Compression: 0.400916	Avg Compression: 0.193997
# Article 1918:	Compression: 0.220499	Avg Compression: 0.194004
# Article 1919:	Compression: 15.875000	Avg Compression: 0.194036
# Article 1920:	Compression: 12.757353	Avg Compression: 0.194067
# Article 1921:	Compression: 0.589814	Avg Compression: 0.194093
# Article 1922:	Compression: 0.340380	Avg Compression: 0.194112
# Article 1923:	Compression: 0.247318	Avg Compression: 0.194126
# Article 1924:	Compression: 0.135007	Avg Compression: 0.194086
# Article 1925:	Compression: 0.201430	Avg Compression: 0.194088
# Article 1926:	Compression: 0.428638	Avg Compression: 0.194111
# Article 1927:	Compression: 0.504064	Avg Compression: 0.194129
# Article 1928:	Compression: 0.377071	Avg Compression: 0.194151
# Article 1929:	Compression: 0.233478	Avg Compression: 0.194162
# Article 1930:	Compression: 0.160462	Avg Compression: 0.194135
# Article 1931:	Compression: 0.196567	Avg Compression: 0.194135
# Article 1932:	Compression: 0.165645	Avg Compression: 0.194112
# Article 1933:	Compression: 0.415970	Avg Compression: 0.194137
# Article 1934:	Compression: 14.254167	Avg Compression: 0.194168
# Article 1935:	Compression: 0.218587	Avg Compression: 0.194176
# Article 1936:	Compression: 0.142262	Avg Compression: 0.194146
# Article 1937:	Compression: 0.430670	Avg Compression: 0.194165
# Article 1938:	Compression: 0.216687	Avg Compression: 0.194173
# Article 1939:	Compression: 0.540136	Avg Compression: 0.194194
# Article 1940:	Compression: 0.141278	Avg Compression: 0.194128
# Article 1941:	Compression: 0.147002	Avg Compression: 0.193970
# Article 1942:	Compression: 0.178660	Avg Compression: 0.193958
# Article 1943:	Compression: 0.780702	Avg Compression: 0.193985
# Article 1944:	Compression: 0.151591	Avg Compression: 0.193958
# Article 1945:	Compression: 0.328937	Avg Compression: 0.193977
# Article 1946:	Compression: 10.945513	Avg Compression: 0.194007
# Article 1947:	Compression: 0.329448	Avg Compression: 0.194029
# Article 1948:	Compression: 18.771739	Avg Compression: 0.194060
# Article 1949:	Compression: 0.181883	Avg Compression: 0.194055
# Article 1950:	Compression: 0.194562	Avg Compression: 0.194055
# Article 1951:	Compression: 0.760540	Avg Compression: 0.194083
# Article 1952:	Compression: 0.284530	Avg Compression: 0.194098
# Article 1953:	Compression: 0.182240	Avg Compression: 0.194091
# Article 1954:	Compression: 0.558654	Avg Compression: 0.194119
# Article 1955:	Compression: 0.275930	Avg Compression: 0.194140
# Article 1956:	Compression: 0.176286	Avg Compression: 0.194125
# Article 1957:	Compression: 0.235297	Avg Compression: 0.194133
# Article 1958:	Compression: 0.187987	Avg Compression: 0.194130
# Article 1959:	Compression: 0.192612	Avg Compression: 0.194129
# Article 1960:	Compression: 17.090000	Avg Compression: 0.194160
# Article 1961:	Compression: 0.252776	Avg Compression: 0.194176
# Article 1962:	Compression: 21.343750	Avg Compression: 0.194206
# Article 1963:	Compression: 19.619318	Avg Compression: 0.194237
# Article 1964:	Compression: 0.519205	Avg Compression: 0.194263
# Article 1965:	Compression: 0.249866	Avg Compression: 0.194271
# Article 1966:	Compression: 0.119614	Avg Compression: 0.194189
# Article 1967:	Compression: 0.117540	Avg Compression: 0.194119
# Article 1968:	Compression: 0.124263	Avg Compression: 0.194034
# Article 1969:	Compression: 0.170474	Avg Compression: 0.194022
# Article 1970:	Compression: 0.178574	Avg Compression: 0.194013
# Article 1971:	Compression: 0.424372	Avg Compression: 0.194037
# Article 1972:	Compression: 0.315082	Avg Compression: 0.194059
# Article 1973:	Compression: 0.440051	Avg Compression: 0.194084
# Article 1974:	Compression: 13.011364	Avg Compression: 0.194114
# Article 1975:	Compression: 17.045000	Avg Compression: 0.194144
# Article 1976:	Compression: 0.175659	Avg Compression: 0.194137
# Article 1977:	Compression: 15.379464	Avg Compression: 0.194167
# Article 1978:	Compression: 0.216125	Avg Compression: 0.194174
# Article 1979:	Compression: 10.548780	Avg Compression: 0.194204
# Article 1980:	Compression: 0.210035	Avg Compression: 0.194209
# Article 1981:	Compression: 12.973485	Avg Compression: 0.194240
# Article 1982:	Compression: 0.139370	Avg Compression: 0.194110
# Article 1983:	Compression: 0.183643	Avg Compression: 0.194106
# Article 1984:	Compression: 0.268452	Avg Compression: 0.194123
# Article 1985:	Compression: 0.255295	Avg Compression: 0.194136
# Article 1986:	Compression: 0.295416	Avg Compression: 0.194153
# Article 1987:	Compression: 12.691176	Avg Compression: 0.194183
# Article 1988:	Compression: 14.383333	Avg Compression: 0.194214
# Article 1989:	Compression: 0.140117	Avg Compression: 0.194169
# Article 1990:	Compression: 0.484544	Avg Compression: 0.194190
# Article 1991:	Compression: 0.189564	Avg Compression: 0.194189
# Article 1992:	Compression: 0.223245	Avg Compression: 0.194197
# Article 1993:	Compression: 6.242754	Avg Compression: 0.194227
# Article 1994:	Compression: 0.238943	Avg Compression: 0.194234
# Article 1995:	Compression: 0.171670	Avg Compression: 0.194216
# Article 1996:	Compression: 12.342857	Avg Compression: 0.194246
# Article 1997:	Compression: 0.276135	Avg Compression: 0.194259
# Article 1998:	Compression: 0.182241	Avg Compression: 0.194256
# Article 1999:	Compression: 0.166351	Avg Compression: 0.194220

# %% [markdown]
# Това е неприятен резултат. Някои статии въобще не се компресират добре. Огромната част дори стават десетки по-големи.
#
# След проверка на подредния номер в данните, се вижда че лошите резултати идват от най-кратките статии. Изглежда RNN мрежата се държи зле преди да е събрала достатъчно вътрешен state. При нормално обучение няма причина това да се случва.
#
# На ум идва причина - подравняването на статиите - TODO - да обясня проблема с подравняване вдясно/вляво.
