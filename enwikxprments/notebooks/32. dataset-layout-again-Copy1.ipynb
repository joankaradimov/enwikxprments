# %%
import itertools
import math
import os

import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds

physical_devices = tf.config.list_physical_devices('GPU')
for physical_device in physical_devices:
    tf.config.experimental.set_memory_growth(physical_device, enable=True)

# %%
TYPE=np.int16

subword_text_encoder = tfds.features.text.SubwordTextEncoder.load_from_file('vocab_2046')

class Articles:
    EMPTY_ARTICLE = np.array([], dtype=TYPE) # used for padding
    
    def __init__(self, path):
        with open(path, 'rb') as text_file:
            data = text_file.read()

        self.articles = sorted(set(data.split(b'\0')), key=len)
        self._encoded_articles = None

    @property
    def encoded_articles(self):
        if self._encoded_articles == None:
            self._encoded_articles = [np.array(subword_text_encoder.encode(article), dtype=TYPE) for article in self.articles]
        
        return self._encoded_articles

    def articles_generator(self, batch_size = 1, start = 0, end = None):
        end = end or len(self.articles)

        for _ in range(batch_size - ((end - start - 1) % batch_size + 1)):
            yield self.EMPTY_ARTICLE

        for article in itertools.islice(self.encoded_articles, start, end):
            yield article

    def subbatch_generator(self, batch_size, batch_length, start = 0, end = None):
        end = end or len(self.articles)

        dataset = tf.data.Dataset.from_generator(self.articles_generator, args=(batch_size, start, end), output_types=TYPE)
        dataset = dataset.padded_batch(batch_size, padded_shapes=([None]), drop_remainder=True)
        dataset = dataset.shuffle(100)

        for batch in dataset.as_numpy_iterator():
            remaining = batch
            while remaining.shape[1] > batch_length + 1:
                yield remaining[:, :batch_length + 1]
                remaining = remaining[:, batch_length:]

            if remaining.shape[1] == batch_length + 1:
                yield remaining
                yield np.zeros((batch_size, batch_length + 1), dtype=TYPE)
            else:
                yield np.hstack([remaining, np.zeros([batch_size, batch_length - remaining.shape[1] + 1])])

    def steps(self, batch_size, batch_length):
        articles = self.articles_generator(batch_size, batch_length)
        return sum(math.ceil(len(article) / batch_length) for i, article in enumerate(articles) if (i + 1) % batch_size == 0)

    def dataset(self, batch_size, batch_length, start = 0, end = None):
        end = end or len(self.articles)

        dataset = tf.data.Dataset.from_generator(self.subbatch_generator, args=(batch_size, batch_length, start, end), output_types=TYPE, output_shapes=(batch_size, batch_length + 1))
        return dataset.map(lambda batch: (batch[:, :-1], batch[:, 1:]))

# %%
articles = Articles('page_revisions_text')

# %%
steps = 15

for i in range(steps):
    batch_size = 2 * 2**i
    batch_item_length = 2 * 2**(steps - i - 1)
    count = articles.steps(batch_size, batch_item_length)
    print("batch size: %6d\t batch item length: %4d\tsteps per epoch: %6d" % (batch_size, batch_item_length, count))
# Out:
# batch size:      2	 batch item length: 32768	steps per epoch:  93929
# batch size:      4	 batch item length: 16384	steps per epoch:  51451
# batch size:      8	 batch item length: 8192	steps per epoch:  27760
# batch size:     16	 batch item length: 4096	steps per epoch:  15763
# batch size:     32	 batch item length: 2048	steps per epoch:  10129
# batch size:     64	 batch item length: 1024	steps per epoch:   7745
# batch size:    128	 batch item length:  512	steps per epoch:   7017
# batch size:    256	 batch item length:  256	steps per epoch:   7168
# batch size:    512	 batch item length:  128	steps per epoch:   8259
# batch size:   1024	 batch item length:   64	steps per epoch:  10861
# batch size:   2048	 batch item length:   32	steps per epoch:  16331
# batch size:   4096	 batch item length:   16	steps per epoch:  27522
# batch size:   8192	 batch item length:    8	steps per epoch:  50147
# batch size:  16384	 batch item length:    4	steps per epoch:  95507
# batch size:  32768	 batch item length:    2	steps per epoch: 186476

# %%
BATCH_SIZE = 16384
BATCHED_ITEM_LENGTH = 2

def build_model(vocab_size, embedding_dim, rnn_units):
    return tf.keras.Sequential([
        tf.keras.layers.Masking(mask_value=0, batch_input_shape=[BATCH_SIZE, BATCHED_ITEM_LENGTH]),
        tf.keras.layers.Embedding(vocab_size, embedding_dim),
        tf.keras.layers.GRU(rnn_units // 4 * 4, return_sequences=True, stateful=True, unroll=True, recurrent_initializer='glorot_uniform'),
        tf.keras.layers.GRU(rnn_units // 4 * 3, return_sequences=True, stateful=True, unroll=True, recurrent_initializer='glorot_uniform'),
        tf.keras.layers.GRU(rnn_units // 4 * 2, return_sequences=True, stateful=True, unroll=True, recurrent_initializer='glorot_uniform'),
        tf.keras.layers.Dense(vocab_size),
    ])

checkpoint_dir = './training_checkpoints-6' # Directory where the checkpoints will be saved
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt_{epoch}") # Name of the checkpoint files

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_prefix, save_weights_only=True)

class ModelStateResetter(tf.keras.callbacks.Callback):
    def __init__(self):
        pass

    def on_epoch_begin(self, epoch, logs=None):
        self.last_final_batch_count = 0
        
    def on_batch_end(self, batch, logs={}):
        average_final_batch_ratio = logs.get('average_final_batch_ratio', 0)
        final_batch_count = int(round(average_final_batch_ratio * (batch + 1)))
        is_final = final_batch_count - self.last_final_batch_count
        self.last_final_batch_count = final_batch_count
        
        if is_final:
            self.model.reset_states()
        
model_state_resetter_callback = ModelStateResetter()

def loss(labels, logits):
    return tf.keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)

def average_final_batch_ratio(true_labels, predictions):
    return 0 ** tf.math.abs(true_labels[-1, -1])

# %%
model = build_model(vocab_size = subword_text_encoder.vocab_size, embedding_dim=32, rnn_units=1024)
# model.load_weights(tf.train.latest_checkpoint(checkpoint_dir))
model.compile(optimizer='adam', loss=loss, metrics=[average_final_batch_ratio])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# masking (Masking)            (16384, 2)                0
# _________________________________________________________________
# embedding (Embedding)        (16384, 2, 32)            65184
# _________________________________________________________________
# gru (GRU)                    (16384, 2, 1024)          3250176
# _________________________________________________________________
# gru_1 (GRU)                  (16384, 2, 768)           4133376
# _________________________________________________________________
# gru_2 (GRU)                  (16384, 2, 512)           1969152
# _________________________________________________________________
# dense (Dense)                (16384, 2, 2037)          1044981
# =================================================================
# Total params: 10,462,869
# Trainable params: 10,462,869
# Non-trainable params: 0
# _________________________________________________________________

# %%
dataset = articles.dataset(BATCH_SIZE, BATCHED_ITEM_LENGTH)
callbacks = [checkpoint_callback, model_state_resetter_callback]
model.fit(dataset, callbacks=callbacks)
# Out:
# 195482/195482 [==============================] - 74542s 381ms/step - loss: 0.2316 - average_final_batch_ratio: 0.0220

# %%
model.fit(dataset, callbacks=callbacks)
# Out:
# 195482/195482 [==============================] - 73725s 377ms/step - loss: 0.2196 - average_final_batch_ratio: 0.0220

# %%
def build_predicting_model(vocab_size, embedding_dim, rnn_units):
    return tf.keras.Sequential([
        tf.keras.layers.Masking(mask_value=0, batch_input_shape=[1, 1]),
        tf.keras.layers.Embedding(vocab_size, embedding_dim),
        tf.keras.layers.GRU(rnn_units // 4 * 4, stateful=True, return_sequences=True),
        tf.keras.layers.GRU(rnn_units // 4 * 3, stateful=True, return_sequences=True),
        tf.keras.layers.GRU(rnn_units // 4 * 2, stateful=True, return_sequences=True),
        tf.keras.layers.Dense(vocab_size),
    ])

model = build_predicting_model(vocab_size = subword_text_encoder.vocab_size, embedding_dim=32, rnn_units=1024)
model.load_weights(tf.train.latest_checkpoint(checkpoint_dir))
model.build(tf.TensorShape([1, 1]))

# %%
import ctypes

class Huffman:
    huffman = ctypes.CDLL('x64/Release/huffman')
    
    huffman.create_tree.restype = ctypes.c_void_p
    huffman.destroy_tree.restype = None
    huffman.load_weights.restype = None
    huffman.create_code_string.restype = ctypes.c_char_p
    
    def __init__(self, category_count):
        self.tree = ctypes.c_void_p(self.huffman.create_tree(category_count))

    def __del__(self):
        self.huffman.destroy_tree(self.tree)
        
    def load_weights(self, weights):
        self.huffman.load_weights(self.tree, weights.ctypes.data_as(ctypes.POINTER(ctypes.c_float)))
    
    def get_code_length(self, category):
        return self.huffman.get_code_length(self.tree, category)

    def get_code_zero_count(self, category):
        return self.huffman.get_code_zero_count(self.tree, category)

# %%
def huffman_archive_size(model, text):
    archived_size = 0
    zeros = 0
    input_eval = np.array([[0]], dtype=TYPE)
    huffman_tree = Huffman(subword_text_encoder.vocab_size)

    text_generated = []

    model.reset_states()

    for index, byte in enumerate(text):
        predictions = model(input_eval)
        predictions = tf.squeeze(predictions, 0) # remove the batch dimension

        weights = tf.nn.softmax(predictions[0]).numpy()
        huffman_tree.load_weights(weights)
        zeros += huffman_tree.get_code_zero_count(byte.item())
        archived_size += huffman_tree.get_code_length(byte.item())

        input_eval = tf.expand_dims([byte], 0)
  
    return archived_size, zeros

# %%
total_raw = 0
total_compressed = 0

for index, encoded_article in enumerate(articles.articles_generator(1)):
    if index % 1000 == 0:
        article = subword_text_encoder.decode(encoded_article)
        raw = len(article) * 8
        if raw == 0:
            continue
        compressed, _ = huffman_archive_size(model, encoded_article)
        total_raw += raw
        total_compressed += compressed

        print('Article %d:\tLength: %d\tCompression: %f\tAvg Compression: %f' % (index, raw, compressed/raw, total_compressed/total_raw))
# Out:
# Article 1000:	Length: 144	Compression: 11.562500	Avg Compression: 11.562500
# Article 2000:	Length: 152	Compression: 11.006579	Avg Compression: 11.277027
# Article 3000:	Length: 152	Compression: 11.105263	Avg Compression: 11.218750
# Article 4000:	Length: 168	Compression: 10.119048	Avg Compression: 10.918831
# Article 5000:	Length: 168	Compression: 9.940476	Avg Compression: 10.709184
# Article 6000:	Length: 176	Compression: 19.596591	Avg Compression: 12.338542
# Article 7000:	Length: 176	Compression: 9.619318	Avg Compression: 11.917254
# Article 8000:	Length: 176	Compression: 9.500000	Avg Compression: 11.592988
# Article 9000:	Length: 184	Compression: 9.309783	Avg Compression: 11.312166
# Article 10000:	Length: 184	Compression: 9.217391	Avg Compression: 11.082738
# Article 11000:	Length: 192	Compression: 18.062500	Avg Compression: 11.798611
# Article 12000:	Length: 192	Compression: 17.989583	Avg Compression: 12.374516
# Article 13000:	Length: 200	Compression: 17.295000	Avg Compression: 12.809187
# Article 14000:	Length: 200	Compression: 8.445000	Avg Compression: 12.454951
# Article 15000:	Length: 208	Compression: 8.197115	Avg Compression: 12.123503
# Article 16000:	Length: 208	Compression: 8.149038	Avg Compression: 11.836458
# Article 17000:	Length: 208	Compression: 8.177885	Avg Compression: 11.590026
# Article 18000:	Length: 208	Compression: 8.235577	Avg Compression: 11.378337
# Article 19000:	Length: 216	Compression: 7.935185	Avg Compression: 11.166572
# Article 20000:	Length: 224	Compression: 7.790179	Avg Compression: 10.964133
# Article 21000:	Length: 224	Compression: 7.553571	Avg Compression: 10.771212
# Article 22000:	Length: 224	Compression: 7.732143	Avg Compression: 10.608509
# Article 23000:	Length: 232	Compression: 7.439655	Avg Compression: 10.442029
# Article 24000:	Length: 232	Compression: 7.469828	Avg Compression: 10.293675
# Article 25000:	Length: 240	Compression: 7.220833	Avg Compression: 10.142799
# Article 26000:	Length: 240	Compression: 7.250000	Avg Compression: 10.007410
# Article 27000:	Length: 248	Compression: 6.915323	Avg Compression: 9.864769
# Article 28000:	Length: 248	Compression: 6.983871	Avg Compression: 9.737731
# Article 29000:	Length: 248	Compression: 7.008065	Avg Compression: 9.622446
# Article 30000:	Length: 256	Compression: 6.777344	Avg Compression: 9.503590
# Article 31000:	Length: 256	Compression: 6.609375	Avg Compression: 9.387531
# Article 32000:	Length: 264	Compression: 6.568182	Avg Compression: 9.275572
# Article 33000:	Length: 264	Compression: 6.424242	Avg Compression: 9.166667
# Article 34000:	Length: 272	Compression: 6.367647	Avg Compression: 9.060690
# Article 35000:	Length: 272	Compression: 6.455882	Avg Compression: 8.965665
# Article 36000:	Length: 280	Compression: 6.103571	Avg Compression: 8.862073
# Article 37000:	Length: 280	Compression: 6.282143	Avg Compression: 8.771956
# Article 38000:	Length: 288	Compression: 5.944444	Avg Compression: 8.673892
# Article 39000:	Length: 296	Compression: 5.962838	Avg Compression: 8.580581
# Article 40000:	Length: 296	Compression: 5.966216	Avg Compression: 8.493593
# Article 41000:	Length: 304	Compression: 5.878289	Avg Compression: 8.407174
# Article 42000:	Length: 312	Compression: 5.567308	Avg Compression: 8.314024
# Article 43000:	Length: 320	Compression: 5.606250	Avg Compression: 8.225895
# Article 44000:	Length: 320	Compression: 5.562500	Avg Compression: 8.141942
# Article 45000:	Length: 336	Compression: 3.059524	Avg Compression: 7.979119
# Article 46000:	Length: 344	Compression: 5.110465	Avg Compression: 7.888017
# Article 47000:	Length: 352	Compression: 1.392045	Avg Compression: 7.683566
# Article 48000:	Length: 368	Compression: 5.649457	Avg Compression: 7.618767
# Article 49000:	Length: 384	Compression: 4.757812	Avg Compression: 7.526726
# Article 50000:	Length: 400	Compression: 3.330000	Avg Compression: 7.390645
# Article 51000:	Length: 416	Compression: 2.935096	Avg Compression: 7.245295
# Article 52000:	Length: 440	Compression: 3.963636	Avg Compression: 7.135840
# Article 53000:	Length: 472	Compression: 0.745763	Avg Compression: 6.915105
# Article 54000:	Length: 520	Compression: 3.515385	Avg Compression: 6.790468
# Article 55000:	Length: 584	Compression: 0.876712	Avg Compression: 6.556609
# Article 56000:	Length: 696	Compression: 0.882184	Avg Compression: 6.301216
# Article 57000:	Length: 848	Compression: 1.810142	Avg Compression: 6.067742
# Article 58000:	Length: 1032	Compression: 0.392442	Avg Compression: 5.730051
# Article 59000:	Length: 1208	Compression: 1.612583	Avg Compression: 5.461945
# Article 60000:	Length: 1352	Compression: 0.591716	Avg Compression: 5.131129
# Article 61000:	Length: 1552	Compression: 0.547036	Avg Compression: 4.799543
# Article 62000:	Length: 1728	Compression: 0.496528	Avg Compression: 4.478822
# Article 63000:	Length: 1952	Compression: 0.537398	Avg Compression: 4.172740
# Article 64000:	Length: 2208	Compression: 0.474638	Avg Compression: 3.874122
# Article 65000:	Length: 2480	Compression: 0.474194	Avg Compression: 3.591403
# Article 66000:	Length: 2760	Compression: 0.951087	Avg Compression: 3.367757
# Article 67000:	Length: 3032	Compression: 0.779354	Avg Compression: 3.147406
# Article 68000:	Length: 3296	Compression: 0.367415	Avg Compression: 2.911929
# Article 69000:	Length: 3648	Compression: 0.429825	Avg Compression: 2.699178
# Article 70000:	Length: 3928	Compression: 0.392821	Avg Compression: 2.504302
# Article 71000:	Length: 4232	Compression: 0.386815	Avg Compression: 2.327622
# Article 72000:	Length: 4520	Compression: 0.399115	Avg Compression: 2.169823
# Article 73000:	Length: 4760	Compression: 0.472689	Avg Compression: 2.035183
# Article 74000:	Length: 5024	Compression: 0.504180	Avg Compression: 1.916892
# Article 75000:	Length: 5304	Compression: 0.541290	Avg Compression: 1.813147
# Article 76000:	Length: 5592	Compression: 0.462446	Avg Compression: 1.713659
# Article 77000:	Length: 5712	Compression: 0.333859	Avg Compression: 1.617111
# Article 78000:	Length: 6152	Compression: 0.669538	Avg Compression: 1.550704
# Article 79000:	Length: 6528	Compression: 0.491115	Avg Compression: 1.477362
# Article 80000:	Length: 6816	Compression: 0.627494	Avg Compression: 1.420081
# Article 81000:	Length: 7032	Compression: 0.460609	Avg Compression: 1.357702
# Article 82000:	Length: 7408	Compression: 0.345302	Avg Compression: 1.292806
# Article 83000:	Length: 7728	Compression: 0.389363	Avg Compression: 1.236180
# Article 84000:	Length: 8056	Compression: 0.400819	Avg Compression: 1.184946
# Article 85000:	Length: 8328	Compression: 0.470941	Avg Compression: 1.142375
# Article 86000:	Length: 8680	Compression: 0.577765	Avg Compression: 1.109342
# Article 87000:	Length: 9032	Compression: 0.360828	Avg Compression: 1.066388
# Article 88000:	Length: 9360	Compression: 0.368056	Avg Compression: 1.027190
# Article 89000:	Length: 9632	Compression: 0.534572	Avg Compression: 1.000289
# Article 90000:	Length: 10016	Compression: 0.420228	Avg Compression: 0.969120
# Article 91000:	Length: 10360	Compression: 0.420560	Avg Compression: 0.940237
# Article 92000:	Length: 10648	Compression: 0.437171	Avg Compression: 0.914410
# Article 93000:	Length: 10616	Compression: 0.474755	Avg Compression: 0.893003
# Article 94000:	Length: 11448	Compression: 0.564465	Avg Compression: 0.876612
# Article 95000:	Length: 11824	Compression: 0.420501	Avg Compression: 0.854262
# Article 96000:	Length: 12040	Compression: 0.458721	Avg Compression: 0.835464
# Article 97000:	Length: 12584	Compression: 0.395502	Avg Compression: 0.814644
# Article 98000:	Length: 12936	Compression: 0.382112	Avg Compression: 0.794579
# Article 99000:	Length: 13272	Compression: 0.444319	Avg Compression: 0.778666
# Article 100000:	Length: 13720	Compression: 0.446574	Avg Compression: 0.763768
# Article 101000:	Length: 14104	Compression: 0.377836	Avg Compression: 0.746756
# Article 102000:	Length: 14520	Compression: 0.389945	Avg Compression: 0.731266
# Article 103000:	Length: 14920	Compression: 0.428753	Avg Compression: 0.718348
# Article 104000:	Length: 15352	Compression: 0.429390	Avg Compression: 0.706186
# Article 105000:	Length: 15800	Compression: 0.436582	Avg Compression: 0.694992
# Article 106000:	Length: 16248	Compression: 0.449532	Avg Compression: 0.684941
# Article 107000:	Length: 16656	Compression: 0.398475	Avg Compression: 0.673400
# Article 108000:	Length: 16920	Compression: 0.448345	Avg Compression: 0.664552
# Article 109000:	Length: 17528	Compression: 0.565838	Avg Compression: 0.660689
# Article 110000:	Length: 18032	Compression: 0.386757	Avg Compression: 0.650088
# Article 111000:	Length: 18480	Compression: 0.420292	Avg Compression: 0.641321
# Article 112000:	Length: 18496	Compression: 0.524059	Avg Compression: 0.637008
# Article 113000:	Length: 19312	Compression: 0.401305	Avg Compression: 0.628292
# Article 114000:	Length: 19672	Compression: 0.208469	Avg Compression: 0.613051
# Article 115000:	Length: 19848	Compression: 0.222088	Avg Compression: 0.599237
# Article 116000:	Length: 20024	Compression: 0.180184	Avg Compression: 0.584813
# Article 117000:	Length: 20096	Compression: 0.182325	Avg Compression: 0.571374
# Article 118000:	Length: 20176	Compression: 0.213125	Avg Compression: 0.559754
# Article 119000:	Length: 20272	Compression: 0.158100	Avg Compression: 0.547077
# Article 120000:	Length: 20408	Compression: 0.201098	Avg Compression: 0.536423
# Article 121000:	Length: 20544	Compression: 0.209696	Avg Compression: 0.526599
# Article 122000:	Length: 20664	Compression: 0.197348	Avg Compression: 0.516934
# Article 123000:	Length: 20728	Compression: 0.449633	Avg Compression: 0.515009
# Article 124000:	Length: 20880	Compression: 0.281226	Avg Compression: 0.508461
# Article 125000:	Length: 20960	Compression: 0.172901	Avg Compression: 0.499285
# Article 126000:	Length: 21024	Compression: 0.266981	Avg Compression: 0.493083
# Article 127000:	Length: 21088	Compression: 0.244784	Avg Compression: 0.486608
# Article 128000:	Length: 21144	Compression: 0.257142	Avg Compression: 0.480760
# Article 129000:	Length: 21200	Compression: 0.454434	Avg Compression: 0.480104
# Article 130000:	Length: 21272	Compression: 0.220196	Avg Compression: 0.473766
# Article 131000:	Length: 21344	Compression: 0.261010	Avg Compression: 0.468684
# Article 132000:	Length: 21432	Compression: 0.213139	Avg Compression: 0.462698
# Article 133000:	Length: 21464	Compression: 0.291372	Avg Compression: 0.458771
# Article 134000:	Length: 21504	Compression: 0.379418	Avg Compression: 0.456990
# Article 135000:	Length: 21744	Compression: 0.206678	Avg Compression: 0.451434
# Article 136000:	Length: 21856	Compression: 0.238928	Avg Compression: 0.446797
# Article 137000:	Length: 21992	Compression: 0.207621	Avg Compression: 0.441658
# Article 138000:	Length: 22136	Compression: 0.244082	Avg Compression: 0.437476
# Article 139000:	Length: 22136	Compression: 0.290432	Avg Compression: 0.434427
# Article 140000:	Length: 22496	Compression: 0.186878	Avg Compression: 0.429320
# Article 141000:	Length: 22712	Compression: 0.498547	Avg Compression: 0.430732
# Article 142000:	Length: 22848	Compression: 0.484550	Avg Compression: 0.431815
# Article 143000:	Length: 23192	Compression: 0.210719	Avg Compression: 0.427391
# Article 144000:	Length: 23472	Compression: 0.387398	Avg Compression: 0.426597
# Article 145000:	Length: 23760	Compression: 0.507239	Avg Compression: 0.428186
# Article 146000:	Length: 24096	Compression: 0.207337	Avg Compression: 0.423861
# Article 147000:	Length: 24432	Compression: 0.234938	Avg Compression: 0.420182
# Article 148000:	Length: 24800	Compression: 0.349274	Avg Compression: 0.418808
# Article 149000:	Length: 25200	Compression: 0.216508	Avg Compression: 0.414901
# Article 150000:	Length: 24968	Compression: 0.639178	Avg Compression: 0.419112
# Article 151000:	Length: 25648	Compression: 0.379523	Avg Compression: 0.418363
# Article 152000:	Length: 26392	Compression: 0.238443	Avg Compression: 0.414926
# Article 153000:	Length: 26600	Compression: 0.436429	Avg Compression: 0.415333
# Article 154000:	Length: 27240	Compression: 0.261601	Avg Compression: 0.412416
# Article 155000:	Length: 27672	Compression: 0.427616	Avg Compression: 0.412703
# Article 156000:	Length: 28136	Compression: 0.451166	Avg Compression: 0.413429
# Article 157000:	Length: 28584	Compression: 0.402778	Avg Compression: 0.413228
# Article 158000:	Length: 29096	Compression: 0.380224	Avg Compression: 0.412609
# Article 159000:	Length: 29576	Compression: 0.407763	Avg Compression: 0.412518
# Article 160000:	Length: 30088	Compression: 0.273764	Avg Compression: 0.409923
# Article 161000:	Length: 30616	Compression: 0.363503	Avg Compression: 0.409056
# Article 162000:	Length: 31208	Compression: 0.430146	Avg Compression: 0.409450
# Article 163000:	Length: 31464	Compression: 0.436435	Avg Compression: 0.409949
# Article 164000:	Length: 32392	Compression: 0.426124	Avg Compression: 0.410251
# Article 165000:	Length: 33032	Compression: 0.415597	Avg Compression: 0.410351
# Article 166000:	Length: 33640	Compression: 0.381570	Avg Compression: 0.409813
# Article 167000:	Length: 34184	Compression: 0.453838	Avg Compression: 0.410633
# Article 168000:	Length: 35072	Compression: 0.406450	Avg Compression: 0.410555
# Article 169000:	Length: 35776	Compression: 0.434146	Avg Compression: 0.410997
# Article 170000:	Length: 36456	Compression: 0.427337	Avg Compression: 0.411304
# Article 171000:	Length: 36744	Compression: 0.497278	Avg Compression: 0.412900
# Article 172000:	Length: 38040	Compression: 0.318165	Avg Compression: 0.411114
# Article 173000:	Length: 38880	Compression: 0.535108	Avg Compression: 0.413458
# Article 174000:	Length: 39728	Compression: 0.525247	Avg Compression: 0.415577
# Article 175000:	Length: 39976	Compression: 0.477361	Avg Compression: 0.416733
# Article 176000:	Length: 41616	Compression: 0.453479	Avg Compression: 0.417436
# Article 177000:	Length: 41640	Compression: 0.456820	Avg Compression: 0.418175
# Article 178000:	Length: 43360	Compression: 0.453782	Avg Compression: 0.418857
# Article 179000:	Length: 44672	Compression: 0.385163	Avg Compression: 0.418205
# Article 180000:	Length: 45584	Compression: 0.483020	Avg Compression: 0.419460
# Article 181000:	Length: 46960	Compression: 0.323020	Avg Compression: 0.417573
# Article 182000:	Length: 48184	Compression: 0.423522	Avg Compression: 0.417690
# Article 183000:	Length: 49280	Compression: 0.470231	Avg Compression: 0.418727
# Article 184000:	Length: 50872	Compression: 0.352886	Avg Compression: 0.417413
# Article 185000:	Length: 52272	Compression: 0.424606	Avg Compression: 0.417557
# Article 186000:	Length: 53744	Compression: 0.438393	Avg Compression: 0.417979
# Article 187000:	Length: 55176	Compression: 0.379259	Avg Compression: 0.417191
# Article 188000:	Length: 56824	Compression: 0.433021	Avg Compression: 0.417516
# Article 189000:	Length: 58464	Compression: 0.381842	Avg Compression: 0.416777
# Article 190000:	Length: 60224	Compression: 0.422440	Avg Compression: 0.416896
# Article 191000:	Length: 62152	Compression: 0.400116	Avg Compression: 0.416542
# Article 192000:	Length: 63760	Compression: 0.407732	Avg Compression: 0.416355
# Article 193000:	Length: 65440	Compression: 0.443414	Avg Compression: 0.416931
# Article 194000:	Length: 68008	Compression: 0.514998	Avg Compression: 0.419052
# Article 195000:	Length: 69480	Compression: 0.598388	Avg Compression: 0.422929
# Article 196000:	Length: 72704	Compression: 0.432975	Avg Compression: 0.423151
# Article 197000:	Length: 75304	Compression: 0.357352	Avg Compression: 0.421677
# Article 198000:	Length: 78192	Compression: 0.409952	Avg Compression: 0.421411
# Article 199000:	Length: 81032	Compression: 0.481328	Avg Compression: 0.422790
# Article 200000:	Length: 84232	Compression: 0.461036	Avg Compression: 0.423683
# Article 201000:	Length: 87152	Compression: 0.459175	Avg Compression: 0.424521
# Article 202000:	Length: 90944	Compression: 0.350820	Avg Compression: 0.422749
# Article 203000:	Length: 94504	Compression: 0.453134	Avg Compression: 0.423490
# Article 204000:	Length: 98712	Compression: 0.502016	Avg Compression: 0.425439
# Article 205000:	Length: 103760	Compression: 0.482758	Avg Compression: 0.426897
# Article 206000:	Length: 108480	Compression: 0.456582	Avg Compression: 0.427666
# Article 207000:	Length: 112664	Compression: 0.441534	Avg Compression: 0.428029
# Article 208000:	Length: 119704	Compression: 0.441213	Avg Compression: 0.428386
# Article 209000:	Length: 126672	Compression: 0.348664	Avg Compression: 0.426165
# Article 210000:	Length: 134016	Compression: 0.457930	Avg Compression: 0.427075
# Article 211000:	Length: 142360	Compression: 0.567793	Avg Compression: 0.431227
# Article 212000:	Length: 152048	Compression: 0.549964	Avg Compression: 0.434855
# Article 213000:	Length: 163720	Compression: 0.409571	Avg Compression: 0.434050
# Article 214000:	Length: 177264	Compression: 0.425354	Avg Compression: 0.433760
# Article 215000:	Length: 193048	Compression: 0.449090	Avg Compression: 0.434297
# Article 216000:	Length: 212904	Compression: 0.430419	Avg Compression: 0.434153
# Article 217000:	Length: 238208	Compression: 0.423525	Avg Compression: 0.433728
# Article 218000:	Length: 274168	Compression: 0.433730	Avg Compression: 0.433728
# Article 219000:	Length: 329056	Compression: 0.416333	Avg Compression: 0.432856
# Article 220000:	Length: 456256	Compression: 0.639783	Avg Compression: 0.446304

# %%
model = build_model(vocab_size = subword_text_encoder.vocab_size, embedding_dim=32, rnn_units=1024)
model.load_weights(tf.train.latest_checkpoint(checkpoint_dir))
model.compile(optimizer='adam', loss=loss, metrics=[average_final_batch_ratio])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# masking (Masking)            (16384, 2)                0
# _________________________________________________________________
# embedding (Embedding)        (16384, 2, 32)            65184
# _________________________________________________________________
# gru (GRU)                    (16384, 2, 1024)          3250176
# _________________________________________________________________
# gru_1 (GRU)                  (16384, 2, 768)           4133376
# _________________________________________________________________
# gru_2 (GRU)                  (16384, 2, 512)           1969152
# _________________________________________________________________
# dense (Dense)                (16384, 2, 2037)          1044981
# =================================================================
# Total params: 10,462,869
# Trainable params: 10,462,869
# Non-trainable params: 0
# _________________________________________________________________

# %%
dataset = articles.dataset(BATCH_SIZE, BATCHED_ITEM_LENGTH)
callbacks = [checkpoint_callback, model_state_resetter_callback]
model.fit(dataset, callbacks=callbacks)
# Out:
# 195483/195483 [==============================] - 74403s 381ms/step - loss: 0.2234 - average_final_batch_ratio: 0.0205

# %%
total_raw = 0
total_compressed = 0

for index, encoded_article in enumerate(articles.articles_generator(1)):
    if index % 1000 == 0:
        article = subword_text_encoder.decode(encoded_article)
        raw = len(article) * 8
        if raw == 0:
            continue
        compressed, _ = huffman_archive_size(model, encoded_article)
        total_raw += raw
        total_compressed += compressed

        print('Article %d:\tLength: %d\tCompression: %f\tAvg Compression: %f' % (index, raw, compressed/raw, total_compressed/total_raw))
# Out:
# Article 1000:	Length: 144	Compression: 1.958333	Avg Compression: 1.958333
# Article 2000:	Length: 152	Compression: 2.059211	Avg Compression: 2.010135
# Article 3000:	Length: 160	Compression: 2.000000	Avg Compression: 2.006579
# Article 4000:	Length: 168	Compression: 1.880952	Avg Compression: 1.972756
# Article 5000:	Length: 168	Compression: 6.202381	Avg Compression: 2.869949
# Article 6000:	Length: 176	Compression: 1.784091	Avg Compression: 2.672521
# Article 7000:	Length: 176	Compression: 1.750000	Avg Compression: 2.530594
# Article 8000:	Length: 176	Compression: 1.698864	Avg Compression: 2.419697
# Article 9000:	Length: 184	Compression: 1.750000	Avg Compression: 2.337766
# Article 10000:	Length: 184	Compression: 1.657609	Avg Compression: 2.263626
# Article 11000:	Length: 192	Compression: 1.614583	Avg Compression: 2.197340
# Article 12000:	Length: 192	Compression: 1.609375	Avg Compression: 2.142857
# Article 13000:	Length: 200	Compression: 1.605000	Avg Compression: 2.095511
# Article 14000:	Length: 200	Compression: 1.605000	Avg Compression: 2.055825
# Article 15000:	Length: 208	Compression: 1.528846	Avg Compression: 2.014925
# Article 16000:	Length: 208	Compression: 1.620192	Avg Compression: 1.986496
# Article 17000:	Length: 208	Compression: 1.533654	Avg Compression: 1.956072
# Article 18000:	Length: 216	Compression: 1.564815	Avg Compression: 1.930556
# Article 19000:	Length: 216	Compression: 1.476852	Avg Compression: 1.902778
# Article 20000:	Length: 224	Compression: 1.647321	Avg Compression: 1.887527
# Article 21000:	Length: 224	Compression: 1.477679	Avg Compression: 1.864437
# Article 22000:	Length: 224	Compression: 1.406250	Avg Compression: 1.840000
# Article 23000:	Length: 232	Compression: 1.379310	Avg Compression: 1.815884
# Article 24000:	Length: 232	Compression: 1.392241	Avg Compression: 1.794811
# Article 25000:	Length: 240	Compression: 1.345833	Avg Compression: 1.772838
# Article 26000:	Length: 240	Compression: 1.379167	Avg Compression: 1.754471
# Article 27000:	Length: 248	Compression: 1.399194	Avg Compression: 1.738131
# Article 28000:	Length: 248	Compression: 1.435484	Avg Compression: 1.724823
# Article 29000:	Length: 248	Compression: 1.266129	Avg Compression: 1.705503
# Article 30000:	Length: 256	Compression: 1.347656	Avg Compression: 1.690592
# Article 31000:	Length: 256	Compression: 1.324219	Avg Compression: 1.675938
# Article 32000:	Length: 264	Compression: 1.185606	Avg Compression: 1.656513
# Article 33000:	Length: 264	Compression: 1.321970	Avg Compression: 1.643764
# Article 34000:	Length: 272	Compression: 1.294118	Avg Compression: 1.630556
# Article 35000:	Length: 272	Compression: 1.183824	Avg Compression: 1.614293
# Article 36000:	Length: 280	Compression: 1.196429	Avg Compression: 1.599200
# Article 37000:	Length: 280	Compression: 1.371429	Avg Compression: 1.591260
# Article 38000:	Length: 288	Compression: 1.385417	Avg Compression: 1.584135
# Article 39000:	Length: 296	Compression: 1.175676	Avg Compression: 1.570102
# Article 40000:	Length: 296	Compression: 1.233108	Avg Compression: 1.558909
# Article 41000:	Length: 304	Compression: 1.529605	Avg Compression: 1.557943
# Article 42000:	Length: 312	Compression: 1.205128	Avg Compression: 1.546390
# Article 43000:	Length: 320	Compression: 1.190625	Avg Compression: 1.534829
# Article 44000:	Length: 328	Compression: 0.993902	Avg Compression: 1.517394
# Article 45000:	Length: 336	Compression: 1.014881	Avg Compression: 1.501332
# Article 46000:	Length: 344	Compression: 1.241279	Avg Compression: 1.493091
# Article 47000:	Length: 352	Compression: 1.232955	Avg Compression: 1.484921
# Article 48000:	Length: 368	Compression: 0.940217	Avg Compression: 1.467605
# Article 49000:	Length: 384	Compression: 0.760417	Avg Compression: 1.444900
# Article 50000:	Length: 400	Compression: 0.825000	Avg Compression: 1.424838
# Article 51000:	Length: 408	Compression: 0.678922	Avg Compression: 1.401003
# Article 52000:	Length: 440	Compression: 0.838636	Avg Compression: 1.382268
# Article 53000:	Length: 472	Compression: 1.040254	Avg Compression: 1.370468
# Article 54000:	Length: 520	Compression: 0.965385	Avg Compression: 1.355634
# Article 55000:	Length: 584	Compression: 0.796233	Avg Compression: 1.333536
# Article 56000:	Length: 696	Compression: 1.048851	Avg Compression: 1.320736
# Article 57000:	Length: 848	Compression: 0.768868	Avg Compression: 1.292075
# Article 58000:	Length: 1032	Compression: 1.518411	Avg Compression: 1.305530
# Article 59000:	Length: 1208	Compression: 0.685430	Avg Compression: 1.265187
# Article 60000:	Length: 1368	Compression: 1.243421	Avg Compression: 1.263694
# Article 61000:	Length: 1544	Compression: 0.629534	Avg Compression: 1.218110
# Article 62000:	Length: 1728	Compression: 0.540509	Avg Compression: 1.167658
# Article 63000:	Length: 1960	Compression: 1.382653	Avg Compression: 1.184401
# Article 64000:	Length: 2208	Compression: 0.910326	Avg Compression: 1.162295
# Article 65000:	Length: 2480	Compression: 0.432258	Avg Compression: 1.101655
# Article 66000:	Length: 2760	Compression: 0.653986	Avg Compression: 1.063772
# Article 67000:	Length: 3032	Compression: 0.779024	Avg Compression: 1.039553
# Article 68000:	Length: 3336	Compression: 0.510791	Avg Compression: 0.994305
# Article 69000:	Length: 3648	Compression: 0.615406	Avg Compression: 0.961883
# Article 70000:	Length: 3936	Compression: 0.663872	Avg Compression: 0.936695
# Article 71000:	Length: 4232	Compression: 0.597117	Avg Compression: 0.908406
# Article 72000:	Length: 4512	Compression: 0.588431	Avg Compression: 0.882304
# Article 73000:	Length: 4736	Compression: 0.581926	Avg Compression: 0.858613
# Article 74000:	Length: 5024	Compression: 0.521696	Avg Compression: 0.832601
# Article 75000:	Length: 5304	Compression: 0.588801	Avg Compression: 0.814226
# Article 76000:	Length: 5592	Compression: 0.631438	Avg Compression: 0.800771
# Article 77000:	Length: 5888	Compression: 0.634171	Avg Compression: 0.788788
# Article 78000:	Length: 6216	Compression: 0.444015	Avg Compression: 0.764454
# Article 79000:	Length: 6528	Compression: 0.435355	Avg Compression: 0.741744
# Article 80000:	Length: 6816	Compression: 0.472858	Avg Compression: 0.723673
# Article 81000:	Length: 7104	Compression: 0.668919	Avg Compression: 0.720088
# Article 82000:	Length: 7368	Compression: 0.470141	Avg Compression: 0.704197
# Article 83000:	Length: 7728	Compression: 0.554995	Avg Compression: 0.694870
# Article 84000:	Length: 7968	Compression: 0.525100	Avg Compression: 0.684589
# Article 85000:	Length: 8360	Compression: 0.498086	Avg Compression: 0.673448
# Article 86000:	Length: 8664	Compression: 0.448984	Avg Compression: 0.660361
# Article 87000:	Length: 9032	Compression: 0.499336	Avg Compression: 0.651135
# Article 88000:	Length: 9344	Compression: 0.604452	Avg Compression: 0.648523
# Article 89000:	Length: 9632	Compression: 0.609946	Avg Compression: 0.646419
# Article 90000:	Length: 9984	Compression: 0.472256	Avg Compression: 0.637101
# Article 91000:	Length: 10264	Compression: 0.518024	Avg Compression: 0.630892
# Article 92000:	Length: 10728	Compression: 0.495712	Avg Compression: 0.623907
# Article 93000:	Length: 10968	Compression: 0.542214	Avg Compression: 0.619807
# Article 94000:	Length: 11416	Compression: 0.440872	Avg Compression: 0.610925
# Article 95000:	Length: 11824	Compression: 0.515815	Avg Compression: 0.606274
# Article 96000:	Length: 12208	Compression: 0.461583	Avg Compression: 0.599320
# Article 97000:	Length: 12424	Compression: 0.452511	Avg Compression: 0.592474
# Article 98000:	Length: 12832	Compression: 0.487453	Avg Compression: 0.587648
# Article 99000:	Length: 13296	Compression: 0.437726	Avg Compression: 0.580835
# Article 100000:	Length: 13720	Compression: 0.572741	Avg Compression: 0.580472
# Article 101000:	Length: 14040	Compression: 0.386681	Avg Compression: 0.571978
# Article 102000:	Length: 14416	Compression: 0.449015	Avg Compression: 0.566682
# Article 103000:	Length: 14800	Compression: 0.451419	Avg Compression: 0.561802
# Article 104000:	Length: 15352	Compression: 0.448801	Avg Compression: 0.557048
# Article 105000:	Length: 15768	Compression: 0.488141	Avg Compression: 0.554193
# Article 106000:	Length: 16248	Compression: 0.465288	Avg Compression: 0.550554
# Article 107000:	Length: 16632	Compression: 0.535474	Avg Compression: 0.549947
# Article 108000:	Length: 16872	Compression: 0.537103	Avg Compression: 0.549444
# Article 109000:	Length: 17584	Compression: 0.456722	Avg Compression: 0.545804
# Article 110000:	Length: 18000	Compression: 0.477333	Avg Compression: 0.543160
# Article 111000:	Length: 18424	Compression: 0.455601	Avg Compression: 0.539829
# Article 112000:	Length: 18920	Compression: 0.419715	Avg Compression: 0.535314
# Article 113000:	Length: 19104	Compression: 0.589405	Avg Compression: 0.537292
# Article 114000:	Length: 19672	Compression: 0.288684	Avg Compression: 0.528271
# Article 115000:	Length: 19848	Compression: 0.599960	Avg Compression: 0.530803
# Article 116000:	Length: 20024	Compression: 0.297293	Avg Compression: 0.522769
# Article 117000:	Length: 20096	Compression: 0.316083	Avg Compression: 0.515870
# Article 118000:	Length: 20176	Compression: 0.318497	Avg Compression: 0.509470
# Article 119000:	Length: 20272	Compression: 0.314769	Avg Compression: 0.503327
# Article 120000:	Length: 20408	Compression: 0.339965	Avg Compression: 0.498298
# Article 121000:	Length: 20544	Compression: 0.350516	Avg Compression: 0.493856
# Article 122000:	Length: 20664	Compression: 0.317944	Avg Compression: 0.488694
# Article 123000:	Length: 20784	Compression: 0.345843	Avg Compression: 0.484598
# Article 124000:	Length: 20880	Compression: 0.320642	Avg Compression: 0.480008
# Article 125000:	Length: 20960	Compression: 0.332824	Avg Compression: 0.475985
# Article 126000:	Length: 21024	Compression: 0.350361	Avg Compression: 0.472632
# Article 127000:	Length: 21088	Compression: 0.318949	Avg Compression: 0.468626
# Article 128000:	Length: 21144	Compression: 0.335083	Avg Compression: 0.465224
# Article 129000:	Length: 21208	Compression: 0.346945	Avg Compression: 0.462277
# Article 130000:	Length: 21272	Compression: 0.419660	Avg Compression: 0.461238
# Article 131000:	Length: 21344	Compression: 0.322995	Avg Compression: 0.457937
# Article 132000:	Length: 21432	Compression: 0.348871	Avg Compression: 0.455383
# Article 133000:	Length: 21528	Compression: 0.300028	Avg Compression: 0.451813
# Article 134000:	Length: 21632	Compression: 0.332794	Avg Compression: 0.449127
# Article 135000:	Length: 21744	Compression: 0.355868	Avg Compression: 0.447058
# Article 136000:	Length: 21856	Compression: 0.335652	Avg Compression: 0.444628
# Article 137000:	Length: 21992	Compression: 0.371862	Avg Compression: 0.443065
# Article 138000:	Length: 21880	Compression: 0.482815	Avg Compression: 0.443897
# Article 139000:	Length: 22312	Compression: 0.353801	Avg Compression: 0.442015
# Article 140000:	Length: 22496	Compression: 0.324635	Avg Compression: 0.439594
# Article 141000:	Length: 22712	Compression: 0.306534	Avg Compression: 0.436880
# Article 142000:	Length: 22936	Compression: 0.358563	Avg Compression: 0.435299
# Article 143000:	Length: 23192	Compression: 0.343394	Avg Compression: 0.433461
# Article 144000:	Length: 23456	Compression: 0.451398	Avg Compression: 0.433817
# Article 145000:	Length: 23736	Compression: 0.436973	Avg Compression: 0.433879
# Article 146000:	Length: 24096	Compression: 0.353627	Avg Compression: 0.432308
# Article 147000:	Length: 24432	Compression: 0.349828	Avg Compression: 0.430702
# Article 148000:	Length: 24800	Compression: 0.366895	Avg Compression: 0.429466
# Article 149000:	Length: 25200	Compression: 0.355873	Avg Compression: 0.428045
# Article 150000:	Length: 25608	Compression: 0.349539	Avg Compression: 0.426535
# Article 151000:	Length: 25992	Compression: 0.417051	Avg Compression: 0.426353
# Article 152000:	Length: 26376	Compression: 0.428988	Avg Compression: 0.426403
# Article 153000:	Length: 26840	Compression: 0.359911	Avg Compression: 0.425138
# Article 154000:	Length: 27240	Compression: 0.358737	Avg Compression: 0.423879
# Article 155000:	Length: 27656	Compression: 0.350774	Avg Compression: 0.422499
# Article 156000:	Length: 28136	Compression: 0.420422	Avg Compression: 0.422460
# Article 157000:	Length: 28448	Compression: 0.416831	Avg Compression: 0.422355
# Article 158000:	Length: 28840	Compression: 0.428641	Avg Compression: 0.422472
# Article 159000:	Length: 29456	Compression: 0.470227	Avg Compression: 0.423362
# Article 160000:	Length: 29656	Compression: 0.457041	Avg Compression: 0.423983
# Article 161000:	Length: 30640	Compression: 0.381168	Avg Compression: 0.423183
# Article 162000:	Length: 31168	Compression: 0.484343	Avg Compression: 0.424323
# Article 163000:	Length: 31728	Compression: 0.499275	Avg Compression: 0.425720
# Article 164000:	Length: 32408	Compression: 0.415237	Avg Compression: 0.425524
# Article 165000:	Length: 32912	Compression: 0.423736	Avg Compression: 0.425491
# Article 166000:	Length: 33680	Compression: 0.342221	Avg Compression: 0.423934
# Article 167000:	Length: 34296	Compression: 0.447836	Avg Compression: 0.424381
# Article 168000:	Length: 35072	Compression: 0.416030	Avg Compression: 0.424224
# Article 169000:	Length: 32712	Compression: 0.662784	Avg Compression: 0.428323
# Article 170000:	Length: 36536	Compression: 0.469126	Avg Compression: 0.429091
# Article 171000:	Length: 37280	Compression: 0.523256	Avg Compression: 0.430866
# Article 172000:	Length: 38040	Compression: 0.375631	Avg Compression: 0.429823
# Article 173000:	Length: 38832	Compression: 0.408967	Avg Compression: 0.429429
# Article 174000:	Length: 39544	Compression: 0.517373	Avg Compression: 0.431090
# Article 175000:	Length: 40464	Compression: 0.428751	Avg Compression: 0.431045
# Article 176000:	Length: 41616	Compression: 0.348520	Avg Compression: 0.429467
# Article 177000:	Length: 42472	Compression: 0.553612	Avg Compression: 0.431844
# Article 178000:	Length: 43560	Compression: 0.415358	Avg Compression: 0.431526
# Article 179000:	Length: 44600	Compression: 0.494305	Avg Compression: 0.432740
# Article 180000:	Length: 45720	Compression: 0.420888	Avg Compression: 0.432510
# Article 181000:	Length: 46872	Compression: 0.430918	Avg Compression: 0.432478
# Article 182000:	Length: 48216	Compression: 0.446283	Avg Compression: 0.432750
# Article 183000:	Length: 49280	Compression: 0.443263	Avg Compression: 0.432958
# Article 184000:	Length: 50872	Compression: 0.428271	Avg Compression: 0.432864
# Article 185000:	Length: 52256	Compression: 0.417923	Avg Compression: 0.432564
# Article 186000:	Length: 53576	Compression: 0.452497	Avg Compression: 0.432966
# Article 187000:	Length: 55152	Compression: 0.378826	Avg Compression: 0.431864
# Article 188000:	Length: 56824	Compression: 0.450162	Avg Compression: 0.432240
# Article 189000:	Length: 58288	Compression: 0.457590	Avg Compression: 0.432763
# Article 190000:	Length: 60224	Compression: 0.446168	Avg Compression: 0.433043
# Article 191000:	Length: 62064	Compression: 0.406065	Avg Compression: 0.432475
# Article 192000:	Length: 63888	Compression: 0.448676	Avg Compression: 0.432819
# Article 193000:	Length: 65440	Compression: 0.426009	Avg Compression: 0.432674
# Article 194000:	Length: 67104	Compression: 0.589965	Avg Compression: 0.436032
# Article 195000:	Length: 69480	Compression: 0.630325	Avg Compression: 0.440235
# Article 196000:	Length: 72224	Compression: 0.422477	Avg Compression: 0.439844
# Article 197000:	Length: 75336	Compression: 0.403831	Avg Compression: 0.439037
# Article 198000:	Length: 78192	Compression: 0.373299	Avg Compression: 0.437542
# Article 199000:	Length: 80304	Compression: 0.498730	Avg Compression: 0.438938
# Article 200000:	Length: 84232	Compression: 0.459944	Avg Compression: 0.439429
# Article 201000:	Length: 87152	Compression: 0.472095	Avg Compression: 0.440201
# Article 202000:	Length: 90944	Compression: 0.375253	Avg Compression: 0.438639
# Article 203000:	Length: 94984	Compression: 0.431231	Avg Compression: 0.438457
# Article 204000:	Length: 98712	Compression: 0.520970	Avg Compression: 0.440506
# Article 205000:	Length: 103760	Compression: 0.428874	Avg Compression: 0.440210
# Article 206000:	Length: 108480	Compression: 0.455992	Avg Compression: 0.440619
# Article 207000:	Length: 112664	Compression: 0.428966	Avg Compression: 0.440314
# Article 208000:	Length: 119704	Compression: 0.449475	Avg Compression: 0.440562
# Article 209000:	Length: 126656	Compression: 0.395820	Avg Compression: 0.439315
# Article 210000:	Length: 134016	Compression: 0.473078	Avg Compression: 0.440282
# Article 211000:	Length: 142360	Compression: 0.495785	Avg Compression: 0.441921
# Article 212000:	Length: 152304	Compression: 0.423489	Avg Compression: 0.441357
# Article 213000:	Length: 163720	Compression: 0.383826	Avg Compression: 0.439523
# Article 214000:	Length: 177264	Compression: 0.438623	Avg Compression: 0.439493
# Article 215000:	Length: 193048	Compression: 0.439632	Avg Compression: 0.439498
# Article 216000:	Length: 212904	Compression: 0.422289	Avg Compression: 0.438858
# Article 217000:	Length: 238072	Compression: 0.426522	Avg Compression: 0.438365
# Article 218000:	Length: 274168	Compression: 0.406561	Avg Compression: 0.436966
# Article 219000:	Length: 329056	Compression: 0.387226	Avg Compression: 0.434472
# Article 220000:	Length: 456256	Compression: 0.624904	Avg Compression: 0.446851
