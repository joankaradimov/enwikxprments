# %%
import itertools
import os

import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds

physical_devices = tf.config.list_physical_devices('GPU')
for physical_device in physical_devices:
    tf.config.experimental.set_memory_growth(physical_device, enable=True)

# %%
#config = tf.compat.v1.ConfigProto()
#config.gpu_options.per_process_gpu_memory_fraction = 2
#config.gpu_options.allow_growth = True
#
#tf.compat.v1.keras.backend.set_session(tf.compat.v1.Session(config=config))

# %%
def articles():
    with open('page_revisions_text', 'rb') as text_file:
        pending_article_data = b''
        while True:
            data = text_file.read(1024 ** 2)
            if len(data) == 0:
                break

            articles = data.split(b'\0')
            articles[0] = pending_article_data + articles[0]
            for index, article in enumerate(articles):
                if index + 1 == len(articles):
                    pending_article_data = article
                else:
                    yield article

        print(pending_article_data)
        if len(pending_article_data) != 0:
            yield pending_article_data

# %%
subword_text_encoder = tfds.features.text.SubwordTextEncoder.load_from_file('vocab_4096')

# %%
BATCH_SIZE = 2048
BATCHED_ITEM_LENGTH = 24
TYPE=np.int16

def articles_generator():
    for index, article in enumerate(itertools.islice(articles(), 0, 25000)):
        yield np.array(subword_text_encoder.encode(article + b'\0'), dtype=TYPE)

    # Pad the article count to the batch size
    # We do this to ensure that no data is dropped
    index += 1
    while index % BATCH_SIZE != 0:
        yield np.array([0], dtype=TYPE)
        index += 1

def subbatches():
    dataset = tf.data.Dataset.from_generator(articles_generator, output_types=TYPE)
    dataset = dataset.shuffle(1500)
    dataset = dataset.padded_batch(BATCH_SIZE, padded_shapes=([None]), drop_remainder=True)
    dataset = dataset.shuffle(50)

    for batch in dataset.as_numpy_iterator():
        remaining = batch
        while remaining.shape[1] > 1:
            yield remaining[:, :BATCHED_ITEM_LENGTH + 1]
            remaining = remaining[:, BATCHED_ITEM_LENGTH:]

dataset = tf.data.Dataset.from_generator(subbatches, output_types=TYPE, output_shapes=(BATCH_SIZE, None))
dataset = dataset.map(lambda batch: (batch[:, :-1], batch[:, 1:]))

dataset
# Out:
# <MapDataset shapes: ((2048, None), (2048, None)), types: (tf.int16, tf.int16)>

# %%
def build_model(vocab_size, embedding_dim, rnn_units, batch_size):
    return tf.keras.Sequential([
        tf.keras.layers.Masking(mask_value=0, batch_input_shape=[batch_size, None]),
        tf.keras.layers.Embedding(vocab_size, embedding_dim),
        tf.keras.layers.GRU(rnn_units, return_sequences=True, stateful=True, recurrent_initializer='glorot_uniform'),
        tf.keras.layers.GRU(rnn_units, return_sequences=True, stateful=True, recurrent_initializer='glorot_uniform'),
        tf.keras.layers.GRU(rnn_units, return_sequences=True, stateful=True, recurrent_initializer='glorot_uniform'),
        tf.keras.layers.Dense(vocab_size),
    ])

# %%
checkpoint_dir = './training_checkpoints-2' # Directory where the checkpoints will be saved
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt_{epoch}") # Name of the checkpoint files

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_prefix, save_weights_only=True)

class ModelStateResetter(tf.keras.callbacks.Callback):
    def __init__(self):
        self.last_total_length = 0

    def on_batch_end(self, batch, logs={}):
        average_batch_length = logs.get('average_batch_length', 0)
        total_length = int(round(average_batch_length * (batch + 1)))
        current_batch_length = total_length - self.last_total_length
        self.last_total_length = total_length
        
        if current_batch_length < BATCHED_ITEM_LENGTH:
            self.model.reset_states()
        
model_state_resetter_callback = ModelStateResetter()

def loss(labels, logits):
    return tf.keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)

def average_batch_length(true_labels, predictions):
    return tf.shape(true_labels)[1]

model = build_model(vocab_size = subword_text_encoder.vocab_size, embedding_dim=512, rnn_units=768, batch_size=BATCH_SIZE)
# model.load_weights(tf.train.latest_checkpoint(checkpoint_dir))
model.compile(optimizer='adam', loss=loss, metrics=[average_batch_length])

# %%
total_epochs = 4

for epoch in range(total_epochs):
    print('Epoch %d/%d' % (epoch + 1, total_epochs))
    model.fit(dataset, callbacks=[checkpoint_callback, model_state_resetter_callback])
# Out:
# Epoch 1/4
# 20166/20166 [==============================] - 14135s 701ms/step - loss: 0.2622 - average_batch_length: 23.9957
# Epoch 2/4
#   14715/Unknown - 10330s 702ms/step - loss: 0.2103 - average_batch_length: 23.9956

# %%
total_epochs = 4

for epoch in range(total_epochs):
    print('Epoch %d/%d' % (epoch + 1, total_epochs))
    model.fit(dataset, callbacks=[checkpoint_callback, model_state_resetter_callback])
# Out:
# Epoch 1/4
# 21523/21523 [==============================] - 15287s 710ms/step - loss: 0.2065 - average_batch_length: 23.9949
# Epoch 2/4
# 22029/22029 [==============================] - 15701s 713ms/step - loss: 0.2025 - average_batch_length: 23.9947
# Epoch 3/4
#     973/Unknown - 759s 780ms/step - loss: 0.3644 - average_batch_length: 24.0000

# %%
total_epochs = 2

for epoch in range(total_epochs):
    print('Epoch %d/%d' % (epoch + 1, total_epochs))
    model.fit(dataset, callbacks=[checkpoint_callback, model_state_resetter_callback])
# Out:
# Epoch 1/2
# 22244/22244 [==============================] - 16001s 719ms/step - loss: 0.2021 - average_batch_length: 23.9951
# Epoch 2/2
#    3568/Unknown - 2612s 732ms/step - loss: 0.2435 - average_batch_length: 23.9980
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-f94a5ee96609> in <module>
#       3 for epoch in range(total_epochs):
#       4     print('Epoch %d/%d' % (epoch + 1, total_epochs))
# ----> 5     model.fit(dataset, callbacks=[checkpoint_callback, model_state_resetter_callback])
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     340                 mode=ModeKeys.TRAIN,
#     341                 training_context=training_context,
# --> 342                 total_epochs=epochs)
#     343             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     344
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     126         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     127       try:
# --> 128         batch_outs = execution_function(iterator)
#     129       except (StopIteration, errors.OutOfRangeError):
#     130         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py in execution_function(input_fn)
#      96     # `numpy` translates Tensors to values in Eager mode.
#      97     return nest.map_structure(_non_none_constant_value,
# ---> 98                               distributed_function(input_fn))
#      99
#     100   return execution_function
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\eager\def_function.py in __call__(self, *args, **kwds)
#     566         xla_context.Exit()
#     567     else:
# --> 568       result = self._call(*args, **kwds)
#     569
#     570     if tracing_count == self._get_tracing_count():
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\eager\def_function.py in _call(self, *args, **kwds)
#     597       # In this case we have created variables on the first call, so we run the
#     598       # defunned version which is guaranteed to never create variables.
# --> 599       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     600     elif self._stateful_fn is not None:
#     601       # Release the lock early so that multiple threads can perform the call
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    2361     with self._lock:
#    2362       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2363     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2364
#    2365   @property
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\eager\function.py in _filtered_call(self, args, kwargs)
#    1609          if isinstance(t, (ops.Tensor,
#    1610                            resource_variable_ops.BaseResourceVariable))),
# -> 1611         self.captured_inputs)
#    1612
#    1613   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
def build_predicting_model(vocab_size, embedding_dim, rnn_units):
    return tf.keras.Sequential([
        tf.keras.layers.Masking(mask_value=0, batch_input_shape=[1, 1]),
        tf.keras.layers.Embedding(vocab_size, embedding_dim),
        tf.keras.layers.GRU(rnn_units, return_sequences=True),
        tf.keras.layers.GRU(rnn_units, return_sequences=True),
        tf.keras.layers.GRU(rnn_units, return_sequences=True),
        tf.keras.layers.Dense(vocab_size),
    ])

model = build_predicting_model(vocab_size = subword_text_encoder.vocab_size, embedding_dim=512, rnn_units=768)
model.load_weights(tf.train.latest_checkpoint(checkpoint_dir))
model.build(tf.TensorShape([1, 1]))

# %%
import ctypes

class Huffman:
    huffman = ctypes.CDLL('x64/Release/huffman')
    
    huffman.create_tree.restype = ctypes.c_void_p
    huffman.destroy_tree.restype = None
    huffman.load_weights.restype = None
    huffman.create_code_string.restype = ctypes.c_char_p
    
    def __init__(self, category_count):
        self.tree = ctypes.c_void_p(self.huffman.create_tree(category_count))

    def __del__(self):
        self.huffman.destroy_tree(self.tree)
        
    def load_weights(self, weights):
        self.huffman.load_weights(self.tree, weights.ctypes.data_as(ctypes.POINTER(ctypes.c_float)))
    
    def get_code_length(self, category):
        return self.huffman.get_code_length(self.tree, category)

    def get_code_zero_count(self, category):
        return self.huffman.get_code_zero_count(self.tree, category)

# %%
def huffman_archive_size(model, text):
    archived_size = 0
    zeros = 0
    input_eval = np.array([[0]], dtype=TYPE)
    huffman_tree = Huffman(subword_text_encoder.vocab_size)

    text_generated = []

    model.reset_states()

    for index, byte in enumerate(text):
        predictions = model(input_eval)
        predictions = tf.squeeze(predictions, 0) # remove the batch dimension

        weights = tf.nn.softmax(predictions[0]).numpy()
        huffman_tree.load_weights(weights)
        zeros += huffman_tree.get_code_zero_count(byte.item())
        archived_size += huffman_tree.get_code_length(byte.item())

        input_eval = tf.expand_dims([byte], 0)
  
    return archived_size, zeros

# %%
total_raw = 0
total_compressed = 0

for index, article in enumerate(itertools.islice(articles(), 0, 512)):
    raw = (len(article) + 1) * 8
    encoded_article = np.array(subword_text_encoder.encode(article + b'\0'), dtype=TYPE)
    compressed, _ = huffman_archive_size(model, encoded_article)
    total_raw += raw
    total_compressed += compressed
    print('Article %d:\tCompression: %f\tAvg Compression: %f' % (index, compressed/raw, total_compressed/total_raw))
# Out:
# Article 0:	Compression: 9.611111	Avg Compression: 9.611111
# Article 1:	Compression: 4.333333	Avg Compression: 5.916667
# Article 2:	Compression: 3.719388	Avg Compression: 4.928899
# Article 3:	Compression: 5.833333	Avg Compression: 5.124101
# Article 4:	Compression: 5.035714	Avg Compression: 5.106322
# Article 5:	Compression: 4.442308	Avg Compression: 4.984742
# Article 6:	Compression: 0.359880	Avg Compression: 0.376640
# Article 7:	Compression: 4.722973	Avg Compression: 0.379374
# Article 8:	Compression: 4.415625	Avg Compression: 0.382117
# Article 9:	Compression: 4.172619	Avg Compression: 0.384820
# Article 10:	Compression: 4.703947	Avg Compression: 0.387605
# Article 11:	Compression: 4.000000	Avg Compression: 0.390300
# Article 12:	Compression: 4.005682	Avg Compression: 0.392995
# Article 13:	Compression: 4.641447	Avg Compression: 0.395728
# Article 14:	Compression: 3.803191	Avg Compression: 0.398438
# Article 15:	Compression: 7.291667	Avg Compression: 0.401235
# Article 16:	Compression: 5.032143	Avg Compression: 0.403975
# Article 17:	Compression: 7.333333	Avg Compression: 0.406784
# Article 18:	Compression: 0.344898	Avg Compression: 0.378682
# Article 19:	Compression: 5.280303	Avg Compression: 0.380174
# Article 20:	Compression: 5.007143	Avg Compression: 0.381666
# Article 21:	Compression: 4.598684	Avg Compression: 0.383143
# Article 22:	Compression: 5.991667	Avg Compression: 0.384692
# Article 23:	Compression: 6.658654	Avg Compression: 0.386195
# Article 24:	Compression: 5.128676	Avg Compression: 0.387679
# Article 25:	Compression: 5.375000	Avg Compression: 0.389194
# Article 26:	Compression: 7.527174	Avg Compression: 0.390704
# Article 27:	Compression: 0.398101	Avg Compression: 0.391263
# Article 28:	Compression: 4.800676	Avg Compression: 0.392650
# Article 29:	Compression: 3.168103	Avg Compression: 0.394018
# Article 30:	Compression: 0.405103	Avg Compression: 0.394928
# Article 31:	Compression: 7.359375	Avg Compression: 0.396232
# Article 32:	Compression: 7.869318	Avg Compression: 0.397514
# Article 33:	Compression: 7.510870	Avg Compression: 0.398790
# Article 34:	Compression: 7.892045	Avg Compression: 0.400075
# Article 35:	Compression: 7.863636	Avg Compression: 0.401355
# Article 36:	Compression: 7.208333	Avg Compression: 0.402629
# Article 37:	Compression: 8.232143	Avg Compression: 0.403910
# Article 38:	Compression: 8.184524	Avg Compression: 0.405183
# Article 39:	Compression: 6.174107	Avg Compression: 0.406441
# Article 40:	Compression: 5.879167	Avg Compression: 0.407720
# Article 41:	Compression: 7.208333	Avg Compression: 0.408991
# Article 42:	Compression: 3.607843	Avg Compression: 0.410261
# Article 43:	Compression: 4.168605	Avg Compression: 0.411518
# Article 44:	Compression: 4.258929	Avg Compression: 0.412775
# Article 45:	Compression: 4.258929	Avg Compression: 0.414031
# Article 46:	Compression: 4.570513	Avg Compression: 0.415291
# Article 47:	Compression: 4.586538	Avg Compression: 0.416556
# Article 48:	Compression: 5.532258	Avg Compression: 0.417788
# Article 49:	Compression: 6.276786	Avg Compression: 0.419062
# Article 50:	Compression: 7.576087	Avg Compression: 0.420340
# Article 51:	Compression: 5.390152	Avg Compression: 0.421614
# Article 52:	Compression: 6.546296	Avg Compression: 0.422897
# Article 53:	Compression: 6.254464	Avg Compression: 0.424165
# Article 54:	Compression: 6.980000	Avg Compression: 0.425436
# Article 55:	Compression: 4.854730	Avg Compression: 0.426708
# Article 56:	Compression: 7.338542	Avg Compression: 0.427994
# Article 57:	Compression: 8.226190	Avg Compression: 0.429264
# Article 58:	Compression: 5.689516	Avg Compression: 0.430528
# Article 59:	Compression: 7.354167	Avg Compression: 0.431816
# Article 60:	Compression: 4.985714	Avg Compression: 0.433052
# Article 61:	Compression: 5.371212	Avg Compression: 0.434314
# Article 62:	Compression: 6.245536	Avg Compression: 0.435574
# Article 63:	Compression: 5.608871	Avg Compression: 0.436816
# Article 64:	Compression: 7.203125	Avg Compression: 0.438073
# Article 65:	Compression: 7.840909	Avg Compression: 0.439334
# Article 66:	Compression: 7.270833	Avg Compression: 0.440603
# Article 67:	Compression: 6.290179	Avg Compression: 0.441870
# Article 68:	Compression: 6.034483	Avg Compression: 0.443125
# Article 69:	Compression: 3.975000	Avg Compression: 0.444354
# Article 70:	Compression: 5.770833	Avg Compression: 0.445590
# Article 71:	Compression: 5.511719	Avg Compression: 0.446843
# Article 72:	Compression: 5.673387	Avg Compression: 0.448095
# Article 73:	Compression: 5.212121	Avg Compression: 0.449309
# Article 74:	Compression: 4.220930	Avg Compression: 0.450562
# Article 75:	Compression: 5.798387	Avg Compression: 0.451842
# Article 76:	Compression: 7.614130	Avg Compression: 0.453114
# Article 77:	Compression: 5.057143	Avg Compression: 0.454357
# Article 78:	Compression: 4.641447	Avg Compression: 0.455585
# Article 79:	Compression: 5.176471	Avg Compression: 0.456823
# Article 80:	Compression: 5.424242	Avg Compression: 0.458087
# Article 81:	Compression: 4.554487	Avg Compression: 0.459319
# Article 82:	Compression: 8.568750	Avg Compression: 0.460569
# Article 83:	Compression: 4.214286	Avg Compression: 0.461784
# Article 84:	Compression: 0.413501	Avg Compression: 0.458014
# Article 85:	Compression: 5.172794	Avg Compression: 0.459153
# Article 86:	Compression: 5.284091	Avg Compression: 0.460283
# Article 87:	Compression: 4.214286	Avg Compression: 0.461403
# Article 88:	Compression: 6.073276	Avg Compression: 0.462558
# Article 89:	Compression: 4.864583	Avg Compression: 0.463682
# Article 90:	Compression: 6.107759	Avg Compression: 0.464843
# Article 91:	Compression: 6.398148	Avg Compression: 0.465979
# Article 92:	Compression: 0.409316	Avg Compression: 0.458744
# Article 93:	Compression: 7.795455	Avg Compression: 0.459742
# Article 94:	Compression: 0.408024	Avg Compression: 0.453951
# Article 95:	Compression: 5.198529	Avg Compression: 0.454837
# Article 96:	Compression: 0.357684	Avg Compression: 0.425097
# Article 97:	Compression: 0.366015	Avg Compression: 0.416550
# Article 98:	Compression: 0.592070	Avg Compression: 0.417187
# Article 99:	Compression: 8.568750	Avg Compression: 0.417716
# Article 100:	Compression: 3.975000	Avg Compression: 0.418236
# Article 101:	Compression: 4.088068	Avg Compression: 0.418760
# Article 102:	Compression: 3.983333	Avg Compression: 0.419281
# Article 103:	Compression: 3.381944	Avg Compression: 0.419800
# Article 104:	Compression: 3.265625	Avg Compression: 0.420317
# Article 105:	Compression: 3.556373	Avg Compression: 0.420836
# Article 106:	Compression: 4.235119	Avg Compression: 0.421356
# Article 107:	Compression: 3.141667	Avg Compression: 0.421885
# Article 108:	Compression: 3.526442	Avg Compression: 0.422409
# Article 109:	Compression: 3.519231	Avg Compression: 0.422931
# Article 110:	Compression: 4.218023	Avg Compression: 0.423460
# Article 111:	Compression: 3.359091	Avg Compression: 0.423983
# Article 112:	Compression: 0.397310	Avg Compression: 0.423136
# Article 113:	Compression: 6.398148	Avg Compression: 0.423643
# Article 114:	Compression: 8.568750	Avg Compression: 0.424154
# Article 115:	Compression: 3.970109	Avg Compression: 0.424666
# Article 116:	Compression: 8.537500	Avg Compression: 0.425175
# Article 117:	Compression: 0.623773	Avg Compression: 0.425871
# Article 118:	Compression: 4.671053	Avg Compression: 0.426375
# Article 119:	Compression: 0.445104	Avg Compression: 0.426583
# Article 120:	Compression: 0.353633	Avg Compression: 0.421245
# Article 121:	Compression: 0.449286	Avg Compression: 0.421636
# Article 122:	Compression: 6.462963	Avg Compression: 0.422097
# Article 123:	Compression: 0.376952	Avg Compression: 0.417387
# Article 124:	Compression: 0.553692	Avg Compression: 0.417998
# Article 125:	Compression: 5.198529	Avg Compression: 0.418408
# Article 126:	Compression: 5.685484	Avg Compression: 0.418819
# Article 127:	Compression: 0.431594	Avg Compression: 0.418956
# Article 128:	Compression: 5.261364	Avg Compression: 0.419354
# Article 129:	Compression: 4.989286	Avg Compression: 0.419753
# Article 130:	Compression: 4.582237	Avg Compression: 0.420147
# Article 131:	Compression: 5.110294	Avg Compression: 0.420544
# Article 132:	Compression: 0.373107	Avg Compression: 0.419476
# Article 133:	Compression: 4.375000	Avg Compression: 0.419861
# Article 134:	Compression: 5.000000	Avg Compression: 0.420251
# Article 135:	Compression: 5.154412	Avg Compression: 0.420643
# Article 136:	Compression: 3.836957	Avg Compression: 0.421026
# Article 137:	Compression: 4.878472	Avg Compression: 0.421416
# Article 138:	Compression: 2.953629	Avg Compression: 0.421798
# Article 139:	Compression: 0.403534	Avg Compression: 0.420760
# Article 140:	Compression: 0.370418	Avg Compression: 0.417437
# Article 141:	Compression: 0.437974	Avg Compression: 0.417593
# Article 142:	Compression: 0.407071	Avg Compression: 0.417415
# Article 143:	Compression: 0.344310	Avg Compression: 0.416730
# Article 144:	Compression: 4.570513	Avg Compression: 0.417066
# Article 145:	Compression: 0.372025	Avg Compression: 0.415459
# Article 146:	Compression: 0.369252	Avg Compression: 0.414700
# Article 147:	Compression: 0.371935	Avg Compression: 0.413552
# Article 148:	Compression: 0.339783	Avg Compression: 0.409262
# Article 149:	Compression: 0.333956	Avg Compression: 0.404510
# Article 150:	Compression: 5.121429	Avg Compression: 0.404789
# Article 151:	Compression: 0.358488	Avg Compression: 0.404245
# Article 152:	Compression: 0.359980	Avg Compression: 0.400195
# Article 153:	Compression: 0.362520	Avg Compression: 0.399331
# Article 154:	Compression: 7.456522	Avg Compression: 0.399571
# Article 155:	Compression: 0.385354	Avg Compression: 0.398950
# Article 156:	Compression: 0.350999	Avg Compression: 0.395866
# Article 157:	Compression: 0.431038	Avg Compression: 0.396505
# Article 158:	Compression: 0.626581	Avg Compression: 0.396812
# Article 159:	Compression: 0.391202	Avg Compression: 0.396774
# Article 160:	Compression: 7.333333	Avg Compression: 0.396989
# Article 161:	Compression: 0.377000	Avg Compression: 0.396882
# Article 162:	Compression: 0.457514	Avg Compression: 0.399000
# Article 163:	Compression: 0.475739	Avg Compression: 0.399282
# Article 164:	Compression: 0.364464	Avg Compression: 0.397208
# Article 165:	Compression: 4.244186	Avg Compression: 0.397400
# Article 166:	Compression: 0.491369	Avg Compression: 0.397683
# Article 167:	Compression: 6.915000	Avg Compression: 0.397871
# Article 168:	Compression: 7.015000	Avg Compression: 0.398063
# Article 169:	Compression: 0.376412	Avg Compression: 0.397791
# Article 170:	Compression: 0.417696	Avg Compression: 0.398425
# Article 171:	Compression: 0.430144	Avg Compression: 0.400017
# Article 172:	Compression: 4.985714	Avg Compression: 0.400185
# Article 173:	Compression: 0.389734	Avg Compression: 0.400137
# Article 174:	Compression: 4.583333	Avg Compression: 0.400308
# Article 175:	Compression: 0.461877	Avg Compression: 0.401033
# Article 176:	Compression: 0.418058	Avg Compression: 0.401283
# Article 177:	Compression: 5.329545	Avg Compression: 0.401449
# Article 178:	Compression: 5.053571	Avg Compression: 0.401614
# Article 179:	Compression: 4.641447	Avg Compression: 0.401778
# Article 180:	Compression: 5.176471	Avg Compression: 0.401943
# Article 181:	Compression: 5.424242	Avg Compression: 0.402112
# Article 182:	Compression: 7.920455	Avg Compression: 0.402280
# Article 183:	Compression: 4.437500	Avg Compression: 0.402444
# Article 184:	Compression: 4.443750	Avg Compression: 0.402609
# Article 185:	Compression: 4.183140	Avg Compression: 0.402774
# Article 186:	Compression: 4.183140	Avg Compression: 0.402939
# Article 187:	Compression: 4.183140	Avg Compression: 0.403105
# Article 188:	Compression: 0.463097	Avg Compression: 0.403347
# Article 189:	Compression: 0.342462	Avg Compression: 0.403190
# Article 190:	Compression: 4.881944	Avg Compression: 0.403353
# Article 191:	Compression: 0.417916	Avg Compression: 0.403358
# Article 192:	Compression: 3.323661	Avg Compression: 0.403523
# Article 193:	Compression: 0.354577	Avg Compression: 0.400898
# Article 194:	Compression: 0.363278	Avg Compression: 0.399982
# Article 195:	Compression: 0.441973	Avg Compression: 0.400322
# Article 196:	Compression: 7.880682	Avg Compression: 0.400474
# Article 197:	Compression: 9.013158	Avg Compression: 0.400626
# Article 198:	Compression: 0.366303	Avg Compression: 0.399532
# Article 199:	Compression: 0.352042	Avg Compression: 0.399367
# Article 200:	Compression: 6.038793	Avg Compression: 0.399513
# Article 201:	Compression: 0.369565	Avg Compression: 0.398837
# Article 202:	Compression: 0.382582	Avg Compression: 0.398580
# Article 203:	Compression: 5.546875	Avg Compression: 0.398721
# Article 204:	Compression: 0.515112	Avg Compression: 0.398934
# Article 205:	Compression: 0.560799	Avg Compression: 0.399214
# Article 206:	Compression: 0.380771	Avg Compression: 0.398979
# Article 207:	Compression: 0.442023	Avg Compression: 0.399095
# Article 208:	Compression: 4.895833	Avg Compression: 0.399231
# Article 209:	Compression: 5.010714	Avg Compression: 0.399367
# Article 210:	Compression: 5.010714	Avg Compression: 0.399503
# Article 211:	Compression: 5.010714	Avg Compression: 0.399639
# Article 212:	Compression: 0.383025	Avg Compression: 0.399113
# Article 213:	Compression: 0.334291	Avg Compression: 0.398530
# Article 214:	Compression: 0.421965	Avg Compression: 0.398572
# Article 215:	Compression: 8.380952	Avg Compression: 0.398707
# Article 216:	Compression: 4.920139	Avg Compression: 0.398838
# Article 217:	Compression: 4.920139	Avg Compression: 0.398970
# Article 218:	Compression: 5.437500	Avg Compression: 0.399100
# Article 219:	Compression: 8.568750	Avg Compression: 0.399232
# Article 220:	Compression: 0.483199	Avg Compression: 0.399370
# Article 221:	Compression: 7.208333	Avg Compression: 0.399501
# Article 222:	Compression: 0.383147	Avg Compression: 0.399381
# Article 223:	Compression: 4.985714	Avg Compression: 0.399509
# Article 224:	Compression: 0.387136	Avg Compression: 0.399403
# Article 225:	Compression: 1.043028	Avg Compression: 0.399606
# Article 226:	Compression: 0.386285	Avg Compression: 0.399485
# Article 227:	Compression: 0.470466	Avg Compression: 0.400260
# Article 228:	Compression: 0.429258	Avg Compression: 0.400332
# Article 229:	Compression: 4.793919	Avg Compression: 0.400458
# Article 230:	Compression: 0.406234	Avg Compression: 0.400475
# Article 231:	Compression: 0.369827	Avg Compression: 0.399463
# Article 232:	Compression: 0.418344	Avg Compression: 0.399506
# Article 233:	Compression: 0.387265	Avg Compression: 0.399254
# Article 234:	Compression: 0.366147	Avg Compression: 0.398138
# Article 235:	Compression: 0.397880	Avg Compression: 0.398137
# Article 236:	Compression: 0.437550	Avg Compression: 0.398240
# Article 237:	Compression: 0.492998	Avg Compression: 0.398519
# Article 238:	Compression: 0.536858	Avg Compression: 0.398678
# Article 239:	Compression: 6.970000	Avg Compression: 0.398792
# Article 240:	Compression: 0.369291	Avg Compression: 0.398409
# Article 241:	Compression: 0.539723	Avg Compression: 0.398695
# Article 242:	Compression: 0.415171	Avg Compression: 0.398787
# Article 243:	Compression: 0.537235	Avg Compression: 0.398969
# Article 244:	Compression: 0.404048	Avg Compression: 0.398993
# Article 245:	Compression: 0.398035	Avg Compression: 0.398991
# Article 246:	Compression: 6.254464	Avg Compression: 0.399101
# Article 247:	Compression: 0.365938	Avg Compression: 0.399080
# Article 248:	Compression: 0.429121	Avg Compression: 0.399217
# Article 249:	Compression: 0.533498	Avg Compression: 0.399409
# Article 250:	Compression: 0.411699	Avg Compression: 0.399450
# Article 251:	Compression: 0.361420	Avg Compression: 0.399409
# Article 252:	Compression: 6.486111	Avg Compression: 0.399519
# Article 253:	Compression: 0.491104	Avg Compression: 0.400845
# Article 254:	Compression: 5.096429	Avg Compression: 0.400953
# Article 255:	Compression: 4.895833	Avg Compression: 0.401059
# Article 256:	Compression: 0.392852	Avg Compression: 0.400927
# Article 257:	Compression: 0.383773	Avg Compression: 0.400780
# Article 258:	Compression: 0.321093	Avg Compression: 0.399931
# Article 259:	Compression: 8.606250	Avg Compression: 0.400035
# Article 260:	Compression: 3.880319	Avg Compression: 0.400139
# Article 261:	Compression: 0.342748	Avg Compression: 0.399743
# Article 262:	Compression: 0.613992	Avg Compression: 0.399955
# Article 263:	Compression: 0.368763	Avg Compression: 0.399554
# Article 264:	Compression: 0.390861	Avg Compression: 0.399425
# Article 265:	Compression: 7.234375	Avg Compression: 0.399525
# Article 266:	Compression: 0.376811	Avg Compression: 0.399156
# Article 267:	Compression: 0.387712	Avg Compression: 0.399009
# Article 268:	Compression: 5.437500	Avg Compression: 0.399105
# Article 269:	Compression: 0.376934	Avg Compression: 0.398887
# Article 270:	Compression: 0.390809	Avg Compression: 0.398861
# Article 271:	Compression: 0.407864	Avg Compression: 0.398885
# Article 272:	Compression: 0.388442	Avg Compression: 0.398853
# Article 273:	Compression: 0.397660	Avg Compression: 0.398853
# Article 274:	Compression: 0.546896	Avg Compression: 0.399044
# Article 275:	Compression: 0.555197	Avg Compression: 0.399157
# Article 276:	Compression: 0.421503	Avg Compression: 0.399183
# Article 277:	Compression: 0.342048	Avg Compression: 0.398853
# Article 278:	Compression: 0.450414	Avg Compression: 0.399150
# Article 279:	Compression: 0.390655	Avg Compression: 0.399096
# Article 280:	Compression: 7.250000	Avg Compression: 0.399190
# Article 281:	Compression: 0.377581	Avg Compression: 0.398740
# Article 282:	Compression: 0.395033	Avg Compression: 0.398732
# Article 283:	Compression: 0.373618	Avg Compression: 0.398498
# Article 284:	Compression: 0.425301	Avg Compression: 0.398847
# Article 285:	Compression: 3.831522	Avg Compression: 0.398933
# Article 286:	Compression: 5.021429	Avg Compression: 0.399021
# Article 287:	Compression: 0.524901	Avg Compression: 0.399211
# Article 288:	Compression: 0.574824	Avg Compression: 0.399388
# Article 289:	Compression: 5.021429	Avg Compression: 0.399476
# Article 290:	Compression: 0.545563	Avg Compression: 0.399842
# Article 291:	Compression: 7.880682	Avg Compression: 0.399931
# Article 292:	Compression: 0.378690	Avg Compression: 0.399192
# Article 293:	Compression: 0.373644	Avg Compression: 0.398429
# Article 294:	Compression: 0.407579	Avg Compression: 0.398533
# Article 295:	Compression: 0.416820	Avg Compression: 0.398679
# Article 296:	Compression: 0.388552	Avg Compression: 0.398517
# Article 297:	Compression: 6.970000	Avg Compression: 0.398598
# Article 298:	Compression: 5.064286	Avg Compression: 0.398678
# Article 299:	Compression: 0.389474	Avg Compression: 0.398519
# Article 300:	Compression: 0.397928	Avg Compression: 0.398511
# Article 301:	Compression: 0.423348	Avg Compression: 0.398745
# Article 302:	Compression: 0.361082	Avg Compression: 0.398474
# Article 303:	Compression: 6.697115	Avg Compression: 0.398551
# Article 304:	Compression: 0.373023	Avg Compression: 0.398197
# Article 305:	Compression: 0.342815	Avg Compression: 0.397577
# Article 306:	Compression: 0.394030	Avg Compression: 0.397561
# Article 307:	Compression: 5.128676	Avg Compression: 0.397634
# Article 308:	Compression: 2.971774	Avg Compression: 0.397707
# Article 309:	Compression: 4.390625	Avg Compression: 0.397779
# Article 310:	Compression: 5.172794	Avg Compression: 0.397853
# Article 311:	Compression: 4.145349	Avg Compression: 0.397926
# Article 312:	Compression: 4.598684	Avg Compression: 0.397999
# Article 313:	Compression: 2.894531	Avg Compression: 0.398071
# Article 314:	Compression: 5.375000	Avg Compression: 0.398146
# Article 315:	Compression: 4.384375	Avg Compression: 0.398218
# Article 316:	Compression: 4.145349	Avg Compression: 0.398291
# Article 317:	Compression: 0.500476	Avg Compression: 0.398425
# Article 318:	Compression: 0.386858	Avg Compression: 0.398124
# Article 319:	Compression: 0.459418	Avg Compression: 0.398183
# Article 320:	Compression: 6.020833	Avg Compression: 0.398258
# Article 321:	Compression: 0.423921	Avg Compression: 0.398266
# Article 322:	Compression: 0.376630	Avg Compression: 0.398177
# Article 323:	Compression: 0.340705	Avg Compression: 0.397172
# Article 324:	Compression: 0.347881	Avg Compression: 0.396178
# Article 325:	Compression: 0.434002	Avg Compression: 0.396230
# Article 326:	Compression: 0.358700	Avg Compression: 0.395556
# Article 327:	Compression: 0.338072	Avg Compression: 0.395013
# Article 328:	Compression: 4.671053	Avg Compression: 0.395080
# Article 329:	Compression: 0.488480	Avg Compression: 0.395124
# Article 330:	Compression: 1.193069	Avg Compression: 0.395290
# Article 331:	Compression: 0.487050	Avg Compression: 0.395404
# Article 332:	Compression: 0.445767	Avg Compression: 0.395432
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-4.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-4.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-4.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-4.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.cell.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-4.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-4.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-4.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-4.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.cell.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-4.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-4.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-4.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-4.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.cell.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-4.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-4.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-4.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-4.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.cell.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-4.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-4.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-4.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-4.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.cell.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-4.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-4.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-4.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-4.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.cell.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# Article 333:	Compression: 0.360780	Avg Compression: 0.394604
# Article 334:	Compression: 0.371112	Avg Compression: 0.394536
# Article 335:	Compression: 0.375629	Avg Compression: 0.394444
# Article 336:	Compression: 0.502053	Avg Compression: 0.394654
# Article 337:	Compression: 0.539279	Avg Compression: 0.394814
# Article 338:	Compression: 0.629167	Avg Compression: 0.394923
# Article 339:	Compression: 0.461779	Avg Compression: 0.395037
# Article 340:	Compression: 0.371066	Avg Compression: 0.394753
# Article 341:	Compression: 0.346277	Avg Compression: 0.394726
# Article 342:	Compression: 0.374404	Avg Compression: 0.394707
# Article 343:	Compression: 5.017361	Avg Compression: 0.394771
# Article 344:	Compression: 0.510524	Avg Compression: 0.395250
# Article 345:	Compression: 0.520832	Avg Compression: 0.395946
# Article 346:	Compression: 0.366179	Avg Compression: 0.395642
# Article 347:	Compression: 2.286164	Avg Compression: 0.395757
# Article 348:	Compression: 0.407253	Avg Compression: 0.395844
# Article 349:	Compression: 0.428496	Avg Compression: 0.396182
# Article 350:	Compression: 8.743750	Avg Compression: 0.396245
# Article 351:	Compression: 9.013158	Avg Compression: 0.396306
# Article 352:	Compression: 0.389361	Avg Compression: 0.396220
# Article 353:	Compression: 4.384375	Avg Compression: 0.396279
# Article 354:	Compression: 0.370625	Avg Compression: 0.395894
# Article 355:	Compression: 0.434282	Avg Compression: 0.395977
# Article 356:	Compression: 0.378253	Avg Compression: 0.395951
# Article 357:	Compression: 3.490566	Avg Compression: 0.396010
# Article 358:	Compression: 2.648214	Avg Compression: 0.396068
# Article 359:	Compression: 2.588542	Avg Compression: 0.396125
# Article 360:	Compression: 4.601974	Avg Compression: 0.396183
# Article 361:	Compression: 4.172619	Avg Compression: 0.396241
# Article 362:	Compression: 2.692857	Avg Compression: 0.396299
# Article 363:	Compression: 4.000000	Avg Compression: 0.396357
# Article 364:	Compression: 2.426948	Avg Compression: 0.396413
# Article 365:	Compression: 2.633803	Avg Compression: 0.396471
# Article 366:	Compression: 2.367188	Avg Compression: 0.396528
# Article 367:	Compression: 6.692308	Avg Compression: 0.396588
# Article 368:	Compression: 0.466628	Avg Compression: 0.396702
# Article 369:	Compression: 0.367700	Avg Compression: 0.396634
# Article 370:	Compression: 4.982143	Avg Compression: 0.396692
# Article 371:	Compression: 4.575658	Avg Compression: 0.396750
# Article 372:	Compression: 5.102941	Avg Compression: 0.396808
# Article 373:	Compression: 5.348485	Avg Compression: 0.396867
# Article 374:	Compression: 4.365625	Avg Compression: 0.396924
# Article 375:	Compression: 4.371875	Avg Compression: 0.396982
# Article 376:	Compression: 4.125000	Avg Compression: 0.397040
# Article 377:	Compression: 5.147059	Avg Compression: 0.397098
# Article 378:	Compression: 4.125000	Avg Compression: 0.397156
# Article 379:	Compression: 5.253788	Avg Compression: 0.397214
# Article 380:	Compression: 3.800532	Avg Compression: 0.397272
# Article 381:	Compression: 4.159091	Avg Compression: 0.397332
# Article 382:	Compression: 5.371212	Avg Compression: 0.397391
# Article 383:	Compression: 0.380578	Avg Compression: 0.397278
# Article 384:	Compression: 0.381559	Avg Compression: 0.397112
# Article 385:	Compression: 0.450794	Avg Compression: 0.397202
# Article 386:	Compression: 0.375122	Avg Compression: 0.397114
# Article 387:	Compression: 0.384644	Avg Compression: 0.397041
# Article 388:	Compression: 0.417526	Avg Compression: 0.397045
# Article 389:	Compression: 0.369603	Avg Compression: 0.396807
# Article 390:	Compression: 0.373756	Avg Compression: 0.396602
# Article 391:	Compression: 0.361481	Avg Compression: 0.396393
# Article 392:	Compression: 0.417553	Avg Compression: 0.396500
# Article 393:	Compression: 0.387775	Avg Compression: 0.396467
# Article 394:	Compression: 0.368982	Avg Compression: 0.396279
# Article 395:	Compression: 0.525759	Avg Compression: 0.396691
# Article 396:	Compression: 0.484980	Avg Compression: 0.397004
# Article 397:	Compression: 7.784091	Avg Compression: 0.397059
# Article 398:	Compression: 0.368089	Avg Compression: 0.396657
# Article 399:	Compression: 0.401345	Avg Compression: 0.396668
# Article 400:	Compression: 10.051471	Avg Compression: 0.396722
# Article 401:	Compression: 0.525285	Avg Compression: 0.396800
# Article 402:	Compression: 8.238095	Avg Compression: 0.396854
# Article 403:	Compression: 0.361450	Avg Compression: 0.396291
# Article 404:	Compression: 0.348579	Avg Compression: 0.395324
# Article 405:	Compression: 0.371308	Avg Compression: 0.395068
# Article 406:	Compression: 0.454428	Avg Compression: 0.395245
# Article 407:	Compression: 0.417532	Avg Compression: 0.395293
# Article 408:	Compression: 0.402120	Avg Compression: 0.395309
# Article 409:	Compression: 0.359218	Avg Compression: 0.395287
# Article 410:	Compression: 0.362805	Avg Compression: 0.395214
# Article 411:	Compression: 6.398148	Avg Compression: 0.395265
# Article 412:	Compression: 0.428168	Avg Compression: 0.395417
# Article 413:	Compression: 5.754167	Avg Compression: 0.395467
# Article 414:	Compression: 0.396825	Avg Compression: 0.395482
# Article 415:	Compression: 0.819853	Avg Compression: 0.395588
# Article 416:	Compression: 0.381541	Avg Compression: 0.395505
# Article 417:	Compression: 0.395453	Avg Compression: 0.395505
# Article 418:	Compression: 0.441829	Avg Compression: 0.395631
# Article 419:	Compression: 0.415327	Avg Compression: 0.396087
# Article 420:	Compression: 0.377304	Avg Compression: 0.395915
# Article 421:	Compression: 0.390637	Avg Compression: 0.395896
# Article 422:	Compression: 0.463983	Avg Compression: 0.395934
# Article 423:	Compression: 0.790196	Avg Compression: 0.396022
# Article 424:	Compression: 0.415814	Avg Compression: 0.396042
# Article 425:	Compression: 1.183333	Avg Compression: 0.396125
# Article 426:	Compression: 0.375299	Avg Compression: 0.395976
# Article 427:	Compression: 0.350201	Avg Compression: 0.395652
# Article 428:	Compression: 0.417591	Avg Compression: 0.395736
# Article 429:	Compression: 0.495609	Avg Compression: 0.395894
# Article 430:	Compression: 0.397997	Avg Compression: 0.395900
# Article 431:	Compression: 6.687500	Avg Compression: 0.395946
# Article 432:	Compression: 0.919563	Avg Compression: 0.396030
# Article 433:	Compression: 0.361158	Avg Compression: 0.395257
# Article 434:	Compression: 0.382844	Avg Compression: 0.395202
# Article 435:	Compression: 7.192708	Avg Compression: 0.395247
# Article 436:	Compression: 0.463860	Avg Compression: 0.395407
# Article 437:	Compression: 0.432903	Avg Compression: 0.395558
# Article 438:	Compression: 0.448812	Avg Compression: 0.395717
# Article 439:	Compression: 0.501854	Avg Compression: 0.395891
# Article 440:	Compression: 0.487048	Avg Compression: 0.396081
# Article 441:	Compression: 0.502964	Avg Compression: 0.396213
# Article 442:	Compression: 0.348959	Avg Compression: 0.395829
# Article 443:	Compression: 0.354457	Avg Compression: 0.395775
# Article 444:	Compression: 0.376842	Avg Compression: 0.395574
# Article 445:	Compression: 0.937702	Avg Compression: 0.395664
# Article 446:	Compression: 0.380178	Avg Compression: 0.395616
# Article 447:	Compression: 4.506410	Avg Compression: 0.395659
# Article 448:	Compression: 8.606250	Avg Compression: 0.395703
# Article 449:	Compression: 0.335549	Avg Compression: 0.395479
# Article 450:	Compression: 0.695986	Avg Compression: 0.395608
# Article 451:	Compression: 0.424485	Avg Compression: 0.395658
# Article 452:	Compression: 4.902778	Avg Compression: 0.395701
# Article 453:	Compression: 0.391229	Avg Compression: 0.395685
# Article 454:	Compression: 0.491720	Avg Compression: 0.395725
# Article 455:	Compression: 0.540013	Avg Compression: 0.395814
# Article 456:	Compression: 4.894737	Avg Compression: 0.395860
# Article 457:	Compression: 6.214286	Avg Compression: 0.395903
# Article 458:	Compression: 6.214286	Avg Compression: 0.395946
# Article 459:	Compression: 0.406076	Avg Compression: 0.395953
# Article 460:	Compression: 0.415395	Avg Compression: 0.395969
# Article 461:	Compression: 0.366216	Avg Compression: 0.395831
# Article 462:	Compression: 6.532407	Avg Compression: 0.395874
# Article 463:	Compression: 0.389762	Avg Compression: 0.395856
# Article 464:	Compression: 7.302083	Avg Compression: 0.395899
# Article 465:	Compression: 7.333333	Avg Compression: 0.395943
# Article 466:	Compression: 0.349278	Avg Compression: 0.395635
# Article 467:	Compression: 0.409923	Avg Compression: 0.395691
# Article 468:	Compression: 0.484279	Avg Compression: 0.395751
# Article 469:	Compression: 0.350993	Avg Compression: 0.395693
# Article 470:	Compression: 0.399117	Avg Compression: 0.395697
# Article 471:	Compression: 0.697051	Avg Compression: 0.395767
# Article 472:	Compression: 0.528036	Avg Compression: 0.395829
# Article 473:	Compression: 7.260417	Avg Compression: 0.395872
# Article 474:	Compression: 7.260417	Avg Compression: 0.395914
# Article 475:	Compression: 7.260417	Avg Compression: 0.395957
# Article 476:	Compression: 7.260417	Avg Compression: 0.396000
# Article 477:	Compression: 7.260417	Avg Compression: 0.396042
# Article 478:	Compression: 7.260417	Avg Compression: 0.396085
# Article 479:	Compression: 7.260417	Avg Compression: 0.396128
# Article 480:	Compression: 7.260417	Avg Compression: 0.396170
# Article 481:	Compression: 7.260417	Avg Compression: 0.396213
# Article 482:	Compression: 7.260417	Avg Compression: 0.396256
# Article 483:	Compression: 7.260417	Avg Compression: 0.396298
# Article 484:	Compression: 7.260417	Avg Compression: 0.396341
# Article 485:	Compression: 0.446988	Avg Compression: 0.396346
# Article 486:	Compression: 0.420917	Avg Compression: 0.396403
# Article 487:	Compression: 0.429529	Avg Compression: 0.396454
# Article 488:	Compression: 0.447354	Avg Compression: 0.396466
# Article 489:	Compression: 0.348657	Avg Compression: 0.396176
# Article 490:	Compression: 0.547611	Avg Compression: 0.396262
# Article 491:	Compression: 0.465443	Avg Compression: 0.396380
# Article 492:	Compression: 0.518615	Avg Compression: 0.396542
# Article 493:	Compression: 0.405098	Avg Compression: 0.396550
# Article 494:	Compression: 6.711538	Avg Compression: 0.396592
# Article 495:	Compression: 0.532144	Avg Compression: 0.396754
# Article 496:	Compression: 5.608871	Avg Compression: 0.396795
# Article 497:	Compression: 1.493794	Avg Compression: 0.396874
# Article 498:	Compression: 0.479145	Avg Compression: 0.396915
# Article 499:	Compression: 0.382727	Avg Compression: 0.396911
# Article 500:	Compression: 0.535150	Avg Compression: 0.396957
# Article 501:	Compression: 4.949324	Avg Compression: 0.397000
# Article 502:	Compression: 0.452415	Avg Compression: 0.397040
# Article 503:	Compression: 5.685484	Avg Compression: 0.397081
# Article 504:	Compression: 0.440496	Avg Compression: 0.397142
# Article 505:	Compression: 7.223958	Avg Compression: 0.397183
# Article 506:	Compression: 0.376818	Avg Compression: 0.397140
# Article 507:	Compression: 5.535156	Avg Compression: 0.397181
# Article 508:	Compression: 0.427698	Avg Compression: 0.397217
# Article 509:	Compression: 0.416891	Avg Compression: 0.397240
# Article 510:	Compression: 0.384063	Avg Compression: 0.397199
# Article 511:	Compression: 7.223958	Avg Compression: 0.397240
