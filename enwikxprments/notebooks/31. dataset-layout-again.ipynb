# %%
import itertools
import math
import os

import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds

physical_devices = tf.config.list_physical_devices('GPU')
for physical_device in physical_devices:
    tf.config.experimental.set_memory_growth(physical_device, enable=True)

# %%
TYPE=np.int16

subword_text_encoder = tfds.features.text.SubwordTextEncoder.load_from_file('vocab_4096')

class Articles:
    EMPTY_ARTICLE = np.array([], dtype=TYPE) # used for padding
    
    def __init__(self, path):
        with open(path, 'rb') as text_file:
            data = text_file.read()

        self.articles = set(data.split(b'\0'))
        self._encoded_articles = None

    @property
    def encoded_articles(self):
        if self._encoded_articles == None:
            articles = [np.array(subword_text_encoder.encode(article), dtype=TYPE) for article in self.articles]
            self._encoded_articles = sorted(articles, key=len)
        
        return self._encoded_articles

    def articles_generator(self, batch_size = 1, start = 0, end = None):
        end = end or len(self.encoded_articles)

        for _ in range(batch_size - ((end - start - 1) % batch_size + 1)):
            yield self.EMPTY_ARTICLE

        for article in itertools.islice(self.encoded_articles, start, end):
            yield article

    def subbatch_generator(self, batch_size, batch_length, start = 0, end = None):
        end = end or len(self.encoded_articles)

        dataset = tf.data.Dataset.from_generator(self.articles_generator, args=(batch_size, start, end), output_types=TYPE)
        dataset = dataset.padded_batch(batch_size, padded_shapes=([None]), drop_remainder=True)
        dataset = dataset.shuffle(100)

        for batch in dataset.as_numpy_iterator():
            remaining = batch
            while remaining.shape[1] > batch_length + 1:
                yield remaining[:, :batch_length + 1]
                remaining = remaining[:, batch_length:]

            yield remaining
            if remaining.shape[1] == batch_length + 1:
                yield np.zeros((batch_size, 2), dtype=TYPE)

    def steps(self, batch_size, batch_length):
        articles = self.articles_generator(batch_size, batch_length)
        return sum(math.ceil(len(article) / batch_length) for i, article in enumerate(articles) if (i + 1) % batch_size == 0)

    def dataset(self, batch_size, batch_length, start = 0, end = None):
        end = end or len(self.encoded_articles)

        dataset = tf.data.Dataset.from_generator(self.subbatch_generator, args=(batch_size, batch_length, start, end), output_types=TYPE, output_shapes=(batch_size, None))
        return dataset.map(lambda batch: (batch[:, :-1], batch[:, 1:]))

# %%
articles = Articles('page_revisions_text')

# %%
BATCH_SIZE = 2048
BATCHED_ITEM_LENGTH = 32

def build_model(vocab_size, embedding_dim, rnn_units):
    return tf.keras.Sequential([
        tf.keras.layers.Masking(mask_value=0, batch_input_shape=[BATCH_SIZE, None]),
        tf.keras.layers.Embedding(vocab_size, embedding_dim),
        tf.keras.layers.GRU(rnn_units, return_sequences=True, stateful=True, recurrent_initializer='glorot_uniform'),
        tf.keras.layers.GRU(rnn_units, return_sequences=True, stateful=True, recurrent_initializer='glorot_uniform'),
        tf.keras.layers.Dense(vocab_size),
    ])

checkpoint_dir = './training_checkpoints-4' # Directory where the checkpoints will be saved
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt_{epoch}") # Name of the checkpoint files

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_prefix, save_weights_only=True)

class ModelStateResetter(tf.keras.callbacks.Callback):
    def __init__(self):
        pass

    def on_epoch_begin(self, epoch, logs=None):
        self.last_total_length = 0
        
    def on_batch_end(self, batch, logs={}):
        average_batch_length = logs.get('average_batch_length', 0)
        total_length = int(round(average_batch_length * (batch + 1)))
        current_batch_length = total_length - self.last_total_length
        self.last_total_length = total_length
        
        if current_batch_length < BATCHED_ITEM_LENGTH:
            self.model.reset_states()
        
model_state_resetter_callback = ModelStateResetter()

def loss(labels, logits):
    return tf.keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)

def average_batch_length(true_labels, predictions):
    return tf.shape(true_labels)[1]

# %%
model = build_model(vocab_size = subword_text_encoder.vocab_size, embedding_dim=64, rnn_units=768)
# model.load_weights(tf.train.latest_checkpoint(checkpoint_dir))
model.compile(optimizer='adam', loss=loss, metrics=[average_batch_length])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# masking_1 (Masking)          (2048, None)              0
# _________________________________________________________________
# embedding_1 (Embedding)      (2048, None, 64)          259072
# _________________________________________________________________
# gru_2 (GRU)                  (2048, None, 768)         1921536
# _________________________________________________________________
# gru_3 (GRU)                  (2048, None, 768)         3543552
# _________________________________________________________________
# dense_1 (Dense)              (2048, None, 4048)        3112912
# =================================================================
# Total params: 8,837,072
# Trainable params: 8,837,072
# Non-trainable params: 0
# _________________________________________________________________

# %%
dataset = articles.dataset(BATCH_SIZE, BATCHED_ITEM_LENGTH)
callbacks = [checkpoint_callback, model_state_resetter_callback]
model.fit(dataset, epochs=5, callbacks=callbacks)
# Out:
# Epoch 1/5
# 14061/14061 [==============================] - 8861s 630ms/step - loss: 1.2865 - average_batch_length: 31.8675
# Epoch 2/5
# 14061/14061 [==============================] - 8639s 614ms/step - loss: 1.0624 - average_batch_length: 31.8675
# Epoch 3/5
# 14061/14061 [==============================] - 8566s 609ms/step - loss: 1.0157 - average_batch_length: 31.8675
# Epoch 4/5
# 14061/14061 [==============================] - 8563s 609ms/step - loss: 0.9705 - average_batch_length: 31.8675
# Epoch 5/5
# 14061/14061 [==============================] - 8566s 609ms/step - loss: 0.9451 - average_batch_length: 31.8675

# %%
dataset = articles.dataset(BATCH_SIZE, BATCHED_ITEM_LENGTH)
callbacks = [checkpoint_callback, model_state_resetter_callback]
model.fit(dataset, epochs=5, callbacks=callbacks)
# Out:
# Epoch 1/5
# 14061/14061 [==============================] - 9751s 694ms/step - loss: 0.9495 - average_batch_length: 31.8675
# Epoch 2/5
#   626/14061 [>.............................] - ETA: 2:44:04 - loss: 2.4925 - average_batch_length: 31.8291

# %%
dataset = articles.dataset(BATCH_SIZE, BATCHED_ITEM_LENGTH)
callbacks = [checkpoint_callback, model_state_resetter_callback]
model.fit(dataset, epochs=4, callbacks=callbacks)
# Out:
# Epoch 1/4
# 14061/14061 [==============================] - 9831s 699ms/step - loss: 0.9230 - average_batch_length: 31.8675
# Epoch 2/4
# 14061/14061 [==============================] - 9802s 697ms/step - loss: 0.9251 - average_batch_length: 31.8675
# Epoch 3/4
# 14061/14061 [==============================] - 9840s 700ms/step - loss: 0.9114 - average_batch_length: 31.8675
# Epoch 4/4
# 14061/14061 [==============================] - 9701s 690ms/step - loss: 0.9345 - average_batch_length: 31.8675

# %%
dataset = articles.dataset(BATCH_SIZE, BATCHED_ITEM_LENGTH)
callbacks = [checkpoint_callback, model_state_resetter_callback]
model.fit(dataset, epochs=2, callbacks=callbacks)
# Out:
# Epoch 1/2
# 14061/14061 [==============================] - 8591s 611ms/step - loss: 0.9249 - average_batch_length: 31.8675
# Epoch 2/2
# 12609/14061 [=========================>....] - ETA: 14:43 - loss: 0.7356 - average_batch_length: 31.8943

# %%
dataset = articles.dataset(BATCH_SIZE, BATCHED_ITEM_LENGTH)
callbacks = [checkpoint_callback, model_state_resetter_callback]
model.fit(dataset, epochs=2, callbacks=callbacks)
# Out:
# Epoch 1/2
# 14061/14061 [==============================] - 8820s 627ms/step - loss: 0.9137 - average_batch_length: 31.8675
# Epoch 2/2
# 14061/14061 [==============================] - 8828s 628ms/step - loss: 0.9092 - average_batch_length: 31.8675

# %% [markdown]
# До тук добре. Числото изглежда много подобно на това, което сме виждали в предишни тетрадки с различен код, но при идентични параметри.
#
# Да видим до каква компресия ще доведе този `loss`.

# %%
def build_predicting_model(vocab_size, embedding_dim, rnn_units):
    return tf.keras.Sequential([
        tf.keras.layers.Masking(mask_value=0, batch_input_shape=[1, 1]),
        tf.keras.layers.Embedding(vocab_size, embedding_dim),
        tf.keras.layers.GRU(rnn_units, stateful=True, return_sequences=True),
        tf.keras.layers.GRU(rnn_units, stateful=True, return_sequences=True),
        tf.keras.layers.Dense(vocab_size),
    ])

model = build_predicting_model(vocab_size = subword_text_encoder.vocab_size, embedding_dim=64, rnn_units=768)
model.load_weights(tf.train.latest_checkpoint(checkpoint_dir))
model.build(tf.TensorShape([1, 1]))

# %%
import ctypes

class Huffman:
    huffman = ctypes.CDLL('x64/Release/huffman')
    
    huffman.create_tree.restype = ctypes.c_void_p
    huffman.destroy_tree.restype = None
    huffman.load_weights.restype = None
    huffman.create_code_string.restype = ctypes.c_char_p
    
    def __init__(self, category_count):
        self.tree = ctypes.c_void_p(self.huffman.create_tree(category_count))

    def __del__(self):
        self.huffman.destroy_tree(self.tree)
        
    def load_weights(self, weights):
        self.huffman.load_weights(self.tree, weights.ctypes.data_as(ctypes.POINTER(ctypes.c_float)))
    
    def get_code_length(self, category):
        return self.huffman.get_code_length(self.tree, category)

    def get_code_zero_count(self, category):
        return self.huffman.get_code_zero_count(self.tree, category)

# %%
def huffman_archive_size(model, text):
    archived_size = 0
    zeros = 0
    input_eval = np.array([[0]], dtype=TYPE)
    huffman_tree = Huffman(subword_text_encoder.vocab_size)

    text_generated = []

    model.reset_states()

    for index, byte in enumerate(text):
        predictions = model(input_eval)
        predictions = tf.squeeze(predictions, 0) # remove the batch dimension

        weights = tf.nn.softmax(predictions[0]).numpy()
        huffman_tree.load_weights(weights)
        zeros += huffman_tree.get_code_zero_count(byte.item())
        archived_size += huffman_tree.get_code_length(byte.item())

        input_eval = tf.expand_dims([byte], 0)
  
    return archived_size, zeros

# %%
total_raw = 0
total_compressed = 0

for index, encoded_article in enumerate(articles.articles_generator(1)):
    if index % 1000 == 0:
        article = subword_text_encoder.decode(encoded_article)
        raw = len(article) * 8
        if raw == 0:
            continue
        compressed, _ = huffman_archive_size(model, encoded_article)
        total_raw += raw
        total_compressed += compressed

        print('Article %d:\tLength: %d\tCompression: %f\tAvg Compression: %f' % (index, raw, compressed/raw, total_compressed/total_raw))
# Out:
# Article 1000:	Length: 136	Compression: 0.610294	Avg Compression: 0.610294
# Article 2000:	Length: 152	Compression: 0.513158	Avg Compression: 0.559028
# Article 3000:	Length: 160	Compression: 0.543750	Avg Compression: 0.553571
# Article 4000:	Length: 216	Compression: 0.407407	Avg Compression: 0.506024
# Article 5000:	Length: 160	Compression: 0.493750	Avg Compression: 0.503641
# Article 6000:	Length: 192	Compression: 0.515625	Avg Compression: 0.505906
# Article 7000:	Length: 184	Compression: 0.445652	Avg Compression: 0.496667
# Article 8000:	Length: 216	Compression: 0.398148	Avg Compression: 0.481638
# Article 9000:	Length: 152	Compression: 0.598684	Avg Compression: 0.492985
# Article 10000:	Length: 184	Compression: 0.467391	Avg Compression: 0.490297
# Article 11000:	Length: 200	Compression: 0.460000	Avg Compression: 0.487193
# Article 12000:	Length: 176	Compression: 0.500000	Avg Compression: 0.488252
# Article 13000:	Length: 224	Compression: 0.361607	Avg Compression: 0.476190
# Article 14000:	Length: 256	Compression: 0.312500	Avg Compression: 0.460123
# Article 15000:	Length: 208	Compression: 0.408654	Avg Compression: 0.456321
# Article 16000:	Length: 216	Compression: 0.430556	Avg Compression: 0.454485
# Article 17000:	Length: 184	Compression: 0.527174	Avg Compression: 0.458644
# Article 18000:	Length: 200	Compression: 0.410000	Avg Compression: 0.455796
# Article 19000:	Length: 200	Compression: 0.505000	Avg Compression: 0.458518
# Article 20000:	Length: 224	Compression: 0.388393	Avg Compression: 0.454427
# Article 21000:	Length: 200	Compression: 0.515000	Avg Compression: 0.457426
# Article 22000:	Length: 200	Compression: 0.430000	Avg Compression: 0.456132
# Article 23000:	Length: 208	Compression: 0.365385	Avg Compression: 0.451888
# Article 24000:	Length: 200	Compression: 0.495000	Avg Compression: 0.453744
# Article 25000:	Length: 240	Compression: 0.345833	Avg Compression: 0.448445
# Article 26000:	Length: 312	Compression: 0.285256	Avg Compression: 0.438654
# Article 27000:	Length: 232	Compression: 0.362069	Avg Compression: 0.435383
# Article 28000:	Length: 248	Compression: 0.383065	Avg Compression: 0.433099
# Article 29000:	Length: 232	Compression: 0.413793	Avg Compression: 0.432341
# Article 30000:	Length: 208	Compression: 0.403846	Avg Compression: 0.431373
# Article 31000:	Length: 288	Compression: 0.350694	Avg Compression: 0.427747
# Article 32000:	Length: 256	Compression: 0.378906	Avg Compression: 0.425870
# Article 33000:	Length: 320	Compression: 0.303125	Avg Compression: 0.420246
# Article 34000:	Length: 392	Compression: 0.234694	Avg Compression: 0.410385
# Article 35000:	Length: 248	Compression: 0.491935	Avg Compression: 0.413038
# Article 36000:	Length: 368	Compression: 0.282609	Avg Compression: 0.407032
# Article 37000:	Length: 232	Compression: 0.439655	Avg Compression: 0.407952
# Article 38000:	Length: 272	Compression: 0.312500	Avg Compression: 0.404896
# Article 39000:	Length: 328	Compression: 0.259146	Avg Compression: 0.399479
# Article 40000:	Length: 272	Compression: 0.367647	Avg Compression: 0.398527
# Article 41000:	Length: 280	Compression: 0.317857	Avg Compression: 0.396118
# Article 42000:	Length: 312	Compression: 0.358974	Avg Compression: 0.394922
# Article 43000:	Length: 400	Compression: 0.272500	Avg Compression: 0.390067
# Article 44000:	Length: 264	Compression: 0.310606	Avg Compression: 0.388041
# Article 45000:	Length: 432	Compression: 0.231481	Avg Compression: 0.381769
# Article 46000:	Length: 320	Compression: 0.406250	Avg Compression: 0.382475
# Article 47000:	Length: 416	Compression: 0.240385	Avg Compression: 0.377344
# Article 48000:	Length: 376	Compression: 0.281915	Avg Compression: 0.374328
# Article 49000:	Length: 496	Compression: 0.229839	Avg Compression: 0.368544
# Article 50000:	Length: 336	Compression: 0.360119	Avg Compression: 0.368322
# Article 51000:	Length: 360	Compression: 0.386111	Avg Compression: 0.368811
# Article 52000:	Length: 448	Compression: 0.337054	Avg Compression: 0.367760
# Article 53000:	Length: 432	Compression: 0.416667	Avg Compression: 0.369273
# Article 54000:	Length: 472	Compression: 0.343220	Avg Compression: 0.368421
# Article 55000:	Length: 408	Compression: 0.272059	Avg Compression: 0.365773
# Article 56000:	Length: 600	Compression: 0.331667	Avg Compression: 0.364448
# Article 57000:	Length: 816	Compression: 0.161765	Avg Compression: 0.354279
# Article 58000:	Length: 1024	Compression: 0.238281	Avg Compression: 0.347409
# Article 59000:	Length: 1320	Compression: 0.190909	Avg Compression: 0.336307
# Article 60000:	Length: 1288	Compression: 0.272516	Avg Compression: 0.332177
# Article 61000:	Length: 1496	Compression: 0.229278	Avg Compression: 0.324981
# Article 62000:	Length: 1768	Compression: 0.194005	Avg Compression: 0.314983
# Article 63000:	Length: 2176	Compression: 0.252298	Avg Compression: 0.309599
# Article 64000:	Length: 1776	Compression: 0.291667	Avg Compression: 0.308424
# Article 65000:	Length: 2320	Compression: 0.219828	Avg Compression: 0.301441
# Article 66000:	Length: 2472	Compression: 0.167071	Avg Compression: 0.291029
# Article 67000:	Length: 3088	Compression: 0.209197	Avg Compression: 0.283808
# Article 68000:	Length: 2840	Compression: 0.120775	Avg Compression: 0.271569
# Article 69000:	Length: 4456	Compression: 0.079443	Avg Compression: 0.251324
# Article 70000:	Length: 3760	Compression: 0.215426	Avg Compression: 0.248393
# Article 71000:	Length: 4776	Compression: 0.160176	Avg Compression: 0.240103
# Article 72000:	Length: 4064	Compression: 0.206201	Avg Compression: 0.237593
# Article 73000:	Length: 4656	Compression: 0.282861	Avg Compression: 0.241133
# Article 74000:	Length: 4648	Compression: 0.236876	Avg Compression: 0.240824
# Article 75000:	Length: 4880	Compression: 0.186270	Avg Compression: 0.236970
# Article 76000:	Length: 5352	Compression: 0.198244	Avg Compression: 0.234185
# Article 77000:	Length: 6352	Compression: 0.181675	Avg Compression: 0.230056
# Article 78000:	Length: 5704	Compression: 0.268583	Avg Compression: 0.232597
# Article 79000:	Length: 6168	Compression: 0.220979	Avg Compression: 0.231824
# Article 80000:	Length: 6032	Compression: 0.176724	Avg Compression: 0.228456
# Article 81000:	Length: 7568	Compression: 0.212870	Avg Compression: 0.227345
# Article 82000:	Length: 7520	Compression: 0.214495	Avg Compression: 0.226496
# Article 83000:	Length: 8384	Compression: 0.188335	Avg Compression: 0.223877
# Article 84000:	Length: 8120	Compression: 0.151724	Avg Compression: 0.219379
# Article 85000:	Length: 8616	Compression: 0.221448	Avg Compression: 0.219508
# Article 86000:	Length: 6648	Compression: 0.155836	Avg Compression: 0.216599
# Article 87000:	Length: 8448	Compression: 0.164773	Avg Compression: 0.213756
# Article 88000:	Length: 10048	Compression: 0.188296	Avg Compression: 0.212196
# Article 89000:	Length: 7976	Compression: 0.146439	Avg Compression: 0.209147
# Article 90000:	Length: 10424	Compression: 0.191769	Avg Compression: 0.208154
# Article 91000:	Length: 11584	Compression: 0.209858	Avg Compression: 0.208256
# Article 92000:	Length: 9256	Compression: 0.272904	Avg Compression: 0.211200
# Article 93000:	Length: 12896	Compression: 0.104141	Avg Compression: 0.204813
# Article 94000:	Length: 10464	Compression: 0.255161	Avg Compression: 0.207138
# Article 95000:	Length: 12216	Compression: 0.166094	Avg Compression: 0.205038
# Article 96000:	Length: 10424	Compression: 0.294609	Avg Compression: 0.208784
# Article 97000:	Length: 11928	Compression: 0.206824	Avg Compression: 0.208694
# Article 98000:	Length: 12888	Compression: 0.227343	Avg Compression: 0.209571
# Article 99000:	Length: 13344	Compression: 0.178132	Avg Compression: 0.208112
# Article 100000:	Length: 13528	Compression: 0.204095	Avg Compression: 0.207931
# Article 101000:	Length: 13000	Compression: 0.223231	Avg Compression: 0.208565
# Article 102000:	Length: 11536	Compression: 0.157854	Avg Compression: 0.206768
# Article 103000:	Length: 15392	Compression: 0.184317	Avg Compression: 0.205754
# Article 104000:	Length: 16832	Compression: 0.195877	Avg Compression: 0.205289
# Article 105000:	Length: 19680	Compression: 0.061077	Avg Compression: 0.197769
# Article 106000:	Length: 18024	Compression: 0.168387	Avg Compression: 0.196430
# Article 107000:	Length: 19720	Compression: 0.067343	Avg Compression: 0.190298
# Article 108000:	Length: 16360	Compression: 0.206724	Avg Compression: 0.190921
# Article 109000:	Length: 20120	Compression: 0.060984	Avg Compression: 0.185132
# Article 110000:	Length: 19760	Compression: 0.063765	Avg Compression: 0.180044
# Article 111000:	Length: 20480	Compression: 0.064795	Avg Compression: 0.175246
# Article 112000:	Length: 14104	Compression: 0.138968	Avg Compression: 0.174234
# Article 113000:	Length: 20296	Compression: 0.066860	Avg Compression: 0.170093
# Article 114000:	Length: 20736	Compression: 0.067998	Avg Compression: 0.166223
# Article 115000:	Length: 20920	Compression: 0.077151	Avg Compression: 0.162942
# Article 116000:	Length: 20864	Compression: 0.072326	Avg Compression: 0.159731
# Article 117000:	Length: 21208	Compression: 0.067239	Avg Compression: 0.156515
# Article 118000:	Length: 20832	Compression: 0.074837	Avg Compression: 0.153818
# Article 119000:	Length: 21152	Compression: 0.071861	Avg Compression: 0.151159
# Article 120000:	Length: 21136	Compression: 0.071253	Avg Compression: 0.148650
# Article 121000:	Length: 21240	Compression: 0.075518	Avg Compression: 0.146413
# Article 122000:	Length: 20864	Compression: 0.072278	Avg Compression: 0.144250
# Article 123000:	Length: 20976	Compression: 0.072797	Avg Compression: 0.142214
# Article 124000:	Length: 21080	Compression: 0.078985	Avg Compression: 0.140454
# Article 125000:	Length: 15232	Compression: 0.263918	Avg Compression: 0.142889
# Article 126000:	Length: 21680	Compression: 0.079566	Avg Compression: 0.141160
# Article 127000:	Length: 21712	Compression: 0.073416	Avg Compression: 0.139357
# Article 128000:	Length: 21432	Compression: 0.072695	Avg Compression: 0.137651
# Article 129000:	Length: 21728	Compression: 0.082704	Avg Compression: 0.136261
# Article 130000:	Length: 21632	Compression: 0.078726	Avg Compression: 0.134848
# Article 131000:	Length: 22200	Compression: 0.075135	Avg Compression: 0.133380
# Article 132000:	Length: 21848	Compression: 0.075888	Avg Compression: 0.132021
# Article 133000:	Length: 17792	Compression: 0.208577	Avg Compression: 0.133467
# Article 134000:	Length: 22520	Compression: 0.074734	Avg Compression: 0.132096
# Article 135000:	Length: 21072	Compression: 0.175304	Avg Compression: 0.133019
# Article 136000:	Length: 22656	Compression: 0.077331	Avg Compression: 0.131769
# Article 137000:	Length: 20880	Compression: 0.204885	Avg Compression: 0.133251
# Article 138000:	Length: 23968	Compression: 0.080232	Avg Compression: 0.132045
# Article 139000:	Length: 23712	Compression: 0.084008	Avg Compression: 0.130988
# Article 140000:	Length: 23216	Compression: 0.079471	Avg Compression: 0.129901
# Article 141000:	Length: 22088	Compression: 0.177246	Avg Compression: 0.130833
# Article 142000:	Length: 24456	Compression: 0.171451	Avg Compression: 0.131699
# Article 143000:	Length: 17416	Compression: 0.241272	Avg Compression: 0.133337
# Article 144000:	Length: 23232	Compression: 0.199251	Avg Compression: 0.134627
# Article 145000:	Length: 22296	Compression: 0.148053	Avg Compression: 0.134874
# Article 146000:	Length: 24168	Compression: 0.201506	Avg Compression: 0.136179
# Article 147000:	Length: 21544	Compression: 0.229298	Avg Compression: 0.137776
# Article 148000:	Length: 23944	Compression: 0.166639	Avg Compression: 0.138316
# Article 149000:	Length: 22056	Compression: 0.225925	Avg Compression: 0.139801
# Article 150000:	Length: 28704	Compression: 0.095736	Avg Compression: 0.138850
# Article 151000:	Length: 29024	Compression: 0.084516	Avg Compression: 0.137690
# Article 152000:	Length: 23424	Compression: 0.215377	Avg Compression: 0.139006
# Article 153000:	Length: 26000	Compression: 0.213654	Avg Compression: 0.140384
# Article 154000:	Length: 23912	Compression: 0.165356	Avg Compression: 0.140800
# Article 155000:	Length: 31928	Compression: 0.095058	Avg Compression: 0.139803
# Article 156000:	Length: 25552	Compression: 0.290623	Avg Compression: 0.142389
# Article 157000:	Length: 31968	Compression: 0.169294	Avg Compression: 0.142954
# Article 158000:	Length: 31960	Compression: 0.084950	Avg Compression: 0.141761
# Article 159000:	Length: 32200	Compression: 0.095497	Avg Compression: 0.140822
# Article 160000:	Length: 27216	Compression: 0.134810	Avg Compression: 0.140721
# Article 161000:	Length: 31800	Compression: 0.195723	Avg Compression: 0.141784
# Article 162000:	Length: 27032	Compression: 0.225843	Avg Compression: 0.143143
# Article 163000:	Length: 31328	Compression: 0.226698	Avg Compression: 0.144679
# Article 164000:	Length: 29448	Compression: 0.201134	Avg Compression: 0.145638
# Article 165000:	Length: 32320	Compression: 0.225186	Avg Compression: 0.147094
# Article 166000:	Length: 37624	Compression: 0.194876	Avg Compression: 0.148091
# Article 167000:	Length: 31848	Compression: 0.147231	Avg Compression: 0.148076
# Article 168000:	Length: 34904	Compression: 0.182415	Avg Compression: 0.148717
# Article 169000:	Length: 38616	Compression: 0.133494	Avg Compression: 0.148409
# Article 170000:	Length: 37944	Compression: 0.178763	Avg Compression: 0.149001
# Article 171000:	Length: 38528	Compression: 0.218724	Avg Compression: 0.150354
# Article 172000:	Length: 38584	Compression: 0.204126	Avg Compression: 0.151380
# Article 173000:	Length: 39424	Compression: 0.241097	Avg Compression: 0.153094
# Article 174000:	Length: 40064	Compression: 0.200704	Avg Compression: 0.154001
# Article 175000:	Length: 36800	Compression: 0.234429	Avg Compression: 0.155384
# Article 176000:	Length: 43000	Compression: 0.134907	Avg Compression: 0.154981
# Article 177000:	Length: 39800	Compression: 0.206231	Avg Compression: 0.155898
# Article 178000:	Length: 46040	Compression: 0.194027	Avg Compression: 0.156672
# Article 179000:	Length: 47008	Compression: 0.198243	Avg Compression: 0.157516
# Article 180000:	Length: 52528	Compression: 0.136594	Avg Compression: 0.157052
# Article 181000:	Length: 42848	Compression: 0.209391	Avg Compression: 0.157982
# Article 182000:	Length: 53072	Compression: 0.187839	Avg Compression: 0.158625
# Article 183000:	Length: 47624	Compression: 0.205149	Avg Compression: 0.159507
# Article 184000:	Length: 48320	Compression: 0.207699	Avg Compression: 0.160417
# Article 185000:	Length: 55552	Compression: 0.167609	Avg Compression: 0.160570
# Article 186000:	Length: 57528	Compression: 0.163833	Avg Compression: 0.160640
# Article 187000:	Length: 56784	Compression: 0.189613	Avg Compression: 0.161242
# Article 188000:	Length: 58728	Compression: 0.197487	Avg Compression: 0.162006
# Article 189000:	Length: 63368	Compression: 0.211668	Avg Compression: 0.163109
# Article 190000:	Length: 59128	Compression: 0.232293	Avg Compression: 0.164514
# Article 191000:	Length: 61160	Compression: 0.232358	Avg Compression: 0.165910
# Article 192000:	Length: 69696	Compression: 0.187400	Avg Compression: 0.166402
# Article 193000:	Length: 71816	Compression: 0.194079	Avg Compression: 0.167041
# Article 194000:	Length: 69264	Compression: 0.227824	Avg Compression: 0.168363
# Article 195000:	Length: 67944	Compression: 0.217164	Avg Compression: 0.169383
# Article 196000:	Length: 79864	Compression: 0.173345	Avg Compression: 0.169478
# Article 197000:	Length: 83080	Compression: 0.176324	Avg Compression: 0.169645
# Article 198000:	Length: 91784	Compression: 0.170956	Avg Compression: 0.169679
# Article 199000:	Length: 69160	Compression: 0.226692	Avg Compression: 0.170782
# Article 200000:	Length: 90112	Compression: 0.161910	Avg Compression: 0.170564
# Article 201000:	Length: 91024	Compression: 0.217657	Avg Compression: 0.171705
# Article 202000:	Length: 89792	Compression: 0.204539	Avg Compression: 0.172472
# Article 203000:	Length: 89568	Compression: 0.199390	Avg Compression: 0.173084
# Article 204000:	Length: 108216	Compression: 0.204739	Avg Compression: 0.173932
# Article 205000:	Length: 106360	Compression: 0.200291	Avg Compression: 0.174607
# Article 206000:	Length: 103816	Compression: 0.249239	Avg Compression: 0.176428
# Article 207000:	Length: 109464	Compression: 0.217414	Avg Compression: 0.177457
# Article 208000:	Length: 132000	Compression: 0.165992	Avg Compression: 0.177120
# Article 209000:	Length: 139872	Compression: 0.206596	Avg Compression: 0.178010
# Article 210000:	Length: 141464	Compression: 0.201429	Avg Compression: 0.178703
# Article 211000:	Length: 147064	Compression: 0.219517	Avg Compression: 0.179922
# Article 212000:	Length: 152616	Compression: 0.201696	Avg Compression: 0.180577
# Article 213000:	Length: 172760	Compression: 0.193940	Avg Compression: 0.181017
# Article 214000:	Length: 163000	Compression: 0.255344	Avg Compression: 0.183255
# Article 215000:	Length: 191240	Compression: 0.202860	Avg Compression: 0.183924
# Article 216000:	Length: 168272	Compression: 0.131400	Avg Compression: 0.182393
# Article 217000:	Length: 240448	Compression: 0.195389	Avg Compression: 0.182913
# Article 218000:	Length: 283136	Compression: 0.199554	Avg Compression: 0.183661
# Article 219000:	Length: 347320	Compression: 0.189739	Avg Compression: 0.183979
# Article 220000:	Length: 461312	Compression: 0.239456	Avg Compression: 0.187582

# %%
model = build_model(vocab_size = subword_text_encoder.vocab_size, embedding_dim=64, rnn_units=768)
model.load_weights(tf.train.latest_checkpoint(checkpoint_dir))
model.compile(optimizer='adam', loss=loss, metrics=[average_batch_length])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# masking_3 (Masking)          (2048, None)              0
# _________________________________________________________________
# embedding_3 (Embedding)      (2048, None, 64)          259072
# _________________________________________________________________
# gru_6 (GRU)                  (2048, None, 768)         1921536
# _________________________________________________________________
# gru_7 (GRU)                  (2048, None, 768)         3543552
# _________________________________________________________________
# dense_3 (Dense)              (2048, None, 4048)        3112912
# =================================================================
# Total params: 8,837,072
# Trainable params: 8,837,072
# Non-trainable params: 0
# _________________________________________________________________

# %%
dataset = articles.dataset(BATCH_SIZE, BATCHED_ITEM_LENGTH)
callbacks = [checkpoint_callback, model_state_resetter_callback]
model.fit(dataset, epochs=10, callbacks=callbacks)
# Out:
# Epoch 1/10
# 14061/14061 [==============================] - 8572s 610ms/step - loss: 0.9029 - average_batch_length: 31.8675
# Epoch 2/10
# 14060/14061 [============================>.] - ETA: 0s - loss: 0.8871 - average_batch_length: 31.8691
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# <ipython-input-15-3bd22bd965d7> in <module>
#       1 dataset = articles.dataset(BATCH_SIZE, BATCHED_ITEM_LENGTH)
#       2 callbacks = [checkpoint_callback, model_state_resetter_callback]
# ----> 3 model.fit(dataset, epochs=10, callbacks=callbacks)
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     395                       total_epochs=1)
#     396                   cbks.make_logs(model, epoch_logs, eval_result, ModeKeys.TEST,
# --> 397                                  prefix='val_')
#     398
#     399     return model.history
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in on_epoch(self, epoch, mode)
#     769       if mode == ModeKeys.TRAIN:
#     770         # Epochs only apply to `fit`.
# --> 771         self.callbacks.on_epoch_end(epoch, epoch_logs)
#     772       self.progbar.on_epoch_end(epoch, epoch_logs)
#     773
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     300     logs = logs or {}
#     301     for callback in self.callbacks:
# --> 302       callback.on_epoch_end(epoch, logs)
#     303
#     304   def on_train_batch_begin(self, batch, logs=None):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     990           self._save_model(epoch=epoch, logs=logs)
#     991       else:
# --> 992         self._save_model(epoch=epoch, logs=logs)
#     993     if self.model._in_multi_worker_mode():
#     994       # For multi-worker training, back up the weights and current training
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\callbacks.py in _save_model(self, epoch, logs)
#    1036             print('\nEpoch %05d: saving model to %s' % (epoch + 1, filepath))
#    1037           if self.save_weights_only:
# -> 1038             self.model.save_weights(filepath, overwrite=True)
#    1039           else:
#    1040             self.model.save(filepath, overwrite=True)
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\network.py in save_weights(self, filepath, overwrite, save_format)
#    1121              'saved.\n\nConsider using a TensorFlow optimizer from `tf.train`.')
#    1122             % (optimizer,))
# -> 1123       self._trackable_saver.save(filepath, session=session)
#    1124       # Record this checkpoint so it's visible from tf.train.latest_checkpoint.
#    1125       checkpoint_management.update_checkpoint_state_internal(
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\tracking\util.py in save(self, file_prefix, checkpoint_number, session)
#    1166     file_io.recursive_create_dir(os.path.dirname(file_prefix))
#    1167     save_path, new_feed_additions = self._save_cached_when_graph_building(
# -> 1168         file_prefix=file_prefix_tensor, object_graph_tensor=object_graph_tensor)
#    1169     if new_feed_additions:
#    1170       feed_dict.update(new_feed_additions)
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\tracking\util.py in _save_cached_when_graph_building(self, file_prefix, object_graph_tensor)
#    1114         or context.executing_eagerly() or ops.inside_function()):
#    1115       saver = functional_saver.MultiDeviceSaver(named_saveable_objects)
# -> 1116       save_op = saver.save(file_prefix)
#    1117       with ops.device("/cpu:0"):
#    1118         with ops.control_dependencies([save_op]):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\functional_saver.py in save(self, file_prefix)
#     236         # attempts to delete the temporary directory, "<user-fed prefix>_temp".
#     237         return gen_io_ops.merge_v2_checkpoints(
# --> 238             sharded_prefixes, file_prefix, delete_old_dirs=True)
#     239
#     240   def restore(self, file_prefix):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\ops\gen_io_ops.py in merge_v2_checkpoints(checkpoint_prefixes, destination_prefix, delete_old_dirs, name)
#     497         return merge_v2_checkpoints_eager_fallback(
#     498             checkpoint_prefixes, destination_prefix,
# --> 499             delete_old_dirs=delete_old_dirs, name=name, ctx=_ctx)
#     500       except _core._SymbolicException:
#     501         pass  # Add nodes to the TensorFlow graph.
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\ops\gen_io_ops.py in merge_v2_checkpoints_eager_fallback(checkpoint_prefixes, destination_prefix, delete_old_dirs, name, ctx)
#     523   _attrs = ("delete_old_dirs", delete_old_dirs)
#     524   _result = _execute.execute(b"MergeV2Checkpoints", 0, inputs=_inputs_flat,
# --> 525                              attrs=_attrs, ctx=ctx, name=name)
#     526   _result = None
#     527   return _result
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      65     else:
#      66       message = e.message
# ---> 67     six.raise_from(core._status_to_exception(e.code, message), None)
#      68   except TypeError as e:
#      69     keras_symbolic_tensors = [
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\six.py in raise_from(value, from_value)
#
# UnknownError: Failed to rename: ./training_checkpoints-4\ckpt_2_temp_18191358c68149299289797b0f08c481/part-00000-of-00002.data-00000-of-00001 to: ./training_checkpoints-4\ckpt_2.data-00000-of-00002 : Access is denied.
# ; Input/output error [Op:MergeV2Checkpoints]

# %%
dataset = articles.dataset(BATCH_SIZE, BATCHED_ITEM_LENGTH)
callbacks = [checkpoint_callback, model_state_resetter_callback]
model.fit(dataset, epochs=8, callbacks=callbacks)
# Out:
# Epoch 1/8
# 14061/14061 [==============================] - 8561s 609ms/step - loss: 0.9156 - average_batch_length: 31.8675
# Epoch 2/8
# 14060/14061 [============================>.] - ETA: 0s - loss: 0.8995 - average_batch_length: 31.8690
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# <ipython-input-16-23c50af393e8> in <module>
#       1 dataset = articles.dataset(BATCH_SIZE, BATCHED_ITEM_LENGTH)
#       2 callbacks = [checkpoint_callback, model_state_resetter_callback]
# ----> 3 model.fit(dataset, epochs=8, callbacks=callbacks)
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     395                       total_epochs=1)
#     396                   cbks.make_logs(model, epoch_logs, eval_result, ModeKeys.TEST,
# --> 397                                  prefix='val_')
#     398
#     399     return model.history
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in on_epoch(self, epoch, mode)
#     769       if mode == ModeKeys.TRAIN:
#     770         # Epochs only apply to `fit`.
# --> 771         self.callbacks.on_epoch_end(epoch, epoch_logs)
#     772       self.progbar.on_epoch_end(epoch, epoch_logs)
#     773
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     300     logs = logs or {}
#     301     for callback in self.callbacks:
# --> 302       callback.on_epoch_end(epoch, logs)
#     303
#     304   def on_train_batch_begin(self, batch, logs=None):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     990           self._save_model(epoch=epoch, logs=logs)
#     991       else:
# --> 992         self._save_model(epoch=epoch, logs=logs)
#     993     if self.model._in_multi_worker_mode():
#     994       # For multi-worker training, back up the weights and current training
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\callbacks.py in _save_model(self, epoch, logs)
#    1036             print('\nEpoch %05d: saving model to %s' % (epoch + 1, filepath))
#    1037           if self.save_weights_only:
# -> 1038             self.model.save_weights(filepath, overwrite=True)
#    1039           else:
#    1040             self.model.save(filepath, overwrite=True)
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\network.py in save_weights(self, filepath, overwrite, save_format)
#    1121              'saved.\n\nConsider using a TensorFlow optimizer from `tf.train`.')
#    1122             % (optimizer,))
# -> 1123       self._trackable_saver.save(filepath, session=session)
#    1124       # Record this checkpoint so it's visible from tf.train.latest_checkpoint.
#    1125       checkpoint_management.update_checkpoint_state_internal(
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\tracking\util.py in save(self, file_prefix, checkpoint_number, session)
#    1166     file_io.recursive_create_dir(os.path.dirname(file_prefix))
#    1167     save_path, new_feed_additions = self._save_cached_when_graph_building(
# -> 1168         file_prefix=file_prefix_tensor, object_graph_tensor=object_graph_tensor)
#    1169     if new_feed_additions:
#    1170       feed_dict.update(new_feed_additions)
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\tracking\util.py in _save_cached_when_graph_building(self, file_prefix, object_graph_tensor)
#    1114         or context.executing_eagerly() or ops.inside_function()):
#    1115       saver = functional_saver.MultiDeviceSaver(named_saveable_objects)
# -> 1116       save_op = saver.save(file_prefix)
#    1117       with ops.device("/cpu:0"):
#    1118         with ops.control_dependencies([save_op]):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\functional_saver.py in save(self, file_prefix)
#     236         # attempts to delete the temporary directory, "<user-fed prefix>_temp".
#     237         return gen_io_ops.merge_v2_checkpoints(
# --> 238             sharded_prefixes, file_prefix, delete_old_dirs=True)
#     239
#     240   def restore(self, file_prefix):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\ops\gen_io_ops.py in merge_v2_checkpoints(checkpoint_prefixes, destination_prefix, delete_old_dirs, name)
#     497         return merge_v2_checkpoints_eager_fallback(
#     498             checkpoint_prefixes, destination_prefix,
# --> 499             delete_old_dirs=delete_old_dirs, name=name, ctx=_ctx)
#     500       except _core._SymbolicException:
#     501         pass  # Add nodes to the TensorFlow graph.
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\ops\gen_io_ops.py in merge_v2_checkpoints_eager_fallback(checkpoint_prefixes, destination_prefix, delete_old_dirs, name, ctx)
#     523   _attrs = ("delete_old_dirs", delete_old_dirs)
#     524   _result = _execute.execute(b"MergeV2Checkpoints", 0, inputs=_inputs_flat,
# --> 525                              attrs=_attrs, ctx=ctx, name=name)
#     526   _result = None
#     527   return _result
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      65     else:
#      66       message = e.message
# ---> 67     six.raise_from(core._status_to_exception(e.code, message), None)
#      68   except TypeError as e:
#      69     keras_symbolic_tensors = [
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\six.py in raise_from(value, from_value)
#
# UnknownError: Failed to rename: ./training_checkpoints-4\ckpt_2_temp_81291d2a6dbe41c1bb6b88bf9a06653c/part-00000-of-00002.data-00000-of-00001 to: ./training_checkpoints-4\ckpt_2.data-00000-of-00002 : Access is denied.
# ; Input/output error [Op:MergeV2Checkpoints]

# %%
checkpoint_dir = './training_checkpoints-5' # Directory where the checkpoints will be saved
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt_{epoch}") # Name of the checkpoint files

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_prefix, save_weights_only=True)

dataset = articles.dataset(BATCH_SIZE, BATCHED_ITEM_LENGTH)
callbacks = [checkpoint_callback, model_state_resetter_callback]
model.fit(dataset, epochs=4, callbacks=callbacks)
# Out:
# Epoch 1/4
# 14061/14061 [==============================] - 8547s 608ms/step - loss: 0.8930 - average_batch_length: 31.8675
# Epoch 2/4
# 14061/14061 [==============================] - 8577s 610ms/step - loss: 0.8991 - average_batch_length: 31.8675
# Epoch 3/4
# 13342/14061 [===========================>..] - ETA: 7:27 - loss: 0.8152 - average_batch_length: 31.8849

# %%
dataset = articles.dataset(BATCH_SIZE, BATCHED_ITEM_LENGTH)
callbacks = [checkpoint_callback, model_state_resetter_callback]
model.fit(dataset, epochs=4, callbacks=callbacks)
# Out:
# Epoch 1/4
# 14061/14061 [==============================] - 8843s 629ms/step - loss: 1.2973 - average_batch_length: 31.8675
# Epoch 2/4
# 14061/14061 [==============================] - 8595s 611ms/step - loss: 1.1844 - average_batch_length: 31.8675
# Epoch 3/4
# 14061/14061 [==============================] - 8574s 610ms/step - loss: 1.0416 - average_batch_length: 31.8675
# Epoch 4/4
# 14061/14061 [==============================] - 8595s 611ms/step - loss: 1.0165 - average_batch_length: 31.8675

# %%
dataset = articles.dataset(BATCH_SIZE, BATCHED_ITEM_LENGTH)
callbacks = [checkpoint_callback, model_state_resetter_callback]
model.fit(dataset, epochs=3, callbacks=callbacks)
# Out:
# Epoch 1/3
# 14061/14061 [==============================] - 8775s 624ms/step - loss: 0.9813 - average_batch_length: 31.8675
# Epoch 2/3
# 14061/14061 [==============================] - 8728s 621ms/step - loss: 0.9657 - average_batch_length: 31.8675
# Epoch 3/3
# 12402/14061 [=========================>....] - ETA: 17:10 - loss: 0.7378 - average_batch_length: 31.9049

# %%
dataset = articles.dataset(BATCH_SIZE, BATCHED_ITEM_LENGTH)
callbacks = [checkpoint_callback, model_state_resetter_callback]
model.fit(dataset, epochs=2, callbacks=callbacks)
# Out:
# Epoch 1/2
# 14061/14061 [==============================] - 8784s 625ms/step - loss: 0.9002 - average_batch_length: 31.8675
# Epoch 2/2
# 14061/14061 [==============================] - 8843s 629ms/step - loss: 0.8970 - average_batch_length: 31.8675

# %%
dataset = articles.dataset(BATCH_SIZE, BATCHED_ITEM_LENGTH)
callbacks = [checkpoint_callback, model_state_resetter_callback]
model.fit(dataset, callbacks=callbacks)
# Out:
# 14061/14061 [==============================] - 8790s 625ms/step - loss: 0.9008 - average_batch_length: 31.8675

# %%
total_raw = 0
total_compressed = 0

for index, encoded_article in enumerate(articles.articles_generator(1)):
    if index % 1000 == 0:
        article = subword_text_encoder.decode(encoded_article)
        raw = len(article) * 8
        if raw == 0:
            continue
        compressed, _ = huffman_archive_size(model, encoded_article)
        total_raw += raw
        total_compressed += compressed

        print('Article %d:\tLength: %d\tCompression: %f\tAvg Compression: %f' % (index, raw, compressed/raw, total_compressed/total_raw))
# Out:
# Article 1000:	Length: 144	Compression: 18.659722	Avg Compression: 18.659722
# Article 2000:	Length: 160	Compression: 16.750000	Avg Compression: 17.654605
# Article 3000:	Length: 176	Compression: 15.369318	Avg Compression: 16.816667
# Article 4000:	Length: 152	Compression: 17.723684	Avg Compression: 17.034810
# Article 5000:	Length: 192	Compression: 13.979167	Avg Compression: 16.322816
# Article 6000:	Length: 216	Compression: 12.472222	Avg Compression: 15.523077
# Article 7000:	Length: 264	Compression: 10.223485	Avg Compression: 14.450153
# Article 8000:	Length: 208	Compression: 13.033654	Avg Compression: 14.255291
# Article 9000:	Length: 216	Compression: 12.435185	Avg Compression: 14.027778
# Article 10000:	Length: 264	Compression: 10.295455	Avg Compression: 13.533133
# Article 11000:	Length: 232	Compression: 11.629310	Avg Compression: 13.334532
# Article 12000:	Length: 192	Compression: 14.119792	Avg Compression: 13.396937
# Article 13000:	Length: 288	Compression: 9.329861	Avg Compression: 12.963757
# Article 14000:	Length: 280	Compression: 9.692857	Avg Compression: 12.656836
# Article 15000:	Length: 184	Compression: 14.586957	Avg Compression: 12.768939
# Article 16000:	Length: 208	Compression: 12.908654	Avg Compression: 12.777547
# Article 17000:	Length: 224	Compression: 12.035714	Avg Compression: 12.731389
# Article 18000:	Length: 232	Compression: 11.607759	Avg Compression: 12.663361
# Article 19000:	Length: 192	Compression: 14.020833	Avg Compression: 12.728131
# Article 20000:	Length: 248	Compression: 10.963710	Avg Compression: 12.625702
# Article 21000:	Length: 224	Compression: 12.142857	Avg Compression: 12.601646
# Article 22000:	Length: 232	Compression: 11.637931	Avg Compression: 12.554357
# Article 23000:	Length: 232	Compression: 11.650862	Avg Compression: 12.512097
# Article 24000:	Length: 200	Compression: 13.515000	Avg Compression: 12.550969
# Article 25000:	Length: 216	Compression: 12.453704	Avg Compression: 12.547061
# Article 26000:	Length: 248	Compression: 10.842742	Avg Compression: 12.471906
# Article 27000:	Length: 288	Compression: 9.413194	Avg Compression: 12.322903
# Article 28000:	Length: 312	Compression: 8.634615	Avg Compression: 12.138014
# Article 29000:	Length: 224	Compression: 12.187500	Avg Compression: 12.139733
# Article 30000:	Length: 272	Compression: 9.838235	Avg Compression: 12.046577
# Article 31000:	Length: 232	Compression: 11.590517	Avg Compression: 12.031358
# Article 32000:	Length: 288	Compression: 9.378472	Avg Compression: 11.925829
# Article 33000:	Length: 312	Compression: 8.644231	Avg Compression: 11.790254
# Article 34000:	Length: 264	Compression: 10.196970	Avg Compression: 11.736438
# Article 35000:	Length: 288	Compression: 9.378472	Avg Compression: 11.652641
# Article 36000:	Length: 224	Compression: 12.066964	Avg Compression: 11.663785
# Article 37000:	Length: 240	Compression: 11.237500	Avg Compression: 11.651844
# Article 38000:	Length: 240	Compression: 11.425000	Avg Compression: 11.645663
# Article 39000:	Length: 304	Compression: 8.878289	Avg Compression: 11.553336
# Article 40000:	Length: 400	Compression: 6.777500	Avg Compression: 11.352502
# Article 41000:	Length: 272	Compression: 9.992647	Avg Compression: 11.314697
# Article 42000:	Length: 280	Compression: 9.653571	Avg Compression: 11.268482
# Article 43000:	Length: 264	Compression: 10.321970	Avg Compression: 11.244287
# Article 44000:	Length: 320	Compression: 8.431250	Avg Compression: 11.159748
# Article 45000:	Length: 384	Compression: 7.091146	Avg Compression: 11.018129
# Article 46000:	Length: 336	Compression: 8.068452	Avg Compression: 10.930947
# Article 47000:	Length: 320	Compression: 8.496875	Avg Compression: 10.864305
# Article 48000:	Length: 280	Compression: 4.325000	Avg Compression: 10.711314
# Article 49000:	Length: 352	Compression: 7.698864	Avg Compression: 10.625244
# Article 50000:	Length: 448	Compression: 6.160714	Avg Compression: 10.468593
# Article 51000:	Length: 464	Compression: 5.877155	Avg Compression: 10.307588
# Article 52000:	Length: 464	Compression: 5.859914	Avg Compression: 10.156907
# Article 53000:	Length: 472	Compression: 5.902542	Avg Compression: 10.015175
# Article 54000:	Length: 616	Compression: 1.167208	Avg Compression: 9.646510
# Article 55000:	Length: 616	Compression: 2.084416	Avg Compression: 9.344026
# Article 56000:	Length: 632	Compression: 2.403481	Avg Compression: 9.070422
# Article 57000:	Length: 920	Compression: 2.650000	Avg Compression: 8.721980
# Article 58000:	Length: 1008	Compression: 0.552579	Avg Compression: 8.263474
# Article 59000:	Length: 1248	Compression: 1.524038	Avg Compression: 7.825594
# Article 60000:	Length: 1288	Compression: 1.123447	Avg Compression: 7.404420
# Article 61000:	Length: 1288	Compression: 1.156832	Avg Compression: 7.035026
# Article 62000:	Length: 1624	Compression: 0.493227	Avg Compression: 6.581169
# Article 63000:	Length: 2096	Compression: 0.988073	Avg Compression: 6.121510
# Article 64000:	Length: 2144	Compression: 0.971082	Avg Compression: 5.722114
# Article 65000:	Length: 2160	Compression: 0.259259	Avg Compression: 5.326255
# Article 66000:	Length: 3128	Compression: 0.637148	Avg Compression: 4.880921
# Article 67000:	Length: 3048	Compression: 0.757546	Avg Compression: 4.531653
# Article 68000:	Length: 3480	Compression: 0.714080	Avg Compression: 4.195013
# Article 69000:	Length: 3440	Compression: 0.604360	Avg Compression: 3.907118
# Article 70000:	Length: 3304	Compression: 0.349274	Avg Compression: 3.652722
# Article 71000:	Length: 4248	Compression: 0.254237	Avg Compression: 3.366597
# Article 72000:	Length: 5032	Compression: 0.459658	Avg Compression: 3.102977
# Article 73000:	Length: 4272	Compression: 0.191713	Avg Compression: 2.894863
# Article 74000:	Length: 5584	Compression: 0.264864	Avg Compression: 2.670115
# Article 75000:	Length: 5800	Compression: 0.197759	Avg Compression: 2.468557
# Article 76000:	Length: 5520	Compression: 0.473370	Avg Compression: 2.324898
# Article 77000:	Length: 5664	Compression: 0.390713	Avg Compression: 2.191830
# Article 78000:	Length: 6456	Compression: 0.423327	Avg Compression: 2.063232
# Article 79000:	Length: 6752	Compression: 0.471416	Avg Compression: 1.950731
# Article 80000:	Length: 7464	Compression: 0.204582	Avg Compression: 1.824194
# Article 81000:	Length: 10672	Compression: 0.216642	Avg Compression: 1.673270
# Article 82000:	Length: 9056	Compression: 0.331824	Avg Compression: 1.574286
# Article 83000:	Length: 7272	Compression: 0.079483	Avg Compression: 1.490669
# Article 84000:	Length: 8200	Compression: 0.488537	Avg Compression: 1.431208
# Article 85000:	Length: 9152	Compression: 0.279174	Avg Compression: 1.359656
# Article 86000:	Length: 9112	Compression: 0.376097	Avg Compression: 1.302376
# Article 87000:	Length: 9128	Compression: 0.376643	Avg Compression: 1.251347
# Article 88000:	Length: 12256	Compression: 0.287125	Avg Compression: 1.184899
# Article 89000:	Length: 8120	Compression: 0.181897	Avg Compression: 1.141105
# Article 90000:	Length: 10784	Compression: 0.267619	Avg Compression: 1.093229
# Article 91000:	Length: 10264	Compression: 0.179462	Avg Compression: 1.047924
# Article 92000:	Length: 8760	Compression: 0.177055	Avg Compression: 1.012569
# Article 93000:	Length: 11136	Compression: 0.220097	Avg Compression: 0.973677
# Article 94000:	Length: 12024	Compression: 0.341234	Avg Compression: 0.941851
# Article 95000:	Length: 9120	Compression: 0.162171	Avg Compression: 0.913185
# Article 96000:	Length: 10424	Compression: 0.297199	Avg Compression: 0.888343
# Article 97000:	Length: 11032	Compression: 0.330402	Avg Compression: 0.865505
# Article 98000:	Length: 13888	Compression: 0.286794	Avg Compression: 0.837145
# Article 99000:	Length: 14160	Compression: 0.205297	Avg Compression: 0.807078
# Article 100000:	Length: 15352	Compression: 0.270193	Avg Compression: 0.780737
# Article 101000:	Length: 15096	Compression: 0.232379	Avg Compression: 0.755500
# Article 102000:	Length: 14408	Compression: 0.199403	Avg Compression: 0.732101
# Article 103000:	Length: 15048	Compression: 0.255183	Avg Compression: 0.712024
# Article 104000:	Length: 15112	Compression: 0.299299	Avg Compression: 0.695284
# Article 105000:	Length: 15600	Compression: 0.174487	Avg Compression: 0.674354
# Article 106000:	Length: 18368	Compression: 0.179769	Avg Compression: 0.652008
# Article 107000:	Length: 16816	Compression: 0.201891	Avg Compression: 0.634129
# Article 108000:	Length: 20080	Compression: 0.139392	Avg Compression: 0.611727
# Article 109000:	Length: 20168	Compression: 0.135413	Avg Compression: 0.591006
# Article 110000:	Length: 16776	Compression: 0.289878	Avg Compression: 0.580490
# Article 111000:	Length: 20168	Compression: 0.137445	Avg Compression: 0.562639
# Article 112000:	Length: 15768	Compression: 0.173072	Avg Compression: 0.550742
# Article 113000:	Length: 20312	Compression: 0.136520	Avg Compression: 0.535063
# Article 114000:	Length: 14880	Compression: 0.144153	Avg Compression: 0.524516
# Article 115000:	Length: 17224	Compression: 0.215571	Avg Compression: 0.515160
# Article 116000:	Length: 18632	Compression: 0.208995	Avg Compression: 0.505448
# Article 117000:	Length: 20888	Compression: 0.148219	Avg Compression: 0.493181
# Article 118000:	Length: 21680	Compression: 0.136808	Avg Compression: 0.480916
# Article 119000:	Length: 21080	Compression: 0.142837	Avg Compression: 0.469968
# Article 120000:	Length: 18984	Compression: 0.280973	Avg Compression: 0.464613
# Article 121000:	Length: 21096	Compression: 0.142065	Avg Compression: 0.454767
# Article 122000:	Length: 21000	Compression: 0.144714	Avg Compression: 0.445624
# Article 123000:	Length: 20480	Compression: 0.194629	Avg Compression: 0.438607
# Article 124000:	Length: 21792	Compression: 0.142116	Avg Compression: 0.430042
# Article 125000:	Length: 21472	Compression: 0.143675	Avg Compression: 0.422117
# Article 126000:	Length: 21216	Compression: 0.145692	Avg Compression: 0.414759
# Article 127000:	Length: 20992	Compression: 0.148580	Avg Compression: 0.407928
# Article 128000:	Length: 21416	Compression: 0.144191	Avg Compression: 0.401200
# Article 129000:	Length: 21768	Compression: 0.142089	Avg Compression: 0.394651
# Article 130000:	Length: 21784	Compression: 0.140378	Avg Compression: 0.388378
# Article 131000:	Length: 22000	Compression: 0.138909	Avg Compression: 0.382314
# Article 132000:	Length: 22376	Compression: 0.143591	Avg Compression: 0.376554
# Article 133000:	Length: 21696	Compression: 0.141777	Avg Compression: 0.371187
# Article 134000:	Length: 22600	Compression: 0.142434	Avg Compression: 0.365866
# Article 135000:	Length: 18264	Compression: 0.227168	Avg Compression: 0.363308
# Article 136000:	Length: 23664	Compression: 0.136875	Avg Compression: 0.358021
# Article 137000:	Length: 23184	Compression: 0.149715	Avg Compression: 0.353363
# Article 138000:	Length: 17048	Compression: 0.181136	Avg Compression: 0.350577
# Article 139000:	Length: 24168	Compression: 0.241973	Avg Compression: 0.348142
# Article 140000:	Length: 22936	Compression: 0.178366	Avg Compression: 0.344605
# Article 141000:	Length: 19968	Compression: 0.172025	Avg Compression: 0.341531
# Article 142000:	Length: 25032	Compression: 0.139941	Avg Compression: 0.337128
# Article 143000:	Length: 24752	Compression: 0.073287	Avg Compression: 0.331549
# Article 144000:	Length: 24792	Compression: 0.142102	Avg Compression: 0.327621
# Article 145000:	Length: 24184	Compression: 0.222957	Avg Compression: 0.325545
# Article 146000:	Length: 27040	Compression: 0.128476	Avg Compression: 0.321271
# Article 147000:	Length: 25064	Compression: 0.180737	Avg Compression: 0.318501
# Article 148000:	Length: 25608	Compression: 0.215714	Avg Compression: 0.316473
# Article 149000:	Length: 25808	Compression: 0.238569	Avg Compression: 0.314953
# Article 150000:	Length: 22808	Compression: 0.221677	Avg Compression: 0.313373
# Article 151000:	Length: 26256	Compression: 0.133569	Avg Compression: 0.309932
# Article 152000:	Length: 24576	Compression: 0.208822	Avg Compression: 0.308153
# Article 153000:	Length: 24096	Compression: 0.289343	Avg Compression: 0.307834
# Article 154000:	Length: 23912	Compression: 0.160380	Avg Compression: 0.305394
# Article 155000:	Length: 31928	Compression: 0.136964	Avg Compression: 0.301753
# Article 156000:	Length: 24952	Compression: 0.215374	Avg Compression: 0.300317
# Article 157000:	Length: 26216	Compression: 0.203845	Avg Compression: 0.298662
# Article 158000:	Length: 30992	Compression: 0.189759	Avg Compression: 0.296497
# Article 159000:	Length: 32784	Compression: 0.193021	Avg Compression: 0.294366
# Article 160000:	Length: 33296	Compression: 0.156265	Avg Compression: 0.291536
# Article 161000:	Length: 32192	Compression: 0.232232	Avg Compression: 0.290384
# Article 162000:	Length: 31040	Compression: 0.259149	Avg Compression: 0.289810
# Article 163000:	Length: 30856	Compression: 0.263579	Avg Compression: 0.289339
# Article 164000:	Length: 33328	Compression: 0.223416	Avg Compression: 0.288085
# Article 165000:	Length: 34848	Compression: 0.086232	Avg Compression: 0.284150
# Article 166000:	Length: 33512	Compression: 0.237855	Avg Compression: 0.283298
# Article 167000:	Length: 32016	Compression: 0.268522	Avg Compression: 0.283042
# Article 168000:	Length: 35808	Compression: 0.242181	Avg Compression: 0.282268
# Article 169000:	Length: 34416	Compression: 0.212343	Avg Compression: 0.281016
# Article 170000:	Length: 33128	Compression: 0.221384	Avg Compression: 0.280006
# Article 171000:	Length: 35056	Compression: 0.212346	Avg Compression: 0.278815
# Article 172000:	Length: 36736	Compression: 0.155896	Avg Compression: 0.276588
# Article 173000:	Length: 34712	Compression: 0.185699	Avg Compression: 0.275059
# Article 174000:	Length: 41024	Compression: 0.106742	Avg Compression: 0.271777
# Article 175000:	Length: 40072	Compression: 0.192703	Avg Compression: 0.270298
# Article 176000:	Length: 42216	Compression: 0.208854	Avg Compression: 0.269112
# Article 177000:	Length: 41912	Compression: 0.259448	Avg Compression: 0.268930
# Article 178000:	Length: 45104	Compression: 0.182356	Avg Compression: 0.267212
# Article 179000:	Length: 39640	Compression: 0.124092	Avg Compression: 0.264759
# Article 180000:	Length: 45208	Compression: 0.195452	Avg Compression: 0.263430
# Article 181000:	Length: 40232	Compression: 0.284823	Avg Compression: 0.263789
# Article 182000:	Length: 55192	Compression: 0.166745	Avg Compression: 0.261606
# Article 183000:	Length: 50640	Compression: 0.194491	Avg Compression: 0.260248
# Article 184000:	Length: 48840	Compression: 0.183845	Avg Compression: 0.258787
# Article 185000:	Length: 48672	Compression: 0.206710	Avg Compression: 0.257812
# Article 186000:	Length: 55496	Compression: 0.215367	Avg Compression: 0.256926
# Article 187000:	Length: 56784	Compression: 0.189138	Avg Compression: 0.255507
# Article 188000:	Length: 54512	Compression: 0.229472	Avg Compression: 0.254995
# Article 189000:	Length: 63720	Compression: 0.194947	Avg Compression: 0.253643
# Article 190000:	Length: 59936	Compression: 0.175988	Avg Compression: 0.252034
# Article 191000:	Length: 69160	Compression: 0.104294	Avg Compression: 0.248583
# Article 192000:	Length: 65808	Compression: 0.178702	Avg Compression: 0.247064
# Article 193000:	Length: 63840	Compression: 0.186497	Avg Compression: 0.245813
# Article 194000:	Length: 69040	Compression: 0.165223	Avg Compression: 0.244052
# Article 195000:	Length: 75184	Compression: 0.211588	Avg Compression: 0.243297
# Article 196000:	Length: 71376	Compression: 0.187738	Avg Compression: 0.242098
# Article 197000:	Length: 83080	Compression: 0.189889	Avg Compression: 0.240818
# Article 198000:	Length: 84936	Compression: 0.175650	Avg Compression: 0.239225
# Article 199000:	Length: 72064	Compression: 0.222289	Avg Compression: 0.238881
# Article 200000:	Length: 74352	Compression: 0.185119	Avg Compression: 0.237777
# Article 201000:	Length: 92552	Compression: 0.204815	Avg Compression: 0.236955
# Article 202000:	Length: 93784	Compression: 0.206816	Avg Compression: 0.236213
# Article 203000:	Length: 101272	Compression: 0.203255	Avg Compression: 0.235359
# Article 204000:	Length: 102528	Compression: 0.228630	Avg Compression: 0.235187
# Article 205000:	Length: 113520	Compression: 0.197278	Avg Compression: 0.234143
# Article 206000:	Length: 52496	Compression: 0.344521	Avg Compression: 0.235531
# Article 207000:	Length: 98296	Compression: 0.216753	Avg Compression: 0.235099
# Article 208000:	Length: 123208	Compression: 0.216057	Avg Compression: 0.234566
# Article 209000:	Length: 110528	Compression: 0.187808	Avg Compression: 0.233419
# Article 210000:	Length: 130536	Compression: 0.200420	Avg Compression: 0.232491
# Article 211000:	Length: 112496	Compression: 0.228195	Avg Compression: 0.232389
# Article 212000:	Length: 151144	Compression: 0.213386	Avg Compression: 0.231803
# Article 213000:	Length: 156488	Compression: 0.229104	Avg Compression: 0.231720
# Article 214000:	Length: 163000	Compression: 0.247331	Avg Compression: 0.232207
# Article 215000:	Length: 191240	Compression: 0.197176	Avg Compression: 0.230970
# Article 216000:	Length: 210688	Compression: 0.183712	Avg Compression: 0.229199
# Article 217000:	Length: 242768	Compression: 0.215399	Avg Compression: 0.228628
# Article 218000:	Length: 278320	Compression: 0.181934	Avg Compression: 0.226514
# Article 219000:	Length: 341104	Compression: 0.202396	Avg Compression: 0.225246
# Article 220000:	Length: 461312	Compression: 0.237505	Avg Compression: 0.226060

# %%
BATCH_SIZE = 8192
BATCHED_ITEM_LENGTH = 8

def build_model(vocab_size, embedding_dim, rnn_units):
    return tf.keras.Sequential([
        tf.keras.layers.Masking(mask_value=0, batch_input_shape=[BATCH_SIZE, None]),
        tf.keras.layers.Embedding(vocab_size, embedding_dim),
        tf.keras.layers.GRU(rnn_units, return_sequences=True, stateful=True, recurrent_initializer='glorot_uniform'),
        tf.keras.layers.GRU(rnn_units, return_sequences=True, stateful=True, recurrent_initializer='glorot_uniform'),
        tf.keras.layers.Dense(vocab_size),
    ])

checkpoint_dir = './training_checkpoints-4' # Directory where the checkpoints will be saved
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt_{epoch}") # Name of the checkpoint files

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_prefix, save_weights_only=True)

class ModelStateResetter(tf.keras.callbacks.Callback):
    def __init__(self):
        pass

    def on_epoch_begin(self, epoch, logs=None):
        self.last_total_length = 0
        
    def on_batch_end(self, batch, logs={}):
        average_batch_length = logs.get('average_batch_length', 0)
        total_length = int(round(average_batch_length * (batch + 1)))
        current_batch_length = total_length - self.last_total_length
        self.last_total_length = total_length
        
        if current_batch_length < BATCHED_ITEM_LENGTH:
            self.model.reset_states()
        
model_state_resetter_callback = ModelStateResetter()

def loss(labels, logits):
    return tf.keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)

def average_batch_length(true_labels, predictions):
    return tf.shape(true_labels)[1]

# %%
model = build_predicting_model(vocab_size = subword_text_encoder.vocab_size, embedding_dim=64, rnn_units=768)
model.load_weights(tf.train.latest_checkpoint(checkpoint_dir))
model.build(tf.TensorShape([1, 1]))

# %%
model = build_model(vocab_size = subword_text_encoder.vocab_size, embedding_dim=64, rnn_units=768)
model.load_weights(tf.train.latest_checkpoint(checkpoint_dir))
model.compile(optimizer='adam', loss=loss, metrics=[average_batch_length])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# masking_4 (Masking)          (8192, None)              0
# _________________________________________________________________
# embedding_4 (Embedding)      (8192, None, 64)          259072
# _________________________________________________________________
# gru_8 (GRU)                  (8192, None, 768)         1921536
# _________________________________________________________________
# gru_9 (GRU)                  (8192, None, 768)         3543552
# _________________________________________________________________
# dense_4 (Dense)              (8192, None, 4048)        3112912
# =================================================================
# Total params: 8,837,072
# Trainable params: 8,837,072
# Non-trainable params: 0
# _________________________________________________________________

# %%
dataset = articles.dataset(BATCH_SIZE, BATCHED_ITEM_LENGTH)
callbacks = [checkpoint_callback, model_state_resetter_callback]
model.fit(dataset, callbacks=callbacks)
# Out:
# 42479/42479 [==============================] - 26232s 618ms/step - loss: 0.3173 - average_batch_length: 7.9975

# %%
model = build_predicting_model(vocab_size = subword_text_encoder.vocab_size, embedding_dim=64, rnn_units=768)
model.load_weights(tf.train.latest_checkpoint(checkpoint_dir))
model.build(tf.TensorShape([1, 1]))

# %%
total_raw = 0
total_compressed = 0

for index, encoded_article in enumerate(articles.articles_generator(1)):
    if index % 1000 == 0:
        article = subword_text_encoder.decode(encoded_article)
        raw = len(article) * 8
        if raw == 0:
            continue
        compressed, _ = huffman_archive_size(model, encoded_article)
        total_raw += raw
        total_compressed += compressed

        print('Article %d:\tLength: %d\tCompression: %f\tAvg Compression: %f' % (index, raw, compressed/raw, total_compressed/total_raw))
# Out:
# Article 1000:	Length: 144	Compression: 26.055556	Avg Compression: 26.055556
# Article 2000:	Length: 160	Compression: 23.375000	Avg Compression: 24.644737
# Article 3000:	Length: 176	Compression: 21.375000	Avg Compression: 23.445833
# Article 4000:	Length: 152	Compression: 24.730263	Avg Compression: 23.754747
# Article 5000:	Length: 192	Compression: 19.500000	Avg Compression: 22.763350
# Article 6000:	Length: 216	Compression: 17.416667	Avg Compression: 21.652885
# Article 7000:	Length: 264	Compression: 14.265152	Avg Compression: 20.157209
# Article 8000:	Length: 208	Compression: 18.105769	Avg Compression: 19.875000
# Article 9000:	Length: 216	Compression: 17.398148	Avg Compression: 19.565394
# Article 10000:	Length: 264	Compression: 14.318182	Avg Compression: 18.869980
# Article 11000:	Length: 232	Compression: 16.206897	Avg Compression: 18.592176
# Article 12000:	Length: 192	Compression: 19.635417	Avg Compression: 18.675083
# Article 13000:	Length: 288	Compression: 5.256944	Avg Compression: 17.245932
# Article 14000:	Length: 280	Compression: 13.439286	Avg Compression: 16.888740
# Article 15000:	Length: 184	Compression: 20.554348	Avg Compression: 17.101641
# Article 16000:	Length: 208	Compression: 7.302885	Avg Compression: 16.497927
# Article 17000:	Length: 224	Compression: 16.754464	Avg Compression: 16.513889
# Article 18000:	Length: 232	Compression: 16.211207	Avg Compression: 16.495564
# Article 19000:	Length: 192	Compression: 19.619792	Avg Compression: 16.644632
# Article 20000:	Length: 248	Compression: 15.233871	Avg Compression: 16.562734
# Article 21000:	Length: 224	Compression: 16.861607	Avg Compression: 16.577625
# Article 22000:	Length: 232	Compression: 16.275862	Avg Compression: 16.562817
# Article 23000:	Length: 232	Compression: 16.280172	Avg Compression: 16.549597
# Article 24000:	Length: 200	Compression: 7.650000	Avg Compression: 16.204651
# Article 25000:	Length: 216	Compression: 7.064815	Avg Compression: 15.837426
# Article 26000:	Length: 248	Compression: 15.221774	Avg Compression: 15.810277
# Article 27000:	Length: 288	Compression: 5.378472	Avg Compression: 15.302097
# Article 28000:	Length: 312	Compression: 12.099359	Avg Compression: 15.141549
# Article 29000:	Length: 224	Compression: 16.995536	Avg Compression: 15.205955
# Article 30000:	Length: 272	Compression: 12.562500	Avg Compression: 15.098958
# Article 31000:	Length: 232	Compression: 16.258621	Avg Compression: 15.137658
# Article 32000:	Length: 288	Compression: 13.086806	Avg Compression: 15.056077
# Article 33000:	Length: 312	Compression: 4.903846	Avg Compression: 14.636653
# Article 34000:	Length: 264	Compression: 14.253788	Avg Compression: 14.623721
# Article 35000:	Length: 288	Compression: 13.111111	Avg Compression: 14.569965
# Article 36000:	Length: 224	Compression: 16.901786	Avg Compression: 14.632685
# Article 37000:	Length: 240	Compression: 6.475000	Avg Compression: 14.404178
# Article 38000:	Length: 240	Compression: 15.920833	Avg Compression: 14.445504
# Article 39000:	Length: 304	Compression: 12.453947	Avg Compression: 14.379061
# Article 40000:	Length: 400	Compression: 9.455000	Avg Compression: 14.171993
# Article 41000:	Length: 272	Compression: 13.952206	Avg Compression: 14.165883
# Article 42000:	Length: 280	Compression: 13.553571	Avg Compression: 14.148847
# Article 43000:	Length: 264	Compression: 14.424242	Avg Compression: 14.155887
# Article 44000:	Length: 320	Compression: 11.834375	Avg Compression: 14.086119
# Article 45000:	Length: 384	Compression: 9.981771	Avg Compression: 13.943256
# Article 46000:	Length: 336	Compression: 11.348214	Avg Compression: 13.866555
# Article 47000:	Length: 320	Compression: 11.993750	Avg Compression: 13.815281
# Article 48000:	Length: 280	Compression: 12.125000	Avg Compression: 13.775735
# Article 49000:	Length: 352	Compression: 10.872159	Avg Compression: 13.692776
# Article 50000:	Length: 448	Compression: 8.584821	Avg Compression: 13.513549
# Article 51000:	Length: 464	Compression: 8.301724	Avg Compression: 13.330789
# Article 52000:	Length: 464	Compression: 8.310345	Avg Compression: 13.160704
# Article 53000:	Length: 472	Compression: 8.252119	Avg Compression: 12.997177
# Article 54000:	Length: 616	Compression: 1.029221	Avg Compression: 12.498512
# Article 55000:	Length: 616	Compression: 0.381494	Avg Compression: 12.013831
# Article 56000:	Length: 632	Compression: 4.776899	Avg Compression: 11.728543
# Article 57000:	Length: 920	Compression: 0.833696	Avg Compression: 11.137270
# Article 58000:	Length: 1008	Compression: 0.841270	Avg Compression: 10.559410
# Article 59000:	Length: 1248	Compression: 2.157853	Avg Compression: 10.013536
# Article 60000:	Length: 1288	Compression: 0.408385	Avg Compression: 9.409934
# Article 61000:	Length: 1288	Compression: 1.710404	Avg Compression: 8.954692
# Article 62000:	Length: 1624	Compression: 0.354064	Avg Compression: 8.357997
# Article 63000:	Length: 2096	Compression: 0.584924	Avg Compression: 7.719181
# Article 64000:	Length: 2144	Compression: 0.426306	Avg Compression: 7.153646
# Article 65000:	Length: 2160	Compression: 1.085648	Avg Compression: 6.713936
# Article 66000:	Length: 3128	Compression: 0.371164	Avg Compression: 6.111550
# Article 67000:	Length: 3048	Compression: 0.624016	Avg Compression: 5.646732
# Article 68000:	Length: 3480	Compression: 0.881897	Avg Compression: 5.226561
# Article 69000:	Length: 3440	Compression: 0.577616	Avg Compression: 4.853813
# Article 70000:	Length: 3304	Compression: 0.309019	Avg Compression: 4.528848
# Article 71000:	Length: 4248	Compression: 0.840395	Avg Compression: 4.218309
# Article 72000:	Length: 5032	Compression: 0.306439	Avg Compression: 3.863556
# Article 73000:	Length: 4272	Compression: 0.877107	Avg Compression: 3.650067
# Article 74000:	Length: 5584	Compression: 0.474212	Avg Compression: 3.378673
# Article 75000:	Length: 5800	Compression: 0.292931	Avg Compression: 3.127108
# Article 76000:	Length: 5520	Compression: 0.564130	Avg Compression: 2.942568
# Article 77000:	Length: 5664	Compression: 0.522246	Avg Compression: 2.776054
# Article 78000:	Length: 6456	Compression: 0.262082	Avg Compression: 2.593249
# Article 79000:	Length: 6752	Compression: 0.594935	Avg Compression: 2.452018
# Article 80000:	Length: 7464	Compression: 0.253617	Avg Compression: 2.292709
# Article 81000:	Length: 10672	Compression: 0.188062	Avg Compression: 2.095116
# Article 82000:	Length: 9056	Compression: 0.468308	Avg Compression: 1.975075
# Article 83000:	Length: 7272	Compression: 0.652640	Avg Compression: 1.901100
# Article 84000:	Length: 8200	Compression: 0.320000	Avg Compression: 1.807287
# Article 85000:	Length: 9152	Compression: 0.300262	Avg Compression: 1.713686
# Article 86000:	Length: 9112	Compression: 0.451712	Avg Compression: 1.640192
# Article 87000:	Length: 9128	Compression: 0.350022	Avg Compression: 1.569073
# Article 88000:	Length: 12256	Compression: 0.466710	Avg Compression: 1.493106
# Article 89000:	Length: 8120	Compression: 0.557759	Avg Compression: 1.452266
# Article 90000:	Length: 10784	Compression: 0.472923	Avg Compression: 1.398588
# Article 91000:	Length: 10264	Compression: 0.388932	Avg Compression: 1.348529
# Article 92000:	Length: 8760	Compression: 0.546461	Avg Compression: 1.315967
# Article 93000:	Length: 11136	Compression: 0.307561	Avg Compression: 1.266478
# Article 94000:	Length: 12024	Compression: 0.396124	Avg Compression: 1.222679
# Article 95000:	Length: 9120	Compression: 0.548904	Avg Compression: 1.197907
# Article 96000:	Length: 10424	Compression: 0.626727	Avg Compression: 1.174872
# Article 97000:	Length: 11032	Compression: 0.504170	Avg Compression: 1.147418
# Article 98000:	Length: 13888	Compression: 0.341662	Avg Compression: 1.107932
# Article 99000:	Length: 14160	Compression: 0.293291	Avg Compression: 1.069166
# Article 100000:	Length: 15352	Compression: 0.238015	Avg Compression: 1.028388
# Article 101000:	Length: 15096	Compression: 0.471383	Avg Compression: 1.002753
# Article 102000:	Length: 14408	Compression: 0.339534	Avg Compression: 0.974846
# Article 103000:	Length: 15048	Compression: 0.517145	Avg Compression: 0.955579
# Article 104000:	Length: 15112	Compression: 0.386977	Avg Compression: 0.932516
# Article 105000:	Length: 15600	Compression: 0.379551	Avg Compression: 0.910293
# Article 106000:	Length: 18368	Compression: 0.371407	Avg Compression: 0.885946
# Article 107000:	Length: 16816	Compression: 0.444101	Avg Compression: 0.868396
# Article 108000:	Length: 20080	Compression: 0.121962	Avg Compression: 0.834595
# Article 109000:	Length: 20168	Compression: 0.138834	Avg Compression: 0.804328
# Article 110000:	Length: 16776	Compression: 0.327432	Avg Compression: 0.787674
# Article 111000:	Length: 20168	Compression: 0.151478	Avg Compression: 0.762041
# Article 112000:	Length: 15768	Compression: 0.343798	Avg Compression: 0.749268
# Article 113000:	Length: 20312	Compression: 0.097381	Avg Compression: 0.724593
# Article 114000:	Length: 14880	Compression: 0.428898	Avg Compression: 0.716615
# Article 115000:	Length: 17224	Compression: 0.448212	Avg Compression: 0.708487
# Article 116000:	Length: 18632	Compression: 0.355195	Avg Compression: 0.697280
# Article 117000:	Length: 20888	Compression: 0.225440	Avg Compression: 0.681077
# Article 118000:	Length: 21680	Compression: 0.149908	Avg Compression: 0.662796
# Article 119000:	Length: 21080	Compression: 0.135911	Avg Compression: 0.645735
# Article 120000:	Length: 18984	Compression: 0.304625	Avg Compression: 0.636070
# Article 121000:	Length: 21096	Compression: 0.171834	Avg Compression: 0.621899
# Article 122000:	Length: 21000	Compression: 0.200905	Avg Compression: 0.609484
# Article 123000:	Length: 20480	Compression: 0.252490	Avg Compression: 0.599504
# Article 124000:	Length: 21792	Compression: 0.110178	Avg Compression: 0.585368
# Article 125000:	Length: 21472	Compression: 0.228064	Avg Compression: 0.575479
# Article 126000:	Length: 21216	Compression: 0.126225	Avg Compression: 0.563521
# Article 127000:	Length: 20992	Compression: 0.180831	Avg Compression: 0.553701
# Article 128000:	Length: 21416	Compression: 0.238467	Avg Compression: 0.545659
# Article 129000:	Length: 21768	Compression: 0.122152	Avg Compression: 0.534955
# Article 130000:	Length: 21784	Compression: 0.131656	Avg Compression: 0.525005
# Article 131000:	Length: 22000	Compression: 0.145636	Avg Compression: 0.515783
# Article 132000:	Length: 22376	Compression: 0.214694	Avg Compression: 0.508519
# Article 133000:	Length: 21696	Compression: 0.148968	Avg Compression: 0.500299
# Article 134000:	Length: 22600	Compression: 0.230841	Avg Compression: 0.494032
# Article 135000:	Length: 18264	Compression: 0.409877	Avg Compression: 0.492479
# Article 136000:	Length: 23664	Compression: 0.124366	Avg Compression: 0.483885
# Article 137000:	Length: 23184	Compression: 0.162655	Avg Compression: 0.476702
# Article 138000:	Length: 17048	Compression: 0.493548	Avg Compression: 0.476975
# Article 139000:	Length: 24168	Compression: 0.316493	Avg Compression: 0.473377
# Article 140000:	Length: 22936	Compression: 0.368416	Avg Compression: 0.471190
# Article 141000:	Length: 19968	Compression: 0.305439	Avg Compression: 0.468238
# Article 142000:	Length: 25032	Compression: 0.181528	Avg Compression: 0.461975
# Article 143000:	Length: 24752	Compression: 0.209559	Avg Compression: 0.456638
# Article 144000:	Length: 24792	Compression: 0.176186	Avg Compression: 0.450822
# Article 145000:	Length: 24184	Compression: 0.278200	Avg Compression: 0.447399
# Article 146000:	Length: 27040	Compression: 0.160466	Avg Compression: 0.441176
# Article 147000:	Length: 25064	Compression: 0.285350	Avg Compression: 0.438105
# Article 148000:	Length: 25608	Compression: 0.301273	Avg Compression: 0.435404
# Article 149000:	Length: 25808	Compression: 0.266545	Avg Compression: 0.432111
# Article 150000:	Length: 22808	Compression: 0.390302	Avg Compression: 0.431402
# Article 151000:	Length: 26256	Compression: 0.221359	Avg Compression: 0.427384
# Article 152000:	Length: 24576	Compression: 0.430542	Avg Compression: 0.427439
# Article 153000:	Length: 24096	Compression: 0.369812	Avg Compression: 0.426462
# Article 154000:	Length: 23912	Compression: 0.328580	Avg Compression: 0.424842
# Article 155000:	Length: 31928	Compression: 0.156414	Avg Compression: 0.419039
# Article 156000:	Length: 24952	Compression: 0.413995	Avg Compression: 0.418955
# Article 157000:	Length: 26216	Compression: 0.445034	Avg Compression: 0.419402
# Article 158000:	Length: 30992	Compression: 0.262229	Avg Compression: 0.416278
# Article 159000:	Length: 32784	Compression: 0.252105	Avg Compression: 0.412896
# Article 160000:	Length: 33296	Compression: 0.229847	Avg Compression: 0.409146
# Article 161000:	Length: 32192	Compression: 0.302435	Avg Compression: 0.407073
# Article 162000:	Length: 31040	Compression: 0.306121	Avg Compression: 0.405217
# Article 163000:	Length: 30856	Compression: 0.335299	Avg Compression: 0.403962
# Article 164000:	Length: 33328	Compression: 0.301008	Avg Compression: 0.402004
# Article 165000:	Length: 34848	Compression: 0.215880	Avg Compression: 0.398375
# Article 166000:	Length: 33512	Compression: 0.289747	Avg Compression: 0.396375
# Article 167000:	Length: 32016	Compression: 0.414918	Avg Compression: 0.396696
# Article 168000:	Length: 35808	Compression: 0.361567	Avg Compression: 0.396030
# Article 169000:	Length: 34416	Compression: 0.337372	Avg Compression: 0.394980
# Article 170000:	Length: 33128	Compression: 0.356436	Avg Compression: 0.394327
# Article 171000:	Length: 35056	Compression: 0.385469	Avg Compression: 0.394171
# Article 172000:	Length: 36736	Compression: 0.335066	Avg Compression: 0.393101
# Article 173000:	Length: 34712	Compression: 0.282438	Avg Compression: 0.391238
# Article 174000:	Length: 41024	Compression: 0.227672	Avg Compression: 0.388049
# Article 175000:	Length: 40072	Compression: 0.288581	Avg Compression: 0.386189
# Article 176000:	Length: 42216	Compression: 0.299176	Avg Compression: 0.384509
# Article 177000:	Length: 41912	Compression: 0.336491	Avg Compression: 0.383605
# Article 178000:	Length: 45104	Compression: 0.277825	Avg Compression: 0.381506
# Article 179000:	Length: 39640	Compression: 0.365817	Avg Compression: 0.381237
# Article 180000:	Length: 45208	Compression: 0.302070	Avg Compression: 0.379720
# Article 181000:	Length: 40232	Compression: 0.341395	Avg Compression: 0.379077
# Article 182000:	Length: 55192	Compression: 0.281816	Avg Compression: 0.376889
# Article 183000:	Length: 50640	Compression: 0.359992	Avg Compression: 0.376547
# Article 184000:	Length: 48840	Compression: 0.305344	Avg Compression: 0.375185
# Article 185000:	Length: 48672	Compression: 0.328628	Avg Compression: 0.374313
# Article 186000:	Length: 55496	Compression: 0.351124	Avg Compression: 0.373829
# Article 187000:	Length: 56784	Compression: 0.333263	Avg Compression: 0.372980
# Article 188000:	Length: 54512	Compression: 0.317912	Avg Compression: 0.371896
# Article 189000:	Length: 63720	Compression: 0.311551	Avg Compression: 0.370538
# Article 190000:	Length: 59936	Compression: 0.318640	Avg Compression: 0.369462
# Article 191000:	Length: 69160	Compression: 0.208415	Avg Compression: 0.365701
# Article 192000:	Length: 65808	Compression: 0.264664	Avg Compression: 0.363504
# Article 193000:	Length: 63840	Compression: 0.348872	Avg Compression: 0.363202
# Article 194000:	Length: 69040	Compression: 0.261269	Avg Compression: 0.360975
# Article 195000:	Length: 75184	Compression: 0.282148	Avg Compression: 0.359143
# Article 196000:	Length: 71376	Compression: 0.299120	Avg Compression: 0.357847
# Article 197000:	Length: 83080	Compression: 0.270944	Avg Compression: 0.355717
# Article 198000:	Length: 84936	Compression: 0.296988	Avg Compression: 0.354281
# Article 199000:	Length: 72064	Compression: 0.336978	Avg Compression: 0.353929
# Article 200000:	Length: 74352	Compression: 0.340879	Avg Compression: 0.353661
# Article 201000:	Length: 92552	Compression: 0.309577	Avg Compression: 0.352563
# Article 202000:	Length: 93784	Compression: 0.296842	Avg Compression: 0.351190
# Article 203000:	Length: 101272	Compression: 0.282191	Avg Compression: 0.349402
# Article 204000:	Length: 102528	Compression: 0.323287	Avg Compression: 0.348734
# Article 205000:	Length: 113520	Compression: 0.282135	Avg Compression: 0.346901
# Article 206000:	Length: 52496	Compression: 0.599760	Avg Compression: 0.350079
# Article 207000:	Length: 98296	Compression: 0.389558	Avg Compression: 0.350987
# Article 208000:	Length: 123208	Compression: 0.341739	Avg Compression: 0.350728
# Article 209000:	Length: 110528	Compression: 0.339651	Avg Compression: 0.350456
# Article 210000:	Length: 130536	Compression: 0.311408	Avg Compression: 0.349358
# Article 211000:	Length: 112496	Compression: 0.401934	Avg Compression: 0.350602
# Article 212000:	Length: 151144	Compression: 0.323499	Avg Compression: 0.349767
# Article 213000:	Length: 156488	Compression: 0.340128	Avg Compression: 0.349469
# Article 214000:	Length: 163000	Compression: 0.382730	Avg Compression: 0.350507
# Article 215000:	Length: 191240	Compression: 0.319766	Avg Compression: 0.349421
# Article 216000:	Length: 210688	Compression: 0.320004	Avg Compression: 0.348319
# Article 217000:	Length: 242768	Compression: 0.309707	Avg Compression: 0.346721
# Article 218000:	Length: 278320	Compression: 0.275277	Avg Compression: 0.343486
# Article 219000:	Length: 341104	Compression: 0.298539	Avg Compression: 0.341122
# Article 220000:	Length: 461312	Compression: 0.324115	Avg Compression: 0.339993
