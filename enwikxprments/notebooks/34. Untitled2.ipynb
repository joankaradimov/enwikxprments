# %%
import itertools
import math
import os

import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds

physical_devices = tf.config.list_physical_devices('GPU')
for physical_device in physical_devices:
    tf.config.experimental.set_memory_growth(physical_device, enable=True)

# %%
TYPE=np.int16

subword_text_encoder = tfds.features.text.SubwordTextEncoder.load_from_file('vocab_4096')

class Articles:
    EMPTY_ARTICLE = np.array([], dtype=TYPE) # used for padding
    
    def __init__(self, path):
        with open(path, 'rb') as text_file:
            data = text_file.read()

        self.articles = sorted(set(data.split(b'\0')[:2000]), key=len)
        self._encoded_articles = None

    @property
    def encoded_articles(self):
        if self._encoded_articles == None:
            self._encoded_articles = [np.array(subword_text_encoder.encode(article), dtype=TYPE) for article in self.articles]
        
        return self._encoded_articles

    def articles_generator(self, batch_size = 1, start = 0, end = None):
        end = end or len(self.articles)

        for _ in range(batch_size - ((end - start - 1) % batch_size + 1)):
            yield self.EMPTY_ARTICLE

        for article in itertools.islice(self.encoded_articles, start, end):
            yield article

    def subbatch_generator(self, batch_size, batch_length, start = 0, end = None):
        end = end or len(self.articles)

        dataset = tf.data.Dataset.from_generator(self.articles_generator, args=(batch_size, start, end), output_types=TYPE)
        dataset = dataset.padded_batch(batch_size, padded_shapes=([None]), drop_remainder=True)
        dataset = dataset.shuffle(100)

        for batch in dataset.as_numpy_iterator():
            remaining = batch
            while remaining.shape[1] > batch_length + 1:
                yield remaining[:, :batch_length + 1]
                remaining = remaining[:, batch_length:]

            if remaining.shape[1] == batch_length + 1:
                yield remaining
                yield np.zeros((batch_size, batch_length + 1), dtype=TYPE)
            else:
                yield np.hstack([remaining, np.zeros([batch_size, batch_length - remaining.shape[1] + 1])])

    def steps(self, batch_size, batch_length):
        articles = self.articles_generator(batch_size, batch_length)
        return sum(math.ceil(len(article) / batch_length) for i, article in enumerate(articles) if (i + 1) % batch_size == 0)

    def dataset(self, batch_size, batch_length, start = 0, end = None):
        end = end or len(self.articles)

        dataset = tf.data.Dataset.from_generator(self.subbatch_generator, args=(batch_size, batch_length, start, end), output_types=TYPE, output_shapes=(batch_size, batch_length + 1))
        return dataset.map(lambda batch: (batch[:, :-1], batch[:, 1:]))

# %%
def loss(labels, logits):
    return tf.keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)

def average_final_batch_ratio(true_labels, predictions):
    return 0 ** tf.math.abs(true_labels[-1, -1])

class ModelStateResetter(tf.keras.callbacks.Callback):
    def __init__(self):
        pass

    def on_epoch_begin(self, epoch, logs=None):
        self.last_final_batch_count = 0
        
    def on_batch_end(self, batch, logs={}):
        average_final_batch_ratio = logs.get('average_final_batch_ratio', 0)
        final_batch_count = int(round(average_final_batch_ratio * (batch + 1)))
        is_final = final_batch_count - self.last_final_batch_count
        self.last_final_batch_count = final_batch_count
        
        if is_final:
            self.model.reset_states()

class Model:
    def __init__(self, articles, checkpoint_dir, vocab_size, embedding_dim, rnn_units):
        self._articles = articles
        self._batch_size = None
        self._batched_item_length = None
        self._training_model = None
        self._predicting_model = None
        self._vocab_size = vocab_size
        self._embedding_dim = embedding_dim
        self._rnn_units = rnn_units

        self._checkpoint_dir = checkpoint_dir
        self._checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt_{epoch}") # Name of the checkpoint files

    def training_model(self, batch_size, batched_item_length):
        if self._training_model == None or batch_size != self._batch_size or batched_item_length != self._batched_item_length:
            self._batch_size = batch_size
            self._batched_item_length = batched_item_length
            self._training_model = tf.keras.Sequential([
                tf.keras.layers.Masking(mask_value=0, batch_input_shape=[batch_size, batched_item_length]),
                tf.keras.layers.Embedding(self._vocab_size, self._embedding_dim),
                tf.keras.layers.GRU(self._rnn_units // 4 * 4, return_sequences=True, stateful=True, recurrent_initializer='glorot_uniform'),
                tf.keras.layers.GRU(self._rnn_units // 4 * 2, return_sequences=True, stateful=True, recurrent_initializer='glorot_uniform'),
                tf.keras.layers.GRU(self._rnn_units // 4 * 1, return_sequences=True, stateful=True, recurrent_initializer='glorot_uniform'),
                tf.keras.layers.Dense(self._vocab_size),
            ])

            if os.path.isdir(self._checkpoint_dir):
                self._training_model.load_weights(tf.train.latest_checkpoint(self._checkpoint_dir))

            self._training_model.compile(optimizer='adam', loss=loss, metrics=[average_final_batch_ratio])
            self._predicting_model = None
        
        return self._training_model

    @property
    def callbacks(self):
        checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=self._checkpoint_prefix, save_weights_only=True)
        model_state_resetter_callback = ModelStateResetter()
        
        return [checkpoint_callback, model_state_resetter_callback]
    
    def train(self, batch_size, batched_item_length, epochs=1):
        dataset = self._articles.dataset(batch_size, batched_item_length)

        model = self.training_model(batch_size, batched_item_length)

        model.fit(dataset, epochs=epochs, callbacks=self.callbacks)
    
    @property
    def predicting_model(self):
        if self._predicting_model == None:
            self._predicting_model = tf.keras.Sequential([
                tf.keras.layers.Masking(mask_value=0, batch_input_shape=[1, 1]),
                tf.keras.layers.Embedding(self._vocab_size, self._embedding_dim),
                tf.keras.layers.GRU(self._rnn_units // 4 * 4, stateful=True, return_sequences=True),
                tf.keras.layers.GRU(self._rnn_units // 4 * 2, stateful=True, return_sequences=True),
                tf.keras.layers.GRU(self._rnn_units // 4 * 1, stateful=True, return_sequences=True),
                tf.keras.layers.Dense(self._vocab_size),
            ])
            
            self._predicting_model.load_weights(tf.train.latest_checkpoint(self._checkpoint_dir))
            self._training_model = None
        
        return self._predicting_model
    
    def predict(self, input_eval):
        return self.predicting_model(input_eval)

# %%
articles = Articles('page_revisions_text')

# %%
steps = 13

for i in range(steps):
    batch_size = 3 * 2**i
    batch_item_length = 3 * 2**(steps - i - 1)
    count = articles.steps(batch_size, batch_item_length)
    print("batch size: %6d\t batch item length: %4d\tsteps per epoch: %6d" % (batch_size, batch_item_length, count))
# Out:
# batch size:      3	 batch item length: 12288	steps per epoch:      0
# batch size:      6	 batch item length: 6144	steps per epoch:      0
# batch size:     12	 batch item length: 3072	steps per epoch:      0
# batch size:     24	 batch item length: 1536	steps per epoch:    108
# batch size:     48	 batch item length:  768	steps per epoch:    166
# batch size:     96	 batch item length:  384	steps per epoch:    193
# batch size:    192	 batch item length:  192	steps per epoch:    249
# batch size:    384	 batch item length:   96	steps per epoch:    374
# batch size:    768	 batch item length:   48	steps per epoch:    645
# batch size:   1536	 batch item length:   24	steps per epoch:   1215
# batch size:   3072	 batch item length:   12	steps per epoch:   2428
# batch size:   6144	 batch item length:    6	steps per epoch:   4855
# batch size:  12288	 batch item length:    3	steps per epoch:   9709

# %%
model = Model(articles, './training_checkpoints-9',
              vocab_size = subword_text_encoder.vocab_size,
              embedding_dim=32,
              rnn_units=1536)

# %%
model.train(192, 192, epochs=5)
# Out:
# Epoch 1/5
# 271/271 [==============================] - 164s 607ms/step - loss: 4.3676 - average_final_batch_ratio: 0.1144
# Epoch 2/5
# 271/271 [==============================] - 167s 617ms/step - loss: 4.3174 - average_final_batch_ratio: 0.1144
# Epoch 3/5
# 271/271 [==============================] - 167s 617ms/step - loss: 4.1539 - average_final_batch_ratio: 0.1144
# Epoch 4/5
# 271/271 [==============================] - 172s 633ms/step - loss: 4.2858 - average_final_batch_ratio: 0.1144
# Epoch 5/5
# 271/271 [==============================] - 170s 627ms/step - loss: 4.1800 - average_final_batch_ratio: 0.1144

# %%
model.train(192, 192, epochs=5)
# Out:
# Epoch 1/5
# 271/271 [==============================] - 168s 622ms/step - loss: 4.2067 - average_final_batch_ratio: 0.1144
# Epoch 2/5
# 271/271 [==============================] - 169s 623ms/step - loss: 4.2596 - average_final_batch_ratio: 0.1144
# Epoch 3/5
# 271/271 [==============================] - 166s 614ms/step - loss: 4.1029 - average_final_batch_ratio: 0.1144
# Epoch 4/5
# 271/271 [==============================] - 167s 616ms/step - loss: 4.0869 - average_final_batch_ratio: 0.1144
# Epoch 5/5
# 271/271 [==============================] - 167s 615ms/step - loss: 4.0358 - average_final_batch_ratio: 0.1144

# %%
import ctypes

class Huffman:
    huffman = ctypes.CDLL('x64/Release/huffman')
    
    huffman.create_tree.restype = ctypes.c_void_p
    huffman.destroy_tree.restype = None
    huffman.load_weights.restype = None
    huffman.create_code_string.restype = ctypes.c_char_p
    
    def __init__(self, category_count):
        self.tree = ctypes.c_void_p(self.huffman.create_tree(category_count))

    def __del__(self):
        self.huffman.destroy_tree(self.tree)
        
    def load_weights(self, weights):
        self.huffman.load_weights(self.tree, weights.ctypes.data_as(ctypes.POINTER(ctypes.c_float)))
    
    def get_code_length(self, category):
        return self.huffman.get_code_length(self.tree, category)

    def get_code_zero_count(self, category):
        return self.huffman.get_code_zero_count(self.tree, category)

# %%
def huffman_archive_size(model, text):
    archived_size = 0
    zeros = 0
    input_eval = np.array([[0]], dtype=TYPE)
    huffman_tree = Huffman(subword_text_encoder.vocab_size)

    text_generated = []

    model.predicting_model.reset_states()

    for index, byte in enumerate(text):
        predictions = model.predict(input_eval)
        predictions = tf.squeeze(predictions, 0) # remove the batch dimension

        weights = tf.nn.softmax(predictions[0]).numpy()
        huffman_tree.load_weights(weights)
        zeros += huffman_tree.get_code_zero_count(byte.item())
        archived_size += huffman_tree.get_code_length(byte.item())

        input_eval = tf.expand_dims([byte], 0)
  
    return archived_size, zeros

# %%
total_raw = 0
total_compressed = 0

for index, encoded_article in enumerate(articles.articles_generator(1)):
    if index % 10 == 0:
        article = subword_text_encoder.decode(encoded_article)
        raw = len(article) * 8
        if raw == 0:
            continue
        compressed, _ = huffman_archive_size(model, encoded_article)
        total_raw += raw
        total_compressed += compressed

        print('Article %d:\tLength: %d\tCompression: %f\tAvg Compression: %f' % (index, raw, compressed/raw, total_compressed/total_raw))
# Out:
# Article 0:	Length: 128	Compression: 0.507812	Avg Compression: 0.507812
# Article 10:	Length: 144	Compression: 0.604167	Avg Compression: 0.558824
# Article 20:	Length: 152	Compression: 0.368421	Avg Compression: 0.490566
# Article 30:	Length: 160	Compression: 0.593750	Avg Compression: 0.518836
# Article 40:	Length: 160	Compression: 0.462500	Avg Compression: 0.506720
# Article 50:	Length: 168	Compression: 0.494048	Avg Compression: 0.504386
# Article 60:	Length: 168	Compression: 0.511905	Avg Compression: 0.505556
# Article 70:	Length: 176	Compression: 0.471591	Avg Compression: 0.500796
# Article 80:	Length: 176	Compression: 0.494318	Avg Compression: 0.500000
# Article 90:	Length: 184	Compression: 0.505435	Avg Compression: 0.500619
# Article 100:	Length: 184	Compression: 0.456522	Avg Compression: 0.496111
# Article 110:	Length: 192	Compression: 0.401042	Avg Compression: 0.486948
# Article 120:	Length: 192	Compression: 0.458333	Avg Compression: 0.484432
# Article 130:	Length: 200	Compression: 0.695000	Avg Compression: 0.502097
# Article 140:	Length: 200	Compression: 0.510000	Avg Compression: 0.502709
# Article 150:	Length: 208	Compression: 0.442308	Avg Compression: 0.498209
# Article 160:	Length: 208	Compression: 0.562500	Avg Compression: 0.502667
# Article 170:	Length: 216	Compression: 0.527778	Avg Compression: 0.504353
# Article 180:	Length: 216	Compression: 0.555556	Avg Compression: 0.507576
# Article 190:	Length: 224	Compression: 0.473214	Avg Compression: 0.505470
# Article 200:	Length: 224	Compression: 0.495536	Avg Compression: 0.504897
# Article 210:	Length: 232	Compression: 0.530172	Avg Compression: 0.506323
# Article 220:	Length: 232	Compression: 0.620690	Avg Compression: 0.512431
# Article 230:	Length: 240	Compression: 0.545833	Avg Compression: 0.514180
# Article 240:	Length: 240	Compression: 0.466667	Avg Compression: 0.511816
# Article 250:	Length: 248	Compression: 0.520161	Avg Compression: 0.512224
# Article 260:	Length: 256	Compression: 0.546875	Avg Compression: 0.513889
# Article 270:	Length: 256	Compression: 0.406250	Avg Compression: 0.508954
# Article 280:	Length: 256	Compression: 0.421875	Avg Compression: 0.505137
# Article 290:	Length: 256	Compression: 0.542969	Avg Compression: 0.506726
# Article 300:	Length: 264	Compression: 0.462121	Avg Compression: 0.504874
# Article 310:	Length: 264	Compression: 0.431818	Avg Compression: 0.501963
# Article 320:	Length: 272	Compression: 0.529412	Avg Compression: 0.503045
# Article 330:	Length: 272	Compression: 0.411765	Avg Compression: 0.499581
# Article 340:	Length: 272	Compression: 0.463235	Avg Compression: 0.498253
# Article 350:	Length: 272	Compression: 0.459559	Avg Compression: 0.496888
# Article 360:	Length: 280	Compression: 0.450000	Avg Compression: 0.495245
# Article 370:	Length: 280	Compression: 0.492857	Avg Compression: 0.495164
# Article 380:	Length: 288	Compression: 0.510417	Avg Compression: 0.495678
# Article 390:	Length: 288	Compression: 0.604167	Avg Compression: 0.499209
# Article 400:	Length: 296	Compression: 0.523649	Avg Compression: 0.500000
# Article 410:	Length: 296	Compression: 0.500000	Avg Compression: 0.500000
# Article 420:	Length: 304	Compression: 0.348684	Avg Compression: 0.495279
# Article 430:	Length: 312	Compression: 0.291667	Avg Compression: 0.488962
# Article 440:	Length: 320	Compression: 0.465625	Avg Compression: 0.488242
# Article 450:	Length: 328	Compression: 0.408537	Avg Compression: 0.485800
# Article 460:	Length: 336	Compression: 0.482143	Avg Compression: 0.485688
# Article 470:	Length: 440	Compression: 0.429545	Avg Compression: 0.483537
# Article 480:	Length: 344	Compression: 0.645349	Avg Compression: 0.488244
# Article 490:	Length: 368	Compression: 0.510870	Avg Compression: 0.488927
# Article 500:	Length: 392	Compression: 0.438776	Avg Compression: 0.487365
# Article 510:	Length: 416	Compression: 0.538462	Avg Compression: 0.489000
# Article 520:	Length: 432	Compression: 0.307870	Avg Compression: 0.483175
# Article 530:	Length: 488	Compression: 0.467213	Avg Compression: 0.482615
# Article 540:	Length: 608	Compression: 0.496711	Avg Compression: 0.483205
# Article 550:	Length: 1696	Compression: 0.632665	Avg Compression: 0.498829
# Article 560:	Length: 2608	Compression: 0.684049	Avg Compression: 0.524480
# Article 570:	Length: 3256	Compression: 0.559275	Avg Compression: 0.529609
# Article 580:	Length: 4032	Compression: 0.523810	Avg Compression: 0.528714
# Article 590:	Length: 4616	Compression: 0.487652	Avg Compression: 0.522547
# Article 600:	Length: 5080	Compression: 0.487992	Avg Compression: 0.517646
# Article 610:	Length: 5552	Compression: 0.485951	Avg Compression: 0.513392
# Article 620:	Length: 5928	Compression: 0.613360	Avg Compression: 0.525922
# Article 630:	Length: 6480	Compression: 0.591512	Avg Compression: 0.533825
# Article 640:	Length: 6720	Compression: 0.526042	Avg Compression: 0.532961
# Article 650:	Length: 6960	Compression: 0.558621	Avg Compression: 0.535608
# Article 660:	Length: 7824	Compression: 0.545629	Avg Compression: 0.536650
# Article 670:	Length: 8360	Compression: 0.572847	Avg Compression: 0.540268
# Article 680:	Length: 8824	Compression: 0.535358	Avg Compression: 0.539799
# Article 690:	Length: 9288	Compression: 0.500754	Avg Compression: 0.536235
# Article 700:	Length: 9920	Compression: 0.517137	Avg Compression: 0.534539
# Article 710:	Length: 10552	Compression: 0.539898	Avg Compression: 0.535001
# Article 720:	Length: 11056	Compression: 0.487247	Avg Compression: 0.531040
# Article 730:	Length: 11776	Compression: 0.527259	Avg Compression: 0.530733
# Article 740:	Length: 12424	Compression: 0.481809	Avg Compression: 0.526873
# Article 750:	Length: 12944	Compression: 0.475201	Avg Compression: 0.522949
# Article 760:	Length: 13472	Compression: 0.586698	Avg Compression: 0.527619
# Article 770:	Length: 13888	Compression: 0.444340	Avg Compression: 0.521771
# Article 780:	Length: 14096	Compression: 0.579597	Avg Compression: 0.525618
# Article 790:	Length: 14800	Compression: 0.506622	Avg Compression: 0.524378
# Article 800:	Length: 15200	Compression: 0.603618	Avg Compression: 0.529358
# Article 810:	Length: 16024	Compression: 0.543997	Avg Compression: 0.530267
# Article 820:	Length: 16336	Compression: 0.515610	Avg Compression: 0.529394
# Article 830:	Length: 16904	Compression: 0.479117	Avg Compression: 0.526475
# Article 840:	Length: 17192	Compression: 0.565437	Avg Compression: 0.528647
# Article 850:	Length: 17632	Compression: 0.575147	Avg Compression: 0.531163
# Article 860:	Length: 17736	Compression: 0.498647	Avg Compression: 0.529485
# Article 870:	Length: 18408	Compression: 0.488049	Avg Compression: 0.527378
# Article 880:	Length: 18944	Compression: 0.536793	Avg Compression: 0.527846
# Article 890:	Length: 19320	Compression: 0.511180	Avg Compression: 0.527042
# Article 900:	Length: 20120	Compression: 0.511879	Avg Compression: 0.526317
# Article 910:	Length: 20368	Compression: 0.497545	Avg Compression: 0.524987
# Article 920:	Length: 20560	Compression: 0.580156	Avg Compression: 0.527445
# Article 930:	Length: 21408	Compression: 0.536295	Avg Compression: 0.527838
# Article 940:	Length: 22352	Compression: 0.584154	Avg Compression: 0.530330
# Article 950:	Length: 23192	Compression: 0.531175	Avg Compression: 0.530367
# Article 960:	Length: 23776	Compression: 0.472914	Avg Compression: 0.527893
# Article 970:	Length: 24192	Compression: 0.570767	Avg Compression: 0.529692
# Article 980:	Length: 25624	Compression: 0.485717	Avg Compression: 0.527820
# Article 990:	Length: 26680	Compression: 0.499475	Avg Compression: 0.526617
# Article 1000:	Length: 27224	Compression: 0.492543	Avg Compression: 0.525203
# Article 1010:	Length: 28328	Compression: 0.462793	Avg Compression: 0.522619
# Article 1020:	Length: 28416	Compression: 0.529490	Avg Compression: 0.522893
# Article 1030:	Length: 29016	Compression: 0.534981	Avg Compression: 0.523366
# Article 1040:	Length: 29920	Compression: 0.515541	Avg Compression: 0.523063
# Article 1050:	Length: 30600	Compression: 0.524052	Avg Compression: 0.523100
# Article 1060:	Length: 30488	Compression: 0.579539	Avg Compression: 0.525167
# Article 1070:	Length: 32032	Compression: 0.528815	Avg Compression: 0.525302
# Article 1080:	Length: 33016	Compression: 0.522383	Avg Compression: 0.525195
# Article 1090:	Length: 33472	Compression: 0.523721	Avg Compression: 0.525142
# Article 1100:	Length: 34536	Compression: 0.503330	Avg Compression: 0.524362
# Article 1110:	Length: 35264	Compression: 0.524473	Avg Compression: 0.524366
# Article 1120:	Length: 35736	Compression: 0.527871	Avg Compression: 0.524486
# Article 1130:	Length: 36448	Compression: 0.573200	Avg Compression: 0.526141
# Article 1140:	Length: 37448	Compression: 0.503685	Avg Compression: 0.525384
# Article 1150:	Length: 38424	Compression: 0.536748	Avg Compression: 0.525764
# Article 1160:	Length: 38680	Compression: 0.600155	Avg Compression: 0.528187
# Article 1170:	Length: 40216	Compression: 0.505868	Avg Compression: 0.527456
# Article 1180:	Length: 41480	Compression: 0.606075	Avg Compression: 0.530025
# Article 1190:	Length: 42616	Compression: 0.502534	Avg Compression: 0.529132
# Article 1200:	Length: 43488	Compression: 0.568824	Avg Compression: 0.530405
# Article 1210:	Length: 45080	Compression: 0.486979	Avg Compression: 0.529007
# Article 1220:	Length: 46864	Compression: 0.505868	Avg Compression: 0.528258
# Article 1230:	Length: 48608	Compression: 0.493334	Avg Compression: 0.527123
# Article 1240:	Length: 50264	Compression: 0.520571	Avg Compression: 0.526910
# Article 1250:	Length: 51272	Compression: 0.515701	Avg Compression: 0.526551
# Article 1260:	Length: 52528	Compression: 0.515953	Avg Compression: 0.526213
# Article 1270:	Length: 53688	Compression: 0.524829	Avg Compression: 0.526170
# Article 1280:	Length: 54640	Compression: 0.512244	Avg Compression: 0.525737
# Article 1290:	Length: 55440	Compression: 0.553247	Avg Compression: 0.526578
# Article 1300:	Length: 56320	Compression: 0.538317	Avg Compression: 0.526931
# Article 1720:	Length: 164208	Compression: 0.528707	Avg Compression: 0.522713
# Article 1730:	Length: 174464	Compression: 0.507755	Avg Compression: 0.522300
# Article 1740:	Length: 189072	Compression: 0.538879	Avg Compression: 0.522781
# Article 1750:	Length: 195080	Compression: 0.466855	Avg Compression: 0.521155
# Article 1760:	Length: 202592	Compression: 0.481979	Avg Compression: 0.520006
# Article 1770:	Length: 213160	Compression: 0.491115	Avg Compression: 0.519142
# Article 1780:	Length: 220440	Compression: 0.487117	Avg Compression: 0.518180
# Article 1790:	Length: 229744	Compression: 0.534182	Avg Compression: 0.518666
# Article 1800:	Length: 246304	Compression: 0.505883	Avg Compression: 0.518263
# Article 1810:	Length: 251304	Compression: 0.514660	Avg Compression: 0.518151
# Article 1820:	Length: 268336	Compression: 0.518406	Avg Compression: 0.518159
# Article 1830:	Length: 283192	Compression: 0.511639	Avg Compression: 0.517945
# Article 1840:	Length: 307368	Compression: 0.475619	Avg Compression: 0.516488
# Article 1850:	Length: 323168	Compression: 0.462447	Avg Compression: 0.514601
# Article 1860:	Length: 341176	Compression: 0.516745	Avg Compression: 0.514677
# Article 1870:	Length: 382048	Compression: 0.503594	Avg Compression: 0.514252
# Article 1880:	Length: 441872	Compression: 0.663079	Avg Compression: 0.520565
# Article 1890:	Length: 508896	Compression: 0.486044	Avg Compression: 0.518957

# %%
model.train(192, 192, epochs=20)
# Out:
# Epoch 1/20
# 271/271 [==============================] - 170s 627ms/step - loss: 3.9705 - average_final_batch_ratio: 0.1144
# Epoch 2/20
# 271/271 [==============================] - 167s 616ms/step - loss: 4.0405 - average_final_batch_ratio: 0.1144
# Epoch 3/20
# 271/271 [==============================] - 167s 617ms/step - loss: 3.9557 - average_final_batch_ratio: 0.1144

# %%
model.train(192, 192, epochs=17)
# Out:
# Epoch 1/17
# 271/271 [==============================] - 181s 669ms/step - loss: 3.9507 - average_final_batch_ratio: 0.1107
# Epoch 2/17
# 271/271 [==============================] - 180s 663ms/step - loss: 3.9580 - average_final_batch_ratio: 0.1107
# Epoch 3/17
# 271/271 [==============================] - 180s 666ms/step - loss: 3.9579 - average_final_batch_ratio: 0.1107
# Epoch 4/17
# 271/271 [==============================] - 171s 632ms/step - loss: 3.9142 - average_final_batch_ratio: 0.1107
# Epoch 5/17
# 271/271 [==============================] - 169s 624ms/step - loss: 3.9689 - average_final_batch_ratio: 0.1107
# Epoch 6/17
# 271/271 [==============================] - 171s 632ms/step - loss: 3.9642 - average_final_batch_ratio: 0.1107
# Epoch 7/17
# 271/271 [==============================] - 171s 629ms/step - loss: 3.9935 - average_final_batch_ratio: 0.1107
# Epoch 8/17
#   1/271 [..............................] - ETA: 50s
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-7-8fe2d3e40b95> in <module>
# ----> 1 model.train(192, 192, epochs=17)
#
# <ipython-input-3-52b93ebffef2> in train(self, batch_size, batched_item_length, epochs)
#      68         model = self.training_model(batch_size, batched_item_length)
#      69
# ---> 70         model.fit(dataset, epochs=epochs, callbacks=self.callbacks)
#      71
#      72     @property
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     395                       total_epochs=1)
#     396                   cbks.make_logs(model, epoch_logs, eval_result, ModeKeys.TEST,
# --> 397                                  prefix='val_')
#     398
#     399     return model.history
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\contextlib.py in __exit__(self, type, value, traceback)
#     128                 value = type()
#     129             try:
# --> 130                 self.gen.throw(type, value, traceback)
#     131             except StopIteration as exc:
#     132                 # Suppress StopIteration *unless* it's the same exception that
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in on_epoch(self, epoch, mode)
#     769       if mode == ModeKeys.TRAIN:
#     770         # Epochs only apply to `fit`.
# --> 771         self.callbacks.on_epoch_end(epoch, epoch_logs)
#     772       self.progbar.on_epoch_end(epoch, epoch_logs)
#     773
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     300     logs = logs or {}
#     301     for callback in self.callbacks:
# --> 302       callback.on_epoch_end(epoch, logs)
#     303
#     304   def on_train_batch_begin(self, batch, logs=None):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     990           self._save_model(epoch=epoch, logs=logs)
#     991       else:
# --> 992         self._save_model(epoch=epoch, logs=logs)
#     993     if self.model._in_multi_worker_mode():
#     994       # For multi-worker training, back up the weights and current training
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\callbacks.py in _save_model(self, epoch, logs)
#    1036             print('\nEpoch %05d: saving model to %s' % (epoch + 1, filepath))
#    1037           if self.save_weights_only:
# -> 1038             self.model.save_weights(filepath, overwrite=True)
#    1039           else:
#    1040             self.model.save(filepath, overwrite=True)
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\network.py in save_weights(self, filepath, overwrite, save_format)
#    1121              'saved.\n\nConsider using a TensorFlow optimizer from `tf.train`.')
#    1122             % (optimizer,))
# -> 1123       self._trackable_saver.save(filepath, session=session)
#    1124       # Record this checkpoint so it's visible from tf.train.latest_checkpoint.
#    1125       checkpoint_management.update_checkpoint_state_internal(
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\tracking\util.py in save(self, file_prefix, checkpoint_number, session)
#    1166     file_io.recursive_create_dir(os.path.dirname(file_prefix))
#    1167     save_path, new_feed_additions = self._save_cached_when_graph_building(
# -> 1168         file_prefix=file_prefix_tensor, object_graph_tensor=object_graph_tensor)
#    1169     if new_feed_additions:
#    1170       feed_dict.update(new_feed_additions)
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\tracking\util.py in _save_cached_when_graph_building(self, file_prefix, object_graph_tensor)
#    1114         or context.executing_eagerly() or ops.inside_function()):
#    1115       saver = functional_saver.MultiDeviceSaver(named_saveable_objects)
# -> 1116       save_op = saver.save(file_prefix)
#    1117       with ops.device("/cpu:0"):
#    1118         with ops.control_dependencies([save_op]):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\functional_saver.py in save(self, file_prefix)
#     228         # _SingleDeviceSaver will use the CPU device when necessary, but initial
#     229         # read operations should be placed on the SaveableObject's device.
# --> 230         sharded_saves.append(saver.save(shard_prefix))
#     231
#     232     with ops.control_dependencies(sharded_saves):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\functional_saver.py in save(self, file_prefix)
#      67       for spec in saveable.specs:
#      68         tensor_names.append(spec.name)
# ---> 69         tensors.append(spec.tensor)
#      70         tensor_slices.append(spec.slice_spec)
#      71     with ops.device("cpu:0"):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\saveable_object.py in tensor(self)
#      50   @property
#      51   def tensor(self):
# ---> 52     return self._tensor() if callable(self._tensor) else self._tensor
#      53
#      54
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\saveable_object_util.py in f()
#      93             # we copy them to CPU on the same machine first.
#      94             with ops.device("/device:CPU:0"):
# ---> 95               return array_ops.identity(x)
#      96         return f
#      97
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\util\dispatch.py in wrapper(*args, **kwargs)
#     178     """Call target, and fall back on dispatchers if there is a TypeError."""
#     179     try:
# --> 180       return target(*args, **kwargs)
#     181     except (TypeError, ValueError):
#     182       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\ops\array_ops.py in identity(input, name)
#     265     # variables. Variables have correct handle data when graph building.
#     266     input = ops.convert_to_tensor(input)
# --> 267   ret = gen_array_ops.identity(input, name=name)
#     268   # Propagate handle data for happier shape inference for resource variables.
#     269   if hasattr(input, "_handle_data"):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\ops\gen_array_ops.py in identity(input, name)
#    3824         pass  # Add nodes to the TensorFlow graph.
#    3825     except _core._NotOkStatusException as e:
# -> 3826       _ops.raise_from_not_ok_status(e, name)
#    3827   # Add nodes to the TensorFlow graph.
#    3828   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\framework\ops.py in raise_from_not_ok_status(e, name)
#    6604   message = e.message + (" name: " + name if name is not None else "")
#    6605   # pylint: disable=protected-access
# -> 6606   six.raise_from(core._status_to_exception(e.code, message), None)
#    6607   # pylint: enable=protected-access
#    6608
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\six.py in raise_from(value, from_value)
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:GPU:0 to /job:localhost/replica:0/task:0/device:CPU:0 in order to run Identity: GPU sync failed [Op:Identity]

# %%
model.train(192, 192, epochs=9)
# Out:
# Epoch 1/9
# 271/271 [==============================] - 170s 627ms/step - loss: 3.8014 - average_final_batch_ratio: 0.1144
# Epoch 2/9
# 271/271 [==============================] - 166s 613ms/step - loss: 3.7963 - average_final_batch_ratio: 0.1144
# Epoch 3/9
# 271/271 [==============================] - 167s 617ms/step - loss: 3.7059 - average_final_batch_ratio: 0.1144
# Epoch 4/9
# 271/271 [==============================] - 167s 617ms/step - loss: 3.5913 - average_final_batch_ratio: 0.1144
# Epoch 5/9
# 271/271 [==============================] - 174s 641ms/step - loss: 3.4915 - average_final_batch_ratio: 0.1144
# Epoch 6/9
# 271/271 [==============================] - 169s 623ms/step - loss: 3.3762 - average_final_batch_ratio: 0.1144
# Epoch 7/9
# 271/271 [==============================] - 169s 623ms/step - loss: 3.3169 - average_final_batch_ratio: 0.1144
# Epoch 8/9
# 271/271 [==============================] - 168s 621ms/step - loss: 3.2572 - average_final_batch_ratio: 0.1144
# Epoch 9/9
# 271/271 [==============================] - 167s 616ms/step - loss: 3.2085 - average_final_batch_ratio: 0.1144

# %%
total_raw = 0
total_compressed = 0

for index, encoded_article in enumerate(articles.articles_generator(1)):
    if index % 10 == 0:
        article = subword_text_encoder.decode(encoded_article)
        raw = len(article) * 8
        if raw == 0:
            continue
        compressed, _ = huffman_archive_size(model, encoded_article)
        total_raw += raw
        total_compressed += compressed

        print('Article %d:\tLength: %d\tCompression: %f\tAvg Compression: %f' % (index, raw, compressed/raw, total_compressed/total_raw))
# Out:
# Article 0:	Length: 128	Compression: 0.406250	Avg Compression: 0.406250
# Article 10:	Length: 144	Compression: 0.368056	Avg Compression: 0.386029
# Article 20:	Length: 152	Compression: 0.394737	Avg Compression: 0.389151
# Article 30:	Length: 160	Compression: 0.331250	Avg Compression: 0.373288
# Article 40:	Length: 152	Compression: 0.605263	Avg Compression: 0.421196
# Article 50:	Length: 168	Compression: 0.386905	Avg Compression: 0.414823
# Article 60:	Length: 168	Compression: 0.386905	Avg Compression: 0.410448
# Article 70:	Length: 176	Compression: 0.363636	Avg Compression: 0.403846
# Article 80:	Length: 176	Compression: 0.380682	Avg Compression: 0.400983
# Article 90:	Length: 184	Compression: 0.364130	Avg Compression: 0.396766
# Article 100:	Length: 184	Compression: 0.494565	Avg Compression: 0.406808
# Article 110:	Length: 192	Compression: 0.343750	Avg Compression: 0.400706
# Article 120:	Length: 192	Compression: 0.411458	Avg Compression: 0.401654
# Article 130:	Length: 200	Compression: 0.410000	Avg Compression: 0.402357
# Article 140:	Length: 200	Compression: 0.510000	Avg Compression: 0.410714
# Article 150:	Length: 208	Compression: 0.278846	Avg Compression: 0.400862
# Article 160:	Length: 208	Compression: 0.413462	Avg Compression: 0.401738
# Article 170:	Length: 216	Compression: 0.513889	Avg Compression: 0.409289
# Article 180:	Length: 216	Compression: 0.412037	Avg Compression: 0.409463
# Article 190:	Length: 224	Compression: 0.406250	Avg Compression: 0.409265
# Article 200:	Length: 224	Compression: 0.383929	Avg Compression: 0.407800
# Article 210:	Length: 232	Compression: 0.474138	Avg Compression: 0.411550
# Article 220:	Length: 232	Compression: 0.443966	Avg Compression: 0.413284
# Article 230:	Length: 240	Compression: 0.370833	Avg Compression: 0.411058
# Article 240:	Length: 240	Compression: 0.487500	Avg Compression: 0.414867
# Article 250:	Length: 248	Compression: 0.387097	Avg Compression: 0.413507
# Article 260:	Length: 256	Compression: 0.394531	Avg Compression: 0.412594
# Article 270:	Length: 256	Compression: 0.394531	Avg Compression: 0.411765
# Article 280:	Length: 248	Compression: 0.673387	Avg Compression: 0.422905
# Article 290:	Length: 256	Compression: 0.359375	Avg Compression: 0.420230
# Article 300:	Length: 264	Compression: 0.352273	Avg Compression: 0.417402
# Article 310:	Length: 264	Compression: 0.469697	Avg Compression: 0.419492
# Article 320:	Length: 272	Compression: 0.433824	Avg Compression: 0.420058
# Article 330:	Length: 272	Compression: 0.360294	Avg Compression: 0.417785
# Article 340:	Length: 272	Compression: 0.371324	Avg Compression: 0.416083
# Article 350:	Length: 320	Compression: 0.396875	Avg Compression: 0.415289
# Article 360:	Length: 280	Compression: 0.360714	Avg Compression: 0.413385
# Article 370:	Length: 280	Compression: 0.407143	Avg Compression: 0.413174
# Article 380:	Length: 288	Compression: 0.447917	Avg Compression: 0.414339
# Article 1650:	Length: 132816	Compression: 0.372161	Avg Compression: 0.433704
# Article 1660:	Length: 134584	Compression: 0.443923	Avg Compression: 0.433967
# Article 1670:	Length: 141472	Compression: 0.381270	Avg Compression: 0.432578
# Article 1680:	Length: 146472	Compression: 0.443716	Avg Compression: 0.432874
# Article 1690:	Length: 151840	Compression: 0.440141	Avg Compression: 0.433069
# Article 1700:	Length: 157048	Compression: 0.499898	Avg Compression: 0.434872
# Article 1710:	Length: 161424	Compression: 0.433380	Avg Compression: 0.434832
# Article 1720:	Length: 164208	Compression: 0.455209	Avg Compression: 0.435376
# Article 1730:	Length: 174464	Compression: 0.453234	Avg Compression: 0.435869
# Article 1740:	Length: 189072	Compression: 0.458624	Avg Compression: 0.436530
# Article 1750:	Length: 195080	Compression: 0.381869	Avg Compression: 0.434939
# Article 1760:	Length: 202592	Compression: 0.407346	Avg Compression: 0.434130
# Article 1770:	Length: 213160	Compression: 0.436039	Avg Compression: 0.434187
# Article 1780:	Length: 220440	Compression: 0.399075	Avg Compression: 0.433133
# Article 1790:	Length: 229744	Compression: 0.457409	Avg Compression: 0.433870
# Article 1800:	Length: 246304	Compression: 0.409798	Avg Compression: 0.433111
# Article 1810:	Length: 251304	Compression: 0.423618	Avg Compression: 0.432816
# Article 1820:	Length: 268336	Compression: 0.464034	Avg Compression: 0.433820
# Article 1830:	Length: 283192	Compression: 0.423335	Avg Compression: 0.433476
# Article 1840:	Length: 307368	Compression: 0.390467	Avg Compression: 0.431995
# Article 1850:	Length: 323168	Compression: 0.387752	Avg Compression: 0.430450
# Article 1860:	Length: 341176	Compression: 0.440104	Avg Compression: 0.430793
# Article 1870:	Length: 382048	Compression: 0.411210	Avg Compression: 0.430043
# Article 1880:	Length: 441872	Compression: 0.641491	Avg Compression: 0.439013
# Article 1890:	Length: 508896	Compression: 0.407394	Avg Compression: 0.437540

# %%
model.train(192, 192, epochs=20)
# Out:
# Epoch 1/20
# 271/271 [==============================] - 175s 647ms/step - loss: 3.1742 - average_final_batch_ratio: 0.1144
# Epoch 2/20
# 271/271 [==============================] - 166s 611ms/step - loss: 3.1499 - average_final_batch_ratio: 0.1144
# Epoch 3/20
# 271/271 [==============================] - 167s 618ms/step - loss: 3.1165 - average_final_batch_ratio: 0.1144
# Epoch 4/20
# 271/271 [==============================] - 167s 618ms/step - loss: 3.1100 - average_final_batch_ratio: 0.1144
# Epoch 5/20
# 271/271 [==============================] - 169s 623ms/step - loss: 3.0744 - average_final_batch_ratio: 0.1144
# Epoch 6/20
# 271/271 [==============================] - 168s 619ms/step - loss: 3.0456 - average_final_batch_ratio: 0.1144
# Epoch 7/20
# 271/271 [==============================] - 168s 620ms/step - loss: 3.0349 - average_final_batch_ratio: 0.1144
# Epoch 8/20
# 271/271 [==============================] - 168s 619ms/step - loss: 3.0256 - average_final_batch_ratio: 0.1144
# Epoch 9/20
# 271/271 [==============================] - 168s 619ms/step - loss: 3.0058 - average_final_batch_ratio: 0.1144
# Epoch 10/20
# 271/271 [==============================] - 169s 623ms/step - loss: 2.9990 - average_final_batch_ratio: 0.1144
# Epoch 11/20
# 271/271 [==============================] - 169s 623ms/step - loss: 2.9710 - average_final_batch_ratio: 0.1144
# Epoch 12/20
# 271/271 [==============================] - 171s 633ms/step - loss: 2.9563 - average_final_batch_ratio: 0.1144
# Epoch 13/20
# 271/271 [==============================] - 168s 621ms/step - loss: 2.9491 - average_final_batch_ratio: 0.1144
# Epoch 14/20
# 271/271 [==============================] - 168s 619ms/step - loss: 2.9310 - average_final_batch_ratio: 0.1144
# Epoch 15/20
# 271/271 [==============================] - 168s 621ms/step - loss: 2.9225 - average_final_batch_ratio: 0.1144
# Epoch 16/20
# 271/271 [==============================] - 170s 627ms/step - loss: 2.9048 - average_final_batch_ratio: 0.1144
# Epoch 17/20
# 271/271 [==============================] - 167s 617ms/step - loss: 2.8856 - average_final_batch_ratio: 0.1144
# Epoch 18/20
# 271/271 [==============================] - 173s 637ms/step - loss: 2.8894 - average_final_batch_ratio: 0.1144
# Epoch 19/20
# 271/271 [==============================] - 183s 676ms/step - loss: 2.8580 - average_final_batch_ratio: 0.1144
# Epoch 20/20
# 271/271 [==============================] - 172s 636ms/step - loss: 2.8540 - average_final_batch_ratio: 0.1144

# %%
total_raw = 0
total_compressed = 0

for index, encoded_article in enumerate(articles.articles_generator(1)):
    if index % 10 == 0:
        article = subword_text_encoder.decode(encoded_article)
        raw = len(article) * 8
        if raw == 0:
            continue
        compressed, _ = huffman_archive_size(model, encoded_article)
        total_raw += raw
        total_compressed += compressed

        print('Article %d:\tLength: %d\tCompression: %f\tAvg Compression: %f' % (index, raw, compressed/raw, total_compressed/total_raw))
# Out:
# Article 0:	Length: 128	Compression: 0.445312	Avg Compression: 0.445312
# Article 10:	Length: 144	Compression: 0.409722	Avg Compression: 0.426471
# Article 20:	Length: 152	Compression: 0.473684	Avg Compression: 0.443396
# Article 30:	Length: 160	Compression: 0.468750	Avg Compression: 0.450342
# Article 40:	Length: 160	Compression: 0.581250	Avg Compression: 0.478495
# Article 50:	Length: 168	Compression: 0.458333	Avg Compression: 0.474781
# Article 60:	Length: 168	Compression: 0.398810	Avg Compression: 0.462963
# Article 70:	Length: 176	Compression: 0.397727	Avg Compression: 0.453822
# Article 80:	Length: 176	Compression: 0.500000	Avg Compression: 0.459497
# Article 90:	Length: 184	Compression: 0.554348	Avg Compression: 0.470297
# Article 100:	Length: 184	Compression: 0.489130	Avg Compression: 0.472222
# Article 110:	Length: 192	Compression: 0.411458	Avg Compression: 0.466365
# Article 120:	Length: 192	Compression: 0.354167	Avg Compression: 0.456502
# Article 130:	Length: 200	Compression: 0.525000	Avg Compression: 0.462248
# Article 140:	Length: 200	Compression: 0.435000	Avg Compression: 0.460139
# Article 150:	Length: 208	Compression: 0.399038	Avg Compression: 0.455587
# Article 160:	Length: 208	Compression: 0.413462	Avg Compression: 0.452667
# Article 170:	Length: 216	Compression: 0.444444	Avg Compression: 0.452114
# Article 180:	Length: 264	Compression: 0.386364	Avg Compression: 0.447126
# Article 190:	Length: 224	Compression: 0.406250	Avg Compression: 0.444654
# Article 200:	Length: 224	Compression: 0.392857	Avg Compression: 0.441701
# Article 210:	Length: 232	Compression: 0.456897	Avg Compression: 0.442548
# Article 220:	Length: 232	Compression: 0.456897	Avg Compression: 0.443306
# Article 230:	Length: 240	Compression: 0.383333	Avg Compression: 0.440199
# Article 240:	Length: 240	Compression: 0.383333	Avg Compression: 0.437397
# Article 250:	Length: 248	Compression: 0.395161	Avg Compression: 0.435352
# Article 260:	Length: 256	Compression: 0.523438	Avg Compression: 0.439546
# Article 270:	Length: 256	Compression: 0.375000	Avg Compression: 0.436612
# Article 280:	Length: 256	Compression: 0.449219	Avg Compression: 0.437160
# Article 290:	Length: 256	Compression: 0.507812	Avg Compression: 0.440104
# Article 300:	Length: 264	Compression: 0.325758	Avg Compression: 0.435393
# Article 310:	Length: 264	Compression: 0.428030	Avg Compression: 0.435102
# Article 320:	Length: 264	Compression: 0.590909	Avg Compression: 0.441032
# Article 330:	Length: 272	Compression: 0.386029	Avg Compression: 0.438957
# Article 340:	Length: 272	Compression: 0.356618	Avg Compression: 0.435963
# Article 350:	Length: 272	Compression: 0.488971	Avg Compression: 0.437822
# Article 360:	Length: 280	Compression: 0.496429	Avg Compression: 0.439866
# Article 370:	Length: 280	Compression: 0.400000	Avg Compression: 0.438523
# Article 380:	Length: 288	Compression: 0.413194	Avg Compression: 0.437674
# Article 390:	Length: 288	Compression: 0.270833	Avg Compression: 0.432268
# Article 400:	Length: 296	Compression: 0.402027	Avg Compression: 0.431294
# Article 410:	Length: 296	Compression: 0.567568	Avg Compression: 0.435549
# Article 420:	Length: 304	Compression: 0.296053	Avg Compression: 0.431214
# Article 430:	Length: 312	Compression: 0.342949	Avg Compression: 0.428487
# Article 440:	Length: 320	Compression: 0.296875	Avg Compression: 0.424443
# Article 450:	Length: 328	Compression: 0.435976	Avg Compression: 0.424795
# Article 460:	Length: 336	Compression: 0.410714	Avg Compression: 0.424368
# Article 470:	Length: 440	Compression: 0.375000	Avg Compression: 0.422483
# Article 480:	Length: 344	Compression: 0.561047	Avg Compression: 0.426500
# Article 490:	Length: 368	Compression: 0.445652	Avg Compression: 0.427077
# Article 500:	Length: 392	Compression: 0.479592	Avg Compression: 0.428707
# Article 510:	Length: 416	Compression: 0.480769	Avg Compression: 0.430368
# Article 520:	Length: 432	Compression: 0.416667	Avg Compression: 0.429929
# Article 530:	Length: 488	Compression: 0.383197	Avg Compression: 0.428295
# Article 540:	Length: 608	Compression: 0.384868	Avg Compression: 0.426483
# Article 550:	Length: 1696	Compression: 0.444575	Avg Compression: 0.428369
# Article 560:	Length: 2608	Compression: 0.483512	Avg Compression: 0.435990
# Article 570:	Length: 3256	Compression: 0.451781	Avg Compression: 0.438313
# Article 580:	Length: 4032	Compression: 0.454117	Avg Compression: 0.440749
# Article 590:	Length: 4616	Compression: 0.387782	Avg Compression: 0.432805
# Article 600:	Length: 5080	Compression: 0.373819	Avg Compression: 0.424448
# Article 610:	Length: 5552	Compression: 0.395713	Avg Compression: 0.420595
# Article 620:	Length: 5944	Compression: 0.537180	Avg Compression: 0.435230
# Article 630:	Length: 6480	Compression: 0.497222	Avg Compression: 0.442692
# Article 640:	Length: 6720	Compression: 0.428720	Avg Compression: 0.441141
# Article 650:	Length: 6960	Compression: 0.418966	Avg Compression: 0.438855
# Article 660:	Length: 7824	Compression: 0.472776	Avg Compression: 0.442378
# Article 670:	Length: 8360	Compression: 0.452990	Avg Compression: 0.443438
# Article 680:	Length: 8824	Compression: 0.429850	Avg Compression: 0.442142
# Article 690:	Length: 9288	Compression: 0.379307	Avg Compression: 0.436410
# Article 700:	Length: 9920	Compression: 0.410282	Avg Compression: 0.434090
# Article 710:	Length: 10552	Compression: 0.429208	Avg Compression: 0.433669
# Article 720:	Length: 11056	Compression: 0.373372	Avg Compression: 0.428669
# Article 730:	Length: 11776	Compression: 0.405146	Avg Compression: 0.426760
# Article 740:	Length: 12424	Compression: 0.372827	Avg Compression: 0.422507
# Article 750:	Length: 12944	Compression: 0.366811	Avg Compression: 0.418278
# Article 760:	Length: 13472	Compression: 0.488272	Avg Compression: 0.423404
# Article 770:	Length: 13888	Compression: 0.340510	Avg Compression: 0.417585
# Article 780:	Length: 14096	Compression: 0.441331	Avg Compression: 0.419164
# Article 790:	Length: 14800	Compression: 0.408784	Avg Compression: 0.418487
# Article 800:	Length: 15200	Compression: 0.520461	Avg Compression: 0.424893
# Article 810:	Length: 16024	Compression: 0.427484	Avg Compression: 0.425054
# Article 820:	Length: 16336	Compression: 0.397588	Avg Compression: 0.423418
# Article 830:	Length: 16904	Compression: 0.381566	Avg Compression: 0.420989
# Article 840:	Length: 17192	Compression: 0.461377	Avg Compression: 0.423241
# Article 850:	Length: 17632	Compression: 0.485594	Avg Compression: 0.426613
# Article 860:	Length: 17736	Compression: 0.394114	Avg Compression: 0.424936
# Article 870:	Length: 18408	Compression: 0.368209	Avg Compression: 0.422053
# Article 880:	Length: 18944	Compression: 0.402449	Avg Compression: 0.421078
# Article 890:	Length: 19320	Compression: 0.465942	Avg Compression: 0.423243
# Article 900:	Length: 20120	Compression: 0.393489	Avg Compression: 0.421819
# Article 910:	Length: 20368	Compression: 0.393951	Avg Compression: 0.420532
# Article 920:	Length: 20560	Compression: 0.431615	Avg Compression: 0.421026
# Article 930:	Length: 21408	Compression: 0.413117	Avg Compression: 0.420675
# Article 940:	Length: 22352	Compression: 0.493289	Avg Compression: 0.423888
# Article 950:	Length: 23192	Compression: 0.436357	Avg Compression: 0.424435
# Article 960:	Length: 23776	Compression: 0.343371	Avg Compression: 0.420945
# Article 970:	Length: 24192	Compression: 0.410590	Avg Compression: 0.420510
# Article 980:	Length: 25624	Compression: 0.371410	Avg Compression: 0.418420
# Article 990:	Length: 26592	Compression: 0.413809	Avg Compression: 0.418225
# Article 1000:	Length: 27224	Compression: 0.373200	Avg Compression: 0.416356
# Article 1010:	Length: 28328	Compression: 0.355726	Avg Compression: 0.413846
# Article 1020:	Length: 28416	Compression: 0.404878	Avg Compression: 0.413488
# Article 1030:	Length: 29016	Compression: 0.402985	Avg Compression: 0.413077
# Article 1040:	Length: 29920	Compression: 0.400201	Avg Compression: 0.412578
# Article 1050:	Length: 30600	Compression: 0.432843	Avg Compression: 0.413351
# Article 1060:	Length: 30488	Compression: 0.417377	Avg Compression: 0.413498
# Article 1070:	Length: 32032	Compression: 0.415990	Avg Compression: 0.413591
# Article 1080:	Length: 33016	Compression: 0.424158	Avg Compression: 0.413979
# Article 1090:	Length: 33472	Compression: 0.373506	Avg Compression: 0.412524
# Article 1100:	Length: 34536	Compression: 0.389854	Avg Compression: 0.411714
# Article 1110:	Length: 35264	Compression: 0.410163	Avg Compression: 0.411659
# Article 1120:	Length: 35736	Compression: 0.392070	Avg Compression: 0.410984
# Article 1130:	Length: 36448	Compression: 0.446828	Avg Compression: 0.412201
# Article 1140:	Length: 37448	Compression: 0.383332	Avg Compression: 0.411228
# Article 1150:	Length: 38424	Compression: 0.410603	Avg Compression: 0.411207
# Article 1160:	Length: 38680	Compression: 0.533195	Avg Compression: 0.415180
# Article 1170:	Length: 40216	Compression: 0.398051	Avg Compression: 0.414619
# Article 1180:	Length: 41480	Compression: 0.487560	Avg Compression: 0.417002
# Article 1190:	Length: 42616	Compression: 0.392341	Avg Compression: 0.416201
# Article 1200:	Length: 43488	Compression: 0.469279	Avg Compression: 0.417904
# Article 1210:	Length: 45080	Compression: 0.381655	Avg Compression: 0.416737
# Article 1220:	Length: 46864	Compression: 0.393436	Avg Compression: 0.415983
# Article 1230:	Length: 48608	Compression: 0.372799	Avg Compression: 0.414580
# Article 1240:	Length: 50264	Compression: 0.409677	Avg Compression: 0.414420
# Article 1250:	Length: 51272	Compression: 0.401779	Avg Compression: 0.414015
# Article 1260:	Length: 52528	Compression: 0.405346	Avg Compression: 0.413739
# Article 1270:	Length: 53688	Compression: 0.424378	Avg Compression: 0.414074
# Article 1280:	Length: 54640	Compression: 0.420480	Avg Compression: 0.414273
# Article 1290:	Length: 55440	Compression: 0.440476	Avg Compression: 0.415074
# Article 1300:	Length: 56320	Compression: 0.501989	Avg Compression: 0.417691
# Article 1310:	Length: 58648	Compression: 0.391846	Avg Compression: 0.416906
# Article 1320:	Length: 60504	Compression: 0.420104	Avg Compression: 0.417003
# Article 1330:	Length: 62376	Compression: 0.501667	Avg Compression: 0.419577
# Article 1340:	Length: 63840	Compression: 0.468405	Avg Compression: 0.421050
# Article 1350:	Length: 65976	Compression: 0.365906	Avg Compression: 0.419383
# Article 1360:	Length: 67128	Compression: 0.402738	Avg Compression: 0.418886
# Article 1370:	Length: 68800	Compression: 0.404128	Avg Compression: 0.418448
# Article 1380:	Length: 70576	Compression: 0.469593	Avg Compression: 0.419959
# Article 1390:	Length: 72432	Compression: 0.484468	Avg Compression: 0.421858
# Article 1400:	Length: 74752	Compression: 0.391147	Avg Compression: 0.420953
# Article 1410:	Length: 75792	Compression: 0.418158	Avg Compression: 0.420871
# Article 1420:	Length: 78368	Compression: 0.386969	Avg Compression: 0.419884
# Article 1430:	Length: 80136	Compression: 0.423555	Avg Compression: 0.419990
# Article 1440:	Length: 81808	Compression: 0.498961	Avg Compression: 0.422256
# Article 1450:	Length: 84736	Compression: 0.518800	Avg Compression: 0.425042
# Article 1460:	Length: 87880	Compression: 0.512142	Avg Compression: 0.427573
# Article 1470:	Length: 88760	Compression: 0.434824	Avg Compression: 0.427780
# Article 1480:	Length: 89704	Compression: 0.467036	Avg Compression: 0.428880
# Article 1490:	Length: 91864	Compression: 0.405273	Avg Compression: 0.428221
# Article 1500:	Length: 94344	Compression: 0.400640	Avg Compression: 0.427453
# Article 1510:	Length: 97160	Compression: 0.381422	Avg Compression: 0.426170
# Article 1520:	Length: 98752	Compression: 0.412913	Avg Compression: 0.425805
# Article 1530:	Length: 101024	Compression: 0.461366	Avg Compression: 0.426780
# Article 1540:	Length: 103016	Compression: 0.409752	Avg Compression: 0.426317
# Article 1550:	Length: 106432	Compression: 0.402041	Avg Compression: 0.425653
# Article 1560:	Length: 107664	Compression: 0.419657	Avg Compression: 0.425492
# Article 1570:	Length: 109952	Compression: 0.409488	Avg Compression: 0.425064
# Article 1580:	Length: 112616	Compression: 0.407686	Avg Compression: 0.424601
# Article 1590:	Length: 115984	Compression: 0.461279	Avg Compression: 0.425581
# Article 1600:	Length: 117944	Compression: 0.445466	Avg Compression: 0.426107
# Article 1610:	Length: 120872	Compression: 0.413992	Avg Compression: 0.425787
# Article 1620:	Length: 123248	Compression: 0.396761	Avg Compression: 0.425027
# Article 1630:	Length: 125152	Compression: 0.450780	Avg Compression: 0.425694
# Article 1640:	Length: 128960	Compression: 0.432560	Avg Compression: 0.425873
# Article 1650:	Length: 132816	Compression: 0.361786	Avg Compression: 0.424201
# Article 1660:	Length: 134584	Compression: 0.428840	Avg Compression: 0.424320
# Article 1670:	Length: 141472	Compression: 0.368971	Avg Compression: 0.422861
# Article 1680:	Length: 146472	Compression: 0.465789	Avg Compression: 0.424001
# Article 1690:	Length: 151840	Compression: 0.434760	Avg Compression: 0.424290
# Article 1700:	Length: 157048	Compression: 0.531392	Avg Compression: 0.427179
# Article 1710:	Length: 161424	Compression: 0.430760	Avg Compression: 0.427276
# Article 1720:	Length: 164208	Compression: 0.480348	Avg Compression: 0.428693
# Article 1730:	Length: 174464	Compression: 0.458622	Avg Compression: 0.429519
# Article 1740:	Length: 189072	Compression: 0.453832	Avg Compression: 0.430225
# Article 1750:	Length: 195080	Compression: 0.374826	Avg Compression: 0.428614
# Article 1760:	Length: 202592	Compression: 0.395282	Avg Compression: 0.427636
# Article 1770:	Length: 213160	Compression: 0.442503	Avg Compression: 0.428081
# Article 1780:	Length: 220440	Compression: 0.395722	Avg Compression: 0.427110
# Article 1790:	Length: 229744	Compression: 0.467425	Avg Compression: 0.428333
# Article 1800:	Length: 246304	Compression: 0.399076	Avg Compression: 0.427411
# Article 1810:	Length: 251304	Compression: 0.434151	Avg Compression: 0.427621
# Article 1820:	Length: 268336	Compression: 0.526165	Avg Compression: 0.430793
# Article 1830:	Length: 283192	Compression: 0.415598	Avg Compression: 0.430294
# Article 1840:	Length: 307368	Compression: 0.385749	Avg Compression: 0.428760
# Article 1850:	Length: 323168	Compression: 0.392134	Avg Compression: 0.427481
# Article 1860:	Length: 341176	Compression: 0.433495	Avg Compression: 0.427695
# Article 1870:	Length: 382048	Compression: 0.413516	Avg Compression: 0.427151
# Article 1880:	Length: 441872	Compression: 0.688733	Avg Compression: 0.438248
# Article 1890:	Length: 508896	Compression: 0.405372	Avg Compression: 0.436716
