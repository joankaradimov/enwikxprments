# %%
import itertools
import math
import os

import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds

physical_devices = tf.config.list_physical_devices('GPU')
for physical_device in physical_devices:
    tf.config.experimental.set_memory_growth(physical_device, enable=True)

# %%
TYPE=np.int16

subword_text_encoder = tfds.features.text.SubwordTextEncoder.load_from_file('vocab_4096')

class Articles:
    EMPTY_ARTICLE = np.array([], dtype=TYPE) # used for padding
    
    def __init__(self, path):
        with open(path, 'rb') as text_file:
            data = text_file.read()

        self.articles = sorted(set(data.split(b'\0')), key=len)
        self._encoded_articles = None

    @property
    def encoded_articles(self):
        if self._encoded_articles == None:
            self._encoded_articles = [np.array(subword_text_encoder.encode(article), dtype=TYPE) for article in self.articles]
        
        return self._encoded_articles

    def articles_generator(self, batch_size = 1, start = 0, end = None):
        end = end or len(self.articles)

        for _ in range(batch_size - ((end - start - 1) % batch_size + 1)):
            yield self.EMPTY_ARTICLE

        for article in itertools.islice(self.encoded_articles, start, end):
            yield article

    def subbatch_generator(self, batch_size, batch_length, start = 0, end = None):
        end = end or len(self.articles)

        dataset = tf.data.Dataset.from_generator(self.articles_generator, args=(batch_size, start, end), output_types=TYPE)
        dataset = dataset.padded_batch(batch_size, padded_shapes=([None]), drop_remainder=True)
        dataset = dataset.shuffle(100)

        for batch in dataset.as_numpy_iterator():
            remaining = batch
            while remaining.shape[1] > batch_length + 1:
                yield remaining[:, :batch_length + 1]
                remaining = remaining[:, batch_length:]

            if remaining.shape[1] == batch_length + 1:
                yield remaining
                yield np.zeros((batch_size, batch_length + 1), dtype=TYPE)
            else:
                yield np.hstack([remaining, np.zeros([batch_size, batch_length - remaining.shape[1] + 1])])

    def steps(self, batch_size, batch_length):
        articles = self.articles_generator(batch_size, batch_length)
        return sum(math.ceil(len(article) / batch_length) for i, article in enumerate(articles) if (i + 1) % batch_size == 0)

    def dataset(self, batch_size, batch_length, start = 0, end = None):
        end = end or len(self.articles)

        dataset = tf.data.Dataset.from_generator(self.subbatch_generator, args=(batch_size, batch_length, start, end), output_types=TYPE, output_shapes=(batch_size, batch_length + 1))
        return dataset.map(lambda batch: (batch[:, :-1], batch[:, 1:]))

# %%
articles = Articles('page_revisions_text')

# %%
steps = 13

for i in range(steps):
    batch_size = 3 * 2**i
    batch_item_length = 3 * 2**(steps - i - 1)
    count = articles.steps(batch_size, batch_item_length)
    print("batch size: %6d\t batch item length: %4d\tsteps per epoch: %6d" % (batch_size, batch_item_length, count))
# Out:
# batch size:      3	 batch item length: 12288	steps per epoch:  70297
# batch size:      6	 batch item length: 6144	steps per epoch:  37955
# batch size:     12	 batch item length: 3072	steps per epoch:  21974
# batch size:     24	 batch item length: 1536	steps per epoch:  14546
# batch size:     48	 batch item length:  768	steps per epoch:  11792
# batch size:     96	 batch item length:  384	steps per epoch:  10574
# batch size:    192	 batch item length:  192	steps per epoch:  10573
# batch size:    384	 batch item length:   96	steps per epoch:  11676
# batch size:    768	 batch item length:   48	steps per epoch:  14588
# batch size:   1536	 batch item length:   24	steps per epoch:  20735
# batch size:   3072	 batch item length:   12	steps per epoch:  33286
# batch size:   6144	 batch item length:    6	steps per epoch:  58607
# batch size:  12288	 batch item length:    3	steps per epoch: 109444

# %%
def loss(labels, logits):
    return tf.keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)

def average_final_batch_ratio(true_labels, predictions):
    return 0 ** tf.math.abs(true_labels[-1, -1])

class ModelStateResetter(tf.keras.callbacks.Callback):
    def __init__(self):
        pass

    def on_epoch_begin(self, epoch, logs=None):
        self.last_final_batch_count = 0
        
    def on_batch_end(self, batch, logs={}):
        average_final_batch_ratio = logs.get('average_final_batch_ratio', 0)
        final_batch_count = int(round(average_final_batch_ratio * (batch + 1)))
        is_final = final_batch_count - self.last_final_batch_count
        self.last_final_batch_count = final_batch_count
        
        if is_final:
            self.model.reset_states()

class Model:
    def __init__(self, articles, checkpoint_dir, vocab_size, embedding_dim, rnn_units):
        self._articles = articles
        self._batch_size = None
        self._batched_item_length = None
        self._training_model = None
        self._predicting_model = None
        self._vocab_size = vocab_size
        self._embedding_dim = embedding_dim
        self._rnn_units = rnn_units

        self._checkpoint_dir = checkpoint_dir
        self._checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt_{epoch}") # Name of the checkpoint files

    def training_model(self, batch_size, batched_item_length):
        if self._training_model == None or batch_size != self._batch_size or batched_item_length != self._batched_item_length:
            self._batch_size = batch_size
            self._batched_item_length = batched_item_length
            self._training_model = tf.keras.Sequential([
                tf.keras.layers.Masking(mask_value=0, batch_input_shape=[batch_size, batched_item_length]),
                tf.keras.layers.Embedding(self._vocab_size, self._embedding_dim),
                tf.keras.layers.GRU(self._rnn_units // 4 * 4, return_sequences=True, stateful=True, recurrent_initializer='glorot_uniform'),
                tf.keras.layers.GRU(self._rnn_units // 4 * 2, return_sequences=True, stateful=True, recurrent_initializer='glorot_uniform'),
                tf.keras.layers.GRU(self._rnn_units // 4 * 1, return_sequences=True, stateful=True, recurrent_initializer='glorot_uniform'),
                tf.keras.layers.Dense(self._vocab_size),
            ])

            if os.path.isdir(self._checkpoint_dir):
                self._training_model.load_weights(tf.train.latest_checkpoint(self._checkpoint_dir))

            self._training_model.compile(optimizer='adam', loss=loss, metrics=[average_final_batch_ratio])
            self._predicting_model = None
        
        return self._training_model

    @property
    def callbacks(self):
        checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=self._checkpoint_prefix, save_weights_only=True)
        model_state_resetter_callback = ModelStateResetter()
        
        return [checkpoint_callback, model_state_resetter_callback]
    
    def train(self, batch_size, batched_item_length, epochs=1):
        dataset = self._articles.dataset(batch_size, batched_item_length)

        model = self.training_model(batch_size, batched_item_length)

        model.fit(dataset, epochs=epochs, callbacks=self.callbacks)
    
    @property
    def predicting_model(self):
        if self._predicting_model == None:
            self._predicting_model = tf.keras.Sequential([
                tf.keras.layers.Masking(mask_value=0, batch_input_shape=[1, 1]),
                tf.keras.layers.Embedding(self._vocab_size, self._embedding_dim),
                tf.keras.layers.GRU(self._rnn_units // 4 * 4, stateful=True, return_sequences=True),
                tf.keras.layers.GRU(self._rnn_units // 4 * 2, stateful=True, return_sequences=True),
                tf.keras.layers.GRU(self._rnn_units // 4 * 1, stateful=True, return_sequences=True),
                tf.keras.layers.Dense(self._vocab_size),
            ])
            
            self._predicting_model.load_weights(tf.train.latest_checkpoint(self._checkpoint_dir))
            self._training_model = None
        
        return self._predicting_model
    
    def predict(self, input_eval):
        return self.predicting_model(input_eval)

# %%
model = Model(articles, './training_checkpoints-8',
              vocab_size = subword_text_encoder.vocab_size,
              embedding_dim=32,
              rnn_units=1536)

# %%
model.training_model(192, 192).summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# masking (Masking)            (192, 192)                0
# _________________________________________________________________
# embedding (Embedding)        (192, 192, 32)            129536
# _________________________________________________________________
# gru (GRU)                    (192, 192, 1536)          7234560
# _________________________________________________________________
# gru_1 (GRU)                  (192, 192, 768)           5313024
# _________________________________________________________________
# gru_2 (GRU)                  (192, 192, 384)           1329408
# _________________________________________________________________
# dense (Dense)                (192, 192, 4048)          1558480
# =================================================================
# Total params: 15,565,008
# Trainable params: 15,565,008
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.train(192, 192)
# Out:
# 14342/14342 [==============================] - 8836s 616ms/step - loss: 3.8454 - average_final_batch_ratio: 0.3428

# %%
model.train(192, 192, epochs=5)
# Out:
# Epoch 1/5
# 14342/14342 [==============================] - 8745s 610ms/step - loss: 2.5060 - average_final_batch_ratio: 0.3428
# Epoch 2/5
# 14342/14342 [==============================] - 8777s 612ms/step - loss: 2.2891 - average_final_batch_ratio: 0.3428
# Epoch 3/5
# 14342/14342 [==============================] - 8782s 612ms/step - loss: 2.2059 - average_final_batch_ratio: 0.3428
# Epoch 4/5
# 14342/14342 [==============================] - 9092s 634ms/step - loss: 2.1542 - average_final_batch_ratio: 0.3428
# Epoch 5/5
# 14342/14342 [==============================] - 8834s 616ms/step - loss: 2.1189 - average_final_batch_ratio: 0.3428

# %%
model.train(192, 192, epochs=2)
# Out:
# Epoch 1/2
# 14342/14342 [==============================] - 8832s 616ms/step - loss: 2.1078 - average_final_batch_ratio: 0.3428
# Epoch 2/2
# 14342/14342 [==============================] - 8956s 624ms/step - loss: 2.0878 - average_final_batch_ratio: 0.3428

# %%
import ctypes

class Huffman:
    huffman = ctypes.CDLL('x64/Release/huffman')
    
    huffman.create_tree.restype = ctypes.c_void_p
    huffman.destroy_tree.restype = None
    huffman.load_weights.restype = None
    huffman.create_code_string.restype = ctypes.c_char_p
    
    def __init__(self, category_count):
        self.tree = ctypes.c_void_p(self.huffman.create_tree(category_count))

    def __del__(self):
        self.huffman.destroy_tree(self.tree)
        
    def load_weights(self, weights):
        self.huffman.load_weights(self.tree, weights.ctypes.data_as(ctypes.POINTER(ctypes.c_float)))
    
    def get_code_length(self, category):
        return self.huffman.get_code_length(self.tree, category)

    def get_code_zero_count(self, category):
        return self.huffman.get_code_zero_count(self.tree, category)

# %%
def huffman_archive_size(model, text):
    archived_size = 0
    zeros = 0
    input_eval = np.array([[0]], dtype=TYPE)
    huffman_tree = Huffman(subword_text_encoder.vocab_size)

    text_generated = []

    model.predicting_model.reset_states()

    for index, byte in enumerate(text):
        predictions = model.predict(input_eval)
        predictions = tf.squeeze(predictions, 0) # remove the batch dimension

        weights = tf.nn.softmax(predictions[0]).numpy()
        huffman_tree.load_weights(weights)
        zeros += huffman_tree.get_code_zero_count(byte.item())
        archived_size += huffman_tree.get_code_length(byte.item())

        input_eval = tf.expand_dims([byte], 0)
  
    return archived_size, zeros

# %%
total_raw = 0
total_compressed = 0

for index, encoded_article in enumerate(articles.articles_generator(1)):
    if index % 1000 == 0:
        article = subword_text_encoder.decode(encoded_article)
        raw = len(article) * 8
        if raw == 0:
            continue
        compressed, _ = huffman_archive_size(model, encoded_article)
        total_raw += raw
        total_compressed += compressed

        print('Article %d:\tLength: %d\tCompression: %f\tAvg Compression: %f' % (index, raw, compressed/raw, total_compressed/total_raw))
# Out:
# Article 1000:	Length: 144	Compression: 0.562500	Avg Compression: 0.562500
# Article 2000:	Length: 152	Compression: 0.467105	Avg Compression: 0.513514
# Article 3000:	Length: 160	Compression: 0.506250	Avg Compression: 0.510965
# Article 4000:	Length: 168	Compression: 0.404762	Avg Compression: 0.482372
# Article 5000:	Length: 168	Compression: 0.357143	Avg Compression: 0.455808
# Article 6000:	Length: 168	Compression: 0.505952	Avg Compression: 0.464583
# Article 7000:	Length: 176	Compression: 0.357955	Avg Compression: 0.448063
# Article 8000:	Length: 176	Compression: 0.539773	Avg Compression: 0.460366
# Article 9000:	Length: 184	Compression: 0.527174	Avg Compression: 0.468583
# Article 10000:	Length: 184	Compression: 0.500000	Avg Compression: 0.472024
# Article 11000:	Length: 192	Compression: 0.302083	Avg Compression: 0.454594
# Article 12000:	Length: 192	Compression: 0.552083	Avg Compression: 0.463663
# Article 13000:	Length: 200	Compression: 0.405000	Avg Compression: 0.458481
# Article 14000:	Length: 200	Compression: 0.260000	Avg Compression: 0.442370
# Article 15000:	Length: 208	Compression: 0.432692	Avg Compression: 0.441617
# Article 16000:	Length: 208	Compression: 0.413462	Avg Compression: 0.439583
# Article 17000:	Length: 208	Compression: 0.346154	Avg Compression: 0.433290
# Article 18000:	Length: 216	Compression: 0.319444	Avg Compression: 0.425847
# Article 19000:	Length: 216	Compression: 0.407407	Avg Compression: 0.424716
# Article 20000:	Length: 224	Compression: 0.250000	Avg Compression: 0.414263
# Article 21000:	Length: 224	Compression: 0.379464	Avg Compression: 0.412298
# Article 22000:	Length: 224	Compression: 0.441964	Avg Compression: 0.413884
# Article 23000:	Length: 280	Compression: 0.364286	Avg Compression: 0.410778
# Article 24000:	Length: 280	Compression: 0.360714	Avg Compression: 0.407828
# Article 25000:	Length: 240	Compression: 0.404167	Avg Compression: 0.407652
# Article 26000:	Length: 240	Compression: 0.287500	Avg Compression: 0.402141
# Article 27000:	Length: 248	Compression: 0.302419	Avg Compression: 0.397628
# Article 28000:	Length: 248	Compression: 0.427419	Avg Compression: 0.398918
# Article 29000:	Length: 248	Compression: 0.314516	Avg Compression: 0.395415
# Article 30000:	Length: 256	Compression: 0.335938	Avg Compression: 0.392972
# Article 31000:	Length: 256	Compression: 0.328125	Avg Compression: 0.390413
# Article 32000:	Length: 256	Compression: 0.621094	Avg Compression: 0.399170
# Article 33000:	Length: 264	Compression: 0.280303	Avg Compression: 0.394692
# Article 34000:	Length: 272	Compression: 0.448529	Avg Compression: 0.396703
# Article 35000:	Length: 272	Compression: 0.253676	Avg Compression: 0.391552
# Article 36000:	Length: 280	Compression: 0.353571	Avg Compression: 0.390194
# Article 37000:	Length: 264	Compression: 0.393939	Avg Compression: 0.390316
# Article 38000:	Length: 288	Compression: 0.381944	Avg Compression: 0.390029
# Article 39000:	Length: 344	Compression: 0.206395	Avg Compression: 0.382791
# Article 40000:	Length: 296	Compression: 0.375000	Avg Compression: 0.382535
# Article 41000:	Length: 296	Compression: 0.574324	Avg Compression: 0.388627
# Article 42000:	Length: 312	Compression: 0.403846	Avg Compression: 0.389120
# Article 43000:	Length: 320	Compression: 0.403125	Avg Compression: 0.389570
# Article 44000:	Length: 328	Compression: 0.429878	Avg Compression: 0.390856
# Article 45000:	Length: 432	Compression: 0.263889	Avg Compression: 0.385736
# Article 46000:	Length: 344	Compression: 0.299419	Avg Compression: 0.383050
# Article 47000:	Length: 352	Compression: 0.369318	Avg Compression: 0.382626
# Article 48000:	Length: 368	Compression: 0.404891	Avg Compression: 0.383322
# Article 49000:	Length: 384	Compression: 0.158854	Avg Compression: 0.376234
# Article 50000:	Length: 400	Compression: 0.152500	Avg Compression: 0.369108
# Article 51000:	Length: 416	Compression: 0.317308	Avg Compression: 0.367448
# Article 52000:	Length: 440	Compression: 0.190909	Avg Compression: 0.361658
# Article 53000:	Length: 472	Compression: 0.421610	Avg Compression: 0.363695
# Article 54000:	Length: 520	Compression: 0.292308	Avg Compression: 0.361119
# Article 55000:	Length: 584	Compression: 0.438356	Avg Compression: 0.364128
# Article 56000:	Length: 696	Compression: 0.347701	Avg Compression: 0.363399
# Article 57000:	Length: 848	Compression: 0.471698	Avg Compression: 0.368953
# Article 58000:	Length: 1032	Compression: 0.402132	Avg Compression: 0.370902
# Article 59000:	Length: 1208	Compression: 0.384934	Avg Compression: 0.371804
# Article 60000:	Length: 1368	Compression: 0.427632	Avg Compression: 0.375596
# Article 61000:	Length: 1552	Compression: 0.272552	Avg Compression: 0.368225
# Article 62000:	Length: 1728	Compression: 0.257523	Avg Compression: 0.360058
# Article 63000:	Length: 1960	Compression: 0.271429	Avg Compression: 0.353215
# Article 64000:	Length: 2208	Compression: 0.284420	Avg Compression: 0.347709
# Article 65000:	Length: 2480	Compression: 0.338306	Avg Compression: 0.346934
# Article 66000:	Length: 2760	Compression: 0.459783	Avg Compression: 0.356421
# Article 67000:	Length: 3000	Compression: 0.236333	Avg Compression: 0.346366
# Article 68000:	Length: 3336	Compression: 0.766787	Avg Compression: 0.382174
# Article 69000:	Length: 3648	Compression: 0.296875	Avg Compression: 0.374907
# Article 70000:	Length: 3936	Compression: 0.280742	Avg Compression: 0.366979
# Article 71000:	Length: 4232	Compression: 0.322543	Avg Compression: 0.363290
# Article 72000:	Length: 4520	Compression: 0.320796	Avg Compression: 0.359830
# Article 73000:	Length: 4688	Compression: 0.337031	Avg Compression: 0.358054
# Article 74000:	Length: 5024	Compression: 0.294387	Avg Compression: 0.353150
# Article 75000:	Length: 5304	Compression: 0.297700	Avg Compression: 0.348979
# Article 76000:	Length: 5592	Compression: 0.358369	Avg Compression: 0.349669
# Article 77000:	Length: 5888	Compression: 0.319803	Avg Compression: 0.347524
# Article 78000:	Length: 6216	Compression: 0.281210	Avg Compression: 0.342852
# Article 79000:	Length: 6464	Compression: 0.411355	Avg Compression: 0.347529
# Article 80000:	Length: 6816	Compression: 0.347124	Avg Compression: 0.347501
# Article 81000:	Length: 7120	Compression: 0.352528	Avg Compression: 0.347831
# Article 82000:	Length: 7368	Compression: 0.403909	Avg Compression: 0.351393
# Article 83000:	Length: 7720	Compression: 0.371244	Avg Compression: 0.352632
# Article 84000:	Length: 8304	Compression: 0.401012	Avg Compression: 0.355675
# Article 85000:	Length: 8384	Compression: 0.383111	Avg Compression: 0.357314
# Article 86000:	Length: 8680	Compression: 0.338134	Avg Compression: 0.356197
# Article 87000:	Length: 9032	Compression: 0.376439	Avg Compression: 0.357353
# Article 88000:	Length: 9216	Compression: 0.325521	Avg Compression: 0.355600
# Article 89000:	Length: 9584	Compression: 0.320117	Avg Compression: 0.353678
# Article 90000:	Length: 10016	Compression: 0.302117	Avg Compression: 0.350915
# Article 91000:	Length: 10360	Compression: 0.353378	Avg Compression: 0.351044
# Article 92000:	Length: 10696	Compression: 0.310957	Avg Compression: 0.348983
# Article 93000:	Length: 11000	Compression: 0.366273	Avg Compression: 0.349851
# Article 94000:	Length: 11456	Compression: 0.301763	Avg Compression: 0.347460
# Article 95000:	Length: 11824	Compression: 0.351235	Avg Compression: 0.347645
# Article 96000:	Length: 12208	Compression: 0.432339	Avg Compression: 0.351708
# Article 97000:	Length: 12584	Compression: 0.306262	Avg Compression: 0.349566
# Article 98000:	Length: 12944	Compression: 0.292877	Avg Compression: 0.346946
# Article 99000:	Length: 13328	Compression: 0.307098	Avg Compression: 0.345135
# Article 100000:	Length: 13816	Compression: 0.519036	Avg Compression: 0.352958
# Article 101000:	Length: 14104	Compression: 0.314237	Avg Compression: 0.351258
# Article 102000:	Length: 14512	Compression: 0.341993	Avg Compression: 0.350857
# Article 103000:	Length: 14920	Compression: 0.336595	Avg Compression: 0.350250
# Article 104000:	Length: 15344	Compression: 0.387578	Avg Compression: 0.351815
# Article 105000:	Length: 15784	Compression: 0.302268	Avg Compression: 0.349767
# Article 106000:	Length: 16336	Compression: 0.457027	Avg Compression: 0.354168
# Article 107000:	Length: 16560	Compression: 0.434601	Avg Compression: 0.357380
# Article 108000:	Length: 17136	Compression: 0.388189	Avg Compression: 0.358602
# Article 109000:	Length: 17576	Compression: 0.424442	Avg Compression: 0.361177
# Article 110000:	Length: 18048	Compression: 0.291888	Avg Compression: 0.358502
# Article 111000:	Length: 18520	Compression: 0.374298	Avg Compression: 0.359104
# Article 112000:	Length: 18920	Compression: 0.495190	Avg Compression: 0.364204
# Article 113000:	Length: 19328	Compression: 0.328177	Avg Compression: 0.362875
# Article 114000:	Length: 19944	Compression: 0.342609	Avg Compression: 0.362133
# Article 115000:	Length: 19848	Compression: 0.093863	Avg Compression: 0.352692
# Article 116000:	Length: 20024	Compression: 0.090192	Avg Compression: 0.343692
# Article 117000:	Length: 20096	Compression: 0.089719	Avg Compression: 0.335244
# Article 118000:	Length: 20176	Compression: 0.090206	Avg Compression: 0.327325
# Article 119000:	Length: 20272	Compression: 0.098461	Avg Compression: 0.320127
# Article 120000:	Length: 20000	Compression: 0.373050	Avg Compression: 0.321720
# Article 121000:	Length: 20544	Compression: 0.100613	Avg Compression: 0.315090
# Article 122000:	Length: 20664	Compression: 0.101965	Avg Compression: 0.308850
# Article 123000:	Length: 20784	Compression: 0.103253	Avg Compression: 0.302969
# Article 124000:	Length: 20880	Compression: 0.107711	Avg Compression: 0.297515
# Article 125000:	Length: 20960	Compression: 0.107204	Avg Compression: 0.292323
# Article 126000:	Length: 21024	Compression: 0.103834	Avg Compression: 0.287304
# Article 127000:	Length: 21088	Compression: 0.107597	Avg Compression: 0.282628
# Article 128000:	Length: 21144	Compression: 0.106886	Avg Compression: 0.278160
# Article 129000:	Length: 21208	Compression: 0.109534	Avg Compression: 0.273967
# Article 130000:	Length: 21272	Compression: 0.104175	Avg Compression: 0.269835
# Article 131000:	Length: 21344	Compression: 0.114599	Avg Compression: 0.266135
# Article 132000:	Length: 21432	Compression: 0.106103	Avg Compression: 0.262395
# Article 133000:	Length: 21528	Compression: 0.108092	Avg Compression: 0.258855
# Article 134000:	Length: 21616	Compression: 0.112926	Avg Compression: 0.255569
# Article 135000:	Length: 21744	Compression: 0.115802	Avg Compression: 0.252474
# Article 136000:	Length: 21856	Compression: 0.350750	Avg Compression: 0.254614
# Article 137000:	Length: 21992	Compression: 0.105948	Avg Compression: 0.251426
# Article 138000:	Length: 22136	Compression: 0.113797	Avg Compression: 0.248519
# Article 139000:	Length: 22312	Compression: 0.115005	Avg Compression: 0.245735
# Article 140000:	Length: 22496	Compression: 0.109931	Avg Compression: 0.242939
# Article 141000:	Length: 22464	Compression: 0.349671	Avg Compression: 0.245089
# Article 142000:	Length: 23008	Compression: 0.351008	Avg Compression: 0.247230
# Article 143000:	Length: 23192	Compression: 0.119352	Avg Compression: 0.244677
# Article 144000:	Length: 23472	Compression: 0.290687	Avg Compression: 0.245588
# Article 145000:	Length: 23760	Compression: 0.294318	Avg Compression: 0.246546
# Article 146000:	Length: 24096	Compression: 0.121223	Avg Compression: 0.244096
# Article 147000:	Length: 24432	Compression: 0.127333	Avg Compression: 0.241827
# Article 148000:	Length: 24800	Compression: 0.296653	Avg Compression: 0.242888
# Article 149000:	Length: 25200	Compression: 0.145079	Avg Compression: 0.241002
# Article 150000:	Length: 25608	Compression: 0.339152	Avg Compression: 0.242888
# Article 151000:	Length: 26040	Compression: 0.398464	Avg Compression: 0.245870
# Article 152000:	Length: 26392	Compression: 0.300811	Avg Compression: 0.246916
# Article 153000:	Length: 26328	Compression: 0.464980	Avg Compression: 0.250984
# Article 154000:	Length: 27144	Compression: 0.307103	Avg Compression: 0.252043
# Article 155000:	Length: 27664	Compression: 0.317814	Avg Compression: 0.253284
# Article 156000:	Length: 28136	Compression: 0.357869	Avg Compression: 0.255253
# Article 157000:	Length: 28608	Compression: 0.162088	Avg Compression: 0.253503
# Article 158000:	Length: 29096	Compression: 0.336954	Avg Compression: 0.255067
# Article 159000:	Length: 29576	Compression: 0.159149	Avg Compression: 0.253274
# Article 160000:	Length: 30096	Compression: 0.396099	Avg Compression: 0.255941
# Article 161000:	Length: 30640	Compression: 0.170072	Avg Compression: 0.254339
# Article 162000:	Length: 31216	Compression: 0.385027	Avg Compression: 0.256777
# Article 163000:	Length: 31496	Compression: 0.322708	Avg Compression: 0.257994
# Article 164000:	Length: 32408	Compression: 0.188133	Avg Compression: 0.256691
# Article 165000:	Length: 33000	Compression: 0.307758	Avg Compression: 0.257643
# Article 166000:	Length: 33248	Compression: 0.383031	Avg Compression: 0.259954
# Article 167000:	Length: 34352	Compression: 0.338263	Avg Compression: 0.261418
# Article 168000:	Length: 35072	Compression: 0.300325	Avg Compression: 0.262146
# Article 169000:	Length: 35776	Compression: 0.325190	Avg Compression: 0.263328
# Article 170000:	Length: 36536	Compression: 0.339884	Avg Compression: 0.264766
# Article 171000:	Length: 37144	Compression: 0.351793	Avg Compression: 0.266396
# Article 172000:	Length: 38040	Compression: 0.200710	Avg Compression: 0.265159
# Article 173000:	Length: 38880	Compression: 0.189532	Avg Compression: 0.263732
# Article 174000:	Length: 39424	Compression: 0.458781	Avg Compression: 0.267395
# Article 175000:	Length: 40688	Compression: 0.194357	Avg Compression: 0.266006
# Article 176000:	Length: 41616	Compression: 0.199875	Avg Compression: 0.264745
# Article 177000:	Length: 42552	Compression: 0.319256	Avg Compression: 0.265788
# Article 178000:	Length: 43360	Compression: 0.417666	Avg Compression: 0.268692
# Article 179000:	Length: 44672	Compression: 0.292040	Avg Compression: 0.269144
# Article 180000:	Length: 45704	Compression: 0.301024	Avg Compression: 0.269762
# Article 181000:	Length: 46872	Compression: 0.287336	Avg Compression: 0.270104
# Article 182000:	Length: 48224	Compression: 0.232353	Avg Compression: 0.269362
# Article 183000:	Length: 49496	Compression: 0.210906	Avg Compression: 0.268206
# Article 184000:	Length: 50872	Compression: 0.210096	Avg Compression: 0.267048
# Article 185000:	Length: 52352	Compression: 0.330092	Avg Compression: 0.268315
# Article 186000:	Length: 53704	Compression: 0.353456	Avg Compression: 0.270034
# Article 187000:	Length: 55128	Compression: 0.315774	Avg Compression: 0.270963
# Article 188000:	Length: 56824	Compression: 0.317278	Avg Compression: 0.271913
# Article 189000:	Length: 58288	Compression: 0.366525	Avg Compression: 0.273862
# Article 190000:	Length: 60624	Compression: 0.336121	Avg Compression: 0.275168
# Article 191000:	Length: 62056	Compression: 0.348024	Avg Compression: 0.276700
# Article 192000:	Length: 63760	Compression: 0.300408	Avg Compression: 0.277201
# Article 193000:	Length: 65488	Compression: 0.331450	Avg Compression: 0.278354
# Article 194000:	Length: 68008	Compression: 0.326550	Avg Compression: 0.279395
# Article 195000:	Length: 70440	Compression: 0.246635	Avg Compression: 0.278678
# Article 196000:	Length: 72224	Compression: 0.317360	Avg Compression: 0.279527
# Article 197000:	Length: 75336	Compression: 0.284711	Avg Compression: 0.279643
# Article 198000:	Length: 77792	Compression: 0.288654	Avg Compression: 0.279846
# Article 199000:	Length: 80256	Compression: 0.338803	Avg Compression: 0.281188
# Article 200000:	Length: 84232	Compression: 0.341723	Avg Compression: 0.282601
# Article 201000:	Length: 87152	Compression: 0.361311	Avg Compression: 0.284457
# Article 202000:	Length: 90944	Compression: 0.287265	Avg Compression: 0.284524
# Article 203000:	Length: 94504	Compression: 0.334314	Avg Compression: 0.285736
# Article 204000:	Length: 99864	Compression: 0.381108	Avg Compression: 0.288128
# Article 205000:	Length: 103760	Compression: 0.318524	Avg Compression: 0.288900
# Article 206000:	Length: 108576	Compression: 0.349120	Avg Compression: 0.290459
# Article 207000:	Length: 112664	Compression: 0.305785	Avg Compression: 0.290860
# Article 208000:	Length: 119704	Compression: 0.351893	Avg Compression: 0.292510
# Article 209000:	Length: 126704	Compression: 0.313542	Avg Compression: 0.293095
# Article 210000:	Length: 133480	Compression: 0.365860	Avg Compression: 0.295168
# Article 211000:	Length: 142360	Compression: 0.418811	Avg Compression: 0.298813
# Article 212000:	Length: 152048	Compression: 0.374106	Avg Compression: 0.301111
# Article 213000:	Length: 163720	Compression: 0.300293	Avg Compression: 0.301085
# Article 214000:	Length: 177648	Compression: 0.314921	Avg Compression: 0.301547
# Article 215000:	Length: 193192	Compression: 0.334020	Avg Compression: 0.302684
# Article 216000:	Length: 213000	Compression: 0.293113	Avg Compression: 0.302328
# Article 217000:	Length: 238400	Compression: 0.332085	Avg Compression: 0.303517
# Article 218000:	Length: 274360	Compression: 0.326881	Avg Compression: 0.304544
# Article 219000:	Length: 329056	Compression: 0.300970	Avg Compression: 0.304365
# Article 220000:	Length: 458704	Compression: 0.502344	Avg Compression: 0.317284

# %%
model.train(384, 96, epochs=5)
# Out:
# Epoch 1/5
# 16031/16031 [==============================] - 9539s 595ms/step - loss: 1.8726 - average_final_batch_ratio: 0.3075
# Epoch 2/5
# 16031/16031 [==============================] - 9522s 594ms/step - loss: 1.8525 - average_final_batch_ratio: 0.3075
# Epoch 3/5
# 16031/16031 [==============================] - 9462s 590ms/step - loss: 1.8470 - average_final_batch_ratio: 0.3075
# Epoch 4/5
# 16031/16031 [==============================] - 9467s 591ms/step - loss: 1.8481 - average_final_batch_ratio: 0.3075
# Epoch 5/5
# 16031/16031 [==============================] - 9452s 590ms/step - loss: 1.8467 - average_final_batch_ratio: 0.3075

# %%
total_raw = 0
total_compressed = 0

for index, encoded_article in enumerate(articles.articles_generator(1)):
    if index % 1000 == 0:
        article = subword_text_encoder.decode(encoded_article)
        raw = len(article) * 8
        if raw == 0:
            continue
        compressed, _ = huffman_archive_size(model, encoded_article)
        total_raw += raw
        total_compressed += compressed

        print('Article %d:\tLength: %d\tCompression: %f\tAvg Compression: %f' % (index, raw, compressed/raw, total_compressed/total_raw))
# Out:
# Article 1000:	Length: 144	Compression: 7.104167	Avg Compression: 7.104167
# Article 2000:	Length: 152	Compression: 6.697368	Avg Compression: 6.895270
# Article 3000:	Length: 160	Compression: 6.356250	Avg Compression: 6.706140
# Article 4000:	Length: 168	Compression: 6.041667	Avg Compression: 6.527244
# Article 5000:	Length: 168	Compression: 5.946429	Avg Compression: 6.404040
# Article 6000:	Length: 168	Compression: 6.125000	Avg Compression: 6.355208
# Article 7000:	Length: 176	Compression: 5.687500	Avg Compression: 6.251761
# Article 8000:	Length: 176	Compression: 5.920455	Avg Compression: 6.207317
# Article 9000:	Length: 184	Compression: 5.646739	Avg Compression: 6.138369
# Article 10000:	Length: 184	Compression: 5.586957	Avg Compression: 6.077976
# Article 11000:	Length: 192	Compression: 5.213542	Avg Compression: 5.989316
# Article 12000:	Length: 192	Compression: 5.458333	Avg Compression: 5.939922
# Article 13000:	Length: 200	Compression: 5.070000	Avg Compression: 5.863074
# Article 14000:	Length: 200	Compression: 4.960000	Avg Compression: 5.789773
# Article 15000:	Length: 208	Compression: 4.990385	Avg Compression: 5.727545
# Article 16000:	Length: 208	Compression: 4.884615	Avg Compression: 5.666667
# Article 17000:	Length: 208	Compression: 4.899038	Avg Compression: 5.614961
# Article 18000:	Length: 216	Compression: 4.689815	Avg Compression: 5.554479
# Article 19000:	Length: 216	Compression: 4.773148	Avg Compression: 5.506534
# Article 20000:	Length: 224	Compression: 4.486607	Avg Compression: 5.445513
# Article 21000:	Length: 224	Compression: 4.638393	Avg Compression: 5.399950
# Article 22000:	Length: 224	Compression: 4.709821	Avg Compression: 5.363073
# Article 23000:	Length: 280	Compression: 3.707143	Avg Compression: 5.259392
# Article 24000:	Length: 280	Compression: 3.735714	Avg Compression: 5.169613
# Article 25000:	Length: 240	Compression: 4.308333	Avg Compression: 5.128205
# Article 26000:	Length: 240	Compression: 4.220833	Avg Compression: 5.086583
# Article 27000:	Length: 248	Compression: 4.072581	Avg Compression: 5.040693
# Article 28000:	Length: 248	Compression: 4.201613	Avg Compression: 5.004365
# Article 29000:	Length: 248	Compression: 4.100806	Avg Compression: 4.966867
# Article 30000:	Length: 256	Compression: 4.039062	Avg Compression: 4.928755
# Article 31000:	Length: 256	Compression: 4.031250	Avg Compression: 4.893342
# Article 32000:	Length: 256	Compression: 4.316406	Avg Compression: 4.871441
# Article 33000:	Length: 264	Compression: 3.890152	Avg Compression: 4.834475
# Article 34000:	Length: 272	Compression: 3.900735	Avg Compression: 4.799588
# Article 35000:	Length: 272	Compression: 3.731618	Avg Compression: 4.761123
# Article 36000:	Length: 280	Compression: 3.664286	Avg Compression: 4.721910
# Article 37000:	Length: 264	Compression: 4.049242	Avg Compression: 4.699975
# Article 38000:	Length: 288	Compression: 3.666667	Avg Compression: 4.664480
# Article 39000:	Length: 344	Compression: 2.973837	Avg Compression: 4.597846
# Article 40000:	Length: 296	Compression: 3.537162	Avg Compression: 4.563054
# Article 41000:	Length: 296	Compression: 3.800676	Avg Compression: 4.538841
# Article 42000:	Length: 312	Compression: 3.461538	Avg Compression: 4.503945
# Article 43000:	Length: 320	Compression: 3.340625	Avg Compression: 4.466539
# Article 44000:	Length: 328	Compression: 3.326220	Avg Compression: 4.430156
# Article 45000:	Length: 432	Compression: 2.444444	Avg Compression: 4.350075
# Article 46000:	Length: 344	Compression: 3.058140	Avg Compression: 4.309877
# Article 47000:	Length: 352	Compression: 3.008523	Avg Compression: 4.269723
# Article 48000:	Length: 368	Compression: 2.967391	Avg Compression: 4.229025
# Article 49000:	Length: 384	Compression: 2.604167	Avg Compression: 4.177714
# Article 50000:	Length: 400	Compression: 2.537500	Avg Compression: 4.125478
# Article 51000:	Length: 416	Compression: 2.629808	Avg Compression: 4.077528
# Article 52000:	Length: 440	Compression: 2.377273	Avg Compression: 4.021765
# Article 53000:	Length: 472	Compression: 1.491525	Avg Compression: 3.935772
# Article 54000:	Length: 520	Compression: 2.101923	Avg Compression: 3.869586
# Article 55000:	Length: 584	Compression: 0.500000	Avg Compression: 3.738327
# Article 56000:	Length: 696	Compression: 4.403736	Avg Compression: 3.767848
# Article 57000:	Length: 848	Compression: 1.339623	Avg Compression: 3.643324
# Article 58000:	Length: 1032	Compression: 3.001938	Avg Compression: 3.605647
# Article 59000:	Length: 1208	Compression: 0.798841	Avg Compression: 3.425064
# Article 60000:	Length: 1368	Compression: 2.716374	Avg Compression: 3.376936
# Article 61000:	Length: 1552	Compression: 0.313789	Avg Compression: 3.157817
# Article 62000:	Length: 1728	Compression: 0.330440	Avg Compression: 2.949240
# Article 63000:	Length: 1960	Compression: 0.336735	Avg Compression: 2.747518
# Article 64000:	Length: 2208	Compression: 0.372283	Avg Compression: 2.557444
# Article 65000:	Length: 2480	Compression: 0.807661	Avg Compression: 2.413142
# Article 66000:	Length: 2760	Compression: 1.229348	Avg Compression: 2.313627
# Article 67000:	Length: 3000	Compression: 0.434333	Avg Compression: 2.156285
# Article 68000:	Length: 3336	Compression: 0.795264	Avg Compression: 2.040365
# Article 69000:	Length: 3648	Compression: 0.320175	Avg Compression: 1.893801
# Article 70000:	Length: 3936	Compression: 0.463415	Avg Compression: 1.773379
# Article 71000:	Length: 4232	Compression: 0.472826	Avg Compression: 1.665424
# Article 72000:	Length: 4520	Compression: 0.481195	Avg Compression: 1.568986
# Article 73000:	Length: 4688	Compression: 0.353882	Avg Compression: 1.474349
# Article 74000:	Length: 5024	Compression: 0.295780	Avg Compression: 1.383556
# Article 75000:	Length: 5304	Compression: 0.426094	Avg Compression: 1.311543
# Article 76000:	Length: 5592	Compression: 0.389843	Avg Compression: 1.243825
# Article 77000:	Length: 5888	Compression: 0.443954	Avg Compression: 1.186390
# Article 78000:	Length: 6216	Compression: 0.462677	Avg Compression: 1.135395
# Article 79000:	Length: 6464	Compression: 0.410736	Avg Compression: 1.085921
# Article 80000:	Length: 6816	Compression: 0.340082	Avg Compression: 1.035834
# Article 81000:	Length: 7120	Compression: 0.451826	Avg Compression: 0.997551
# Article 82000:	Length: 7368	Compression: 0.480320	Avg Compression: 0.964693
# Article 83000:	Length: 7720	Compression: 0.470207	Avg Compression: 0.933834
# Article 84000:	Length: 8304	Compression: 0.357418	Avg Compression: 0.897574
# Article 85000:	Length: 8384	Compression: 0.388717	Avg Compression: 0.867186
# Article 86000:	Length: 8680	Compression: 0.353687	Avg Compression: 0.837287
# Article 87000:	Length: 9032	Compression: 0.389615	Avg Compression: 0.811713
# Article 88000:	Length: 9216	Compression: 0.283854	Avg Compression: 0.782638
# Article 89000:	Length: 9584	Compression: 0.319491	Avg Compression: 0.757546
# Article 90000:	Length: 10016	Compression: 0.330272	Avg Compression: 0.734651
# Article 91000:	Length: 10360	Compression: 0.439093	Avg Compression: 0.719130
# Article 92000:	Length: 10696	Compression: 0.551234	Avg Compression: 0.710495
# Article 93000:	Length: 11000	Compression: 0.349909	Avg Compression: 0.692382
# Article 94000:	Length: 11456	Compression: 0.321927	Avg Compression: 0.673965
# Article 95000:	Length: 11824	Compression: 0.343116	Avg Compression: 0.657817
# Article 96000:	Length: 12208	Compression: 0.455931	Avg Compression: 0.648131
# Article 97000:	Length: 12584	Compression: 0.312301	Avg Compression: 0.632306
# Article 98000:	Length: 12944	Compression: 0.387515	Avg Compression: 0.620989
# Article 99000:	Length: 13328	Compression: 0.311375	Avg Compression: 0.606921
# Article 100000:	Length: 13816	Compression: 0.467140	Avg Compression: 0.600633
# Article 101000:	Length: 14104	Compression: 0.330119	Avg Compression: 0.588756
# Article 102000:	Length: 14512	Compression: 0.347850	Avg Compression: 0.578344
# Article 103000:	Length: 14920	Compression: 0.351206	Avg Compression: 0.568680
# Article 104000:	Length: 15344	Compression: 0.367049	Avg Compression: 0.560227
# Article 105000:	Length: 15784	Compression: 0.354663	Avg Compression: 0.551729
# Article 106000:	Length: 16336	Compression: 0.405913	Avg Compression: 0.545746
# Article 107000:	Length: 16560	Compression: 0.454891	Avg Compression: 0.542118
# Article 108000:	Length: 17136	Compression: 0.406629	Avg Compression: 0.536741
# Article 109000:	Length: 17576	Compression: 0.448851	Avg Compression: 0.533304
# Article 110000:	Length: 18048	Compression: 0.358932	Avg Compression: 0.526571
# Article 111000:	Length: 18520	Compression: 0.356749	Avg Compression: 0.520100
# Article 112000:	Length: 18920	Compression: 0.538901	Avg Compression: 0.520804
# Article 113000:	Length: 19328	Compression: 0.469319	Avg Compression: 0.518906
# Article 114000:	Length: 19944	Compression: 0.330225	Avg Compression: 0.511991
# Article 115000:	Length: 19848	Compression: 0.094821	Avg Compression: 0.497310
# Article 116000:	Length: 20024	Compression: 0.089592	Avg Compression: 0.483332
# Article 117000:	Length: 20096	Compression: 0.091361	Avg Compression: 0.470293
# Article 118000:	Length: 20176	Compression: 0.092337	Avg Compression: 0.458079
# Article 119000:	Length: 20272	Compression: 0.098017	Avg Compression: 0.446755
# Article 120000:	Length: 20000	Compression: 0.357550	Avg Compression: 0.444070
# Article 121000:	Length: 20544	Compression: 0.098764	Avg Compression: 0.433716
# Article 122000:	Length: 20664	Compression: 0.103223	Avg Compression: 0.424040
# Article 123000:	Length: 20784	Compression: 0.106909	Avg Compression: 0.414968
# Article 124000:	Length: 20880	Compression: 0.108764	Avg Compression: 0.406415
# Article 125000:	Length: 20960	Compression: 0.110687	Avg Compression: 0.398348
# Article 126000:	Length: 21024	Compression: 0.105213	Avg Compression: 0.390541
# Article 127000:	Length: 21088	Compression: 0.105605	Avg Compression: 0.383128
# Article 128000:	Length: 21144	Compression: 0.108589	Avg Compression: 0.376148
# Article 129000:	Length: 21208	Compression: 0.109015	Avg Compression: 0.369506
# Article 130000:	Length: 21272	Compression: 0.104457	Avg Compression: 0.363056
# Article 131000:	Length: 21344	Compression: 0.115723	Avg Compression: 0.357161
# Article 132000:	Length: 21432	Compression: 0.105403	Avg Compression: 0.351276
# Article 133000:	Length: 21528	Compression: 0.109810	Avg Compression: 0.345737
# Article 134000:	Length: 21616	Compression: 0.115192	Avg Compression: 0.340546
# Article 135000:	Length: 21744	Compression: 0.117918	Avg Compression: 0.335616
# Article 136000:	Length: 21856	Compression: 0.359535	Avg Compression: 0.336137
# Article 137000:	Length: 21992	Compression: 0.108267	Avg Compression: 0.331251
# Article 138000:	Length: 22136	Compression: 0.112848	Avg Compression: 0.326637
# Article 139000:	Length: 22312	Compression: 0.111465	Avg Compression: 0.322150
# Article 140000:	Length: 22496	Compression: 0.108819	Avg Compression: 0.317758
# Article 141000:	Length: 22464	Compression: 0.402733	Avg Compression: 0.319470
# Article 142000:	Length: 23008	Compression: 0.364308	Avg Compression: 0.320376
# Article 143000:	Length: 23192	Compression: 0.118015	Avg Compression: 0.316335
# Article 144000:	Length: 23472	Compression: 0.288897	Avg Compression: 0.315791
# Article 145000:	Length: 23760	Compression: 0.330261	Avg Compression: 0.316076
# Article 146000:	Length: 24096	Compression: 0.119605	Avg Compression: 0.312235
# Article 147000:	Length: 24432	Compression: 0.131713	Avg Compression: 0.308726
# Article 148000:	Length: 24800	Compression: 0.297742	Avg Compression: 0.308514
# Article 149000:	Length: 25200	Compression: 0.131667	Avg Compression: 0.305104
# Article 150000:	Length: 25608	Compression: 0.333724	Avg Compression: 0.305654
# Article 151000:	Length: 26040	Compression: 0.375768	Avg Compression: 0.306998
# Article 152000:	Length: 26392	Compression: 0.345900	Avg Compression: 0.307739
# Article 153000:	Length: 26328	Compression: 0.440140	Avg Compression: 0.310209
# Article 154000:	Length: 27144	Compression: 0.365090	Avg Compression: 0.311245
# Article 155000:	Length: 27664	Compression: 0.319549	Avg Compression: 0.311401
# Article 156000:	Length: 28136	Compression: 0.361494	Avg Compression: 0.312344
# Article 157000:	Length: 28608	Compression: 0.160549	Avg Compression: 0.309493
# Article 158000:	Length: 29096	Compression: 0.330011	Avg Compression: 0.309878
# Article 159000:	Length: 29576	Compression: 0.156681	Avg Compression: 0.307013
# Article 160000:	Length: 30096	Compression: 0.417198	Avg Compression: 0.309070
# Article 161000:	Length: 30640	Compression: 0.173727	Avg Compression: 0.306545
# Article 162000:	Length: 31216	Compression: 0.373462	Avg Compression: 0.307794
# Article 163000:	Length: 31496	Compression: 0.402115	Avg Compression: 0.309536
# Article 164000:	Length: 32408	Compression: 0.178042	Avg Compression: 0.307083
# Article 165000:	Length: 33000	Compression: 0.333545	Avg Compression: 0.307576
# Article 166000:	Length: 33248	Compression: 0.405528	Avg Compression: 0.309382
# Article 167000:	Length: 34352	Compression: 0.360881	Avg Compression: 0.310344
# Article 168000:	Length: 35072	Compression: 0.298586	Avg Compression: 0.310124
# Article 169000:	Length: 35776	Compression: 0.328097	Avg Compression: 0.310461
# Article 170000:	Length: 36536	Compression: 0.349737	Avg Compression: 0.311199
# Article 171000:	Length: 37144	Compression: 0.352816	Avg Compression: 0.311978
# Article 172000:	Length: 38040	Compression: 0.204416	Avg Compression: 0.309954
# Article 173000:	Length: 38880	Compression: 0.193056	Avg Compression: 0.307747
# Article 174000:	Length: 39424	Compression: 0.491680	Avg Compression: 0.311201
# Article 175000:	Length: 40688	Compression: 0.194111	Avg Compression: 0.308975
# Article 176000:	Length: 41616	Compression: 0.203503	Avg Compression: 0.306963
# Article 177000:	Length: 42552	Compression: 0.347410	Avg Compression: 0.307737
# Article 178000:	Length: 43360	Compression: 0.398409	Avg Compression: 0.309471
# Article 179000:	Length: 44672	Compression: 0.292756	Avg Compression: 0.309148
# Article 180000:	Length: 45704	Compression: 0.300696	Avg Compression: 0.308984
# Article 181000:	Length: 46872	Compression: 0.298110	Avg Compression: 0.308772
# Article 182000:	Length: 48224	Compression: 0.233722	Avg Compression: 0.307296
# Article 183000:	Length: 49496	Compression: 0.208684	Avg Compression: 0.305346
# Article 184000:	Length: 50872	Compression: 0.202056	Avg Compression: 0.303287
# Article 185000:	Length: 52352	Compression: 0.332022	Avg Compression: 0.303865
# Article 186000:	Length: 53704	Compression: 0.337722	Avg Compression: 0.304549
# Article 187000:	Length: 55128	Compression: 0.318332	Avg Compression: 0.304828
# Article 188000:	Length: 56824	Compression: 0.317753	Avg Compression: 0.305094
# Article 189000:	Length: 58288	Compression: 0.351359	Avg Compression: 0.306047
# Article 190000:	Length: 60624	Compression: 0.307766	Avg Compression: 0.306083
# Article 191000:	Length: 62056	Compression: 0.340064	Avg Compression: 0.306797
# Article 192000:	Length: 63760	Compression: 0.308516	Avg Compression: 0.306833
# Article 193000:	Length: 65488	Compression: 0.322746	Avg Compression: 0.307172
# Article 194000:	Length: 68008	Compression: 0.328682	Avg Compression: 0.307636
# Article 195000:	Length: 70440	Compression: 0.246408	Avg Compression: 0.306297
# Article 196000:	Length: 72224	Compression: 0.325197	Avg Compression: 0.306711
# Article 197000:	Length: 75336	Compression: 0.286384	Avg Compression: 0.306256
# Article 198000:	Length: 77792	Compression: 0.286045	Avg Compression: 0.305800
# Article 199000:	Length: 80256	Compression: 0.336237	Avg Compression: 0.306493
# Article 200000:	Length: 84232	Compression: 0.360659	Avg Compression: 0.307757
# Article 201000:	Length: 87152	Compression: 0.358753	Avg Compression: 0.308959
# Article 202000:	Length: 90944	Compression: 0.285890	Avg Compression: 0.308405
# Article 203000:	Length: 94504	Compression: 0.341583	Avg Compression: 0.309213
# Article 204000:	Length: 99864	Compression: 0.367470	Avg Compression: 0.310674
# Article 205000:	Length: 103760	Compression: 0.315661	Avg Compression: 0.310801
# Article 206000:	Length: 108576	Compression: 0.363229	Avg Compression: 0.312158
# Article 207000:	Length: 112664	Compression: 0.313596	Avg Compression: 0.312195
# Article 208000:	Length: 119704	Compression: 0.379895	Avg Compression: 0.314026
# Article 209000:	Length: 126704	Compression: 0.318222	Avg Compression: 0.314143
# Article 210000:	Length: 133480	Compression: 0.369763	Avg Compression: 0.315727
# Article 211000:	Length: 142360	Compression: 0.401398	Avg Compression: 0.318252
# Article 212000:	Length: 152048	Compression: 0.357690	Avg Compression: 0.319456
# Article 213000:	Length: 163720	Compression: 0.309602	Avg Compression: 0.319143
# Article 214000:	Length: 177648	Compression: 0.314785	Avg Compression: 0.318997
# Article 215000:	Length: 193192	Compression: 0.343762	Avg Compression: 0.319865
# Article 216000:	Length: 213000	Compression: 0.286333	Avg Compression: 0.318618
# Article 217000:	Length: 238400	Compression: 0.327815	Avg Compression: 0.318985
# Article 218000:	Length: 274360	Compression: 0.330081	Avg Compression: 0.319473
# Article 219000:	Length: 329056	Compression: 0.292503	Avg Compression: 0.318122
# Article 220000:	Length: 458704	Compression: 0.509937	Avg Compression: 0.330639

# %%
model.train(192, 192, epochs=5)
# Out:
# Epoch 1/5
# 14342/14342 [==============================] - 9118s 636ms/step - loss: nan - average_final_batch_ratio: 0.3428
# Epoch 2/5
#  3824/14342 [======>.......................] - ETA: 1:43:25 - loss: nan - average_final_batch_ratio: 0.4792
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-b2f433aa52ae> in <module>
# ----> 1 model.train(192, 192, epochs=5)
#
# <ipython-input-10-52b93ebffef2> in train(self, batch_size, batched_item_length, epochs)
#      68         model = self.training_model(batch_size, batched_item_length)
#      69
# ---> 70         model.fit(dataset, epochs=epochs, callbacks=self.callbacks)
#      71
#      72     @property
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     340                 mode=ModeKeys.TRAIN,
#     341                 training_context=training_context,
# --> 342                 total_epochs=epochs)
#     343             cbks.make_logs(model, epoch_logs, training_result, ModeKeys.TRAIN)
#     344
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in run_one_epoch(model, iterator, execution_function, dataset_size, batch_size, strategy, steps_per_epoch, num_samples, mode, training_context, total_epochs)
#     126         step=step, mode=mode, size=current_batch_size) as batch_logs:
#     127       try:
# --> 128         batch_outs = execution_function(iterator)
#     129       except (StopIteration, errors.OutOfRangeError):
#     130         # TODO(kaftan): File bug about tf function and errors.OutOfRangeError?
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training_v2_utils.py in execution_function(input_fn)
#      96     # `numpy` translates Tensors to values in Eager mode.
#      97     return nest.map_structure(_non_none_constant_value,
# ---> 98                               distributed_function(input_fn))
#      99
#     100   return execution_function
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\eager\def_function.py in __call__(self, *args, **kwds)
#     566         xla_context.Exit()
#     567     else:
# --> 568       result = self._call(*args, **kwds)
#     569
#     570     if tracing_count == self._get_tracing_count():
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\eager\def_function.py in _call(self, *args, **kwds)
#     597       # In this case we have created variables on the first call, so we run the
#     598       # defunned version which is guaranteed to never create variables.
# --> 599       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     600     elif self._stateful_fn is not None:
#     601       # Release the lock early so that multiple threads can perform the call
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    2361     with self._lock:
#    2362       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2363     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2364
#    2365   @property
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\eager\function.py in _filtered_call(self, args, kwargs)
#    1609          if isinstance(t, (ops.Tensor,
#    1610                            resource_variable_ops.BaseResourceVariable))),
# -> 1611         self.captured_inputs)
#    1612
#    1613   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:
