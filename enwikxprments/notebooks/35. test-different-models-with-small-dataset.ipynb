# %%
import itertools
import math
import os

import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds

physical_devices = tf.config.list_physical_devices('GPU')
for physical_device in physical_devices:
    tf.config.experimental.set_memory_growth(physical_device, enable=True)

# %%
TYPE=np.int16

subword_text_encoder = tfds.features.text.SubwordTextEncoder.load_from_file('vocab_4096')

class Articles:
    EMPTY_ARTICLE = np.array([], dtype=TYPE) # used for padding
    
    def __init__(self, path):
        with open(path, 'rb') as text_file:
            data = text_file.read()

        self.articles = sorted(set(data.split(b'\0')[:2000]), key=len)
        self._encoded_articles = None

    @property
    def encoded_articles(self):
        if self._encoded_articles == None:
            self._encoded_articles = [np.array(subword_text_encoder.encode(article), dtype=TYPE) for article in self.articles]
        
        return self._encoded_articles

    def articles_generator(self, batch_size = 1, start = 0, end = None):
        end = end or len(self.articles)

        for _ in range(batch_size - ((end - start - 1) % batch_size + 1)):
            yield self.EMPTY_ARTICLE

        for article in itertools.islice(self.encoded_articles, start, end):
            yield article

    def subbatch_generator(self, batch_size, batch_length, start = 0, end = None):
        end = end or len(self.articles)

        dataset = tf.data.Dataset.from_generator(self.articles_generator, args=(batch_size, start, end), output_types=TYPE)
        dataset = dataset.padded_batch(batch_size, padded_shapes=([None]), drop_remainder=True)
        dataset = dataset.shuffle(100)

        for batch in dataset.as_numpy_iterator():
            remaining = batch
            while remaining.shape[1] > batch_length + 1:
                yield remaining[:, :batch_length + 1]
                remaining = remaining[:, batch_length:]

            if remaining.shape[1] == batch_length + 1:
                yield remaining
                yield np.zeros((batch_size, batch_length + 1), dtype=TYPE)
            else:
                yield np.hstack([remaining, np.zeros([batch_size, batch_length - remaining.shape[1] + 1])])

    def steps(self, batch_size, batch_length):
        articles = self.articles_generator(batch_size, batch_length)
        return sum(math.ceil(len(article) / batch_length + 1) for i, article in enumerate(articles) if (i + 1) % batch_size == 0)

    def dataset(self, batch_size, batch_length, start = 0, end = None):
        end = end or len(self.articles)

        dataset = tf.data.Dataset.from_generator(self.subbatch_generator, args=(batch_size, batch_length, start, end), output_types=TYPE, output_shapes=(batch_size, batch_length + 1))
        return dataset.map(lambda batch: (batch[:, :-1], batch[:, 1:]))

# %%
def loss(labels, logits):
    return tf.keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)

def average_final_batch_ratio(true_labels, predictions):
    return 0 ** tf.math.abs(true_labels[-1, -1])

class ModelStateResetter(tf.keras.callbacks.Callback):
    def __init__(self):
        pass

    def on_epoch_begin(self, epoch, logs=None):
        self.last_final_batch_count = 0
        
    def on_batch_end(self, batch, logs={}):
        average_final_batch_ratio = logs.get('average_final_batch_ratio', 0)
        final_batch_count = int(round(average_final_batch_ratio * (batch + 1)))
        is_final = final_batch_count - self.last_final_batch_count
        self.last_final_batch_count = final_batch_count
        
        if is_final:
            self.model.reset_states()

class Model:
    def __init__(self, articles, checkpoint_dir, vocab_size, embedding_dim, rnn_units):
        self._articles = articles
        self._batch_size = None
        self._batched_item_length = None
        self._training_model = None
        self._predicting_model = None
        self._vocab_size = vocab_size
        self._embedding_dim = embedding_dim
        self._rnn_units = rnn_units

        self._checkpoint_dir = checkpoint_dir
        self._checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt_{epoch}") # Name of the checkpoint files

    def training_model(self, batch_size, batched_item_length):
        if self._training_model == None or batch_size != self._batch_size or batched_item_length != self._batched_item_length:
            self._batch_size = batch_size
            self._batched_item_length = batched_item_length
            self._training_model = tf.keras.Sequential([
                tf.keras.layers.Masking(mask_value=0, batch_input_shape=[batch_size, batched_item_length]),
                tf.keras.layers.Embedding(self._vocab_size, self._embedding_dim),
                tf.keras.layers.GRU(self._rnn_units, return_sequences=True, stateful=True, recurrent_initializer='glorot_uniform'),
                tf.keras.layers.GRU(self._rnn_units, return_sequences=True, stateful=True, recurrent_initializer='glorot_uniform'),
                tf.keras.layers.Dense(self._vocab_size),
            ])

            if os.path.isdir(self._checkpoint_dir):
                self._training_model.load_weights(tf.train.latest_checkpoint(self._checkpoint_dir))

            self._training_model.compile(optimizer='adam', loss=loss, metrics=[average_final_batch_ratio])
            self._predicting_model = None
        
        return self._training_model

    @property
    def callbacks(self):
        checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=self._checkpoint_prefix, save_weights_only=True)
        model_state_resetter_callback = ModelStateResetter()
        
        return [checkpoint_callback, model_state_resetter_callback]
    
    def train(self, batch_size, batched_item_length, epochs=1):
        dataset = self._articles.dataset(batch_size, batched_item_length)

        model = self.training_model(batch_size, batched_item_length)

        model.fit(dataset, epochs=epochs, callbacks=self.callbacks)
    
    @property
    def predicting_model(self):
        if self._predicting_model == None:
            self._predicting_model = tf.keras.Sequential([
                tf.keras.layers.Masking(mask_value=0, batch_input_shape=[1, 1]),
                tf.keras.layers.Embedding(self._vocab_size, self._embedding_dim),
                tf.keras.layers.GRU(self._rnn_units, stateful=True, return_sequences=True),
                tf.keras.layers.GRU(self._rnn_units, stateful=True, return_sequences=True),
                tf.keras.layers.Dense(self._vocab_size),
            ])
            
            self._predicting_model.load_weights(tf.train.latest_checkpoint(self._checkpoint_dir))
            self._training_model = None
        
        return self._predicting_model
    
    def predict(self, input_eval):
        return self.predicting_model(input_eval)

# %%
articles = Articles('page_revisions_text')

# %%
steps = 13

for i in range(steps):
    batch_size = 4 * 2**i
    batch_item_length = 3 * 2**(steps - i - 1)
    count = articles.steps(batch_size, batch_item_length)
    print("batch size: %6d\t batch item length: %4d\tsteps per epoch: %6d" % (batch_size, batch_item_length, count))
# Out:
# batch size:      4	 batch item length: 12288	steps per epoch:      0
# batch size:      8	 batch item length: 6144	steps per epoch:      0
# batch size:     16	 batch item length: 3072	steps per epoch:      0
# batch size:     32	 batch item length: 1536	steps per epoch:     96
# batch size:     64	 batch item length:  768	steps per epoch:    149
# batch size:    128	 batch item length:  384	steps per epoch:    167
# batch size:    256	 batch item length:  192	steps per epoch:    220
# batch size:    512	 batch item length:   96	steps per epoch:    349
# batch size:   1024	 batch item length:   48	steps per epoch:    625
# batch size:   2048	 batch item length:   24	steps per epoch:   1215
# batch size:   4096	 batch item length:   12	steps per epoch:   2429
# batch size:   8192	 batch item length:    6	steps per epoch:   4856
# batch size:  16384	 batch item length:    3	steps per epoch:   9710

# %%
model = Model(articles, './training_checkpoints-10',
              vocab_size = subword_text_encoder.vocab_size,
              embedding_dim=512,
              rnn_units=1024)

# %%
model.training_model(256, 192).summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# masking (Masking)            (256, 192)                0
# _________________________________________________________________
# embedding (Embedding)        (256, 192, 512)           2072576
# _________________________________________________________________
# gru (GRU)                    (256, 192, 1024)          4724736
# _________________________________________________________________
# gru_1 (GRU)                  (256, 192, 1024)          6297600
# _________________________________________________________________
# dense (Dense)                (256, 192, 4048)          4149200
# =================================================================
# Total params: 17,244,112
# Trainable params: 17,244,112
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.train(256, 192, epochs=10)
# Out:
# Epoch 1/10
# 236/236 [==============================] - 187s 791ms/step - loss: 3.3773 - average_final_batch_ratio: 0.1271
# Epoch 2/10
# 236/236 [==============================] - 185s 785ms/step - loss: 2.5523 - average_final_batch_ratio: 0.1271
# Epoch 3/10
# 236/236 [==============================] - 186s 787ms/step - loss: 2.2062 - average_final_batch_ratio: 0.1271
# Epoch 4/10
# 236/236 [==============================] - 185s 783ms/step - loss: 2.0383 - average_final_batch_ratio: 0.1271
# Epoch 5/10
# 236/236 [==============================] - 186s 788ms/step - loss: 1.9080 - average_final_batch_ratio: 0.1271
# Epoch 6/10
# 236/236 [==============================] - 185s 785ms/step - loss: 1.8081 - average_final_batch_ratio: 0.1271
# Epoch 7/10
# 236/236 [==============================] - 186s 787ms/step - loss: 1.7176 - average_final_batch_ratio: 0.1271
# Epoch 8/10
# 236/236 [==============================] - 186s 787ms/step - loss: 1.6542 - average_final_batch_ratio: 0.1271
# Epoch 9/10
# 236/236 [==============================] - 185s 785ms/step - loss: 1.5941 - average_final_batch_ratio: 0.1271
# Epoch 10/10
# 236/236 [==============================] - 186s 788ms/step - loss: 1.5437 - average_final_batch_ratio: 0.1271

# %%
import ctypes

class Huffman:
    huffman = ctypes.CDLL('x64/Release/huffman')
    
    huffman.create_tree.restype = ctypes.c_void_p
    huffman.destroy_tree.restype = None
    huffman.load_weights.restype = None
    huffman.create_code_string.restype = ctypes.c_char_p
    
    def __init__(self, category_count):
        self.tree = ctypes.c_void_p(self.huffman.create_tree(category_count))

    def __del__(self):
        self.huffman.destroy_tree(self.tree)
        
    def load_weights(self, weights):
        self.huffman.load_weights(self.tree, weights.ctypes.data_as(ctypes.POINTER(ctypes.c_float)))
    
    def get_code_length(self, category):
        return self.huffman.get_code_length(self.tree, category)

    def get_code_zero_count(self, category):
        return self.huffman.get_code_zero_count(self.tree, category)

# %%
def huffman_archive_size(model, text):
    archived_size = 0
    zeros = 0
    input_eval = np.array([[0]], dtype=TYPE)
    huffman_tree = Huffman(subword_text_encoder.vocab_size)

    text_generated = []

    model.predicting_model.reset_states()

    for index, byte in enumerate(text):
        predictions = model.predict(input_eval)
        predictions = tf.squeeze(predictions, 0) # remove the batch dimension

        weights = tf.nn.softmax(predictions[0]).numpy()
        huffman_tree.load_weights(weights)
        zeros += huffman_tree.get_code_zero_count(byte.item())
        archived_size += huffman_tree.get_code_length(byte.item())

        input_eval = tf.expand_dims([byte], 0)
  
    return archived_size, zeros

# %%
total_raw = 0
total_compressed = 0

for index, encoded_article in enumerate(articles.articles_generator(1)):
    if index % 10 == 0:
        article = subword_text_encoder.decode(encoded_article)
        raw = len(article) * 8
        if raw == 0:
            continue
        compressed, _ = huffman_archive_size(model, encoded_article)
        total_raw += raw
        total_compressed += compressed

        print('Article %d:\tLength: %d\tCompression: %f\tAvg Compression: %f' % (index, raw, compressed/raw, total_compressed/total_raw))
# Out:
# Article 0:	Length: 128	Compression: 0.609375	Avg Compression: 0.609375
# Article 10:	Length: 144	Compression: 0.534722	Avg Compression: 0.569853
# Article 20:	Length: 152	Compression: 0.585526	Avg Compression: 0.575472
# Article 30:	Length: 160	Compression: 0.537500	Avg Compression: 0.565068
# Article 40:	Length: 160	Compression: 0.456250	Avg Compression: 0.541667
# Article 50:	Length: 168	Compression: 0.464286	Avg Compression: 0.527412
# Article 60:	Length: 168	Compression: 0.440476	Avg Compression: 0.513889
# Article 70:	Length: 176	Compression: 0.443182	Avg Compression: 0.503981
# Article 80:	Length: 176	Compression: 0.426136	Avg Compression: 0.494413
# Article 90:	Length: 184	Compression: 0.483696	Avg Compression: 0.493193
# Article 100:	Length: 184	Compression: 0.494565	Avg Compression: 0.493333
# Article 110:	Length: 192	Compression: 0.453125	Avg Compression: 0.489458
# Article 120:	Length: 192	Compression: 0.458333	Avg Compression: 0.486722
# Article 130:	Length: 200	Compression: 0.585000	Avg Compression: 0.494966
# Article 140:	Length: 200	Compression: 0.530000	Avg Compression: 0.497678
# Article 150:	Length: 208	Compression: 0.533654	Avg Compression: 0.500358
# Article 160:	Length: 208	Compression: 0.399038	Avg Compression: 0.493333
# Article 170:	Length: 216	Compression: 0.444444	Avg Compression: 0.490050
# Article 180:	Length: 216	Compression: 0.356481	Avg Compression: 0.481643
# Article 190:	Length: 224	Compression: 0.495536	Avg Compression: 0.482495
# Article 200:	Length: 224	Compression: 0.339286	Avg Compression: 0.474227
# Article 210:	Length: 232	Compression: 0.400862	Avg Compression: 0.470088
# Article 220:	Length: 232	Compression: 0.375000	Avg Compression: 0.465009
# Article 230:	Length: 240	Compression: 0.375000	Avg Compression: 0.460297
# Article 240:	Length: 240	Compression: 0.375000	Avg Compression: 0.456053
# Article 250:	Length: 248	Compression: 0.318548	Avg Compression: 0.449330
# Article 260:	Length: 256	Compression: 0.441406	Avg Compression: 0.448949
# Article 270:	Length: 256	Compression: 0.339844	Avg Compression: 0.443947
# Article 280:	Length: 256	Compression: 0.312500	Avg Compression: 0.438185
# Article 290:	Length: 256	Compression: 0.558594	Avg Compression: 0.443241
# Article 300:	Length: 264	Compression: 0.325758	Avg Compression: 0.438365
# Article 310:	Length: 264	Compression: 0.344697	Avg Compression: 0.434632
# Article 320:	Length: 272	Compression: 0.294118	Avg Compression: 0.429089
# Article 330:	Length: 272	Compression: 0.448529	Avg Compression: 0.429827
# Article 340:	Length: 272	Compression: 0.430147	Avg Compression: 0.429839
# Article 350:	Length: 264	Compression: 0.583333	Avg Compression: 0.435099
# Article 360:	Length: 280	Compression: 0.289286	Avg Compression: 0.429985
# Article 370:	Length: 280	Compression: 0.292857	Avg Compression: 0.425339
# Article 380:	Length: 288	Compression: 0.586806	Avg Compression: 0.430776
# Article 390:	Length: 288	Compression: 0.319444	Avg Compression: 0.427149
# Article 400:	Length: 296	Compression: 0.263514	Avg Compression: 0.421848
# Article 410:	Length: 296	Compression: 0.364865	Avg Compression: 0.420059
# Article 420:	Length: 304	Compression: 0.256579	Avg Compression: 0.414955
# Article 430:	Length: 312	Compression: 0.285256	Avg Compression: 0.410928
# Article 440:	Length: 320	Compression: 0.300000	Avg Compression: 0.407504
# Article 450:	Length: 328	Compression: 0.292683	Avg Compression: 0.403983
# Article 460:	Length: 336	Compression: 0.306548	Avg Compression: 0.401015
# Article 470:	Length: 344	Compression: 0.252907	Avg Compression: 0.396537
# Article 480:	Length: 360	Compression: 0.297222	Avg Compression: 0.393490
# Article 490:	Length: 368	Compression: 0.366848	Avg Compression: 0.392680
# Article 500:	Length: 440	Compression: 0.415909	Avg Compression: 0.393495
# Article 510:	Length: 416	Compression: 0.411058	Avg Compression: 0.394059
# Article 520:	Length: 432	Compression: 0.261574	Avg Compression: 0.389785
# Article 530:	Length: 488	Compression: 0.256148	Avg Compression: 0.385086
# Article 540:	Length: 608	Compression: 0.235197	Avg Compression: 0.378796
# Article 550:	Length: 1696	Compression: 0.198113	Avg Compression: 0.359862
# Article 560:	Length: 2608	Compression: 0.197086	Avg Compression: 0.337271
# Article 570:	Length: 3256	Compression: 0.267813	Avg Compression: 0.327014
# Article 580:	Length: 4032	Compression: 0.316468	Avg Compression: 0.325383
# Article 590:	Length: 4616	Compression: 0.247617	Avg Compression: 0.313689
# Article 600:	Length: 5080	Compression: 0.239567	Avg Compression: 0.303164
# Article 610:	Length: 5552	Compression: 0.254323	Avg Compression: 0.296603
# Article 620:	Length: 5928	Compression: 0.338394	Avg Compression: 0.301845
# Article 630:	Length: 6480	Compression: 0.279475	Avg Compression: 0.299148
# Article 640:	Length: 6720	Compression: 0.287798	Avg Compression: 0.297886
# Article 650:	Length: 6960	Compression: 0.230029	Avg Compression: 0.290881
# Article 660:	Length: 7824	Compression: 0.295884	Avg Compression: 0.291401
# Article 670:	Length: 8360	Compression: 0.273565	Avg Compression: 0.289617
# Article 680:	Length: 8824	Compression: 0.273685	Avg Compression: 0.288096
# Article 690:	Length: 9288	Compression: 0.227821	Avg Compression: 0.282592
# Article 700:	Length: 9920	Compression: 0.286492	Avg Compression: 0.282939
# Article 710:	Length: 10552	Compression: 0.276061	Avg Compression: 0.282345
# Article 720:	Length: 11056	Compression: 0.262482	Avg Compression: 0.280696
# Article 730:	Length: 11776	Compression: 0.251613	Avg Compression: 0.278335
# Article 740:	Length: 12424	Compression: 0.273100	Avg Compression: 0.277922
# Article 750:	Length: 12944	Compression: 0.221879	Avg Compression: 0.273664
# Article 760:	Length: 13472	Compression: 0.309754	Avg Compression: 0.276309
# Article 770:	Length: 13888	Compression: 0.213206	Avg Compression: 0.271877
# Article 780:	Length: 14096	Compression: 0.260570	Avg Compression: 0.271124
# Article 790:	Length: 14800	Compression: 0.242027	Avg Compression: 0.269224
# Article 800:	Length: 15200	Compression: 0.306250	Avg Compression: 0.271551
# Article 810:	Length: 16024	Compression: 0.253183	Avg Compression: 0.270410
# Article 820:	Length: 16336	Compression: 0.241552	Avg Compression: 0.268691
# Article 830:	Length: 16904	Compression: 0.252958	Avg Compression: 0.267777
# Article 840:	Length: 17192	Compression: 0.300081	Avg Compression: 0.269579
# Article 850:	Length: 17632	Compression: 0.272346	Avg Compression: 0.269728
# Article 860:	Length: 17736	Compression: 0.236299	Avg Compression: 0.268003
# Article 870:	Length: 18408	Compression: 0.235767	Avg Compression: 0.266364
# Article 880:	Length: 18944	Compression: 0.246358	Avg Compression: 0.265369
# Article 890:	Length: 19320	Compression: 0.254865	Avg Compression: 0.264863
# Article 900:	Length: 20120	Compression: 0.259891	Avg Compression: 0.264625
# Article 910:	Length: 20368	Compression: 0.297427	Avg Compression: 0.266140
# Article 920:	Length: 20560	Compression: 0.249951	Avg Compression: 0.265419
# Article 930:	Length: 21408	Compression: 0.272702	Avg Compression: 0.265742
# Article 940:	Length: 22352	Compression: 0.308205	Avg Compression: 0.267621
# Article 950:	Length: 23192	Compression: 0.284452	Avg Compression: 0.268360
# Article 960:	Length: 23944	Compression: 0.243986	Avg Compression: 0.267303
# Article 970:	Length: 24192	Compression: 0.287244	Avg Compression: 0.268140
# Article 980:	Length: 25624	Compression: 0.234234	Avg Compression: 0.266697
# Article 990:	Length: 26592	Compression: 0.245111	Avg Compression: 0.265784
# Article 1000:	Length: 27224	Compression: 0.256208	Avg Compression: 0.265386
# Article 1010:	Length: 28328	Compression: 0.271216	Avg Compression: 0.265628
# Article 1020:	Length: 28416	Compression: 0.260065	Avg Compression: 0.265406
# Article 1030:	Length: 29016	Compression: 0.265888	Avg Compression: 0.265425
# Article 1040:	Length: 29920	Compression: 0.266009	Avg Compression: 0.265447
# Article 1050:	Length: 30600	Compression: 0.286732	Avg Compression: 0.266259
# Article 1060:	Length: 30488	Compression: 0.275551	Avg Compression: 0.266599
# Article 1070:	Length: 32032	Compression: 0.259553	Avg Compression: 0.266338
# Article 1080:	Length: 33016	Compression: 0.264145	Avg Compression: 0.266258
# Article 1090:	Length: 33472	Compression: 0.246475	Avg Compression: 0.265547
# Article 1100:	Length: 34536	Compression: 0.243167	Avg Compression: 0.264746
# Article 1110:	Length: 35264	Compression: 0.272232	Avg Compression: 0.265010
# Article 1120:	Length: 35736	Compression: 0.264663	Avg Compression: 0.264998
# Article 1130:	Length: 36448	Compression: 0.285530	Avg Compression: 0.265695
# Article 1140:	Length: 37448	Compression: 0.254673	Avg Compression: 0.265324
# Article 1150:	Length: 38424	Compression: 0.262362	Avg Compression: 0.265225
# Article 1160:	Length: 38680	Compression: 0.278102	Avg Compression: 0.265644
# Article 1170:	Length: 40216	Compression: 0.283196	Avg Compression: 0.266219
# Article 1180:	Length: 41480	Compression: 0.320685	Avg Compression: 0.267999
# Article 1190:	Length: 42616	Compression: 0.282218	Avg Compression: 0.268460
# Article 1200:	Length: 43488	Compression: 0.304912	Avg Compression: 0.269630
# Article 1210:	Length: 45080	Compression: 0.266038	Avg Compression: 0.269514
# Article 1220:	Length: 46864	Compression: 0.265150	Avg Compression: 0.269373
# Article 1230:	Length: 48608	Compression: 0.243972	Avg Compression: 0.268548
# Article 1240:	Length: 50264	Compression: 0.262892	Avg Compression: 0.268364
# Article 1250:	Length: 51272	Compression: 0.282025	Avg Compression: 0.268802
# Article 1260:	Length: 52528	Compression: 0.265192	Avg Compression: 0.268687
# Article 1270:	Length: 53688	Compression: 0.275499	Avg Compression: 0.268902
# Article 1280:	Length: 54640	Compression: 0.257778	Avg Compression: 0.268556
# Article 1290:	Length: 55440	Compression: 0.258838	Avg Compression: 0.268259
# Article 1300:	Length: 56320	Compression: 0.257156	Avg Compression: 0.267925
# Article 1310:	Length: 58648	Compression: 0.225396	Avg Compression: 0.266632
# Article 1320:	Length: 60504	Compression: 0.281089	Avg Compression: 0.267072
# Article 1330:	Length: 62376	Compression: 0.238281	Avg Compression: 0.266196
# Article 1340:	Length: 63840	Compression: 0.282675	Avg Compression: 0.266694
# Article 1350:	Length: 65976	Compression: 0.249727	Avg Compression: 0.266180
# Article 1360:	Length: 67128	Compression: 0.250477	Avg Compression: 0.265712
# Article 1370:	Length: 68800	Compression: 0.264593	Avg Compression: 0.265678
# Article 1380:	Length: 70576	Compression: 0.317502	Avg Compression: 0.267210
# Article 1390:	Length: 72432	Compression: 0.253935	Avg Compression: 0.266819
# Article 1400:	Length: 74752	Compression: 0.268501	Avg Compression: 0.266869
# Article 1410:	Length: 75792	Compression: 0.273010	Avg Compression: 0.267047
# Article 1420:	Length: 78368	Compression: 0.266588	Avg Compression: 0.267034
# Article 1430:	Length: 80136	Compression: 0.235787	Avg Compression: 0.266130
# Article 1440:	Length: 83192	Compression: 0.260518	Avg Compression: 0.265966
# Article 1450:	Length: 84736	Compression: 0.254957	Avg Compression: 0.265648
# Article 1460:	Length: 87880	Compression: 0.273043	Avg Compression: 0.265863
# Article 1470:	Length: 88760	Compression: 0.279811	Avg Compression: 0.266261
# Article 1480:	Length: 89704	Compression: 0.276900	Avg Compression: 0.266559
# Article 1490:	Length: 91864	Compression: 0.258121	Avg Compression: 0.266323
# Article 1500:	Length: 94344	Compression: 0.263080	Avg Compression: 0.266233
# Article 1510:	Length: 97160	Compression: 0.243670	Avg Compression: 0.265604
# Article 1520:	Length: 98752	Compression: 0.228785	Avg Compression: 0.264591
# Article 1530:	Length: 101024	Compression: 0.233539	Avg Compression: 0.263740
# Article 1540:	Length: 103016	Compression: 0.222664	Avg Compression: 0.262623
# Article 1550:	Length: 106432	Compression: 0.262844	Avg Compression: 0.262629
# Article 1560:	Length: 107664	Compression: 0.232436	Avg Compression: 0.261817
# Article 1570:	Length: 109952	Compression: 0.261341	Avg Compression: 0.261805
# Article 1580:	Length: 112616	Compression: 0.227641	Avg Compression: 0.260894
# Article 1590:	Length: 115984	Compression: 0.251129	Avg Compression: 0.260634
# Article 1600:	Length: 117944	Compression: 0.264032	Avg Compression: 0.260723
# Article 1610:	Length: 120872	Compression: 0.233412	Avg Compression: 0.260003
# Article 1620:	Length: 123248	Compression: 0.234868	Avg Compression: 0.259344
# Article 1630:	Length: 125152	Compression: 0.233396	Avg Compression: 0.258672
# Article 1640:	Length: 128960	Compression: 0.254389	Avg Compression: 0.258561
# Article 1650:	Length: 132816	Compression: 0.219379	Avg Compression: 0.257539
# Article 1660:	Length: 134584	Compression: 0.223110	Avg Compression: 0.256652
# Article 1670:	Length: 141472	Compression: 0.224044	Avg Compression: 0.255793
# Article 1680:	Length: 146472	Compression: 0.254404	Avg Compression: 0.255756
# Article 1690:	Length: 151840	Compression: 0.278945	Avg Compression: 0.256377
# Article 1700:	Length: 157048	Compression: 0.290605	Avg Compression: 0.257300
# Article 1710:	Length: 161424	Compression: 0.258159	Avg Compression: 0.257323
# Article 1720:	Length: 164208	Compression: 0.286369	Avg Compression: 0.258099
# Article 1730:	Length: 174464	Compression: 0.276814	Avg Compression: 0.258615
# Article 1740:	Length: 189072	Compression: 0.230991	Avg Compression: 0.257813
# Article 1750:	Length: 195080	Compression: 0.236626	Avg Compression: 0.257197
# Article 1760:	Length: 202592	Compression: 0.237379	Avg Compression: 0.256616
# Article 1770:	Length: 213160	Compression: 0.252876	Avg Compression: 0.256504
# Article 1780:	Length: 220440	Compression: 0.257154	Avg Compression: 0.256524
# Article 1790:	Length: 229744	Compression: 0.282366	Avg Compression: 0.257308
# Article 1800:	Length: 246304	Compression: 0.233533	Avg Compression: 0.256559
# Article 1810:	Length: 251304	Compression: 0.273856	Avg Compression: 0.257097
# Article 1820:	Length: 268336	Compression: 0.255512	Avg Compression: 0.257046
# Article 1830:	Length: 283192	Compression: 0.244043	Avg Compression: 0.256619
# Article 1840:	Length: 307368	Compression: 0.243165	Avg Compression: 0.256156
# Article 1850:	Length: 323168	Compression: 0.236759	Avg Compression: 0.255479
# Article 1860:	Length: 341176	Compression: 0.253289	Avg Compression: 0.255401
# Article 1870:	Length: 382048	Compression: 0.245391	Avg Compression: 0.255017
# Article 1880:	Length: 441872	Compression: 0.196206	Avg Compression: 0.252523
# Article 1890:	Length: 508896	Compression: 0.230943	Avg Compression: 0.251518

# %%
model.train(256, 192, epochs=40)
# Out:
# Epoch 1/40
# 236/236 [==============================] - 186s 790ms/step - loss: 1.4959 - average_final_batch_ratio: 0.1271
# Epoch 2/40
# 236/236 [==============================] - 185s 784ms/step - loss: 1.4601 - average_final_batch_ratio: 0.1271
# Epoch 3/40
# 236/236 [==============================] - 186s 788ms/step - loss: 1.4204 - average_final_batch_ratio: 0.1271
# Epoch 4/40
# 236/236 [==============================] - 185s 786ms/step - loss: 1.3931 - average_final_batch_ratio: 0.1271
# Epoch 5/40
# 236/236 [==============================] - 186s 789ms/step - loss: 1.3573 - average_final_batch_ratio: 0.1271
# Epoch 6/40
# 236/236 [==============================] - 185s 784ms/step - loss: 1.3439 - average_final_batch_ratio: 0.1271
# Epoch 7/40
# 236/236 [==============================] - 186s 789ms/step - loss: 1.3069 - average_final_batch_ratio: 0.1271
# Epoch 8/40
# 236/236 [==============================] - 186s 787ms/step - loss: 1.2781 - average_final_batch_ratio: 0.1271
# Epoch 9/40
# 236/236 [==============================] - 186s 786ms/step - loss: 1.2678 - average_final_batch_ratio: 0.1271
# Epoch 10/40
# 236/236 [==============================] - 186s 788ms/step - loss: 1.2359 - average_final_batch_ratio: 0.1271
# Epoch 11/40
# 236/236 [==============================] - 185s 786ms/step - loss: 1.2286 - average_final_batch_ratio: 0.1271
# Epoch 12/40
# 236/236 [==============================] - 186s 789ms/step - loss: 1.2097 - average_final_batch_ratio: 0.1271
# Epoch 13/40
# 236/236 [==============================] - 185s 785ms/step - loss: 1.1869 - average_final_batch_ratio: 0.1271
# Epoch 14/40
# 236/236 [==============================] - 186s 789ms/step - loss: 1.1637 - average_final_batch_ratio: 0.1271
# Epoch 15/40
# 236/236 [==============================] - 186s 787ms/step - loss: 1.1564 - average_final_batch_ratio: 0.1271
# Epoch 16/40
# 236/236 [==============================] - 185s 786ms/step - loss: 1.1438 - average_final_batch_ratio: 0.1271
# Epoch 17/40
# 236/236 [==============================] - 186s 788ms/step - loss: 1.1303 - average_final_batch_ratio: 0.1271
# Epoch 18/40
# 236/236 [==============================] - 185s 786ms/step - loss: 1.1088 - average_final_batch_ratio: 0.1271
# Epoch 19/40
# 236/236 [==============================] - 186s 789ms/step - loss: 1.1006 - average_final_batch_ratio: 0.1271
# Epoch 20/40
# 236/236 [==============================] - 185s 785ms/step - loss: 1.0839 - average_final_batch_ratio: 0.1271
# Epoch 21/40
# 236/236 [==============================] - 186s 790ms/step - loss: 1.0742 - average_final_batch_ratio: 0.1271
# Epoch 22/40
# 236/236 [==============================] - 186s 787ms/step - loss: 1.0524 - average_final_batch_ratio: 0.1271
# Epoch 23/40
# 236/236 [==============================] - 186s 787ms/step - loss: 1.0468 - average_final_batch_ratio: 0.1271
# Epoch 24/40
# 236/236 [==============================] - 186s 789ms/step - loss: 1.0357 - average_final_batch_ratio: 0.1271
# Epoch 25/40
# 236/236 [==============================] - 186s 787ms/step - loss: 1.0255 - average_final_batch_ratio: 0.1271
# Epoch 26/40
# 236/236 [==============================] - 186s 790ms/step - loss: 1.0290 - average_final_batch_ratio: 0.1271
# Epoch 27/40
# 236/236 [==============================] - 185s 785ms/step - loss: 1.0138 - average_final_batch_ratio: 0.1271
# Epoch 28/40
# 236/236 [==============================] - 186s 790ms/step - loss: 0.9932 - average_final_batch_ratio: 0.1271
# Epoch 29/40
# 236/236 [==============================] - 186s 788ms/step - loss: 0.9797 - average_final_batch_ratio: 0.1271
# Epoch 30/40
# 236/236 [==============================] - 186s 787ms/step - loss: 0.9723 - average_final_batch_ratio: 0.1271
# Epoch 31/40
# 236/236 [==============================] - 186s 789ms/step - loss: 0.9737 - average_final_batch_ratio: 0.1271
# Epoch 32/40
# 236/236 [==============================] - 186s 787ms/step - loss: 0.9624 - average_final_batch_ratio: 0.1271
# Epoch 33/40
# 236/236 [==============================] - 186s 790ms/step - loss: 0.9523 - average_final_batch_ratio: 0.1271
# Epoch 34/40
# 236/236 [==============================] - 186s 786ms/step - loss: 0.9569 - average_final_batch_ratio: 0.1271
# Epoch 35/40
# 236/236 [==============================] - 187s 791ms/step - loss: 0.9399 - average_final_batch_ratio: 0.1271
# Epoch 36/40
# 236/236 [==============================] - 186s 788ms/step - loss: 0.9253 - average_final_batch_ratio: 0.1271
# Epoch 37/40
# 236/236 [==============================] - 186s 788ms/step - loss: 0.9202 - average_final_batch_ratio: 0.1271
# Epoch 38/40
# 236/236 [==============================] - 186s 789ms/step - loss: 0.9078 - average_final_batch_ratio: 0.1271
# Epoch 39/40
# 236/236 [==============================] - 186s 787ms/step - loss: 0.9023 - average_final_batch_ratio: 0.1271
# Epoch 40/40
# 236/236 [==============================] - 186s 790ms/step - loss: 0.9003 - average_final_batch_ratio: 0.1271

# %%
total_raw = 0
total_compressed = 0

for index, encoded_article in enumerate(articles.articles_generator(1)):
    if index % 10 == 0:
        article = subword_text_encoder.decode(encoded_article)
        raw = len(article) * 8
        if raw == 0:
            continue
        compressed, _ = huffman_archive_size(model, encoded_article)
        total_raw += raw
        total_compressed += compressed

        print('Article %d:\tLength: %d\tCompression: %f\tAvg Compression: %f' % (index, raw, compressed/raw, total_compressed/total_raw))
# Out:
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# Article 0:	Length: 128	Compression: 0.664062	Avg Compression: 0.664062
# Article 10:	Length: 144	Compression: 0.659722	Avg Compression: 0.661765
# Article 20:	Length: 152	Compression: 0.565789	Avg Compression: 0.627358
# Article 30:	Length: 160	Compression: 0.618750	Avg Compression: 0.625000
# Article 40:	Length: 160	Compression: 0.487500	Avg Compression: 0.595430
# Article 50:	Length: 168	Compression: 0.500000	Avg Compression: 0.577851
# Article 60:	Length: 168	Compression: 0.517857	Avg Compression: 0.568519
# Article 70:	Length: 176	Compression: 0.431818	Avg Compression: 0.549363
# Article 80:	Length: 176	Compression: 0.494318	Avg Compression: 0.542598
# Article 90:	Length: 184	Compression: 0.472826	Avg Compression: 0.534653
# Article 100:	Length: 184	Compression: 0.527174	Avg Compression: 0.533889
# Article 110:	Length: 192	Compression: 0.468750	Avg Compression: 0.527610
# Article 120:	Length: 192	Compression: 0.453125	Avg Compression: 0.521062
# Article 130:	Length: 200	Compression: 0.615000	Avg Compression: 0.528943
# Article 140:	Length: 200	Compression: 0.530000	Avg Compression: 0.529025
# Article 150:	Length: 208	Compression: 0.442308	Avg Compression: 0.522564
# Article 160:	Length: 208	Compression: 0.365385	Avg Compression: 0.511667
# Article 170:	Length: 216	Compression: 0.481481	Avg Compression: 0.509639
# Article 180:	Length: 216	Compression: 0.337963	Avg Compression: 0.498834
# Article 190:	Length: 224	Compression: 0.495536	Avg Compression: 0.498632
# Article 200:	Length: 224	Compression: 0.357143	Avg Compression: 0.490464
# Article 210:	Length: 232	Compression: 0.409483	Avg Compression: 0.485895
# Article 220:	Length: 232	Compression: 0.405172	Avg Compression: 0.481584
# Article 230:	Length: 240	Compression: 0.408333	Avg Compression: 0.477749
# Article 240:	Length: 240	Compression: 0.412500	Avg Compression: 0.474502
# Article 250:	Length: 248	Compression: 0.375000	Avg Compression: 0.469637
# Article 260:	Length: 256	Compression: 0.367188	Avg Compression: 0.464715
# Article 270:	Length: 256	Compression: 0.359375	Avg Compression: 0.459885
# Article 280:	Length: 256	Compression: 0.347656	Avg Compression: 0.454966
# Article 290:	Length: 256	Compression: 0.644531	Avg Compression: 0.462927
# Article 300:	Length: 264	Compression: 0.386364	Avg Compression: 0.459748
# Article 310:	Length: 264	Compression: 0.333333	Avg Compression: 0.454710
# Article 320:	Length: 272	Compression: 0.360294	Avg Compression: 0.450986
# Article 330:	Length: 272	Compression: 0.452206	Avg Compression: 0.451032
# Article 340:	Length: 272	Compression: 0.470588	Avg Compression: 0.451747
# Article 350:	Length: 264	Compression: 0.556818	Avg Compression: 0.455348
# Article 360:	Length: 280	Compression: 0.342857	Avg Compression: 0.451403
# Article 370:	Length: 280	Compression: 0.335714	Avg Compression: 0.447483
# Article 380:	Length: 288	Compression: 0.597222	Avg Compression: 0.452526
# Article 390:	Length: 288	Compression: 0.319444	Avg Compression: 0.448190
# Article 400:	Length: 296	Compression: 0.310811	Avg Compression: 0.443739
# Article 410:	Length: 296	Compression: 0.358108	Avg Compression: 0.441052
# Article 420:	Length: 304	Compression: 0.250000	Avg Compression: 0.435086
# Article 430:	Length: 312	Compression: 0.323718	Avg Compression: 0.431628
# Article 440:	Length: 320	Compression: 0.306250	Avg Compression: 0.427758
# Article 450:	Length: 328	Compression: 0.362805	Avg Compression: 0.425767
# Article 460:	Length: 336	Compression: 0.309524	Avg Compression: 0.422226
# Article 470:	Length: 344	Compression: 0.267442	Avg Compression: 0.417546
# Article 480:	Length: 360	Compression: 0.275000	Avg Compression: 0.413173
# Article 490:	Length: 368	Compression: 0.375000	Avg Compression: 0.412013
# Article 500:	Length: 440	Compression: 0.429545	Avg Compression: 0.412628
# Article 510:	Length: 416	Compression: 0.326923	Avg Compression: 0.409877
# Article 520:	Length: 432	Compression: 0.259259	Avg Compression: 0.405018
# Article 530:	Length: 488	Compression: 0.250000	Avg Compression: 0.399568
# Article 540:	Length: 608	Compression: 0.212171	Avg Compression: 0.391703
# Article 550:	Length: 1696	Compression: 0.141509	Avg Compression: 0.365484
# Article 560:	Length: 2608	Compression: 0.134586	Avg Compression: 0.333440
# Article 570:	Length: 3256	Compression: 0.198710	Avg Compression: 0.313543
# Article 580:	Length: 4032	Compression: 0.220982	Avg Compression: 0.299233
# Article 590:	Length: 4616	Compression: 0.201906	Avg Compression: 0.284597
# Article 600:	Length: 5080	Compression: 0.210630	Avg Compression: 0.274094
# Article 610:	Length: 5552	Compression: 0.205512	Avg Compression: 0.264881
# Article 620:	Length: 5928	Compression: 0.256410	Avg Compression: 0.263818
# Article 630:	Length: 6480	Compression: 0.161420	Avg Compression: 0.251470
# Article 640:	Length: 6720	Compression: 0.202381	Avg Compression: 0.246014
# Article 650:	Length: 6960	Compression: 0.154885	Avg Compression: 0.236606
# Article 660:	Length: 7824	Compression: 0.162704	Avg Compression: 0.228921
# Article 670:	Length: 8360	Compression: 0.179545	Avg Compression: 0.223983
# Article 680:	Length: 8824	Compression: 0.180644	Avg Compression: 0.219845
# Article 690:	Length: 9288	Compression: 0.149655	Avg Compression: 0.213436
# Article 700:	Length: 9920	Compression: 0.204940	Avg Compression: 0.212681
# Article 710:	Length: 10552	Compression: 0.174659	Avg Compression: 0.209397
# Article 720:	Length: 11056	Compression: 0.199801	Avg Compression: 0.208601
# Article 730:	Length: 11776	Compression: 0.163893	Avg Compression: 0.204970
# Article 740:	Length: 12424	Compression: 0.195187	Avg Compression: 0.204198
# Article 750:	Length: 12944	Compression: 0.173748	Avg Compression: 0.201885
# Article 760:	Length: 13472	Compression: 0.192696	Avg Compression: 0.201212
# Article 770:	Length: 13888	Compression: 0.157474	Avg Compression: 0.198140
# Article 780:	Length: 14096	Compression: 0.178278	Avg Compression: 0.196818
# Article 790:	Length: 14800	Compression: 0.168446	Avg Compression: 0.194966
# Article 800:	Length: 15200	Compression: 0.194539	Avg Compression: 0.194939
# Article 810:	Length: 16024	Compression: 0.176236	Avg Compression: 0.193777
# Article 820:	Length: 16336	Compression: 0.158852	Avg Compression: 0.191696
# Article 830:	Length: 16904	Compression: 0.197764	Avg Compression: 0.192048
# Article 840:	Length: 17192	Compression: 0.204048	Avg Compression: 0.192717
# Article 850:	Length: 17632	Compression: 0.180637	Avg Compression: 0.192064
# Article 860:	Length: 17736	Compression: 0.149357	Avg Compression: 0.189860
# Article 870:	Length: 18408	Compression: 0.167753	Avg Compression: 0.188736
# Article 880:	Length: 18944	Compression: 0.161159	Avg Compression: 0.187365
# Article 890:	Length: 19320	Compression: 0.169772	Avg Compression: 0.186516
# Article 900:	Length: 20120	Compression: 0.163320	Avg Compression: 0.185406
# Article 910:	Length: 20368	Compression: 0.207237	Avg Compression: 0.186415
# Article 920:	Length: 20560	Compression: 0.162451	Avg Compression: 0.185347
# Article 930:	Length: 21408	Compression: 0.178718	Avg Compression: 0.185053
# Article 940:	Length: 22352	Compression: 0.182847	Avg Compression: 0.184955
# Article 950:	Length: 23192	Compression: 0.172042	Avg Compression: 0.184388
# Article 960:	Length: 23944	Compression: 0.164759	Avg Compression: 0.183537
# Article 970:	Length: 24192	Compression: 0.168444	Avg Compression: 0.182904
# Article 980:	Length: 25624	Compression: 0.154777	Avg Compression: 0.181707
# Article 990:	Length: 26592	Compression: 0.165651	Avg Compression: 0.181028
# Article 1000:	Length: 27224	Compression: 0.172017	Avg Compression: 0.180654
# Article 1010:	Length: 28328	Compression: 0.177633	Avg Compression: 0.180529
# Article 1020:	Length: 28416	Compression: 0.168039	Avg Compression: 0.180031
# Article 1030:	Length: 29016	Compression: 0.171354	Avg Compression: 0.179691
# Article 1040:	Length: 29920	Compression: 0.161430	Avg Compression: 0.178983
# Article 1050:	Length: 30600	Compression: 0.180098	Avg Compression: 0.179026
# Article 1060:	Length: 30488	Compression: 0.177906	Avg Compression: 0.178985
# Article 1070:	Length: 32032	Compression: 0.158748	Avg Compression: 0.178235
# Article 1080:	Length: 33016	Compression: 0.170130	Avg Compression: 0.177937
# Article 1090:	Length: 33472	Compression: 0.160343	Avg Compression: 0.177305
# Article 1100:	Length: 34536	Compression: 0.142228	Avg Compression: 0.176050
# Article 1110:	Length: 35264	Compression: 0.178114	Avg Compression: 0.176123
# Article 1120:	Length: 35736	Compression: 0.167898	Avg Compression: 0.175839
# Article 1130:	Length: 36448	Compression: 0.157759	Avg Compression: 0.175225
# Article 1140:	Length: 37448	Compression: 0.176645	Avg Compression: 0.175273
# Article 1150:	Length: 38424	Compression: 0.164767	Avg Compression: 0.174922
# Article 1160:	Length: 38680	Compression: 0.170476	Avg Compression: 0.174777
# Article 1170:	Length: 40216	Compression: 0.184056	Avg Compression: 0.175081
# Article 1180:	Length: 41480	Compression: 0.205834	Avg Compression: 0.176086
# Article 1190:	Length: 42616	Compression: 0.194528	Avg Compression: 0.176685
# Article 1200:	Length: 43488	Compression: 0.184166	Avg Compression: 0.176925
# Article 1210:	Length: 45080	Compression: 0.195142	Avg Compression: 0.177511
# Article 1220:	Length: 46864	Compression: 0.169042	Avg Compression: 0.177237
# Article 1230:	Length: 48608	Compression: 0.165467	Avg Compression: 0.176855
# Article 1240:	Length: 50264	Compression: 0.172609	Avg Compression: 0.176717
# Article 1250:	Length: 51272	Compression: 0.186905	Avg Compression: 0.177044
# Article 1260:	Length: 52528	Compression: 0.170081	Avg Compression: 0.176822
# Article 1270:	Length: 53688	Compression: 0.178047	Avg Compression: 0.176861
# Article 1280:	Length: 54640	Compression: 0.157247	Avg Compression: 0.176251
# Article 1290:	Length: 55440	Compression: 0.144354	Avg Compression: 0.175276
# Article 1300:	Length: 56320	Compression: 0.166779	Avg Compression: 0.175020
# Article 1310:	Length: 58648	Compression: 0.148513	Avg Compression: 0.174214
# Article 1320:	Length: 60504	Compression: 0.176302	Avg Compression: 0.174278
# Article 1330:	Length: 62376	Compression: 0.121826	Avg Compression: 0.172683
# Article 1340:	Length: 63840	Compression: 0.174875	Avg Compression: 0.172749
# Article 1350:	Length: 65976	Compression: 0.173366	Avg Compression: 0.172768
# Article 1360:	Length: 67128	Compression: 0.162853	Avg Compression: 0.172472
# Article 1370:	Length: 68800	Compression: 0.180494	Avg Compression: 0.172710
# Article 1380:	Length: 70576	Compression: 0.195647	Avg Compression: 0.173388
# Article 1390:	Length: 72432	Compression: 0.145364	Avg Compression: 0.172563
# Article 1400:	Length: 74752	Compression: 0.169360	Avg Compression: 0.172469
# Article 1410:	Length: 75792	Compression: 0.162999	Avg Compression: 0.172194
# Article 1420:	Length: 78368	Compression: 0.186926	Avg Compression: 0.172623
# Article 1430:	Length: 80136	Compression: 0.139712	Avg Compression: 0.171671
# Article 1440:	Length: 83192	Compression: 0.162083	Avg Compression: 0.171391
# Article 1450:	Length: 84736	Compression: 0.134441	Avg Compression: 0.170325
# Article 1460:	Length: 87880	Compression: 0.134627	Avg Compression: 0.169288
# Article 1470:	Length: 88760	Compression: 0.168195	Avg Compression: 0.169257
# Article 1480:	Length: 89704	Compression: 0.160929	Avg Compression: 0.169024
# Article 1490:	Length: 91864	Compression: 0.161282	Avg Compression: 0.168808
# Article 1500:	Length: 94344	Compression: 0.173662	Avg Compression: 0.168943
# Article 1510:	Length: 97160	Compression: 0.160138	Avg Compression: 0.168698
# Article 1520:	Length: 98752	Compression: 0.138620	Avg Compression: 0.167870
# Article 1530:	Length: 101024	Compression: 0.143748	Avg Compression: 0.167209
# Article 1540:	Length: 103016	Compression: 0.140046	Avg Compression: 0.166470
# Article 1550:	Length: 106432	Compression: 0.168493	Avg Compression: 0.166526
# Article 1560:	Length: 107664	Compression: 0.140279	Avg Compression: 0.165820
# Article 1570:	Length: 109952	Compression: 0.160652	Avg Compression: 0.165682
# Article 1580:	Length: 112616	Compression: 0.145699	Avg Compression: 0.165149
# Article 1590:	Length: 115984	Compression: 0.145563	Avg Compression: 0.164626
# Article 1600:	Length: 117944	Compression: 0.161704	Avg Compression: 0.164549
# Article 1610:	Length: 120872	Compression: 0.145791	Avg Compression: 0.164054
# Article 1620:	Length: 123248	Compression: 0.143507	Avg Compression: 0.163516
# Article 1630:	Length: 125152	Compression: 0.147876	Avg Compression: 0.163111
# Article 1640:	Length: 128960	Compression: 0.142191	Avg Compression: 0.162567
# Article 1650:	Length: 132816	Compression: 0.150908	Avg Compression: 0.162262
# Article 1660:	Length: 134584	Compression: 0.150337	Avg Compression: 0.161955
# Article 1670:	Length: 141472	Compression: 0.160166	Avg Compression: 0.161908
# Article 1680:	Length: 146472	Compression: 0.161430	Avg Compression: 0.161896
# Article 1690:	Length: 151840	Compression: 0.184747	Avg Compression: 0.162508
# Article 1700:	Length: 157048	Compression: 0.198684	Avg Compression: 0.163484
# Article 1710:	Length: 161424	Compression: 0.186224	Avg Compression: 0.164097
# Article 1720:	Length: 164208	Compression: 0.201032	Avg Compression: 0.165083
# Article 1730:	Length: 174464	Compression: 0.196270	Avg Compression: 0.165944
# Article 1740:	Length: 189072	Compression: 0.152148	Avg Compression: 0.165543
# Article 1750:	Length: 195080	Compression: 0.164891	Avg Compression: 0.165524
# Article 1760:	Length: 202592	Compression: 0.170377	Avg Compression: 0.165667
# Article 1770:	Length: 213160	Compression: 0.177927	Avg Compression: 0.166034
# Article 1780:	Length: 220440	Compression: 0.190038	Avg Compression: 0.166754
# Article 1790:	Length: 229744	Compression: 0.199574	Avg Compression: 0.167750
# Article 1800:	Length: 246304	Compression: 0.165897	Avg Compression: 0.167691
# Article 1810:	Length: 251304	Compression: 0.193113	Avg Compression: 0.168483
# Article 1820:	Length: 268336	Compression: 0.178247	Avg Compression: 0.168797
# Article 1830:	Length: 283192	Compression: 0.157455	Avg Compression: 0.168425
# Article 1840:	Length: 307368	Compression: 0.185380	Avg Compression: 0.169008
# Article 1850:	Length: 323168	Compression: 0.165626	Avg Compression: 0.168890
# Article 1860:	Length: 341176	Compression: 0.170287	Avg Compression: 0.168940
# Article 1870:	Length: 382048	Compression: 0.169685	Avg Compression: 0.168968
# Article 1880:	Length: 441872	Compression: 0.129343	Avg Compression: 0.167288
# Article 1890:	Length: 508896	Compression: 0.161094	Avg Compression: 0.166999

# %%
model.train(256, 192, epochs=20)
# Out:
# Epoch 1/20
# 236/236 [==============================] - 187s 791ms/step - loss: 0.8993 - average_final_batch_ratio: 0.1271
# Epoch 2/20
# 236/236 [==============================] - 188s 797ms/step - loss: 0.8874 - average_final_batch_ratio: 0.1271
# Epoch 3/20
# 236/236 [==============================] - 189s 799ms/step - loss: 0.8765 - average_final_batch_ratio: 0.1271
# Epoch 4/20
# 236/236 [==============================] - 190s 805ms/step - loss: 0.8667 - average_final_batch_ratio: 0.1271
# Epoch 5/20
# 236/236 [==============================] - 191s 807ms/step - loss: 0.8748 - average_final_batch_ratio: 0.1271
# Epoch 6/20
# 236/236 [==============================] - 188s 798ms/step - loss: 0.8774 - average_final_batch_ratio: 0.1271
# Epoch 7/20
# 236/236 [==============================] - 194s 822ms/step - loss: 0.8648 - average_final_batch_ratio: 0.1271
# Epoch 8/20
# 236/236 [==============================] - 187s 794ms/step - loss: 0.8553 - average_final_batch_ratio: 0.1271
# Epoch 9/20
# 236/236 [==============================] - 188s 798ms/step - loss: 0.8582 - average_final_batch_ratio: 0.1271
# Epoch 10/20
# 236/236 [==============================] - 188s 798ms/step - loss: 0.8534 - average_final_batch_ratio: 0.1271
# Epoch 11/20
# 236/236 [==============================] - 187s 793ms/step - loss: 0.8321 - average_final_batch_ratio: 0.1271
# Epoch 12/20
# 236/236 [==============================] - 188s 797ms/step - loss: 0.8341 - average_final_batch_ratio: 0.1271
# Epoch 13/20
# 236/236 [==============================] - 187s 794ms/step - loss: 0.8420 - average_final_batch_ratio: 0.1271
# Epoch 14/20
# 236/236 [==============================] - 188s 795ms/step - loss: 0.8243 - average_final_batch_ratio: 0.1271
# Epoch 15/20
# 236/236 [==============================] - 187s 791ms/step - loss: 0.8142 - average_final_batch_ratio: 0.1271
# Epoch 16/20
# 236/236 [==============================] - 189s 800ms/step - loss: 0.8091 - average_final_batch_ratio: 0.1271
# Epoch 17/20
# 236/236 [==============================] - 189s 800ms/step - loss: 0.8070 - average_final_batch_ratio: 0.1271
# Epoch 18/20
# 236/236 [==============================] - 187s 793ms/step - loss: 0.7920 - average_final_batch_ratio: 0.1271
# Epoch 19/20
# 236/236 [==============================] - 189s 800ms/step - loss: 0.8045 - average_final_batch_ratio: 0.1271
# Epoch 20/20
# 236/236 [==============================] - 187s 793ms/step - loss: 0.7861 - average_final_batch_ratio: 0.1271

# %%
total_raw = 0
total_compressed = 0

for index, encoded_article in enumerate(articles.articles_generator(1)):
    if index % 10 == 0:
        article = subword_text_encoder.decode(encoded_article)
        raw = len(article) * 8
        if raw == 0:
            continue
        compressed, _ = huffman_archive_size(model, encoded_article)
        total_raw += raw
        total_compressed += compressed

        print('Article %d:\tLength: %d\tCompression: %f\tAvg Compression: %f' % (index, raw, compressed/raw, total_compressed/total_raw))
# Out:
# Article 0:	Length: 128	Compression: 0.671875	Avg Compression: 0.671875
# Article 10:	Length: 144	Compression: 0.659722	Avg Compression: 0.665441
# Article 20:	Length: 152	Compression: 0.552632	Avg Compression: 0.625000
# Article 30:	Length: 160	Compression: 0.637500	Avg Compression: 0.628425
# Article 40:	Length: 160	Compression: 0.481250	Avg Compression: 0.596774
# Article 50:	Length: 168	Compression: 0.565476	Avg Compression: 0.591009
# Article 60:	Length: 168	Compression: 0.529762	Avg Compression: 0.581481
# Article 70:	Length: 176	Compression: 0.448864	Avg Compression: 0.562898
# Article 80:	Length: 176	Compression: 0.477273	Avg Compression: 0.552374
# Article 90:	Length: 184	Compression: 0.483696	Avg Compression: 0.544554
# Article 100:	Length: 184	Compression: 0.554348	Avg Compression: 0.545556
# Article 110:	Length: 192	Compression: 0.494792	Avg Compression: 0.540663
# Article 120:	Length: 192	Compression: 0.479167	Avg Compression: 0.535256
# Article 130:	Length: 200	Compression: 0.610000	Avg Compression: 0.541527
# Article 140:	Length: 200	Compression: 0.565000	Avg Compression: 0.543344
# Article 150:	Length: 208	Compression: 0.471154	Avg Compression: 0.537966
# Article 160:	Length: 208	Compression: 0.394231	Avg Compression: 0.528000
# Article 170:	Length: 216	Compression: 0.458333	Avg Compression: 0.523321
# Article 180:	Length: 216	Compression: 0.370370	Avg Compression: 0.513695
# Article 190:	Length: 224	Compression: 0.500000	Avg Compression: 0.512856
# Article 200:	Length: 224	Compression: 0.334821	Avg Compression: 0.502577
# Article 210:	Length: 232	Compression: 0.422414	Avg Compression: 0.498054
# Article 220:	Length: 232	Compression: 0.400862	Avg Compression: 0.492864
# Article 230:	Length: 240	Compression: 0.420833	Avg Compression: 0.489092
# Article 240:	Length: 240	Compression: 0.462500	Avg Compression: 0.487769
# Article 250:	Length: 248	Compression: 0.362903	Avg Compression: 0.481664
# Article 260:	Length: 256	Compression: 0.359375	Avg Compression: 0.475788
# Article 270:	Length: 256	Compression: 0.367188	Avg Compression: 0.470809
# Article 280:	Length: 256	Compression: 0.335938	Avg Compression: 0.464897
# Article 290:	Length: 256	Compression: 0.605469	Avg Compression: 0.470801
# Article 300:	Length: 264	Compression: 0.378788	Avg Compression: 0.466981
# Article 310:	Length: 264	Compression: 0.356061	Avg Compression: 0.462560
# Article 320:	Length: 272	Compression: 0.397059	Avg Compression: 0.459977
# Article 330:	Length: 272	Compression: 0.422794	Avg Compression: 0.458566
# Article 340:	Length: 272	Compression: 0.433824	Avg Compression: 0.457661
# Article 350:	Length: 264	Compression: 0.651515	Avg Compression: 0.464304
# Article 360:	Length: 280	Compression: 0.396429	Avg Compression: 0.461924
# Article 370:	Length: 280	Compression: 0.375000	Avg Compression: 0.458979
# Article 380:	Length: 288	Compression: 0.569444	Avg Compression: 0.462699
# Article 390:	Length: 288	Compression: 0.329861	Avg Compression: 0.458371
# Article 400:	Length: 296	Compression: 0.358108	Avg Compression: 0.455123
# Article 410:	Length: 296	Compression: 0.412162	Avg Compression: 0.453774
# Article 420:	Length: 304	Compression: 0.263158	Avg Compression: 0.447823
# Article 430:	Length: 312	Compression: 0.330128	Avg Compression: 0.444168
# Article 440:	Length: 320	Compression: 0.303125	Avg Compression: 0.439815
# Article 450:	Length: 328	Compression: 0.341463	Avg Compression: 0.436799
# Article 460:	Length: 336	Compression: 0.303571	Avg Compression: 0.432741
# Article 470:	Length: 344	Compression: 0.258721	Avg Compression: 0.427479
# Article 480:	Length: 360	Compression: 0.300000	Avg Compression: 0.423569
# Article 490:	Length: 368	Compression: 0.380435	Avg Compression: 0.422257
# Article 500:	Length: 440	Compression: 0.427273	Avg Compression: 0.422433
# Article 510:	Length: 416	Compression: 0.319712	Avg Compression: 0.419136
# Article 520:	Length: 432	Compression: 0.231481	Avg Compression: 0.413082
# Article 530:	Length: 488	Compression: 0.235656	Avg Compression: 0.406844
# Article 540:	Length: 608	Compression: 0.202303	Avg Compression: 0.398261
# Article 550:	Length: 1696	Compression: 0.145047	Avg Compression: 0.371725
# Article 560:	Length: 2608	Compression: 0.114647	Avg Compression: 0.336047
# Article 570:	Length: 3256	Compression: 0.176904	Avg Compression: 0.312545
# Article 580:	Length: 4032	Compression: 0.190228	Avg Compression: 0.293635
# Article 590:	Length: 4616	Compression: 0.185009	Avg Compression: 0.277300
# Article 600:	Length: 5080	Compression: 0.199409	Avg Compression: 0.266240
# Article 610:	Length: 5552	Compression: 0.182277	Avg Compression: 0.254960
# Article 620:	Length: 5928	Compression: 0.233300	Avg Compression: 0.252243
# Article 630:	Length: 6480	Compression: 0.146914	Avg Compression: 0.239541
# Article 640:	Length: 6720	Compression: 0.201488	Avg Compression: 0.235312
# Article 650:	Length: 6960	Compression: 0.137356	Avg Compression: 0.225199
# Article 660:	Length: 7824	Compression: 0.147623	Avg Compression: 0.217132
# Article 670:	Length: 8360	Compression: 0.167464	Avg Compression: 0.212165
# Article 680:	Length: 8824	Compression: 0.171578	Avg Compression: 0.208290
# Article 690:	Length: 9288	Compression: 0.143519	Avg Compression: 0.202375
# Article 700:	Length: 9920	Compression: 0.195262	Avg Compression: 0.201743
# Article 710:	Length: 10552	Compression: 0.163287	Avg Compression: 0.198422
# Article 720:	Length: 11056	Compression: 0.183339	Avg Compression: 0.197171
# Article 730:	Length: 11776	Compression: 0.149202	Avg Compression: 0.193275
# Article 740:	Length: 12424	Compression: 0.179733	Avg Compression: 0.192207
# Article 750:	Length: 12944	Compression: 0.150881	Avg Compression: 0.189067
# Article 760:	Length: 13472	Compression: 0.178964	Avg Compression: 0.188327
# Article 770:	Length: 13888	Compression: 0.145161	Avg Compression: 0.185295
# Article 780:	Length: 14096	Compression: 0.169339	Avg Compression: 0.184233
# Article 790:	Length: 14800	Compression: 0.152973	Avg Compression: 0.182192
# Article 800:	Length: 15200	Compression: 0.179342	Avg Compression: 0.182013
# Article 810:	Length: 16024	Compression: 0.153020	Avg Compression: 0.180211
# Article 820:	Length: 16336	Compression: 0.147221	Avg Compression: 0.178246
# Article 830:	Length: 16904	Compression: 0.186820	Avg Compression: 0.178744
# Article 840:	Length: 17192	Compression: 0.188111	Avg Compression: 0.179266
# Article 850:	Length: 17632	Compression: 0.157781	Avg Compression: 0.178104
# Article 860:	Length: 17736	Compression: 0.135487	Avg Compression: 0.175904
# Article 870:	Length: 18408	Compression: 0.153629	Avg Compression: 0.174772
# Article 880:	Length: 18944	Compression: 0.149229	Avg Compression: 0.173502
# Article 890:	Length: 19320	Compression: 0.158644	Avg Compression: 0.172785
# Article 900:	Length: 20120	Compression: 0.145775	Avg Compression: 0.171492
# Article 910:	Length: 20368	Compression: 0.185340	Avg Compression: 0.172132
# Article 920:	Length: 20560	Compression: 0.147665	Avg Compression: 0.171042
# Article 930:	Length: 21408	Compression: 0.161949	Avg Compression: 0.170639
# Article 940:	Length: 22352	Compression: 0.155243	Avg Compression: 0.169957
# Article 950:	Length: 23192	Compression: 0.149534	Avg Compression: 0.169061
# Article 960:	Length: 23944	Compression: 0.148889	Avg Compression: 0.168186
# Article 970:	Length: 24192	Compression: 0.159516	Avg Compression: 0.167823
# Article 980:	Length: 25624	Compression: 0.133547	Avg Compression: 0.166364
# Article 990:	Length: 26592	Compression: 0.145006	Avg Compression: 0.165460
# Article 1000:	Length: 27224	Compression: 0.154900	Avg Compression: 0.165022
# Article 1010:	Length: 28328	Compression: 0.160442	Avg Compression: 0.164833
# Article 1020:	Length: 28416	Compression: 0.141540	Avg Compression: 0.163904
# Article 1030:	Length: 29016	Compression: 0.159119	Avg Compression: 0.163717
# Article 1040:	Length: 29920	Compression: 0.153743	Avg Compression: 0.163330
# Article 1050:	Length: 30600	Compression: 0.158758	Avg Compression: 0.163155
# Article 1060:	Length: 30488	Compression: 0.152585	Avg Compression: 0.162768
# Article 1070:	Length: 32032	Compression: 0.148570	Avg Compression: 0.162242
# Article 1080:	Length: 33016	Compression: 0.148110	Avg Compression: 0.161723
# Article 1090:	Length: 33472	Compression: 0.137070	Avg Compression: 0.160837
# Article 1100:	Length: 34536	Compression: 0.129170	Avg Compression: 0.159704
# Article 1110:	Length: 35264	Compression: 0.163566	Avg Compression: 0.159840
# Article 1120:	Length: 35736	Compression: 0.145987	Avg Compression: 0.159363
# Article 1130:	Length: 36448	Compression: 0.136167	Avg Compression: 0.158575
# Article 1140:	Length: 37448	Compression: 0.152345	Avg Compression: 0.158365
# Article 1150:	Length: 38424	Compression: 0.144155	Avg Compression: 0.157890
# Article 1160:	Length: 38680	Compression: 0.141262	Avg Compression: 0.157348
# Article 1170:	Length: 40216	Compression: 0.157972	Avg Compression: 0.157369
# Article 1180:	Length: 41480	Compression: 0.170636	Avg Compression: 0.157802
# Article 1190:	Length: 42616	Compression: 0.166323	Avg Compression: 0.158079
# Article 1200:	Length: 43488	Compression: 0.162367	Avg Compression: 0.158216
# Article 1210:	Length: 45080	Compression: 0.171118	Avg Compression: 0.158632
# Article 1220:	Length: 46864	Compression: 0.149454	Avg Compression: 0.158334
# Article 1230:	Length: 48608	Compression: 0.138640	Avg Compression: 0.157695
# Article 1240:	Length: 50264	Compression: 0.150406	Avg Compression: 0.157458
# Article 1250:	Length: 51272	Compression: 0.163598	Avg Compression: 0.157655
# Article 1260:	Length: 52528	Compression: 0.147845	Avg Compression: 0.157342
# Article 1270:	Length: 53688	Compression: 0.153498	Avg Compression: 0.157221
# Article 1280:	Length: 54640	Compression: 0.133583	Avg Compression: 0.156487
# Article 1290:	Length: 55440	Compression: 0.123557	Avg Compression: 0.155480
# Article 1300:	Length: 56320	Compression: 0.146555	Avg Compression: 0.155212
# Article 1310:	Length: 58648	Compression: 0.120959	Avg Compression: 0.154170
# Article 1320:	Length: 60504	Compression: 0.159940	Avg Compression: 0.154346
# Article 1330:	Length: 62376	Compression: 0.105890	Avg Compression: 0.152873
# Article 1340:	Length: 63840	Compression: 0.155279	Avg Compression: 0.152945
# Article 1350:	Length: 65976	Compression: 0.148448	Avg Compression: 0.152809
# Article 1360:	Length: 67128	Compression: 0.134415	Avg Compression: 0.152260
# Article 1370:	Length: 68800	Compression: 0.160422	Avg Compression: 0.152502
# Article 1380:	Length: 70576	Compression: 0.172877	Avg Compression: 0.153104
# Article 1390:	Length: 72432	Compression: 0.127789	Avg Compression: 0.152359
# Article 1400:	Length: 74752	Compression: 0.151608	Avg Compression: 0.152337
# Article 1410:	Length: 75792	Compression: 0.148736	Avg Compression: 0.152233
# Article 1420:	Length: 78368	Compression: 0.173795	Avg Compression: 0.152861
# Article 1430:	Length: 80136	Compression: 0.126822	Avg Compression: 0.152107
# Article 1440:	Length: 83192	Compression: 0.147598	Avg Compression: 0.151976
# Article 1450:	Length: 84736	Compression: 0.123171	Avg Compression: 0.151145
# Article 1460:	Length: 87880	Compression: 0.126570	Avg Compression: 0.150431
# Article 1470:	Length: 88760	Compression: 0.152186	Avg Compression: 0.150481
# Article 1480:	Length: 89704	Compression: 0.144185	Avg Compression: 0.150305
# Article 1490:	Length: 91864	Compression: 0.146260	Avg Compression: 0.150192
# Article 1500:	Length: 94344	Compression: 0.156078	Avg Compression: 0.150356
# Article 1510:	Length: 97160	Compression: 0.143341	Avg Compression: 0.150161
# Article 1520:	Length: 98752	Compression: 0.124666	Avg Compression: 0.149458
# Article 1530:	Length: 101024	Compression: 0.126435	Avg Compression: 0.148828
# Article 1540:	Length: 103016	Compression: 0.125747	Avg Compression: 0.148200
# Article 1550:	Length: 106432	Compression: 0.149325	Avg Compression: 0.148231
# Article 1560:	Length: 107664	Compression: 0.124276	Avg Compression: 0.147587
# Article 1570:	Length: 109952	Compression: 0.145591	Avg Compression: 0.147534
# Article 1580:	Length: 112616	Compression: 0.130452	Avg Compression: 0.147078
# Article 1590:	Length: 115984	Compression: 0.135131	Avg Compression: 0.146759
# Article 1600:	Length: 117944	Compression: 0.145340	Avg Compression: 0.146722
# Article 1610:	Length: 120872	Compression: 0.128698	Avg Compression: 0.146246
# Article 1620:	Length: 123248	Compression: 0.129227	Avg Compression: 0.145800
# Article 1630:	Length: 125152	Compression: 0.139215	Avg Compression: 0.145630
# Article 1640:	Length: 128960	Compression: 0.128334	Avg Compression: 0.145180
# Article 1650:	Length: 132816	Compression: 0.138206	Avg Compression: 0.144998
# Article 1660:	Length: 134584	Compression: 0.133627	Avg Compression: 0.144705
# Article 1670:	Length: 141472	Compression: 0.149570	Avg Compression: 0.144833
# Article 1680:	Length: 146472	Compression: 0.148820	Avg Compression: 0.144939
# Article 1690:	Length: 151840	Compression: 0.168803	Avg Compression: 0.145579
# Article 1700:	Length: 157048	Compression: 0.177188	Avg Compression: 0.146431
# Article 1710:	Length: 161424	Compression: 0.167658	Avg Compression: 0.147004
# Article 1720:	Length: 164208	Compression: 0.184912	Avg Compression: 0.148016
# Article 1730:	Length: 174464	Compression: 0.176839	Avg Compression: 0.148812
# Article 1740:	Length: 189072	Compression: 0.142723	Avg Compression: 0.148635
# Article 1750:	Length: 195080	Compression: 0.150062	Avg Compression: 0.148676
# Article 1760:	Length: 202592	Compression: 0.153708	Avg Compression: 0.148824
# Article 1770:	Length: 213160	Compression: 0.160363	Avg Compression: 0.149169
# Article 1780:	Length: 220440	Compression: 0.177282	Avg Compression: 0.150013
# Article 1790:	Length: 229744	Compression: 0.179378	Avg Compression: 0.150904
# Article 1800:	Length: 246304	Compression: 0.154155	Avg Compression: 0.151006
# Article 1810:	Length: 251304	Compression: 0.176611	Avg Compression: 0.151804
# Article 1820:	Length: 268336	Compression: 0.163996	Avg Compression: 0.152196
# Article 1830:	Length: 283192	Compression: 0.146074	Avg Compression: 0.151995
# Article 1840:	Length: 307368	Compression: 0.172184	Avg Compression: 0.152690
# Article 1850:	Length: 323168	Compression: 0.153874	Avg Compression: 0.152731
# Article 1860:	Length: 341176	Compression: 0.157101	Avg Compression: 0.152886
# Article 1870:	Length: 382048	Compression: 0.158258	Avg Compression: 0.153092
# Article 1880:	Length: 441872	Compression: 0.123952	Avg Compression: 0.151856
# Article 1890:	Length: 508896	Compression: 0.151414	Avg Compression: 0.151836

# %%
model.train(256, 192, epochs=30)
# Out:
# Epoch 1/30
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# 236/236 [==============================] - 188s 797ms/step - loss: 0.7832 - average_final_batch_ratio: 0.1271
# Epoch 2/30
# 236/236 [==============================] - 187s 792ms/step - loss: 0.7828 - average_final_batch_ratio: 0.1271
# Epoch 3/30
# 236/236 [==============================] - 187s 791ms/step - loss: 0.7852 - average_final_batch_ratio: 0.1271
# Epoch 4/30
# 236/236 [==============================] - 188s 795ms/step - loss: 0.7759 - average_final_batch_ratio: 0.1271
# Epoch 5/30
# 236/236 [==============================] - 187s 790ms/step - loss: 0.7704 - average_final_batch_ratio: 0.1271
# Epoch 6/30
# 236/236 [==============================] - 188s 795ms/step - loss: 0.7628 - average_final_batch_ratio: 0.1271
# Epoch 7/30
# 236/236 [==============================] - 186s 790ms/step - loss: 0.7616 - average_final_batch_ratio: 0.1271
# Epoch 8/30
# 236/236 [==============================] - 189s 799ms/step - loss: 0.7606 - average_final_batch_ratio: 0.1271
# Epoch 9/30
# 236/236 [==============================] - 187s 793ms/step - loss: 0.7626 - average_final_batch_ratio: 0.1271
# Epoch 10/30
# 236/236 [==============================] - 187s 792ms/step - loss: 0.7739 - average_final_batch_ratio: 0.1271
# Epoch 11/30
# 236/236 [==============================] - 188s 795ms/step - loss: 0.7554 - average_final_batch_ratio: 0.1271
# Epoch 12/30
# 236/236 [==============================] - 187s 791ms/step - loss: 0.7426 - average_final_batch_ratio: 0.1271
# Epoch 13/30
# 236/236 [==============================] - 188s 796ms/step - loss: 0.7441 - average_final_batch_ratio: 0.1271
# Epoch 14/30
# 236/236 [==============================] - 188s 798ms/step - loss: 0.7411 - average_final_batch_ratio: 0.1271
# Epoch 15/30
# 236/236 [==============================] - 190s 805ms/step - loss: 0.7430 - average_final_batch_ratio: 0.1271
# Epoch 16/30
# 236/236 [==============================] - 187s 791ms/step - loss: 0.7551 - average_final_batch_ratio: 0.1271
# Epoch 17/30
# 236/236 [==============================] - 187s 792ms/step - loss: 0.7339 - average_final_batch_ratio: 0.1271
# Epoch 18/30
# 236/236 [==============================] - 189s 803ms/step - loss: 0.7353 - average_final_batch_ratio: 0.1271
# Epoch 19/30
# 236/236 [==============================] - 190s 805ms/step - loss: 0.7424 - average_final_batch_ratio: 0.1271
# Epoch 20/30
# 236/236 [==============================] - 188s 796ms/step - loss: 0.7378 - average_final_batch_ratio: 0.1271
# Epoch 21/30
# 236/236 [==============================] - 188s 796ms/step - loss: 0.7247 - average_final_batch_ratio: 0.1271
# Epoch 22/30
# 236/236 [==============================] - 189s 802ms/step - loss: 0.7239 - average_final_batch_ratio: 0.1271
# Epoch 23/30
# 236/236 [==============================] - 188s 799ms/step - loss: 0.7110 - average_final_batch_ratio: 0.1271
# Epoch 24/30
# 236/236 [==============================] - 187s 794ms/step - loss: 0.7230 - average_final_batch_ratio: 0.1271
# Epoch 25/30
# 236/236 [==============================] - 188s 797ms/step - loss: 0.7327 - average_final_batch_ratio: 0.1271
# Epoch 26/30
# 236/236 [==============================] - 187s 793ms/step - loss: 0.7235 - average_final_batch_ratio: 0.1271
# Epoch 27/30
# 236/236 [==============================] - 188s 796ms/step - loss: 0.7261 - average_final_batch_ratio: 0.1271
# Epoch 28/30
# 236/236 [==============================] - 187s 793ms/step - loss: 0.7026 - average_final_batch_ratio: 0.1271
# Epoch 29/30
# 236/236 [==============================] - 188s 795ms/step - loss: 0.7037 - average_final_batch_ratio: 0.1271
# Epoch 30/30
# 236/236 [==============================] - 188s 797ms/step - loss: 0.7006 - average_final_batch_ratio: 0.1271

# %%
total_raw = 0
total_compressed = 0

for index, encoded_article in enumerate(articles.articles_generator(1)):
    if index % 10 == 0:
        article = subword_text_encoder.decode(encoded_article)
        raw = len(article) * 8
        if raw == 0:
            continue
        compressed, _ = huffman_archive_size(model, encoded_article)
        total_raw += raw
        total_compressed += compressed

        print('Article %d:\tLength: %d\tCompression: %f\tAvg Compression: %f' % (index, raw, compressed/raw, total_compressed/total_raw))
# Out:
# Article 0:	Length: 128	Compression: 0.742188	Avg Compression: 0.742188
# Article 10:	Length: 144	Compression: 0.743056	Avg Compression: 0.742647
# Article 20:	Length: 152	Compression: 0.625000	Avg Compression: 0.700472
# Article 30:	Length: 160	Compression: 0.662500	Avg Compression: 0.690068
# Article 40:	Length: 160	Compression: 0.525000	Avg Compression: 0.654570
# Article 50:	Length: 168	Compression: 0.541667	Avg Compression: 0.633772
# Article 60:	Length: 168	Compression: 0.529762	Avg Compression: 0.617593
# Article 70:	Length: 176	Compression: 0.494318	Avg Compression: 0.600318
# Article 80:	Length: 176	Compression: 0.511364	Avg Compression: 0.589385
# Article 90:	Length: 184	Compression: 0.559783	Avg Compression: 0.586015
# Article 100:	Length: 184	Compression: 0.635870	Avg Compression: 0.591111
# Article 110:	Length: 192	Compression: 0.484375	Avg Compression: 0.580823
# Article 120:	Length: 192	Compression: 0.526042	Avg Compression: 0.576007
# Article 130:	Length: 200	Compression: 0.650000	Avg Compression: 0.582215
# Article 140:	Length: 200	Compression: 0.600000	Avg Compression: 0.583591
# Article 150:	Length: 208	Compression: 0.466346	Avg Compression: 0.574857
# Article 160:	Length: 208	Compression: 0.475962	Avg Compression: 0.568000
# Article 170:	Length: 216	Compression: 0.518519	Avg Compression: 0.564677
# Article 180:	Length: 216	Compression: 0.388889	Avg Compression: 0.553613
# Article 190:	Length: 224	Compression: 0.571429	Avg Compression: 0.554705
# Article 200:	Length: 224	Compression: 0.348214	Avg Compression: 0.542784
# Article 210:	Length: 232	Compression: 0.456897	Avg Compression: 0.537938
# Article 220:	Length: 232	Compression: 0.431034	Avg Compression: 0.532228
# Article 230:	Length: 240	Compression: 0.425000	Avg Compression: 0.526614
# Article 240:	Length: 240	Compression: 0.466667	Avg Compression: 0.523632
# Article 250:	Length: 248	Compression: 0.403226	Avg Compression: 0.517744
# Article 260:	Length: 256	Compression: 0.343750	Avg Compression: 0.509384
# Article 270:	Length: 256	Compression: 0.460938	Avg Compression: 0.507163
# Article 280:	Length: 256	Compression: 0.347656	Avg Compression: 0.500171
# Article 290:	Length: 256	Compression: 0.632812	Avg Compression: 0.505741
# Article 300:	Length: 264	Compression: 0.405303	Avg Compression: 0.501572
# Article 310:	Length: 264	Compression: 0.393939	Avg Compression: 0.497283
# Article 320:	Length: 272	Compression: 0.404412	Avg Compression: 0.493619
# Article 330:	Length: 272	Compression: 0.444853	Avg Compression: 0.491769
# Article 340:	Length: 272	Compression: 0.507353	Avg Compression: 0.492339
# Article 350:	Length: 264	Compression: 0.715909	Avg Compression: 0.500000
# Article 360:	Length: 280	Compression: 0.389286	Avg Compression: 0.496117
# Article 370:	Length: 280	Compression: 0.382143	Avg Compression: 0.492256
# Article 380:	Length: 288	Compression: 0.607639	Avg Compression: 0.496141
# Article 390:	Length: 288	Compression: 0.423611	Avg Compression: 0.493778
# Article 400:	Length: 296	Compression: 0.364865	Avg Compression: 0.489602
# Article 410:	Length: 296	Compression: 0.442568	Avg Compression: 0.488126
# Article 420:	Length: 304	Compression: 0.292763	Avg Compression: 0.482025
# Article 430:	Length: 312	Compression: 0.375000	Avg Compression: 0.478702
# Article 440:	Length: 320	Compression: 0.387500	Avg Compression: 0.475887
# Article 450:	Length: 328	Compression: 0.402439	Avg Compression: 0.473635
# Article 460:	Length: 336	Compression: 0.333333	Avg Compression: 0.469362
# Article 470:	Length: 344	Compression: 0.267442	Avg Compression: 0.463256
# Article 480:	Length: 360	Compression: 0.372222	Avg Compression: 0.460464
# Article 490:	Length: 368	Compression: 0.415761	Avg Compression: 0.459104
# Article 500:	Length: 440	Compression: 0.488636	Avg Compression: 0.460140
# Article 510:	Length: 416	Compression: 0.377404	Avg Compression: 0.457485
# Article 520:	Length: 432	Compression: 0.268519	Avg Compression: 0.451389
# Article 530:	Length: 488	Compression: 0.254098	Avg Compression: 0.444452
# Article 540:	Length: 608	Compression: 0.251645	Avg Compression: 0.436361
# Article 550:	Length: 1696	Compression: 0.135024	Avg Compression: 0.404783
# Article 560:	Length: 2608	Compression: 0.127684	Avg Compression: 0.366326
# Article 570:	Length: 3256	Compression: 0.183968	Avg Compression: 0.339396
# Article 580:	Length: 4032	Compression: 0.197173	Avg Compression: 0.317408
# Article 590:	Length: 4616	Compression: 0.190641	Avg Compression: 0.298345
# Article 600:	Length: 5080	Compression: 0.204134	Avg Compression: 0.284968
# Article 610:	Length: 5552	Compression: 0.190202	Avg Compression: 0.272237
# Article 620:	Length: 5928	Compression: 0.225202	Avg Compression: 0.266337
# Article 630:	Length: 6480	Compression: 0.152469	Avg Compression: 0.252605
# Article 640:	Length: 6720	Compression: 0.194494	Avg Compression: 0.246146
# Article 650:	Length: 6960	Compression: 0.139943	Avg Compression: 0.235182
# Article 660:	Length: 7824	Compression: 0.141360	Avg Compression: 0.225425
# Article 670:	Length: 8360	Compression: 0.165789	Avg Compression: 0.219462
# Article 680:	Length: 8824	Compression: 0.152199	Avg Compression: 0.213040
# Article 690:	Length: 9288	Compression: 0.140935	Avg Compression: 0.206455
# Article 700:	Length: 9920	Compression: 0.182560	Avg Compression: 0.204332
# Article 710:	Length: 10552	Compression: 0.157411	Avg Compression: 0.200280
# Article 720:	Length: 11056	Compression: 0.182254	Avg Compression: 0.198784
# Article 730:	Length: 11776	Compression: 0.140795	Avg Compression: 0.194075
# Article 740:	Length: 12424	Compression: 0.174501	Avg Compression: 0.192530
# Article 750:	Length: 12944	Compression: 0.149645	Avg Compression: 0.189272
# Article 760:	Length: 13472	Compression: 0.166122	Avg Compression: 0.187576
# Article 770:	Length: 13888	Compression: 0.132921	Avg Compression: 0.183738
# Article 780:	Length: 14096	Compression: 0.160329	Avg Compression: 0.182180
# Article 790:	Length: 14800	Compression: 0.155946	Avg Compression: 0.180467
# Article 800:	Length: 15200	Compression: 0.165789	Avg Compression: 0.179544
# Article 810:	Length: 16024	Compression: 0.150462	Avg Compression: 0.177737
# Article 820:	Length: 16336	Compression: 0.142875	Avg Compression: 0.175660
# Article 830:	Length: 16904	Compression: 0.172977	Avg Compression: 0.175504
# Article 840:	Length: 17192	Compression: 0.179444	Avg Compression: 0.175724
# Article 850:	Length: 17632	Compression: 0.154038	Avg Compression: 0.174551
# Article 860:	Length: 17736	Compression: 0.138024	Avg Compression: 0.172666
# Article 870:	Length: 18408	Compression: 0.145915	Avg Compression: 0.171306
# Article 880:	Length: 18944	Compression: 0.146379	Avg Compression: 0.170066
# Article 890:	Length: 19320	Compression: 0.159161	Avg Compression: 0.169540
# Article 900:	Length: 20120	Compression: 0.149503	Avg Compression: 0.168581
# Article 910:	Length: 20368	Compression: 0.175717	Avg Compression: 0.168911
# Article 920:	Length: 20560	Compression: 0.143239	Avg Compression: 0.167767
# Article 930:	Length: 21408	Compression: 0.161248	Avg Compression: 0.167478
# Article 940:	Length: 22352	Compression: 0.148622	Avg Compression: 0.166644
# Article 950:	Length: 23192	Compression: 0.151733	Avg Compression: 0.165989
# Article 960:	Length: 23944	Compression: 0.146383	Avg Compression: 0.165139
# Article 970:	Length: 24192	Compression: 0.153398	Avg Compression: 0.164646
# Article 980:	Length: 25624	Compression: 0.134171	Avg Compression: 0.163349
# Article 990:	Length: 26592	Compression: 0.141509	Avg Compression: 0.162426
# Article 1000:	Length: 27224	Compression: 0.148729	Avg Compression: 0.161857
# Article 1010:	Length: 28328	Compression: 0.154406	Avg Compression: 0.161549
# Article 1020:	Length: 28416	Compression: 0.145833	Avg Compression: 0.160922
# Article 1030:	Length: 29016	Compression: 0.152192	Avg Compression: 0.160580
# Article 1040:	Length: 29920	Compression: 0.155983	Avg Compression: 0.160402
# Article 1050:	Length: 30600	Compression: 0.153268	Avg Compression: 0.160130
# Article 1060:	Length: 30488	Compression: 0.155012	Avg Compression: 0.159943
# Article 1070:	Length: 32032	Compression: 0.143357	Avg Compression: 0.159328
# Article 1080:	Length: 33016	Compression: 0.145111	Avg Compression: 0.158805
# Article 1090:	Length: 33472	Compression: 0.137906	Avg Compression: 0.158054
# Article 1100:	Length: 34536	Compression: 0.131283	Avg Compression: 0.157097
# Article 1110:	Length: 35264	Compression: 0.162659	Avg Compression: 0.157293
# Article 1120:	Length: 35736	Compression: 0.146659	Avg Compression: 0.156926
# Article 1130:	Length: 36448	Compression: 0.133752	Avg Compression: 0.156139
# Article 1140:	Length: 37448	Compression: 0.148072	Avg Compression: 0.155867
# Article 1150:	Length: 38424	Compression: 0.142177	Avg Compression: 0.155409
# Article 1160:	Length: 38680	Compression: 0.145217	Avg Compression: 0.155077
# Article 1170:	Length: 40216	Compression: 0.156679	Avg Compression: 0.155130
# Article 1180:	Length: 41480	Compression: 0.173770	Avg Compression: 0.155739
# Article 1190:	Length: 42616	Compression: 0.164516	Avg Compression: 0.156024
# Article 1200:	Length: 43488	Compression: 0.164988	Avg Compression: 0.156312
# Article 1210:	Length: 45080	Compression: 0.165905	Avg Compression: 0.156620
# Article 1220:	Length: 46864	Compression: 0.145570	Avg Compression: 0.156263
# Article 1230:	Length: 48608	Compression: 0.137529	Avg Compression: 0.155654
# Article 1240:	Length: 50264	Compression: 0.144059	Avg Compression: 0.155277
# Article 1250:	Length: 51272	Compression: 0.159210	Avg Compression: 0.155403
# Article 1260:	Length: 52528	Compression: 0.147502	Avg Compression: 0.155152
# Article 1270:	Length: 53688	Compression: 0.152529	Avg Compression: 0.155069
# Article 1280:	Length: 54640	Compression: 0.134846	Avg Compression: 0.154441
# Article 1290:	Length: 55440	Compression: 0.129509	Avg Compression: 0.153679
# Article 1300:	Length: 56320	Compression: 0.145810	Avg Compression: 0.153442
# Article 1310:	Length: 58648	Compression: 0.120737	Avg Compression: 0.152447
# Article 1320:	Length: 60504	Compression: 0.153791	Avg Compression: 0.152488
# Article 1330:	Length: 62376	Compression: 0.108455	Avg Compression: 0.151150
# Article 1340:	Length: 63840	Compression: 0.158913	Avg Compression: 0.151384
# Article 1350:	Length: 65976	Compression: 0.146493	Avg Compression: 0.151236
# Article 1360:	Length: 67128	Compression: 0.136173	Avg Compression: 0.150786
# Article 1370:	Length: 68800	Compression: 0.154462	Avg Compression: 0.150895
# Article 1380:	Length: 70576	Compression: 0.170072	Avg Compression: 0.151462
# Article 1390:	Length: 72432	Compression: 0.124779	Avg Compression: 0.150677
# Article 1400:	Length: 74752	Compression: 0.140210	Avg Compression: 0.150368
# Article 1410:	Length: 75792	Compression: 0.136729	Avg Compression: 0.149972
# Article 1420:	Length: 78368	Compression: 0.157960	Avg Compression: 0.150205
# Article 1430:	Length: 80136	Compression: 0.117201	Avg Compression: 0.149250
# Article 1440:	Length: 83192	Compression: 0.136900	Avg Compression: 0.148890
# Article 1450:	Length: 84736	Compression: 0.117376	Avg Compression: 0.147981
# Article 1460:	Length: 87880	Compression: 0.115658	Avg Compression: 0.147042
# Article 1470:	Length: 88760	Compression: 0.139241	Avg Compression: 0.146820
# Article 1480:	Length: 89704	Compression: 0.130540	Avg Compression: 0.146364
# Article 1490:	Length: 91864	Compression: 0.135287	Avg Compression: 0.146055
# Article 1500:	Length: 94344	Compression: 0.141037	Avg Compression: 0.145915
# Article 1510:	Length: 97160	Compression: 0.130455	Avg Compression: 0.145485
# Article 1520:	Length: 98752	Compression: 0.120423	Avg Compression: 0.144794
# Article 1530:	Length: 101024	Compression: 0.123456	Avg Compression: 0.144210
# Article 1540:	Length: 103016	Compression: 0.124583	Avg Compression: 0.143676
# Article 1550:	Length: 106432	Compression: 0.131821	Avg Compression: 0.143352
# Article 1560:	Length: 107664	Compression: 0.121666	Avg Compression: 0.142769
# Article 1570:	Length: 109952	Compression: 0.132822	Avg Compression: 0.142503
# Article 1580:	Length: 112616	Compression: 0.124512	Avg Compression: 0.142024
# Article 1590:	Length: 115984	Compression: 0.118939	Avg Compression: 0.141408
# Article 1600:	Length: 117944	Compression: 0.127382	Avg Compression: 0.141037
# Article 1610:	Length: 120872	Compression: 0.124446	Avg Compression: 0.140599
# Article 1620:	Length: 123248	Compression: 0.118533	Avg Compression: 0.140021
# Article 1630:	Length: 125152	Compression: 0.124393	Avg Compression: 0.139616
# Article 1640:	Length: 128960	Compression: 0.114663	Avg Compression: 0.138967
# Article 1650:	Length: 132816	Compression: 0.130353	Avg Compression: 0.138742
# Article 1660:	Length: 134584	Compression: 0.130201	Avg Compression: 0.138522
# Article 1670:	Length: 141472	Compression: 0.136260	Avg Compression: 0.138463
# Article 1680:	Length: 146472	Compression: 0.133582	Avg Compression: 0.138333
# Article 1690:	Length: 151840	Compression: 0.157106	Avg Compression: 0.138836
# Article 1700:	Length: 157048	Compression: 0.165128	Avg Compression: 0.139545
# Article 1710:	Length: 161424	Compression: 0.155943	Avg Compression: 0.139988
# Article 1720:	Length: 164208	Compression: 0.172537	Avg Compression: 0.140857
# Article 1730:	Length: 174464	Compression: 0.165788	Avg Compression: 0.141545
# Article 1740:	Length: 189072	Compression: 0.130982	Avg Compression: 0.141238
# Article 1750:	Length: 195080	Compression: 0.143444	Avg Compression: 0.141302
# Article 1760:	Length: 202592	Compression: 0.145139	Avg Compression: 0.141415
# Article 1770:	Length: 213160	Compression: 0.150305	Avg Compression: 0.141681
# Article 1780:	Length: 220440	Compression: 0.169248	Avg Compression: 0.142508
# Article 1790:	Length: 229744	Compression: 0.169780	Avg Compression: 0.143336
# Article 1800:	Length: 246304	Compression: 0.144687	Avg Compression: 0.143378
# Article 1810:	Length: 251304	Compression: 0.169054	Avg Compression: 0.144178
# Article 1820:	Length: 268336	Compression: 0.153990	Avg Compression: 0.144493
# Article 1830:	Length: 283192	Compression: 0.139612	Avg Compression: 0.144333
# Article 1840:	Length: 307368	Compression: 0.165059	Avg Compression: 0.145046
# Article 1850:	Length: 323168	Compression: 0.146311	Avg Compression: 0.145091
# Article 1860:	Length: 341176	Compression: 0.147147	Avg Compression: 0.145164
# Article 1870:	Length: 382048	Compression: 0.151690	Avg Compression: 0.145414
# Article 1880:	Length: 441872	Compression: 0.123597	Avg Compression: 0.144488
# Article 1890:	Length: 508896	Compression: 0.146665	Avg Compression: 0.144590

# %%
def loss(labels, logits):
    return tf.keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)

def average_final_batch_ratio(true_labels, predictions):
    return 0 ** tf.math.abs(true_labels[-1, -1])

class ModelStateResetter(tf.keras.callbacks.Callback):
    def __init__(self):
        pass

    def on_epoch_begin(self, epoch, logs=None):
        self.last_final_batch_count = 0
        
    def on_batch_end(self, batch, logs={}):
        average_final_batch_ratio = logs.get('average_final_batch_ratio', 0)
        final_batch_count = int(round(average_final_batch_ratio * (batch + 1)))
        is_final = final_batch_count - self.last_final_batch_count
        self.last_final_batch_count = final_batch_count
        
        if is_final:
            self.model.reset_states()

class Model:
    def __init__(self, articles, checkpoint_dir, vocab_size, embedding_dim, rnn_units):
        self._articles = articles
        self._batch_size = None
        self._batched_item_length = None
        self._training_model = None
        self._predicting_model = None
        self._vocab_size = vocab_size
        self._embedding_dim = embedding_dim
        self._rnn_units = rnn_units

        self._checkpoint_dir = checkpoint_dir
        self._checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt_{epoch}") # Name of the checkpoint files

    def training_model(self, batch_size, batched_item_length):
        if self._training_model == None or batch_size != self._batch_size or batched_item_length != self._batched_item_length:
            self._batch_size = batch_size
            self._batched_item_length = batched_item_length
            self._training_model = tf.keras.Sequential([
                tf.keras.layers.Masking(mask_value=0, batch_input_shape=[batch_size, batched_item_length]),
                tf.keras.layers.Embedding(self._vocab_size, self._embedding_dim),
                tf.keras.layers.LSTM(self._rnn_units, return_sequences=True, stateful=True, recurrent_initializer='glorot_uniform'),
                tf.keras.layers.LSTM(self._rnn_units, return_sequences=True, stateful=True, recurrent_initializer='glorot_uniform'),
                tf.keras.layers.Dense(self._vocab_size),
            ])

            if os.path.isdir(self._checkpoint_dir):
                self._training_model.load_weights(tf.train.latest_checkpoint(self._checkpoint_dir))

            self._training_model.compile(optimizer='adam', loss=loss, metrics=[average_final_batch_ratio])
            self._predicting_model = None
        
        return self._training_model

    @property
    def callbacks(self):
        checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=self._checkpoint_prefix, save_weights_only=True)
        model_state_resetter_callback = ModelStateResetter()
        
        return [checkpoint_callback, model_state_resetter_callback]
    
    def train(self, batch_size, batched_item_length, epochs=1):
        dataset = self._articles.dataset(batch_size, batched_item_length)

        model = self.training_model(batch_size, batched_item_length)

        model.fit(dataset, epochs=epochs, callbacks=self.callbacks)
    
    @property
    def predicting_model(self):
        if self._predicting_model == None:
            self._predicting_model = tf.keras.Sequential([
                tf.keras.layers.Masking(mask_value=0, batch_input_shape=[1, 1]),
                tf.keras.layers.Embedding(self._vocab_size, self._embedding_dim),
                tf.keras.layers.LSTM(self._rnn_units, stateful=True, return_sequences=True),
                tf.keras.layers.LSTM(self._rnn_units, stateful=True, return_sequences=True),
                tf.keras.layers.Dense(self._vocab_size),
            ])
            
            self._predicting_model.load_weights(tf.train.latest_checkpoint(self._checkpoint_dir))
            self._training_model = None
        
        return self._predicting_model
    
    def predict(self, input_eval):
        return self.predicting_model(input_eval)

# %%
model = Model(articles, './training_checkpoints-11',
              vocab_size = subword_text_encoder.vocab_size,
              embedding_dim=512,
              rnn_units=1024)

# %%
model.training_model(256, 192).summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# masking_11 (Masking)         (256, 192)                0
# _________________________________________________________________
# embedding_11 (Embedding)     (256, 192, 512)           2072576
# _________________________________________________________________
# lstm_6 (LSTM)                (256, 192, 1024)          6295552
# _________________________________________________________________
# lstm_7 (LSTM)                (256, 192, 1024)          8392704
# _________________________________________________________________
# dense_11 (Dense)             (256, 192, 4048)          4149200
# =================================================================
# Total params: 20,910,032
# Trainable params: 20,910,032
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.train(256, 192, epochs=50)
# Out:
# Epoch 1/50
# 236/236 [==============================] - 220s 934ms/step - loss: 3.7519 - average_final_batch_ratio: 0.1271
# Epoch 2/50
# 236/236 [==============================] - 221s 938ms/step - loss: 3.4630 - average_final_batch_ratio: 0.1271
# Epoch 3/50
# 236/236 [==============================] - 222s 939ms/step - loss: 3.4879 - average_final_batch_ratio: 0.1271
# Epoch 4/50
# 236/236 [==============================] - 223s 946ms/step - loss: 3.2230 - average_final_batch_ratio: 0.1271
# Epoch 5/50
# 236/236 [==============================] - 222s 943ms/step - loss: 2.5779 - average_final_batch_ratio: 0.1271
# Epoch 6/50
# 236/236 [==============================] - 223s 946ms/step - loss: 2.3626 - average_final_batch_ratio: 0.1271
# Epoch 7/50
# 236/236 [==============================] - 223s 944ms/step - loss: 2.2173 - average_final_batch_ratio: 0.1271
# Epoch 8/50
# 236/236 [==============================] - 222s 942ms/step - loss: 2.0923 - average_final_batch_ratio: 0.1271
# Epoch 9/50
# 236/236 [==============================] - 223s 945ms/step - loss: 1.9926 - average_final_batch_ratio: 0.1271
# Epoch 10/50
# 236/236 [==============================] - 223s 946ms/step - loss: 1.8957 - average_final_batch_ratio: 0.1271
# Epoch 11/50
# 236/236 [==============================] - 224s 950ms/step - loss: 1.8298 - average_final_batch_ratio: 0.1271
# Epoch 12/50
# 236/236 [==============================] - 224s 950ms/step - loss: 1.7594 - average_final_batch_ratio: 0.1271
# Epoch 13/50
# 236/236 [==============================] - 224s 950ms/step - loss: 1.7025 - average_final_batch_ratio: 0.1271
# Epoch 14/50
# 236/236 [==============================] - 224s 948ms/step - loss: 1.6521 - average_final_batch_ratio: 0.1271
# Epoch 15/50
# 236/236 [==============================] - 223s 946ms/step - loss: 1.6081 - average_final_batch_ratio: 0.1271
# Epoch 16/50
# 236/236 [==============================] - 223s 947ms/step - loss: 1.5721 - average_final_batch_ratio: 0.1271
# Epoch 17/50
# 236/236 [==============================] - 224s 948ms/step - loss: 1.5329 - average_final_batch_ratio: 0.1271
# Epoch 18/50
# 236/236 [==============================] - 224s 951ms/step - loss: 1.5016 - average_final_batch_ratio: 0.1271
# Epoch 19/50
# 236/236 [==============================] - 223s 946ms/step - loss: 1.4740 - average_final_batch_ratio: 0.1271
# Epoch 20/50
# 236/236 [==============================] - 224s 949ms/step - loss: 1.4451 - average_final_batch_ratio: 0.1271
# Epoch 21/50
# 236/236 [==============================] - 224s 948ms/step - loss: 1.4235 - average_final_batch_ratio: 0.1271
# Epoch 22/50
# 236/236 [==============================] - 223s 945ms/step - loss: 1.3972 - average_final_batch_ratio: 0.1271
# Epoch 23/50
# 236/236 [==============================] - 224s 948ms/step - loss: 1.3766 - average_final_batch_ratio: 0.1271
# Epoch 24/50
# 236/236 [==============================] - 224s 948ms/step - loss: 1.3541 - average_final_batch_ratio: 0.1271
# Epoch 25/50
# 236/236 [==============================] - 224s 951ms/step - loss: 1.3319 - average_final_batch_ratio: 0.1271
# Epoch 26/50
# 236/236 [==============================] - 223s 946ms/step - loss: 1.3104 - average_final_batch_ratio: 0.1271
# Epoch 27/50
# 236/236 [==============================] - 224s 949ms/step - loss: 1.2956 - average_final_batch_ratio: 0.1271
# Epoch 28/50
# 236/236 [==============================] - 223s 946ms/step - loss: 1.2762 - average_final_batch_ratio: 0.1271
# Epoch 29/50
# 236/236 [==============================] - 223s 944ms/step - loss: 1.2661 - average_final_batch_ratio: 0.1271
# Epoch 30/50
# 236/236 [==============================] - 223s 946ms/step - loss: 1.2416 - average_final_batch_ratio: 0.1271
# Epoch 31/50
# 236/236 [==============================] - 224s 948ms/step - loss: 1.2338 - average_final_batch_ratio: 0.1271
# Epoch 32/50
# 236/236 [==============================] - 224s 951ms/step - loss: 1.2074 - average_final_batch_ratio: 0.1271
# Epoch 33/50
# 236/236 [==============================] - 223s 946ms/step - loss: 1.2082 - average_final_batch_ratio: 0.1271
# Epoch 34/50
# 236/236 [==============================] - 224s 947ms/step - loss: 1.1810 - average_final_batch_ratio: 0.1271
# Epoch 35/50
# 236/236 [==============================] - 223s 946ms/step - loss: 1.1669 - average_final_batch_ratio: 0.1271
# Epoch 36/50
# 236/236 [==============================] - 223s 943ms/step - loss: 1.1587 - average_final_batch_ratio: 0.1271
# Epoch 37/50
# 236/236 [==============================] - 223s 946ms/step - loss: 1.1435 - average_final_batch_ratio: 0.1271
# Epoch 38/50
# 236/236 [==============================] - 223s 947ms/step - loss: 1.1315 - average_final_batch_ratio: 0.1271
# Epoch 39/50
# 236/236 [==============================] - 225s 952ms/step - loss: 1.1144 - average_final_batch_ratio: 0.1271
# Epoch 40/50
# 236/236 [==============================] - 223s 947ms/step - loss: 1.1062 - average_final_batch_ratio: 0.1271
# Epoch 41/50
# 236/236 [==============================] - 224s 949ms/step - loss: 1.0932 - average_final_batch_ratio: 0.1271
# Epoch 42/50
# 236/236 [==============================] - 223s 946ms/step - loss: 1.0836 - average_final_batch_ratio: 0.1271
# Epoch 43/50
# 236/236 [==============================] - 223s 944ms/step - loss: 1.0772 - average_final_batch_ratio: 0.1271
# Epoch 44/50
# 236/236 [==============================] - 223s 946ms/step - loss: 1.0671 - average_final_batch_ratio: 0.1271
# Epoch 45/50
# 236/236 [==============================] - 223s 946ms/step - loss: 1.0494 - average_final_batch_ratio: 0.1271
# Epoch 46/50
# 236/236 [==============================] - 224s 950ms/step - loss: 1.0451 - average_final_batch_ratio: 0.1271
# Epoch 47/50
# 236/236 [==============================] - 223s 946ms/step - loss: 1.0324 - average_final_batch_ratio: 0.1271
# Epoch 48/50
# 236/236 [==============================] - 224s 949ms/step - loss: 1.0220 - average_final_batch_ratio: 0.1271
# Epoch 49/50
# 236/236 [==============================] - 224s 948ms/step - loss: 1.0106 - average_final_batch_ratio: 0.1271
# Epoch 50/50
# 236/236 [==============================] - 224s 950ms/step - loss: 0.9986 - average_final_batch_ratio: 0.1271

# %%
total_raw = 0
total_compressed = 0

for index, encoded_article in enumerate(articles.articles_generator(1)):
    if index % 10 == 0:
        article = subword_text_encoder.decode(encoded_article)
        raw = len(article) * 8
        if raw == 0:
            continue
        compressed, _ = huffman_archive_size(model, encoded_article)
        total_raw += raw
        total_compressed += compressed

        print('Article %d:\tLength: %d\tCompression: %f\tAvg Compression: %f' % (index, raw, compressed/raw, total_compressed/total_raw))
# Out:
# Article 0:	Length: 128	Compression: 0.757812	Avg Compression: 0.757812
# Article 10:	Length: 144	Compression: 0.722222	Avg Compression: 0.738971
# Article 20:	Length: 152	Compression: 0.750000	Avg Compression: 0.742925
# Article 30:	Length: 160	Compression: 0.700000	Avg Compression: 0.731164
# Article 40:	Length: 160	Compression: 0.750000	Avg Compression: 0.735215
# Article 50:	Length: 168	Compression: 0.779762	Avg Compression: 0.743421
# Article 60:	Length: 168	Compression: 0.654762	Avg Compression: 0.729630
# Article 70:	Length: 176	Compression: 0.636364	Avg Compression: 0.716561
# Article 80:	Length: 176	Compression: 0.653409	Avg Compression: 0.708799
# Article 90:	Length: 184	Compression: 0.695652	Avg Compression: 0.707302
# Article 100:	Length: 184	Compression: 0.576087	Avg Compression: 0.693889
# Article 110:	Length: 192	Compression: 0.567708	Avg Compression: 0.681727
# Article 120:	Length: 192	Compression: 0.583333	Avg Compression: 0.673077
# Article 130:	Length: 200	Compression: 0.705000	Avg Compression: 0.675755
# Article 140:	Length: 200	Compression: 0.725000	Avg Compression: 0.679567
# Article 150:	Length: 208	Compression: 0.620192	Avg Compression: 0.675143
# Article 160:	Length: 208	Compression: 0.509615	Avg Compression: 0.663667
# Article 170:	Length: 216	Compression: 0.712963	Avg Compression: 0.666978
# Article 180:	Length: 216	Compression: 0.490741	Avg Compression: 0.655886
# Article 190:	Length: 224	Compression: 0.638393	Avg Compression: 0.654814
# Article 200:	Length: 224	Compression: 0.571429	Avg Compression: 0.650000
# Article 210:	Length: 232	Compression: 0.530172	Avg Compression: 0.643239
# Article 220:	Length: 232	Compression: 0.594828	Avg Compression: 0.640654
# Article 230:	Length: 240	Compression: 0.625000	Avg Compression: 0.639834
# Article 240:	Length: 240	Compression: 0.583333	Avg Compression: 0.637023
# Article 250:	Length: 248	Compression: 0.399194	Avg Compression: 0.625394
# Article 260:	Length: 256	Compression: 0.597656	Avg Compression: 0.624062
# Article 270:	Length: 256	Compression: 0.429688	Avg Compression: 0.615150
# Article 280:	Length: 256	Compression: 0.433594	Avg Compression: 0.607192
# Article 290:	Length: 256	Compression: 0.750000	Avg Compression: 0.613189
# Article 300:	Length: 264	Compression: 0.462121	Avg Compression: 0.606918
# Article 310:	Length: 264	Compression: 0.484848	Avg Compression: 0.602053
# Article 320:	Length: 272	Compression: 0.488971	Avg Compression: 0.597593
# Article 330:	Length: 272	Compression: 0.702206	Avg Compression: 0.601562
# Article 340:	Length: 272	Compression: 0.555147	Avg Compression: 0.599866
# Article 350:	Length: 264	Compression: 0.992424	Avg Compression: 0.613318
# Article 360:	Length: 280	Compression: 0.446429	Avg Compression: 0.607465
# Article 370:	Length: 280	Compression: 0.489286	Avg Compression: 0.603461
# Article 380:	Length: 288	Compression: 0.680556	Avg Compression: 0.606057
# Article 390:	Length: 288	Compression: 0.458333	Avg Compression: 0.601244
# Article 400:	Length: 296	Compression: 0.442568	Avg Compression: 0.596103
# Article 410:	Length: 296	Compression: 0.594595	Avg Compression: 0.596056
# Article 420:	Length: 304	Compression: 0.368421	Avg Compression: 0.588948
# Article 430:	Length: 312	Compression: 0.400641	Avg Compression: 0.583101
# Article 440:	Length: 320	Compression: 0.425000	Avg Compression: 0.578221
# Article 450:	Length: 328	Compression: 0.420732	Avg Compression: 0.573392
# Article 460:	Length: 336	Compression: 0.502976	Avg Compression: 0.571247
# Article 470:	Length: 344	Compression: 0.433140	Avg Compression: 0.567071
# Article 480:	Length: 360	Compression: 0.363889	Avg Compression: 0.560838
# Article 490:	Length: 368	Compression: 0.464674	Avg Compression: 0.557915
# Article 500:	Length: 440	Compression: 0.404545	Avg Compression: 0.552535
# Article 510:	Length: 416	Compression: 0.360577	Avg Compression: 0.546373
# Article 520:	Length: 432	Compression: 0.398148	Avg Compression: 0.541592
# Article 530:	Length: 488	Compression: 0.278689	Avg Compression: 0.532349
# Article 540:	Length: 608	Compression: 0.274671	Avg Compression: 0.521535
# Article 550:	Length: 1696	Compression: 0.147995	Avg Compression: 0.482390
# Article 560:	Length: 2608	Compression: 0.143788	Avg Compression: 0.435398
# Article 570:	Length: 3256	Compression: 0.195025	Avg Compression: 0.399900
# Article 580:	Length: 4032	Compression: 0.237351	Avg Compression: 0.374770
# Article 590:	Length: 4616	Compression: 0.206239	Avg Compression: 0.349427
# Article 600:	Length: 5080	Compression: 0.217520	Avg Compression: 0.330697
# Article 610:	Length: 5552	Compression: 0.210735	Avg Compression: 0.314581
# Article 620:	Length: 5928	Compression: 0.246289	Avg Compression: 0.306014
# Article 630:	Length: 6480	Compression: 0.167747	Avg Compression: 0.289340
# Article 640:	Length: 6720	Compression: 0.213393	Avg Compression: 0.280899
# Article 650:	Length: 6960	Compression: 0.169684	Avg Compression: 0.269417
# Article 660:	Length: 7824	Compression: 0.157720	Avg Compression: 0.257802
# Article 670:	Length: 8360	Compression: 0.192943	Avg Compression: 0.251316
# Article 680:	Length: 8824	Compression: 0.194810	Avg Compression: 0.245921
# Article 690:	Length: 9288	Compression: 0.152239	Avg Compression: 0.237366
# Article 700:	Length: 9920	Compression: 0.203125	Avg Compression: 0.234323
# Article 710:	Length: 10552	Compression: 0.180345	Avg Compression: 0.229662
# Article 720:	Length: 11056	Compression: 0.200072	Avg Compression: 0.227207
# Article 730:	Length: 11776	Compression: 0.168393	Avg Compression: 0.222431
# Article 740:	Length: 12424	Compression: 0.197601	Avg Compression: 0.220471
# Article 750:	Length: 12944	Compression: 0.179079	Avg Compression: 0.217327
# Article 760:	Length: 13472	Compression: 0.206280	Avg Compression: 0.216517
# Article 770:	Length: 13888	Compression: 0.167915	Avg Compression: 0.213104
# Article 780:	Length: 14096	Compression: 0.186932	Avg Compression: 0.211362
# Article 790:	Length: 14800	Compression: 0.177230	Avg Compression: 0.209133
# Article 800:	Length: 15200	Compression: 0.188224	Avg Compression: 0.207819
# Article 810:	Length: 16024	Compression: 0.188093	Avg Compression: 0.206593
# Article 820:	Length: 16336	Compression: 0.167422	Avg Compression: 0.204260
# Article 830:	Length: 16904	Compression: 0.197882	Avg Compression: 0.203889
# Article 840:	Length: 17192	Compression: 0.206724	Avg Compression: 0.204047
# Article 850:	Length: 17632	Compression: 0.173491	Avg Compression: 0.202394
# Article 860:	Length: 17736	Compression: 0.176083	Avg Compression: 0.201036
# Article 870:	Length: 18408	Compression: 0.173077	Avg Compression: 0.199615
# Article 880:	Length: 18944	Compression: 0.170186	Avg Compression: 0.198152
# Article 890:	Length: 19320	Compression: 0.174689	Avg Compression: 0.197020
# Article 900:	Length: 20120	Compression: 0.181461	Avg Compression: 0.196275
# Article 910:	Length: 20368	Compression: 0.206500	Avg Compression: 0.196747
# Article 920:	Length: 20560	Compression: 0.182101	Avg Compression: 0.196095
# Article 930:	Length: 21408	Compression: 0.191470	Avg Compression: 0.195890
# Article 940:	Length: 22352	Compression: 0.191974	Avg Compression: 0.195716
# Article 950:	Length: 23192	Compression: 0.178855	Avg Compression: 0.194976
# Article 960:	Length: 23944	Compression: 0.178458	Avg Compression: 0.194260
# Article 970:	Length: 24192	Compression: 0.183077	Avg Compression: 0.193791
# Article 980:	Length: 25624	Compression: 0.166953	Avg Compression: 0.192649
# Article 990:	Length: 26592	Compression: 0.172947	Avg Compression: 0.191815
# Article 1000:	Length: 27224	Compression: 0.180282	Avg Compression: 0.191337
# Article 1010:	Length: 28328	Compression: 0.185294	Avg Compression: 0.191086
# Article 1020:	Length: 28416	Compression: 0.188591	Avg Compression: 0.190987
# Article 1030:	Length: 29016	Compression: 0.188965	Avg Compression: 0.190908
# Article 1040:	Length: 29920	Compression: 0.182453	Avg Compression: 0.190580
# Article 1050:	Length: 30600	Compression: 0.182157	Avg Compression: 0.190259
# Article 1060:	Length: 30488	Compression: 0.184269	Avg Compression: 0.190039
# Article 1070:	Length: 32032	Compression: 0.163836	Avg Compression: 0.189069
# Article 1080:	Length: 33016	Compression: 0.188878	Avg Compression: 0.189062
# Article 1090:	Length: 33472	Compression: 0.168947	Avg Compression: 0.188339
# Article 1100:	Length: 34536	Compression: 0.159515	Avg Compression: 0.187308
# Article 1110:	Length: 35264	Compression: 0.182140	Avg Compression: 0.187126
# Article 1120:	Length: 35736	Compression: 0.171536	Avg Compression: 0.186588
# Article 1130:	Length: 36448	Compression: 0.166978	Avg Compression: 0.185922
# Article 1140:	Length: 37448	Compression: 0.176939	Avg Compression: 0.185620
# Article 1150:	Length: 38424	Compression: 0.184650	Avg Compression: 0.185587
# Article 1160:	Length: 38680	Compression: 0.182756	Avg Compression: 0.185495
# Article 1170:	Length: 40216	Compression: 0.198777	Avg Compression: 0.185930
# Article 1180:	Length: 41480	Compression: 0.204870	Avg Compression: 0.186549
# Article 1190:	Length: 42616	Compression: 0.197086	Avg Compression: 0.186891
# Article 1200:	Length: 43488	Compression: 0.200124	Avg Compression: 0.187316
# Article 1210:	Length: 45080	Compression: 0.201065	Avg Compression: 0.187758
# Article 1220:	Length: 46864	Compression: 0.184214	Avg Compression: 0.187643
# Article 1230:	Length: 48608	Compression: 0.163697	Avg Compression: 0.186865
# Article 1240:	Length: 50264	Compression: 0.183193	Avg Compression: 0.186746
# Article 1250:	Length: 51272	Compression: 0.192191	Avg Compression: 0.186921
# Article 1260:	Length: 52528	Compression: 0.201435	Avg Compression: 0.187383
# Article 1270:	Length: 53688	Compression: 0.189055	Avg Compression: 0.187435
# Article 1280:	Length: 54640	Compression: 0.179228	Avg Compression: 0.187180
# Article 1290:	Length: 55440	Compression: 0.154437	Avg Compression: 0.186180
# Article 1300:	Length: 56320	Compression: 0.175533	Avg Compression: 0.185859
# Article 1310:	Length: 58648	Compression: 0.159886	Avg Compression: 0.185069
# Article 1320:	Length: 60504	Compression: 0.197987	Avg Compression: 0.185462
# Article 1330:	Length: 62376	Compression: 0.128431	Avg Compression: 0.183728
# Article 1340:	Length: 63840	Compression: 0.186482	Avg Compression: 0.183811
# Article 1350:	Length: 65976	Compression: 0.180702	Avg Compression: 0.183717
# Article 1360:	Length: 67128	Compression: 0.175486	Avg Compression: 0.183472
# Article 1370:	Length: 68800	Compression: 0.191148	Avg Compression: 0.183700
# Article 1380:	Length: 70576	Compression: 0.222696	Avg Compression: 0.184852
# Article 1390:	Length: 72432	Compression: 0.169041	Avg Compression: 0.184387
# Article 1400:	Length: 74752	Compression: 0.181868	Avg Compression: 0.184312
# Article 1410:	Length: 75792	Compression: 0.175876	Avg Compression: 0.184067
# Article 1420:	Length: 78368	Compression: 0.190346	Avg Compression: 0.184250
# Article 1430:	Length: 80136	Compression: 0.148747	Avg Compression: 0.183223
# Article 1440:	Length: 83192	Compression: 0.178154	Avg Compression: 0.183075
# Article 1450:	Length: 84736	Compression: 0.138737	Avg Compression: 0.181796
# Article 1460:	Length: 87880	Compression: 0.146461	Avg Compression: 0.180770
# Article 1470:	Length: 88760	Compression: 0.183968	Avg Compression: 0.180861
# Article 1480:	Length: 89704	Compression: 0.185945	Avg Compression: 0.181003
# Article 1490:	Length: 91864	Compression: 0.175368	Avg Compression: 0.180846
# Article 1500:	Length: 94344	Compression: 0.180446	Avg Compression: 0.180835
# Article 1510:	Length: 97160	Compression: 0.166488	Avg Compression: 0.180435
# Article 1520:	Length: 98752	Compression: 0.142276	Avg Compression: 0.179385
# Article 1530:	Length: 101024	Compression: 0.144609	Avg Compression: 0.178432
# Article 1540:	Length: 103016	Compression: 0.142852	Avg Compression: 0.177465
# Article 1550:	Length: 106432	Compression: 0.173754	Avg Compression: 0.177363
# Article 1560:	Length: 107664	Compression: 0.147422	Avg Compression: 0.176558
# Article 1570:	Length: 109952	Compression: 0.172293	Avg Compression: 0.176444
# Article 1580:	Length: 112616	Compression: 0.146223	Avg Compression: 0.175639
# Article 1590:	Length: 115984	Compression: 0.147598	Avg Compression: 0.174890
# Article 1600:	Length: 117944	Compression: 0.168970	Avg Compression: 0.174734
# Article 1610:	Length: 120872	Compression: 0.149059	Avg Compression: 0.174056
# Article 1620:	Length: 123248	Compression: 0.155743	Avg Compression: 0.173576
# Article 1630:	Length: 125152	Compression: 0.157265	Avg Compression: 0.173154
# Article 1640:	Length: 128960	Compression: 0.150822	Avg Compression: 0.172573
# Article 1650:	Length: 132816	Compression: 0.166170	Avg Compression: 0.172406
# Article 1660:	Length: 134584	Compression: 0.151303	Avg Compression: 0.171863
# Article 1670:	Length: 141472	Compression: 0.170182	Avg Compression: 0.171818
# Article 1680:	Length: 146472	Compression: 0.180533	Avg Compression: 0.172050
# Article 1690:	Length: 151840	Compression: 0.191471	Avg Compression: 0.172570
# Article 1700:	Length: 157048	Compression: 0.206427	Avg Compression: 0.173483
# Article 1710:	Length: 161424	Compression: 0.192369	Avg Compression: 0.173993
# Article 1720:	Length: 164208	Compression: 0.212688	Avg Compression: 0.175026
# Article 1730:	Length: 174464	Compression: 0.207114	Avg Compression: 0.175911
# Article 1740:	Length: 189072	Compression: 0.162536	Avg Compression: 0.175523
# Article 1750:	Length: 195080	Compression: 0.182033	Avg Compression: 0.175712
# Article 1760:	Length: 202592	Compression: 0.182065	Avg Compression: 0.175899
# Article 1770:	Length: 213160	Compression: 0.191776	Avg Compression: 0.176374
# Article 1780:	Length: 220440	Compression: 0.195609	Avg Compression: 0.176951
# Article 1790:	Length: 229744	Compression: 0.209168	Avg Compression: 0.177929
# Article 1800:	Length: 246304	Compression: 0.176440	Avg Compression: 0.177882
# Article 1810:	Length: 251304	Compression: 0.201569	Avg Compression: 0.178619
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# Article 1820:	Length: 268336	Compression: 0.192464	Avg Compression: 0.179065
# Article 1830:	Length: 283192	Compression: 0.169539	Avg Compression: 0.178752
# Article 1840:	Length: 307368	Compression: 0.190742	Avg Compression: 0.179165
# Article 1850:	Length: 323168	Compression: 0.175983	Avg Compression: 0.179053
# Article 1860:	Length: 341176	Compression: 0.186004	Avg Compression: 0.179301
# Article 1870:	Length: 382048	Compression: 0.175237	Avg Compression: 0.179145
# Article 1880:	Length: 441872	Compression: 0.141865	Avg Compression: 0.177564
# Article 1890:	Length: 508896	Compression: 0.176702	Avg Compression: 0.177524

# %%
model.train(256, 192, epochs=50)
# Out:
# Epoch 1/50
# 236/236 [==============================] - 225s 952ms/step - loss: 0.9989 - average_final_batch_ratio: 0.1271
# Epoch 2/50
# 236/236 [==============================] - 223s 946ms/step - loss: 0.9808 - average_final_batch_ratio: 0.1271
# Epoch 3/50
# 236/236 [==============================] - 223s 945ms/step - loss: 0.9802 - average_final_batch_ratio: 0.1271
# Epoch 4/50
# 236/236 [==============================] - 224s 949ms/step - loss: 0.9685 - average_final_batch_ratio: 0.1271
# Epoch 5/50
# 236/236 [==============================] - 222s 943ms/step - loss: 0.9441 - average_final_batch_ratio: 0.1271
# Epoch 6/50
# 236/236 [==============================] - 224s 947ms/step - loss: 0.9494 - average_final_batch_ratio: 0.1271
# Epoch 7/50
# 236/236 [==============================] - 224s 947ms/step - loss: 0.9417 - average_final_batch_ratio: 0.1271
# Epoch 8/50
# 236/236 [==============================] - 224s 949ms/step - loss: 0.9262 - average_final_batch_ratio: 0.1271
# Epoch 9/50
# 236/236 [==============================] - 223s 947ms/step - loss: 0.9180 - average_final_batch_ratio: 0.1271
# Epoch 10/50
# 236/236 [==============================] - 223s 945ms/step - loss: 0.9047 - average_final_batch_ratio: 0.1271
# Epoch 11/50
# 236/236 [==============================] - 224s 949ms/step - loss: 0.8991 - average_final_batch_ratio: 0.1271
# Epoch 12/50
# 236/236 [==============================] - 222s 942ms/step - loss: 0.9006 - average_final_batch_ratio: 0.1271
# Epoch 13/50
# 236/236 [==============================] - 223s 947ms/step - loss: 0.8977 - average_final_batch_ratio: 0.1271
# Epoch 14/50
# 236/236 [==============================] - 223s 947ms/step - loss: 0.8981 - average_final_batch_ratio: 0.1271
# Epoch 15/50
# 236/236 [==============================] - 224s 949ms/step - loss: 0.8756 - average_final_batch_ratio: 0.1271
# Epoch 16/50
# 236/236 [==============================] - 223s 947ms/step - loss: 0.8766 - average_final_batch_ratio: 0.1271
# Epoch 17/50
# 236/236 [==============================] - 223s 945ms/step - loss: 0.8864 - average_final_batch_ratio: 0.1271
# Epoch 18/50
# 236/236 [==============================] - 224s 950ms/step - loss: 0.8720 - average_final_batch_ratio: 0.1271
# Epoch 19/50
# 236/236 [==============================] - 223s 943ms/step - loss: 0.8405 - average_final_batch_ratio: 0.1271
# Epoch 20/50
# 236/236 [==============================] - 224s 951ms/step - loss: 0.8320 - average_final_batch_ratio: 0.1271
# Epoch 21/50
# 236/236 [==============================] - 225s 951ms/step - loss: 0.8401 - average_final_batch_ratio: 0.1271
# Epoch 22/50
# 236/236 [==============================] - 224s 949ms/step - loss: 0.8353 - average_final_batch_ratio: 0.1271
# Epoch 23/50
# 236/236 [==============================] - 225s 953ms/step - loss: 0.8207 - average_final_batch_ratio: 0.1271
# Epoch 24/50
# 236/236 [==============================] - 223s 947ms/step - loss: 0.8101 - average_final_batch_ratio: 0.1271
# Epoch 25/50
# 236/236 [==============================] - 224s 951ms/step - loss: 0.8077 - average_final_batch_ratio: 0.1271
# Epoch 26/50
# 236/236 [==============================] - 223s 947ms/step - loss: 0.7932 - average_final_batch_ratio: 0.1271
# Epoch 27/50
# 236/236 [==============================] - 224s 947ms/step - loss: 0.7894 - average_final_batch_ratio: 0.1271
# Epoch 28/50
# 236/236 [==============================] - 224s 950ms/step - loss: 0.7982 - average_final_batch_ratio: 0.1271
# Epoch 29/50
# 236/236 [==============================] - 226s 959ms/step - loss: 0.7819 - average_final_batch_ratio: 0.1271
# Epoch 30/50
# 236/236 [==============================] - 223s 947ms/step - loss: 0.7849 - average_final_batch_ratio: 0.1271
# Epoch 31/50
# 236/236 [==============================] - 223s 945ms/step - loss: 0.7826 - average_final_batch_ratio: 0.1271
# Epoch 32/50
# 236/236 [==============================] - 225s 955ms/step - loss: 0.7925 - average_final_batch_ratio: 0.1271
# Epoch 33/50
# 236/236 [==============================] - 223s 945ms/step - loss: 0.7705 - average_final_batch_ratio: 0.1271
# Epoch 34/50
# 236/236 [==============================] - 224s 949ms/step - loss: 0.7465 - average_final_batch_ratio: 0.1271
# Epoch 35/50
# 236/236 [==============================] - 223s 946ms/step - loss: 0.7614 - average_final_batch_ratio: 0.1271
# Epoch 36/50
# 236/236 [==============================] - 224s 948ms/step - loss: 0.7599 - average_final_batch_ratio: 0.1271
# Epoch 37/50
# 236/236 [==============================] - 223s 946ms/step - loss: 0.7565 - average_final_batch_ratio: 0.1271
# Epoch 38/50
# 236/236 [==============================] - 223s 945ms/step - loss: 0.7408 - average_final_batch_ratio: 0.1271
# Epoch 39/50
# 236/236 [==============================] - 224s 948ms/step - loss: 0.7409 - average_final_batch_ratio: 0.1271
# Epoch 40/50
# 236/236 [==============================] - 222s 942ms/step - loss: 0.7288 - average_final_batch_ratio: 0.1271
# Epoch 41/50
# 236/236 [==============================] - 223s 946ms/step - loss: 0.7185 - average_final_batch_ratio: 0.1271
# Epoch 42/50
# 236/236 [==============================] - 223s 946ms/step - loss: 0.7241 - average_final_batch_ratio: 0.1271
# Epoch 43/50
# 236/236 [==============================] - 224s 948ms/step - loss: 0.7203 - average_final_batch_ratio: 0.1271
# Epoch 44/50
# 236/236 [==============================] - 223s 946ms/step - loss: 0.7203 - average_final_batch_ratio: 0.1271
# Epoch 45/50
# 236/236 [==============================] - 223s 945ms/step - loss: 0.7043 - average_final_batch_ratio: 0.1271
# Epoch 46/50
# 236/236 [==============================] - 224s 950ms/step - loss: 0.7165 - average_final_batch_ratio: 0.1271
# Epoch 47/50
# 236/236 [==============================] - 222s 942ms/step - loss: 0.7195 - average_final_batch_ratio: 0.1271
# Epoch 48/50
# 236/236 [==============================] - 224s 947ms/step - loss: 0.6955 - average_final_batch_ratio: 0.1271
# Epoch 49/50
# 236/236 [==============================] - 224s 947ms/step - loss: 0.6867 - average_final_batch_ratio: 0.1271
# Epoch 50/50
# 236/236 [==============================] - 224s 950ms/step - loss: 0.6966 - average_final_batch_ratio: 0.1271

# %%
total_raw = 0
total_compressed = 0

for index, encoded_article in enumerate(articles.articles_generator(1)):
    if index % 10 == 0:
        article = subword_text_encoder.decode(encoded_article)
        raw = len(article) * 8
        if raw == 0:
            continue
        compressed, _ = huffman_archive_size(model, encoded_article)
        total_raw += raw
        total_compressed += compressed

        print('Article %d:\tLength: %d\tCompression: %f\tAvg Compression: %f' % (index, raw, compressed/raw, total_compressed/total_raw))
# Out:
# Article 0:	Length: 128	Compression: 1.250000	Avg Compression: 1.250000
# Article 10:	Length: 144	Compression: 1.166667	Avg Compression: 1.205882
# Article 20:	Length: 152	Compression: 1.111842	Avg Compression: 1.172170
# Article 30:	Length: 160	Compression: 1.193750	Avg Compression: 1.178082
# Article 40:	Length: 160	Compression: 1.187500	Avg Compression: 1.180108
# Article 50:	Length: 168	Compression: 1.130952	Avg Compression: 1.171053
# Article 60:	Length: 168	Compression: 0.988095	Avg Compression: 1.142593
# Article 70:	Length: 176	Compression: 1.113636	Avg Compression: 1.138535
# Article 80:	Length: 176	Compression: 1.039773	Avg Compression: 1.126397
# Article 90:	Length: 184	Compression: 1.097826	Avg Compression: 1.123144
# Article 100:	Length: 184	Compression: 0.896739	Avg Compression: 1.100000
# Article 110:	Length: 192	Compression: 0.802083	Avg Compression: 1.071285
# Article 120:	Length: 192	Compression: 0.953125	Avg Compression: 1.060897
# Article 130:	Length: 200	Compression: 0.945000	Avg Compression: 1.051174
# Article 140:	Length: 200	Compression: 0.925000	Avg Compression: 1.041409
# Article 150:	Length: 208	Compression: 0.995192	Avg Compression: 1.037966
# Article 160:	Length: 208	Compression: 0.841346	Avg Compression: 1.024333
# Article 170:	Length: 216	Compression: 0.916667	Avg Compression: 1.017102
# Article 180:	Length: 216	Compression: 0.912037	Avg Compression: 1.010490
# Article 190:	Length: 224	Compression: 1.049107	Avg Compression: 1.012856
# Article 200:	Length: 224	Compression: 0.959821	Avg Compression: 1.009794
# Article 210:	Length: 232	Compression: 0.762931	Avg Compression: 0.995866
# Article 220:	Length: 232	Compression: 0.836207	Avg Compression: 0.987339
# Article 230:	Length: 240	Compression: 0.941667	Avg Compression: 0.984948
# Article 240:	Length: 240	Compression: 0.966667	Avg Compression: 0.984038
# Article 250:	Length: 248	Compression: 0.677419	Avg Compression: 0.969046
# Article 260:	Length: 256	Compression: 1.058594	Avg Compression: 0.973348
# Article 270:	Length: 256	Compression: 0.695312	Avg Compression: 0.960602
# Article 280:	Length: 256	Compression: 0.593750	Avg Compression: 0.944521
# Article 290:	Length: 256	Compression: 0.925781	Avg Compression: 0.943734
# Article 300:	Length: 264	Compression: 0.738636	Avg Compression: 0.935220
# Article 310:	Length: 264	Compression: 0.784091	Avg Compression: 0.929197
# Article 320:	Length: 272	Compression: 0.716912	Avg Compression: 0.920824
# Article 330:	Length: 272	Compression: 0.966912	Avg Compression: 0.922573
# Article 340:	Length: 272	Compression: 0.753676	Avg Compression: 0.916398
# Article 350:	Length: 264	Compression: 1.613636	Avg Compression: 0.940291
# Article 360:	Length: 280	Compression: 0.678571	Avg Compression: 0.931112
# Article 370:	Length: 280	Compression: 0.789286	Avg Compression: 0.926307
# Article 380:	Length: 288	Compression: 0.965278	Avg Compression: 0.927619
# Article 390:	Length: 288	Compression: 0.746528	Avg Compression: 0.921719
# Article 400:	Length: 296	Compression: 0.709459	Avg Compression: 0.914842
# Article 410:	Length: 296	Compression: 0.820946	Avg Compression: 0.911896
# Article 420:	Length: 304	Compression: 0.592105	Avg Compression: 0.901910
# Article 430:	Length: 312	Compression: 0.538462	Avg Compression: 0.890625
# Article 440:	Length: 320	Compression: 0.546875	Avg Compression: 0.880015
# Article 450:	Length: 328	Compression: 0.661585	Avg Compression: 0.873317
# Article 460:	Length: 336	Compression: 0.732143	Avg Compression: 0.869017
# Article 470:	Length: 344	Compression: 0.741279	Avg Compression: 0.865155
# Article 480:	Length: 360	Compression: 0.580556	Avg Compression: 0.856425
# Article 490:	Length: 368	Compression: 0.644022	Avg Compression: 0.849967
# Article 500:	Length: 440	Compression: 0.613636	Avg Compression: 0.841677
# Article 510:	Length: 416	Compression: 0.622596	Avg Compression: 0.834645
# Article 520:	Length: 432	Compression: 0.555556	Avg Compression: 0.825642
# Article 530:	Length: 488	Compression: 0.368852	Avg Compression: 0.809582
# Article 540:	Length: 608	Compression: 0.416118	Avg Compression: 0.793070
# Article 550:	Length: 1696	Compression: 0.150943	Avg Compression: 0.725779
# Article 560:	Length: 2608	Compression: 0.136887	Avg Compression: 0.644051
# Article 570:	Length: 3256	Compression: 0.163391	Avg Compression: 0.573068
# Article 580:	Length: 4032	Compression: 0.222222	Avg Compression: 0.518827
# Article 590:	Length: 4616	Compression: 0.207972	Avg Compression: 0.472081
# Article 600:	Length: 5080	Compression: 0.196063	Avg Compression: 0.432888
# Article 610:	Length: 5552	Compression: 0.190562	Avg Compression: 0.400334
# Article 620:	Length: 5928	Compression: 0.187584	Avg Compression: 0.373646
# Article 630:	Length: 6480	Compression: 0.150309	Avg Compression: 0.346714
# Article 640:	Length: 6720	Compression: 0.166815	Avg Compression: 0.326717
# Article 650:	Length: 6960	Compression: 0.130747	Avg Compression: 0.306485
# Article 660:	Length: 7824	Compression: 0.131902	Avg Compression: 0.288331
# Article 670:	Length: 8360	Compression: 0.149761	Avg Compression: 0.274474
# Article 680:	Length: 8824	Compression: 0.148232	Avg Compression: 0.262421
# Article 690:	Length: 9288	Compression: 0.117033	Avg Compression: 0.249145
# Article 700:	Length: 9920	Compression: 0.166734	Avg Compression: 0.241821
# Article 710:	Length: 10552	Compression: 0.138552	Avg Compression: 0.232903
# Article 720:	Length: 11056	Compression: 0.153944	Avg Compression: 0.226351
# Article 730:	Length: 11776	Compression: 0.127463	Avg Compression: 0.218321
# Article 740:	Length: 12424	Compression: 0.161945	Avg Compression: 0.213872
# Article 750:	Length: 12944	Compression: 0.141842	Avg Compression: 0.208400
# Article 760:	Length: 13472	Compression: 0.149718	Avg Compression: 0.204100
# Article 770:	Length: 13888	Compression: 0.134361	Avg Compression: 0.199202
# Article 780:	Length: 14096	Compression: 0.140040	Avg Compression: 0.195265
# Article 790:	Length: 14800	Compression: 0.137230	Avg Compression: 0.191475
# Article 800:	Length: 15200	Compression: 0.142763	Avg Compression: 0.188414
# Article 810:	Length: 16024	Compression: 0.136233	Avg Compression: 0.185171
# Article 820:	Length: 16336	Compression: 0.132407	Avg Compression: 0.182028
# Article 830:	Length: 16904	Compression: 0.159371	Avg Compression: 0.180712
# Article 840:	Length: 17192	Compression: 0.156759	Avg Compression: 0.179376
# Article 850:	Length: 17632	Compression: 0.125113	Avg Compression: 0.176441
# Article 860:	Length: 17736	Compression: 0.136784	Avg Compression: 0.174394
# Article 870:	Length: 18408	Compression: 0.138798	Avg Compression: 0.172584
# Article 880:	Length: 18944	Compression: 0.134343	Avg Compression: 0.170683
# Article 890:	Length: 19320	Compression: 0.140528	Avg Compression: 0.169228
# Article 900:	Length: 20120	Compression: 0.138419	Avg Compression: 0.167754
# Article 910:	Length: 20368	Compression: 0.162117	Avg Compression: 0.167493
# Article 920:	Length: 20560	Compression: 0.138813	Avg Compression: 0.166215
# Article 930:	Length: 21408	Compression: 0.144105	Avg Compression: 0.165235
# Article 940:	Length: 22352	Compression: 0.130145	Avg Compression: 0.163682
# Article 950:	Length: 23192	Compression: 0.129441	Avg Compression: 0.162179
# Article 960:	Length: 23944	Compression: 0.140870	Avg Compression: 0.161255
# Article 970:	Length: 24192	Compression: 0.129051	Avg Compression: 0.159904
# Article 980:	Length: 25624	Compression: 0.121644	Avg Compression: 0.158275
# Article 990:	Length: 26592	Compression: 0.130979	Avg Compression: 0.157121
# Article 1000:	Length: 27224	Compression: 0.135616	Avg Compression: 0.156228
# Article 1010:	Length: 28328	Compression: 0.146357	Avg Compression: 0.155820
# Article 1020:	Length: 28416	Compression: 0.150795	Avg Compression: 0.155619
# Article 1030:	Length: 29016	Compression: 0.139957	Avg Compression: 0.155007
# Article 1040:	Length: 29920	Compression: 0.135662	Avg Compression: 0.154256
# Article 1050:	Length: 30600	Compression: 0.137974	Avg Compression: 0.153635
# Article 1060:	Length: 30488	Compression: 0.136677	Avg Compression: 0.153014
# Article 1070:	Length: 32032	Compression: 0.129558	Avg Compression: 0.152145
# Article 1080:	Length: 33016	Compression: 0.134026	Avg Compression: 0.151479
# Article 1090:	Length: 33472	Compression: 0.129870	Avg Compression: 0.150702
# Article 1100:	Length: 34536	Compression: 0.123205	Avg Compression: 0.149719
# Article 1110:	Length: 35264	Compression: 0.137222	Avg Compression: 0.149279
# Article 1120:	Length: 35736	Compression: 0.129113	Avg Compression: 0.148584
# Article 1130:	Length: 36448	Compression: 0.118278	Avg Compression: 0.147554
# Article 1140:	Length: 37448	Compression: 0.132664	Avg Compression: 0.147052
# Article 1150:	Length: 38424	Compression: 0.136842	Avg Compression: 0.146711
# Article 1160:	Length: 38680	Compression: 0.128826	Avg Compression: 0.146128
# Article 1170:	Length: 40216	Compression: 0.154192	Avg Compression: 0.146393
# Article 1180:	Length: 41480	Compression: 0.136933	Avg Compression: 0.146083
# Article 1190:	Length: 42616	Compression: 0.151445	Avg Compression: 0.146258
# Article 1200:	Length: 43488	Compression: 0.151145	Avg Compression: 0.146414
# Article 1210:	Length: 45080	Compression: 0.159894	Avg Compression: 0.146848
# Article 1220:	Length: 46864	Compression: 0.139745	Avg Compression: 0.146618
# Article 1230:	Length: 48608	Compression: 0.124794	Avg Compression: 0.145909
# Article 1240:	Length: 50264	Compression: 0.138708	Avg Compression: 0.145675
# Article 1250:	Length: 51272	Compression: 0.149009	Avg Compression: 0.145782
# Article 1260:	Length: 52528	Compression: 0.150015	Avg Compression: 0.145917
# Article 1270:	Length: 53688	Compression: 0.141540	Avg Compression: 0.145779
# Article 1280:	Length: 54640	Compression: 0.131845	Avg Compression: 0.145346
# Article 1290:	Length: 55440	Compression: 0.114105	Avg Compression: 0.144391
# Article 1300:	Length: 56320	Compression: 0.136914	Avg Compression: 0.144166
# Article 1310:	Length: 58648	Compression: 0.119731	Avg Compression: 0.143423
# Article 1320:	Length: 60504	Compression: 0.146602	Avg Compression: 0.143520
# Article 1330:	Length: 62376	Compression: 0.103614	Avg Compression: 0.142307
# Article 1340:	Length: 63840	Compression: 0.143217	Avg Compression: 0.142334
# Article 1350:	Length: 65976	Compression: 0.141794	Avg Compression: 0.142318
# Article 1360:	Length: 67128	Compression: 0.128620	Avg Compression: 0.141909
# Article 1370:	Length: 68800	Compression: 0.149651	Avg Compression: 0.142139
# Article 1380:	Length: 70576	Compression: 0.164093	Avg Compression: 0.142787
# Article 1390:	Length: 72432	Compression: 0.121673	Avg Compression: 0.142166
# Article 1400:	Length: 74752	Compression: 0.134766	Avg Compression: 0.141948
# Article 1410:	Length: 75792	Compression: 0.132257	Avg Compression: 0.141666
# Article 1420:	Length: 78368	Compression: 0.150648	Avg Compression: 0.141928
# Article 1430:	Length: 80136	Compression: 0.111535	Avg Compression: 0.141049
# Article 1440:	Length: 83192	Compression: 0.134087	Avg Compression: 0.140846
# Article 1450:	Length: 84736	Compression: 0.109623	Avg Compression: 0.139945
# Article 1460:	Length: 87880	Compression: 0.112528	Avg Compression: 0.139149
# Article 1470:	Length: 88760	Compression: 0.132627	Avg Compression: 0.138963
# Article 1480:	Length: 89704	Compression: 0.129203	Avg Compression: 0.138690
# Article 1490:	Length: 91864	Compression: 0.130116	Avg Compression: 0.138451
# Article 1500:	Length: 94344	Compression: 0.136543	Avg Compression: 0.138397
# Article 1510:	Length: 97160	Compression: 0.124444	Avg Compression: 0.138009
# Article 1520:	Length: 98752	Compression: 0.111269	Avg Compression: 0.137272
# Article 1530:	Length: 101024	Compression: 0.116972	Avg Compression: 0.136716
# Article 1540:	Length: 103016	Compression: 0.110400	Avg Compression: 0.136001
# Article 1550:	Length: 106432	Compression: 0.127574	Avg Compression: 0.135771
# Article 1560:	Length: 107664	Compression: 0.111105	Avg Compression: 0.135107
# Article 1570:	Length: 109952	Compression: 0.128629	Avg Compression: 0.134934
# Article 1580:	Length: 112616	Compression: 0.112497	Avg Compression: 0.134336
# Article 1590:	Length: 115984	Compression: 0.112309	Avg Compression: 0.133748
# Article 1600:	Length: 117944	Compression: 0.126246	Avg Compression: 0.133550
# Article 1610:	Length: 120872	Compression: 0.113417	Avg Compression: 0.133019
# Article 1620:	Length: 123248	Compression: 0.118615	Avg Compression: 0.132641
# Article 1630:	Length: 125152	Compression: 0.118680	Avg Compression: 0.132280
# Article 1640:	Length: 128960	Compression: 0.111352	Avg Compression: 0.131735
# Article 1650:	Length: 132816	Compression: 0.129156	Avg Compression: 0.131668
# Article 1660:	Length: 134584	Compression: 0.119502	Avg Compression: 0.131355
# Article 1670:	Length: 141472	Compression: 0.130853	Avg Compression: 0.131341
# Article 1680:	Length: 146472	Compression: 0.135336	Avg Compression: 0.131448
# Article 1690:	Length: 151840	Compression: 0.146128	Avg Compression: 0.131841
# Article 1700:	Length: 157048	Compression: 0.161460	Avg Compression: 0.132640
# Article 1710:	Length: 161424	Compression: 0.149773	Avg Compression: 0.133102
# Article 1720:	Length: 164208	Compression: 0.166977	Avg Compression: 0.134007
# Article 1730:	Length: 174464	Compression: 0.165358	Avg Compression: 0.134872
# Article 1740:	Length: 189072	Compression: 0.125138	Avg Compression: 0.134589
# Article 1750:	Length: 195080	Compression: 0.141183	Avg Compression: 0.134781
# Article 1760:	Length: 202592	Compression: 0.141945	Avg Compression: 0.134991
# Article 1770:	Length: 213160	Compression: 0.150277	Avg Compression: 0.135448
# Article 1780:	Length: 220440	Compression: 0.159998	Avg Compression: 0.136185
# Article 1790:	Length: 229744	Compression: 0.165206	Avg Compression: 0.137066
# Article 1800:	Length: 246304	Compression: 0.146303	Avg Compression: 0.137357
# Article 1810:	Length: 251304	Compression: 0.163646	Avg Compression: 0.138175
# Article 1820:	Length: 268336	Compression: 0.152324	Avg Compression: 0.138630
# Article 1830:	Length: 283192	Compression: 0.136346	Avg Compression: 0.138555
# Article 1840:	Length: 307368	Compression: 0.162301	Avg Compression: 0.139373
# Article 1850:	Length: 323168	Compression: 0.142950	Avg Compression: 0.139498
# Article 1860:	Length: 341176	Compression: 0.149275	Avg Compression: 0.139845
# Article 1870:	Length: 382048	Compression: 0.147042	Avg Compression: 0.140121
# Article 1880:	Length: 441872	Compression: 0.122151	Avg Compression: 0.139359
# Article 1890:	Length: 508896	Compression: 0.144381	Avg Compression: 0.139593

# %%
def loss(labels, logits):
    return tf.keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)

def average_final_batch_ratio(true_labels, predictions):
    return 0 ** tf.math.abs(true_labels[-1, -1])

class ModelStateResetter(tf.keras.callbacks.Callback):
    def __init__(self):
        pass

    def on_epoch_begin(self, epoch, logs=None):
        self.last_final_batch_count = 0
        
    def on_batch_end(self, batch, logs={}):
        average_final_batch_ratio = logs.get('average_final_batch_ratio', 0)
        final_batch_count = int(round(average_final_batch_ratio * (batch + 1)))
        is_final = final_batch_count - self.last_final_batch_count
        self.last_final_batch_count = final_batch_count
        
        if is_final:
            self.model.reset_states()

class Model:
    def __init__(self, articles, checkpoint_dir, vocab_size, embedding_dim, rnn_units):
        self._articles = articles
        self._batch_size = None
        self._batched_item_length = None
        self._training_model = None
        self._predicting_model = None
        self._vocab_size = vocab_size
        self._embedding_dim = embedding_dim
        self._rnn_units = rnn_units

        self._checkpoint_dir = checkpoint_dir
        self._checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt_{epoch}") # Name of the checkpoint files

    def training_model(self, batch_size, batched_item_length):
        if self._training_model == None or batch_size != self._batch_size or batched_item_length != self._batched_item_length:
            self._batch_size = batch_size
            self._batched_item_length = batched_item_length
            self._training_model = tf.keras.Sequential([
                tf.keras.layers.Masking(mask_value=0, batch_input_shape=[batch_size, batched_item_length]),
                tf.keras.layers.Embedding(self._vocab_size, self._embedding_dim),
                tf.keras.layers.LSTM(self._rnn_units, return_sequences=True, stateful=True, recurrent_initializer='glorot_uniform'),
                tf.keras.layers.LSTM(self._rnn_units, return_sequences=True, stateful=True, recurrent_initializer='glorot_uniform'),
                tf.keras.layers.Dense(self._vocab_size),
            ])

            if os.path.isdir(self._checkpoint_dir):
                self._training_model.load_weights(tf.train.latest_checkpoint(self._checkpoint_dir))

            self._training_model.compile(optimizer='adam', loss=loss, metrics=[average_final_batch_ratio])
            self._predicting_model = None
        
        return self._training_model

    @property
    def callbacks(self):
        checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=self._checkpoint_prefix, save_weights_only=True)
        model_state_resetter_callback = ModelStateResetter()
        
        return [checkpoint_callback, model_state_resetter_callback]
    
    def train(self, batch_size, batched_item_length, epochs=1):
        dataset = self._articles.dataset(batch_size, batched_item_length)

        model = self.training_model(batch_size, batched_item_length)

        model.fit(dataset, epochs=epochs, callbacks=self.callbacks)
    
    @property
    def predicting_model(self):
        if self._predicting_model == None:
            self._predicting_model = tf.keras.Sequential([
                tf.keras.layers.Masking(mask_value=0, batch_input_shape=[1, 1]),
                tf.keras.layers.Embedding(self._vocab_size, self._embedding_dim),
                tf.keras.layers.LSTM(self._rnn_units, stateful=True, return_sequences=True),
                tf.keras.layers.LSTM(self._rnn_units, stateful=True, return_sequences=True),
                tf.keras.layers.Dense(self._vocab_size),
            ])
            
            self._predicting_model.load_weights(tf.train.latest_checkpoint(self._checkpoint_dir))
            self._training_model = None
        
        return self._predicting_model
    
    def predict(self, input_eval):
        return self.predicting_model(input_eval)

# %%
model = Model(articles, './training_checkpoints-14',
              vocab_size = subword_text_encoder.vocab_size,
              embedding_dim=512,
              rnn_units=1024)

# %%
model.training_model(128, 256).summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# masking (Masking)            (128, 256)                0
# _________________________________________________________________
# embedding (Embedding)        (128, 256, 512)           2072576
# _________________________________________________________________
# lstm (LSTM)                  (128, 256, 1024)          6295552
# _________________________________________________________________
# lstm_1 (LSTM)                (128, 256, 1024)          8392704
# _________________________________________________________________
# dense (Dense)                (128, 256, 4048)          4149200
# =================================================================
# Total params: 20,910,032
# Trainable params: 20,910,032
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.train(192, 256, epochs=50)
# Out:
# Epoch 1/50
# 203/203 [==============================] - 196s 964ms/step - loss: 4.3103 - average_final_batch_ratio: 0.1182
# Epoch 2/50
# 203/203 [==============================] - 195s 959ms/step - loss: 4.2549 - average_final_batch_ratio: 0.1182
# Epoch 3/50
# 203/203 [==============================] - 195s 963ms/step - loss: 4.1003 - average_final_batch_ratio: 0.1182
# Epoch 4/50
# 203/203 [==============================] - 195s 963ms/step - loss: 3.9176 - average_final_batch_ratio: 0.1182
# Epoch 5/50
# 203/203 [==============================] - 196s 968ms/step - loss: 3.3921 - average_final_batch_ratio: 0.1182
# Epoch 6/50
# 203/203 [==============================] - 196s 964ms/step - loss: 3.0076 - average_final_batch_ratio: 0.1182
# Epoch 7/50
# 203/203 [==============================] - 196s 966ms/step - loss: 2.7216 - average_final_batch_ratio: 0.1182
# Epoch 8/50
# 203/203 [==============================] - 196s 965ms/step - loss: 2.5378 - average_final_batch_ratio: 0.1182
# Epoch 9/50
# 203/203 [==============================] - 196s 964ms/step - loss: 2.4087 - average_final_batch_ratio: 0.1182
# Epoch 10/50
# 203/203 [==============================] - 196s 966ms/step - loss: 2.2952 - average_final_batch_ratio: 0.1182
# Epoch 11/50
# 203/203 [==============================] - 196s 966ms/step - loss: 2.1912 - average_final_batch_ratio: 0.1182
# Epoch 12/50
# 203/203 [==============================] - 197s 969ms/step - loss: 2.1037 - average_final_batch_ratio: 0.1182
# Epoch 13/50
# 203/203 [==============================] - 196s 965ms/step - loss: 2.0302 - average_final_batch_ratio: 0.1182
# Epoch 14/50
# 203/203 [==============================] - 197s 968ms/step - loss: 1.9600 - average_final_batch_ratio: 0.1182
# Epoch 15/50
# 203/203 [==============================] - 196s 966ms/step - loss: 1.9043 - average_final_batch_ratio: 0.1182
# Epoch 16/50
# 203/203 [==============================] - 196s 965ms/step - loss: 1.8561 - average_final_batch_ratio: 0.1182
# Epoch 17/50
# 203/203 [==============================] - 196s 967ms/step - loss: 1.8109 - average_final_batch_ratio: 0.1182
# Epoch 18/50
# 203/203 [==============================] - 196s 967ms/step - loss: 1.7705 - average_final_batch_ratio: 0.1182
# Epoch 19/50
# 203/203 [==============================] - 197s 971ms/step - loss: 1.7337 - average_final_batch_ratio: 0.1182
# Epoch 20/50
# 203/203 [==============================] - 196s 966ms/step - loss: 1.6956 - average_final_batch_ratio: 0.1182
# Epoch 21/50
# 203/203 [==============================] - 197s 969ms/step - loss: 1.6648 - average_final_batch_ratio: 0.1182
# Epoch 22/50
# 203/203 [==============================] - 197s 968ms/step - loss: 1.6306 - average_final_batch_ratio: 0.1182
# Epoch 23/50
# 203/203 [==============================] - 196s 967ms/step - loss: 1.6012 - average_final_batch_ratio: 0.1182
# Epoch 24/50
# 203/203 [==============================] - 197s 968ms/step - loss: 1.5740 - average_final_batch_ratio: 0.1182
# Epoch 25/50
# 203/203 [==============================] - 197s 968ms/step - loss: 1.5472 - average_final_batch_ratio: 0.1182
# Epoch 26/50
# 203/203 [==============================] - 197s 971ms/step - loss: 1.5233 - average_final_batch_ratio: 0.1182
# Epoch 27/50
# 203/203 [==============================] - 196s 966ms/step - loss: 1.5042 - average_final_batch_ratio: 0.1182
# Epoch 28/50
# 203/203 [==============================] - 197s 969ms/step - loss: 1.4762 - average_final_batch_ratio: 0.1182
# Epoch 29/50
# 203/203 [==============================] - 196s 967ms/step - loss: 1.4556 - average_final_batch_ratio: 0.1182
# Epoch 30/50
# 203/203 [==============================] - 196s 966ms/step - loss: 1.4311 - average_final_batch_ratio: 0.1182
# Epoch 31/50
# 203/203 [==============================] - 196s 968ms/step - loss: 1.4123 - average_final_batch_ratio: 0.1182
# Epoch 32/50
# 203/203 [==============================] - 196s 968ms/step - loss: 1.3896 - average_final_batch_ratio: 0.1182
# Epoch 33/50
# 203/203 [==============================] - 197s 971ms/step - loss: 1.3756 - average_final_batch_ratio: 0.1182
# Epoch 34/50
# 203/203 [==============================] - 196s 966ms/step - loss: 1.3495 - average_final_batch_ratio: 0.1182
# Epoch 35/50
# 203/203 [==============================] - 197s 970ms/step - loss: 1.3353 - average_final_batch_ratio: 0.1182
# Epoch 36/50
# 203/203 [==============================] - 196s 968ms/step - loss: 1.3142 - average_final_batch_ratio: 0.1182
# Epoch 37/50
# 203/203 [==============================] - 196s 966ms/step - loss: 1.2951 - average_final_batch_ratio: 0.1182
# Epoch 38/50
# 203/203 [==============================] - 196s 968ms/step - loss: 1.2733 - average_final_batch_ratio: 0.1182
# Epoch 39/50
# 203/203 [==============================] - 196s 968ms/step - loss: 1.2526 - average_final_batch_ratio: 0.1182
# Epoch 40/50
# 203/203 [==============================] - 197s 971ms/step - loss: 1.2432 - average_final_batch_ratio: 0.1182
# Epoch 41/50
# 203/203 [==============================] - 196s 966ms/step - loss: 1.2288 - average_final_batch_ratio: 0.1182
# Epoch 42/50
# 203/203 [==============================] - 197s 969ms/step - loss: 1.2043 - average_final_batch_ratio: 0.1182
# Epoch 43/50
# 203/203 [==============================] - 196s 967ms/step - loss: 1.1954 - average_final_batch_ratio: 0.1182
# Epoch 44/50
# 203/203 [==============================] - 196s 966ms/step - loss: 1.1797 - average_final_batch_ratio: 0.1182
# Epoch 45/50
# 203/203 [==============================] - 197s 968ms/step - loss: 1.1677 - average_final_batch_ratio: 0.1182
# Epoch 46/50
# 203/203 [==============================] - 197s 968ms/step - loss: 1.1554 - average_final_batch_ratio: 0.1182
# Epoch 47/50
# 203/203 [==============================] - 197s 971ms/step - loss: 1.1343 - average_final_batch_ratio: 0.1182
# Epoch 48/50
# 203/203 [==============================] - 196s 967ms/step - loss: 1.1310 - average_final_batch_ratio: 0.1182
# Epoch 49/50
# 203/203 [==============================] - 197s 970ms/step - loss: 1.1032 - average_final_batch_ratio: 0.1182
# Epoch 50/50
# 203/203 [==============================] - 197s 968ms/step - loss: 1.0839 - average_final_batch_ratio: 0.1182

# %%
total_raw = 0
total_compressed = 0

for index, encoded_article in enumerate(articles.articles_generator(1)):
    if index % 10 == 0:
        article = subword_text_encoder.decode(encoded_article)
        raw = len(article) * 8
        if raw == 0:
            continue
        compressed, _ = huffman_archive_size(model, encoded_article)
        total_raw += raw
        total_compressed += compressed

        print('Article %d:\tLength: %d\tCompression: %f\tAvg Compression: %f' % (index, raw, compressed/raw, total_compressed/total_raw))
# Out:
# Article 0:	Length: 128	Compression: 0.703125	Avg Compression: 0.703125
# Article 10:	Length: 144	Compression: 0.750000	Avg Compression: 0.727941
# Article 20:	Length: 152	Compression: 0.684211	Avg Compression: 0.712264
# Article 30:	Length: 160	Compression: 0.687500	Avg Compression: 0.705479
# Article 40:	Length: 160	Compression: 0.656250	Avg Compression: 0.694892
# Article 50:	Length: 168	Compression: 0.529762	Avg Compression: 0.664474
# Article 60:	Length: 168	Compression: 0.607143	Avg Compression: 0.655556
# Article 70:	Length: 176	Compression: 0.539773	Avg Compression: 0.639331
# Article 80:	Length: 176	Compression: 0.585227	Avg Compression: 0.632682
# Article 90:	Length: 184	Compression: 0.614130	Avg Compression: 0.630569
# Article 100:	Length: 184	Compression: 0.543478	Avg Compression: 0.621667
# Article 110:	Length: 192	Compression: 0.557292	Avg Compression: 0.615462
# Article 120:	Length: 192	Compression: 0.640625	Avg Compression: 0.617674
# Article 130:	Length: 200	Compression: 0.490000	Avg Compression: 0.606963
# Article 140:	Length: 200	Compression: 0.605000	Avg Compression: 0.606811
# Article 150:	Length: 208	Compression: 0.600962	Avg Compression: 0.606375
# Article 160:	Length: 208	Compression: 0.495192	Avg Compression: 0.598667
# Article 170:	Length: 208	Compression: 0.480769	Avg Compression: 0.591022
# Article 180:	Length: 264	Compression: 0.469697	Avg Compression: 0.581797
# Article 190:	Length: 224	Compression: 0.464286	Avg Compression: 0.574675
# Article 200:	Length: 224	Compression: 0.486607	Avg Compression: 0.569643
# Article 210:	Length: 232	Compression: 0.512931	Avg Compression: 0.566474
# Article 220:	Length: 232	Compression: 0.603448	Avg Compression: 0.568431
# Article 230:	Length: 240	Compression: 0.408333	Avg Compression: 0.560121
# Article 240:	Length: 232	Compression: 0.487069	Avg Compression: 0.556631
# Article 250:	Length: 248	Compression: 0.451613	Avg Compression: 0.551528
# Article 260:	Length: 256	Compression: 0.398438	Avg Compression: 0.544216
# Article 270:	Length: 256	Compression: 0.421875	Avg Compression: 0.538640
# Article 280:	Length: 256	Compression: 0.542969	Avg Compression: 0.538828
# Article 290:	Length: 256	Compression: 0.640625	Avg Compression: 0.543081
# Article 300:	Length: 264	Compression: 0.409091	Avg Compression: 0.537547
# Article 310:	Length: 264	Compression: 0.507576	Avg Compression: 0.536358
# Article 320:	Length: 272	Compression: 0.426471	Avg Compression: 0.532044
# Article 330:	Length: 272	Compression: 0.360294	Avg Compression: 0.525556
# Article 340:	Length: 272	Compression: 0.397059	Avg Compression: 0.520878
# Article 350:	Length: 272	Compression: 0.404412	Avg Compression: 0.516787
# Article 360:	Length: 280	Compression: 0.392857	Avg Compression: 0.512463
# Article 370:	Length: 280	Compression: 0.396429	Avg Compression: 0.508550
# Article 380:	Length: 288	Compression: 0.604167	Avg Compression: 0.511755
# Article 390:	Length: 288	Compression: 0.375000	Avg Compression: 0.507320
# Article 400:	Length: 296	Compression: 0.331081	Avg Compression: 0.501635
# Article 410:	Length: 296	Compression: 0.351351	Avg Compression: 0.496938
# Article 420:	Length: 304	Compression: 0.414474	Avg Compression: 0.494374
# Article 430:	Length: 312	Compression: 0.355769	Avg Compression: 0.490087
# Article 440:	Length: 320	Compression: 0.550000	Avg Compression: 0.491929
# Article 450:	Length: 328	Compression: 0.295732	Avg Compression: 0.485935
# Article 460:	Length: 336	Compression: 0.333333	Avg Compression: 0.481304
# Article 470:	Length: 344	Compression: 0.345930	Avg Compression: 0.477225
# Article 480:	Length: 360	Compression: 0.300000	Avg Compression: 0.471807
# Article 490:	Length: 360	Compression: 0.486111	Avg Compression: 0.472231
# Article 500:	Length: 392	Compression: 0.303571	Avg Compression: 0.466954
# Article 510:	Length: 416	Compression: 0.346154	Avg Compression: 0.463072
# Article 520:	Length: 432	Compression: 0.229167	Avg Compression: 0.455517
# Article 530:	Length: 488	Compression: 0.241803	Avg Compression: 0.447995
# Article 540:	Length: 608	Compression: 0.220395	Avg Compression: 0.438433
# Article 550:	Length: 1696	Compression: 0.135613	Avg Compression: 0.406667
# Article 560:	Length: 2608	Compression: 0.127301	Avg Compression: 0.367863
# Article 570:	Length: 3256	Compression: 0.165848	Avg Compression: 0.338008
# Article 580:	Length: 4032	Compression: 0.196677	Avg Compression: 0.316145
# Article 590:	Length: 4616	Compression: 0.175910	Avg Compression: 0.295046
# Article 600:	Length: 5080	Compression: 0.186417	Avg Compression: 0.279614
# Article 610:	Length: 5552	Compression: 0.168948	Avg Compression: 0.264741
# Article 620:	Length: 5928	Compression: 0.237854	Avg Compression: 0.261367
# Article 630:	Length: 6480	Compression: 0.140586	Avg Compression: 0.246798
# Article 640:	Length: 6720	Compression: 0.191667	Avg Compression: 0.240668
# Article 650:	Length: 6960	Compression: 0.151006	Avg Compression: 0.231409
# Article 660:	Length: 7824	Compression: 0.153246	Avg Compression: 0.223280
# Article 670:	Length: 8360	Compression: 0.166866	Avg Compression: 0.217637
# Article 680:	Length: 8824	Compression: 0.168404	Avg Compression: 0.212936
# Article 690:	Length: 9288	Compression: 0.129845	Avg Compression: 0.205347
# Article 700:	Length: 9920	Compression: 0.172984	Avg Compression: 0.202471
# Article 710:	Length: 10552	Compression: 0.147839	Avg Compression: 0.197752
# Article 720:	Length: 11056	Compression: 0.184063	Avg Compression: 0.196616
# Article 730:	Length: 11776	Compression: 0.149796	Avg Compression: 0.192814
# Article 740:	Length: 12424	Compression: 0.189874	Avg Compression: 0.192582
# Article 750:	Length: 12944	Compression: 0.158761	Avg Compression: 0.190012
# Article 760:	Length: 13472	Compression: 0.167978	Avg Compression: 0.188398
# Article 770:	Length: 13888	Compression: 0.152650	Avg Compression: 0.185887
# Article 780:	Length: 14096	Compression: 0.167707	Avg Compression: 0.184677
# Article 790:	Length: 14800	Compression: 0.149595	Avg Compression: 0.182386
# Article 800:	Length: 15200	Compression: 0.156908	Avg Compression: 0.180784
# Article 810:	Length: 16024	Compression: 0.159136	Avg Compression: 0.179439
# Article 820:	Length: 16336	Compression: 0.148323	Avg Compression: 0.177585
# Article 830:	Length: 16904	Compression: 0.176053	Avg Compression: 0.177496
# Article 840:	Length: 17192	Compression: 0.171882	Avg Compression: 0.177183
# Article 850:	Length: 17632	Compression: 0.156363	Avg Compression: 0.176057
# Article 860:	Length: 17736	Compression: 0.144959	Avg Compression: 0.174452
# Article 870:	Length: 18048	Compression: 0.142786	Avg Compression: 0.172872
# Article 880:	Length: 19152	Compression: 0.164578	Avg Compression: 0.172455
# Article 890:	Length: 19320	Compression: 0.156108	Avg Compression: 0.171665
# Article 900:	Length: 20120	Compression: 0.158946	Avg Compression: 0.171057
# Article 910:	Length: 20368	Compression: 0.189464	Avg Compression: 0.171907
# Article 920:	Length: 20560	Compression: 0.154621	Avg Compression: 0.171137
# Article 930:	Length: 21408	Compression: 0.170544	Avg Compression: 0.171110
# Article 940:	Length: 22352	Compression: 0.164460	Avg Compression: 0.170816
# Article 950:	Length: 23192	Compression: 0.160271	Avg Compression: 0.170353
# Article 960:	Length: 23776	Compression: 0.162433	Avg Compression: 0.170012
# Article 970:	Length: 24192	Compression: 0.146412	Avg Compression: 0.169021
# Article 980:	Length: 25624	Compression: 0.155713	Avg Compression: 0.168454
# Article 990:	Length: 26680	Compression: 0.178898	Avg Compression: 0.168898
# Article 1000:	Length: 27224	Compression: 0.160594	Avg Compression: 0.168553
# Article 1010:	Length: 28328	Compression: 0.170926	Avg Compression: 0.168651
# Article 1020:	Length: 28416	Compression: 0.163711	Avg Compression: 0.168454
# Article 1030:	Length: 29016	Compression: 0.164323	Avg Compression: 0.168292
# Article 1040:	Length: 29920	Compression: 0.161564	Avg Compression: 0.168031
# Article 1050:	Length: 30600	Compression: 0.164739	Avg Compression: 0.167906
# Article 1060:	Length: 30488	Compression: 0.169477	Avg Compression: 0.167963
# Article 1070:	Length: 32032	Compression: 0.142795	Avg Compression: 0.167031
# Article 1080:	Length: 33016	Compression: 0.164829	Avg Compression: 0.166950
# Article 1090:	Length: 33472	Compression: 0.152277	Avg Compression: 0.166422
# Article 1100:	Length: 34536	Compression: 0.144805	Avg Compression: 0.165649
# Article 1110:	Length: 35264	Compression: 0.169918	Avg Compression: 0.165799
# Article 1120:	Length: 35736	Compression: 0.163393	Avg Compression: 0.165716
# Article 1130:	Length: 36448	Compression: 0.141215	Avg Compression: 0.164884
# Article 1140:	Length: 37448	Compression: 0.167913	Avg Compression: 0.164986
# Article 1150:	Length: 37904	Compression: 0.182461	Avg Compression: 0.165563
# Article 1160:	Length: 38680	Compression: 0.164736	Avg Compression: 0.165536
# Article 1170:	Length: 40216	Compression: 0.183783	Avg Compression: 0.166134
# Article 1180:	Length: 41480	Compression: 0.183052	Avg Compression: 0.166687
# Article 1190:	Length: 42616	Compression: 0.179651	Avg Compression: 0.167108
# Article 1200:	Length: 43488	Compression: 0.171013	Avg Compression: 0.167234
# Article 1210:	Length: 45080	Compression: 0.178461	Avg Compression: 0.167595
# Article 1220:	Length: 46864	Compression: 0.171027	Avg Compression: 0.167706
# Article 1230:	Length: 48608	Compression: 0.147321	Avg Compression: 0.167044
# Article 1240:	Length: 50264	Compression: 0.167098	Avg Compression: 0.167046
# Article 1250:	Length: 51272	Compression: 0.178050	Avg Compression: 0.167399
# Article 1260:	Length: 52528	Compression: 0.178990	Avg Compression: 0.167768
# Article 1270:	Length: 53688	Compression: 0.166890	Avg Compression: 0.167740
# Article 1280:	Length: 54640	Compression: 0.155747	Avg Compression: 0.167368
# Article 1290:	Length: 55440	Compression: 0.131403	Avg Compression: 0.166268
# Article 1300:	Length: 56320	Compression: 0.160636	Avg Compression: 0.166098
# Article 1310:	Length: 58648	Compression: 0.145069	Avg Compression: 0.165459
# Article 1320:	Length: 60504	Compression: 0.176418	Avg Compression: 0.165792
# Article 1330:	Length: 62376	Compression: 0.110619	Avg Compression: 0.164114
# Article 1340:	Length: 63840	Compression: 0.164333	Avg Compression: 0.164121
# Article 1350:	Length: 65976	Compression: 0.162574	Avg Compression: 0.164074
# Article 1360:	Length: 67128	Compression: 0.156567	Avg Compression: 0.163850
# Article 1370:	Length: 68800	Compression: 0.168997	Avg Compression: 0.164003
# Article 1380:	Length: 70576	Compression: 0.180345	Avg Compression: 0.164486
# Article 1390:	Length: 72432	Compression: 0.138268	Avg Compression: 0.163714
# Article 1400:	Length: 74752	Compression: 0.161935	Avg Compression: 0.163661
# Article 1410:	Length: 75792	Compression: 0.159384	Avg Compression: 0.163537
# Article 1420:	Length: 78368	Compression: 0.176501	Avg Compression: 0.163915
# Article 1430:	Length: 80136	Compression: 0.133610	Avg Compression: 0.163038
# Article 1440:	Length: 81808	Compression: 0.157454	Avg Compression: 0.162878
# Article 1450:	Length: 84736	Compression: 0.121507	Avg Compression: 0.161683
# Article 1460:	Length: 87880	Compression: 0.120619	Avg Compression: 0.160490
# Article 1470:	Length: 88760	Compression: 0.155813	Avg Compression: 0.160356
# Article 1480:	Length: 89704	Compression: 0.166135	Avg Compression: 0.160518
# Article 1490:	Length: 91864	Compression: 0.153531	Avg Compression: 0.160323
# Article 1500:	Length: 94344	Compression: 0.164197	Avg Compression: 0.160431
# Article 1510:	Length: 97160	Compression: 0.152820	Avg Compression: 0.160219
# Article 1520:	Length: 98752	Compression: 0.123086	Avg Compression: 0.159196
# Article 1530:	Length: 101024	Compression: 0.128821	Avg Compression: 0.158363
# Article 1540:	Length: 103016	Compression: 0.127233	Avg Compression: 0.157516
# Article 1550:	Length: 106432	Compression: 0.167901	Avg Compression: 0.157800
# Article 1560:	Length: 107664	Compression: 0.130155	Avg Compression: 0.157056
# Article 1570:	Length: 109952	Compression: 0.164626	Avg Compression: 0.157259
# Article 1580:	Length: 112616	Compression: 0.132734	Avg Compression: 0.156605
# Article 1590:	Length: 115984	Compression: 0.137140	Avg Compression: 0.156085
# Article 1600:	Length: 118032	Compression: 0.159194	Avg Compression: 0.156167
# Article 1610:	Length: 120872	Compression: 0.132992	Avg Compression: 0.155556
# Article 1620:	Length: 123248	Compression: 0.148059	Avg Compression: 0.155359
# Article 1630:	Length: 125152	Compression: 0.149866	Avg Compression: 0.155217
# Article 1640:	Length: 128960	Compression: 0.138337	Avg Compression: 0.154778
# Article 1650:	Length: 132816	Compression: 0.148815	Avg Compression: 0.154622
# Article 1660:	Length: 134584	Compression: 0.129421	Avg Compression: 0.153973
# Article 1670:	Length: 141472	Compression: 0.147796	Avg Compression: 0.153810
# Article 1680:	Length: 146472	Compression: 0.151408	Avg Compression: 0.153746
# Article 1690:	Length: 151840	Compression: 0.164528	Avg Compression: 0.154035
# Article 1700:	Length: 157048	Compression: 0.178722	Avg Compression: 0.154701
# Article 1710:	Length: 161424	Compression: 0.179633	Avg Compression: 0.155374
# Article 1720:	Length: 164208	Compression: 0.193833	Avg Compression: 0.156401
# Article 1730:	Length: 174464	Compression: 0.191226	Avg Compression: 0.157362
# Article 1740:	Length: 189072	Compression: 0.146600	Avg Compression: 0.157050
# Article 1750:	Length: 195080	Compression: 0.163738	Avg Compression: 0.157244
# Article 1760:	Length: 202592	Compression: 0.163896	Avg Compression: 0.157440
# Article 1770:	Length: 213160	Compression: 0.172837	Avg Compression: 0.157900
# Article 1780:	Length: 220440	Compression: 0.184508	Avg Compression: 0.158699
# Article 1790:	Length: 229744	Compression: 0.190947	Avg Compression: 0.159678
# Article 1800:	Length: 246304	Compression: 0.160497	Avg Compression: 0.159704
# Article 1810:	Length: 251304	Compression: 0.183057	Avg Compression: 0.160431
# Article 1820:	Length: 268336	Compression: 0.175485	Avg Compression: 0.160916
# Article 1830:	Length: 283192	Compression: 0.151346	Avg Compression: 0.160601
# Article 1840:	Length: 307368	Compression: 0.175012	Avg Compression: 0.161097
# Article 1850:	Length: 323168	Compression: 0.156798	Avg Compression: 0.160947
# Article 1860:	Length: 341176	Compression: 0.169862	Avg Compression: 0.161264
# Article 1870:	Length: 382048	Compression: 0.158710	Avg Compression: 0.161166
# Article 1880:	Length: 441872	Compression: 0.126867	Avg Compression: 0.159711
# Article 1890:	Length: 508896	Compression: 0.160072	Avg Compression: 0.159728

# %%
model.train(192, 256, epochs=50)
# Out:
# Epoch 1/50
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# 203/203 [==============================] - 198s 977ms/step - loss: 1.0646 - average_final_batch_ratio: 0.1182
# Epoch 2/50
# 203/203 [==============================] - 197s 972ms/step - loss: 1.0543 - average_final_batch_ratio: 0.1182
# Epoch 3/50
# 203/203 [==============================] - 197s 969ms/step - loss: 1.0471 - average_final_batch_ratio: 0.1182
# Epoch 4/50
# 203/203 [==============================] - 197s 972ms/step - loss: 1.0288 - average_final_batch_ratio: 0.1182
# Epoch 5/50
# 203/203 [==============================] - 197s 969ms/step - loss: 1.0124 - average_final_batch_ratio: 0.1182
# Epoch 6/50
# 203/203 [==============================] - 197s 969ms/step - loss: 0.9983 - average_final_batch_ratio: 0.1182
# Epoch 7/50
# 203/203 [==============================] - 197s 971ms/step - loss: 0.9860 - average_final_batch_ratio: 0.1182
# Epoch 8/50
# 203/203 [==============================] - 197s 971ms/step - loss: 0.9723 - average_final_batch_ratio: 0.1182
# Epoch 9/50
# 203/203 [==============================] - 198s 973ms/step - loss: 0.9721 - average_final_batch_ratio: 0.1182
# Epoch 10/50
# 203/203 [==============================] - 197s 968ms/step - loss: 0.9699 - average_final_batch_ratio: 0.1182
# Epoch 11/50
# 203/203 [==============================] - 197s 972ms/step - loss: 0.9664 - average_final_batch_ratio: 0.1182
# Epoch 12/50
# 203/203 [==============================] - 197s 969ms/step - loss: 0.9440 - average_final_batch_ratio: 0.1182
# Epoch 13/50
# 203/203 [==============================] - 196s 968ms/step - loss: 0.9184 - average_final_batch_ratio: 0.1182
# Epoch 14/50
# 203/203 [==============================] - 197s 970ms/step - loss: 0.9034 - average_final_batch_ratio: 0.1182
# Epoch 15/50
# 203/203 [==============================] - 197s 971ms/step - loss: 0.8932 - average_final_batch_ratio: 0.1182
# Epoch 16/50
# 203/203 [==============================] - 198s 973ms/step - loss: 0.8854 - average_final_batch_ratio: 0.1182
# Epoch 17/50
# 203/203 [==============================] - 197s 969ms/step - loss: 0.8963 - average_final_batch_ratio: 0.1182
# Epoch 18/50
# 203/203 [==============================] - 197s 973ms/step - loss: 0.8789 - average_final_batch_ratio: 0.1182
# Epoch 19/50
# 203/203 [==============================] - 197s 970ms/step - loss: 0.8740 - average_final_batch_ratio: 0.1182
# Epoch 20/50
# 203/203 [==============================] - 197s 969ms/step - loss: 0.8692 - average_final_batch_ratio: 0.1182
# Epoch 21/50
# 203/203 [==============================] - 197s 972ms/step - loss: 0.8477 - average_final_batch_ratio: 0.1182
# Epoch 22/50
# 203/203 [==============================] - 197s 971ms/step - loss: 0.8284 - average_final_batch_ratio: 0.1182
# Epoch 23/50
# 203/203 [==============================] - 197s 973ms/step - loss: 0.8186 - average_final_batch_ratio: 0.1182
# Epoch 24/50
# 203/203 [==============================] - 197s 969ms/step - loss: 0.8084 - average_final_batch_ratio: 0.1182
# Epoch 25/50
# 203/203 [==============================] - 197s 972ms/step - loss: 0.8088 - average_final_batch_ratio: 0.1182
# Epoch 26/50
# 203/203 [==============================] - 197s 970ms/step - loss: 0.7834 - average_final_batch_ratio: 0.1182
# Epoch 27/50
# 203/203 [==============================] - 197s 969ms/step - loss: 0.7938 - average_final_batch_ratio: 0.1182
# Epoch 28/50
# 203/203 [==============================] - 197s 971ms/step - loss: 0.7740 - average_final_batch_ratio: 0.1182
# Epoch 29/50
# 203/203 [==============================] - 197s 971ms/step - loss: 0.7794 - average_final_batch_ratio: 0.1182
# Epoch 30/50
# 203/203 [==============================] - 198s 973ms/step - loss: 0.7549 - average_final_batch_ratio: 0.1182
# Epoch 31/50
# 203/203 [==============================] - 197s 969ms/step - loss: 0.7397 - average_final_batch_ratio: 0.1182
# Epoch 32/50
# 203/203 [==============================] - 197s 972ms/step - loss: 0.7460 - average_final_batch_ratio: 0.1182
# Epoch 33/50
# 203/203 [==============================] - 197s 970ms/step - loss: 0.7553 - average_final_batch_ratio: 0.1182
# Epoch 34/50
# 203/203 [==============================] - 197s 969ms/step - loss: 0.7357 - average_final_batch_ratio: 0.1182
# Epoch 35/50
# 203/203 [==============================] - 197s 971ms/step - loss: 0.7226 - average_final_batch_ratio: 0.1182
# Epoch 36/50
# 203/203 [==============================] - 197s 971ms/step - loss: 0.7318 - average_final_batch_ratio: 0.1182
# Epoch 37/50
# 203/203 [==============================] - 197s 973ms/step - loss: 0.7314 - average_final_batch_ratio: 0.1182
# Epoch 38/50
# 203/203 [==============================] - 197s 968ms/step - loss: 0.7024 - average_final_batch_ratio: 0.1182
# Epoch 39/50
# 203/203 [==============================] - 197s 971ms/step - loss: 0.6868 - average_final_batch_ratio: 0.1182
# Epoch 40/50
# 203/203 [==============================] - 197s 970ms/step - loss: 0.6731 - average_final_batch_ratio: 0.1182
# Epoch 41/50
# 203/203 [==============================] - 197s 969ms/step - loss: 0.6766 - average_final_batch_ratio: 0.1182
# Epoch 42/50
# 203/203 [==============================] - 197s 971ms/step - loss: 0.6562 - average_final_batch_ratio: 0.1182
# Epoch 43/50
# 203/203 [==============================] - 197s 971ms/step - loss: 0.6721 - average_final_batch_ratio: 0.1182
# Epoch 44/50
# 203/203 [==============================] - 198s 973ms/step - loss: 0.6564 - average_final_batch_ratio: 0.1182
# Epoch 45/50
# 203/203 [==============================] - 197s 969ms/step - loss: 0.6498 - average_final_batch_ratio: 0.1182
# Epoch 46/50
# 203/203 [==============================] - 197s 972ms/step - loss: 0.6220 - average_final_batch_ratio: 0.1182
# Epoch 47/50
# 203/203 [==============================] - 197s 970ms/step - loss: 0.6282 - average_final_batch_ratio: 0.1182
# Epoch 48/50
# 203/203 [==============================] - 197s 969ms/step - loss: 0.6275 - average_final_batch_ratio: 0.1182
# Epoch 49/50
# 203/203 [==============================] - 197s 971ms/step - loss: 0.6135 - average_final_batch_ratio: 0.1182
# Epoch 50/50
# 203/203 [==============================] - 197s 971ms/step - loss: 0.6101 - average_final_batch_ratio: 0.1182

# %%
total_raw = 0
total_compressed = 0

for index, encoded_article in enumerate(articles.articles_generator(1)):
    if index % 10 == 0:
        article = subword_text_encoder.decode(encoded_article)
        raw = len(article) * 8
        if raw == 0:
            continue
        compressed, _ = huffman_archive_size(model, encoded_article)
        total_raw += raw
        total_compressed += compressed

        print('Article %d:\tLength: %d\tCompression: %f\tAvg Compression: %f' % (index, raw, compressed/raw, total_compressed/total_raw))
# Out:
# Article 0:	Length: 128	Compression: 0.882812	Avg Compression: 0.882812
# Article 10:	Length: 144	Compression: 0.909722	Avg Compression: 0.897059
# Article 20:	Length: 152	Compression: 0.809211	Avg Compression: 0.865566
# Article 30:	Length: 160	Compression: 0.937500	Avg Compression: 0.885274
# Article 40:	Length: 160	Compression: 0.775000	Avg Compression: 0.861559
# Article 50:	Length: 168	Compression: 0.809524	Avg Compression: 0.851974
# Article 60:	Length: 168	Compression: 0.696429	Avg Compression: 0.827778
# Article 70:	Length: 176	Compression: 0.630682	Avg Compression: 0.800159
# Article 80:	Length: 176	Compression: 0.693182	Avg Compression: 0.787011
# Article 90:	Length: 184	Compression: 0.657609	Avg Compression: 0.772277
# Article 100:	Length: 184	Compression: 0.668478	Avg Compression: 0.761667
# Article 110:	Length: 192	Compression: 0.656250	Avg Compression: 0.751506
# Article 120:	Length: 192	Compression: 0.812500	Avg Compression: 0.756868
# Article 130:	Length: 200	Compression: 0.525000	Avg Compression: 0.737416
# Article 140:	Length: 200	Compression: 0.745000	Avg Compression: 0.738003
# Article 150:	Length: 208	Compression: 0.677885	Avg Compression: 0.733524
# Article 160:	Length: 208	Compression: 0.677885	Avg Compression: 0.729667
# Article 170:	Length: 208	Compression: 0.600962	Avg Compression: 0.721322
# Article 180:	Length: 264	Compression: 0.579545	Avg Compression: 0.710541
# Article 190:	Length: 224	Compression: 0.535714	Avg Compression: 0.699946
# Article 200:	Length: 224	Compression: 0.535714	Avg Compression: 0.690561
# Article 210:	Length: 232	Compression: 0.681034	Avg Compression: 0.690029
# Article 220:	Length: 232	Compression: 0.676724	Avg Compression: 0.689325
# Article 230:	Length: 240	Compression: 0.458333	Avg Compression: 0.677336
# Article 240:	Length: 232	Compression: 0.551724	Avg Compression: 0.671334
# Article 250:	Length: 248	Compression: 0.532258	Avg Compression: 0.664577
# Article 260:	Length: 256	Compression: 0.445312	Avg Compression: 0.654104
# Article 270:	Length: 256	Compression: 0.601562	Avg Compression: 0.651709
# Article 280:	Length: 256	Compression: 0.628906	Avg Compression: 0.650715
# Article 290:	Length: 256	Compression: 0.765625	Avg Compression: 0.655516
# Article 300:	Length: 264	Compression: 0.515152	Avg Compression: 0.649718
# Article 310:	Length: 264	Compression: 0.651515	Avg Compression: 0.649790
# Article 320:	Length: 272	Compression: 0.496324	Avg Compression: 0.643764
# Article 330:	Length: 272	Compression: 0.382353	Avg Compression: 0.633889
# Article 340:	Length: 272	Compression: 0.481618	Avg Compression: 0.628346
# Article 350:	Length: 272	Compression: 0.481618	Avg Compression: 0.623192
# Article 360:	Length: 280	Compression: 0.510714	Avg Compression: 0.619267
# Article 370:	Length: 280	Compression: 0.485714	Avg Compression: 0.614764
# Article 380:	Length: 288	Compression: 0.656250	Avg Compression: 0.616155
# Article 390:	Length: 288	Compression: 0.458333	Avg Compression: 0.611036
# Article 400:	Length: 296	Compression: 0.395270	Avg Compression: 0.604076
# Article 410:	Length: 296	Compression: 0.422297	Avg Compression: 0.598395
# Article 420:	Length: 304	Compression: 0.440789	Avg Compression: 0.593494
# Article 430:	Length: 312	Compression: 0.458333	Avg Compression: 0.589314
# Article 440:	Length: 320	Compression: 0.584375	Avg Compression: 0.589162
# Article 450:	Length: 328	Compression: 0.320122	Avg Compression: 0.580943
# Article 460:	Length: 336	Compression: 0.419643	Avg Compression: 0.576048
# Article 470:	Length: 344	Compression: 0.386628	Avg Compression: 0.570340
# Article 480:	Length: 360	Compression: 0.358333	Avg Compression: 0.563859
# Article 490:	Length: 360	Compression: 0.580556	Avg Compression: 0.564354
# Article 500:	Length: 392	Compression: 0.321429	Avg Compression: 0.556753
# Article 510:	Length: 416	Compression: 0.415865	Avg Compression: 0.552225
# Article 520:	Length: 432	Compression: 0.335648	Avg Compression: 0.545230
# Article 530:	Length: 488	Compression: 0.272541	Avg Compression: 0.535632
# Article 540:	Length: 608	Compression: 0.246711	Avg Compression: 0.523494
# Article 550:	Length: 1696	Compression: 0.118514	Avg Compression: 0.481012
# Article 560:	Length: 2608	Compression: 0.105061	Avg Compression: 0.428792
# Article 570:	Length: 3256	Compression: 0.122236	Avg Compression: 0.383488
# Article 580:	Length: 4032	Compression: 0.140377	Avg Compression: 0.345879
# Article 590:	Length: 4616	Compression: 0.154679	Avg Compression: 0.317112
# Article 600:	Length: 5080	Compression: 0.159252	Avg Compression: 0.294687
# Article 610:	Length: 5552	Compression: 0.133465	Avg Compression: 0.273020
# Article 620:	Length: 5928	Compression: 0.190452	Avg Compression: 0.262659
# Article 630:	Length: 6480	Compression: 0.108642	Avg Compression: 0.244080
# Article 640:	Length: 6720	Compression: 0.136756	Avg Compression: 0.232148
# Article 650:	Length: 6960	Compression: 0.124282	Avg Compression: 0.221009
# Article 660:	Length: 7824	Compression: 0.111835	Avg Compression: 0.209654
# Article 670:	Length: 8360	Compression: 0.129426	Avg Compression: 0.201629
# Article 680:	Length: 8824	Compression: 0.110041	Avg Compression: 0.192884
# Article 690:	Length: 9288	Compression: 0.085810	Avg Compression: 0.183105
# Article 700:	Length: 9920	Compression: 0.123891	Avg Compression: 0.177842
# Article 710:	Length: 10552	Compression: 0.105193	Avg Compression: 0.171567
# Article 720:	Length: 11056	Compression: 0.133774	Avg Compression: 0.168431
# Article 730:	Length: 11776	Compression: 0.098081	Avg Compression: 0.162717
# Article 740:	Length: 12424	Compression: 0.138844	Avg Compression: 0.160833
# Article 750:	Length: 12944	Compression: 0.121910	Avg Compression: 0.157876
# Article 760:	Length: 13472	Compression: 0.123441	Avg Compression: 0.155352
# Article 770:	Length: 13888	Compression: 0.112039	Avg Compression: 0.152310
# Article 780:	Length: 14096	Compression: 0.117480	Avg Compression: 0.149992
# Article 790:	Length: 14800	Compression: 0.102162	Avg Compression: 0.146869
# Article 800:	Length: 15200	Compression: 0.105724	Avg Compression: 0.144283
# Article 810:	Length: 16024	Compression: 0.110959	Avg Compression: 0.142212
# Article 820:	Length: 16336	Compression: 0.105840	Avg Compression: 0.140045
# Article 830:	Length: 16904	Compression: 0.129614	Avg Compression: 0.139439
# Article 840:	Length: 17192	Compression: 0.113483	Avg Compression: 0.137991
# Article 850:	Length: 17632	Compression: 0.099025	Avg Compression: 0.135883
# Article 860:	Length: 17736	Compression: 0.103124	Avg Compression: 0.134193
# Article 870:	Length: 18048	Compression: 0.106771	Avg Compression: 0.132824
# Article 880:	Length: 19152	Compression: 0.108866	Avg Compression: 0.131619
# Article 890:	Length: 19320	Compression: 0.105435	Avg Compression: 0.130355
# Article 900:	Length: 20120	Compression: 0.108002	Avg Compression: 0.129285
# Article 910:	Length: 20368	Compression: 0.136440	Avg Compression: 0.129616
# Article 920:	Length: 20560	Compression: 0.103016	Avg Compression: 0.128430
# Article 930:	Length: 21408	Compression: 0.119208	Avg Compression: 0.128021
# Article 940:	Length: 22352	Compression: 0.111042	Avg Compression: 0.127269
# Article 950:	Length: 23192	Compression: 0.116506	Avg Compression: 0.126797
# Article 960:	Length: 23776	Compression: 0.129837	Avg Compression: 0.126928
# Article 970:	Length: 24192	Compression: 0.093006	Avg Compression: 0.125503
# Article 980:	Length: 25624	Compression: 0.111887	Avg Compression: 0.124924
# Article 990:	Length: 26680	Compression: 0.127849	Avg Compression: 0.125048
# Article 1000:	Length: 27224	Compression: 0.109940	Avg Compression: 0.124420
# Article 1010:	Length: 28328	Compression: 0.122070	Avg Compression: 0.124323
# Article 1020:	Length: 28416	Compression: 0.119193	Avg Compression: 0.124118
# Article 1030:	Length: 29016	Compression: 0.114592	Avg Compression: 0.123746
# Article 1040:	Length: 29920	Compression: 0.114873	Avg Compression: 0.123401
# Article 1050:	Length: 30600	Compression: 0.116340	Avg Compression: 0.123132
# Article 1060:	Length: 30488	Compression: 0.109092	Avg Compression: 0.122618
# Article 1070:	Length: 32032	Compression: 0.095810	Avg Compression: 0.121624
# Article 1080:	Length: 33016	Compression: 0.115368	Avg Compression: 0.121394
# Article 1090:	Length: 33472	Compression: 0.111317	Avg Compression: 0.121032
# Article 1100:	Length: 34536	Compression: 0.096942	Avg Compression: 0.120170
# Article 1110:	Length: 35264	Compression: 0.113373	Avg Compression: 0.119931
# Article 1120:	Length: 35736	Compression: 0.109302	Avg Compression: 0.119564
# Article 1130:	Length: 36448	Compression: 0.093613	Avg Compression: 0.118683
# Article 1140:	Length: 37448	Compression: 0.117523	Avg Compression: 0.118644
# Article 1150:	Length: 37904	Compression: 0.128746	Avg Compression: 0.118977
# Article 1160:	Length: 38680	Compression: 0.109643	Avg Compression: 0.118673
# Article 1170:	Length: 40216	Compression: 0.123558	Avg Compression: 0.118833
# Article 1180:	Length: 41480	Compression: 0.118370	Avg Compression: 0.118818
# Article 1190:	Length: 42616	Compression: 0.120330	Avg Compression: 0.118867
# Article 1200:	Length: 43488	Compression: 0.109938	Avg Compression: 0.118580
# Article 1210:	Length: 45080	Compression: 0.117547	Avg Compression: 0.118547
# Article 1220:	Length: 46864	Compression: 0.116230	Avg Compression: 0.118472
# Article 1230:	Length: 48608	Compression: 0.100889	Avg Compression: 0.117901
# Article 1240:	Length: 50264	Compression: 0.108149	Avg Compression: 0.117583
# Article 1250:	Length: 51272	Compression: 0.114975	Avg Compression: 0.117500
# Article 1260:	Length: 52528	Compression: 0.111179	Avg Compression: 0.117298
# Article 1270:	Length: 53688	Compression: 0.110378	Avg Compression: 0.117080
# Article 1280:	Length: 54640	Compression: 0.098335	Avg Compression: 0.116497
# Article 1290:	Length: 55440	Compression: 0.084993	Avg Compression: 0.115534
# Article 1300:	Length: 56320	Compression: 0.107049	Avg Compression: 0.115279
# Article 1310:	Length: 58648	Compression: 0.104692	Avg Compression: 0.114957
# Article 1320:	Length: 60504	Compression: 0.115976	Avg Compression: 0.114988
# Article 1330:	Length: 62376	Compression: 0.077562	Avg Compression: 0.113849
# Article 1340:	Length: 63840	Compression: 0.105623	Avg Compression: 0.113601
# Article 1350:	Length: 65976	Compression: 0.106872	Avg Compression: 0.113397
# Article 1360:	Length: 67128	Compression: 0.097858	Avg Compression: 0.112933
# Article 1370:	Length: 68800	Compression: 0.108794	Avg Compression: 0.112810
# Article 1380:	Length: 70576	Compression: 0.108748	Avg Compression: 0.112690
# Article 1390:	Length: 72432	Compression: 0.079675	Avg Compression: 0.111718
# Article 1400:	Length: 74752	Compression: 0.101348	Avg Compression: 0.111412
# Article 1410:	Length: 75792	Compression: 0.098586	Avg Compression: 0.111040
# Article 1420:	Length: 78368	Compression: 0.114192	Avg Compression: 0.111132
# Article 1430:	Length: 80136	Compression: 0.086041	Avg Compression: 0.110406
# Article 1440:	Length: 81808	Compression: 0.095345	Avg Compression: 0.109973
# Article 1450:	Length: 84736	Compression: 0.080532	Avg Compression: 0.109123
# Article 1460:	Length: 87880	Compression: 0.079062	Avg Compression: 0.108250
# Article 1470:	Length: 88760	Compression: 0.090660	Avg Compression: 0.107748
# Article 1480:	Length: 89704	Compression: 0.098446	Avg Compression: 0.107487
# Article 1490:	Length: 91864	Compression: 0.093758	Avg Compression: 0.107104
# Article 1500:	Length: 94344	Compression: 0.103356	Avg Compression: 0.107000
# Article 1510:	Length: 97160	Compression: 0.094885	Avg Compression: 0.106662
# Article 1520:	Length: 98752	Compression: 0.081983	Avg Compression: 0.105982
# Article 1530:	Length: 101024	Compression: 0.085019	Avg Compression: 0.105408
# Article 1540:	Length: 103016	Compression: 0.083861	Avg Compression: 0.104822
# Article 1550:	Length: 106432	Compression: 0.109413	Avg Compression: 0.104947
# Article 1560:	Length: 107664	Compression: 0.085107	Avg Compression: 0.104413
# Article 1570:	Length: 109952	Compression: 0.103736	Avg Compression: 0.104395
# Article 1580:	Length: 112616	Compression: 0.085965	Avg Compression: 0.103904
# Article 1590:	Length: 115984	Compression: 0.088521	Avg Compression: 0.103493
# Article 1600:	Length: 118032	Compression: 0.099143	Avg Compression: 0.103378
# Article 1610:	Length: 120872	Compression: 0.085694	Avg Compression: 0.102911
# Article 1620:	Length: 123248	Compression: 0.095158	Avg Compression: 0.102708
# Article 1630:	Length: 125152	Compression: 0.098368	Avg Compression: 0.102595
# Article 1640:	Length: 128960	Compression: 0.084166	Avg Compression: 0.102116
# Article 1650:	Length: 132816	Compression: 0.099687	Avg Compression: 0.102052
# Article 1660:	Length: 134584	Compression: 0.084869	Avg Compression: 0.101610
# Article 1670:	Length: 141472	Compression: 0.099829	Avg Compression: 0.101563
# Article 1680:	Length: 146472	Compression: 0.104866	Avg Compression: 0.101650
# Article 1690:	Length: 151840	Compression: 0.103194	Avg Compression: 0.101692
# Article 1700:	Length: 157048	Compression: 0.112889	Avg Compression: 0.101994
# Article 1710:	Length: 161424	Compression: 0.129838	Avg Compression: 0.102745
# Article 1720:	Length: 164208	Compression: 0.137509	Avg Compression: 0.103674
# Article 1730:	Length: 174464	Compression: 0.136366	Avg Compression: 0.104576
# Article 1740:	Length: 189072	Compression: 0.099967	Avg Compression: 0.104442
# Article 1750:	Length: 195080	Compression: 0.116470	Avg Compression: 0.104792
# Article 1760:	Length: 202592	Compression: 0.123312	Avg Compression: 0.105336
# Article 1770:	Length: 213160	Compression: 0.120412	Avg Compression: 0.105787
# Article 1780:	Length: 220440	Compression: 0.135638	Avg Compression: 0.106683
# Article 1790:	Length: 229744	Compression: 0.137758	Avg Compression: 0.107626
# Article 1800:	Length: 246304	Compression: 0.124821	Avg Compression: 0.108168
# Article 1810:	Length: 251304	Compression: 0.132302	Avg Compression: 0.108920
# Article 1820:	Length: 268336	Compression: 0.129099	Avg Compression: 0.109569
# Article 1830:	Length: 283192	Compression: 0.110702	Avg Compression: 0.109606
# Article 1840:	Length: 307368	Compression: 0.138778	Avg Compression: 0.110611
# Article 1850:	Length: 323168	Compression: 0.115636	Avg Compression: 0.110786
# Article 1860:	Length: 341176	Compression: 0.127386	Avg Compression: 0.111377
# Article 1870:	Length: 382048	Compression: 0.123500	Avg Compression: 0.111841
# Article 1880:	Length: 441872	Compression: 0.104367	Avg Compression: 0.111524
# Article 1890:	Length: 508896	Compression: 0.122271	Avg Compression: 0.112025

# %%
def loss(labels, logits):
    return tf.keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)

def average_final_batch_ratio(true_labels, predictions):
    return 0 ** tf.math.abs(true_labels[-1, -1])

class ModelStateResetter(tf.keras.callbacks.Callback):
    def __init__(self):
        pass

    def on_epoch_begin(self, epoch, logs=None):
        self.last_final_batch_count = 0
        
    def on_batch_end(self, batch, logs={}):
        average_final_batch_ratio = logs.get('average_final_batch_ratio', 0)
        final_batch_count = int(round(average_final_batch_ratio * (batch + 1)))
        is_final = final_batch_count - self.last_final_batch_count
        self.last_final_batch_count = final_batch_count
        
        if is_final:
            self.model.reset_states()

class Model:
    def __init__(self, articles, checkpoint_dir, vocab_size, embedding_dim, rnn_units):
        self._articles = articles
        self._batch_size = None
        self._batched_item_length = None
        self._training_model = None
        self._predicting_model = None
        self._vocab_size = vocab_size
        self._embedding_dim = embedding_dim
        self._rnn_units = rnn_units

        self._checkpoint_dir = checkpoint_dir
        self._checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt_{epoch}") # Name of the checkpoint files

    def training_model(self, batch_size, batched_item_length):
        if self._training_model == None or batch_size != self._batch_size or batched_item_length != self._batched_item_length:
            self._batch_size = batch_size
            self._batched_item_length = batched_item_length
            self._training_model = tf.keras.Sequential([
                tf.keras.layers.Masking(mask_value=0, batch_input_shape=[batch_size, batched_item_length]),
                tf.keras.layers.Embedding(self._vocab_size, self._embedding_dim),
                tf.keras.layers.GRU(self._rnn_units, return_sequences=True, stateful=True, recurrent_initializer='glorot_uniform'),
                tf.keras.layers.GRU(self._rnn_units, return_sequences=True, stateful=True, recurrent_initializer='glorot_uniform'),
                tf.keras.layers.Dense(self._vocab_size),
            ])

            if os.path.isdir(self._checkpoint_dir):
                self._training_model.load_weights(tf.train.latest_checkpoint(self._checkpoint_dir))

            self._training_model.compile(optimizer='adam', loss=loss, metrics=[average_final_batch_ratio])
            self._predicting_model = None
        
        return self._training_model

    @property
    def callbacks(self):
        checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=self._checkpoint_prefix, save_weights_only=True)
        model_state_resetter_callback = ModelStateResetter()
        
        return [checkpoint_callback, model_state_resetter_callback]
    
    def train(self, batch_size, batched_item_length, epochs=1):
        dataset = self._articles.dataset(batch_size, batched_item_length)

        model = self.training_model(batch_size, batched_item_length)

        model.fit(dataset, epochs=epochs, callbacks=self.callbacks)
    
    @property
    def predicting_model(self):
        if self._predicting_model == None:
            self._predicting_model = tf.keras.Sequential([
                tf.keras.layers.Masking(mask_value=0, batch_input_shape=[1, 1]),
                tf.keras.layers.Embedding(self._vocab_size, self._embedding_dim),
                tf.keras.layers.GRU(self._rnn_units, stateful=True, return_sequences=True),
                tf.keras.layers.GRU(self._rnn_units, stateful=True, return_sequences=True),
                tf.keras.layers.Dense(self._vocab_size),
            ])
            
            self._predicting_model.load_weights(tf.train.latest_checkpoint(self._checkpoint_dir))
            self._training_model = None
        
        return self._predicting_model
    
    def predict(self, input_eval):
        return self.predicting_model(input_eval)

# %%
model = Model(articles, './training_checkpoints-15',
              vocab_size = subword_text_encoder.vocab_size,
              embedding_dim=512,
              rnn_units=1024)

# %%
model.training_model(192, 256).summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# masking_1 (Masking)          (192, 256)                0
# _________________________________________________________________
# embedding_1 (Embedding)      (192, 256, 512)           2072576
# _________________________________________________________________
# gru_2 (GRU)                  (192, 256, 1024)          4724736
# _________________________________________________________________
# gru_3 (GRU)                  (192, 256, 1024)          6297600
# _________________________________________________________________
# dense_1 (Dense)              (192, 256, 4048)          4149200
# =================================================================
# Total params: 17,244,112
# Trainable params: 17,244,112
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.train(192, 256, epochs=50)
# Out:
# Epoch 1/50
# 203/203 [==============================] - 165s 815ms/step - loss: 3.9912 - average_final_batch_ratio: 0.1182
# Epoch 2/50
# 203/203 [==============================] - 166s 816ms/step - loss: 3.0434 - average_final_batch_ratio: 0.1182
# Epoch 3/50
#   1/203 [..............................] - ETA: 2:46
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-18-38c1121ca254> in <module>
# ----> 1 model.train(192, 256, epochs=50)
#
# <ipython-input-15-74936f3ed6d5> in train(self, batch_size, batched_item_length, epochs)
#      67         model = self.training_model(batch_size, batched_item_length)
#      68
# ---> 69         model.fit(dataset, epochs=epochs, callbacks=self.callbacks)
#      70
#      71     @property
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     395                       total_epochs=1)
#     396                   cbks.make_logs(model, epoch_logs, eval_result, ModeKeys.TEST,
# --> 397                                  prefix='val_')
#     398
#     399     return model.history
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\contextlib.py in __exit__(self, type, value, traceback)
#     128                 value = type()
#     129             try:
# --> 130                 self.gen.throw(type, value, traceback)
#     131             except StopIteration as exc:
#     132                 # Suppress StopIteration *unless* it's the same exception that
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in on_epoch(self, epoch, mode)
#     769       if mode == ModeKeys.TRAIN:
#     770         # Epochs only apply to `fit`.
# --> 771         self.callbacks.on_epoch_end(epoch, epoch_logs)
#     772       self.progbar.on_epoch_end(epoch, epoch_logs)
#     773
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     300     logs = logs or {}
#     301     for callback in self.callbacks:
# --> 302       callback.on_epoch_end(epoch, logs)
#     303
#     304   def on_train_batch_begin(self, batch, logs=None):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     990           self._save_model(epoch=epoch, logs=logs)
#     991       else:
# --> 992         self._save_model(epoch=epoch, logs=logs)
#     993     if self.model._in_multi_worker_mode():
#     994       # For multi-worker training, back up the weights and current training
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\callbacks.py in _save_model(self, epoch, logs)
#    1036             print('\nEpoch %05d: saving model to %s' % (epoch + 1, filepath))
#    1037           if self.save_weights_only:
# -> 1038             self.model.save_weights(filepath, overwrite=True)
#    1039           else:
#    1040             self.model.save(filepath, overwrite=True)
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\network.py in save_weights(self, filepath, overwrite, save_format)
#    1121              'saved.\n\nConsider using a TensorFlow optimizer from `tf.train`.')
#    1122             % (optimizer,))
# -> 1123       self._trackable_saver.save(filepath, session=session)
#    1124       # Record this checkpoint so it's visible from tf.train.latest_checkpoint.
#    1125       checkpoint_management.update_checkpoint_state_internal(
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\tracking\util.py in save(self, file_prefix, checkpoint_number, session)
#    1166     file_io.recursive_create_dir(os.path.dirname(file_prefix))
#    1167     save_path, new_feed_additions = self._save_cached_when_graph_building(
# -> 1168         file_prefix=file_prefix_tensor, object_graph_tensor=object_graph_tensor)
#    1169     if new_feed_additions:
#    1170       feed_dict.update(new_feed_additions)
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\tracking\util.py in _save_cached_when_graph_building(self, file_prefix, object_graph_tensor)
#    1114         or context.executing_eagerly() or ops.inside_function()):
#    1115       saver = functional_saver.MultiDeviceSaver(named_saveable_objects)
# -> 1116       save_op = saver.save(file_prefix)
#    1117       with ops.device("/cpu:0"):
#    1118         with ops.control_dependencies([save_op]):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\functional_saver.py in save(self, file_prefix)
#     228         # _SingleDeviceSaver will use the CPU device when necessary, but initial
#     229         # read operations should be placed on the SaveableObject's device.
# --> 230         sharded_saves.append(saver.save(shard_prefix))
#     231
#     232     with ops.control_dependencies(sharded_saves):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\functional_saver.py in save(self, file_prefix)
#      67       for spec in saveable.specs:
#      68         tensor_names.append(spec.name)
# ---> 69         tensors.append(spec.tensor)
#      70         tensor_slices.append(spec.slice_spec)
#      71     with ops.device("cpu:0"):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\saveable_object.py in tensor(self)
#      50   @property
#      51   def tensor(self):
# ---> 52     return self._tensor() if callable(self._tensor) else self._tensor
#      53
#      54
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\saveable_object_util.py in f()
#      93             # we copy them to CPU on the same machine first.
#      94             with ops.device("/device:CPU:0"):
# ---> 95               return array_ops.identity(x)
#      96         return f
#      97
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\util\dispatch.py in wrapper(*args, **kwargs)
#     178     """Call target, and fall back on dispatchers if there is a TypeError."""
#     179     try:
# --> 180       return target(*args, **kwargs)
#     181     except (TypeError, ValueError):
#     182       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\ops\array_ops.py in identity(input, name)
#     265     # variables. Variables have correct handle data when graph building.
#     266     input = ops.convert_to_tensor(input)
# --> 267   ret = gen_array_ops.identity(input, name=name)
#     268   # Propagate handle data for happier shape inference for resource variables.
#     269   if hasattr(input, "_handle_data"):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\ops\gen_array_ops.py in identity(input, name)
#    3824         pass  # Add nodes to the TensorFlow graph.
#    3825     except _core._NotOkStatusException as e:
# -> 3826       _ops.raise_from_not_ok_status(e, name)
#    3827   # Add nodes to the TensorFlow graph.
#    3828   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\framework\ops.py in raise_from_not_ok_status(e, name)
#    6604   message = e.message + (" name: " + name if name is not None else "")
#    6605   # pylint: disable=protected-access
# -> 6606   six.raise_from(core._status_to_exception(e.code, message), None)
#    6607   # pylint: enable=protected-access
#    6608
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\six.py in raise_from(value, from_value)
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:GPU:0 to /job:localhost/replica:0/task:0/device:CPU:0 in order to run Identity: GPU sync failed [Op:Identity]

# %%
model.train(192, 256, epochs=48)
# Out:
# Epoch 1/48
# 203/203 [==============================] - 168s 826ms/step - loss: 2.8710 - average_final_batch_ratio: 0.1182
# Epoch 2/48
#   1/203 [..............................] - ETA: 41s
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-12-8ff307265f06> in <module>
# ----> 1 model.train(192, 256, epochs=48)
#
# <ipython-input-3-74936f3ed6d5> in train(self, batch_size, batched_item_length, epochs)
#      67         model = self.training_model(batch_size, batched_item_length)
#      68
# ---> 69         model.fit(dataset, epochs=epochs, callbacks=self.callbacks)
#      70
#      71     @property
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     395                       total_epochs=1)
#     396                   cbks.make_logs(model, epoch_logs, eval_result, ModeKeys.TEST,
# --> 397                                  prefix='val_')
#     398
#     399     return model.history
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\contextlib.py in __exit__(self, type, value, traceback)
#     128                 value = type()
#     129             try:
# --> 130                 self.gen.throw(type, value, traceback)
#     131             except StopIteration as exc:
#     132                 # Suppress StopIteration *unless* it's the same exception that
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in on_epoch(self, epoch, mode)
#     769       if mode == ModeKeys.TRAIN:
#     770         # Epochs only apply to `fit`.
# --> 771         self.callbacks.on_epoch_end(epoch, epoch_logs)
#     772       self.progbar.on_epoch_end(epoch, epoch_logs)
#     773
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     300     logs = logs or {}
#     301     for callback in self.callbacks:
# --> 302       callback.on_epoch_end(epoch, logs)
#     303
#     304   def on_train_batch_begin(self, batch, logs=None):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     990           self._save_model(epoch=epoch, logs=logs)
#     991       else:
# --> 992         self._save_model(epoch=epoch, logs=logs)
#     993     if self.model._in_multi_worker_mode():
#     994       # For multi-worker training, back up the weights and current training
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\callbacks.py in _save_model(self, epoch, logs)
#    1036             print('\nEpoch %05d: saving model to %s' % (epoch + 1, filepath))
#    1037           if self.save_weights_only:
# -> 1038             self.model.save_weights(filepath, overwrite=True)
#    1039           else:
#    1040             self.model.save(filepath, overwrite=True)
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\network.py in save_weights(self, filepath, overwrite, save_format)
#    1121              'saved.\n\nConsider using a TensorFlow optimizer from `tf.train`.')
#    1122             % (optimizer,))
# -> 1123       self._trackable_saver.save(filepath, session=session)
#    1124       # Record this checkpoint so it's visible from tf.train.latest_checkpoint.
#    1125       checkpoint_management.update_checkpoint_state_internal(
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\tracking\util.py in save(self, file_prefix, checkpoint_number, session)
#    1166     file_io.recursive_create_dir(os.path.dirname(file_prefix))
#    1167     save_path, new_feed_additions = self._save_cached_when_graph_building(
# -> 1168         file_prefix=file_prefix_tensor, object_graph_tensor=object_graph_tensor)
#    1169     if new_feed_additions:
#    1170       feed_dict.update(new_feed_additions)
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\tracking\util.py in _save_cached_when_graph_building(self, file_prefix, object_graph_tensor)
#    1114         or context.executing_eagerly() or ops.inside_function()):
#    1115       saver = functional_saver.MultiDeviceSaver(named_saveable_objects)
# -> 1116       save_op = saver.save(file_prefix)
#    1117       with ops.device("/cpu:0"):
#    1118         with ops.control_dependencies([save_op]):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\functional_saver.py in save(self, file_prefix)
#     228         # _SingleDeviceSaver will use the CPU device when necessary, but initial
#     229         # read operations should be placed on the SaveableObject's device.
# --> 230         sharded_saves.append(saver.save(shard_prefix))
#     231
#     232     with ops.control_dependencies(sharded_saves):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\functional_saver.py in save(self, file_prefix)
#      67       for spec in saveable.specs:
#      68         tensor_names.append(spec.name)
# ---> 69         tensors.append(spec.tensor)
#      70         tensor_slices.append(spec.slice_spec)
#      71     with ops.device("cpu:0"):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\saveable_object.py in tensor(self)
#      50   @property
#      51   def tensor(self):
# ---> 52     return self._tensor() if callable(self._tensor) else self._tensor
#      53
#      54
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\saveable_object_util.py in f()
#      93             # we copy them to CPU on the same machine first.
#      94             with ops.device("/device:CPU:0"):
# ---> 95               return array_ops.identity(x)
#      96         return f
#      97
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\util\dispatch.py in wrapper(*args, **kwargs)
#     178     """Call target, and fall back on dispatchers if there is a TypeError."""
#     179     try:
# --> 180       return target(*args, **kwargs)
#     181     except (TypeError, ValueError):
#     182       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\ops\array_ops.py in identity(input, name)
#     265     # variables. Variables have correct handle data when graph building.
#     266     input = ops.convert_to_tensor(input)
# --> 267   ret = gen_array_ops.identity(input, name=name)
#     268   # Propagate handle data for happier shape inference for resource variables.
#     269   if hasattr(input, "_handle_data"):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\ops\gen_array_ops.py in identity(input, name)
#    3824         pass  # Add nodes to the TensorFlow graph.
#    3825     except _core._NotOkStatusException as e:
# -> 3826       _ops.raise_from_not_ok_status(e, name)
#    3827   # Add nodes to the TensorFlow graph.
#    3828   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\framework\ops.py in raise_from_not_ok_status(e, name)
#    6604   message = e.message + (" name: " + name if name is not None else "")
#    6605   # pylint: disable=protected-access
# -> 6606   six.raise_from(core._status_to_exception(e.code, message), None)
#    6607   # pylint: enable=protected-access
#    6608
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\six.py in raise_from(value, from_value)
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:GPU:0 to /job:localhost/replica:0/task:0/device:CPU:0 in order to run Identity: GPU sync failed [Op:Identity]

# %%
model.train(192, 256, epochs=47)
# Out:
# Epoch 1/47
# 203/203 [==============================] - 167s 823ms/step - loss: 2.5273 - average_final_batch_ratio: 0.1182
# Epoch 2/47
# 203/203 [==============================] - 165s 813ms/step - loss: 2.3137 - average_final_batch_ratio: 0.1182
# Epoch 3/47
# 203/203 [==============================] - 165s 814ms/step - loss: 2.1469 - average_final_batch_ratio: 0.1182
# Epoch 4/47

# %% [markdown]
# Моделът забива няколко поредни пъти при обучение. Не успях да дебъгна проблема.

# %%
def loss(labels, logits):
    return tf.keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)

def average_final_batch_ratio(true_labels, predictions):
    return 0 ** tf.math.abs(true_labels[-1, -1])

class ModelStateResetter(tf.keras.callbacks.Callback):
    def __init__(self):
        pass

    def on_epoch_begin(self, epoch, logs=None):
        self.last_final_batch_count = 0
        
    def on_batch_end(self, batch, logs={}):
        average_final_batch_ratio = logs.get('average_final_batch_ratio', 0)
        final_batch_count = int(round(average_final_batch_ratio * (batch + 1)))
        is_final = final_batch_count - self.last_final_batch_count
        self.last_final_batch_count = final_batch_count
        
        if is_final:
            self.model.reset_states()

class Model:
    def __init__(self, articles, checkpoint_dir, vocab_size, embedding_dim, rnn_units):
        self._articles = articles
        self._batch_size = None
        self._batched_item_length = None
        self._training_model = None
        self._predicting_model = None
        self._vocab_size = vocab_size
        self._embedding_dim = embedding_dim
        self._rnn_units = rnn_units

        self._checkpoint_dir = checkpoint_dir
        self._checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt_{epoch}") # Name of the checkpoint files

    def training_model(self, batch_size, batched_item_length):
        if self._training_model == None or batch_size != self._batch_size or batched_item_length != self._batched_item_length:
            self._batch_size = batch_size
            self._batched_item_length = batched_item_length
            self._training_model = tf.keras.Sequential([
                tf.keras.layers.Masking(mask_value=0, batch_input_shape=[batch_size, batched_item_length]),
                tf.keras.layers.Embedding(self._vocab_size, self._embedding_dim),
                tf.keras.layers.LSTM(self._rnn_units, return_sequences=True, stateful=True, recurrent_initializer='glorot_uniform'),
                tf.keras.layers.LSTM(self._rnn_units // 2, return_sequences=True, stateful=True, recurrent_initializer='glorot_uniform'),
                tf.keras.layers.Dense(self._vocab_size),
            ])

            if os.path.isdir(self._checkpoint_dir):
                self._training_model.load_weights(tf.train.latest_checkpoint(self._checkpoint_dir))

            self._training_model.compile(optimizer='adam', loss=loss, metrics=[average_final_batch_ratio])
            self._predicting_model = None
        
        return self._training_model

    @property
    def callbacks(self):
        checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=self._checkpoint_prefix, save_weights_only=True)
        model_state_resetter_callback = ModelStateResetter()
        
        return [checkpoint_callback, model_state_resetter_callback]
    
    def train(self, batch_size, batched_item_length, epochs=1):
        dataset = self._articles.dataset(batch_size, batched_item_length)

        model = self.training_model(batch_size, batched_item_length)

        model.fit(dataset, epochs=epochs, callbacks=self.callbacks)
    
    @property
    def predicting_model(self):
        if self._predicting_model == None:
            self._predicting_model = tf.keras.Sequential([
                tf.keras.layers.Masking(mask_value=0, batch_input_shape=[1, 1]),
                tf.keras.layers.Embedding(self._vocab_size, self._embedding_dim),
                tf.keras.layers.LSTM(self._rnn_units, stateful=True, return_sequences=True),
                tf.keras.layers.LSTM(self._rnn_units // 2, stateful=True, return_sequences=True),
                tf.keras.layers.Dense(self._vocab_size),
            ])
            
            self._predicting_model.load_weights(tf.train.latest_checkpoint(self._checkpoint_dir))
            self._training_model = None
        
        return self._predicting_model
    
    def predict(self, input_eval):
        return self.predicting_model(input_eval)

# %%
model = Model(articles, './training_checkpoints-16',
              vocab_size = subword_text_encoder.vocab_size,
              embedding_dim=256,
              rnn_units=1024)

# %%
model.training_model(192, 256).summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# masking_2 (Masking)          (192, 256)                0
# _________________________________________________________________
# embedding_2 (Embedding)      (192, 256, 256)           1036288
# _________________________________________________________________
# lstm_4 (LSTM)                (192, 256, 1024)          5246976
# _________________________________________________________________
# lstm_5 (LSTM)                (192, 256, 512)           3147776
# _________________________________________________________________
# dense_2 (Dense)              (192, 256, 4048)          2076624
# =================================================================
# Total params: 11,507,664
# Trainable params: 11,507,664
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.train(192, 256, epochs=50)
# Out:
# Epoch 1/50
# 203/203 [==============================] - 117s 579ms/step - loss: 4.4659 - average_final_batch_ratio: 0.1182
# Epoch 2/50
# 203/203 [==============================] - 116s 574ms/step - loss: 4.2034 - average_final_batch_ratio: 0.1182
# Epoch 3/50
# 203/203 [==============================] - 118s 581ms/step - loss: 4.1400 - average_final_batch_ratio: 0.1182
# Epoch 4/50
# 203/203 [==============================] - 115s 568ms/step - loss: 4.0855 - average_final_batch_ratio: 0.1182
# Epoch 5/50
# 203/203 [==============================] - 116s 572ms/step - loss: 4.2143 - average_final_batch_ratio: 0.1182
# Epoch 6/50
# 203/203 [==============================] - 116s 570ms/step - loss: 3.6487 - average_final_batch_ratio: 0.1182
# Epoch 7/50
# 203/203 [==============================] - 117s 574ms/step - loss: 3.0859 - average_final_batch_ratio: 0.1182
# Epoch 8/50
# 203/203 [==============================] - 117s 575ms/step - loss: 2.8203 - average_final_batch_ratio: 0.1182
# Epoch 9/50
# 203/203 [==============================] - 117s 575ms/step - loss: 2.6490 - average_final_batch_ratio: 0.1182
# Epoch 10/50
# 203/203 [==============================] - 118s 580ms/step - loss: 2.5272 - average_final_batch_ratio: 0.1182
# Epoch 11/50
# 203/203 [==============================] - 116s 572ms/step - loss: 2.4275 - average_final_batch_ratio: 0.1182
# Epoch 12/50
# 203/203 [==============================] - 116s 574ms/step - loss: 2.3467 - average_final_batch_ratio: 0.1182
# Epoch 13/50
# 203/203 [==============================] - 116s 573ms/step - loss: 2.2680 - average_final_batch_ratio: 0.1182
# Epoch 14/50
# 203/203 [==============================] - 117s 575ms/step - loss: 2.2009 - average_final_batch_ratio: 0.1182
# Epoch 15/50
# 203/203 [==============================] - 117s 576ms/step - loss: 2.1350 - average_final_batch_ratio: 0.1182
# Epoch 16/50
# 203/203 [==============================] - 117s 575ms/step - loss: 2.0801 - average_final_batch_ratio: 0.1182
# Epoch 17/50
# 203/203 [==============================] - 118s 580ms/step - loss: 2.0301 - average_final_batch_ratio: 0.1182
# Epoch 18/50
# 203/203 [==============================] - 116s 572ms/step - loss: 1.9892 - average_final_batch_ratio: 0.1182
# Epoch 19/50
# 203/203 [==============================] - 116s 574ms/step - loss: 1.9458 - average_final_batch_ratio: 0.1182
# Epoch 20/50
# 203/203 [==============================] - 116s 574ms/step - loss: 1.9068 - average_final_batch_ratio: 0.1182
# Epoch 21/50
# 203/203 [==============================] - 117s 575ms/step - loss: 1.8720 - average_final_batch_ratio: 0.1182
# Epoch 22/50
# 203/203 [==============================] - 117s 576ms/step - loss: 1.8402 - average_final_batch_ratio: 0.1182
# Epoch 23/50
# 203/203 [==============================] - 117s 575ms/step - loss: 1.8104 - average_final_batch_ratio: 0.1182
# Epoch 24/50
# 203/203 [==============================] - 118s 581ms/step - loss: 1.7804 - average_final_batch_ratio: 0.1182
# Epoch 25/50
# 203/203 [==============================] - 116s 573ms/step - loss: 1.7549 - average_final_batch_ratio: 0.1182
# Epoch 26/50
# 203/203 [==============================] - 117s 574ms/step - loss: 1.7283 - average_final_batch_ratio: 0.1182
# Epoch 27/50
# 203/203 [==============================] - 116s 574ms/step - loss: 1.7030 - average_final_batch_ratio: 0.1182
# Epoch 28/50
# 203/203 [==============================] - 117s 575ms/step - loss: 1.6835 - average_final_batch_ratio: 0.1182
# Epoch 29/50
# 203/203 [==============================] - 117s 575ms/step - loss: 1.6633 - average_final_batch_ratio: 0.1182
# Epoch 30/50
# 203/203 [==============================] - 117s 576ms/step - loss: 1.6403 - average_final_batch_ratio: 0.1182
# Epoch 31/50
# 203/203 [==============================] - 118s 581ms/step - loss: 1.6222 - average_final_batch_ratio: 0.1182
# Epoch 32/50
# 203/203 [==============================] - 116s 572ms/step - loss: 1.6040 - average_final_batch_ratio: 0.1182
# Epoch 33/50
# 203/203 [==============================] - 117s 575ms/step - loss: 1.5872 - average_final_batch_ratio: 0.1182
# Epoch 34/50
# 203/203 [==============================] - 117s 574ms/step - loss: 1.5690 - average_final_batch_ratio: 0.1182
# Epoch 35/50
# 203/203 [==============================] - 117s 576ms/step - loss: 1.5567 - average_final_batch_ratio: 0.1182
# Epoch 36/50
# 203/203 [==============================] - 117s 577ms/step - loss: 1.5378 - average_final_batch_ratio: 0.1182
# Epoch 37/50
# 203/203 [==============================] - 117s 576ms/step - loss: 1.5215 - average_final_batch_ratio: 0.1182
# Epoch 38/50
# 203/203 [==============================] - 118s 581ms/step - loss: 1.5045 - average_final_batch_ratio: 0.1182
# Epoch 39/50
# 203/203 [==============================] - 116s 573ms/step - loss: 1.4933 - average_final_batch_ratio: 0.1182
# Epoch 40/50
# 203/203 [==============================] - 117s 575ms/step - loss: 1.4792 - average_final_batch_ratio: 0.1182
# Epoch 41/50
# 203/203 [==============================] - 117s 574ms/step - loss: 1.4659 - average_final_batch_ratio: 0.1182
# Epoch 42/50
# 203/203 [==============================] - 117s 576ms/step - loss: 1.4531 - average_final_batch_ratio: 0.1182
# Epoch 43/50
# 203/203 [==============================] - 117s 576ms/step - loss: 1.4394 - average_final_batch_ratio: 0.1182
# Epoch 44/50
# 203/203 [==============================] - 117s 576ms/step - loss: 1.4301 - average_final_batch_ratio: 0.1182
# Epoch 45/50
# 203/203 [==============================] - 118s 581ms/step - loss: 1.4107 - average_final_batch_ratio: 0.1182
# Epoch 46/50
# 203/203 [==============================] - 116s 573ms/step - loss: 1.4073 - average_final_batch_ratio: 0.1182
# Epoch 47/50
# 203/203 [==============================] - 117s 575ms/step - loss: 1.3915 - average_final_batch_ratio: 0.1182
# Epoch 48/50
# 203/203 [==============================] - 117s 574ms/step - loss: 1.3835 - average_final_batch_ratio: 0.1182
# Epoch 49/50
# 203/203 [==============================] - 117s 576ms/step - loss: 1.3696 - average_final_batch_ratio: 0.1182
# Epoch 50/50
# 203/203 [==============================] - 117s 576ms/step - loss: 1.3555 - average_final_batch_ratio: 0.1182

# %%
total_raw = 0
total_compressed = 0

for index, encoded_article in enumerate(articles.articles_generator(1)):
    if index % 10 == 0:
        article = subword_text_encoder.decode(encoded_article)
        raw = len(article) * 8
        if raw == 0:
            continue
        compressed, _ = huffman_archive_size(model, encoded_article)
        total_raw += raw
        total_compressed += compressed

        print('Article %d:\tLength: %d\tCompression: %f\tAvg Compression: %f' % (index, raw, compressed/raw, total_compressed/total_raw))
# Out:
# Article 0:	Length: 128	Compression: 0.820312	Avg Compression: 0.820312
# Article 10:	Length: 144	Compression: 0.715278	Avg Compression: 0.764706
# Article 20:	Length: 152	Compression: 0.598684	Avg Compression: 0.705189
# Article 30:	Length: 160	Compression: 0.556250	Avg Compression: 0.664384
# Article 40:	Length: 160	Compression: 0.731250	Avg Compression: 0.678763
# Article 50:	Length: 168	Compression: 0.648810	Avg Compression: 0.673246
# Article 60:	Length: 168	Compression: 0.642857	Avg Compression: 0.668519
# Article 70:	Length: 176	Compression: 0.920455	Avg Compression: 0.703822
# Article 80:	Length: 176	Compression: 0.676136	Avg Compression: 0.700419
# Article 90:	Length: 184	Compression: 0.586957	Avg Compression: 0.687500
# Article 100:	Length: 184	Compression: 0.630435	Avg Compression: 0.681667
# Article 110:	Length: 192	Compression: 0.744792	Avg Compression: 0.687751
# Article 120:	Length: 192	Compression: 0.552083	Avg Compression: 0.675824
# Article 130:	Length: 200	Compression: 0.665000	Avg Compression: 0.674916
# Article 140:	Length: 200	Compression: 0.575000	Avg Compression: 0.667183
# Article 150:	Length: 208	Compression: 0.706731	Avg Compression: 0.670129
# Article 160:	Length: 208	Compression: 0.586538	Avg Compression: 0.664333
# Article 170:	Length: 216	Compression: 0.569444	Avg Compression: 0.657960
# Article 180:	Length: 216	Compression: 0.662037	Avg Compression: 0.658217
# Article 190:	Length: 224	Compression: 0.861607	Avg Compression: 0.670678
# Article 200:	Length: 224	Compression: 0.491071	Avg Compression: 0.660309
# Article 210:	Length: 232	Compression: 0.530172	Avg Compression: 0.652967
# Article 220:	Length: 232	Compression: 0.590517	Avg Compression: 0.649632
# Article 230:	Length: 240	Compression: 0.475000	Avg Compression: 0.640489
# Article 240:	Length: 240	Compression: 0.662500	Avg Compression: 0.641584
# Article 250:	Length: 248	Compression: 0.346774	Avg Compression: 0.627169
# Article 260:	Length: 256	Compression: 0.410156	Avg Compression: 0.616742
# Article 270:	Length: 256	Compression: 0.398438	Avg Compression: 0.606734
# Article 280:	Length: 256	Compression: 0.382812	Avg Compression: 0.596918
# Article 290:	Length: 256	Compression: 0.476562	Avg Compression: 0.591864
# Article 300:	Length: 264	Compression: 0.435606	Avg Compression: 0.585377
# Article 310:	Length: 264	Compression: 0.473485	Avg Compression: 0.580918
# Article 320:	Length: 272	Compression: 0.492647	Avg Compression: 0.577436
# Article 330:	Length: 272	Compression: 0.433824	Avg Compression: 0.571987
# Article 340:	Length: 272	Compression: 0.459559	Avg Compression: 0.567876
# Article 350:	Length: 272	Compression: 0.411765	Avg Compression: 0.562370
# Article 360:	Length: 280	Compression: 0.421429	Avg Compression: 0.557432
# Article 370:	Length: 280	Compression: 0.553571	Avg Compression: 0.557302
# Article 380:	Length: 288	Compression: 0.347222	Avg Compression: 0.550234
# Article 390:	Length: 288	Compression: 0.444444	Avg Compression: 0.546790
# Article 400:	Length: 296	Compression: 0.347973	Avg Compression: 0.540354
# Article 410:	Length: 296	Compression: 0.439189	Avg Compression: 0.537182
# Article 420:	Length: 304	Compression: 0.424342	Avg Compression: 0.533662
# Article 430:	Length: 312	Compression: 0.407051	Avg Compression: 0.529733
# Article 440:	Length: 320	Compression: 0.328125	Avg Compression: 0.523516
# Article 450:	Length: 328	Compression: 0.326220	Avg Compression: 0.517470
# Article 460:	Length: 336	Compression: 0.440476	Avg Compression: 0.515127
# Article 470:	Length: 344	Compression: 0.354651	Avg Compression: 0.510278
# Article 480:	Length: 360	Compression: 0.341667	Avg Compression: 0.505109
# Article 490:	Length: 368	Compression: 0.328804	Avg Compression: 0.499752
# Article 500:	Length: 392	Compression: 0.311224	Avg Compression: 0.493842
# Article 510:	Length: 416	Compression: 0.367788	Avg Compression: 0.489783
# Article 520:	Length: 432	Compression: 0.467593	Avg Compression: 0.489065
# Article 530:	Length: 488	Compression: 0.293033	Avg Compression: 0.482153
# Article 540:	Length: 608	Compression: 0.235197	Avg Compression: 0.471761
# Article 550:	Length: 1696	Compression: 0.156840	Avg Compression: 0.438677
# Article 560:	Length: 2608	Compression: 0.148006	Avg Compression: 0.398251
# Article 570:	Length: 3256	Compression: 0.187961	Avg Compression: 0.367139
# Article 580:	Length: 4032	Compression: 0.241071	Avg Compression: 0.347619
# Article 590:	Length: 4616	Compression: 0.215771	Avg Compression: 0.327766
# Article 600:	Length: 5080	Compression: 0.218898	Avg Compression: 0.312290
# Article 610:	Length: 5552	Compression: 0.214157	Avg Compression: 0.299094
# Article 620:	Length: 5928	Compression: 0.265520	Avg Compression: 0.294879
# Article 630:	Length: 6480	Compression: 0.188580	Avg Compression: 0.282051
# Article 640:	Length: 6720	Compression: 0.244345	Avg Compression: 0.277857
# Article 650:	Length: 6960	Compression: 0.179454	Avg Compression: 0.267692
# Article 660:	Length: 7824	Compression: 0.192996	Avg Compression: 0.259920
# Article 670:	Length: 8360	Compression: 0.212081	Avg Compression: 0.255134
# Article 680:	Length: 8824	Compression: 0.225635	Avg Compression: 0.252316
# Article 690:	Length: 9288	Compression: 0.163006	Avg Compression: 0.244158
# Article 700:	Length: 9920	Compression: 0.210988	Avg Compression: 0.241209
# Article 710:	Length: 10552	Compression: 0.207544	Avg Compression: 0.238301
# Article 720:	Length: 11056	Compression: 0.215539	Avg Compression: 0.236411
# Article 730:	Length: 11776	Compression: 0.197266	Avg Compression: 0.233232
# Article 740:	Length: 12424	Compression: 0.214665	Avg Compression: 0.231766
# Article 750:	Length: 12944	Compression: 0.190822	Avg Compression: 0.228655
# Article 760:	Length: 13472	Compression: 0.236194	Avg Compression: 0.229207
# Article 770:	Length: 13888	Compression: 0.181020	Avg Compression: 0.225822
# Article 780:	Length: 14096	Compression: 0.206300	Avg Compression: 0.224523
# Article 790:	Length: 14800	Compression: 0.192973	Avg Compression: 0.222462
# Article 800:	Length: 15200	Compression: 0.214474	Avg Compression: 0.221960
# Article 810:	Length: 16024	Compression: 0.194833	Avg Compression: 0.220274
# Article 820:	Length: 16336	Compression: 0.184684	Avg Compression: 0.218154
# Article 830:	Length: 16904	Compression: 0.207702	Avg Compression: 0.217547
# Article 840:	Length: 17192	Compression: 0.226733	Avg Compression: 0.218059
# Article 850:	Length: 17632	Compression: 0.189315	Avg Compression: 0.216504
# Article 860:	Length: 17736	Compression: 0.181608	Avg Compression: 0.214703
# Article 870:	Length: 18048	Compression: 0.164672	Avg Compression: 0.212206
# Article 880:	Length: 18944	Compression: 0.185758	Avg Compression: 0.210890
# Article 890:	Length: 19320	Compression: 0.192081	Avg Compression: 0.209981
# Article 900:	Length: 20120	Compression: 0.190557	Avg Compression: 0.209051
# Article 910:	Length: 20368	Compression: 0.227710	Avg Compression: 0.209914
# Article 920:	Length: 20560	Compression: 0.187986	Avg Compression: 0.208936
# Article 930:	Length: 21408	Compression: 0.209127	Avg Compression: 0.208944
# Article 940:	Length: 22352	Compression: 0.214522	Avg Compression: 0.209191
# Article 950:	Length: 23192	Compression: 0.204855	Avg Compression: 0.209001
# Article 960:	Length: 23944	Compression: 0.189860	Avg Compression: 0.208170
# Article 970:	Length: 24192	Compression: 0.196139	Avg Compression: 0.207665
# Article 980:	Length: 25624	Compression: 0.181119	Avg Compression: 0.206535
# Article 990:	Length: 26592	Compression: 0.187688	Avg Compression: 0.205737
# Article 1000:	Length: 27224	Compression: 0.200081	Avg Compression: 0.205502
# Article 1010:	Length: 28328	Compression: 0.203191	Avg Compression: 0.205406
# Article 1020:	Length: 28416	Compression: 0.193166	Avg Compression: 0.204918
# Article 1030:	Length: 29016	Compression: 0.200993	Avg Compression: 0.204764
# Article 1040:	Length: 29920	Compression: 0.192680	Avg Compression: 0.204295
# Article 1050:	Length: 30600	Compression: 0.201046	Avg Compression: 0.204171
# Article 1060:	Length: 30488	Compression: 0.200735	Avg Compression: 0.204046
# Article 1070:	Length: 32032	Compression: 0.179695	Avg Compression: 0.203143
# Article 1080:	Length: 33016	Compression: 0.197056	Avg Compression: 0.202919
# Article 1090:	Length: 33472	Compression: 0.180808	Avg Compression: 0.202124
# Article 1100:	Length: 34536	Compression: 0.179494	Avg Compression: 0.201314
# Article 1110:	Length: 35264	Compression: 0.203267	Avg Compression: 0.201383
# Article 1120:	Length: 36120	Compression: 0.146069	Avg Compression: 0.199456
# Article 1130:	Length: 36448	Compression: 0.192219	Avg Compression: 0.199210
# Article 1140:	Length: 37448	Compression: 0.187780	Avg Compression: 0.198825
# Article 1150:	Length: 38424	Compression: 0.191833	Avg Compression: 0.198591
# Article 1160:	Length: 38680	Compression: 0.192218	Avg Compression: 0.198383
# Article 1170:	Length: 40216	Compression: 0.212552	Avg Compression: 0.198847
# Article 1180:	Length: 41480	Compression: 0.225579	Avg Compression: 0.199721
# Article 1190:	Length: 42616	Compression: 0.212878	Avg Compression: 0.200148
# Article 1200:	Length: 43488	Compression: 0.213300	Avg Compression: 0.200570
# Article 1210:	Length: 45080	Compression: 0.212134	Avg Compression: 0.200942
# Article 1220:	Length: 46864	Compression: 0.192493	Avg Compression: 0.200669
# Article 1230:	Length: 48608	Compression: 0.175938	Avg Compression: 0.199865
# Article 1240:	Length: 50264	Compression: 0.197537	Avg Compression: 0.199790
# Article 1250:	Length: 51272	Compression: 0.208379	Avg Compression: 0.200065
# Article 1260:	Length: 52528	Compression: 0.209050	Avg Compression: 0.200351
# Article 1270:	Length: 53688	Compression: 0.200548	Avg Compression: 0.200358
# Article 1280:	Length: 54640	Compression: 0.186072	Avg Compression: 0.199914
# Article 1290:	Length: 55440	Compression: 0.166144	Avg Compression: 0.198882
# Article 1300:	Length: 56320	Compression: 0.189169	Avg Compression: 0.198589
# Article 1310:	Length: 58648	Compression: 0.166144	Avg Compression: 0.197603
# Article 1320:	Length: 60504	Compression: 0.207193	Avg Compression: 0.197894
# Article 1330:	Length: 62376	Compression: 0.140519	Avg Compression: 0.196150
# Article 1340:	Length: 63840	Compression: 0.201472	Avg Compression: 0.196311
# Article 1350:	Length: 65976	Compression: 0.194237	Avg Compression: 0.196248
# Article 1360:	Length: 67128	Compression: 0.185139	Avg Compression: 0.195916
# Article 1370:	Length: 68800	Compression: 0.203430	Avg Compression: 0.196139
# Article 1380:	Length: 70576	Compression: 0.229228	Avg Compression: 0.197117
# Article 1390:	Length: 72432	Compression: 0.180155	Avg Compression: 0.196618
# Article 1400:	Length: 74752	Compression: 0.203245	Avg Compression: 0.196813
# Article 1410:	Length: 75792	Compression: 0.197936	Avg Compression: 0.196846
# Article 1420:	Length: 78368	Compression: 0.213097	Avg Compression: 0.197319
# Article 1430:	Length: 80136	Compression: 0.163634	Avg Compression: 0.196345
# Article 1440:	Length: 81808	Compression: 0.195164	Avg Compression: 0.196311
# Article 1450:	Length: 84736	Compression: 0.154657	Avg Compression: 0.195109
# Article 1460:	Length: 87880	Compression: 0.156611	Avg Compression: 0.193990
# Article 1470:	Length: 88760	Compression: 0.207932	Avg Compression: 0.194388
# Article 1480:	Length: 89704	Compression: 0.213491	Avg Compression: 0.194923
# Article 1490:	Length: 91864	Compression: 0.192872	Avg Compression: 0.194865
# Article 1500:	Length: 94344	Compression: 0.201645	Avg Compression: 0.195054
# Article 1510:	Length: 97160	Compression: 0.186322	Avg Compression: 0.194811
# Article 1520:	Length: 98752	Compression: 0.150913	Avg Compression: 0.193601
# Article 1530:	Length: 101024	Compression: 0.156319	Avg Compression: 0.192580
# Article 1540:	Length: 103016	Compression: 0.148744	Avg Compression: 0.191388
# Article 1550:	Length: 106432	Compression: 0.199376	Avg Compression: 0.191606
# Article 1560:	Length: 107664	Compression: 0.155512	Avg Compression: 0.190635
# Article 1570:	Length: 109952	Compression: 0.194157	Avg Compression: 0.190729
# Article 1580:	Length: 112616	Compression: 0.155866	Avg Compression: 0.189800
# Article 1590:	Length: 115984	Compression: 0.164911	Avg Compression: 0.189135
# Article 1600:	Length: 118032	Compression: 0.195176	Avg Compression: 0.189295
# Article 1610:	Length: 120872	Compression: 0.161907	Avg Compression: 0.188572
# Article 1620:	Length: 123248	Compression: 0.179167	Avg Compression: 0.188326
# Article 1630:	Length: 125152	Compression: 0.176609	Avg Compression: 0.188022
# Article 1640:	Length: 128960	Compression: 0.175434	Avg Compression: 0.187695
# Article 1650:	Length: 132816	Compression: 0.172125	Avg Compression: 0.187288
# Article 1660:	Length: 134584	Compression: 0.155345	Avg Compression: 0.186466
# Article 1670:	Length: 141472	Compression: 0.173935	Avg Compression: 0.186135
# Article 1680:	Length: 146472	Compression: 0.186131	Avg Compression: 0.186135
# Article 1690:	Length: 151840	Compression: 0.201561	Avg Compression: 0.186549
# Article 1700:	Length: 157048	Compression: 0.216010	Avg Compression: 0.187343
# Article 1710:	Length: 161424	Compression: 0.205564	Avg Compression: 0.187835
# Article 1720:	Length: 164208	Compression: 0.223083	Avg Compression: 0.188776
# Article 1730:	Length: 174464	Compression: 0.221100	Avg Compression: 0.189669
# Article 1740:	Length: 189072	Compression: 0.178863	Avg Compression: 0.189355
# Article 1750:	Length: 195080	Compression: 0.191040	Avg Compression: 0.189404
# Article 1760:	Length: 202592	Compression: 0.192559	Avg Compression: 0.189496
# Article 1770:	Length: 213160	Compression: 0.202186	Avg Compression: 0.189876
# Article 1780:	Length: 220440	Compression: 0.209844	Avg Compression: 0.190476
# Article 1790:	Length: 229744	Compression: 0.220193	Avg Compression: 0.191377
# Article 1800:	Length: 246304	Compression: 0.186067	Avg Compression: 0.191210
# Article 1810:	Length: 251304	Compression: 0.214067	Avg Compression: 0.191922
# Article 1820:	Length: 268336	Compression: 0.205354	Avg Compression: 0.192354
# Article 1830:	Length: 283192	Compression: 0.180514	Avg Compression: 0.191965
# Article 1840:	Length: 307368	Compression: 0.198736	Avg Compression: 0.192198
# Article 1850:	Length: 323168	Compression: 0.184146	Avg Compression: 0.191917
# Article 1860:	Length: 341176	Compression: 0.200674	Avg Compression: 0.192228
# Article 1870:	Length: 382048	Compression: 0.184288	Avg Compression: 0.191924
# Article 1880:	Length: 441872	Compression: 0.144933	Avg Compression: 0.189931
# Article 1890:	Length: 508896	Compression: 0.183833	Avg Compression: 0.189647

# %%
model.train(192, 256, epochs=50)
# Out:
# Epoch 1/50
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# 203/203 [==============================] - 117s 577ms/step - loss: 1.3531 - average_final_batch_ratio: 0.1182
# Epoch 2/50
# 203/203 [==============================] - 116s 573ms/step - loss: 1.3429 - average_final_batch_ratio: 0.1182
# Epoch 3/50
# 203/203 [==============================] - 117s 575ms/step - loss: 1.3252 - average_final_batch_ratio: 0.1182
# Epoch 4/50
# 203/203 [==============================] - 117s 574ms/step - loss: 1.3220 - average_final_batch_ratio: 0.1182
# Epoch 5/50
# 203/203 [==============================] - 117s 574ms/step - loss: 1.3121 - average_final_batch_ratio: 0.1182
# Epoch 6/50
# 203/203 [==============================] - 117s 575ms/step - loss: 1.3032 - average_final_batch_ratio: 0.1182
# Epoch 7/50
# 203/203 [==============================] - 118s 580ms/step - loss: 1.2954 - average_final_batch_ratio: 0.1182
# Epoch 8/50
# 203/203 [==============================] - 116s 571ms/step - loss: 1.2836 - average_final_batch_ratio: 0.1182
# Epoch 9/50
# 203/203 [==============================] - 117s 574ms/step - loss: 1.2794 - average_final_batch_ratio: 0.1182
# Epoch 10/50
# 203/203 [==============================] - 117s 576ms/step - loss: 1.2699 - average_final_batch_ratio: 0.1182
# Epoch 11/50
# 203/203 [==============================] - 117s 575ms/step - loss: 1.2562 - average_final_batch_ratio: 0.1182
# Epoch 12/50
# 203/203 [==============================] - 116s 574ms/step - loss: 1.2490 - average_final_batch_ratio: 0.1182
# Epoch 13/50
# 203/203 [==============================] - 117s 576ms/step - loss: 1.2433 - average_final_batch_ratio: 0.1182
# Epoch 14/50
# 203/203 [==============================] - 118s 581ms/step - loss: 1.2319 - average_final_batch_ratio: 0.1182
# Epoch 15/50
# 203/203 [==============================] - 116s 572ms/step - loss: 1.2219 - average_final_batch_ratio: 0.1182
# Epoch 16/50
# 203/203 [==============================] - 117s 575ms/step - loss: 1.2169 - average_final_batch_ratio: 0.1182
# Epoch 17/50
# 203/203 [==============================] - 117s 577ms/step - loss: 1.2143 - average_final_batch_ratio: 0.1182
# Epoch 18/50
# 203/203 [==============================] - 117s 575ms/step - loss: 1.2052 - average_final_batch_ratio: 0.1182
# Epoch 19/50
# 203/203 [==============================] - 117s 574ms/step - loss: 1.2039 - average_final_batch_ratio: 0.1182
# Epoch 20/50
# 203/203 [==============================] - 117s 576ms/step - loss: 1.1823 - average_final_batch_ratio: 0.1182
# Epoch 21/50
# 203/203 [==============================] - 118s 580ms/step - loss: 1.1919 - average_final_batch_ratio: 0.1182
# Epoch 22/50
# 203/203 [==============================] - 116s 571ms/step - loss: 1.1821 - average_final_batch_ratio: 0.1182
# Epoch 23/50
# 203/203 [==============================] - 117s 574ms/step - loss: 1.1800 - average_final_batch_ratio: 0.1182
# Epoch 24/50
# 203/203 [==============================] - 117s 576ms/step - loss: 1.1679 - average_final_batch_ratio: 0.1182
# Epoch 25/50
# 203/203 [==============================] - 117s 575ms/step - loss: 1.1562 - average_final_batch_ratio: 0.1182
# Epoch 26/50
# 203/203 [==============================] - 117s 574ms/step - loss: 1.1451 - average_final_batch_ratio: 0.1182
# Epoch 27/50
# 203/203 [==============================] - 117s 576ms/step - loss: 1.1508 - average_final_batch_ratio: 0.1182
# Epoch 28/50
# 203/203 [==============================] - 118s 581ms/step - loss: 1.1374 - average_final_batch_ratio: 0.1182
# Epoch 29/50
# 203/203 [==============================] - 116s 572ms/step - loss: 1.1452 - average_final_batch_ratio: 0.1182
# Epoch 30/50
# 203/203 [==============================] - 117s 575ms/step - loss: 1.1343 - average_final_batch_ratio: 0.1182
# Epoch 31/50
# 203/203 [==============================] - 117s 576ms/step - loss: 1.1221 - average_final_batch_ratio: 0.1182
# Epoch 32/50
# 203/203 [==============================] - 117s 576ms/step - loss: 1.1169 - average_final_batch_ratio: 0.1182
# Epoch 33/50
# 203/203 [==============================] - 117s 575ms/step - loss: 1.1111 - average_final_batch_ratio: 0.1182
# Epoch 34/50
# 203/203 [==============================] - 117s 577ms/step - loss: 1.1089 - average_final_batch_ratio: 0.1182
# Epoch 35/50
# 203/203 [==============================] - 118s 581ms/step - loss: 1.0940 - average_final_batch_ratio: 0.1182
# Epoch 36/50
# 203/203 [==============================] - 116s 572ms/step - loss: 1.1019 - average_final_batch_ratio: 0.1182
# Epoch 37/50
# 203/203 [==============================] - 117s 575ms/step - loss: 1.0888 - average_final_batch_ratio: 0.1182
# Epoch 38/50
# 203/203 [==============================] - 117s 577ms/step - loss: 1.0875 - average_final_batch_ratio: 0.1182
# Epoch 39/50
# 203/203 [==============================] - 117s 576ms/step - loss: 1.0816 - average_final_batch_ratio: 0.1182
# Epoch 40/50
# 203/203 [==============================] - 117s 575ms/step - loss: 1.0790 - average_final_batch_ratio: 0.1182
# Epoch 41/50
# 203/203 [==============================] - 117s 576ms/step - loss: 1.0781 - average_final_batch_ratio: 0.1182
# Epoch 42/50
# 203/203 [==============================] - 118s 581ms/step - loss: 1.0769 - average_final_batch_ratio: 0.1182
# Epoch 43/50
# 203/203 [==============================] - 116s 572ms/step - loss: 1.0714 - average_final_batch_ratio: 0.1182
# Epoch 44/50
# 203/203 [==============================] - 117s 574ms/step - loss: 1.0670 - average_final_batch_ratio: 0.1182
# Epoch 45/50
# 203/203 [==============================] - 117s 577ms/step - loss: 1.0528 - average_final_batch_ratio: 0.1182
# Epoch 46/50
# 203/203 [==============================] - 117s 576ms/step - loss: 1.0468 - average_final_batch_ratio: 0.1182
# Epoch 47/50
# 203/203 [==============================] - 117s 575ms/step - loss: 1.0371 - average_final_batch_ratio: 0.1182
# Epoch 48/50
# 203/203 [==============================] - 117s 576ms/step - loss: 1.0286 - average_final_batch_ratio: 0.1182
# Epoch 49/50
# 203/203 [==============================] - 118s 581ms/step - loss: 1.0194 - average_final_batch_ratio: 0.1182
# Epoch 50/50
# 203/203 [==============================] - 116s 571ms/step - loss: 1.0418 - average_final_batch_ratio: 0.1182

# %%
total_raw = 0
total_compressed = 0

for index, encoded_article in enumerate(articles.articles_generator(1)):
    if index % 10 == 0:
        article = subword_text_encoder.decode(encoded_article)
        raw = len(article) * 8
        if raw == 0:
            continue
        compressed, _ = huffman_archive_size(model, encoded_article)
        total_raw += raw
        total_compressed += compressed

        print('Article %d:\tLength: %d\tCompression: %f\tAvg Compression: %f' % (index, raw, compressed/raw, total_compressed/total_raw))
# Out:
# Article 0:	Length: 128	Compression: 1.015625	Avg Compression: 1.015625
# Article 10:	Length: 144	Compression: 0.909722	Avg Compression: 0.959559
# Article 20:	Length: 152	Compression: 0.822368	Avg Compression: 0.910377
# Article 30:	Length: 160	Compression: 0.731250	Avg Compression: 0.861301
# Article 40:	Length: 160	Compression: 0.962500	Avg Compression: 0.883065
# Article 50:	Length: 168	Compression: 0.851190	Avg Compression: 0.877193
# Article 60:	Length: 168	Compression: 0.839286	Avg Compression: 0.871296
# Article 70:	Length: 176	Compression: 1.215909	Avg Compression: 0.919586
# Article 80:	Length: 176	Compression: 0.857955	Avg Compression: 0.912011
# Article 90:	Length: 184	Compression: 0.869565	Avg Compression: 0.907178
# Article 100:	Length: 184	Compression: 0.929348	Avg Compression: 0.909444
# Article 110:	Length: 192	Compression: 0.791667	Avg Compression: 0.898092
# Article 120:	Length: 192	Compression: 0.692708	Avg Compression: 0.880037
# Article 130:	Length: 200	Compression: 0.870000	Avg Compression: 0.879195
# Article 140:	Length: 200	Compression: 0.800000	Avg Compression: 0.873065
# Article 150:	Length: 208	Compression: 0.913462	Avg Compression: 0.876074
# Article 160:	Length: 208	Compression: 0.697115	Avg Compression: 0.863667
# Article 170:	Length: 216	Compression: 0.652778	Avg Compression: 0.849502
# Article 180:	Length: 216	Compression: 0.958333	Avg Compression: 0.856352
# Article 190:	Length: 224	Compression: 1.125000	Avg Compression: 0.872812
# Article 200:	Length: 224	Compression: 0.593750	Avg Compression: 0.856701
# Article 210:	Length: 232	Compression: 0.625000	Avg Compression: 0.843628
# Article 220:	Length: 232	Compression: 0.818966	Avg Compression: 0.842311
# Article 230:	Length: 240	Compression: 0.583333	Avg Compression: 0.828752
# Article 240:	Length: 240	Compression: 0.795833	Avg Compression: 0.827114
# Article 250:	Length: 248	Compression: 0.459677	Avg Compression: 0.809148
# Article 260:	Length: 256	Compression: 0.640625	Avg Compression: 0.801051
# Article 270:	Length: 256	Compression: 0.554688	Avg Compression: 0.789756
# Article 280:	Length: 256	Compression: 0.562500	Avg Compression: 0.779795
# Article 290:	Length: 256	Compression: 0.660156	Avg Compression: 0.774770
# Article 300:	Length: 264	Compression: 0.598485	Avg Compression: 0.767453
# Article 310:	Length: 264	Compression: 0.625000	Avg Compression: 0.761775
# Article 320:	Length: 272	Compression: 0.606618	Avg Compression: 0.755655
# Article 330:	Length: 272	Compression: 0.525735	Avg Compression: 0.746931
# Article 340:	Length: 272	Compression: 0.511029	Avg Compression: 0.738306
# Article 350:	Length: 272	Compression: 0.536765	Avg Compression: 0.731198
# Article 360:	Length: 280	Compression: 0.560714	Avg Compression: 0.725225
# Article 370:	Length: 280	Compression: 0.660714	Avg Compression: 0.723042
# Article 380:	Length: 288	Compression: 0.517361	Avg Compression: 0.716121
# Article 390:	Length: 288	Compression: 0.625000	Avg Compression: 0.713156
# Article 400:	Length: 296	Compression: 0.486486	Avg Compression: 0.705818
# Article 410:	Length: 296	Compression: 0.567568	Avg Compression: 0.701483
# Article 420:	Length: 304	Compression: 0.542763	Avg Compression: 0.696531
# Article 430:	Length: 312	Compression: 0.557692	Avg Compression: 0.692224
# Article 440:	Length: 320	Compression: 0.500000	Avg Compression: 0.686295
# Article 450:	Length: 328	Compression: 0.478659	Avg Compression: 0.679933
# Article 460:	Length: 336	Compression: 0.556548	Avg Compression: 0.676178
# Article 470:	Length: 344	Compression: 0.468023	Avg Compression: 0.669888
# Article 480:	Length: 360	Compression: 0.461111	Avg Compression: 0.663488
# Article 490:	Length: 368	Compression: 0.445652	Avg Compression: 0.656869
# Article 500:	Length: 392	Compression: 0.367347	Avg Compression: 0.647793
# Article 510:	Length: 416	Compression: 0.435096	Avg Compression: 0.640944
# Article 520:	Length: 432	Compression: 0.532407	Avg Compression: 0.637433
# Article 530:	Length: 488	Compression: 0.356557	Avg Compression: 0.627529
# Article 540:	Length: 608	Compression: 0.299342	Avg Compression: 0.613718
# Article 550:	Length: 1696	Compression: 0.152712	Avg Compression: 0.565287
# Article 560:	Length: 2608	Compression: 0.134969	Avg Compression: 0.505439
# Article 570:	Length: 3256	Compression: 0.153870	Avg Compression: 0.453426
# Article 580:	Length: 4032	Compression: 0.264881	Avg Compression: 0.424232
# Article 590:	Length: 4616	Compression: 0.211872	Avg Compression: 0.392256
# Article 600:	Length: 5080	Compression: 0.224409	Avg Compression: 0.368396
# Article 610:	Length: 5552	Compression: 0.195425	Avg Compression: 0.345137
# Article 620:	Length: 5928	Compression: 0.236505	Avg Compression: 0.331498
# Article 630:	Length: 6480	Compression: 0.150000	Avg Compression: 0.309595
# Article 640:	Length: 6720	Compression: 0.240774	Avg Compression: 0.301940
# Article 650:	Length: 6960	Compression: 0.155891	Avg Compression: 0.286853
# Article 660:	Length: 7824	Compression: 0.156186	Avg Compression: 0.273258
# Article 670:	Length: 8360	Compression: 0.189952	Avg Compression: 0.264923
# Article 680:	Length: 8824	Compression: 0.195716	Avg Compression: 0.258313
# Article 690:	Length: 9288	Compression: 0.134798	Avg Compression: 0.247030
# Article 700:	Length: 9920	Compression: 0.199496	Avg Compression: 0.242804
# Article 710:	Length: 10552	Compression: 0.172384	Avg Compression: 0.236721
# Article 720:	Length: 11056	Compression: 0.179902	Avg Compression: 0.232005
# Article 730:	Length: 11776	Compression: 0.169243	Avg Compression: 0.226907
# Article 740:	Length: 12424	Compression: 0.190840	Avg Compression: 0.224060
# Article 750:	Length: 12944	Compression: 0.166255	Avg Compression: 0.219667
# Article 760:	Length: 13472	Compression: 0.185570	Avg Compression: 0.217168
# Article 770:	Length: 13888	Compression: 0.163522	Avg Compression: 0.213400
# Article 780:	Length: 14096	Compression: 0.167069	Avg Compression: 0.210316
# Article 790:	Length: 14800	Compression: 0.175608	Avg Compression: 0.208049
# Article 800:	Length: 15200	Compression: 0.169211	Avg Compression: 0.205608
# Article 810:	Length: 16024	Compression: 0.163318	Avg Compression: 0.202980
# Article 820:	Length: 16336	Compression: 0.158117	Avg Compression: 0.200306
# Article 830:	Length: 16904	Compression: 0.187530	Avg Compression: 0.199564
# Article 840:	Length: 17192	Compression: 0.183516	Avg Compression: 0.198669
# Article 850:	Length: 17632	Compression: 0.149274	Avg Compression: 0.195997
# Article 860:	Length: 17736	Compression: 0.149639	Avg Compression: 0.193604
# Article 870:	Length: 18048	Compression: 0.143451	Avg Compression: 0.191101
# Article 880:	Length: 18944	Compression: 0.163060	Avg Compression: 0.189706
# Article 890:	Length: 19320	Compression: 0.162836	Avg Compression: 0.188408
# Article 900:	Length: 20120	Compression: 0.163419	Avg Compression: 0.187211
# Article 910:	Length: 20368	Compression: 0.201689	Avg Compression: 0.187880
# Article 920:	Length: 20560	Compression: 0.154086	Avg Compression: 0.186373
# Article 930:	Length: 21408	Compression: 0.178204	Avg Compression: 0.186011
# Article 940:	Length: 22352	Compression: 0.162804	Avg Compression: 0.184983
# Article 950:	Length: 23192	Compression: 0.164884	Avg Compression: 0.184100
# Article 960:	Length: 23944	Compression: 0.168059	Avg Compression: 0.183404
# Article 970:	Length: 24192	Compression: 0.160301	Avg Compression: 0.182434
# Article 980:	Length: 25624	Compression: 0.149157	Avg Compression: 0.181017
# Article 990:	Length: 26592	Compression: 0.152189	Avg Compression: 0.179797
# Article 1000:	Length: 27224	Compression: 0.170071	Avg Compression: 0.179393
# Article 1010:	Length: 28328	Compression: 0.185506	Avg Compression: 0.179646
# Article 1020:	Length: 28416	Compression: 0.156004	Avg Compression: 0.178703
# Article 1030:	Length: 29016	Compression: 0.162945	Avg Compression: 0.178086
# Article 1040:	Length: 29920	Compression: 0.156217	Avg Compression: 0.177237
# Article 1050:	Length: 30600	Compression: 0.165654	Avg Compression: 0.176795
# Article 1060:	Length: 30488	Compression: 0.160916	Avg Compression: 0.176214
# Article 1070:	Length: 32032	Compression: 0.146541	Avg Compression: 0.175114
# Article 1080:	Length: 33016	Compression: 0.153017	Avg Compression: 0.174301
# Article 1090:	Length: 33472	Compression: 0.147706	Avg Compression: 0.173344
# Article 1100:	Length: 34536	Compression: 0.152450	Avg Compression: 0.172597
# Article 1110:	Length: 35264	Compression: 0.165806	Avg Compression: 0.172358
# Article 1120:	Length: 36120	Compression: 0.122231	Avg Compression: 0.170611
# Article 1130:	Length: 36448	Compression: 0.152244	Avg Compression: 0.169987
# Article 1140:	Length: 37448	Compression: 0.160382	Avg Compression: 0.169664
# Article 1150:	Length: 38424	Compression: 0.154877	Avg Compression: 0.169169
# Article 1160:	Length: 38680	Compression: 0.151060	Avg Compression: 0.168579
# Article 1170:	Length: 40216	Compression: 0.180127	Avg Compression: 0.168958
# Article 1180:	Length: 41480	Compression: 0.169600	Avg Compression: 0.168978
# Article 1190:	Length: 42616	Compression: 0.186362	Avg Compression: 0.169543
# Article 1200:	Length: 43488	Compression: 0.179268	Avg Compression: 0.169855
# Article 1210:	Length: 45080	Compression: 0.182010	Avg Compression: 0.170246
# Article 1220:	Length: 46864	Compression: 0.164092	Avg Compression: 0.170047
# Article 1230:	Length: 48608	Compression: 0.152156	Avg Compression: 0.169466
# Article 1240:	Length: 50264	Compression: 0.161706	Avg Compression: 0.169214
# Article 1250:	Length: 51272	Compression: 0.173096	Avg Compression: 0.169338
# Article 1260:	Length: 52528	Compression: 0.172898	Avg Compression: 0.169451
# Article 1270:	Length: 53688	Compression: 0.164972	Avg Compression: 0.169310
# Article 1280:	Length: 54640	Compression: 0.152599	Avg Compression: 0.168791
# Article 1290:	Length: 55440	Compression: 0.133911	Avg Compression: 0.167725
# Article 1300:	Length: 56320	Compression: 0.157937	Avg Compression: 0.167430
# Article 1310:	Length: 58648	Compression: 0.140840	Avg Compression: 0.166622
# Article 1320:	Length: 60504	Compression: 0.172633	Avg Compression: 0.166805
# Article 1330:	Length: 62376	Compression: 0.122114	Avg Compression: 0.165446
# Article 1340:	Length: 63840	Compression: 0.164019	Avg Compression: 0.165403
# Article 1350:	Length: 65976	Compression: 0.171699	Avg Compression: 0.165593
# Article 1360:	Length: 67128	Compression: 0.150965	Avg Compression: 0.165157
# Article 1370:	Length: 68800	Compression: 0.174637	Avg Compression: 0.165438
# Article 1380:	Length: 70576	Compression: 0.187897	Avg Compression: 0.166102
# Article 1390:	Length: 72432	Compression: 0.145764	Avg Compression: 0.165503
# Article 1400:	Length: 74752	Compression: 0.172209	Avg Compression: 0.165701
# Article 1410:	Length: 75792	Compression: 0.158592	Avg Compression: 0.165494
# Article 1420:	Length: 78368	Compression: 0.187296	Avg Compression: 0.166130
# Article 1430:	Length: 80136	Compression: 0.130428	Avg Compression: 0.165097
# Article 1440:	Length: 81808	Compression: 0.156158	Avg Compression: 0.164840
# Article 1450:	Length: 84736	Compression: 0.121412	Avg Compression: 0.163587
# Article 1460:	Length: 87880	Compression: 0.129347	Avg Compression: 0.162592
# Article 1470:	Length: 88760	Compression: 0.167384	Avg Compression: 0.162729
# Article 1480:	Length: 89704	Compression: 0.169926	Avg Compression: 0.162930
# Article 1490:	Length: 91864	Compression: 0.156285	Avg Compression: 0.162745
# Article 1500:	Length: 94344	Compression: 0.168893	Avg Compression: 0.162916
# Article 1510:	Length: 97160	Compression: 0.156988	Avg Compression: 0.162751
# Article 1520:	Length: 98752	Compression: 0.124058	Avg Compression: 0.161685
# Article 1530:	Length: 101024	Compression: 0.129761	Avg Compression: 0.160810
# Article 1540:	Length: 103016	Compression: 0.126194	Avg Compression: 0.159869
# Article 1550:	Length: 106432	Compression: 0.161784	Avg Compression: 0.159921
# Article 1560:	Length: 107664	Compression: 0.128139	Avg Compression: 0.159066
# Article 1570:	Length: 109952	Compression: 0.164417	Avg Compression: 0.159209
# Article 1580:	Length: 112616	Compression: 0.128738	Avg Compression: 0.158397
# Article 1590:	Length: 115984	Compression: 0.138191	Avg Compression: 0.157857
# Article 1600:	Length: 118032	Compression: 0.157457	Avg Compression: 0.157847
# Article 1610:	Length: 120872	Compression: 0.133530	Avg Compression: 0.157205
# Article 1620:	Length: 123248	Compression: 0.148798	Avg Compression: 0.156985
# Article 1630:	Length: 125152	Compression: 0.153517	Avg Compression: 0.156895
# Article 1640:	Length: 128960	Compression: 0.142843	Avg Compression: 0.156529
# Article 1650:	Length: 132816	Compression: 0.150983	Avg Compression: 0.156384
# Article 1660:	Length: 134584	Compression: 0.129815	Avg Compression: 0.155700
# Article 1670:	Length: 141472	Compression: 0.153253	Avg Compression: 0.155636
# Article 1680:	Length: 146472	Compression: 0.150254	Avg Compression: 0.155493
# Article 1690:	Length: 151840	Compression: 0.168941	Avg Compression: 0.155853
# Article 1700:	Length: 157048	Compression: 0.180021	Avg Compression: 0.156505
# Article 1710:	Length: 161424	Compression: 0.179905	Avg Compression: 0.157136
# Article 1720:	Length: 164208	Compression: 0.190167	Avg Compression: 0.158019
# Article 1730:	Length: 174464	Compression: 0.188474	Avg Compression: 0.158859
# Article 1740:	Length: 189072	Compression: 0.145040	Avg Compression: 0.158458
# Article 1750:	Length: 195080	Compression: 0.164784	Avg Compression: 0.158642
# Article 1760:	Length: 202592	Compression: 0.166808	Avg Compression: 0.158881
# Article 1770:	Length: 213160	Compression: 0.168474	Avg Compression: 0.159168
# Article 1780:	Length: 220440	Compression: 0.181655	Avg Compression: 0.159844
# Article 1790:	Length: 229744	Compression: 0.186564	Avg Compression: 0.160654
# Article 1800:	Length: 246304	Compression: 0.160935	Avg Compression: 0.160663
# Article 1810:	Length: 251304	Compression: 0.181016	Avg Compression: 0.161297
# Article 1820:	Length: 268336	Compression: 0.171091	Avg Compression: 0.161612
# Article 1830:	Length: 283192	Compression: 0.151509	Avg Compression: 0.161280
# Article 1840:	Length: 307368	Compression: 0.177426	Avg Compression: 0.161836
# Article 1850:	Length: 323168	Compression: 0.159434	Avg Compression: 0.161752
# Article 1860:	Length: 341176	Compression: 0.168321	Avg Compression: 0.161986
# Article 1870:	Length: 382048	Compression: 0.160909	Avg Compression: 0.161945
# Article 1880:	Length: 441872	Compression: 0.125088	Avg Compression: 0.160381
# Article 1890:	Length: 508896	Compression: 0.159129	Avg Compression: 0.160323

# %%
model.train(192, 256, epochs=50)
# Out:
# Epoch 1/50
# 203/203 [==============================] - 119s 585ms/step - loss: 1.0327 - average_final_batch_ratio: 0.1182
# Epoch 2/50
# 203/203 [==============================] - 117s 577ms/step - loss: 1.0171 - average_final_batch_ratio: 0.1182
# Epoch 3/50
# 203/203 [==============================] - 117s 576ms/step - loss: 1.0086 - average_final_batch_ratio: 0.1182
# Epoch 4/50
# 203/203 [==============================] - 118s 580ms/step - loss: 1.0274 - average_final_batch_ratio: 0.1182
# Epoch 5/50
# 203/203 [==============================] - 117s 574ms/step - loss: 0.9992 - average_final_batch_ratio: 0.1182
# Epoch 6/50
# 203/203 [==============================] - 117s 579ms/step - loss: 1.0182 - average_final_batch_ratio: 0.1182
# Epoch 7/50
# 203/203 [==============================] - 118s 579ms/step - loss: 0.9988 - average_final_batch_ratio: 0.1182
# Epoch 8/50
# 203/203 [==============================] - 118s 580ms/step - loss: 0.9981 - average_final_batch_ratio: 0.1182
# Epoch 9/50
# 203/203 [==============================] - 118s 582ms/step - loss: 0.9873 - average_final_batch_ratio: 0.1182
# Epoch 10/50
# 203/203 [==============================] - 118s 581ms/step - loss: 0.9910 - average_final_batch_ratio: 0.1182
# Epoch 11/50
# 203/203 [==============================] - 118s 582ms/step - loss: 0.9841 - average_final_batch_ratio: 0.1182
# Epoch 12/50
# 203/203 [==============================] - 117s 577ms/step - loss: 0.9765 - average_final_batch_ratio: 0.1182
# Epoch 13/50
# 203/203 [==============================] - 118s 579ms/step - loss: 0.9921 - average_final_batch_ratio: 0.1182
# Epoch 14/50
# 203/203 [==============================] - 118s 580ms/step - loss: 0.9716 - average_final_batch_ratio: 0.1182
# Epoch 15/50
# 203/203 [==============================] - 118s 579ms/step - loss: 0.9637 - average_final_batch_ratio: 0.1182
# Epoch 16/50
# 203/203 [==============================] - 119s 585ms/step - loss: 0.9746 - average_final_batch_ratio: 0.1182
# Epoch 17/50
# 203/203 [==============================] - 119s 584ms/step - loss: 0.9608 - average_final_batch_ratio: 0.1182
# Epoch 18/50
# 203/203 [==============================] - 119s 585ms/step - loss: 0.9702 - average_final_batch_ratio: 0.1182
# Epoch 19/50
# 203/203 [==============================] - 117s 577ms/step - loss: 0.9493 - average_final_batch_ratio: 0.1182
# Epoch 20/50
# 203/203 [==============================] - 117s 578ms/step - loss: 0.9545 - average_final_batch_ratio: 0.1182
# Epoch 21/50
# 203/203 [==============================] - 118s 580ms/step - loss: 0.9428 - average_final_batch_ratio: 0.1182
# Epoch 22/50
# 203/203 [==============================] - 117s 578ms/step - loss: 0.9301 - average_final_batch_ratio: 0.1182
# Epoch 23/50
# 203/203 [==============================] - 119s 584ms/step - loss: 0.9430 - average_final_batch_ratio: 0.1182
# Epoch 24/50
# 203/203 [==============================] - 118s 582ms/step - loss: 0.9409 - average_final_batch_ratio: 0.1182
# Epoch 25/50
# 203/203 [==============================] - 119s 587ms/step - loss: 0.9376 - average_final_batch_ratio: 0.1182
# Epoch 26/50
# 203/203 [==============================] - 116s 573ms/step - loss: 0.9433 - average_final_batch_ratio: 0.1182
# Epoch 27/50
# 203/203 [==============================] - 118s 580ms/step - loss: 0.9417 - average_final_batch_ratio: 0.1182
# Epoch 28/50
# 203/203 [==============================] - 118s 582ms/step - loss: 0.9440 - average_final_batch_ratio: 0.1182
# Epoch 29/50
# 203/203 [==============================] - 117s 578ms/step - loss: 0.9286 - average_final_batch_ratio: 0.1182
# Epoch 30/50
# 203/203 [==============================] - 117s 577ms/step - loss: 0.9275 - average_final_batch_ratio: 0.1182
# Epoch 31/50
# 203/203 [==============================] - 118s 580ms/step - loss: 0.9376 - average_final_batch_ratio: 0.1182
# Epoch 32/50
# 203/203 [==============================] - 119s 584ms/step - loss: 0.9324 - average_final_batch_ratio: 0.1182
# Epoch 33/50
# 203/203 [==============================] - 118s 580ms/step - loss: 0.9191 - average_final_batch_ratio: 0.1182
# Epoch 34/50
# 203/203 [==============================] - 120s 593ms/step - loss: 0.9249 - average_final_batch_ratio: 0.1182
# Epoch 35/50
# 203/203 [==============================] - 122s 602ms/step - loss: 0.9053 - average_final_batch_ratio: 0.1182
# Epoch 36/50
# 203/203 [==============================] - 121s 598ms/step - loss: 0.9215 - average_final_batch_ratio: 0.1182
# Epoch 37/50
# 203/203 [==============================] - 117s 578ms/step - loss: 0.9299 - average_final_batch_ratio: 0.1182
# Epoch 38/50
# 203/203 [==============================] - 118s 581ms/step - loss: 0.8995 - average_final_batch_ratio: 0.1182
# Epoch 39/50
# 203/203 [==============================] - 118s 584ms/step - loss: 0.9082 - average_final_batch_ratio: 0.1182
# Epoch 40/50
# 203/203 [==============================] - 118s 579ms/step - loss: 0.9257 - average_final_batch_ratio: 0.1182
# Epoch 41/50
# 203/203 [==============================] - 118s 583ms/step - loss: 0.9040 - average_final_batch_ratio: 0.1182
# Epoch 42/50
# 203/203 [==============================] - 117s 577ms/step - loss: 0.8977 - average_final_batch_ratio: 0.1182
# Epoch 43/50
# 203/203 [==============================] - 117s 576ms/step - loss: 0.9008 - average_final_batch_ratio: 0.1182
# Epoch 44/50
# 203/203 [==============================] - 117s 576ms/step - loss: 0.8948 - average_final_batch_ratio: 0.1182
# Epoch 45/50
# 203/203 [==============================] - 117s 576ms/step - loss: 0.8968 - average_final_batch_ratio: 0.1182
# Epoch 46/50
# 203/203 [==============================] - 118s 579ms/step - loss: 0.9203 - average_final_batch_ratio: 0.1182
# Epoch 47/50
# 203/203 [==============================] - 116s 573ms/step - loss: 0.8915 - average_final_batch_ratio: 0.1182
# Epoch 48/50
# 203/203 [==============================] - 117s 575ms/step - loss: 0.8868 - average_final_batch_ratio: 0.1182
# Epoch 49/50
# 203/203 [==============================] - 117s 576ms/step - loss: 0.8831 - average_final_batch_ratio: 0.1182
# Epoch 50/50
# 203/203 [==============================] - 117s 574ms/step - loss: 0.8782 - average_final_batch_ratio: 0.1182

# %%
total_raw = 0
total_compressed = 0

for index, encoded_article in enumerate(articles.articles_generator(1)):
    if index % 10 == 0:
        article = subword_text_encoder.decode(encoded_article)
        raw = len(article) * 8
        if raw == 0:
            continue
        compressed, _ = huffman_archive_size(model, encoded_article)
        total_raw += raw
        total_compressed += compressed

        print('Article %d:\tLength: %d\tCompression: %f\tAvg Compression: %f' % (index, raw, compressed/raw, total_compressed/total_raw))
# Out:
# Article 0:	Length: 128	Compression: 1.617188	Avg Compression: 1.617188
# Article 10:	Length: 144	Compression: 1.361111	Avg Compression: 1.481618
# Article 20:	Length: 152	Compression: 1.236842	Avg Compression: 1.393868
# Article 30:	Length: 160	Compression: 1.193750	Avg Compression: 1.339041
# Article 40:	Length: 160	Compression: 1.456250	Avg Compression: 1.364247
# Article 50:	Length: 168	Compression: 1.220238	Avg Compression: 1.337719
# Article 60:	Length: 168	Compression: 1.220238	Avg Compression: 1.319444
# Article 70:	Length: 176	Compression: 1.784091	Avg Compression: 1.384554
# Article 80:	Length: 176	Compression: 1.232955	Avg Compression: 1.365922
# Article 90:	Length: 184	Compression: 1.048913	Avg Compression: 1.329827
# Article 100:	Length: 184	Compression: 1.217391	Avg Compression: 1.318333
# Article 110:	Length: 192	Compression: 1.192708	Avg Compression: 1.306225
# Article 120:	Length: 192	Compression: 0.989583	Avg Compression: 1.278388
# Article 130:	Length: 200	Compression: 1.195000	Avg Compression: 1.271393
# Article 140:	Length: 200	Compression: 1.130000	Avg Compression: 1.260449
# Article 150:	Length: 208	Compression: 1.278846	Avg Compression: 1.261819
# Article 160:	Length: 208	Compression: 0.975962	Avg Compression: 1.242000
# Article 170:	Length: 216	Compression: 1.060185	Avg Compression: 1.229789
# Article 180:	Length: 216	Compression: 1.203704	Avg Compression: 1.228147
# Article 190:	Length: 224	Compression: 1.647321	Avg Compression: 1.253829
# Article 200:	Length: 224	Compression: 1.107143	Avg Compression: 1.245361
# Article 210:	Length: 232	Compression: 1.000000	Avg Compression: 1.231518
# Article 220:	Length: 232	Compression: 1.159483	Avg Compression: 1.227670
# Article 230:	Length: 240	Compression: 0.820833	Avg Compression: 1.206370
# Article 240:	Length: 240	Compression: 0.987500	Avg Compression: 1.195481
# Article 250:	Length: 248	Compression: 0.721774	Avg Compression: 1.172319
# Article 260:	Length: 256	Compression: 0.960938	Avg Compression: 1.162162
# Article 270:	Length: 256	Compression: 0.816406	Avg Compression: 1.146311
# Article 280:	Length: 256	Compression: 0.707031	Avg Compression: 1.127055
# Article 290:	Length: 256	Compression: 0.851562	Avg Compression: 1.115486
# Article 300:	Length: 264	Compression: 0.840909	Avg Compression: 1.104088
# Article 310:	Length: 264	Compression: 0.897727	Avg Compression: 1.095864
# Article 320:	Length: 272	Compression: 0.823529	Avg Compression: 1.085122
# Article 330:	Length: 272	Compression: 0.772059	Avg Compression: 1.073242
# Article 340:	Length: 272	Compression: 0.805147	Avg Compression: 1.063441
# Article 350:	Length: 272	Compression: 0.746324	Avg Compression: 1.052256
# Article 360:	Length: 280	Compression: 0.839286	Avg Compression: 1.044795
# Article 370:	Length: 280	Compression: 0.932143	Avg Compression: 1.040982
# Article 380:	Length: 288	Compression: 0.718750	Avg Compression: 1.030140
# Article 390:	Length: 288	Compression: 0.819444	Avg Compression: 1.023282
# Article 400:	Length: 296	Compression: 0.662162	Avg Compression: 1.011592
# Article 410:	Length: 296	Compression: 0.763514	Avg Compression: 1.003814
# Article 420:	Length: 304	Compression: 0.851974	Avg Compression: 0.999076
# Article 430:	Length: 312	Compression: 0.746795	Avg Compression: 0.991249
# Article 440:	Length: 320	Compression: 0.784375	Avg Compression: 0.984869
# Article 450:	Length: 328	Compression: 0.701220	Avg Compression: 0.976177
# Article 460:	Length: 336	Compression: 0.747024	Avg Compression: 0.969203
# Article 470:	Length: 344	Compression: 0.654070	Avg Compression: 0.959680
# Article 480:	Length: 360	Compression: 0.633333	Avg Compression: 0.949676
# Article 490:	Length: 368	Compression: 0.605978	Avg Compression: 0.939234
# Article 500:	Length: 392	Compression: 0.545918	Avg Compression: 0.926903
# Article 510:	Length: 416	Compression: 0.677885	Avg Compression: 0.918885
# Article 520:	Length: 432	Compression: 0.810185	Avg Compression: 0.915368
# Article 530:	Length: 488	Compression: 0.491803	Avg Compression: 0.900434
# Article 540:	Length: 608	Compression: 0.404605	Avg Compression: 0.879568
# Article 550:	Length: 1696	Compression: 0.182783	Avg Compression: 0.806368
# Article 560:	Length: 2608	Compression: 0.158359	Avg Compression: 0.716244
# Article 570:	Length: 3256	Compression: 0.160319	Avg Compression: 0.633997
# Article 580:	Length: 4032	Compression: 0.268353	Avg Compression: 0.577381
# Article 590:	Length: 4616	Compression: 0.243284	Avg Compression: 0.527075
# Article 600:	Length: 5080	Compression: 0.242323	Avg Compression: 0.486596
# Article 610:	Length: 5552	Compression: 0.191643	Avg Compression: 0.446934
# Article 620:	Length: 5928	Compression: 0.218117	Avg Compression: 0.418206
# Article 630:	Length: 6480	Compression: 0.153549	Avg Compression: 0.386267
# Article 640:	Length: 6720	Compression: 0.241220	Avg Compression: 0.370134
# Article 650:	Length: 6960	Compression: 0.158333	Avg Compression: 0.348255
# Article 660:	Length: 7824	Compression: 0.140849	Avg Compression: 0.326676
# Article 670:	Length: 8360	Compression: 0.184211	Avg Compression: 0.312422
# Article 680:	Length: 8824	Compression: 0.193903	Avg Compression: 0.301102
# Article 690:	Length: 9288	Compression: 0.124139	Avg Compression: 0.284936
# Article 700:	Length: 9920	Compression: 0.216633	Avg Compression: 0.278864
# Article 710:	Length: 10552	Compression: 0.156653	Avg Compression: 0.268306
# Article 720:	Length: 11056	Compression: 0.166154	Avg Compression: 0.259827
# Article 730:	Length: 11776	Compression: 0.169243	Avg Compression: 0.252469
# Article 740:	Length: 12424	Compression: 0.180135	Avg Compression: 0.246760
# Article 750:	Length: 12944	Compression: 0.159070	Avg Compression: 0.240097
# Article 760:	Length: 13472	Compression: 0.164935	Avg Compression: 0.234588
# Article 770:	Length: 13888	Compression: 0.144873	Avg Compression: 0.228286
# Article 780:	Length: 14096	Compression: 0.144225	Avg Compression: 0.222691
# Article 790:	Length: 14800	Compression: 0.174865	Avg Compression: 0.219568
# Article 800:	Length: 15200	Compression: 0.150987	Avg Compression: 0.215256
# Article 810:	Length: 16024	Compression: 0.146655	Avg Compression: 0.210993
# Article 820:	Length: 16336	Compression: 0.140671	Avg Compression: 0.206803
# Article 830:	Length: 16904	Compression: 0.173095	Avg Compression: 0.204845
# Article 840:	Length: 17192	Compression: 0.168276	Avg Compression: 0.202805
# Article 850:	Length: 17632	Compression: 0.130898	Avg Compression: 0.198915
# Article 860:	Length: 17736	Compression: 0.131766	Avg Compression: 0.195449
# Article 870:	Length: 18048	Compression: 0.129156	Avg Compression: 0.192141
# Article 880:	Length: 18944	Compression: 0.152185	Avg Compression: 0.190152
# Article 890:	Length: 19320	Compression: 0.142184	Avg Compression: 0.187835
# Article 900:	Length: 20120	Compression: 0.145924	Avg Compression: 0.185828
# Article 910:	Length: 20368	Compression: 0.182050	Avg Compression: 0.185653
# Article 920:	Length: 20560	Compression: 0.141537	Avg Compression: 0.183685
# Article 930:	Length: 21408	Compression: 0.160080	Avg Compression: 0.182638
# Article 940:	Length: 22352	Compression: 0.143790	Avg Compression: 0.180917
# Article 950:	Length: 23192	Compression: 0.144058	Avg Compression: 0.179298
# Article 960:	Length: 23944	Compression: 0.154485	Avg Compression: 0.178222
# Article 970:	Length: 24192	Compression: 0.144097	Avg Compression: 0.176789
# Article 980:	Length: 25624	Compression: 0.133078	Avg Compression: 0.174927
# Article 990:	Length: 26592	Compression: 0.130791	Avg Compression: 0.173059
# Article 1000:	Length: 27224	Compression: 0.229430	Avg Compression: 0.175400
# Article 1010:	Length: 28328	Compression: 0.184658	Avg Compression: 0.175784
# Article 1020:	Length: 28416	Compression: 0.143335	Avg Compression: 0.174489
# Article 1030:	Length: 29016	Compression: 0.142232	Avg Compression: 0.173227
# Article 1040:	Length: 29920	Compression: 0.138102	Avg Compression: 0.171864
# Article 1050:	Length: 30600	Compression: 0.144150	Avg Compression: 0.170806
# Article 1060:	Length: 30488	Compression: 0.140875	Avg Compression: 0.169710
# Article 1070:	Length: 32032	Compression: 0.133554	Avg Compression: 0.168370
# Article 1080:	Length: 33016	Compression: 0.138599	Avg Compression: 0.167274
# Article 1090:	Length: 33472	Compression: 0.131842	Avg Compression: 0.166000
# Article 1100:	Length: 34536	Compression: 0.132934	Avg Compression: 0.164817
# Article 1110:	Length: 35264	Compression: 0.146665	Avg Compression: 0.164177
# Article 1120:	Length: 36120	Compression: 0.109524	Avg Compression: 0.162273
# Article 1130:	Length: 36448	Compression: 0.137072	Avg Compression: 0.161417
# Article 1140:	Length: 37448	Compression: 0.142010	Avg Compression: 0.160763
# Article 1150:	Length: 38424	Compression: 0.136842	Avg Compression: 0.159963
# Article 1160:	Length: 38680	Compression: 0.130584	Avg Compression: 0.159006
# Article 1170:	Length: 40216	Compression: 0.161055	Avg Compression: 0.159073
# Article 1180:	Length: 41480	Compression: 0.143852	Avg Compression: 0.158576
# Article 1190:	Length: 42616	Compression: 0.173268	Avg Compression: 0.159053
# Article 1200:	Length: 43488	Compression: 0.169012	Avg Compression: 0.159373
# Article 1210:	Length: 45080	Compression: 0.162866	Avg Compression: 0.159485
# Article 1220:	Length: 46864	Compression: 0.145805	Avg Compression: 0.159042
# Article 1230:	Length: 48608	Compression: 0.134443	Avg Compression: 0.158243
# Article 1240:	Length: 50264	Compression: 0.141194	Avg Compression: 0.157689
# Article 1250:	Length: 51272	Compression: 0.150706	Avg Compression: 0.157465
# Article 1260:	Length: 52528	Compression: 0.145960	Avg Compression: 0.157099
# Article 1270:	Length: 53688	Compression: 0.143049	Avg Compression: 0.156656
# Article 1280:	Length: 54640	Compression: 0.129246	Avg Compression: 0.155804
# Article 1290:	Length: 55440	Compression: 0.115657	Avg Compression: 0.154577
# Article 1300:	Length: 56320	Compression: 0.139187	Avg Compression: 0.154114
# Article 1310:	Length: 58648	Compression: 0.121010	Avg Compression: 0.153107
# Article 1320:	Length: 60504	Compression: 0.146536	Avg Compression: 0.152907
# Article 1330:	Length: 62376	Compression: 0.106098	Avg Compression: 0.151484
# Article 1340:	Length: 63840	Compression: 0.141526	Avg Compression: 0.151184
# Article 1350:	Length: 65976	Compression: 0.147599	Avg Compression: 0.151075
# Article 1360:	Length: 67128	Compression: 0.130244	Avg Compression: 0.150453
# Article 1370:	Length: 68800	Compression: 0.156177	Avg Compression: 0.150623
# Article 1380:	Length: 70576	Compression: 0.160735	Avg Compression: 0.150922
# Article 1390:	Length: 72432	Compression: 0.123716	Avg Compression: 0.150121
# Article 1400:	Length: 74752	Compression: 0.152143	Avg Compression: 0.150181
# Article 1410:	Length: 75792	Compression: 0.134843	Avg Compression: 0.149736
# Article 1420:	Length: 78368	Compression: 0.161928	Avg Compression: 0.150091
# Article 1430:	Length: 80136	Compression: 0.115354	Avg Compression: 0.149086
# Article 1440:	Length: 81808	Compression: 0.133606	Avg Compression: 0.148642
# Article 1450:	Length: 84736	Compression: 0.107640	Avg Compression: 0.147458
# Article 1460:	Length: 87880	Compression: 0.114269	Avg Compression: 0.146494
# Article 1470:	Length: 88760	Compression: 0.146958	Avg Compression: 0.146507
# Article 1480:	Length: 89704	Compression: 0.142212	Avg Compression: 0.146387
# Article 1490:	Length: 91864	Compression: 0.135156	Avg Compression: 0.146074
# Article 1500:	Length: 94344	Compression: 0.147853	Avg Compression: 0.146123
# Article 1510:	Length: 97160	Compression: 0.135766	Avg Compression: 0.145834
# Article 1520:	Length: 98752	Compression: 0.108433	Avg Compression: 0.144804
# Article 1530:	Length: 101024	Compression: 0.110687	Avg Compression: 0.143869
# Article 1540:	Length: 103016	Compression: 0.110798	Avg Compression: 0.142970
# Article 1550:	Length: 106432	Compression: 0.135204	Avg Compression: 0.142757
# Article 1560:	Length: 107664	Compression: 0.111235	Avg Compression: 0.141910
# Article 1570:	Length: 109952	Compression: 0.134832	Avg Compression: 0.141720
# Article 1580:	Length: 112616	Compression: 0.111965	Avg Compression: 0.140927
# Article 1590:	Length: 115984	Compression: 0.113585	Avg Compression: 0.140197
# Article 1600:	Length: 118032	Compression: 0.130685	Avg Compression: 0.139945
# Article 1610:	Length: 120872	Compression: 0.113360	Avg Compression: 0.139243
# Article 1620:	Length: 123248	Compression: 0.121592	Avg Compression: 0.138781
# Article 1630:	Length: 125152	Compression: 0.127469	Avg Compression: 0.138488
# Article 1640:	Length: 128960	Compression: 0.114291	Avg Compression: 0.137858
# Article 1650:	Length: 132816	Compression: 0.124556	Avg Compression: 0.137511
# Article 1660:	Length: 134584	Compression: 0.109701	Avg Compression: 0.136795
# Article 1670:	Length: 141472	Compression: 0.123699	Avg Compression: 0.136450
# Article 1680:	Length: 146472	Compression: 0.117599	Avg Compression: 0.135949
# Article 1690:	Length: 151840	Compression: 0.134556	Avg Compression: 0.135911
# Article 1700:	Length: 157048	Compression: 0.145777	Avg Compression: 0.136178
# Article 1710:	Length: 161424	Compression: 0.155875	Avg Compression: 0.136709
# Article 1720:	Length: 164208	Compression: 0.162928	Avg Compression: 0.137409
# Article 1730:	Length: 174464	Compression: 0.164441	Avg Compression: 0.138155
# Article 1740:	Length: 189072	Compression: 0.125450	Avg Compression: 0.137786
# Article 1750:	Length: 195080	Compression: 0.141983	Avg Compression: 0.137908
# Article 1760:	Length: 202592	Compression: 0.145554	Avg Compression: 0.138133
# Article 1770:	Length: 213160	Compression: 0.146683	Avg Compression: 0.138389
# Article 1780:	Length: 220440	Compression: 0.160270	Avg Compression: 0.139046
# Article 1790:	Length: 229744	Compression: 0.165741	Avg Compression: 0.139856
# Article 1800:	Length: 246304	Compression: 0.144833	Avg Compression: 0.140012
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# Article 1810:	Length: 251304	Compression: 0.162357	Avg Compression: 0.140708
# Article 1820:	Length: 268336	Compression: 0.153893	Avg Compression: 0.141133
# Article 1830:	Length: 283192	Compression: 0.134096	Avg Compression: 0.140901
# Article 1840:	Length: 307368	Compression: 0.161201	Avg Compression: 0.141600
# Article 1850:	Length: 323168	Compression: 0.142703	Avg Compression: 0.141639
# Article 1860:	Length: 341176	Compression: 0.150084	Avg Compression: 0.141939
# Article 1870:	Length: 382048	Compression: 0.148002	Avg Compression: 0.142171
# Article 1880:	Length: 441872	Compression: 0.122787	Avg Compression: 0.141349
# Article 1890:	Length: 508896	Compression: 0.146672	Avg Compression: 0.141597

# %% [markdown]
# Странно е, че за малки файлове компресията е толкова по-лоша. Да опитаме винаги да използваме първия символ некомпресиран.

# %%
import ctypes

class Huffman:
    huffman = ctypes.CDLL('x64/Release/huffman')
    
    huffman.create_tree.restype = ctypes.c_void_p
    huffman.destroy_tree.restype = None
    huffman.load_weights.restype = None
    huffman.create_code_string.restype = ctypes.c_char_p
    
    def __init__(self, category_count):
        self.tree = ctypes.c_void_p(self.huffman.create_tree(category_count))

    def __del__(self):
        self.huffman.destroy_tree(self.tree)
        
    def load_weights(self, weights):
        self.huffman.load_weights(self.tree, weights.ctypes.data_as(ctypes.POINTER(ctypes.c_float)))
    
    def get_code_length(self, category):
        return self.huffman.get_code_length(self.tree, category)

    def get_code_zero_count(self, category):
        return self.huffman.get_code_zero_count(self.tree, category)
    
    def archive_size(self, model, text):
        archived_size = 14
        input_eval = np.array([[text[0]]], dtype=TYPE)

        model.predicting_model.reset_states()

        for byte in text[1:]:
            predictions = model.predict(input_eval)
            predictions = tf.squeeze(predictions, 0) # remove the batch dimension

            weights = tf.nn.softmax(predictions[0]).numpy()
            self.load_weights(weights)
            archived_size += self.get_code_length(byte.item())

            input_eval = tf.expand_dims([byte], 0)

        return archived_size

# %%
total_raw = 0
total_compressed = 0

huffman = Huffman(subword_text_encoder.vocab_size)
for index, encoded_article in enumerate(articles.articles_generator(1)):
    if index % 10 == 0:
        article = subword_text_encoder.decode(encoded_article)
        if len(article) == 0:
            continue
        total_raw += len(article) * 8
        total_compressed += huffman.archive_size(model, encoded_article)
        print('Article %d:\tLength: %d\tAvg Compression: %f' % (index, len(article), total_compressed/total_raw))
# Out:
# Article 0:	Length: 16	Avg Compression: 0.195312
# Article 10:	Length: 18	Avg Compression: 0.194853
# Article 20:	Length: 19	Avg Compression: 0.188679
# Article 30:	Length: 20	Avg Compression: 0.184932
# Article 40:	Length: 20	Avg Compression: 0.181452
# Article 50:	Length: 21	Avg Compression: 0.178728
# Article 60:	Length: 21	Avg Compression: 0.176852
# Article 70:	Length: 22	Avg Compression: 0.187102
# Article 80:	Length: 22	Avg Compression: 0.185056
# Article 90:	Length: 23	Avg Compression: 0.184406
# Article 100:	Length: 23	Avg Compression: 0.183333
# Article 110:	Length: 24	Avg Compression: 0.188253
# Article 120:	Length: 24	Avg Compression: 0.184982
# Article 130:	Length: 25	Avg Compression: 0.184564
# Article 140:	Length: 25	Avg Compression: 0.184598
# Article 150:	Length: 26	Avg Compression: 0.180874
# Article 160:	Length: 26	Avg Compression: 0.177333
# Article 170:	Length: 27	Avg Compression: 0.175684
# Article 180:	Length: 27	Avg Compression: 0.172203
# Article 190:	Length: 28	Avg Compression: 0.170131
# Article 200:	Length: 28	Avg Compression: 0.168814
# Article 210:	Length: 29	Avg Compression: 0.167072
# Article 220:	Length: 29	Avg Compression: 0.165746
# Article 230:	Length: 30	Avg Compression: 0.163831
# Article 240:	Length: 30	Avg Compression: 0.162935
# Article 250:	Length: 31	Avg Compression: 0.160095
# Article 260:	Length: 32	Avg Compression: 0.158971
# Article 270:	Length: 32	Avg Compression: 0.157772
# Article 280:	Length: 32	Avg Compression: 0.156164
# Article 290:	Length: 32	Avg Compression: 0.155348
# Article 300:	Length: 33	Avg Compression: 0.154245
# Article 310:	Length: 33	Avg Compression: 0.152929
# Article 320:	Length: 34	Avg Compression: 0.151102
# Article 330:	Length: 34	Avg Compression: 0.149414
# Article 340:	Length: 34	Avg Compression: 0.148790
# Article 350:	Length: 34	Avg Compression: 0.147562
# Article 360:	Length: 35	Avg Compression: 0.146647
# Article 370:	Length: 35	Avg Compression: 0.147123
# Article 380:	Length: 36	Avg Compression: 0.146145
# Article 390:	Length: 36	Avg Compression: 0.145231
# Article 400:	Length: 37	Avg Compression: 0.144029
# Article 410:	Length: 37	Avg Compression: 0.142903
# Article 420:	Length: 38	Avg Compression: 0.141626
# Article 430:	Length: 39	Avg Compression: 0.140314
# Article 440:	Length: 40	Avg Compression: 0.138878
# Article 450:	Length: 41	Avg Compression: 0.137986
# Article 460:	Length: 42	Avg Compression: 0.136957
# Article 470:	Length: 43	Avg Compression: 0.135892
# Article 480:	Length: 45	Avg Compression: 0.134707
# Article 490:	Length: 46	Avg Compression: 0.133504
# Article 500:	Length: 49	Avg Compression: 0.132278
# Article 510:	Length: 52	Avg Compression: 0.131656
# Article 520:	Length: 54	Avg Compression: 0.130542
# Article 530:	Length: 61	Avg Compression: 0.128902
# Article 540:	Length: 76	Avg Compression: 0.126800
# Article 550:	Length: 212	Avg Compression: 0.121531
# Article 560:	Length: 326	Avg Compression: 0.115934
# Article 570:	Length: 407	Avg Compression: 0.112959
# Article 580:	Length: 504	Avg Compression: 0.114401
# Article 590:	Length: 577	Avg Compression: 0.115084
# Article 600:	Length: 635	Avg Compression: 0.119208
# Article 610:	Length: 694	Avg Compression: 0.121488
# Article 620:	Length: 741	Avg Compression: 0.128410
# Article 630:	Length: 810	Avg Compression: 0.125913
# Article 640:	Length: 840	Avg Compression: 0.128195
# Article 650:	Length: 870	Avg Compression: 0.125712
# Article 660:	Length: 978	Avg Compression: 0.124255
# Article 670:	Length: 1045	Avg Compression: 0.124174
# Article 680:	Length: 1103	Avg Compression: 0.125704
# Article 690:	Length: 1161	Avg Compression: 0.123112
# Article 700:	Length: 1240	Avg Compression: 0.124704
# Article 710:	Length: 1319	Avg Compression: 0.123428
# Article 720:	Length: 1382	Avg Compression: 0.124985
# Article 730:	Length: 1472	Avg Compression: 0.124041
# Article 740:	Length: 1553	Avg Compression: 0.126048
# Article 750:	Length: 1618	Avg Compression: 0.126632
# Article 760:	Length: 1684	Avg Compression: 0.127040
# Article 770:	Length: 1736	Avg Compression: 0.126993
# Article 780:	Length: 1762	Avg Compression: 0.126907
# Article 790:	Length: 1850	Avg Compression: 0.126028
# Article 800:	Length: 1900	Avg Compression: 0.125624
# Article 810:	Length: 2003	Avg Compression: 0.125535
# Article 820:	Length: 2042	Avg Compression: 0.125419
# Article 830:	Length: 2113	Avg Compression: 0.127089
# Article 840:	Length: 2149	Avg Compression: 0.127676
# Article 850:	Length: 2204	Avg Compression: 0.127010
# Article 860:	Length: 2217	Avg Compression: 0.126214
# Article 870:	Length: 2256	Avg Compression: 0.125827
# Article 880:	Length: 2368	Avg Compression: 0.125670
# Article 890:	Length: 2415	Avg Compression: 0.125575
# Article 900:	Length: 2515	Avg Compression: 0.125809
# Article 910:	Length: 2546	Avg Compression: 0.127007
# Article 920:	Length: 2570	Avg Compression: 0.126818
# Article 930:	Length: 2676	Avg Compression: 0.127564
# Article 940:	Length: 2794	Avg Compression: 0.127720
# Article 950:	Length: 2899	Avg Compression: 0.128000
# Article 960:	Length: 2993	Avg Compression: 0.128316
# Article 970:	Length: 3024	Avg Compression: 0.128024
# Article 980:	Length: 3203	Avg Compression: 0.127594
# Article 990:	Length: 3324	Avg Compression: 0.127335
# Article 1000:	Length: 3403	Avg Compression: 0.127542
# Article 1010:	Length: 3541	Avg Compression: 0.128197
# Article 1020:	Length: 3552	Avg Compression: 0.128391
# Article 1030:	Length: 3627	Avg Compression: 0.128611
# Article 1040:	Length: 3740	Avg Compression: 0.128585
# Article 1050:	Length: 3825	Avg Compression: 0.128838
# Article 1060:	Length: 3811	Avg Compression: 0.128905
# Article 1070:	Length: 4004	Avg Compression: 0.128573
# Article 1080:	Length: 4127	Avg Compression: 0.128590
# Article 1090:	Length: 4184	Avg Compression: 0.128494
# Article 1100:	Length: 4317	Avg Compression: 0.128186
# Article 1110:	Length: 4408	Avg Compression: 0.128568
# Article 1120:	Length: 4515	Avg Compression: 0.127636
# Article 1130:	Length: 4556	Avg Compression: 0.127491
# Article 1140:	Length: 4681	Avg Compression: 0.127810
# Article 1150:	Length: 4803	Avg Compression: 0.127935
# Article 1160:	Length: 4835	Avg Compression: 0.127830
# Article 1170:	Length: 5027	Avg Compression: 0.128624
# Article 1180:	Length: 5185	Avg Compression: 0.128903
# Article 1190:	Length: 5327	Avg Compression: 0.129564
# Article 1200:	Length: 5436	Avg Compression: 0.129828
# Article 1210:	Length: 5635	Avg Compression: 0.130597
# Article 1220:	Length: 5858	Avg Compression: 0.130840
# Article 1230:	Length: 6076	Avg Compression: 0.130653
# Article 1240:	Length: 6283	Avg Compression: 0.130870
# Article 1250:	Length: 6409	Avg Compression: 0.131264
# Article 1260:	Length: 6566	Avg Compression: 0.131490
# Article 1270:	Length: 6711	Avg Compression: 0.131671
# Article 1280:	Length: 6830	Avg Compression: 0.131417
# Article 1290:	Length: 6930	Avg Compression: 0.130775
# Article 1300:	Length: 7040	Avg Compression: 0.130919
# Article 1310:	Length: 7331	Avg Compression: 0.130331
# Article 1320:	Length: 7563	Avg Compression: 0.130694
# Article 1330:	Length: 7797	Avg Compression: 0.129591
# Article 1340:	Length: 7980	Avg Compression: 0.129762
# Article 1350:	Length: 8247	Avg Compression: 0.129980
# Article 1360:	Length: 8391	Avg Compression: 0.129889
# Article 1370:	Length: 8600	Avg Compression: 0.130358
# Article 1380:	Length: 8822	Avg Compression: 0.130965
# Article 1390:	Length: 9054	Avg Compression: 0.130566
# Article 1400:	Length: 9344	Avg Compression: 0.130967
# Article 1410:	Length: 9474	Avg Compression: 0.130978
# Article 1420:	Length: 9796	Avg Compression: 0.131698
# Article 1430:	Length: 10017	Avg Compression: 0.131053
# Article 1440:	Length: 10226	Avg Compression: 0.131063
# Article 1450:	Length: 10592	Avg Compression: 0.130260
# Article 1460:	Length: 10985	Avg Compression: 0.129676
# Article 1470:	Length: 11095	Avg Compression: 0.129938
# Article 1480:	Length: 11213	Avg Compression: 0.130146
# Article 1490:	Length: 11483	Avg Compression: 0.130224
# Article 1500:	Length: 11793	Avg Compression: 0.130645
# Article 1510:	Length: 12145	Avg Compression: 0.130719
# Article 1520:	Length: 12344	Avg Compression: 0.130009
# Article 1530:	Length: 12628	Avg Compression: 0.129374
# Article 1540:	Length: 12877	Avg Compression: 0.128758
# Article 1550:	Length: 13304	Avg Compression: 0.128879
# Article 1560:	Length: 13458	Avg Compression: 0.128310
# Article 1570:	Length: 13744	Avg Compression: 0.128388
# Article 1580:	Length: 14077	Avg Compression: 0.127866
# Article 1590:	Length: 14498	Avg Compression: 0.127394
# Article 1600:	Length: 14754	Avg Compression: 0.127406
# Article 1610:	Length: 15109	Avg Compression: 0.126944
# Article 1620:	Length: 15406	Avg Compression: 0.126757
# Article 1630:	Length: 15644	Avg Compression: 0.126720
# Article 1640:	Length: 16120	Avg Compression: 0.126298
# Article 1650:	Length: 16602	Avg Compression: 0.126138
# Article 1660:	Length: 16823	Avg Compression: 0.125653
# Article 1670:	Length: 17684	Avg Compression: 0.125502
# Article 1680:	Length: 18309	Avg Compression: 0.125229
# Article 1690:	Length: 18980	Avg Compression: 0.125401
# Article 1700:	Length: 19631	Avg Compression: 0.125847
# Article 1710:	Length: 20178	Avg Compression: 0.126605
# Article 1720:	Length: 20526	Avg Compression: 0.127528
# Article 1730:	Length: 21808	Avg Compression: 0.128492
# Article 1740:	Length: 23634	Avg Compression: 0.128349
# Article 1750:	Length: 24385	Avg Compression: 0.128701
# Article 1760:	Length: 25324	Avg Compression: 0.129135
# Article 1770:	Length: 26645	Avg Compression: 0.129614
# Article 1780:	Length: 27555	Avg Compression: 0.130475
# Article 1790:	Length: 28718	Avg Compression: 0.131492
# Article 1800:	Length: 30788	Avg Compression: 0.131856
# Article 1810:	Length: 31413	Avg Compression: 0.132774
# Article 1820:	Length: 33542	Avg Compression: 0.133434
# Article 1830:	Length: 35399	Avg Compression: 0.133393
# Article 1840:	Length: 38421	Avg Compression: 0.134309
# Article 1850:	Length: 40396	Avg Compression: 0.134460
# Article 1860:	Length: 42647	Avg Compression: 0.134956
# Article 1870:	Length: 47756	Avg Compression: 0.135394
# Article 1880:	Length: 55234	Avg Compression: 0.134861
# Article 1890:	Length: 63612	Avg Compression: 0.135383

# %% [markdown]
# ............................

# %%
def loss(labels, logits):
    return tf.keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)

def average_final_batch_ratio(true_labels, predictions):
    return 0 ** tf.math.abs(true_labels[-1, -1])

class ModelStateResetter(tf.keras.callbacks.Callback):
    def __init__(self):
        pass

    def on_epoch_begin(self, epoch, logs=None):
        self.last_final_batch_count = 0
        
    def on_batch_end(self, batch, logs={}):
        average_final_batch_ratio = logs.get('average_final_batch_ratio', 0)
        final_batch_count = int(round(average_final_batch_ratio * (batch + 1)))
        is_final = final_batch_count - self.last_final_batch_count
        self.last_final_batch_count = final_batch_count
        
        if is_final:
            self.model.reset_states()

class Model:
    def __init__(self, articles, checkpoint_dir, vocab_size, embedding_dim, rnn_units):
        self._articles = articles
        self._batch_size = None
        self._batched_item_length = None
        self._training_model = None
        self._predicting_model = None
        self._vocab_size = vocab_size
        self._embedding_dim = embedding_dim
        self._rnn_units = rnn_units

        self._checkpoint_dir = checkpoint_dir
        self._checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt_{epoch}") # Name of the checkpoint files

    def training_model(self, batch_size, batched_item_length):
        if self._training_model == None or batch_size != self._batch_size or batched_item_length != self._batched_item_length:
            self._batch_size = batch_size
            self._batched_item_length = batched_item_length
            self._training_model = tf.keras.Sequential([
                tf.keras.layers.Masking(mask_value=0, batch_input_shape=[batch_size, batched_item_length]),
                tf.keras.layers.Embedding(self._vocab_size, self._embedding_dim),
                tf.keras.layers.LSTM(self._rnn_units, return_sequences=True, stateful=True, recurrent_initializer='glorot_uniform'),
                tf.keras.layers.LSTM(self._rnn_units, return_sequences=True, stateful=True, recurrent_initializer='glorot_uniform'),
                tf.keras.layers.Dense(self._vocab_size),
            ])

            if os.path.isdir(self._checkpoint_dir):
                self._training_model.load_weights(tf.train.latest_checkpoint(self._checkpoint_dir))

            self._training_model.compile(optimizer='adam', loss=loss, metrics=[average_final_batch_ratio])
            self._predicting_model = None
        
        return self._training_model

    @property
    def callbacks(self):
        checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=self._checkpoint_prefix, save_weights_only=True)
        model_state_resetter_callback = ModelStateResetter()
        
        return [checkpoint_callback, model_state_resetter_callback]
    
    def train(self, batch_size, batched_item_length, epochs=1):
        dataset = self._articles.dataset(batch_size, batched_item_length)

        model = self.training_model(batch_size, batched_item_length)

        model.fit(dataset, epochs=epochs, callbacks=self.callbacks)
    
    @property
    def predicting_model(self):
        if self._predicting_model == None:
            self._predicting_model = tf.keras.Sequential([
                tf.keras.layers.Masking(mask_value=0, batch_input_shape=[1, 1]),
                tf.keras.layers.Embedding(self._vocab_size, self._embedding_dim),
                tf.keras.layers.LSTM(self._rnn_units, stateful=True, return_sequences=True),
                tf.keras.layers.LSTM(self._rnn_units, stateful=True, return_sequences=True),
                tf.keras.layers.Dense(self._vocab_size),
            ])
            
            self._predicting_model.load_weights(tf.train.latest_checkpoint(self._checkpoint_dir))
            self._training_model = None
        
        return self._predicting_model
    
    def predict(self, input_eval):
        return self.predicting_model(input_eval)

# %%
model = Model(articles, './training_checkpoints-17',
              vocab_size = subword_text_encoder.vocab_size,
              embedding_dim=256,
              rnn_units=1024)

# %%
model.training_model(192, 256).summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# masking (Masking)            (192, 256)                0
# _________________________________________________________________
# embedding (Embedding)        (192, 256, 256)           1036288
# _________________________________________________________________
# lstm (LSTM)                  (192, 256, 1024)          5246976
# _________________________________________________________________
# lstm_1 (LSTM)                (192, 256, 1024)          8392704
# _________________________________________________________________
# dense (Dense)                (192, 256, 4048)          4149200
# =================================================================
# Total params: 18,825,168
# Trainable params: 18,825,168
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.train(192, 256, epochs=100)
# Out:
# Epoch 1/100
# 203/203 [==============================] - 181s 890ms/step - loss: 4.5341 - average_final_batch_ratio: 0.1182
# Epoch 2/100
# 203/203 [==============================] - 183s 902ms/step - loss: 4.1103 - average_final_batch_ratio: 0.1182
# Epoch 3/100
# 203/203 [==============================] - 183s 900ms/step - loss: 4.0277 - average_final_batch_ratio: 0.1182
# Epoch 4/100
# 203/203 [==============================] - 182s 899ms/step - loss: 4.1291 - average_final_batch_ratio: 0.1182
# Epoch 5/100
# 203/203 [==============================] - 184s 906ms/step - loss: 4.2063 - average_final_batch_ratio: 0.1182
# Epoch 6/100
# 203/203 [==============================] - 184s 905ms/step - loss: 4.1629 - average_final_batch_ratio: 0.1182
# Epoch 7/100
# 203/203 [==============================] - 183s 902ms/step - loss: 4.0687 - average_final_batch_ratio: 0.1182
# Epoch 8/100
# 203/203 [==============================] - 183s 902ms/step - loss: 4.2870 - average_final_batch_ratio: 0.1182
# Epoch 9/100
# 203/203 [==============================] - 182s 898ms/step - loss: 3.7101 - average_final_batch_ratio: 0.1182
# Epoch 10/100
# 203/203 [==============================] - 182s 899ms/step - loss: 3.1666 - average_final_batch_ratio: 0.1182
# Epoch 11/100
# 203/203 [==============================] - 181s 893ms/step - loss: 2.8593 - average_final_batch_ratio: 0.1182
# Epoch 12/100
# 203/203 [==============================] - 183s 903ms/step - loss: 2.6592 - average_final_batch_ratio: 0.1182
# Epoch 13/100
# 203/203 [==============================] - 182s 898ms/step - loss: 2.5314 - average_final_batch_ratio: 0.1182
# Epoch 14/100
# 203/203 [==============================] - 182s 898ms/step - loss: 2.4292 - average_final_batch_ratio: 0.1182
# Epoch 15/100
# 203/203 [==============================] - 183s 901ms/step - loss: 2.3341 - average_final_batch_ratio: 0.1182
# Epoch 16/100
# 203/203 [==============================] - 185s 913ms/step - loss: 2.2603 - average_final_batch_ratio: 0.1182
# Epoch 17/100
# 203/203 [==============================] - 184s 907ms/step - loss: 2.1863 - average_final_batch_ratio: 0.1182
# Epoch 18/100
# 203/203 [==============================] - 182s 899ms/step - loss: 2.1223 - average_final_batch_ratio: 0.1182
# Epoch 19/100
# 203/203 [==============================] - 186s 915ms/step - loss: 2.0733 - average_final_batch_ratio: 0.1182
# Epoch 20/100
# 203/203 [==============================] - 184s 908ms/step - loss: 2.0168 - average_final_batch_ratio: 0.1182
# Epoch 21/100
# 203/203 [==============================] - 185s 913ms/step - loss: 1.9683 - average_final_batch_ratio: 0.1182
# Epoch 22/100
# 203/203 [==============================] - 184s 905ms/step - loss: 1.9240 - average_final_batch_ratio: 0.1182
# Epoch 23/100
# 203/203 [==============================] - 183s 904ms/step - loss: 1.8869 - average_final_batch_ratio: 0.1182
# Epoch 24/100
# 203/203 [==============================] - 183s 903ms/step - loss: 1.8503 - average_final_batch_ratio: 0.1182
# Epoch 25/100
# 203/203 [==============================] - 183s 900ms/step - loss: 1.8196 - average_final_batch_ratio: 0.1182
# Epoch 26/100
# 203/203 [==============================] - 185s 912ms/step - loss: 1.7889 - average_final_batch_ratio: 0.1182
# Epoch 27/100
# 203/203 [==============================] - 189s 929ms/step - loss: 1.7563 - average_final_batch_ratio: 0.1182
# Epoch 28/100
# 203/203 [==============================] - 192s 944ms/step - loss: 1.7339 - average_final_batch_ratio: 0.1182
# Epoch 29/100
# 203/203 [==============================] - 187s 920ms/step - loss: 1.7028 - average_final_batch_ratio: 0.1182

# %%
model.train(192, 256, epochs=71)
# Out:
# Epoch 1/71
# 203/203 [==============================] - 186s 916ms/step - loss: 1.6764 - average_final_batch_ratio: 0.1182
# Epoch 2/71

# %%
model.train(192, 192, epochs=70)
# Out:
# Epoch 1/70
# 271/271 [==============================] - 188s 694ms/step - loss: 1.6594 - average_final_batch_ratio: 0.1144
# Epoch 2/70
# 271/271 [==============================] - 185s 683ms/step - loss: 1.6239 - average_final_batch_ratio: 0.1144
