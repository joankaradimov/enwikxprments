# %%
import html
import re

import tensorflow_datasets as tfds

class SubalphabetSubwordTextEncoder:
    HTML_ESCAPE_PATTERN = re.compile('&(((#\d+)|([A-Za-z]+));&?)+')
    SPECIAL_CHAR = 'X'

    def __init__(self, subalphabet, vocab_list=None):
        self._subword_text_encoder = tfds.features.text.SubwordTextEncoder(vocab_list)
        self._subalphabet = subalphabet

    def encode(self, s):
        subword_max_code = len(self.subwords)
        codes = self._build_encoding_dict(self._subalphabet)
        preprocessed_string = self.preprocess_string(s)

        result = []
        unicode_buffer = bytearray()
        for id in self._subword_text_encoder.encode(preprocessed_string):
            if id <= subword_max_code:
                result.append(id)
            else:
                unicode_buffer.append(id - subword_max_code - 1)
                try:
                    id = ord(unicode_buffer.decode())
                    result.append(subword_max_code + codes[id] + 1)
                    unicode_buffer = bytearray()
                except UnicodeDecodeError:
                    pass
        return result

    def decode(self, ids):
        subword_max_code = len(self.subwords)

        processed_ids = []
        for id in ids:
            if id <= subword_max_code:
                processed_ids.append(id)
            else:
                char = self._subalphabet[id - subword_max_code - 1].encode()
                processed_ids += [codepoint + subword_max_code + 1 for codepoint in char]

        return self._subword_text_encoder.decode(processed_ids)
    
    @classmethod
    def build_from_corpus(cls, corpus_generator, subalphabet_size, target_vocab_size, max_subword_length=20, max_corpus_chars=None, reserved_tokens=None):
        simplified_strings = []
        char_counts = defaultdict(lambda: 0)

        for string in corpus_generator:
            simplified_string = cls._unescape_string(string.lower())
            simplified_strings.append(simplified_string)
            for char in simplified_string:
                char_counts[char] += 1

        sorted_char_counts = sorted(char_counts.items(), key = lambda item: item[1], reverse = True)
        chars = [char for char, char_count in sorted_char_counts[:subalphabet_size - 1]]
        chars = list(reversed(chars)) # We reverse the chars so that the most common ones are last
        chars = cls._ensure_special_character_presence(chars)

        def simplified_corpus():
            for string in simplified_strings:
                yield cls._compact_string(chars, string)

        subword_text_encoder = tfds.features.text.SubwordTextEncoder.build_from_corpus(simplified_corpus(), target_vocab_size + 256 - subalphabet_size)
        
        return cls(chars, subword_text_encoder.subwords)
    
    @classmethod
    def load_from_file(cls, filename_prefix):
        subword_text_encoder = tfds.features.text.SubwordTextEncoder.load_from_file(filename_prefix)
        with open(filename_prefix + '.subalphabet', 'rb') as text_file:
            subalphabet = ['\0', cls.SPECIAL_CHAR] + text_file.read().decode().split('\0')

        return cls(subalphabet, subword_text_encoder.subwords)
    
    def save_to_file(self, filename_prefix):
        self._subword_text_encoder.save_to_file(filename_prefix)
        with open(filename_prefix + '.subalphabet', 'wb') as text_file:
            text_file.write('\0'.join(self._subalphabet[2:]).encode())

    def preprocess_string(self, string):
        return self._compact_string(self._subalphabet, self._unescape_string(string.lower()))

    @property
    def vocab_size(self):
        return self._subword_text_encoder.vocab_size - 256 + len(self._subalphabet)
    
    @property
    def subwords(self):
        return self._subword_text_encoder.subwords

    @classmethod
    def _ensure_special_character_presence(cls, chars):
        if '\0' in chars:
            chars = [char for char in chars if char != '\0']
        else:
            chars = chars[1:]

        return ['\0', cls.SPECIAL_CHAR] + chars
    
    @classmethod
    def _unescape_html_symbol(cls, escaped):
        escaped_symbols = escaped.group(0).split(';')
        escaped_symbols = escaped_symbols[:-1] # strip the last string empty string
        escaped_symbols = (escaped_symbol + ';' for escaped_symbol in escaped_symbols)
        result = ''

        for escaped_symbol in escaped_symbols:
            code = escaped_symbol[1:] if escaped_symbol[0] == '&' else escaped_symbol

            if code[0] == '#':
                result += chr(int(code[1:-1]))
            elif code in html.entities.html5:
                result += html.entities.html5[code]
            else:
                result += escaped_symbol

        return result
    
    @classmethod
    def _unescape_string(cls, string):
        return cls.HTML_ESCAPE_PATTERN.sub(cls._unescape_html_symbol, string)
    
    @classmethod
    def _compact_string(cls, chars, string):
        if len(string) == 0:
            return string
        else:
            compacted_string = string[0]

            for char in string[1:]:
                if char not in chars or char == cls.SPECIAL_CHAR:
                    if compacted_string[-1] != cls.SPECIAL_CHAR:
                        compacted_string += cls.SPECIAL_CHAR
                else:
                    compacted_string += char

            return compacted_string
    
    @classmethod
    def _build_encoding_dict(cls, chars):
        return {ord(char): index for index, char in enumerate(chars)}

# %%
encoder = SubalphabetSubwordTextEncoder.load_from_file('72_1024')

# %%
import itertools
import math
import os

import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds

physical_devices = tf.config.list_physical_devices('GPU')
for physical_device in physical_devices:
    tf.config.experimental.set_memory_growth(physical_device, enable=True)

# %%
TYPE=np.int16

class Articles:
    EMPTY_ARTICLE = np.array([], dtype=TYPE) # used for padding
    
    def __init__(self, path):
        with open(path, 'rb') as text_file:
            data = text_file.read().decode()

        self.articles = sorted(set(data.split('\0')[:20000]), key=len)
        self._encoded_articles = None

    @property
    def encoded_articles(self):
        if self._encoded_articles == None:
            self._encoded_articles = [np.array(encoder.encode(article), dtype=TYPE) for article in self.articles]
        
        return self._encoded_articles

    def articles_generator(self, batch_size = 1, start = 0, end = None):
        end = end or len(self.articles)

        for _ in range(batch_size - ((end - start - 1) % batch_size + 1)):
            yield self.EMPTY_ARTICLE

        for article in itertools.islice(self.encoded_articles, start, end):
            yield article

    def subbatch_generator(self, batch_size, batch_length, start = 0, end = None):
        end = end or len(self.articles)

        dataset = tf.data.Dataset.from_generator(self.articles_generator, args=(batch_size, start, end), output_types=TYPE)
        dataset = dataset.padded_batch(batch_size, padded_shapes=([None]), drop_remainder=True)
        dataset = dataset.shuffle(100)

        for batch in dataset.as_numpy_iterator():
            remaining = batch
            while remaining.shape[1] > batch_length + 1:
                yield remaining[:, :batch_length + 1]
                remaining = remaining[:, batch_length:]

            if remaining.shape[1] == batch_length + 1:
                yield remaining
                yield np.zeros((batch_size, batch_length + 1), dtype=TYPE)
            else:
                yield np.hstack([remaining, np.zeros([batch_size, batch_length - remaining.shape[1] + 1])])

    def steps(self, batch_size, batch_length):
        articles = self.articles_generator(batch_size, batch_length)
        return sum(math.ceil(len(article) / batch_length + 1) for i, article in enumerate(articles) if (i + 1) % batch_size == 0)

    def dataset(self, batch_size, batch_length, start = 0, end = None):
        end = end or len(self.articles)

        dataset = tf.data.Dataset.from_generator(self.subbatch_generator, args=(batch_size, batch_length, start, end), output_types=TYPE, output_shapes=(batch_size, batch_length + 1))
        return dataset.map(lambda batch: (batch[:, :-1], batch[:, 1:]))

# %%
def loss(labels, logits):
    return tf.keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)

def average_final_batch_ratio(true_labels, predictions):
    return 0 ** tf.math.abs(true_labels[-1, -1])

class ModelStateResetter(tf.keras.callbacks.Callback):
    def __init__(self):
        pass

    def on_epoch_begin(self, epoch, logs=None):
        self.last_final_batch_count = 0
        
    def on_batch_end(self, batch, logs={}):
        average_final_batch_ratio = logs.get('average_final_batch_ratio', 0)
        final_batch_count = int(round(average_final_batch_ratio * (batch + 1)))
        is_final = final_batch_count - self.last_final_batch_count
        self.last_final_batch_count = final_batch_count
        
        if is_final:
            self.model.reset_states()

class Model:
    def __init__(self, articles, checkpoint_dir, vocab_size, embedding_dim, rnn_units):
        self._articles = articles
        self._batch_size = None
        self._batched_item_length = None
        self._training_model = None
        self._predicting_model = None
        self._vocab_size = vocab_size
        self._embedding_dim = embedding_dim
        self._rnn_units = rnn_units

        self._checkpoint_dir = checkpoint_dir
        self._checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt_{epoch}") # Name of the checkpoint files

    def training_model(self, batch_size, batched_item_length):
        if self._training_model == None or batch_size != self._batch_size or batched_item_length != self._batched_item_length:
            self._batch_size = batch_size
            self._batched_item_length = batched_item_length
            self._training_model = tf.keras.Sequential([
                tf.keras.layers.Masking(mask_value=0, batch_input_shape=[batch_size, batched_item_length]),
                tf.keras.layers.Embedding(self._vocab_size, self._embedding_dim),
                tf.keras.layers.GRU(self._rnn_units, return_sequences=True, stateful=True, recurrent_initializer='glorot_uniform'),
                tf.keras.layers.GRU(self._rnn_units, return_sequences=True, stateful=True, recurrent_initializer='glorot_uniform'),
                tf.keras.layers.Dense(self._vocab_size),
            ])

            if os.path.isdir(self._checkpoint_dir):
                self._training_model.load_weights(tf.train.latest_checkpoint(self._checkpoint_dir))

            self._training_model.compile(optimizer='adam', loss=loss, metrics=[average_final_batch_ratio])
            self._predicting_model = None
        
        return self._training_model

    @property
    def callbacks(self):
        checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=self._checkpoint_prefix, save_weights_only=True)
        model_state_resetter_callback = ModelStateResetter()
        
        return [checkpoint_callback, model_state_resetter_callback]
    
    def train(self, batch_size, batched_item_length, epochs=1):
        dataset = self._articles.dataset(batch_size, batched_item_length)

        model = self.training_model(batch_size, batched_item_length)

        model.fit(dataset, epochs=epochs, callbacks=self.callbacks)
    
    @property
    def predicting_model(self):
        if self._predicting_model == None:
            self._predicting_model = tf.keras.Sequential([
                tf.keras.layers.Masking(mask_value=0, batch_input_shape=[1, 1]),
                tf.keras.layers.Embedding(self._vocab_size, self._embedding_dim),
                tf.keras.layers.GRU(self._rnn_units, stateful=True, return_sequences=True),
                tf.keras.layers.GRU(self._rnn_units, stateful=True, return_sequences=True),
                tf.keras.layers.Dense(self._vocab_size),
            ])
            
            self._predicting_model.load_weights(tf.train.latest_checkpoint(self._checkpoint_dir))
            self._training_model = None
        
        return self._predicting_model
    
    def predict(self, input_eval):
        return self.predicting_model(input_eval)

# %%
articles = Articles('page_revisions_text_with_title')

# %%
model = Model(articles, './training_checkpoints-25', vocab_size = encoder.vocab_size, embedding_dim=64, rnn_units=1024)

# %%
model.training_model(256, 192).summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# masking (Masking)            (256, 192)                0
# _________________________________________________________________
# embedding (Embedding)        (256, 192, 64)            64896
# _________________________________________________________________
# gru (GRU)                    (256, 192, 1024)          3348480
# _________________________________________________________________
# gru_1 (GRU)                  (256, 192, 1024)          6297600
# _________________________________________________________________
# dense (Dense)                (256, 192, 1014)          1039350
# =================================================================
# Total params: 10,750,326
# Trainable params: 10,750,326
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.train(256, 192, epochs=5)
# Out:
# Epoch 1/5
# 1950/1950 [==============================] - 1257s 645ms/step - loss: 4.7023 - average_final_batch_ratio: 0.1928
# Epoch 2/5
# 1950/1950 [==============================] - 1043s 535ms/step - loss: 4.5976 - average_final_batch_ratio: 0.1928
# Epoch 3/5
# 1950/1950 [==============================] - 1041s 534ms/step - loss: 4.5240 - average_final_batch_ratio: 0.1928
# Epoch 4/5
# 1950/1950 [==============================] - 1027s 527ms/step - loss: 4.5090 - average_final_batch_ratio: 0.1928
# Epoch 5/5
# 1950/1950 [==============================] - 1040s 533ms/step - loss: 4.4543 - average_final_batch_ratio: 0.1928

# %%
import ctypes

class Huffman:
    huffman = ctypes.CDLL('x64/Release/huffman')
    
    huffman.create_tree.restype = ctypes.c_void_p
    huffman.destroy_tree.restype = None
    huffman.load_weights.restype = None
    huffman.create_code_string.restype = ctypes.c_char_p
    
    def __init__(self, category_count):
        self.category_count = category_count
        self.tree = ctypes.c_void_p(self.huffman.create_tree(category_count))

    def __del__(self):
        self.huffman.destroy_tree(self.tree)
        
    def load_weights(self, weights):
        self.huffman.load_weights(self.tree, weights.ctypes.data_as(ctypes.POINTER(ctypes.c_float)))
    
    def get_code_length(self, category):
        return self.huffman.get_code_length(self.tree, category)

    def get_code_zero_count(self, category):
        return self.huffman.get_code_zero_count(self.tree, category)
    
    def archive_size(self, model, text):
        archived_size = math.ceil(math.log2(self.category_count))
        input_eval = np.array([[text[0]]], dtype=TYPE)

        model.predicting_model.reset_states()

        for byte in text[1:]:
            predictions = model.predict(input_eval)
            predictions = tf.squeeze(predictions, 0) # remove the batch dimension

            weights = tf.nn.softmax(predictions[0]).numpy()
            self.load_weights(weights)
            archived_size += self.get_code_length(byte.item())

            input_eval = tf.expand_dims([byte], 0)

        return archived_size

# %%
total_raw = 0
total_compressed = 0

huffman = Huffman(encoder.vocab_size)
for index, encoded_article in enumerate(articles.articles_generator(1)):
    if index % 100 == 0:
        article = encoder.decode(encoded_article)
        if len(article) == 0:
            continue
        total_raw += len(article) * 8
        total_compressed += huffman.archive_size(model, encoded_article)
        print('Article %d:\tLength: %d\tAvg Compression: %f' % (index, len(article), total_compressed/total_raw))
# Out:
# Article 0:	Length: 12	Avg Compression: 0.572917
# Article 100:	Length: 28	Avg Compression: 0.590625
# Article 200:	Length: 30	Avg Compression: 0.580357
# Article 300:	Length: 31	Avg Compression: 0.606436
# Article 400:	Length: 32	Avg Compression: 0.612782
# Article 500:	Length: 33	Avg Compression: 0.608434
# Article 600:	Length: 34	Avg Compression: 0.613750
# Article 700:	Length: 35	Avg Compression: 0.608511
# Article 800:	Length: 36	Avg Compression: 0.613930
# Article 900:	Length: 37	Avg Compression: 0.602679
# Article 1000:	Length: 38	Avg Compression: 0.600072
# Article 17800:	Length: 20117	Avg Compression: 0.525570
# Article 17900:	Length: 20626	Avg Compression: 0.525664
# Article 18000:	Length: 20350	Avg Compression: 0.525926
# Article 18100:	Length: 22076	Avg Compression: 0.526130
# Article 18200:	Length: 22940	Avg Compression: 0.526351
# Article 18300:	Length: 23355	Avg Compression: 0.526085
# Article 18400:	Length: 24560	Avg Compression: 0.527909
# Article 18500:	Length: 25488	Avg Compression: 0.527687
# Article 18600:	Length: 26439	Avg Compression: 0.527599
# Article 18700:	Length: 27252	Avg Compression: 0.527505
# Article 18800:	Length: 28415	Avg Compression: 0.528461
# Article 18900:	Length: 29287	Avg Compression: 0.528383
# Article 19000:	Length: 30865	Avg Compression: 0.528183
# Article 19100:	Length: 32381	Avg Compression: 0.528123
# Article 19200:	Length: 34164	Avg Compression: 0.527885
# Article 19300:	Length: 35990	Avg Compression: 0.527970
# Article 19400:	Length: 38524	Avg Compression: 0.527471
# Article 19500:	Length: 41139	Avg Compression: 0.527592
# Article 19600:	Length: 43795	Avg Compression: 0.527675
# Article 19700:	Length: 47945	Avg Compression: 0.527690
# Article 19800:	Length: 52573	Avg Compression: 0.528044
# Article 19900:	Length: 61215	Avg Compression: 0.527741

# %%
model.train(256, 192, epochs=10)
# Out:
# Epoch 1/10
# 1950/1950 [==============================] - 1033s 530ms/step - loss: 4.4650 - average_final_batch_ratio: 0.1928
# Epoch 2/10
# 1950/1950 [==============================] - 1045s 536ms/step - loss: 4.4707 - average_final_batch_ratio: 0.1928
# Epoch 3/10
# 1950/1950 [==============================] - 1068s 548ms/step - loss: 4.1584 - average_final_batch_ratio: 0.1928
# Epoch 4/10
# 1950/1950 [==============================] - 1076s 552ms/step - loss: 3.3820 - average_final_batch_ratio: 0.1928
# Epoch 5/10
# 1950/1950 [==============================] - 1073s 550ms/step - loss: 3.0172 - average_final_batch_ratio: 0.1928
# Epoch 6/10
#    1/1950 [..............................] - ETA: 29:51
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-16-278db9904967> in <module>
# ----> 1 model.train(256, 192, epochs=10)
#
# <ipython-input-8-74936f3ed6d5> in train(self, batch_size, batched_item_length, epochs)
#      67         model = self.training_model(batch_size, batched_item_length)
#      68
# ---> 69         model.fit(dataset, epochs=epochs, callbacks=self.callbacks)
#      70
#      71     @property
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     395                       total_epochs=1)
#     396                   cbks.make_logs(model, epoch_logs, eval_result, ModeKeys.TEST,
# --> 397                                  prefix='val_')
#     398
#     399     return model.history
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\contextlib.py in __exit__(self, type, value, traceback)
#     128                 value = type()
#     129             try:
# --> 130                 self.gen.throw(type, value, traceback)
#     131             except StopIteration as exc:
#     132                 # Suppress StopIteration *unless* it's the same exception that
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in on_epoch(self, epoch, mode)
#     769       if mode == ModeKeys.TRAIN:
#     770         # Epochs only apply to `fit`.
# --> 771         self.callbacks.on_epoch_end(epoch, epoch_logs)
#     772       self.progbar.on_epoch_end(epoch, epoch_logs)
#     773
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     300     logs = logs or {}
#     301     for callback in self.callbacks:
# --> 302       callback.on_epoch_end(epoch, logs)
#     303
#     304   def on_train_batch_begin(self, batch, logs=None):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     990           self._save_model(epoch=epoch, logs=logs)
#     991       else:
# --> 992         self._save_model(epoch=epoch, logs=logs)
#     993     if self.model._in_multi_worker_mode():
#     994       # For multi-worker training, back up the weights and current training
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\callbacks.py in _save_model(self, epoch, logs)
#    1036             print('\nEpoch %05d: saving model to %s' % (epoch + 1, filepath))
#    1037           if self.save_weights_only:
# -> 1038             self.model.save_weights(filepath, overwrite=True)
#    1039           else:
#    1040             self.model.save(filepath, overwrite=True)
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\network.py in save_weights(self, filepath, overwrite, save_format)
#    1121              'saved.\n\nConsider using a TensorFlow optimizer from `tf.train`.')
#    1122             % (optimizer,))
# -> 1123       self._trackable_saver.save(filepath, session=session)
#    1124       # Record this checkpoint so it's visible from tf.train.latest_checkpoint.
#    1125       checkpoint_management.update_checkpoint_state_internal(
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\tracking\util.py in save(self, file_prefix, checkpoint_number, session)
#    1166     file_io.recursive_create_dir(os.path.dirname(file_prefix))
#    1167     save_path, new_feed_additions = self._save_cached_when_graph_building(
# -> 1168         file_prefix=file_prefix_tensor, object_graph_tensor=object_graph_tensor)
#    1169     if new_feed_additions:
#    1170       feed_dict.update(new_feed_additions)
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\tracking\util.py in _save_cached_when_graph_building(self, file_prefix, object_graph_tensor)
#    1114         or context.executing_eagerly() or ops.inside_function()):
#    1115       saver = functional_saver.MultiDeviceSaver(named_saveable_objects)
# -> 1116       save_op = saver.save(file_prefix)
#    1117       with ops.device("/cpu:0"):
#    1118         with ops.control_dependencies([save_op]):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\functional_saver.py in save(self, file_prefix)
#     228         # _SingleDeviceSaver will use the CPU device when necessary, but initial
#     229         # read operations should be placed on the SaveableObject's device.
# --> 230         sharded_saves.append(saver.save(shard_prefix))
#     231
#     232     with ops.control_dependencies(sharded_saves):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\functional_saver.py in save(self, file_prefix)
#      67       for spec in saveable.specs:
#      68         tensor_names.append(spec.name)
# ---> 69         tensors.append(spec.tensor)
#      70         tensor_slices.append(spec.slice_spec)
#      71     with ops.device("cpu:0"):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\saveable_object.py in tensor(self)
#      50   @property
#      51   def tensor(self):
# ---> 52     return self._tensor() if callable(self._tensor) else self._tensor
#      53
#      54
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\saveable_object_util.py in f()
#      93             # we copy them to CPU on the same machine first.
#      94             with ops.device("/device:CPU:0"):
# ---> 95               return array_ops.identity(x)
#      96         return f
#      97
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\util\dispatch.py in wrapper(*args, **kwargs)
#     178     """Call target, and fall back on dispatchers if there is a TypeError."""
#     179     try:
# --> 180       return target(*args, **kwargs)
#     181     except (TypeError, ValueError):
#     182       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\ops\array_ops.py in identity(input, name)
#     265     # variables. Variables have correct handle data when graph building.
#     266     input = ops.convert_to_tensor(input)
# --> 267   ret = gen_array_ops.identity(input, name=name)
#     268   # Propagate handle data for happier shape inference for resource variables.
#     269   if hasattr(input, "_handle_data"):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\ops\gen_array_ops.py in identity(input, name)
#    3824         pass  # Add nodes to the TensorFlow graph.
#    3825     except _core._NotOkStatusException as e:
# -> 3826       _ops.raise_from_not_ok_status(e, name)
#    3827   # Add nodes to the TensorFlow graph.
#    3828   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\framework\ops.py in raise_from_not_ok_status(e, name)
#    6604   message = e.message + (" name: " + name if name is not None else "")
#    6605   # pylint: disable=protected-access
# -> 6606   six.raise_from(core._status_to_exception(e.code, message), None)
#    6607   # pylint: enable=protected-access
#    6608
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\six.py in raise_from(value, from_value)
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:GPU:0 to /job:localhost/replica:0/task:0/device:CPU:0 in order to run Identity: GPU sync failed [Op:Identity]

# %%
total_raw = 0
total_compressed = 0

huffman = Huffman(encoder.vocab_size)
for index, encoded_article in enumerate(articles.articles_generator(1)):
    if index % 100 == 0:
        article = encoder.decode(encoded_article)
        if len(article) == 0:
            continue
        total_raw += len(article) * 8
        total_compressed += huffman.archive_size(model, encoded_article)
        print('Article %d:\tLength: %d\tAvg Compression: %f' % (index, len(article), total_compressed/total_raw))
# Out:
# Article 0:	Length: 12	Avg Compression: 0.395833
# Article 100:	Length: 28	Avg Compression: 0.409375
# Article 200:	Length: 30	Avg Compression: 0.398214
# Article 300:	Length: 31	Avg Compression: 0.413366
# Article 400:	Length: 32	Avg Compression: 0.403195
# Article 500:	Length: 33	Avg Compression: 0.403614
# Article 600:	Length: 34	Avg Compression: 0.413125
# Article 700:	Length: 35	Avg Compression: 0.406915
# Article 800:	Length: 36	Avg Compression: 0.412362
# Article 900:	Length: 37	Avg Compression: 0.408685
# Article 1000:	Length: 38	Avg Compression: 0.409321
# Article 1100:	Length: 39	Avg Compression: 0.412013
# Article 1200:	Length: 39	Avg Compression: 0.422759
# Article 1300:	Length: 40	Avg Compression: 0.429957
# Article 1400:	Length: 41	Avg Compression: 0.432673
# Article 1500:	Length: 41	Avg Compression: 0.440705
# Article 1600:	Length: 42	Avg Compression: 0.442815
# Article 1700:	Length: 42	Avg Compression: 0.445238
# Article 1800:	Length: 43	Avg Compression: 0.443165
# Article 1900:	Length: 44	Avg Compression: 0.440551
# Article 2000:	Length: 44	Avg Compression: 0.443495
# Article 2100:	Length: 45	Avg Compression: 0.441067
# Article 2200:	Length: 46	Avg Compression: 0.438380
# Article 2300:	Length: 46	Avg Compression: 0.432767
# Article 2400:	Length: 47	Avg Compression: 0.428307
# Article 2500:	Length: 47	Avg Compression: 0.429940
# Article 2600:	Length: 48	Avg Compression: 0.427404
# Article 2700:	Length: 49	Avg Compression: 0.427112
# Article 19400:	Length: 38524	Avg Compression: 0.344623
# Article 19500:	Length: 41139	Avg Compression: 0.344779
# Article 19600:	Length: 43795	Avg Compression: 0.345130
# Article 19700:	Length: 47945	Avg Compression: 0.345692
# Article 19800:	Length: 52573	Avg Compression: 0.345959
# Article 19900:	Length: 61215	Avg Compression: 0.346582

# %%
model.train(256, 192, epochs=5)
# Out:
# Epoch 1/5
# 1950/1950 [==============================] - 1043s 535ms/step - loss: 2.7470 - average_final_batch_ratio: 0.1954
# Epoch 2/5
# 1950/1950 [==============================] - 1046s 536ms/step - loss: 2.5762 - average_final_batch_ratio: 0.1954
# Epoch 3/5
# 1950/1950 [==============================] - 1041s 534ms/step - loss: 2.4526 - average_final_batch_ratio: 0.1954
# Epoch 4/5
# 1950/1950 [==============================] - 1044s 535ms/step - loss: 2.3599 - average_final_batch_ratio: 0.1954
# Epoch 5/5
# 1950/1950 [==============================] - 1037s 532ms/step - loss: 2.2971 - average_final_batch_ratio: 0.1954

# %%
total_raw = 0
total_compressed = 0

huffman = Huffman(encoder.vocab_size)
for index, encoded_article in enumerate(articles.articles_generator(1)):
    if index % 100 == 0:
        article = encoder.decode(encoded_article)
        if len(article) == 0:
            continue
        total_raw += len(article) * 8
        total_compressed += huffman.archive_size(model, encoded_article)
        print('Article %d:\tLength: %d\tAvg Compression: %f' % (index, len(article), total_compressed/total_raw))
# Out:
# Article 0:	Length: 12	Avg Compression: 0.302083
# Article 100:	Length: 28	Avg Compression: 0.253125
# Article 200:	Length: 30	Avg Compression: 0.287500
# Article 300:	Length: 31	Avg Compression: 0.295792
# Article 400:	Length: 32	Avg Compression: 0.296992
# Article 500:	Length: 33	Avg Compression: 0.292922
# Article 600:	Length: 34	Avg Compression: 0.296875
# Article 700:	Length: 35	Avg Compression: 0.296277
# Article 800:	Length: 36	Avg Compression: 0.307196
# Article 900:	Length: 37	Avg Compression: 0.302760
# Article 1000:	Length: 38	Avg Compression: 0.305636
# Article 1100:	Length: 39	Avg Compression: 0.302922
# Article 1200:	Length: 39	Avg Compression: 0.317512
# Article 1300:	Length: 40	Avg Compression: 0.323276
# Article 1400:	Length: 41	Avg Compression: 0.325000
# Article 1500:	Length: 41	Avg Compression: 0.336767
# Article 1600:	Length: 42	Avg Compression: 0.342474
# Article 1700:	Length: 42	Avg Compression: 0.343452
# Article 1800:	Length: 43	Avg Compression: 0.341753
# Article 1900:	Length: 44	Avg Compression: 0.339261
# Article 2000:	Length: 44	Avg Compression: 0.345926
# Article 2100:	Length: 45	Avg Compression: 0.345844
# Article 2200:	Length: 46	Avg Compression: 0.339789
# Article 2300:	Length: 46	Avg Compression: 0.332962
# Article 2400:	Length: 47	Avg Compression: 0.328704
# Article 2500:	Length: 47	Avg Compression: 0.329133
# Article 2600:	Length: 48	Avg Compression: 0.326803
# Article 2700:	Length: 49	Avg Compression: 0.326217
# Article 2800:	Length: 49	Avg Compression: 0.326670
# Article 2900:	Length: 50	Avg Compression: 0.329440
# Article 3000:	Length: 50	Avg Compression: 0.332492
# Article 3100:	Length: 51	Avg Compression: 0.328452
# Article 19800:	Length: 52573	Avg Compression: 0.281260
# Article 19900:	Length: 61215	Avg Compression: 0.281708

# %%
model.train(256, 192, epochs=5)
# Out:
# Epoch 1/5
# 1950/1950 [==============================] - 1053s 540ms/step - loss: 2.2461 - average_final_batch_ratio: 0.1954
# Epoch 2/5
# 1950/1950 [==============================] - 1047s 537ms/step - loss: 2.2046 - average_final_batch_ratio: 0.1954
# Epoch 3/5
# 1950/1950 [==============================] - 1045s 536ms/step - loss: 2.1719 - average_final_batch_ratio: 0.1954
# Epoch 4/5
# 1950/1950 [==============================] - 1049s 538ms/step - loss: 2.1409 - average_final_batch_ratio: 0.1954
# Epoch 5/5
#    1/1950 [..............................] - ETA: 45:22
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-14-09ec6fff952f> in <module>
# ----> 1 model.train(256, 192, epochs=5)
#
# <ipython-input-5-74936f3ed6d5> in train(self, batch_size, batched_item_length, epochs)
#      67         model = self.training_model(batch_size, batched_item_length)
#      68
# ---> 69         model.fit(dataset, epochs=epochs, callbacks=self.callbacks)
#      70
#      71     @property
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     395                       total_epochs=1)
#     396                   cbks.make_logs(model, epoch_logs, eval_result, ModeKeys.TEST,
# --> 397                                  prefix='val_')
#     398
#     399     return model.history
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\contextlib.py in __exit__(self, type, value, traceback)
#     128                 value = type()
#     129             try:
# --> 130                 self.gen.throw(type, value, traceback)
#     131             except StopIteration as exc:
#     132                 # Suppress StopIteration *unless* it's the same exception that
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in on_epoch(self, epoch, mode)
#     769       if mode == ModeKeys.TRAIN:
#     770         # Epochs only apply to `fit`.
# --> 771         self.callbacks.on_epoch_end(epoch, epoch_logs)
#     772       self.progbar.on_epoch_end(epoch, epoch_logs)
#     773
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     300     logs = logs or {}
#     301     for callback in self.callbacks:
# --> 302       callback.on_epoch_end(epoch, logs)
#     303
#     304   def on_train_batch_begin(self, batch, logs=None):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     990           self._save_model(epoch=epoch, logs=logs)
#     991       else:
# --> 992         self._save_model(epoch=epoch, logs=logs)
#     993     if self.model._in_multi_worker_mode():
#     994       # For multi-worker training, back up the weights and current training
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\callbacks.py in _save_model(self, epoch, logs)
#    1036             print('\nEpoch %05d: saving model to %s' % (epoch + 1, filepath))
#    1037           if self.save_weights_only:
# -> 1038             self.model.save_weights(filepath, overwrite=True)
#    1039           else:
#    1040             self.model.save(filepath, overwrite=True)
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\network.py in save_weights(self, filepath, overwrite, save_format)
#    1121              'saved.\n\nConsider using a TensorFlow optimizer from `tf.train`.')
#    1122             % (optimizer,))
# -> 1123       self._trackable_saver.save(filepath, session=session)
#    1124       # Record this checkpoint so it's visible from tf.train.latest_checkpoint.
#    1125       checkpoint_management.update_checkpoint_state_internal(
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\tracking\util.py in save(self, file_prefix, checkpoint_number, session)
#    1166     file_io.recursive_create_dir(os.path.dirname(file_prefix))
#    1167     save_path, new_feed_additions = self._save_cached_when_graph_building(
# -> 1168         file_prefix=file_prefix_tensor, object_graph_tensor=object_graph_tensor)
#    1169     if new_feed_additions:
#    1170       feed_dict.update(new_feed_additions)
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\tracking\util.py in _save_cached_when_graph_building(self, file_prefix, object_graph_tensor)
#    1114         or context.executing_eagerly() or ops.inside_function()):
#    1115       saver = functional_saver.MultiDeviceSaver(named_saveable_objects)
# -> 1116       save_op = saver.save(file_prefix)
#    1117       with ops.device("/cpu:0"):
#    1118         with ops.control_dependencies([save_op]):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\functional_saver.py in save(self, file_prefix)
#     228         # _SingleDeviceSaver will use the CPU device when necessary, but initial
#     229         # read operations should be placed on the SaveableObject's device.
# --> 230         sharded_saves.append(saver.save(shard_prefix))
#     231
#     232     with ops.control_dependencies(sharded_saves):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\functional_saver.py in save(self, file_prefix)
#      67       for spec in saveable.specs:
#      68         tensor_names.append(spec.name)
# ---> 69         tensors.append(spec.tensor)
#      70         tensor_slices.append(spec.slice_spec)
#      71     with ops.device("cpu:0"):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\saveable_object.py in tensor(self)
#      50   @property
#      51   def tensor(self):
# ---> 52     return self._tensor() if callable(self._tensor) else self._tensor
#      53
#      54
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\saveable_object_util.py in f()
#      93             # we copy them to CPU on the same machine first.
#      94             with ops.device("/device:CPU:0"):
# ---> 95               return array_ops.identity(x)
#      96         return f
#      97
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\util\dispatch.py in wrapper(*args, **kwargs)
#     178     """Call target, and fall back on dispatchers if there is a TypeError."""
#     179     try:
# --> 180       return target(*args, **kwargs)
#     181     except (TypeError, ValueError):
#     182       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\ops\array_ops.py in identity(input, name)
#     265     # variables. Variables have correct handle data when graph building.
#     266     input = ops.convert_to_tensor(input)
# --> 267   ret = gen_array_ops.identity(input, name=name)
#     268   # Propagate handle data for happier shape inference for resource variables.
#     269   if hasattr(input, "_handle_data"):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\ops\gen_array_ops.py in identity(input, name)
#    3824         pass  # Add nodes to the TensorFlow graph.
#    3825     except _core._NotOkStatusException as e:
# -> 3826       _ops.raise_from_not_ok_status(e, name)
#    3827   # Add nodes to the TensorFlow graph.
#    3828   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\framework\ops.py in raise_from_not_ok_status(e, name)
#    6604   message = e.message + (" name: " + name if name is not None else "")
#    6605   # pylint: disable=protected-access
# -> 6606   six.raise_from(core._status_to_exception(e.code, message), None)
#    6607   # pylint: enable=protected-access
#    6608
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\six.py in raise_from(value, from_value)
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:GPU:0 to /job:localhost/replica:0/task:0/device:CPU:0 in order to run Identity: GPU sync failed [Op:Identity]

# %%
total_raw = 0
total_compressed = 0

huffman = Huffman(encoder.vocab_size)
for index, encoded_article in enumerate(articles.articles_generator(1)):
    if index % 100 == 0:
        article = encoder.decode(encoded_article)
        if len(article) == 0:
            continue
        total_raw += len(article) * 8
        total_compressed += huffman.archive_size(model, encoded_article)
        print('Article %d:\tLength: %d\tAvg Compression: %f' % (index, len(article), total_compressed/total_raw))
# Out:
# Article 0:	Length: 12	Avg Compression: 0.270833
# Article 100:	Length: 28	Avg Compression: 0.337500
# Article 200:	Length: 30	Avg Compression: 0.307143
# Article 300:	Length: 31	Avg Compression: 0.299505
# Article 400:	Length: 32	Avg Compression: 0.313910
# Article 500:	Length: 33	Avg Compression: 0.317018
# Article 600:	Length: 34	Avg Compression: 0.303125
# Article 700:	Length: 35	Avg Compression: 0.307979
# Article 800:	Length: 36	Avg Compression: 0.316882
# Article 900:	Length: 37	Avg Compression: 0.311688
# Article 1000:	Length: 38	Avg Compression: 0.312500
# Article 1100:	Length: 39	Avg Compression: 0.307468
# Article 1200:	Length: 39	Avg Compression: 0.299233
# Article 1300:	Length: 40	Avg Compression: 0.307381
# Article 1400:	Length: 41	Avg Compression: 0.300248
# Article 1500:	Length: 41	Avg Compression: 0.305632
# Article 1600:	Length: 42	Avg Compression: 0.302721
# Article 1700:	Length: 42	Avg Compression: 0.295833
# Article 1800:	Length: 43	Avg Compression: 0.298105
# Article 1900:	Length: 44	Avg Compression: 0.298291
# Article 2000:	Length: 44	Avg Compression: 0.292050
# Article 2100:	Length: 45	Avg Compression: 0.293890
# Article 2200:	Length: 46	Avg Compression: 0.295041
# Article 2300:	Length: 46	Avg Compression: 0.292038
# Article 2400:	Length: 47	Avg Compression: 0.292857
# Article 2500:	Length: 47	Avg Compression: 0.294607
# Article 2600:	Length: 48	Avg Compression: 0.299760
# Article 2700:	Length: 49	Avg Compression: 0.301423
# Article 2800:	Length: 49	Avg Compression: 0.297781
# Article 2900:	Length: 50	Avg Compression: 0.298190
# Article 3000:	Length: 50	Avg Compression: 0.292710
# Article 3100:	Length: 51	Avg Compression: 0.293638
# Article 3200:	Length: 51	Avg Compression: 0.292817
# Article 3300:	Length: 52	Avg Compression: 0.291667
# Article 3400:	Length: 52	Avg Compression: 0.294235
# Article 3500:	Length: 53	Avg Compression: 0.290748
# Article 3600:	Length: 54	Avg Compression: 0.288121
# Article 3700:	Length: 54	Avg Compression: 0.288240
# Article 3800:	Length: 55	Avg Compression: 0.292846
# Article 3900:	Length: 56	Avg Compression: 0.289700
# Article 4000:	Length: 56	Avg Compression: 0.285553
# Article 4100:	Length: 57	Avg Compression: 0.282600
# Article 4200:	Length: 58	Avg Compression: 0.280339
# Article 4300:	Length: 59	Avg Compression: 0.278263
# Article 4400:	Length: 60	Avg Compression: 0.276670
# Article 4500:	Length: 61	Avg Compression: 0.275097
# Article 4600:	Length: 62	Avg Compression: 0.273485
# Article 4700:	Length: 63	Avg Compression: 0.274806
# Article 4800:	Length: 64	Avg Compression: 0.273825
# Article 4900:	Length: 66	Avg Compression: 0.269757
# Article 5000:	Length: 67	Avg Compression: 0.271505
# Article 16200:	Length: 13335	Avg Compression: 0.258688
# Article 16300:	Length: 13582	Avg Compression: 0.258092
# Article 16400:	Length: 13943	Avg Compression: 0.258477
# Article 16500:	Length: 14159	Avg Compression: 0.257893
# Article 16600:	Length: 14497	Avg Compression: 0.257078
# Article 16700:	Length: 14766	Avg Compression: 0.257635
# Article 16800:	Length: 15138	Avg Compression: 0.258364
# Article 16900:	Length: 15589	Avg Compression: 0.258718
# Article 17000:	Length: 15922	Avg Compression: 0.258189
# Article 17100:	Length: 16145	Avg Compression: 0.257737
# Article 17200:	Length: 16798	Avg Compression: 0.257222
# Article 17300:	Length: 17120	Avg Compression: 0.256367
# Article 17400:	Length: 17810	Avg Compression: 0.257121
# Article 17500:	Length: 18049	Avg Compression: 0.257774
# Article 17600:	Length: 18844	Avg Compression: 0.257889
# Article 17700:	Length: 19503	Avg Compression: 0.257720
# Article 17800:	Length: 20117	Avg Compression: 0.258302
# Article 17900:	Length: 20626	Avg Compression: 0.257825
# Article 18000:	Length: 20350	Avg Compression: 0.257577
# Article 18100:	Length: 22076	Avg Compression: 0.257756
# Article 18200:	Length: 22940	Avg Compression: 0.257818
# Article 18300:	Length: 23355	Avg Compression: 0.258316
# Article 18400:	Length: 24560	Avg Compression: 0.258534
# Article 18500:	Length: 25488	Avg Compression: 0.259040
# Article 18600:	Length: 26439	Avg Compression: 0.259651
# Article 18700:	Length: 27252	Avg Compression: 0.260238
# Article 18800:	Length: 28415	Avg Compression: 0.260697
# Article 18900:	Length: 29287	Avg Compression: 0.260936
# Article 19000:	Length: 30865	Avg Compression: 0.260957
# Article 19100:	Length: 32409	Avg Compression: 0.260658
# Article 19200:	Length: 34164	Avg Compression: 0.260088
# Article 19300:	Length: 35990	Avg Compression: 0.258879
# Article 19400:	Length: 38524	Avg Compression: 0.259094
# Article 19500:	Length: 41139	Avg Compression: 0.259500
# Article 19600:	Length: 43795	Avg Compression: 0.260138
# Article 19700:	Length: 47945	Avg Compression: 0.260784
# Article 19800:	Length: 52573	Avg Compression: 0.260842
# Article 19900:	Length: 61215	Avg Compression: 0.261700

# %%
model.train(256, 192, epochs=5)
# Out:
# Epoch 1/5
# 1950/1950 [==============================] - 1056s 541ms/step - loss: 2.1125 - average_final_batch_ratio: 0.1933
# Epoch 2/5
# 1950/1950 [==============================] - 1055s 541ms/step - loss: 2.0886 - average_final_batch_ratio: 0.1933
# Epoch 3/5
# 1950/1950 [==============================] - 1044s 535ms/step - loss: 2.0666 - average_final_batch_ratio: 0.1933
# Epoch 4/5
# 1950/1950 [==============================] - 1067s 547ms/step - loss: 2.0467 - average_final_batch_ratio: 0.1933
# Epoch 5/5
# 1950/1950 [==============================] - 1058s 542ms/step - loss: 2.0305 - average_final_batch_ratio: 0.1933

# %%
total_raw = 0
total_compressed = 0

huffman = Huffman(encoder.vocab_size)
for index, encoded_article in enumerate(articles.articles_generator(1)):
    if index % 100 == 0:
        article = encoder.decode(encoded_article)
        total_raw += len(article) * 8
        total_compressed += huffman.archive_size(model, encoded_article)
        print('Article %d:\tLength: %d\tAvg Compression: %f' % (index, len(article), total_compressed/total_raw))
# Out:
# Article 0:	Length: 12	Avg Compression: 0.260417
# Article 100:	Length: 28	Avg Compression: 0.334375
# Article 200:	Length: 30	Avg Compression: 0.301786
# Article 300:	Length: 31	Avg Compression: 0.295792
# Article 400:	Length: 32	Avg Compression: 0.307331
# Article 500:	Length: 33	Avg Compression: 0.302711
# Article 600:	Length: 34	Avg Compression: 0.286875
# Article 700:	Length: 35	Avg Compression: 0.293085
# Article 800:	Length: 36	Avg Compression: 0.302122
# Article 900:	Length: 37	Avg Compression: 0.300325
# Article 1000:	Length: 38	Avg Compression: 0.303468
# Article 1100:	Length: 39	Avg Compression: 0.296429
# Article 1200:	Length: 39	Avg Compression: 0.285672
# Article 1300:	Length: 40	Avg Compression: 0.293912
# Article 1400:	Length: 41	Avg Compression: 0.288366
# Article 1500:	Length: 41	Avg Compression: 0.294185
# Article 1600:	Length: 42	Avg Compression: 0.290391
# Article 1700:	Length: 42	Avg Compression: 0.283135
# Article 1800:	Length: 43	Avg Compression: 0.285290
# Article 1900:	Length: 44	Avg Compression: 0.285216
# Article 2000:	Length: 44	Avg Compression: 0.277924
# Article 2100:	Length: 45	Avg Compression: 0.280242
# Article 2200:	Length: 46	Avg Compression: 0.278756
# Article 2300:	Length: 46	Avg Compression: 0.275891
# Article 2400:	Length: 47	Avg Compression: 0.278175
# Article 2500:	Length: 47	Avg Compression: 0.279360
# Article 2600:	Length: 48	Avg Compression: 0.285337
# Article 2700:	Length: 49	Avg Compression: 0.287534
# Article 2800:	Length: 49	Avg Compression: 0.282953
# Article 2900:	Length: 50	Avg Compression: 0.283880
# Article 3000:	Length: 50	Avg Compression: 0.279382
# Article 3100:	Length: 51	Avg Compression: 0.280256
# Article 3200:	Length: 51	Avg Compression: 0.279011
# Article 3300:	Length: 52	Avg Compression: 0.278825
# Article 3400:	Length: 52	Avg Compression: 0.279952
# Article 3500:	Length: 53	Avg Compression: 0.276219
# Article 3600:	Length: 54	Avg Compression: 0.274339
# Article 3700:	Length: 54	Avg Compression: 0.275000
# Article 3800:	Length: 55	Avg Compression: 0.279142
# Article 3900:	Length: 56	Avg Compression: 0.275714
# Article 4000:	Length: 56	Avg Compression: 0.271304
# Article 4100:	Length: 57	Avg Compression: 0.267701
# Article 4200:	Length: 58	Avg Compression: 0.265170
# Article 4300:	Length: 59	Avg Compression: 0.263232
# Article 4400:	Length: 60	Avg Compression: 0.260593
# Article 4500:	Length: 61	Avg Compression: 0.259253
# Article 4600:	Length: 62	Avg Compression: 0.257926
# Article 4700:	Length: 63	Avg Compression: 0.258497
# Article 4800:	Length: 64	Avg Compression: 0.258533
# Article 4900:	Length: 66	Avg Compression: 0.254576
# Article 5000:	Length: 67	Avg Compression: 0.255180
# Article 5100:	Length: 69	Avg Compression: 0.253407
# Article 5200:	Length: 72	Avg Compression: 0.252915
# Article 5300:	Length: 75	Avg Compression: 0.250048
# Article 5400:	Length: 79	Avg Compression: 0.248510
# Article 5500:	Length: 83	Avg Compression: 0.249819
# Article 16700:	Length: 14766	Avg Compression: 0.249282
# Article 16800:	Length: 15138	Avg Compression: 0.249918
# Article 16900:	Length: 15589	Avg Compression: 0.250320
# Article 17000:	Length: 15922	Avg Compression: 0.249785
# Article 17100:	Length: 16145	Avg Compression: 0.249417
# Article 17200:	Length: 16798	Avg Compression: 0.248803
# Article 17300:	Length: 17120	Avg Compression: 0.247943
# Article 17400:	Length: 17810	Avg Compression: 0.248783
# Article 17500:	Length: 18049	Avg Compression: 0.249490
# Article 17600:	Length: 18844	Avg Compression: 0.249618
# Article 17700:	Length: 19503	Avg Compression: 0.249550
# Article 17800:	Length: 20117	Avg Compression: 0.250160
# Article 17900:	Length: 20626	Avg Compression: 0.249624
# Article 18000:	Length: 20350	Avg Compression: 0.249361
# Article 18100:	Length: 22076	Avg Compression: 0.249578
# Article 18200:	Length: 22940	Avg Compression: 0.249601
# Article 18300:	Length: 23355	Avg Compression: 0.250199
# Article 18400:	Length: 24560	Avg Compression: 0.250497
# Article 18500:	Length: 25488	Avg Compression: 0.251113
# Article 18600:	Length: 26439	Avg Compression: 0.251859
# Article 18700:	Length: 27252	Avg Compression: 0.252484
# Article 18800:	Length: 28415	Avg Compression: 0.253012
# Article 18900:	Length: 29287	Avg Compression: 0.253277
# Article 19000:	Length: 30865	Avg Compression: 0.253423
# Article 19100:	Length: 32409	Avg Compression: 0.253266
# Article 19200:	Length: 34164	Avg Compression: 0.252922
# Article 19300:	Length: 35990	Avg Compression: 0.251770
# Article 19400:	Length: 38524	Avg Compression: 0.252031
# Article 19500:	Length: 41139	Avg Compression: 0.252485
# Article 19600:	Length: 43795	Avg Compression: 0.252911
# Article 19700:	Length: 47945	Avg Compression: 0.253542
# Article 19800:	Length: 52573	Avg Compression: 0.253620
# Article 19900:	Length: 61215	Avg Compression: 0.254570

# %%
model.train(256, 192, epochs=5)
# Out:
# Epoch 1/5
# 1950/1950 [==============================] - 1039s 533ms/step - loss: 2.0152 - average_final_batch_ratio: 0.1933
# Epoch 2/5
# 1950/1950 [==============================] - 1048s 538ms/step - loss: 2.0044 - average_final_batch_ratio: 0.1933
# Epoch 3/5
# 1950/1950 [==============================] - 1049s 538ms/step - loss: 1.9894 - average_final_batch_ratio: 0.1933
# Epoch 4/5
# 1950/1950 [==============================] - 1052s 540ms/step - loss: 1.9789 - average_final_batch_ratio: 0.1933
# Epoch 5/5
# 1950/1950 [==============================] - 1041s 534ms/step - loss: 1.9663 - average_final_batch_ratio: 0.1933

# %%
total_raw = 0
total_compressed = 0

huffman = Huffman(encoder.vocab_size)
for index, encoded_article in enumerate(articles.articles_generator(1)):
    if index % 100 == 0:
        article = encoder.decode(encoded_article)
        total_raw += len(article) * 8
        total_compressed += huffman.archive_size(model, encoded_article)
        print('Article %d:\tLength: %d\tAvg Compression: %f' % (index, len(article), total_compressed/total_raw))
# Out:
# Article 0:	Length: 12	Avg Compression: 0.281250
# Article 100:	Length: 28	Avg Compression: 0.337500
# Article 200:	Length: 30	Avg Compression: 0.307143
# Article 300:	Length: 31	Avg Compression: 0.299505
# Article 17200:	Length: 16798	Avg Compression: 0.241522
# Article 17300:	Length: 17120	Avg Compression: 0.240824
# Article 17400:	Length: 17810	Avg Compression: 0.241888
# Article 17500:	Length: 18049	Avg Compression: 0.242698
# Article 17600:	Length: 18844	Avg Compression: 0.242979
# Article 17700:	Length: 19503	Avg Compression: 0.242991
# Article 17800:	Length: 20117	Avg Compression: 0.243773
# Article 17900:	Length: 20626	Avg Compression: 0.243336
# Article 18000:	Length: 20350	Avg Compression: 0.243071
# Article 18100:	Length: 22076	Avg Compression: 0.243343
# Article 18200:	Length: 22940	Avg Compression: 0.243551
# Article 18300:	Length: 23355	Avg Compression: 0.244110
# Article 18400:	Length: 24560	Avg Compression: 0.244492
# Article 18500:	Length: 25488	Avg Compression: 0.245104
# Article 18600:	Length: 26439	Avg Compression: 0.245804
# Article 18700:	Length: 27252	Avg Compression: 0.246468
# Article 18800:	Length: 28415	Avg Compression: 0.247013
# Article 18900:	Length: 29287	Avg Compression: 0.247251
# Article 19000:	Length: 30865	Avg Compression: 0.247403
# Article 19100:	Length: 32409	Avg Compression: 0.247246
# Article 19200:	Length: 34164	Avg Compression: 0.246946
# Article 19300:	Length: 35990	Avg Compression: 0.245834
# Article 19400:	Length: 38524	Avg Compression: 0.246149
# Article 19500:	Length: 41139	Avg Compression: 0.246815
# Article 19600:	Length: 43795	Avg Compression: 0.247357
# Article 19700:	Length: 47945	Avg Compression: 0.247988
# Article 19800:	Length: 52573	Avg Compression: 0.248082
# Article 19900:	Length: 61215	Avg Compression: 0.248923

# %%
model.train(256, 192, epochs=10)
# Out:
# Epoch 1/10
#     315/Unknown - 172s 546ms/step - loss: 2.2415 - average_final_batch_ratio: 0.2603WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-1.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'm' for (root).layer_with_weights-2.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-0.embeddings
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-3.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-1.cell.bias
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.recurrent_kernel
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer's state 'v' for (root).layer_with_weights-2.cell.bias
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# 1950/1950 [==============================] - 1052s 540ms/step - loss: 1.9590 - average_final_batch_ratio: 0.1933
# Epoch 2/10
# 1950/1950 [==============================] - 1048s 537ms/step - loss: 1.9479 - average_final_batch_ratio: 0.1933
# Epoch 3/10
#    1/1950 [..............................] - ETA: 29:10
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-15-278db9904967> in <module>
# ----> 1 model.train(256, 192, epochs=10)
#
# <ipython-input-5-74936f3ed6d5> in train(self, batch_size, batched_item_length, epochs)
#      67         model = self.training_model(batch_size, batched_item_length)
#      68
# ---> 69         model.fit(dataset, epochs=epochs, callbacks=self.callbacks)
#      70
#      71     @property
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     395                       total_epochs=1)
#     396                   cbks.make_logs(model, epoch_logs, eval_result, ModeKeys.TEST,
# --> 397                                  prefix='val_')
#     398
#     399     return model.history
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\contextlib.py in __exit__(self, type, value, traceback)
#     128                 value = type()
#     129             try:
# --> 130                 self.gen.throw(type, value, traceback)
#     131             except StopIteration as exc:
#     132                 # Suppress StopIteration *unless* it's the same exception that
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in on_epoch(self, epoch, mode)
#     769       if mode == ModeKeys.TRAIN:
#     770         # Epochs only apply to `fit`.
# --> 771         self.callbacks.on_epoch_end(epoch, epoch_logs)
#     772       self.progbar.on_epoch_end(epoch, epoch_logs)
#     773
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     300     logs = logs or {}
#     301     for callback in self.callbacks:
# --> 302       callback.on_epoch_end(epoch, logs)
#     303
#     304   def on_train_batch_begin(self, batch, logs=None):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     990           self._save_model(epoch=epoch, logs=logs)
#     991       else:
# --> 992         self._save_model(epoch=epoch, logs=logs)
#     993     if self.model._in_multi_worker_mode():
#     994       # For multi-worker training, back up the weights and current training
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\callbacks.py in _save_model(self, epoch, logs)
#    1036             print('\nEpoch %05d: saving model to %s' % (epoch + 1, filepath))
#    1037           if self.save_weights_only:
# -> 1038             self.model.save_weights(filepath, overwrite=True)
#    1039           else:
#    1040             self.model.save(filepath, overwrite=True)
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\network.py in save_weights(self, filepath, overwrite, save_format)
#    1121              'saved.\n\nConsider using a TensorFlow optimizer from `tf.train`.')
#    1122             % (optimizer,))
# -> 1123       self._trackable_saver.save(filepath, session=session)
#    1124       # Record this checkpoint so it's visible from tf.train.latest_checkpoint.
#    1125       checkpoint_management.update_checkpoint_state_internal(
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\tracking\util.py in save(self, file_prefix, checkpoint_number, session)
#    1166     file_io.recursive_create_dir(os.path.dirname(file_prefix))
#    1167     save_path, new_feed_additions = self._save_cached_when_graph_building(
# -> 1168         file_prefix=file_prefix_tensor, object_graph_tensor=object_graph_tensor)
#    1169     if new_feed_additions:
#    1170       feed_dict.update(new_feed_additions)
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\tracking\util.py in _save_cached_when_graph_building(self, file_prefix, object_graph_tensor)
#    1114         or context.executing_eagerly() or ops.inside_function()):
#    1115       saver = functional_saver.MultiDeviceSaver(named_saveable_objects)
# -> 1116       save_op = saver.save(file_prefix)
#    1117       with ops.device("/cpu:0"):
#    1118         with ops.control_dependencies([save_op]):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\functional_saver.py in save(self, file_prefix)
#     228         # _SingleDeviceSaver will use the CPU device when necessary, but initial
#     229         # read operations should be placed on the SaveableObject's device.
# --> 230         sharded_saves.append(saver.save(shard_prefix))
#     231
#     232     with ops.control_dependencies(sharded_saves):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\functional_saver.py in save(self, file_prefix)
#      67       for spec in saveable.specs:
#      68         tensor_names.append(spec.name)
# ---> 69         tensors.append(spec.tensor)
#      70         tensor_slices.append(spec.slice_spec)
#      71     with ops.device("cpu:0"):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\saveable_object.py in tensor(self)
#      50   @property
#      51   def tensor(self):
# ---> 52     return self._tensor() if callable(self._tensor) else self._tensor
#      53
#      54
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\saveable_object_util.py in f()
#      93             # we copy them to CPU on the same machine first.
#      94             with ops.device("/device:CPU:0"):
# ---> 95               return array_ops.identity(x)
#      96         return f
#      97
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\util\dispatch.py in wrapper(*args, **kwargs)
#     178     """Call target, and fall back on dispatchers if there is a TypeError."""
#     179     try:
# --> 180       return target(*args, **kwargs)
#     181     except (TypeError, ValueError):
#     182       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\ops\array_ops.py in identity(input, name)
#     265     # variables. Variables have correct handle data when graph building.
#     266     input = ops.convert_to_tensor(input)
# --> 267   ret = gen_array_ops.identity(input, name=name)
#     268   # Propagate handle data for happier shape inference for resource variables.
#     269   if hasattr(input, "_handle_data"):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\ops\gen_array_ops.py in identity(input, name)
#    3824         pass  # Add nodes to the TensorFlow graph.
#    3825     except _core._NotOkStatusException as e:
# -> 3826       _ops.raise_from_not_ok_status(e, name)
#    3827   # Add nodes to the TensorFlow graph.
#    3828   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\framework\ops.py in raise_from_not_ok_status(e, name)
#    6604   message = e.message + (" name: " + name if name is not None else "")
#    6605   # pylint: disable=protected-access
# -> 6606   six.raise_from(core._status_to_exception(e.code, message), None)
#    6607   # pylint: enable=protected-access
#    6608
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\six.py in raise_from(value, from_value)
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:GPU:0 to /job:localhost/replica:0/task:0/device:CPU:0 in order to run Identity: GPU sync failed [Op:Identity]

# %%
model.train(256, 192, epochs=8)
# Out:
# Epoch 1/8
# 1950/1950 [==============================] - 1274s 653ms/step - loss: 1.9393 - average_final_batch_ratio: 0.1944
# Epoch 2/8
# 1950/1950 [==============================] - 1066s 547ms/step - loss: 1.9315 - average_final_batch_ratio: 0.1944
# Epoch 3/8
# 1950/1950 [==============================] - 1060s 543ms/step - loss: 1.9199 - average_final_batch_ratio: 0.1944
# Epoch 4/8
# 1950/1950 [==============================] - 1059s 543ms/step - loss: 1.9151 - average_final_batch_ratio: 0.1944
# Epoch 5/8
# 1950/1950 [==============================] - 1081s 555ms/step - loss: 1.9096 - average_final_batch_ratio: 0.1944
# Epoch 6/8
# 1950/1950 [==============================] - 1054s 540ms/step - loss: 1.9012 - average_final_batch_ratio: 0.1944
# Epoch 7/8
# 1950/1950 [==============================] - 1053s 540ms/step - loss: 1.8974 - average_final_batch_ratio: 0.1944
# Epoch 8/8
# 1950/1950 [==============================] - 1055s 541ms/step - loss: 1.8899 - average_final_batch_ratio: 0.1944

# %%
total_raw = 0
total_compressed = 0

huffman = Huffman(encoder.vocab_size)
for index, encoded_article in enumerate(articles.articles_generator(1)):
    if index % 100 == 0:
        article = encoder.decode(encoded_article)
        total_raw += len(article) * 8
        total_compressed += huffman.archive_size(model, encoded_article)
        print('Article %d:\tLength: %d\tAvg Compression: %f' % (index, len(article), total_compressed/total_raw))
# Out:
# Article 0:	Length: 12	Avg Compression: 0.291667
# Article 100:	Length: 28	Avg Compression: 0.228125
# Article 200:	Length: 30	Avg Compression: 0.291071
# Article 300:	Length: 31	Avg Compression: 0.295792
# Article 400:	Length: 32	Avg Compression: 0.294173
# Article 500:	Length: 33	Avg Compression: 0.279367
# Article 600:	Length: 34	Avg Compression: 0.274375
# Article 17400:	Length: 17810	Avg Compression: 0.232116
# Article 17500:	Length: 18049	Avg Compression: 0.232933
# Article 17600:	Length: 18912	Avg Compression: 0.233263
# Article 17700:	Length: 19503	Avg Compression: 0.233413
# Article 17800:	Length: 20117	Avg Compression: 0.234201
# Article 17900:	Length: 20626	Avg Compression: 0.233834
# Article 18000:	Length: 20350	Avg Compression: 0.233499
# Article 18100:	Length: 22076	Avg Compression: 0.233750
# Article 18200:	Length: 22940	Avg Compression: 0.233679
# Article 18300:	Length: 23355	Avg Compression: 0.234322
# Article 18400:	Length: 24560	Avg Compression: 0.234510
# Article 18500:	Length: 25488	Avg Compression: 0.235282
# Article 18600:	Length: 26439	Avg Compression: 0.236048
# Article 18700:	Length: 27252	Avg Compression: 0.236657
# Article 18800:	Length: 28415	Avg Compression: 0.237228
# Article 18900:	Length: 29287	Avg Compression: 0.237508
# Article 19000:	Length: 30534	Avg Compression: 0.237995
# Article 19100:	Length: 32381	Avg Compression: 0.238510
# Article 19200:	Length: 34164	Avg Compression: 0.238199
# Article 19300:	Length: 35990	Avg Compression: 0.237107
# Article 19400:	Length: 38524	Avg Compression: 0.237561
# Article 19500:	Length: 41139	Avg Compression: 0.237964
# Article 19600:	Length: 43795	Avg Compression: 0.238438
# Article 19700:	Length: 47945	Avg Compression: 0.239105
# Article 19800:	Length: 52573	Avg Compression: 0.239210
# Article 19900:	Length: 61215	Avg Compression: 0.240271

# %%
model.train(256, 192, epochs=20)
# Out:
# Epoch 1/20
# 1950/1950 [==============================] - 1044s 536ms/step - loss: 1.8863 - average_final_batch_ratio: 0.1944
# Epoch 2/20
# 1950/1950 [==============================] - 1050s 539ms/step - loss: 1.8779 - average_final_batch_ratio: 0.1944
# Epoch 3/20
# 1950/1950 [==============================] - 1041s 534ms/step - loss: 1.8769 - average_final_batch_ratio: 0.1944
# Epoch 4/20
# 1950/1950 [==============================] - 1057s 542ms/step - loss: 1.8689 - average_final_batch_ratio: 0.1944
# Epoch 5/20
# 1950/1950 [==============================] - 1051s 539ms/step - loss: 1.8635 - average_final_batch_ratio: 0.1944
# Epoch 6/20
# 1950/1950 [==============================] - 1049s 538ms/step - loss: 1.8618 - average_final_batch_ratio: 0.1944
# Epoch 7/20
# 1950/1950 [==============================] - 1046s 536ms/step - loss: 1.8547 - average_final_batch_ratio: 0.1944
# Epoch 8/20
#    1/1950 [..............................] - ETA: 43:51
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-16-5a36cec3115f> in <module>
# ----> 1 model.train(256, 192, epochs=20)
#
# <ipython-input-5-74936f3ed6d5> in train(self, batch_size, batched_item_length, epochs)
#      67         model = self.training_model(batch_size, batched_item_length)
#      68
# ---> 69         model.fit(dataset, epochs=epochs, callbacks=self.callbacks)
#      70
#      71     @property
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     395                       total_epochs=1)
#     396                   cbks.make_logs(model, epoch_logs, eval_result, ModeKeys.TEST,
# --> 397                                  prefix='val_')
#     398
#     399     return model.history
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\contextlib.py in __exit__(self, type, value, traceback)
#     128                 value = type()
#     129             try:
# --> 130                 self.gen.throw(type, value, traceback)
#     131             except StopIteration as exc:
#     132                 # Suppress StopIteration *unless* it's the same exception that
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in on_epoch(self, epoch, mode)
#     769       if mode == ModeKeys.TRAIN:
#     770         # Epochs only apply to `fit`.
# --> 771         self.callbacks.on_epoch_end(epoch, epoch_logs)
#     772       self.progbar.on_epoch_end(epoch, epoch_logs)
#     773
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     300     logs = logs or {}
#     301     for callback in self.callbacks:
# --> 302       callback.on_epoch_end(epoch, logs)
#     303
#     304   def on_train_batch_begin(self, batch, logs=None):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     990           self._save_model(epoch=epoch, logs=logs)
#     991       else:
# --> 992         self._save_model(epoch=epoch, logs=logs)
#     993     if self.model._in_multi_worker_mode():
#     994       # For multi-worker training, back up the weights and current training
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\callbacks.py in _save_model(self, epoch, logs)
#    1036             print('\nEpoch %05d: saving model to %s' % (epoch + 1, filepath))
#    1037           if self.save_weights_only:
# -> 1038             self.model.save_weights(filepath, overwrite=True)
#    1039           else:
#    1040             self.model.save(filepath, overwrite=True)
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\network.py in save_weights(self, filepath, overwrite, save_format)
#    1121              'saved.\n\nConsider using a TensorFlow optimizer from `tf.train`.')
#    1122             % (optimizer,))
# -> 1123       self._trackable_saver.save(filepath, session=session)
#    1124       # Record this checkpoint so it's visible from tf.train.latest_checkpoint.
#    1125       checkpoint_management.update_checkpoint_state_internal(
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\tracking\util.py in save(self, file_prefix, checkpoint_number, session)
#    1166     file_io.recursive_create_dir(os.path.dirname(file_prefix))
#    1167     save_path, new_feed_additions = self._save_cached_when_graph_building(
# -> 1168         file_prefix=file_prefix_tensor, object_graph_tensor=object_graph_tensor)
#    1169     if new_feed_additions:
#    1170       feed_dict.update(new_feed_additions)
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\tracking\util.py in _save_cached_when_graph_building(self, file_prefix, object_graph_tensor)
#    1114         or context.executing_eagerly() or ops.inside_function()):
#    1115       saver = functional_saver.MultiDeviceSaver(named_saveable_objects)
# -> 1116       save_op = saver.save(file_prefix)
#    1117       with ops.device("/cpu:0"):
#    1118         with ops.control_dependencies([save_op]):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\functional_saver.py in save(self, file_prefix)
#     228         # _SingleDeviceSaver will use the CPU device when necessary, but initial
#     229         # read operations should be placed on the SaveableObject's device.
# --> 230         sharded_saves.append(saver.save(shard_prefix))
#     231
#     232     with ops.control_dependencies(sharded_saves):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\functional_saver.py in save(self, file_prefix)
#      67       for spec in saveable.specs:
#      68         tensor_names.append(spec.name)
# ---> 69         tensors.append(spec.tensor)
#      70         tensor_slices.append(spec.slice_spec)
#      71     with ops.device("cpu:0"):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\saveable_object.py in tensor(self)
#      50   @property
#      51   def tensor(self):
# ---> 52     return self._tensor() if callable(self._tensor) else self._tensor
#      53
#      54
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\saveable_object_util.py in f()
#      93             # we copy them to CPU on the same machine first.
#      94             with ops.device("/device:CPU:0"):
# ---> 95               return array_ops.identity(x)
#      96         return f
#      97
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\util\dispatch.py in wrapper(*args, **kwargs)
#     178     """Call target, and fall back on dispatchers if there is a TypeError."""
#     179     try:
# --> 180       return target(*args, **kwargs)
#     181     except (TypeError, ValueError):
#     182       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\ops\array_ops.py in identity(input, name)
#     265     # variables. Variables have correct handle data when graph building.
#     266     input = ops.convert_to_tensor(input)
# --> 267   ret = gen_array_ops.identity(input, name=name)
#     268   # Propagate handle data for happier shape inference for resource variables.
#     269   if hasattr(input, "_handle_data"):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\ops\gen_array_ops.py in identity(input, name)
#    3824         pass  # Add nodes to the TensorFlow graph.
#    3825     except _core._NotOkStatusException as e:
# -> 3826       _ops.raise_from_not_ok_status(e, name)
#    3827   # Add nodes to the TensorFlow graph.
#    3828   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\framework\ops.py in raise_from_not_ok_status(e, name)
#    6604   message = e.message + (" name: " + name if name is not None else "")
#    6605   # pylint: disable=protected-access
# -> 6606   six.raise_from(core._status_to_exception(e.code, message), None)
#    6607   # pylint: enable=protected-access
#    6608
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\six.py in raise_from(value, from_value)
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:GPU:0 to /job:localhost/replica:0/task:0/device:CPU:0 in order to run Identity: GPU sync failed [Op:Identity]

# %%
total_raw = 0
total_compressed = 0

huffman = Huffman(encoder.vocab_size)
for index, encoded_article in enumerate(articles.articles_generator(1)):
    if index % 100 == 0:
        article = encoder.decode(encoded_article)
        total_raw += len(article) * 8
        total_compressed += huffman.archive_size(model, encoded_article)
        print('Article %d:\tLength: %d\tAvg Compression: %f' % (index, len(article), total_compressed/total_raw))
# Out:
# Article 0:	Length: 12	Avg Compression: 0.270833
# Article 100:	Length: 28	Avg Compression: 0.246875
# Article 200:	Length: 30	Avg Compression: 0.298214
# Article 300:	Length: 31	Avg Compression: 0.300743
# Article 400:	Length: 32	Avg Compression: 0.263158
# Article 500:	Length: 33	Avg Compression: 0.262801
# Article 600:	Length: 34	Avg Compression: 0.276875
# Article 700:	Length: 35	Avg Compression: 0.262234
# Article 800:	Length: 36	Avg Compression: 0.257841
# Article 900:	Length: 37	Avg Compression: 0.262175
# Article 1000:	Length: 38	Avg Compression: 0.256503
# Article 1100:	Length: 39	Avg Compression: 0.256169
# Article 1200:	Length: 39	Avg Compression: 0.248526
# Article 1300:	Length: 40	Avg Compression: 0.253233
# Article 1400:	Length: 41	Avg Compression: 0.254455
# Article 1500:	Length: 41	Avg Compression: 0.257097
# Article 1600:	Length: 42	Avg Compression: 0.259779
# Article 1700:	Length: 42	Avg Compression: 0.262698
# Article 1800:	Length: 43	Avg Compression: 0.264302
# Article 1900:	Length: 44	Avg Compression: 0.270746
# Article 18600:	Length: 26439	Avg Compression: 0.236210
# Article 18700:	Length: 27252	Avg Compression: 0.236718
# Article 18800:	Length: 28415	Avg Compression: 0.237217
# Article 18900:	Length: 29287	Avg Compression: 0.237540
# Article 19000:	Length: 30865	Avg Compression: 0.237763
# Article 19100:	Length: 32409	Avg Compression: 0.237474
# Article 19200:	Length: 34164	Avg Compression: 0.237134
# Article 19300:	Length: 35990	Avg Compression: 0.236028
# Article 19400:	Length: 38524	Avg Compression: 0.236429
# Article 19500:	Length: 41139	Avg Compression: 0.236989
# Article 19600:	Length: 43795	Avg Compression: 0.237519
# Article 19700:	Length: 47945	Avg Compression: 0.238401
# Article 19800:	Length: 52573	Avg Compression: 0.238488
# Article 19900:	Length: 61215	Avg Compression: 0.239479

# %%
model.train(256, 192, epochs=12)
# Out:
# Epoch 1/12
# 1950/1950 [==============================] - 1056s 541ms/step - loss: 1.8546 - average_final_batch_ratio: 0.1944
# Epoch 2/12
# 1950/1950 [==============================] - 1054s 541ms/step - loss: 1.8499 - average_final_batch_ratio: 0.1944
# Epoch 3/12
# 1950/1950 [==============================] - 1045s 536ms/step - loss: 1.8443 - average_final_batch_ratio: 0.1944
# Epoch 4/12
# 1950/1950 [==============================] - 1051s 539ms/step - loss: 1.8411 - average_final_batch_ratio: 0.1944
# Epoch 5/12
# 1950/1950 [==============================] - 1054s 540ms/step - loss: 1.8370 - average_final_batch_ratio: 0.1944
# Epoch 6/12
#    1/1950 [..............................] - ETA: 1:36:16
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-11-13d3e8fa627c> in <module>
# ----> 1 model.train(256, 192, epochs=12)
#
# <ipython-input-5-74936f3ed6d5> in train(self, batch_size, batched_item_length, epochs)
#      67         model = self.training_model(batch_size, batched_item_length)
#      68
# ---> 69         model.fit(dataset, epochs=epochs, callbacks=self.callbacks)
#      70
#      71     @property
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     395                       total_epochs=1)
#     396                   cbks.make_logs(model, epoch_logs, eval_result, ModeKeys.TEST,
# --> 397                                  prefix='val_')
#     398
#     399     return model.history
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\contextlib.py in __exit__(self, type, value, traceback)
#     128                 value = type()
#     129             try:
# --> 130                 self.gen.throw(type, value, traceback)
#     131             except StopIteration as exc:
#     132                 # Suppress StopIteration *unless* it's the same exception that
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in on_epoch(self, epoch, mode)
#     769       if mode == ModeKeys.TRAIN:
#     770         # Epochs only apply to `fit`.
# --> 771         self.callbacks.on_epoch_end(epoch, epoch_logs)
#     772       self.progbar.on_epoch_end(epoch, epoch_logs)
#     773
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     300     logs = logs or {}
#     301     for callback in self.callbacks:
# --> 302       callback.on_epoch_end(epoch, logs)
#     303
#     304   def on_train_batch_begin(self, batch, logs=None):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     990           self._save_model(epoch=epoch, logs=logs)
#     991       else:
# --> 992         self._save_model(epoch=epoch, logs=logs)
#     993     if self.model._in_multi_worker_mode():
#     994       # For multi-worker training, back up the weights and current training
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\callbacks.py in _save_model(self, epoch, logs)
#    1036             print('\nEpoch %05d: saving model to %s' % (epoch + 1, filepath))
#    1037           if self.save_weights_only:
# -> 1038             self.model.save_weights(filepath, overwrite=True)
#    1039           else:
#    1040             self.model.save(filepath, overwrite=True)
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\network.py in save_weights(self, filepath, overwrite, save_format)
#    1121              'saved.\n\nConsider using a TensorFlow optimizer from `tf.train`.')
#    1122             % (optimizer,))
# -> 1123       self._trackable_saver.save(filepath, session=session)
#    1124       # Record this checkpoint so it's visible from tf.train.latest_checkpoint.
#    1125       checkpoint_management.update_checkpoint_state_internal(
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\tracking\util.py in save(self, file_prefix, checkpoint_number, session)
#    1166     file_io.recursive_create_dir(os.path.dirname(file_prefix))
#    1167     save_path, new_feed_additions = self._save_cached_when_graph_building(
# -> 1168         file_prefix=file_prefix_tensor, object_graph_tensor=object_graph_tensor)
#    1169     if new_feed_additions:
#    1170       feed_dict.update(new_feed_additions)
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\tracking\util.py in _save_cached_when_graph_building(self, file_prefix, object_graph_tensor)
#    1114         or context.executing_eagerly() or ops.inside_function()):
#    1115       saver = functional_saver.MultiDeviceSaver(named_saveable_objects)
# -> 1116       save_op = saver.save(file_prefix)
#    1117       with ops.device("/cpu:0"):
#    1118         with ops.control_dependencies([save_op]):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\functional_saver.py in save(self, file_prefix)
#     228         # _SingleDeviceSaver will use the CPU device when necessary, but initial
#     229         # read operations should be placed on the SaveableObject's device.
# --> 230         sharded_saves.append(saver.save(shard_prefix))
#     231
#     232     with ops.control_dependencies(sharded_saves):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\functional_saver.py in save(self, file_prefix)
#      67       for spec in saveable.specs:
#      68         tensor_names.append(spec.name)
# ---> 69         tensors.append(spec.tensor)
#      70         tensor_slices.append(spec.slice_spec)
#      71     with ops.device("cpu:0"):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\saveable_object.py in tensor(self)
#      50   @property
#      51   def tensor(self):
# ---> 52     return self._tensor() if callable(self._tensor) else self._tensor
#      53
#      54
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\saveable_object_util.py in f()
#      93             # we copy them to CPU on the same machine first.
#      94             with ops.device("/device:CPU:0"):
# ---> 95               return array_ops.identity(x)
#      96         return f
#      97
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\util\dispatch.py in wrapper(*args, **kwargs)
#     178     """Call target, and fall back on dispatchers if there is a TypeError."""
#     179     try:
# --> 180       return target(*args, **kwargs)
#     181     except (TypeError, ValueError):
#     182       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\ops\array_ops.py in identity(input, name)
#     265     # variables. Variables have correct handle data when graph building.
#     266     input = ops.convert_to_tensor(input)
# --> 267   ret = gen_array_ops.identity(input, name=name)
#     268   # Propagate handle data for happier shape inference for resource variables.
#     269   if hasattr(input, "_handle_data"):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\ops\gen_array_ops.py in identity(input, name)
#    3824         pass  # Add nodes to the TensorFlow graph.
#    3825     except _core._NotOkStatusException as e:
# -> 3826       _ops.raise_from_not_ok_status(e, name)
#    3827   # Add nodes to the TensorFlow graph.
#    3828   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\framework\ops.py in raise_from_not_ok_status(e, name)
#    6604   message = e.message + (" name: " + name if name is not None else "")
#    6605   # pylint: disable=protected-access
# -> 6606   six.raise_from(core._status_to_exception(e.code, message), None)
#    6607   # pylint: enable=protected-access
#    6608
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\six.py in raise_from(value, from_value)
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:GPU:0 to /job:localhost/replica:0/task:0/device:CPU:0 in order to run Identity: GPU sync failed [Op:Identity]

# %%
model.train(256, 192, epochs=6)
# Out:
# Epoch 1/6
# 1950/1950 [==============================] - 1268s 650ms/step - loss: 1.8357 - average_final_batch_ratio: 0.1969
# Epoch 2/6
# 1950/1950 [==============================] - 1073s 550ms/step - loss: 1.8346 - average_final_batch_ratio: 0.1969
# Epoch 3/6
# 1950/1950 [==============================] - 1080s 554ms/step - loss: 1.8272 - average_final_batch_ratio: 0.1969
# Epoch 4/6
# 1950/1950 [==============================] - 1047s 537ms/step - loss: 1.8261 - average_final_batch_ratio: 0.1969
# Epoch 5/6
# 1950/1950 [==============================] - 1053s 540ms/step - loss: 1.8198 - average_final_batch_ratio: 0.1969
# Epoch 6/6
# 1950/1950 [==============================] - 1055s 541ms/step - loss: 1.8217 - average_final_batch_ratio: 0.1969

# %%
model.train(256, 192, epochs=10)
# Out:
# Epoch 1/10
# 1950/1950 [==============================] - 1056s 541ms/step - loss: 1.8181 - average_final_batch_ratio: 0.1969
# Epoch 2/10
# 1950/1950 [==============================] - 1057s 542ms/step - loss: 1.8148 - average_final_batch_ratio: 0.1969
# Epoch 3/10
#    1/1950 [..............................] - ETA: 37:03
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# <ipython-input-11-278db9904967> in <module>
# ----> 1 model.train(256, 192, epochs=10)
#
# <ipython-input-5-74936f3ed6d5> in train(self, batch_size, batched_item_length, epochs)
#      67         model = self.training_model(batch_size, batched_item_length)
#      68
# ---> 69         model.fit(dataset, epochs=epochs, callbacks=self.callbacks)
#      70
#      71     @property
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     817         max_queue_size=max_queue_size,
#     818         workers=workers,
# --> 819         use_multiprocessing=use_multiprocessing)
#     820
#     821   def evaluate(self,
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     395                       total_epochs=1)
#     396                   cbks.make_logs(model, epoch_logs, eval_result, ModeKeys.TEST,
# --> 397                                  prefix='val_')
#     398
#     399     return model.history
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Python37_64\lib\contextlib.py in __exit__(self, type, value, traceback)
#     128                 value = type()
#     129             try:
# --> 130                 self.gen.throw(type, value, traceback)
#     131             except StopIteration as exc:
#     132                 # Suppress StopIteration *unless* it's the same exception that
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\training_v2.py in on_epoch(self, epoch, mode)
#     769       if mode == ModeKeys.TRAIN:
#     770         # Epochs only apply to `fit`.
# --> 771         self.callbacks.on_epoch_end(epoch, epoch_logs)
#     772       self.progbar.on_epoch_end(epoch, epoch_logs)
#     773
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     300     logs = logs or {}
#     301     for callback in self.callbacks:
# --> 302       callback.on_epoch_end(epoch, logs)
#     303
#     304   def on_train_batch_begin(self, batch, logs=None):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\callbacks.py in on_epoch_end(self, epoch, logs)
#     990           self._save_model(epoch=epoch, logs=logs)
#     991       else:
# --> 992         self._save_model(epoch=epoch, logs=logs)
#     993     if self.model._in_multi_worker_mode():
#     994       # For multi-worker training, back up the weights and current training
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\callbacks.py in _save_model(self, epoch, logs)
#    1036             print('\nEpoch %05d: saving model to %s' % (epoch + 1, filepath))
#    1037           if self.save_weights_only:
# -> 1038             self.model.save_weights(filepath, overwrite=True)
#    1039           else:
#    1040             self.model.save(filepath, overwrite=True)
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\keras\engine\network.py in save_weights(self, filepath, overwrite, save_format)
#    1121              'saved.\n\nConsider using a TensorFlow optimizer from `tf.train`.')
#    1122             % (optimizer,))
# -> 1123       self._trackable_saver.save(filepath, session=session)
#    1124       # Record this checkpoint so it's visible from tf.train.latest_checkpoint.
#    1125       checkpoint_management.update_checkpoint_state_internal(
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\tracking\util.py in save(self, file_prefix, checkpoint_number, session)
#    1166     file_io.recursive_create_dir(os.path.dirname(file_prefix))
#    1167     save_path, new_feed_additions = self._save_cached_when_graph_building(
# -> 1168         file_prefix=file_prefix_tensor, object_graph_tensor=object_graph_tensor)
#    1169     if new_feed_additions:
#    1170       feed_dict.update(new_feed_additions)
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\tracking\util.py in _save_cached_when_graph_building(self, file_prefix, object_graph_tensor)
#    1114         or context.executing_eagerly() or ops.inside_function()):
#    1115       saver = functional_saver.MultiDeviceSaver(named_saveable_objects)
# -> 1116       save_op = saver.save(file_prefix)
#    1117       with ops.device("/cpu:0"):
#    1118         with ops.control_dependencies([save_op]):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\functional_saver.py in save(self, file_prefix)
#     228         # _SingleDeviceSaver will use the CPU device when necessary, but initial
#     229         # read operations should be placed on the SaveableObject's device.
# --> 230         sharded_saves.append(saver.save(shard_prefix))
#     231
#     232     with ops.control_dependencies(sharded_saves):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\functional_saver.py in save(self, file_prefix)
#      67       for spec in saveable.specs:
#      68         tensor_names.append(spec.name)
# ---> 69         tensors.append(spec.tensor)
#      70         tensor_slices.append(spec.slice_spec)
#      71     with ops.device("cpu:0"):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\saveable_object.py in tensor(self)
#      50   @property
#      51   def tensor(self):
# ---> 52     return self._tensor() if callable(self._tensor) else self._tensor
#      53
#      54
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\training\saving\saveable_object_util.py in f()
#      93             # we copy them to CPU on the same machine first.
#      94             with ops.device("/device:CPU:0"):
# ---> 95               return array_ops.identity(x)
#      96         return f
#      97
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\util\dispatch.py in wrapper(*args, **kwargs)
#     178     """Call target, and fall back on dispatchers if there is a TypeError."""
#     179     try:
# --> 180       return target(*args, **kwargs)
#     181     except (TypeError, ValueError):
#     182       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\ops\array_ops.py in identity(input, name)
#     265     # variables. Variables have correct handle data when graph building.
#     266     input = ops.convert_to_tensor(input)
# --> 267   ret = gen_array_ops.identity(input, name=name)
#     268   # Propagate handle data for happier shape inference for resource variables.
#     269   if hasattr(input, "_handle_data"):
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\ops\gen_array_ops.py in identity(input, name)
#    3824         pass  # Add nodes to the TensorFlow graph.
#    3825     except _core._NotOkStatusException as e:
# -> 3826       _ops.raise_from_not_ok_status(e, name)
#    3827   # Add nodes to the TensorFlow graph.
#    3828   _, _, _op, _outputs = _op_def_library._apply_op_helper(
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\tensorflow_core\python\framework\ops.py in raise_from_not_ok_status(e, name)
#    6604   message = e.message + (" name: " + name if name is not None else "")
#    6605   # pylint: disable=protected-access
# -> 6606   six.raise_from(core._status_to_exception(e.code, message), None)
#    6607   # pylint: enable=protected-access
#    6608
#
# c:\users\joank_000\desktop\rnn-enwik-predictor\env\lib\site-packages\six.py in raise_from(value, from_value)
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:GPU:0 to /job:localhost/replica:0/task:0/device:CPU:0 in order to run Identity: GPU sync failed [Op:Identity]

# %%
model.train(256, 192, epochs=8)
# Out:
# Epoch 1/8
# 1950/1950 [==============================] - 1275s 654ms/step - loss: 2.2094 - average_final_batch_ratio: 0.1918
# Epoch 2/8
# 1950/1950 [==============================] - 1071s 549ms/step - loss: 2.3063 - average_final_batch_ratio: 0.1918
# Epoch 3/8
# 1950/1950 [==============================] - 1050s 538ms/step - loss: 2.1655 - average_final_batch_ratio: 0.1918
# Epoch 4/8
# 1950/1950 [==============================] - 1047s 537ms/step - loss: 2.0989 - average_final_batch_ratio: 0.1918
# Epoch 5/8
# 1950/1950 [==============================] - 1059s 543ms/step - loss: 2.0537 - average_final_batch_ratio: 0.1918
# Epoch 6/8
# 1950/1950 [==============================] - 1050s 538ms/step - loss: 2.0133 - average_final_batch_ratio: 0.1918
# Epoch 7/8
# 1950/1950 [==============================] - 1063s 545ms/step - loss: 1.9896 - average_final_batch_ratio: 0.1918
# Epoch 8/8
# 1950/1950 [==============================] - 1050s 539ms/step - loss: 1.9635 - average_final_batch_ratio: 0.1918

# %%
model.train(256, 192, epochs=5)
# Out:
# Epoch 1/5
# 1950/1950 [==============================] - 1257s 645ms/step - loss: 1.9471 - average_final_batch_ratio: 0.1938
# Epoch 2/5
# 1950/1950 [==============================] - 1046s 536ms/step - loss: 1.9266 - average_final_batch_ratio: 0.1938
# Epoch 3/5
# 1950/1950 [==============================] - 1054s 541ms/step - loss: 1.9137 - average_final_batch_ratio: 0.1938
# Epoch 4/5
# 1950/1950 [==============================] - 1044s 536ms/step - loss: 1.8994 - average_final_batch_ratio: 0.1938
# Epoch 5/5
# 1950/1950 [==============================] - 1052s 540ms/step - loss: 1.8892 - average_final_batch_ratio: 0.1938

# %%
total_raw = 0
total_compressed = 0

huffman = Huffman(encoder.vocab_size)
for index, encoded_article in enumerate(articles.articles_generator(1)):
    if index % 100 == 0:
        article = encoder.decode(encoded_article)
        total_raw += len(article) * 8
        total_compressed += huffman.archive_size(model, encoded_article)
        print('Article %d:\tLength: %d\tAvg Compression: %f' % (index, len(article), total_compressed/total_raw))
# Out:
# Article 0:	Length: 12	Avg Compression: 0.250000
# Article 100:	Length: 28	Avg Compression: 0.287500
# Article 200:	Length: 30	Avg Compression: 0.251786
# Article 300:	Length: 31	Avg Compression: 0.237624
# Article 400:	Length: 32	Avg Compression: 0.219925
# Article 500:	Length: 33	Avg Compression: 0.240211
# Article 600:	Length: 34	Avg Compression: 0.258750
# Article 700:	Length: 35	Avg Compression: 0.254787
# Article 800:	Length: 36	Avg Compression: 0.250000
# Article 900:	Length: 37	Avg Compression: 0.242289
# Article 1000:	Length: 38	Avg Compression: 0.241691
# Article 1100:	Length: 39	Avg Compression: 0.241558
# Article 1200:	Length: 39	Avg Compression: 0.235849
# Article 1300:	Length: 40	Avg Compression: 0.237608
# Article 1400:	Length: 41	Avg Compression: 0.234406
# Article 1500:	Length: 41	Avg Compression: 0.233516
# Article 1600:	Length: 42	Avg Compression: 0.236820
# Article 1700:	Length: 42	Avg Compression: 0.237302
# Article 1800:	Length: 43	Avg Compression: 0.241828
# Article 1900:	Length: 44	Avg Compression: 0.237796
# Article 2000:	Length: 44	Avg Compression: 0.240802
# Article 2100:	Length: 45	Avg Compression: 0.243176
# Article 2200:	Length: 46	Avg Compression: 0.238850
# Article 2300:	Length: 46	Avg Compression: 0.235245
# Article 2400:	Length: 47	Avg Compression: 0.233466
# Article 2500:	Length: 47	Avg Compression: 0.235635
# Article 2600:	Length: 48	Avg Compression: 0.231971
# Article 2700:	Length: 49	Avg Compression: 0.239440
# Article 2800:	Length: 49	Avg Compression: 0.238686
# Article 2900:	Length: 50	Avg Compression: 0.238426
# Article 3000:	Length: 50	Avg Compression: 0.237581
# Article 3100:	Length: 51	Avg Compression: 0.239624
# Article 3200:	Length: 51	Avg Compression: 0.237873
# Article 3300:	Length: 52	Avg Compression: 0.234375
# Article 3400:	Length: 52	Avg Compression: 0.231129
# Article 3500:	Length: 53	Avg Compression: 0.232548
# Article 3600:	Length: 54	Avg Compression: 0.229610
# Article 3700:	Length: 54	Avg Compression: 0.232321
# Article 3800:	Length: 55	Avg Compression: 0.233358
# Article 3900:	Length: 56	Avg Compression: 0.231133
# Article 4000:	Length: 56	Avg Compression: 0.230601
# Article 4100:	Length: 57	Avg Compression: 0.232572
# Article 4200:	Length: 58	Avg Compression: 0.230723
# Article 4300:	Length: 59	Avg Compression: 0.229573
# Article 4400:	Length: 60	Avg Compression: 0.231244
# Article 4500:	Length: 61	Avg Compression: 0.229197
# Article 4600:	Length: 62	Avg Compression: 0.227983
# Article 4700:	Length: 63	Avg Compression: 0.227190
# Article 4800:	Length: 64	Avg Compression: 0.224679
# Article 4900:	Length: 66	Avg Compression: 0.223407
# Article 5000:	Length: 67	Avg Compression: 0.222583
# Article 16200:	Length: 13324	Avg Compression: 0.228748
# Article 16300:	Length: 13582	Avg Compression: 0.228051
# Article 16400:	Length: 13868	Avg Compression: 0.228679
# Article 16500:	Length: 14159	Avg Compression: 0.227888
# Article 16600:	Length: 14497	Avg Compression: 0.226889
# Article 16700:	Length: 14766	Avg Compression: 0.227600
# Article 16800:	Length: 15189	Avg Compression: 0.227720
# Article 16900:	Length: 15589	Avg Compression: 0.228260
# Article 17000:	Length: 15922	Avg Compression: 0.227685
# Article 17100:	Length: 16145	Avg Compression: 0.227485
# Article 17200:	Length: 16798	Avg Compression: 0.226831
# Article 17300:	Length: 17120	Avg Compression: 0.226112
# Article 17400:	Length: 17810	Avg Compression: 0.226871
# Article 17500:	Length: 18049	Avg Compression: 0.227688
# Article 17600:	Length: 18912	Avg Compression: 0.228060
# Article 17700:	Length: 19503	Avg Compression: 0.228150
# Article 17800:	Length: 20117	Avg Compression: 0.228905
# Article 17900:	Length: 20626	Avg Compression: 0.228595
# Article 18000:	Length: 20350	Avg Compression: 0.228262
# Article 18100:	Length: 22076	Avg Compression: 0.228583
# Article 18200:	Length: 22940	Avg Compression: 0.228621
# Article 18300:	Length: 23355	Avg Compression: 0.229168
# Article 18400:	Length: 24560	Avg Compression: 0.229257
# Article 18500:	Length: 25488	Avg Compression: 0.229807
# Article 18600:	Length: 26439	Avg Compression: 0.230338
# Article 18700:	Length: 27252	Avg Compression: 0.230769
# Article 18800:	Length: 28415	Avg Compression: 0.231271
# Article 18900:	Length: 29287	Avg Compression: 0.231523
# Article 19000:	Length: 30865	Avg Compression: 0.231732
# Article 19100:	Length: 32381	Avg Compression: 0.232284
# Article 19200:	Length: 34164	Avg Compression: 0.231924
# Article 19300:	Length: 35990	Avg Compression: 0.230895
# Article 19400:	Length: 38524	Avg Compression: 0.231364
# Article 19500:	Length: 41139	Avg Compression: 0.231848
# Article 19600:	Length: 43795	Avg Compression: 0.232296
# Article 19700:	Length: 47945	Avg Compression: 0.232989
# Article 19800:	Length: 52573	Avg Compression: 0.232968
# Article 19900:	Length: 61215	Avg Compression: 0.233794

# %% [markdown]
# ## Нека запишем примерно предвиждане на данни; ще го използваме за тестване на кодиране на huffman и аритметично кодиране

# %%
text = articles.encoded_articles[18000]
input_eval = np.array([[text[0]]], dtype=TYPE)

model.predicting_model.reset_states()

char_actual = []
char_predictions = []

for byte in text[1:]:
    predictions = model.predict(input_eval)
    predictions = tf.squeeze(predictions, 0) # remove the batch dimension

    weights = tf.nn.softmax(predictions[0]).numpy()
    char_actual.append(byte)
    char_predictions.append(weights)

    input_eval = tf.expand_dims([byte], 0)

# %%
with open('char-actual', 'wb') as file:
    file.write(np.array(char_actual).tobytes())

# %%
with open('char-predictions', 'wb') as file:
    file.write(np.array(char_predictions).tobytes())

# %%
np.array(char_predictions).shape
# Out:
# (8680, 1014)

# %%
char_predictions[0]
# Out:
# array([1.7285488e-06, 3.6423372e-03, 1.1795628e-06, ..., 7.9423105e-03,
#        2.4557270e-03, 2.2815516e-06], dtype=float32)
