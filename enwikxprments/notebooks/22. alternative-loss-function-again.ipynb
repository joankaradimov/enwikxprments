# %%
import itertools
import os

import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds

# %%
def articles():
    with open('page_revisions_text', 'rb') as text_file:
        pending_article_data = b''
        while True:
            data = text_file.read(1024 ** 2)
            if len(data) == 0:
                break

            articles = data.split(b'\0')
            articles[0] = pending_article_data + articles[0]
            for index, article in enumerate(articles):
                if index + 1 == len(articles):
                    pending_article_data = article
                else:
                    yield article

        print(pending_article_data)
        if len(pending_article_data) != 0:
            yield pending_article_data

# %%
subword_text_encoder = tfds.features.text.SubwordTextEncoder.load_from_file('vocab_4096')

# %%
BATCH_SIZE = 256
BATCHED_ITEM_LENGTH = 128
BUFFER_SIZE = 1024
TYPE=np.int16

def articles_generator():
    for index, article in enumerate(itertools.islice(articles(), 0, 512)):
        yield np.array(subword_text_encoder.encode(article + b'\0'), dtype=TYPE)

    # Pad the article count to the batch size
    # We do this to ensure that no data is dropped
    index += 1
    while index % BATCH_SIZE != 0:
        yield np.array([0], dtype=TYPE)
        index += 1

def subbatches():
    dataset = tf.data.Dataset.from_generator(articles_generator, output_types=TYPE)
    dataset = dataset.shuffle(BUFFER_SIZE)
    dataset = dataset.padded_batch(BATCH_SIZE, padded_shapes=([None]), drop_remainder=True)
    dataset = dataset.shuffle(2000)

    for batch in dataset.as_numpy_iterator():
        remaining = batch
        while remaining.shape[1] > 1:
            yield remaining[:, :BATCHED_ITEM_LENGTH + 1]
            remaining = remaining[:, BATCHED_ITEM_LENGTH:]

dataset = tf.data.Dataset.from_generator(subbatches, output_types=TYPE, output_shapes=(BATCH_SIZE, None))
dataset = dataset.map(lambda batch: (batch[:, :-1], batch[:, 1:]))

dataset
# Out:
# <MapDataset shapes: ((256, None), (256, None)), types: (tf.int16, tf.int16)>

# %%
def build_model(vocab_size, embedding_dim, rnn_units, batch_size):
    return tf.keras.Sequential([
        tf.keras.layers.Masking(mask_value=0, batch_input_shape=[batch_size, None]),
        tf.keras.layers.Embedding(vocab_size, embedding_dim),
        tf.keras.layers.LSTM(rnn_units, return_sequences=True, stateful=True, recurrent_initializer='glorot_uniform'),
        tf.keras.layers.LSTM(rnn_units, return_sequences=True, stateful=True, recurrent_initializer='glorot_uniform'),
        tf.keras.layers.Dense(vocab_size),
    ])

# %%
from tensorflow.python.eager import context
from tensorflow.python.keras import backend_config
from tensorflow.python.framework import constant_op
from tensorflow.python.framework import ops
from tensorflow.python.framework import tensor_util
from tensorflow.python.ops import array_ops
from tensorflow.python.ops import nn
from tensorflow.python.ops import clip_ops
from tensorflow.python.ops import math_ops
from tensorflow.python.ops import variables as variables_module

epsilon = backend_config.epsilon

def get_graph():
    if context.executing_eagerly():
        global _GRAPH
        if _GRAPH is None:
            _GRAPH = func_graph.FuncGraph('keras_graph')
        return _GRAPH
    else:
        return ops.get_default_graph()

def flatten(x):
    return array_ops.reshape(x, [-1])

def cast(x, dtype):
    return math_ops.cast(x, dtype)
  
def _is_symbolic_tensor(x):
    return tensor_util.is_tensor(x) and not isinstance(x, ops.EagerTensor)

# This is based around the `sparse_categorical_crossentropy` implementation in Keras:
# https://github.com/tensorflow/tensorflow/blob/v2.1.0/tensorflow/python/keras/backend.py#L4507-L4582
def loss(target, output, from_logits=False, axis=-1):
    if not from_logits:
        if (isinstance(output, (ops.EagerTensor, variables_module.Variable)) or output.op.type != 'Softmax'):
            epsilon_ = constant_op.constant(epsilon(), dtype=output.dtype.base_dtype)
            output = clip_ops.clip_by_value(output, epsilon_, 1 - epsilon_)
            output = math_ops.log(output)
        else:
            # When softmax activation function is used for output operation, we
            # use logits from the softmax function directly to compute loss in order
            # to prevent collapsing zero when training.
            # See b/117284466
            assert len(output.op.inputs) == 1
            output = output.op.inputs[0]
  
    if isinstance(output.shape, (tuple, list)):
        output_rank = len(output.shape)
    else:
        output_rank = output.shape.ndims

    if output_rank is not None:
        axis %= output_rank
        if axis != output_rank - 1:
            permutation = list(itertools.chain(range(axis), range(axis + 1, output_rank), [axis]))
            output = array_ops.transpose(output, perm=permutation)
    elif axis != -1:
        raise ValueError(
            'Cannot compute sparse categorical crossentropy with `axis={}` on an '
            'output tensor with unknown rank'.format(axis))
  
    target = cast(target, 'int64')
  
    # Try to adjust the shape so that rank of labels = rank of logits - 1.
    output_shape = array_ops.shape_v2(output)
    target_rank = target.shape.ndims
  
    update_shape = (target_rank is not None and output_rank is not None and target_rank != output_rank - 1)
    if update_shape:
        target = flatten(target)
        output = array_ops.reshape(output, [-1, output_shape[-1]])
  
    if __builtins__.any([_is_symbolic_tensor(v) for v in [target, output]]):
        with get_graph().as_default():
            res = huffman_code_lengths(labels=target, logits=output)
    else:
        res = huffman_code_lengths(labels=target, logits=output)
  
    if update_shape and output_rank >= 3:
        # If our output includes timesteps or spatial dimensions we need to reshape
        return array_ops.reshape(res, output_shape[:-1])
    else:
        return res

def log2(x):
    return tf.math.log(x) / tf.math.log(2.0)
    
def huffman_code_lengths(labels, logits):
    category_count = logits.shape[-1] or 0
    
    return tf.reduce_sum(-log2(tf.one_hot(labels, depth=category_count) * tf.nn.softmax(logits) + 0.0001), axis=-1)

# %%
def average_batch_length(true_labels, predictions):
    return tf.shape(true_labels)[1]

model = build_model(vocab_size = subword_text_encoder.vocab_size, embedding_dim=512, rnn_units=1024, batch_size=BATCH_SIZE)
model.compile(optimizer='adam', loss=loss, metrics=[average_batch_length])

# %%
checkpoint_dir = './training_checkpoints-1' # Directory where the checkpoints will be saved
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt_{epoch}") # Name of the checkpoint files

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_prefix, save_weights_only=True)

# %%
class ModelStateResetter(tf.keras.callbacks.Callback):
    def __init__(self):
        self.last_total_length = 0

    def on_batch_end(self, batch, logs={}):
        average_batch_length = logs.get('average_batch_length', 0)
        total_length = int(round(average_batch_length * (batch + 1)))
        current_batch_length = total_length - self.last_total_length
        self.last_total_length = total_length
        
        if current_batch_length < BATCHED_ITEM_LENGTH:
            self.model.reset_states()
        
model_state_resetter_callback = ModelStateResetter()

# %%
total_epochs = 10

for epoch in range(total_epochs):
    print('Epoch %d/%d' % (epoch + 1, total_epochs))
    model.fit(dataset, callbacks=[checkpoint_callback, model_state_resetter_callback])
# Out:
# Epoch 1/10
# 423/423 [==============================] - 303s 717ms/step - loss: 53776.4013 - average_batch_length: 127.7447
# Epoch 2/10
# 448/448 [==============================] - 316s 706ms/step - loss: 53776.4237 - average_batch_length: 127.8125
# Epoch 3/10
# 448/448 [==============================] - 312s 697ms/step - loss: 53776.6859 - average_batch_length: 127.8125
# Epoch 4/10
# 448/448 [==============================] - 312s 697ms/step - loss: 53777.4770 - average_batch_length: 127.8125
# Epoch 5/10
# 401/401 [==============================] - 279s 696ms/step - loss: 53777.6240 - average_batch_length: 127.9327
# Epoch 6/10
# 448/448 [==============================] - 311s 694ms/step - loss: 53777.4947 - average_batch_length: 127.8125
# Epoch 7/10
# 448/448 [==============================] - 311s 694ms/step - loss: 53777.4929 - average_batch_length: 127.8125
# Epoch 8/10
# 448/448 [==============================] - 311s 695ms/step - loss: 53777.4932 - average_batch_length: 127.8013
# Epoch 9/10
# 423/423 [==============================] - 295s 696ms/step - loss: 53777.5590 - average_batch_length: 127.7447
# Epoch 10/10
# 448/448 [==============================] - 312s 697ms/step - loss: 53778.0135 - average_batch_length: 127.8013

# %%
import ctypes

class Huffman:
    huffman = ctypes.CDLL('x64/Release/huffman')
    
    huffman.create_tree.restype = ctypes.c_void_p
    huffman.destroy_tree.restype = None
    huffman.load_weights.restype = None
    huffman.create_code_string.restype = ctypes.c_char_p
    
    def __init__(self, category_count):
        self.tree = ctypes.c_void_p(self.huffman.create_tree(category_count))

    def __del__(self):
        self.huffman.destroy_tree(self.tree)
        
    def load_weights(self, weights):
        self.huffman.load_weights(self.tree, weights.ctypes.data_as(ctypes.POINTER(ctypes.c_float)))
    
    def get_code_length(self, category):
        return self.huffman.get_code_length(self.tree, category)

    def get_code_zero_count(self, category):
        return self.huffman.get_code_zero_count(self.tree, category)

# %%
def huffman_archive_size(model, text):
    archived_size = 0
    zeros = 0
    input_eval = np.array([[0]], dtype=TYPE)
    huffman_tree = Huffman(subword_text_encoder.vocab_size)

    text_generated = []

    model.reset_states()

    for index, byte in enumerate(text):
        predictions = model(input_eval)
        predictions = tf.squeeze(predictions, 0) # remove the batch dimension

        weights = tf.nn.softmax(predictions[0]).numpy()
        huffman_tree.load_weights(weights)
        zeros += huffman_tree.get_code_zero_count(byte.item())
        archived_size += huffman_tree.get_code_length(byte.item())

        input_eval = tf.expand_dims([byte], 0)
  
    return archived_size, zeros

# %%
tf.train.latest_checkpoint(checkpoint_dir)
model = build_model(vocab_size = subword_text_encoder.vocab_size, embedding_dim=512, rnn_units=1024, batch_size=1)
model.load_weights(tf.train.latest_checkpoint(checkpoint_dir))
model.build(tf.TensorShape([1, None]))

# %%
total_raw = 0
total_compressed = 0

for index, article in enumerate(itertools.islice(articles(), 0, 512)):
    raw = (len(article) + 1) * 8
    encoded_article = np.array(subword_text_encoder.encode(article + b'\0'), dtype=TYPE)
    compressed, _ = huffman_archive_size(model, encoded_article)
    total_raw += raw
    total_compressed += compressed
    print('Article %d:\tCompression: %f\tAvg Compression: %f' % (index, compressed/raw, total_compressed/total_raw))
# Out:
# Article 0:	Compression: 0.611111	Avg Compression: 0.611111
# Article 1:	Compression: 0.630952	Avg Compression: 0.625000
# Article 2:	Compression: 0.520408	Avg Compression: 0.577982
# Article 3:	Compression: 0.658333	Avg Compression: 0.595324
# Article 4:	Compression: 0.671429	Avg Compression: 0.610632
# Article 5:	Compression: 0.455128	Avg Compression: 0.582160
# Article 6:	Compression: 0.580207	Avg Compression: 0.580214
# Article 7:	Compression: 0.577703	Avg Compression: 0.580212
# Article 8:	Compression: 0.596875	Avg Compression: 0.580223
# Article 9:	Compression: 0.517857	Avg Compression: 0.580179
# Article 10:	Compression: 0.773026	Avg Compression: 0.580303
# Article 11:	Compression: 0.505682	Avg Compression: 0.580248
# Article 12:	Compression: 0.531250	Avg Compression: 0.580211
# Article 13:	Compression: 0.671053	Avg Compression: 0.580269
# Article 14:	Compression: 0.563830	Avg Compression: 0.580256
# Article 15:	Compression: 0.671875	Avg Compression: 0.580294
# Article 16:	Compression: 0.578571	Avg Compression: 0.580293
# Article 17:	Compression: 0.755208	Avg Compression: 0.580363
# Article 18:	Compression: 0.563721	Avg Compression: 0.572806
# Article 19:	Compression: 0.575758	Avg Compression: 0.572807
# Article 20:	Compression: 0.557143	Avg Compression: 0.572802
# Article 21:	Compression: 0.516447	Avg Compression: 0.572782
# Article 22:	Compression: 0.766667	Avg Compression: 0.572836
# Article 23:	Compression: 0.620192	Avg Compression: 0.572847
# Article 24:	Compression: 0.632353	Avg Compression: 0.572866
# Article 25:	Compression: 0.757576	Avg Compression: 0.572922
# Article 26:	Compression: 0.744565	Avg Compression: 0.572958
# Article 27:	Compression: 0.603040	Avg Compression: 0.575229
# Article 28:	Compression: 0.584459	Avg Compression: 0.575232
# Article 29:	Compression: 0.480603	Avg Compression: 0.575186
# Article 30:	Compression: 0.657362	Avg Compression: 0.581927
# Article 31:	Compression: 0.708333	Avg Compression: 0.581951
# Article 32:	Compression: 0.778409	Avg Compression: 0.581984
# Article 33:	Compression: 0.771739	Avg Compression: 0.582018
# Article 34:	Compression: 0.818182	Avg Compression: 0.582059
# Article 35:	Compression: 0.784091	Avg Compression: 0.582093
# Article 36:	Compression: 0.640625	Avg Compression: 0.582104
# Article 37:	Compression: 0.892857	Avg Compression: 0.582155
# Article 38:	Compression: 0.767857	Avg Compression: 0.582186
# Article 39:	Compression: 0.678571	Avg Compression: 0.582207
# Article 40:	Compression: 0.829167	Avg Compression: 0.582264
# Article 41:	Compression: 0.796875	Avg Compression: 0.582305
# Article 42:	Compression: 0.546569	Avg Compression: 0.582290
# Article 43:	Compression: 0.706395	Avg Compression: 0.582332
# Article 44:	Compression: 0.660714	Avg Compression: 0.582357
# Article 45:	Compression: 0.660714	Avg Compression: 0.582383
# Article 46:	Compression: 0.714744	Avg Compression: 0.582423
# Article 47:	Compression: 0.714744	Avg Compression: 0.582463
# Article 48:	Compression: 0.399194	Avg Compression: 0.582419
# Article 49:	Compression: 0.794643	Avg Compression: 0.582465
# Article 50:	Compression: 0.744565	Avg Compression: 0.582494
# Article 51:	Compression: 0.768939	Avg Compression: 0.582542
# Article 52:	Compression: 0.763889	Avg Compression: 0.582580
# Article 53:	Compression: 0.678571	Avg Compression: 0.582601
# Article 54:	Compression: 0.690000	Avg Compression: 0.582622
# Article 55:	Compression: 0.702703	Avg Compression: 0.582656
# Article 56:	Compression: 0.713542	Avg Compression: 0.582681
# Article 57:	Compression: 0.702381	Avg Compression: 0.582700
# Article 58:	Compression: 0.673387	Avg Compression: 0.582722
# Article 59:	Compression: 0.770833	Avg Compression: 0.582757
# Article 60:	Compression: 0.582143	Avg Compression: 0.582757
# Article 61:	Compression: 0.746212	Avg Compression: 0.582798
# Article 62:	Compression: 0.656250	Avg Compression: 0.582814
# Article 63:	Compression: 0.612903	Avg Compression: 0.582822
# Article 64:	Compression: 0.583333	Avg Compression: 0.582822
# Article 65:	Compression: 0.715909	Avg Compression: 0.582844
# Article 66:	Compression: 0.677083	Avg Compression: 0.582862
# Article 67:	Compression: 0.683036	Avg Compression: 0.582884
# Article 68:	Compression: 0.625000	Avg Compression: 0.582893
# Article 69:	Compression: 0.511111	Avg Compression: 0.582868
# Article 70:	Compression: 0.512500	Avg Compression: 0.582852
# Article 71:	Compression: 0.683594	Avg Compression: 0.582877
# Article 72:	Compression: 0.705645	Avg Compression: 0.582906
# Article 73:	Compression: 0.454545	Avg Compression: 0.582873
# Article 74:	Compression: 0.561047	Avg Compression: 0.582866
# Article 75:	Compression: 0.729839	Avg Compression: 0.582901
# Article 76:	Compression: 0.733696	Avg Compression: 0.582928
# Article 77:	Compression: 0.692857	Avg Compression: 0.582958
# Article 78:	Compression: 0.532895	Avg Compression: 0.582943
# Article 79:	Compression: 0.650735	Avg Compression: 0.582961
# Article 80:	Compression: 0.776515	Avg Compression: 0.583010
# Article 81:	Compression: 0.554487	Avg Compression: 0.583002
# Article 82:	Compression: 0.637500	Avg Compression: 0.583010
# Article 83:	Compression: 0.500000	Avg Compression: 0.582983
# Article 84:	Compression: 0.649045	Avg Compression: 0.588141
# Article 85:	Compression: 0.672794	Avg Compression: 0.588161
# Article 86:	Compression: 0.609848	Avg Compression: 0.588166
# Article 87:	Compression: 0.500000	Avg Compression: 0.588140
# Article 88:	Compression: 0.663793	Avg Compression: 0.588156
# Article 89:	Compression: 0.527778	Avg Compression: 0.588140
# Article 90:	Compression: 0.775862	Avg Compression: 0.588179
# Article 91:	Compression: 0.513889	Avg Compression: 0.588164
# Article 92:	Compression: 0.642739	Avg Compression: 0.595133
# Article 93:	Compression: 0.579545	Avg Compression: 0.595131
# Article 94:	Compression: 0.656436	Avg Compression: 0.601995
# Article 95:	Compression: 0.661765	Avg Compression: 0.602006
# Article 96:	Compression: 0.574993	Avg Compression: 0.593737
# Article 97:	Compression: 0.589538	Avg Compression: 0.593130
# Article 98:	Compression: 0.615255	Avg Compression: 0.593210
# Article 99:	Compression: 0.637500	Avg Compression: 0.593213
# Article 100:	Compression: 0.511111	Avg Compression: 0.593201
# Article 101:	Compression: 0.588068	Avg Compression: 0.593200
# Article 102:	Compression: 0.513889	Avg Compression: 0.593188
# Article 103:	Compression: 0.562500	Avg Compression: 0.593183
# Article 104:	Compression: 0.533482	Avg Compression: 0.593172
# Article 105:	Compression: 0.544118	Avg Compression: 0.593164
# Article 106:	Compression: 0.556548	Avg Compression: 0.593159
# Article 107:	Compression: 0.620833	Avg Compression: 0.593165
# Article 108:	Compression: 0.576923	Avg Compression: 0.593162
# Article 109:	Compression: 0.572115	Avg Compression: 0.593158
# Article 110:	Compression: 0.645349	Avg Compression: 0.593166
# Article 111:	Compression: 0.625000	Avg Compression: 0.593171
# Article 112:	Compression: 0.646148	Avg Compression: 0.594854
# Article 113:	Compression: 0.513889	Avg Compression: 0.594847
# Article 114:	Compression: 0.637500	Avg Compression: 0.594849
# Article 115:	Compression: 0.660326	Avg Compression: 0.594859
# Article 116:	Compression: 0.518750	Avg Compression: 0.594854
# Article 117:	Compression: 0.670830	Avg Compression: 0.595120
# Article 118:	Compression: 0.667763	Avg Compression: 0.595129
# Article 119:	Compression: 0.606458	Avg Compression: 0.595255
# Article 120:	Compression: 0.550985	Avg Compression: 0.592016
# Article 121:	Compression: 0.678499	Avg Compression: 0.593222
# Article 122:	Compression: 0.662037	Avg Compression: 0.593227
# Article 123:	Compression: 0.593922	Avg Compression: 0.593299
# Article 124:	Compression: 0.659321	Avg Compression: 0.593596
# Article 125:	Compression: 0.661765	Avg Compression: 0.593601
# Article 126:	Compression: 0.661290	Avg Compression: 0.593607
# Article 127:	Compression: 0.602304	Avg Compression: 0.593700
# Article 128:	Compression: 0.606061	Avg Compression: 0.593701
# Article 129:	Compression: 0.582143	Avg Compression: 0.593700
# Article 130:	Compression: 0.539474	Avg Compression: 0.593695
# Article 131:	Compression: 0.658088	Avg Compression: 0.593701
# Article 132:	Compression: 0.572889	Avg Compression: 0.593232
# Article 133:	Compression: 0.525000	Avg Compression: 0.593226
# Article 134:	Compression: 0.589286	Avg Compression: 0.593225
# Article 135:	Compression: 0.713235	Avg Compression: 0.593235
# Article 136:	Compression: 0.554348	Avg Compression: 0.593231
# Article 137:	Compression: 0.659722	Avg Compression: 0.593237
# Article 138:	Compression: 0.705645	Avg Compression: 0.593254
# Article 139:	Compression: 0.650873	Avg Compression: 0.596527
# Article 140:	Compression: 0.594263	Avg Compression: 0.596378
# Article 141:	Compression: 0.600547	Avg Compression: 0.596409
# Article 142:	Compression: 0.662625	Avg Compression: 0.597531
# Article 143:	Compression: 0.583555	Avg Compression: 0.597400
# Article 144:	Compression: 0.714744	Avg Compression: 0.597410
# Article 145:	Compression: 0.631118	Avg Compression: 0.598612
# Article 146:	Compression: 0.584941	Avg Compression: 0.598387
# Article 147:	Compression: 0.612198	Avg Compression: 0.598758
# Article 148:	Compression: 0.541552	Avg Compression: 0.595430
# Article 149:	Compression: 0.542976	Avg Compression: 0.592121
# Article 150:	Compression: 0.667857	Avg Compression: 0.592125
# Article 151:	Compression: 0.550688	Avg Compression: 0.591638
# Article 152:	Compression: 0.575468	Avg Compression: 0.590159
# Article 153:	Compression: 0.558955	Avg Compression: 0.589443
# Article 154:	Compression: 0.586957	Avg Compression: 0.589443
# Article 155:	Compression: 0.614339	Avg Compression: 0.590530
# Article 156:	Compression: 0.570562	Avg Compression: 0.589246
# Article 157:	Compression: 0.674304	Avg Compression: 0.590791
# Article 158:	Compression: 0.675584	Avg Compression: 0.590904
# Article 159:	Compression: 0.640125	Avg Compression: 0.591236
# Article 160:	Compression: 0.755208	Avg Compression: 0.591241
# Article 161:	Compression: 0.574111	Avg Compression: 0.591149
# Article 162:	Compression: 0.742365	Avg Compression: 0.596432
# Article 163:	Compression: 0.611106	Avg Compression: 0.596485
# Article 164:	Compression: 0.602261	Avg Compression: 0.596829
# Article 165:	Compression: 0.761628	Avg Compression: 0.596838
# Article 166:	Compression: 0.679804	Avg Compression: 0.597088
# Article 167:	Compression: 0.685000	Avg Compression: 0.597090
# Article 168:	Compression: 0.740000	Avg Compression: 0.597094
# Article 169:	Compression: 0.614499	Avg Compression: 0.597312
# Article 170:	Compression: 0.635530	Avg Compression: 0.598530
# Article 171:	Compression: 0.663464	Avg Compression: 0.601788
# Article 172:	Compression: 0.460714	Avg Compression: 0.601783
# Article 173:	Compression: 0.597257	Avg Compression: 0.601762
# Article 174:	Compression: 0.669872	Avg Compression: 0.601765
# Article 175:	Compression: 0.665819	Avg Compression: 0.602519
# Article 176:	Compression: 0.665362	Avg Compression: 0.603444
# Article 177:	Compression: 0.598485	Avg Compression: 0.603444
# Article 178:	Compression: 0.575000	Avg Compression: 0.603443
# Article 179:	Compression: 0.532895	Avg Compression: 0.603440
# Article 180:	Compression: 0.650735	Avg Compression: 0.603442
# Article 181:	Compression: 0.776515	Avg Compression: 0.603447
# Article 182:	Compression: 0.670455	Avg Compression: 0.603449
# Article 183:	Compression: 0.518750	Avg Compression: 0.603445
# Article 184:	Compression: 0.546875	Avg Compression: 0.603443
# Article 185:	Compression: 0.581395	Avg Compression: 0.603442
# Article 186:	Compression: 0.581395	Avg Compression: 0.603441
# Article 187:	Compression: 0.581395	Avg Compression: 0.603440
# Article 188:	Compression: 0.632820	Avg Compression: 0.603559
# Article 189:	Compression: 0.555359	Avg Compression: 0.603435
# Article 190:	Compression: 0.604167	Avg Compression: 0.603435
# Article 191:	Compression: 0.596390	Avg Compression: 0.603432
# Article 192:	Compression: 0.575893	Avg Compression: 0.603431
# Article 193:	Compression: 0.569050	Avg Compression: 0.601586
# Article 194:	Compression: 0.586346	Avg Compression: 0.601215
# Article 195:	Compression: 0.658087	Avg Compression: 0.601676
# Article 196:	Compression: 0.659091	Avg Compression: 0.601677
# Article 197:	Compression: 0.717105	Avg Compression: 0.601679
# Article 198:	Compression: 0.599257	Avg Compression: 0.601602
# Article 199:	Compression: 0.602395	Avg Compression: 0.601605
# Article 200:	Compression: 0.625000	Avg Compression: 0.601606
# Article 201:	Compression: 0.612443	Avg Compression: 0.601850
# Article 202:	Compression: 0.593285	Avg Compression: 0.601714
# Article 203:	Compression: 0.695312	Avg Compression: 0.601717
# Article 204:	Compression: 0.719541	Avg Compression: 0.601932
# Article 205:	Compression: 0.763050	Avg Compression: 0.602211
# Article 206:	Compression: 0.604292	Avg Compression: 0.602237
# Article 207:	Compression: 0.594939	Avg Compression: 0.602218
# Article 208:	Compression: 0.718750	Avg Compression: 0.602221
# Article 209:	Compression: 0.675000	Avg Compression: 0.602223
# Article 210:	Compression: 0.675000	Avg Compression: 0.602225
# Article 211:	Compression: 0.675000	Avg Compression: 0.602228
# Article 212:	Compression: 0.614288	Avg Compression: 0.602609
# Article 213:	Compression: 0.542314	Avg Compression: 0.602067
# Article 214:	Compression: 0.570087	Avg Compression: 0.602009
# Article 215:	Compression: 0.833333	Avg Compression: 0.602013
# Article 216:	Compression: 0.527778	Avg Compression: 0.602011
# Article 217:	Compression: 0.527778	Avg Compression: 0.602009
# Article 218:	Compression: 0.550781	Avg Compression: 0.602007
# Article 219:	Compression: 0.637500	Avg Compression: 0.602008
# Article 220:	Compression: 0.574719	Avg Compression: 0.601963
# Article 221:	Compression: 0.640625	Avg Compression: 0.601964
# Article 222:	Compression: 0.592983	Avg Compression: 0.601898
# Article 223:	Compression: 0.460714	Avg Compression: 0.601894
# Article 224:	Compression: 0.592550	Avg Compression: 0.601814
# Article 225:	Compression: 0.671168	Avg Compression: 0.601836
# Article 226:	Compression: 0.605140	Avg Compression: 0.601866
# Article 227:	Compression: 0.718219	Avg Compression: 0.603137
# Article 228:	Compression: 0.619027	Avg Compression: 0.603176
# Article 229:	Compression: 0.581081	Avg Compression: 0.603176
# Article 230:	Compression: 0.652763	Avg Compression: 0.603322
# Article 231:	Compression: 0.590643	Avg Compression: 0.602903
# Article 232:	Compression: 0.575883	Avg Compression: 0.602842
# Article 233:	Compression: 0.611375	Avg Compression: 0.603018
# Article 234:	Compression: 0.578717	Avg Compression: 0.602199
# Article 235:	Compression: 0.624495	Avg Compression: 0.602361
# Article 236:	Compression: 0.561720	Avg Compression: 0.602254
# Article 237:	Compression: 0.738980	Avg Compression: 0.602657
# Article 238:	Compression: 0.581873	Avg Compression: 0.602633
# Article 239:	Compression: 0.750000	Avg Compression: 0.602635
# Article 240:	Compression: 0.584743	Avg Compression: 0.602403
# Article 241:	Compression: 0.726969	Avg Compression: 0.602655
# Article 242:	Compression: 0.752098	Avg Compression: 0.603486
# Article 243:	Compression: 0.644424	Avg Compression: 0.603539
# Article 244:	Compression: 0.660434	Avg Compression: 0.603812
# Article 245:	Compression: 0.548833	Avg Compression: 0.603649
# Article 246:	Compression: 0.678571	Avg Compression: 0.603650
# Article 247:	Compression: 0.593284	Avg Compression: 0.603644
# Article 248:	Compression: 0.618322	Avg Compression: 0.603710
# Article 249:	Compression: 0.680418	Avg Compression: 0.603820
# Article 250:	Compression: 0.605411	Avg Compression: 0.603825
# Article 251:	Compression: 0.577006	Avg Compression: 0.603796
# Article 252:	Compression: 0.787037	Avg Compression: 0.603799
# Article 253:	Compression: 0.747735	Avg Compression: 0.605883
# Article 254:	Compression: 0.532143	Avg Compression: 0.605882
# Article 255:	Compression: 0.718750	Avg Compression: 0.605884
# Article 256:	Compression: 0.661442	Avg Compression: 0.606779
# Article 257:	Compression: 0.652535	Avg Compression: 0.607171
# Article 258:	Compression: 0.531127	Avg Compression: 0.606361
# Article 259:	Compression: 0.600000	Avg Compression: 0.606361
# Article 260:	Compression: 0.542553	Avg Compression: 0.606359
# Article 261:	Compression: 0.558908	Avg Compression: 0.606032
# Article 262:	Compression: 0.689694	Avg Compression: 0.606115
# Article 263:	Compression: 0.592822	Avg Compression: 0.605944
# Article 264:	Compression: 0.617587	Avg Compression: 0.606118
# Article 265:	Compression: 0.635417	Avg Compression: 0.606118
# Article 266:	Compression: 0.585684	Avg Compression: 0.605786
# Article 267:	Compression: 0.630676	Avg Compression: 0.606106
# Article 268:	Compression: 0.621094	Avg Compression: 0.606106
# Article 269:	Compression: 0.586823	Avg Compression: 0.605917
# Article 270:	Compression: 0.635348	Avg Compression: 0.606011
# Article 271:	Compression: 0.612852	Avg Compression: 0.606028
# Article 272:	Compression: 0.571936	Avg Compression: 0.605926
# Article 273:	Compression: 0.609928	Avg Compression: 0.605929
# Article 274:	Compression: 0.687978	Avg Compression: 0.606035
# Article 275:	Compression: 0.606064	Avg Compression: 0.606035
# Article 276:	Compression: 0.528584	Avg Compression: 0.605945
# Article 277:	Compression: 0.557722	Avg Compression: 0.605666
# Article 278:	Compression: 0.697410	Avg Compression: 0.606194
# Article 279:	Compression: 0.589542	Avg Compression: 0.606089
# Article 280:	Compression: 0.692708	Avg Compression: 0.606091
# Article 281:	Compression: 0.607606	Avg Compression: 0.606122
# Article 282:	Compression: 0.660010	Avg Compression: 0.606242
# Article 283:	Compression: 0.579454	Avg Compression: 0.605993
# Article 284:	Compression: 0.686028	Avg Compression: 0.607032
# Article 285:	Compression: 0.467391	Avg Compression: 0.607029
# Article 286:	Compression: 0.650000	Avg Compression: 0.607030
# Article 287:	Compression: 0.853573	Avg Compression: 0.607402
# Article 288:	Compression: 0.590222	Avg Compression: 0.607384
# Article 289:	Compression: 0.650000	Avg Compression: 0.607385
# Article 290:	Compression: 0.768371	Avg Compression: 0.607789
# Article 291:	Compression: 0.659091	Avg Compression: 0.607789
# Article 292:	Compression: 0.611965	Avg Compression: 0.607935
# Article 293:	Compression: 0.603759	Avg Compression: 0.607810
# Article 294:	Compression: 0.655278	Avg Compression: 0.608351
# Article 295:	Compression: 0.653960	Avg Compression: 0.608717
# Article 296:	Compression: 0.626105	Avg Compression: 0.608995
# Article 297:	Compression: 0.700000	Avg Compression: 0.608997
# Article 298:	Compression: 0.678571	Avg Compression: 0.608998
# Article 299:	Compression: 0.619448	Avg Compression: 0.609178
# Article 300:	Compression: 0.624125	Avg Compression: 0.609372
# Article 301:	Compression: 0.653405	Avg Compression: 0.609788
# Article 302:	Compression: 0.569102	Avg Compression: 0.609495
# Article 303:	Compression: 0.721154	Avg Compression: 0.609496
# Article 304:	Compression: 0.562610	Avg Compression: 0.608847
# Article 305:	Compression: 0.564431	Avg Compression: 0.608349
# Article 306:	Compression: 0.602796	Avg Compression: 0.608325
# Article 307:	Compression: 0.632353	Avg Compression: 0.608325
# Article 308:	Compression: 0.675403	Avg Compression: 0.608327
# Article 309:	Compression: 0.531250	Avg Compression: 0.608326
# Article 310:	Compression: 0.687500	Avg Compression: 0.608327
# Article 311:	Compression: 0.566860	Avg Compression: 0.608326
# Article 312:	Compression: 0.516447	Avg Compression: 0.608325
# Article 313:	Compression: 0.664062	Avg Compression: 0.608326
# Article 314:	Compression: 0.757576	Avg Compression: 0.608328
# Article 315:	Compression: 0.503125	Avg Compression: 0.608327
# Article 316:	Compression: 0.566860	Avg Compression: 0.608326
# Article 317:	Compression: 0.647940	Avg Compression: 0.608378
# Article 318:	Compression: 0.617606	Avg Compression: 0.608618
# Article 319:	Compression: 0.588071	Avg Compression: 0.608598
# Article 320:	Compression: 0.754167	Avg Compression: 0.608600
# Article 321:	Compression: 0.581655	Avg Compression: 0.608591
# Article 322:	Compression: 0.601651	Avg Compression: 0.608563
# Article 323:	Compression: 0.551562	Avg Compression: 0.607567
# Article 324:	Compression: 0.553593	Avg Compression: 0.606478
# Article 325:	Compression: 0.726601	Avg Compression: 0.606641
# Article 326:	Compression: 0.544414	Avg Compression: 0.605524
# Article 327:	Compression: 0.548141	Avg Compression: 0.604982
# Article 328:	Compression: 0.667763	Avg Compression: 0.604983
# Article 329:	Compression: 0.702519	Avg Compression: 0.605030
# Article 330:	Compression: 0.611386	Avg Compression: 0.605031
# Article 331:	Compression: 0.651724	Avg Compression: 0.605089
# Article 332:	Compression: 0.627544	Avg Compression: 0.605102
# Article 333:	Compression: 0.570273	Avg Compression: 0.604270
# Article 334:	Compression: 0.597133	Avg Compression: 0.604249
# Article 335:	Compression: 0.572298	Avg Compression: 0.604093
# Article 336:	Compression: 0.726551	Avg Compression: 0.604332
# Article 337:	Compression: 0.707874	Avg Compression: 0.604447
# Article 338:	Compression: 0.683761	Avg Compression: 0.604484
# Article 339:	Compression: 0.661571	Avg Compression: 0.604581
# Article 340:	Compression: 0.600818	Avg Compression: 0.604537
# Article 341:	Compression: 0.533422	Avg Compression: 0.604497
# Article 342:	Compression: 0.562153	Avg Compression: 0.604456
# Article 343:	Compression: 0.753472	Avg Compression: 0.604458
# Article 344:	Compression: 0.737460	Avg Compression: 0.605008
# Article 345:	Compression: 0.726134	Avg Compression: 0.605680
# Article 346:	Compression: 0.576569	Avg Compression: 0.605382
# Article 347:	Compression: 0.844340	Avg Compression: 0.605397
# Article 348:	Compression: 0.637730	Avg Compression: 0.605643
# Article 349:	Compression: 0.657312	Avg Compression: 0.606178
# Article 350:	Compression: 0.743750	Avg Compression: 0.606179
# Article 351:	Compression: 0.631579	Avg Compression: 0.606179
# Article 352:	Compression: 0.593963	Avg Compression: 0.606027
# Article 353:	Compression: 0.503125	Avg Compression: 0.606025
# Article 354:	Compression: 0.595153	Avg Compression: 0.605862
# Article 355:	Compression: 0.635995	Avg Compression: 0.605927
# Article 356:	Compression: 0.615422	Avg Compression: 0.605941
# Article 357:	Compression: 0.603774	Avg Compression: 0.605941
# Article 358:	Compression: 0.664286	Avg Compression: 0.605943
# Article 359:	Compression: 0.651042	Avg Compression: 0.605944
# Article 360:	Compression: 0.621711	Avg Compression: 0.605944
# Article 361:	Compression: 0.517857	Avg Compression: 0.605943
# Article 362:	Compression: 0.750000	Avg Compression: 0.605947
# Article 363:	Compression: 0.505682	Avg Compression: 0.605945
# Article 364:	Compression: 0.631494	Avg Compression: 0.605946
# Article 365:	Compression: 0.714789	Avg Compression: 0.605948
# Article 366:	Compression: 0.646875	Avg Compression: 0.605950
# Article 367:	Compression: 0.711538	Avg Compression: 0.605951
# Article 368:	Compression: 0.640174	Avg Compression: 0.606007
# Article 369:	Compression: 0.518867	Avg Compression: 0.605803
# Article 370:	Compression: 0.507143	Avg Compression: 0.605801
# Article 371:	Compression: 0.470395	Avg Compression: 0.605799
# Article 372:	Compression: 0.580882	Avg Compression: 0.605799
# Article 373:	Compression: 0.704545	Avg Compression: 0.605800
# Article 374:	Compression: 0.459375	Avg Compression: 0.605798
# Article 375:	Compression: 0.487500	Avg Compression: 0.605796
# Article 376:	Compression: 0.526163	Avg Compression: 0.605795
# Article 377:	Compression: 0.636029	Avg Compression: 0.605796
# Article 378:	Compression: 0.526163	Avg Compression: 0.605794
# Article 379:	Compression: 0.522727	Avg Compression: 0.605793
# Article 380:	Compression: 0.598404	Avg Compression: 0.605793
# Article 381:	Compression: 0.605114	Avg Compression: 0.605793
# Article 382:	Compression: 0.678030	Avg Compression: 0.605794
# Article 383:	Compression: 0.588829	Avg Compression: 0.605679
# Article 384:	Compression: 0.589242	Avg Compression: 0.605506
# Article 385:	Compression: 0.692381	Avg Compression: 0.605651
# Article 386:	Compression: 0.588200	Avg Compression: 0.605582
# Article 387:	Compression: 0.609092	Avg Compression: 0.605603
# Article 388:	Compression: 0.614905	Avg Compression: 0.605605
# Article 389:	Compression: 0.600349	Avg Compression: 0.605559
# Article 390:	Compression: 0.585751	Avg Compression: 0.605382
# Article 391:	Compression: 0.603996	Avg Compression: 0.605374
# Article 392:	Compression: 0.624232	Avg Compression: 0.605470
# Article 393:	Compression: 0.636733	Avg Compression: 0.605586
# Article 394:	Compression: 0.586410	Avg Compression: 0.605454
# Article 395:	Compression: 0.702026	Avg Compression: 0.605762
# Article 396:	Compression: 0.737274	Avg Compression: 0.606228
# Article 397:	Compression: 0.602273	Avg Compression: 0.606228
# Article 398:	Compression: 0.582272	Avg Compression: 0.605896
# Article 399:	Compression: 0.592700	Avg Compression: 0.605866
# Article 400:	Compression: 0.647059	Avg Compression: 0.605866
# Article 401:	Compression: 0.593869	Avg Compression: 0.605859
# Article 402:	Compression: 0.702381	Avg Compression: 0.605860
# Article 403:	Compression: 0.565016	Avg Compression: 0.605210
# Article 404:	Compression: 0.561836	Avg Compression: 0.604330
# Article 405:	Compression: 0.583442	Avg Compression: 0.604108
# Article 406:	Compression: 0.652104	Avg Compression: 0.604251
# Article 407:	Compression: 0.629994	Avg Compression: 0.604307
# Article 408:	Compression: 0.599433	Avg Compression: 0.604296
# Article 409:	Compression: 0.599699	Avg Compression: 0.604293
# Article 410:	Compression: 0.570945	Avg Compression: 0.604219
# Article 411:	Compression: 0.513889	Avg Compression: 0.604218
# Article 412:	Compression: 0.616620	Avg Compression: 0.604276
# Article 413:	Compression: 0.545833	Avg Compression: 0.604275
# Article 414:	Compression: 0.637831	Avg Compression: 0.604641
# Article 415:	Compression: 0.713388	Avg Compression: 0.604668
# Article 416:	Compression: 0.592111	Avg Compression: 0.604594
# Article 417:	Compression: 0.618173	Avg Compression: 0.604613
# Article 418:	Compression: 0.634697	Avg Compression: 0.604695
# Article 419:	Compression: 0.664232	Avg Compression: 0.606073
# Article 420:	Compression: 0.574258	Avg Compression: 0.605782
# Article 421:	Compression: 0.563915	Avg Compression: 0.605633
# Article 422:	Compression: 0.538930	Avg Compression: 0.605596
# Article 423:	Compression: 0.633987	Avg Compression: 0.605602
# Article 424:	Compression: 0.538725	Avg Compression: 0.605535
# Article 425:	Compression: 0.586458	Avg Compression: 0.605533
# Article 426:	Compression: 0.615963	Avg Compression: 0.605607
# Article 427:	Compression: 0.561830	Avg Compression: 0.605298
# Article 428:	Compression: 0.609319	Avg Compression: 0.605313
# Article 429:	Compression: 0.699716	Avg Compression: 0.605463
# Article 430:	Compression: 0.607339	Avg Compression: 0.605468
# Article 431:	Compression: 0.610577	Avg Compression: 0.605468
# Article 432:	Compression: 0.667558	Avg Compression: 0.605478
# Article 433:	Compression: 0.578459	Avg Compression: 0.604878
# Article 434:	Compression: 0.588547	Avg Compression: 0.604807
# Article 435:	Compression: 0.640625	Avg Compression: 0.604807
# Article 436:	Compression: 0.714758	Avg Compression: 0.605062
# Article 437:	Compression: 0.670792	Avg Compression: 0.605328
# Article 438:	Compression: 0.697104	Avg Compression: 0.605602
# Article 439:	Compression: 0.752254	Avg Compression: 0.605842
# Article 440:	Compression: 0.744181	Avg Compression: 0.606130
# Article 441:	Compression: 0.739833	Avg Compression: 0.606296
# Article 442:	Compression: 0.575324	Avg Compression: 0.606044
# Article 443:	Compression: 0.561999	Avg Compression: 0.605987
# Article 444:	Compression: 0.604064	Avg Compression: 0.605967
# Article 445:	Compression: 0.718447	Avg Compression: 0.605985
# Article 446:	Compression: 0.610441	Avg Compression: 0.605999
# Article 447:	Compression: 0.477564	Avg Compression: 0.605998
# Article 448:	Compression: 0.625000	Avg Compression: 0.605998
# Article 449:	Compression: 0.568568	Avg Compression: 0.605859
# Article 450:	Compression: 0.739073	Avg Compression: 0.605916
# Article 451:	Compression: 0.738769	Avg Compression: 0.606143
# Article 452:	Compression: 0.642361	Avg Compression: 0.606143
# Article 453:	Compression: 0.639799	Avg Compression: 0.606262
# Article 454:	Compression: 0.635932	Avg Compression: 0.606274
# Article 455:	Compression: 0.796308	Avg Compression: 0.606392
# Article 456:	Compression: 0.756579	Avg Compression: 0.606393
# Article 457:	Compression: 0.727679	Avg Compression: 0.606394
# Article 458:	Compression: 0.727679	Avg Compression: 0.606395
# Article 459:	Compression: 0.562801	Avg Compression: 0.606364
# Article 460:	Compression: 0.565904	Avg Compression: 0.606332
# Article 461:	Compression: 0.563000	Avg Compression: 0.606130
# Article 462:	Compression: 0.726852	Avg Compression: 0.606131
# Article 463:	Compression: 0.607182	Avg Compression: 0.606134
# Article 464:	Compression: 0.802083	Avg Compression: 0.606136
# Article 465:	Compression: 0.807292	Avg Compression: 0.606137
# Article 466:	Compression: 0.555490	Avg Compression: 0.605802
# Article 467:	Compression: 0.609500	Avg Compression: 0.605817
# Article 468:	Compression: 0.676716	Avg Compression: 0.605865
# Article 469:	Compression: 0.578178	Avg Compression: 0.605829
# Article 470:	Compression: 0.582467	Avg Compression: 0.605799
# Article 471:	Compression: 0.610393	Avg Compression: 0.605800
# Article 472:	Compression: 0.662404	Avg Compression: 0.605827
# Article 473:	Compression: 0.723958	Avg Compression: 0.605827
# Article 474:	Compression: 0.723958	Avg Compression: 0.605828
# Article 475:	Compression: 0.723958	Avg Compression: 0.605829
# Article 476:	Compression: 0.723958	Avg Compression: 0.605829
# Article 477:	Compression: 0.723958	Avg Compression: 0.605830
# Article 478:	Compression: 0.723958	Avg Compression: 0.605831
# Article 479:	Compression: 0.723958	Avg Compression: 0.605832
# Article 480:	Compression: 0.723958	Avg Compression: 0.605832
# Article 481:	Compression: 0.723958	Avg Compression: 0.605833
# Article 482:	Compression: 0.723958	Avg Compression: 0.605834
# Article 483:	Compression: 0.723958	Avg Compression: 0.605835
# Article 484:	Compression: 0.723958	Avg Compression: 0.605835
# Article 485:	Compression: 0.593373	Avg Compression: 0.605834
# Article 486:	Compression: 0.666507	Avg Compression: 0.605973
# Article 487:	Compression: 0.639193	Avg Compression: 0.606025
# Article 488:	Compression: 0.673236	Avg Compression: 0.606041
# Article 489:	Compression: 0.564063	Avg Compression: 0.605786
# Article 490:	Compression: 0.667912	Avg Compression: 0.605821
# Article 491:	Compression: 0.671943	Avg Compression: 0.605934
# Article 492:	Compression: 0.749183	Avg Compression: 0.606124
# Article 493:	Compression: 0.622627	Avg Compression: 0.606140
# Article 494:	Compression: 0.605769	Avg Compression: 0.606140
# Article 495:	Compression: 0.785398	Avg Compression: 0.606354
# Article 496:	Compression: 0.612903	Avg Compression: 0.606354
# Article 497:	Compression: 0.666667	Avg Compression: 0.606358
# Article 498:	Compression: 0.608751	Avg Compression: 0.606359
# Article 499:	Compression: 0.555455	Avg Compression: 0.606345
# Article 500:	Compression: 0.584211	Avg Compression: 0.606337
# Article 501:	Compression: 0.770270	Avg Compression: 0.606339
# Article 502:	Compression: 0.621377	Avg Compression: 0.606350
# Article 503:	Compression: 0.637097	Avg Compression: 0.606350
# Article 504:	Compression: 0.616767	Avg Compression: 0.606364
# Article 505:	Compression: 0.666667	Avg Compression: 0.606365
# Article 506:	Compression: 0.631667	Avg Compression: 0.606419
# Article 507:	Compression: 0.687500	Avg Compression: 0.606420
# Article 508:	Compression: 0.577244	Avg Compression: 0.606385
# Article 509:	Compression: 0.586424	Avg Compression: 0.606363
# Article 510:	Compression: 0.632830	Avg Compression: 0.606444
# Article 511:	Compression: 0.666667	Avg Compression: 0.606444
